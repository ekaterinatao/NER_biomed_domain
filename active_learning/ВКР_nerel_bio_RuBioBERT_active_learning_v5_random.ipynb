# %% [markdown]
# <a href="https://colab.research.google.com/github/ekaterinatao/NER_biomed_domain/blob/main/active_learning/%D0%92%D0%9A%D0%A0_nerel_bio_RuBioBERT_active_learning_v5_random.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Инструменты
# Предобработанный дасасет [NEREL-BIO](https://huggingface.co/datasets/ekaterinatao/nerel_bio_ner_unnested)
#
# Исходная модель [RuBioBERT](https://huggingface.co/alexyalunin/RuBioBERT)

# %% [markdown]
# ### Установка зависимостей

# %%
# !pip install datasets accelerate evaluate wandb seqeval -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 12.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 18.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 12.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 3.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 kB 11.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 14.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 15.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 26.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 15.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 11.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 68.9 MB/s eta 0:00:00
#   Building wheel for seqeval (setup.py) ... done

# %%
import numpy as np
import pandas as pd
import random
from dataclasses import dataclass
import torch
from torch.nn.functional import softmax
import datasets
from datasets import Dataset, DatasetDict, concatenate_datasets
from transformers import (AutoTokenizer,
                          DataCollatorForTokenClassification,
                          AutoModelForTokenClassification,
                          TrainingArguments, Trainer,
                          pipeline)
from transformers.trainer_utils import get_last_checkpoint
import evaluate

import warnings
warnings.filterwarnings("ignore")

# %%
@dataclass
class TrainingConfig:
    seed = 64
    dataset = 'ekaterinatao/nerel_bio_ner_unnested'
    checkpoint = 'alexyalunin/RuBioBERT'
    hf_repo_id = "ekaterinatao/nerel-bio-RuBioBERT-al"
    n_labels = 45
    n_epochs = 10
    train_batch_size = 4
    eval_batch_size = 4
    device = "cuda" if torch.cuda.is_available() else "cpu"
    l_rate = 5e-05
    w_decay = 0.1
    warm_up = 0.1
    run_name = "RuBioBERT_AL_v5"

config = TrainingConfig()

# %%
seed = config.seed

random.seed(seed)
np.random.seed(seed)

torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %% [markdown]
# ### Скачивание датасета

# %%
dataset = datasets.load_dataset(config.dataset)
dataset
# Out:
# Downloading readme:   0%|          | 0.00/1.56k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/603k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/76.2k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/70.8k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/612 [00:00<?, ? examples/s]
# Generating valid split:   0%|          | 0/77 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/77 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'words', 'ner_tags'],
#         num_rows: 612
#     })
#     valid: Dataset({
#         features: ['id', 'words', 'ner_tags'],
#         num_rows: 77
#     })
#     test: Dataset({
#         features: ['id', 'words', 'ner_tags'],
#         num_rows: 77
#     })
# })

# %%
# Labels
url = 'https://raw.githubusercontent.com/ekaterinatao/NER_biomed_domain/main/labels.txt'
tags = pd.read_csv(url, names=['tag']).values.tolist()
tags = [item for sublist in tags for item in sublist]
tag_to_id = {tag: i for i, tag in enumerate(tags)}
id_to_tag = {i: tag for i, tag in enumerate(tags)}

# %% [markdown]
# ___
# ### Токенизация

# %%
tokenizer = AutoTokenizer.from_pretrained(config.checkpoint)
# Out:
# tokenizer_config.json:   0%|          | 0.00/413 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/1.78M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.75M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(examples["words"], truncation=True, max_length=512, is_split_into_words=True)

    labels = []
    for i, label in enumerate(examples[f"ner_tags"]):
        word_idxs = tokenized_inputs.word_ids(batch_index=i)  # Map tokens to their respective word.
        previous_word_idx = None
        label_ids = []
        for word_idx in word_idxs:
            if word_idx is None:
                label_ids.append(-100) # Set the special tokens to -100.
            elif word_idx != previous_word_idx:  # Only label the first token of a given word.
                label_ids.append(label[word_idx])
            else:
                label_ids.append(-100)
            previous_word_idx = word_idx
        labels.append(label_ids)

    tokenized_inputs["labels"] = labels
    return tokenized_inputs

# %%
tokenized_dataset = dataset.map(
    tokenize_and_align_labels, batched=True,
    #remove_columns = ['id', 'words', 'ner_tags']
)
tokenized_dataset
# Out:
# Map:   0%|          | 0/612 [00:00<?, ? examples/s]
# Map:   0%|          | 0/77 [00:00<?, ? examples/s]
# Map:   0%|          | 0/77 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'words', 'ner_tags', 'input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 612
#     })
#     valid: Dataset({
#         features: ['id', 'words', 'ner_tags', 'input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 77
#     })
#     test: Dataset({
#         features: ['id', 'words', 'ner_tags', 'input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 77
#     })
# })

# %% [markdown]
# # Обучение модели

# %%
seqeval = evaluate.load("seqeval")

def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=2)

    true_predictions = [
        [tags[p] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]
    true_labels = [
        [tags[l] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]

    results = seqeval.compute(predictions=true_predictions, references=true_labels)
    return {
        "precision": results["overall_precision"],
        "recall": results["overall_recall"],
        "f1": results["overall_f1"],
        "accuracy": results["overall_accuracy"],
    }
# Out:
# Downloading builder script:   0%|          | 0.00/6.34k [00:00<?, ?B/s]

# %%
def choose_samples_random(test_predictions, n_tokens) -> np.ndarray:
    """Функция для рандомного отбора примеров для разметки"""

    return random.sample(range(test_predictions.shape[0]), n_tokens)

# %%
data_collator = DataCollatorForTokenClassification(tokenizer=tokenizer)

# %%
model = AutoModelForTokenClassification.from_pretrained(
    config.checkpoint, num_labels=config.n_labels, id2label=id_to_tag, label2id=tag_to_id
)
# Out:
# config.json:   0%|          | 0.00/889 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at alexyalunin/RuBioBERT and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
print(f'device is {config.device}')
# Out:
# device is cuda

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
import wandb
wandb.login()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
import os
os.environ["WANDB_PROJECT"]="ner_bert_nerel_bio"

# %%
def train_and_predict(
    train_dataset, eval_dataset, test_dataset,
    model, tokenizer, data_collator, compute_metrics
):
    "Функция для тренировки модели, сохранения метрик и предсказаний"

    global config
    training_args = TrainingArguments(
        output_dir=config.hf_repo_id,
        num_train_epochs=config.n_epochs,
        learning_rate=config.l_rate,
        weight_decay=config.w_decay,
        warmup_ratio=config.warm_up,
        per_device_train_batch_size=config.train_batch_size,
        per_device_eval_batch_size=config.eval_batch_size,
        group_by_length=True,
        optim="adamw_torch",
        lr_scheduler_type="cosine",
        evaluation_strategy="epoch",
        seed = config.seed,
        data_seed = config.seed,
        push_to_hub=True,
        save_strategy="no",
        report_to="wandb",
        logging_steps=16,
        run_name=config.run_name,
    )

    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=eval_dataset,
        tokenizer=tokenizer,
        data_collator=data_collator,
        compute_metrics=compute_metrics,
    )

    train_result = trainer.train()
    test_predictions = trainer.predict(
        test_dataset, metric_key_prefix="pred"
    )
    metrics = {}
    metrics['train_loss'] = train_result.metrics['train_loss']
    metrics.update(trainer.evaluate(eval_dataset))
    metrics.update(test_predictions.metrics)
    probas = test_predictions.predictions

    return metrics, probas, trainer

# %%
def run_active_learning(
    dataset, al_iters, init_train_size, choose_tokens,
    model, tokenizer, data_collator, compute_metrics
):
    "Функция для реализации цикла активного обучения"

    train_dataset = dataset['train'].select(
        random.sample(
            range(dataset['train'].num_rows),
            int(dataset['train'].num_rows * init_train_size)
        )
    )
    test_dataset = dataset['train'].filter(
        lambda s: s['id'] not in train_dataset['id']
    )
    all_metrics = {}

    for iter in range(al_iters):
        train_size = train_dataset.num_rows
        print(f'Training using {train_size} samples')

        eval_metrics, test_predictions, trainer = train_and_predict(
            train_dataset, dataset['valid'], test_dataset,
            model, tokenizer, data_collator, compute_metrics
        )

        all_metrics[f'{iter}'] = {'metrics': eval_metrics, 'train_size': train_size}

        if test_dataset.num_rows >= choose_tokens:
            new_args = choose_samples_random(test_predictions, choose_tokens)
            new_train_samples = test_dataset.select(new_args)
            extended_train_dataset = concatenate_datasets(
                [train_dataset, new_train_samples]
            )

            train_dataset = extended_train_dataset
            test_dataset = dataset['train'].filter(
                lambda s: s['id'] not in train_dataset['id']
            )

    return all_metrics, trainer

# %%
metrics, trainer = run_active_learning(
    dataset=tokenized_dataset, al_iters=10, init_train_size=0.1, choose_tokens=61,
    model=model, tokenizer=tokenizer,
    data_collator=data_collator, compute_metrics=compute_metrics
)
# Out:
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]
# Training using 61 samples
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# wandb: Currently logged in as: taoea. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.4
# Run data is saved locally in <code>/content/wandb/run-20240322_202742-9wsd3i8l</code>
# Syncing run <strong><a href='https://wandb.ai/taoea/ner_bert_nerel_bio/runs/9wsd3i8l' target="_blank">RuBioBERT_AL_v5</a></strong> to <a href='https://wandb.ai/taoea/ner_bert_nerel_bio' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/taoea/ner_bert_nerel_bio' target="_blank">https://wandb.ai/taoea/ner_bert_nerel_bio</a>
#  View run at <a href='https://wandb.ai/taoea/ner_bert_nerel_bio/runs/9wsd3i8l' target="_blank">https://wandb.ai/taoea/ner_bert_nerel_bio/runs/9wsd3i8l</a>
#     <div>
#
#       <progress value='160' max='160' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [160/160 00:25, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.385500</td>
#       <td>2.925789</td>
#       <td>0.049296</td>
#       <td>0.001642</td>
#       <td>0.003177</td>
#       <td>0.158042</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.267000</td>
#       <td>2.012529</td>
#       <td>0.420856</td>
#       <td>0.343574</td>
#       <td>0.378309</td>
#       <td>0.537685</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.350600</td>
#       <td>1.434593</td>
#       <td>0.603119</td>
#       <td>0.562383</td>
#       <td>0.582039</td>
#       <td>0.693551</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.860100</td>
#       <td>1.240490</td>
#       <td>0.645208</td>
#       <td>0.620544</td>
#       <td>0.632636</td>
#       <td>0.727894</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.663400</td>
#       <td>1.124020</td>
#       <td>0.660775</td>
#       <td>0.640009</td>
#       <td>0.650226</td>
#       <td>0.742191</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.472900</td>
#       <td>1.049967</td>
#       <td>0.691080</td>
#       <td>0.670497</td>
#       <td>0.680633</td>
#       <td>0.770319</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.396700</td>
#       <td>1.000270</td>
#       <td>0.703881</td>
#       <td>0.689024</td>
#       <td>0.696374</td>
#       <td>0.781974</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.322900</td>
#       <td>1.009882</td>
#       <td>0.695569</td>
#       <td>0.684803</td>
#       <td>0.690144</td>
#       <td>0.779021</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.295800</td>
#       <td>1.000625</td>
#       <td>0.702774</td>
#       <td>0.689259</td>
#       <td>0.695951</td>
#       <td>0.784771</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.282500</td>
#       <td>1.000039</td>
#       <td>0.702774</td>
#       <td>0.689259</td>
#       <td>0.695951</td>
#       <td>0.784771</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:00]
#     </div>
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]
# Training using 122 samples
#     <div>
#
#       <progress value='310' max='310' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [310/310 00:38, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.615300</td>
#       <td>0.894986</td>
#       <td>0.717672</td>
#       <td>0.702861</td>
#       <td>0.710190</td>
#       <td>0.796115</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.456500</td>
#       <td>0.813268</td>
#       <td>0.751309</td>
#       <td>0.740385</td>
#       <td>0.745807</td>
#       <td>0.819580</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.310000</td>
#       <td>0.792901</td>
#       <td>0.742514</td>
#       <td>0.738508</td>
#       <td>0.740506</td>
#       <td>0.818182</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.224600</td>
#       <td>0.807064</td>
#       <td>0.748819</td>
#       <td>0.743199</td>
#       <td>0.745998</td>
#       <td>0.823310</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.144700</td>
#       <td>0.794928</td>
#       <td>0.749473</td>
#       <td>0.750000</td>
#       <td>0.749736</td>
#       <td>0.824864</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.104100</td>
#       <td>0.821863</td>
#       <td>0.755682</td>
#       <td>0.748593</td>
#       <td>0.752121</td>
#       <td>0.828438</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.085200</td>
#       <td>0.838298</td>
#       <td>0.749296</td>
#       <td>0.748593</td>
#       <td>0.748944</td>
#       <td>0.825330</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.067600</td>
#       <td>0.864175</td>
#       <td>0.748113</td>
#       <td>0.743902</td>
#       <td>0.746002</td>
#       <td>0.825486</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.048400</td>
#       <td>0.852054</td>
#       <td>0.753599</td>
#       <td>0.748827</td>
#       <td>0.751206</td>
#       <td>0.827506</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.048800</td>
#       <td>0.854280</td>
#       <td>0.753072</td>
#       <td>0.747420</td>
#       <td>0.750235</td>
#       <td>0.827195</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:00]
#     </div>
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]
# Training using 183 samples
#     <div>
#
#       <progress value='460' max='460' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [460/460 00:53, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.228600</td>
#       <td>0.740444</td>
#       <td>0.732295</td>
#       <td>0.727486</td>
#       <td>0.729882</td>
#       <td>0.818026</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.115200</td>
#       <td>0.690849</td>
#       <td>0.754133</td>
#       <td>0.748827</td>
#       <td>0.751471</td>
#       <td>0.830614</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.118700</td>
#       <td>0.738394</td>
#       <td>0.773243</td>
#       <td>0.750938</td>
#       <td>0.761927</td>
#       <td>0.841181</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.092700</td>
#       <td>0.729283</td>
#       <td>0.761770</td>
#       <td>0.755159</td>
#       <td>0.758450</td>
#       <td>0.835742</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.071300</td>
#       <td>0.745157</td>
#       <td>0.772999</td>
#       <td>0.758677</td>
#       <td>0.765771</td>
#       <td>0.841647</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.036500</td>
#       <td>0.776008</td>
#       <td>0.772911</td>
#       <td>0.761492</td>
#       <td>0.767159</td>
#       <td>0.843046</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.024700</td>
#       <td>0.788789</td>
#       <td>0.775655</td>
#       <td>0.771107</td>
#       <td>0.773374</td>
#       <td>0.847397</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.018800</td>
#       <td>0.782914</td>
#       <td>0.777410</td>
#       <td>0.771576</td>
#       <td>0.774482</td>
#       <td>0.847086</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.015700</td>
#       <td>0.786250</td>
#       <td>0.776704</td>
#       <td>0.772514</td>
#       <td>0.774603</td>
#       <td>0.847863</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.019800</td>
#       <td>0.786998</td>
#       <td>0.777045</td>
#       <td>0.773218</td>
#       <td>0.775126</td>
#       <td>0.848329</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:00]
#     </div>
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]
# Training using 244 samples
#     <div>
#
#       <progress value='610' max='610' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [610/610 01:08, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.143300</td>
#       <td>0.675301</td>
#       <td>0.771938</td>
#       <td>0.761257</td>
#       <td>0.766560</td>
#       <td>0.843512</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.102000</td>
#       <td>0.676989</td>
#       <td>0.791317</td>
#       <td>0.773687</td>
#       <td>0.782402</td>
#       <td>0.854235</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.107600</td>
#       <td>0.725323</td>
#       <td>0.762415</td>
#       <td>0.766886</td>
#       <td>0.764644</td>
#       <td>0.841336</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.068500</td>
#       <td>0.757050</td>
#       <td>0.767040</td>
#       <td>0.770638</td>
#       <td>0.768835</td>
#       <td>0.845066</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.036100</td>
#       <td>0.772777</td>
#       <td>0.776196</td>
#       <td>0.780019</td>
#       <td>0.778103</td>
#       <td>0.849262</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.022500</td>
#       <td>0.795807</td>
#       <td>0.778952</td>
#       <td>0.777674</td>
#       <td>0.778312</td>
#       <td>0.850505</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.009300</td>
#       <td>0.817947</td>
#       <td>0.783008</td>
#       <td>0.780253</td>
#       <td>0.781628</td>
#       <td>0.852214</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.010900</td>
#       <td>0.835956</td>
#       <td>0.782957</td>
#       <td>0.780019</td>
#       <td>0.781485</td>
#       <td>0.850971</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.005300</td>
#       <td>0.836692</td>
#       <td>0.781477</td>
#       <td>0.781660</td>
#       <td>0.781569</td>
#       <td>0.851748</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.007200</td>
#       <td>0.836619</td>
#       <td>0.782211</td>
#       <td>0.781660</td>
#       <td>0.781935</td>
#       <td>0.851748</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:00]
#     </div>
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]
# Training using 305 samples
#     <div>
#
#       <progress value='770' max='770' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [770/770 01:23, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.096700</td>
#       <td>0.794777</td>
#       <td>0.764184</td>
#       <td>0.767589</td>
#       <td>0.765883</td>
#       <td>0.832479</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.080900</td>
#       <td>0.708352</td>
#       <td>0.775838</td>
#       <td>0.771107</td>
#       <td>0.773465</td>
#       <td>0.849106</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.091300</td>
#       <td>0.750277</td>
#       <td>0.769499</td>
#       <td>0.777439</td>
#       <td>0.773448</td>
#       <td>0.843512</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.045900</td>
#       <td>0.754095</td>
#       <td>0.774693</td>
#       <td>0.785413</td>
#       <td>0.780016</td>
#       <td>0.848640</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.030900</td>
#       <td>0.720503</td>
#       <td>0.795719</td>
#       <td>0.802064</td>
#       <td>0.798879</td>
#       <td>0.863403</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.024000</td>
#       <td>0.751231</td>
#       <td>0.792047</td>
#       <td>0.794090</td>
#       <td>0.793067</td>
#       <td>0.858897</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.012300</td>
#       <td>0.763706</td>
#       <td>0.793047</td>
#       <td>0.797139</td>
#       <td>0.795088</td>
#       <td>0.860917</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.011800</td>
#       <td>0.775044</td>
#       <td>0.794441</td>
#       <td>0.797608</td>
#       <td>0.796021</td>
#       <td>0.860606</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.004800</td>
#       <td>0.777719</td>
#       <td>0.796266</td>
#       <td>0.800188</td>
#       <td>0.798222</td>
#       <td>0.862315</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.007200</td>
#       <td>0.778778</td>
#       <td>0.796409</td>
#       <td>0.800891</td>
#       <td>0.798644</td>
#       <td>0.862626</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:00]
#     </div>
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]
# Training using 366 samples
#     <div>
#
#       <progress value='920' max='920' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [920/920 01:37, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.091800</td>
#       <td>0.709285</td>
#       <td>0.786099</td>
#       <td>0.787758</td>
#       <td>0.786927</td>
#       <td>0.854856</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.066300</td>
#       <td>0.714021</td>
#       <td>0.798381</td>
#       <td>0.786585</td>
#       <td>0.792439</td>
#       <td>0.861538</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.041200</td>
#       <td>0.728401</td>
#       <td>0.785266</td>
#       <td>0.792448</td>
#       <td>0.788841</td>
#       <td>0.857809</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.018900</td>
#       <td>0.795005</td>
#       <td>0.783048</td>
#       <td>0.782129</td>
#       <td>0.782588</td>
#       <td>0.853147</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.014100</td>
#       <td>0.828172</td>
#       <td>0.771613</td>
#       <td>0.782833</td>
#       <td>0.777183</td>
#       <td>0.850039</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.012700</td>
#       <td>0.817127</td>
#       <td>0.782254</td>
#       <td>0.787758</td>
#       <td>0.784996</td>
#       <td>0.856099</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.006900</td>
#       <td>0.826447</td>
#       <td>0.783664</td>
#       <td>0.787523</td>
#       <td>0.785589</td>
#       <td>0.855789</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.004800</td>
#       <td>0.847667</td>
#       <td>0.783714</td>
#       <td>0.787758</td>
#       <td>0.785731</td>
#       <td>0.856721</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.002900</td>
#       <td>0.848415</td>
#       <td>0.785398</td>
#       <td>0.789634</td>
#       <td>0.787510</td>
#       <td>0.857498</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.002400</td>
#       <td>0.848006</td>
#       <td>0.786514</td>
#       <td>0.790572</td>
#       <td>0.788538</td>
#       <td>0.858120</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:00]
#     </div>
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]
# Training using 427 samples
#     <div>
#
#       <progress value='1070' max='1070' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1070/1070 01:51, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.116600</td>
#       <td>0.723583</td>
#       <td>0.779212</td>
#       <td>0.778846</td>
#       <td>0.779029</td>
#       <td>0.853613</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.069800</td>
#       <td>0.796252</td>
#       <td>0.768607</td>
#       <td>0.777439</td>
#       <td>0.772998</td>
#       <td>0.848640</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.054100</td>
#       <td>0.795686</td>
#       <td>0.774292</td>
#       <td>0.775563</td>
#       <td>0.774927</td>
#       <td>0.847708</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.032900</td>
#       <td>0.810021</td>
#       <td>0.778396</td>
#       <td>0.787523</td>
#       <td>0.782933</td>
#       <td>0.854235</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.018000</td>
#       <td>0.828697</td>
#       <td>0.777003</td>
#       <td>0.784475</td>
#       <td>0.780721</td>
#       <td>0.852059</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.008800</td>
#       <td>0.862987</td>
#       <td>0.781641</td>
#       <td>0.790807</td>
#       <td>0.786197</td>
#       <td>0.855789</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.006500</td>
#       <td>0.849705</td>
#       <td>0.784078</td>
#       <td>0.794559</td>
#       <td>0.789284</td>
#       <td>0.856566</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.005400</td>
#       <td>0.884361</td>
#       <td>0.784255</td>
#       <td>0.791979</td>
#       <td>0.788098</td>
#       <td>0.856410</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.001800</td>
#       <td>0.892022</td>
#       <td>0.784173</td>
#       <td>0.792448</td>
#       <td>0.788289</td>
#       <td>0.856721</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.001400</td>
#       <td>0.892597</td>
#       <td>0.783809</td>
#       <td>0.792448</td>
#       <td>0.788105</td>
#       <td>0.856566</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:00]
#     </div>
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]
# Training using 488 samples
#     <div>
#
#       <progress value='1220' max='1220' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1220/1220 02:05, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.047600</td>
#       <td>0.805920</td>
#       <td>0.787367</td>
#       <td>0.798077</td>
#       <td>0.792686</td>
#       <td>0.857187</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.054900</td>
#       <td>0.846034</td>
#       <td>0.769249</td>
#       <td>0.773218</td>
#       <td>0.771228</td>
#       <td>0.848019</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.050300</td>
#       <td>0.779469</td>
#       <td>0.772414</td>
#       <td>0.787992</td>
#       <td>0.780125</td>
#       <td>0.851904</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.023200</td>
#       <td>0.862723</td>
#       <td>0.781046</td>
#       <td>0.784709</td>
#       <td>0.782873</td>
#       <td>0.854701</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.018300</td>
#       <td>0.849529</td>
#       <td>0.782589</td>
#       <td>0.792683</td>
#       <td>0.787603</td>
#       <td>0.857498</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.010500</td>
#       <td>0.860389</td>
#       <td>0.791608</td>
#       <td>0.796435</td>
#       <td>0.794014</td>
#       <td>0.861849</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.006300</td>
#       <td>0.870849</td>
#       <td>0.794268</td>
#       <td>0.799484</td>
#       <td>0.796868</td>
#       <td>0.863869</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.003400</td>
#       <td>0.896810</td>
#       <td>0.792680</td>
#       <td>0.802533</td>
#       <td>0.797576</td>
#       <td>0.863869</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.001700</td>
#       <td>0.900236</td>
#       <td>0.792904</td>
#       <td>0.801829</td>
#       <td>0.797341</td>
#       <td>0.863869</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.002200</td>
#       <td>0.901241</td>
#       <td>0.793271</td>
#       <td>0.801829</td>
#       <td>0.797527</td>
#       <td>0.864180</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:00]
#     </div>
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]
# Training using 549 samples
#     <div>
#
#       <progress value='1380' max='1380' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1380/1380 02:20, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.101000</td>
#       <td>0.747618</td>
#       <td>0.795375</td>
#       <td>0.798546</td>
#       <td>0.796957</td>
#       <td>0.864336</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.037800</td>
#       <td>0.777137</td>
#       <td>0.779043</td>
#       <td>0.786351</td>
#       <td>0.782680</td>
#       <td>0.856099</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.051600</td>
#       <td>0.765528</td>
#       <td>0.790412</td>
#       <td>0.800422</td>
#       <td>0.795386</td>
#       <td>0.863869</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.022500</td>
#       <td>0.827802</td>
#       <td>0.789302</td>
#       <td>0.792448</td>
#       <td>0.790872</td>
#       <td>0.859207</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.021400</td>
#       <td>0.819347</td>
#       <td>0.782922</td>
#       <td>0.789165</td>
#       <td>0.786031</td>
#       <td>0.859363</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.005400</td>
#       <td>0.853540</td>
#       <td>0.791132</td>
#       <td>0.795028</td>
#       <td>0.793075</td>
#       <td>0.861383</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.005900</td>
#       <td>0.863786</td>
#       <td>0.788847</td>
#       <td>0.792917</td>
#       <td>0.790877</td>
#       <td>0.860761</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.002300</td>
#       <td>0.883106</td>
#       <td>0.791385</td>
#       <td>0.797139</td>
#       <td>0.794252</td>
#       <td>0.862471</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.003700</td>
#       <td>0.885119</td>
#       <td>0.792782</td>
#       <td>0.798546</td>
#       <td>0.795654</td>
#       <td>0.862937</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.001300</td>
#       <td>0.886977</td>
#       <td>0.792734</td>
#       <td>0.798311</td>
#       <td>0.795513</td>
#       <td>0.862782</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:00]
#     </div>
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]
# Training using 610 samples
#     <div>
#
#       <progress value='1530' max='1530' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1530/1530 02:33, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.076900</td>
#       <td>0.764343</td>
#       <td>0.794254</td>
#       <td>0.803940</td>
#       <td>0.799068</td>
#       <td>0.862005</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.045300</td>
#       <td>0.796443</td>
#       <td>0.778217</td>
#       <td>0.784240</td>
#       <td>0.781217</td>
#       <td>0.853147</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.034000</td>
#       <td>0.806526</td>
#       <td>0.788923</td>
#       <td>0.795028</td>
#       <td>0.791964</td>
#       <td>0.863092</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.010700</td>
#       <td>0.854305</td>
#       <td>0.795133</td>
#       <td>0.804644</td>
#       <td>0.799860</td>
#       <td>0.863714</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.014100</td>
#       <td>0.846806</td>
#       <td>0.793855</td>
#       <td>0.811914</td>
#       <td>0.802783</td>
#       <td>0.865113</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.011600</td>
#       <td>0.862487</td>
#       <td>0.801950</td>
#       <td>0.810038</td>
#       <td>0.805974</td>
#       <td>0.867599</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.000900</td>
#       <td>0.881236</td>
#       <td>0.803150</td>
#       <td>0.813321</td>
#       <td>0.808203</td>
#       <td>0.870085</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.001700</td>
#       <td>0.888878</td>
#       <td>0.801108</td>
#       <td>0.814259</td>
#       <td>0.807630</td>
#       <td>0.870552</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.001400</td>
#       <td>0.891280</td>
#       <td>0.800833</td>
#       <td>0.811914</td>
#       <td>0.806335</td>
#       <td>0.869464</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000800</td>
#       <td>0.892077</td>
#       <td>0.801850</td>
#       <td>0.813321</td>
#       <td>0.807545</td>
#       <td>0.870241</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:00]
#     </div>

# %%
wandb.finish()
# Out:
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>▁▆▇▇▇▇██▇███████████████████████████████</td></tr><tr><td>eval/f1</td><td>▁▆▇▇▇▇██▇███████████████████████████████</td></tr><tr><td>eval/loss</td><td>█▃▂▂▂▁▁▂▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▂▁▁▂▂▂▂▂▂▁▁▂▂▁▂▂▂</td></tr><tr><td>eval/precision</td><td>▁▆▇▇▇▇██▇███████████████████████████████</td></tr><tr><td>eval/recall</td><td>▁▆▇▇▇▇▇▇▇▇██████████████████████████████</td></tr><tr><td>eval/runtime</td><td>▄▂▇▁▁▁▁▂▆▁▂▂▁▇▂▂▂▂▆▆▂▂▁▂▂█▂▁▂▂▂▂▂▂▂▂▂▂▂▆</td></tr><tr><td>eval/samples_per_second</td><td>▅▇▂██▇▇▇▂█▇▇▇▂▇▆▇▇▃▂▇▇▇▇▇▁▇█▇▇▆▇▇▇▇▇▆▇▇▃</td></tr><tr><td>eval/steps_per_second</td><td>▅▇▂██▇▇▇▂█▇▇▇▂▇▆▇▇▃▂▇▇▇▇▇▁▇█▇▇▆▇▇▇▇▇▆▇▇▃</td></tr><tr><td>train/epoch</td><td>▄▂▅▂▄▇▃▅▇▂▄▆█▂▄▆▇▂▃▅▆█▂▃▄▆▇▁▂▃▅▆▇█▂▃▄▅▆█</td></tr><tr><td>train/global_step</td><td>▁▁▂▁▂▃▂▃▃▁▂▃▄▂▃▄▅▁▂▃▅▆▂▃▄▅▆▁▂▃▄▅▆▇▂▃▄▅▆█</td></tr><tr><td>train/grad_norm</td><td>▂▂▂▃▂▃▂▅▃▃▁▂▃▁▄▁▁▂▂▂▁▁▁▁▂▁█▂▂▂▁▁▁▅▄▁▁▂▁▁</td></tr><tr><td>train/learning_rate</td><td>▂▇█▆▁▆▄▂▇▅▁█▇▄▃▁█▇▄▂▁█▆▅▃▁▃█▇▅▃▂▁██▆▅▄▂▁</td></tr><tr><td>train/loss</td><td>█▇▇▃▁▂▁▄▂▁▁▃▂▁▁▁▂▂▁▁▁▂▁▁▁▁▃▂▂▁▁▁▁▂▂▁▁▁▁▁</td></tr><tr><td>train/total_flos</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train/train_loss</td><td>█▂▁▁▁▁▁▁▁▁</td></tr><tr><td>train/train_runtime</td><td>▁▁▂▃▄▅▆▆▇█</td></tr><tr><td>train/train_samples_per_second</td><td>▁▅▆▆▇▇▇███</td></tr><tr><td>train/train_steps_per_second</td><td>▁▅▆▆▇▇▇███</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>0.87024</td></tr><tr><td>eval/f1</td><td>0.80754</td></tr><tr><td>eval/loss</td><td>0.89208</td></tr><tr><td>eval/precision</td><td>0.80185</td></tr><tr><td>eval/recall</td><td>0.81332</td></tr><tr><td>eval/runtime</td><td>1.1031</td></tr><tr><td>eval/samples_per_second</td><td>69.802</td></tr><tr><td>eval/steps_per_second</td><td>18.13</td></tr><tr><td>train/epoch</td><td>10.0</td></tr><tr><td>train/global_step</td><td>1530</td></tr><tr><td>train/grad_norm</td><td>0.06008</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>train/loss</td><td>0.0008</td></tr><tr><td>train/total_flos</td><td>862353118909440.0</td></tr><tr><td>train/train_loss</td><td>0.0181</td></tr><tr><td>train/train_runtime</td><td>154.108</td></tr><tr><td>train/train_samples_per_second</td><td>39.583</td></tr><tr><td>train/train_steps_per_second</td><td>9.928</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">RuBioBERT_AL_v5</strong> at: <a href='https://wandb.ai/taoea/ner_bert_nerel_bio/runs/9wsd3i8l' target="_blank">https://wandb.ai/taoea/ner_bert_nerel_bio/runs/9wsd3i8l</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240322_202742-9wsd3i8l/logs</code>

# %%
metrics
# Out:
# {'0': {'metrics': {'train_loss': 1.0297480553388596,
#    'eval_loss': 1.0000391006469727,
#    'eval_precision': 0.7027737924438068,
#    'eval_recall': 0.6892589118198874,
#    'eval_f1': 0.6959507459152261,
#    'eval_accuracy': 0.7847707847707848,
#    'eval_runtime': 0.8741,
#    'eval_samples_per_second': 88.094,
#    'eval_steps_per_second': 22.882,
#    'epoch': 10.0,
#    'pred_loss': 0.7819056510925293,
#    'pred_precision': 0.7273767885532592,
#    'pred_recall': 0.7065291247143122,
#    'pred_f1': 0.7168014037726389,
#    'pred_accuracy': 0.8206197854588796,
#    'pred_runtime': 6.8132,
#    'pred_samples_per_second': 80.873,
#    'pred_steps_per_second': 20.255},
#   'train_size': 61},
#  '1': {'metrics': {'train_loss': 0.20622231498841317,
#    'eval_loss': 0.8542803525924683,
#    'eval_precision': 0.7530718336483931,
#    'eval_recall': 0.7474202626641651,
#    'eval_f1': 0.7502354048964218,
#    'eval_accuracy': 0.8271950271950272,
#    'eval_runtime': 0.8739,
#    'eval_samples_per_second': 88.109,
#    'eval_steps_per_second': 22.885,
#    'epoch': 10.0,
#    'pred_loss': 0.6619196534156799,
#    'pred_precision': 0.7750351123595506,
#    'pred_recall': 0.7644329004329005,
#    'pred_f1': 0.769697498038532,
#    'pred_accuracy': 0.8596018870095501,
#    'pred_runtime': 6.1857,
#    'pred_samples_per_second': 79.214,
#    'pred_steps_per_second': 19.884},
#   'train_size': 122},
#  '2': {'metrics': {'train_loss': 0.08408257468886997,
#    'eval_loss': 0.7869976758956909,
#    'eval_precision': 0.777044543954749,
#    'eval_recall': 0.773217636022514,
#    'eval_f1': 0.775126366521688,
#    'eval_accuracy': 0.8483294483294483,
#    'eval_runtime': 0.8853,
#    'eval_samples_per_second': 86.972,
#    'eval_steps_per_second': 22.59,
#    'epoch': 10.0,
#    'pred_loss': 0.6641528606414795,
#    'pred_precision': 0.7927247769389156,
#    'pred_recall': 0.7767931320963722,
#    'pred_f1': 0.7846780961515406,
#    'pred_accuracy': 0.869870239476738,
#    'pred_runtime': 5.3934,
#    'pred_samples_per_second': 79.542,
#    'pred_steps_per_second': 20.025},
#   'train_size': 183},
#  '3': {'metrics': {'train_loss': 0.05874228420071915,
#    'eval_loss': 0.8366186022758484,
#    'eval_precision': 0.7822107486505515,
#    'eval_recall': 0.7816604127579737,
#    'eval_f1': 0.7819354838709678,
#    'eval_accuracy': 0.8517482517482518,
#    'eval_runtime': 0.8794,
#    'eval_samples_per_second': 87.56,
#    'eval_steps_per_second': 22.743,
#    'epoch': 10.0,
#    'pred_loss': 0.6413569450378418,
#    'pred_precision': 0.8038470672049395,
#    'pred_recall': 0.7931115276476102,
#    'pred_f1': 0.7984432126430004,
#    'pred_accuracy': 0.8789066144229872,
#    'pred_runtime': 4.3327,
#    'pred_samples_per_second': 84.936,
#    'pred_steps_per_second': 21.234},
#   'train_size': 244},
#  '4': {'metrics': {'train_loss': 0.04239711359463777,
#    'eval_loss': 0.7787779569625854,
#    'eval_precision': 0.7964085820895522,
#    'eval_recall': 0.800891181988743,
#    'eval_f1': 0.7986435921421889,
#    'eval_accuracy': 0.8626262626262626,
#    'eval_runtime': 0.8857,
#    'eval_samples_per_second': 86.935,
#    'eval_steps_per_second': 22.58,
#    'epoch': 10.0,
#    'pred_loss': 0.6197212338447571,
#    'pred_precision': 0.8137052341597796,
#    'pred_recall': 0.8020591729365842,
#    'pred_f1': 0.8078402324720094,
#    'pred_accuracy': 0.885062628528697,
#    'pred_runtime': 3.6901,
#    'pred_samples_per_second': 83.194,
#    'pred_steps_per_second': 20.866},
#   'train_size': 305},
#  '5': {'metrics': {'train_loss': 0.02963508597737097,
#    'eval_loss': 0.8480064868927002,
#    'eval_precision': 0.7865142323845077,
#    'eval_recall': 0.7905722326454033,
#    'eval_f1': 0.7885380116959064,
#    'eval_accuracy': 0.8581196581196581,
#    'eval_runtime': 1.1308,
#    'eval_samples_per_second': 68.095,
#    'eval_steps_per_second': 17.687,
#    'epoch': 10.0,
#    'pred_loss': 0.6714668869972229,
#    'pred_precision': 0.8182012390514847,
#    'pred_recall': 0.8040025190679448,
#    'pred_f1': 0.811039740241406,
#    'pred_accuracy': 0.8861642190819248,
#    'pred_runtime': 3.198,
#    'pred_samples_per_second': 76.924,
#    'pred_steps_per_second': 19.387},
#   'train_size': 366},
#  '6': {'metrics': {'train_loss': 0.029959486263029488,
#    'eval_loss': 0.8925970792770386,
#    'eval_precision': 0.78380886105312,
#    'eval_recall': 0.7924484052532833,
#    'eval_f1': 0.7881049562682217,
#    'eval_accuracy': 0.8565656565656565,
#    'eval_runtime': 0.8815,
#    'eval_samples_per_second': 87.355,
#    'eval_steps_per_second': 22.69,
#    'epoch': 10.0,
#    'pred_loss': 0.6797716021537781,
#    'pred_precision': 0.8127728221673942,
#    'pred_recall': 0.8046786922209695,
#    'pred_f1': 0.8087055046737796,
#    'pred_accuracy': 0.8832675222112537,
#    'pred_runtime': 2.188,
#    'pred_samples_per_second': 84.553,
#    'pred_steps_per_second': 21.481},
#   'train_size': 427},
#  '7': {'metrics': {'train_loss': 0.02569183171192398,
#    'eval_loss': 0.9012412428855896,
#    'eval_precision': 0.7932714617169374,
#    'eval_recall': 0.801829268292683,
#    'eval_f1': 0.7975274084441336,
#    'eval_accuracy': 0.8641802641802642,
#    'eval_runtime': 0.8785,
#    'eval_samples_per_second': 87.652,
#    'eval_steps_per_second': 22.767,
#    'epoch': 10.0,
#    'pred_loss': 0.6619004011154175,
#    'pred_precision': 0.823760498509889,
#    'pred_recall': 0.8204263356718834,
#    'pred_f1': 0.8220900365012842,
#    'pred_accuracy': 0.8908397623481422,
#    'pred_runtime': 1.5389,
#    'pred_samples_per_second': 80.577,
#    'pred_steps_per_second': 20.144},
#   'train_size': 488},
#  '8': {'metrics': {'train_loss': 0.022043446627735715,
#    'eval_loss': 0.8869768381118774,
#    'eval_precision': 0.7927340475081509,
#    'eval_recall': 0.798311444652908,
#    'eval_f1': 0.7955129703201683,
#    'eval_accuracy': 0.8627816627816628,
#    'eval_runtime': 0.8767,
#    'eval_samples_per_second': 87.827,
#    'eval_steps_per_second': 22.812,
#    'epoch': 10.0,
#    'pred_loss': 0.6485807299613953,
#    'pred_precision': 0.8296195652173913,
#    'pred_recall': 0.8178408786498794,
#    'pred_f1': 0.8236881154728181,
#    'pred_accuracy': 0.8943046820405312,
#    'pred_runtime': 0.8115,
#    'pred_samples_per_second': 77.637,
#    'pred_steps_per_second': 19.717},
#   'train_size': 549},
#  '9': {'metrics': {'train_loss': 0.01810039279775487,
#    'eval_loss': 0.8920772671699524,
#    'eval_precision': 0.801849710982659,
#    'eval_recall': 0.8133208255159474,
#    'eval_f1': 0.807544533705903,
#    'eval_accuracy': 0.8702408702408703,
#    'eval_runtime': 1.1031,
#    'eval_samples_per_second': 69.802,
#    'eval_steps_per_second': 18.13,
#    'epoch': 10.0,
#    'pred_loss': 0.3286469280719757,
#    'pred_precision': 0.9,
#    'pred_recall': 0.8834355828220859,
#    'pred_f1': 0.891640866873065,
#    'pred_accuracy': 0.944,
#    'pred_runtime': 0.0476,
#    'pred_samples_per_second': 42.053,
#    'pred_steps_per_second': 21.027},
#   'train_size': 610}}

# %% [markdown]
# ### Отчет об обучении [ссылка](https://api.wandb.ai/links/taoea/tbvussrd)

# %% [markdown]
# ![image.png](data:image/png;base64,...)   ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Оценка качества на тестовой выборке

# %%
predictions = trainer.predict(test_dataset=tokenized_dataset["test"])

# %%
predictions.metrics
# Out:
# {'test_loss': 0.7769635319709778,
#  'test_precision': 0.8247298919567827,
#  'test_recall': 0.8207885304659498,
#  'test_f1': 0.822754491017964,
#  'test_accuracy': 0.8859834334903361,
#  'test_runtime': 0.8457,
#  'test_samples_per_second': 91.049,
#  'test_steps_per_second': 23.649}

# %% [markdown]
# Оценка модели на абстракте, которого не было в тестовом наборе

# %%
ner_bio = pipeline("ner", model=model, tokenizer=tokenizer, device=config.device)

# %%
abstract = """Цель. Оценить выживаемость у пациентов с болезнью Фабри (БФ) в зависимости от вида заместительной почечной терапии, и определить роль диализного скрининга в ранней диагностике БФ у родственников.
Материалы и методы. В исследование включали взрослых (старше 18 лет) пациентов с подтвержденным диагнозом БФ. Терминальная стадия хронической почечной недостаточности (тХПН) диагностировали в соответствии с рекомендациями Научного общества нефрологов России (2016) и KDIGO (2012). На основании опроса пробандов выявляли его родственников, которые могли унаследовать мутантный ген.
Результаты. У 50 (24,9%) из 201 обследованных пациентов с БФ диагностирована тХПН, в том числе у 48 (40%) из 120 мужчин и 2 (2,7%) из 81 женщин. Оценка кумулятивной частоты методом Каплана-Майера демонстрирует выраженное увеличение частоты регистрации тХПН к возрасту 20-30 лет, а к возрасту 50 лет ожидаемое количество пациентов с тХПН составляет 95%. Пяти из 50 больных с тХПН была выполнена трансплантация почки, в среднем, через 17 месяцев (диапазон от 7 до 70 месяцев) после инициации лечения гемодиализом. Умерло 15 (30%) из 50 пациентов, получавших лечение гемодиализом. Все умершие пациенты были мужского пола. Медиана возраста на момент летального исхода составила 45 (39; 58) лет. Среди пациентов, которым проведена трансплантация почки, летальных исходов зарегистрировано не было. У 44 (88%) из 50 пациентов диагноз БФ установлен, в среднем, через 1 год (диапазон от 0 до 12 лет) после начала лечения программным гемодиализом, в том числе у одного пациента – после трансплантации почки. Среди 44 пробандов, выявленных при всероссийском диализном скрининге, проведен семейный скрининг. Патогенная мутация в гене GLA диагностирована у 89 (57%) из 156 обследованных родственников диализных пробандов, в том числе у 18 детей моложе 18 лет, клинические проявления БФ имелись у 48 родственников. У 80,4% обследованных родственников диализных пробандов обнаружено поражение почек, преимущественно на ранних стадиях.
Заключение. ТХПН нередкое осложнение БФ, ассоциированное с неблагоприятным прогнозом. Однако диализный скрининг –  эффективный способ выявления пробандов с БФ, открывающий возможность установить диагноз БФ у родственников на ранних стадиях, когда лечение наиболее эффективно.
"""

# %%
ner_bio(abstract)
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# [{'entity': 'FINDING',
#   'score': 0.30770007,
#   'index': 1,
#   'word': 'Цель',
#   'start': 0,
#   'end': 4},
#  {'entity': 'FINDING',
#   'score': 0.2876546,
#   'index': 2,
#   'word': '.',
#   'start': 4,
#   'end': 5},
#  {'entity': 'FINDING',
#   'score': 0.9677279,
#   'index': 3,
#   'word': 'Оцени',
#   'start': 6,
#   'end': 11},
#  {'entity': 'FINDING',
#   'score': 0.9927861,
#   'index': 4,
#   'word': '##ть',
#   'start': 11,
#   'end': 13},
#  {'entity': 'PHYS',
#   'score': 0.9852276,
#   'index': 5,
#   'word': 'выжи',
#   'start': 14,
#   'end': 18},
#  {'entity': 'PHYS',
#   'score': 0.99123645,
#   'index': 6,
#   'word': '##ваемость',
#   'start': 18,
#   'end': 26},
#  {'entity': 'FINDING',
#   'score': 0.43817616,
#   'index': 7,
#   'word': 'у',
#   'start': 27,
#   'end': 28},
#  {'entity': 'PERSON',
#   'score': 0.99971014,
#   'index': 8,
#   'word': 'пациентов',
#   'start': 29,
#   'end': 38},
#  {'entity': 'DISO',
#   'score': 0.9972671,
#   'index': 9,
#   'word': 'с',
#   'start': 39,
#   'end': 40},
#  {'entity': 'DISO',
#   'score': 0.9998264,
#   'index': 10,
#   'word': 'болезнью',
#   'start': 41,
#   'end': 49},
#  {'entity': 'DISO',
#   'score': 0.95507926,
#   'index': 11,
#   'word': 'Фабри',
#   'start': 50,
#   'end': 55},
#  {'entity': 'DISO',
#   'score': 0.77079344,
#   'index': 12,
#   'word': '(',
#   'start': 56,
#   'end': 57},
#  {'entity': 'DISO',
#   'score': 0.99973696,
#   'index': 13,
#   'word': 'БФ',
#   'start': 57,
#   'end': 59},
#  {'entity': 'DISO',
#   'score': 0.34528935,
#   'index': 14,
#   'word': ')',
#   'start': 59,
#   'end': 60},
#  {'entity': 'DATE',
#   'score': 0.5157522,
#   'index': 15,
#   'word': 'в',
#   'start': 61,
#   'end': 62},
#  {'entity': 'FINDING',
#   'score': 0.95423335,
#   'index': 16,
#   'word': 'зависимости',
#   'start': 63,
#   'end': 74},
#  {'entity': 'FINDING',
#   'score': 0.8414621,
#   'index': 17,
#   'word': 'от',
#   'start': 75,
#   'end': 77},
#  {'entity': 'MEDPROC',
#   'score': 0.9920018,
#   'index': 18,
#   'word': 'вида',
#   'start': 78,
#   'end': 82},
#  {'entity': 'MEDPROC',
#   'score': 0.99982065,
#   'index': 19,
#   'word': 'заместитель',
#   'start': 83,
#   'end': 94},
#  {'entity': 'MEDPROC',
#   'score': 0.99979955,
#   'index': 20,
#   'word': '##ной',
#   'start': 94,
#   'end': 97},
#  {'entity': 'MEDPROC',
#   'score': 0.99871695,
#   'index': 21,
#   'word': 'почечной',
#   'start': 98,
#   'end': 106},
#  {'entity': 'MEDPROC',
#   'score': 0.99980277,
#   'index': 22,
#   'word': 'терапии',
#   'start': 107,
#   'end': 114},
#  {'entity': 'FINDING',
#   'score': 0.3197023,
#   'index': 23,
#   'word': ',',
#   'start': 114,
#   'end': 115},
#  {'entity': 'FINDING',
#   'score': 0.8317603,
#   'index': 24,
#   'word': 'и',
#   'start': 116,
#   'end': 117},
#  {'entity': 'FINDING',
#   'score': 0.9854639,
#   'index': 25,
#   'word': 'определить',
#   'start': 118,
#   'end': 128},
#  {'entity': 'FINDING',
#   'score': 0.978627,
#   'index': 26,
#   'word': 'роль',
#   'start': 129,
#   'end': 133},
#  {'entity': 'MEDPROC',
#   'score': 0.99972683,
#   'index': 27,
#   'word': 'диа',
#   'start': 134,
#   'end': 137},
#  {'entity': 'MEDPROC',
#   'score': 0.999493,
#   'index': 28,
#   'word': '##лиз',
#   'start': 137,
#   'end': 140},
#  {'entity': 'MEDPROC',
#   'score': 0.99575955,
#   'index': 29,
#   'word': '##ного',
#   'start': 140,
#   'end': 144},
#  {'entity': 'MEDPROC',
#   'score': 0.98422146,
#   'index': 30,
#   'word': 'скрин',
#   'start': 145,
#   'end': 150},
#  {'entity': 'MEDPROC',
#   'score': 0.99444145,
#   'index': 31,
#   'word': '##инга',
#   'start': 150,
#   'end': 154},
#  {'entity': 'FINDING',
#   'score': 0.9861957,
#   'index': 32,
#   'word': 'в',
#   'start': 155,
#   'end': 156},
#  {'entity': 'FINDING',
#   'score': 0.81404346,
#   'index': 33,
#   'word': 'ранней',
#   'start': 157,
#   'end': 163},
#  {'entity': 'MEDPROC',
#   'score': 0.86212367,
#   'index': 34,
#   'word': 'диагностике',
#   'start': 164,
#   'end': 175},
#  {'entity': 'DISO',
#   'score': 0.99980766,
#   'index': 35,
#   'word': 'БФ',
#   'start': 176,
#   'end': 178},
#  {'entity': 'PERSON',
#   'score': 0.42503417,
#   'index': 36,
#   'word': 'у',
#   'start': 179,
#   'end': 180},
#  {'entity': 'PERSON',
#   'score': 0.9996141,
#   'index': 37,
#   'word': 'родственников',
#   'start': 181,
#   'end': 194},
#  {'entity': 'FINDING',
#   'score': 0.4715908,
#   'index': 38,
#   'word': '.',
#   'start': 194,
#   'end': 195},
#  {'entity': 'MEDPROC',
#   'score': 0.5395383,
#   'index': 39,
#   'word': 'Материалы',
#   'start': 196,
#   'end': 205},
#  {'entity': 'MEDPROC',
#   'score': 0.14920224,
#   'index': 40,
#   'word': 'и',
#   'start': 206,
#   'end': 207},
#  {'entity': 'MEDPROC',
#   'score': 0.12066885,
#   'index': 41,
#   'word': 'методы',
#   'start': 208,
#   'end': 214},
#  {'entity': 'FINDING',
#   'score': 0.25279054,
#   'index': 42,
#   'word': '.',
#   'start': 214,
#   'end': 215},
#  {'entity': 'MEDPROC',
#   'score': 0.5061196,
#   'index': 43,
#   'word': 'В',
#   'start': 216,
#   'end': 217},
#  {'entity': 'SCIPROC',
#   'score': 0.9081402,
#   'index': 44,
#   'word': 'исследование',
#   'start': 218,
#   'end': 230},
#  {'entity': 'PERSON',
#   'score': 0.41472194,
#   'index': 45,
#   'word': 'включали',
#   'start': 231,
#   'end': 239},
#  {'entity': 'PERSON',
#   'score': 0.9997814,
#   'index': 46,
#   'word': 'взрослых',
#   'start': 240,
#   'end': 248},
#  {'entity': 'AGE',
#   'score': 0.93464154,
#   'index': 47,
#   'word': '(',
#   'start': 249,
#   'end': 250},
#  {'entity': 'AGE',
#   'score': 0.99969316,
#   'index': 48,
#   'word': 'старше',
#   'start': 250,
#   'end': 256},
#  {'entity': 'AGE',
#   'score': 0.9995504,
#   'index': 49,
#   'word': '18',
#   'start': 257,
#   'end': 259},
#  {'entity': 'AGE',
#   'score': 0.9988966,
#   'index': 50,
#   'word': 'лет',
#   'start': 260,
#   'end': 263},
#  {'entity': 'PERSON',
#   'score': 0.9726001,
#   'index': 51,
#   'word': ')',
#   'start': 263,
#   'end': 264},
#  {'entity': 'PERSON',
#   'score': 0.9998192,
#   'index': 52,
#   'word': 'пациентов',
#   'start': 265,
#   'end': 274},
#  {'entity': 'FINDING',
#   'score': 0.98580694,
#   'index': 53,
#   'word': 'с',
#   'start': 275,
#   'end': 276},
#  {'entity': 'FINDING',
#   'score': 0.95611906,
#   'index': 54,
#   'word': 'подтвержден',
#   'start': 277,
#   'end': 288},
#  {'entity': 'FINDING',
#   'score': 0.8252222,
#   'index': 55,
#   'word': '##ным',
#   'start': 288,
#   'end': 291},
#  {'entity': 'DISO',
#   'score': 0.80889326,
#   'index': 56,
#   'word': 'диагнозом',
#   'start': 292,
#   'end': 301},
#  {'entity': 'DISO',
#   'score': 0.99976486,
#   'index': 57,
#   'word': 'БФ',
#   'start': 302,
#   'end': 304},
#  {'entity': 'FINDING',
#   'score': 0.24095623,
#   'index': 58,
#   'word': '.',
#   'start': 304,
#   'end': 305},
#  {'entity': 'DISO',
#   'score': 0.9998276,
#   'index': 59,
#   'word': 'Терминал',
#   'start': 306,
#   'end': 314},
#  {'entity': 'DISO',
#   'score': 0.9997925,
#   'index': 60,
#   'word': '##ь',
#   'start': 314,
#   'end': 315},
#  {'entity': 'DISO',
#   'score': 0.9997439,
#   'index': 61,
#   'word': '##ная',
#   'start': 315,
#   'end': 318},
#  {'entity': 'DISO',
#   'score': 0.99979275,
#   'index': 62,
#   'word': 'стадия',
#   'start': 319,
#   'end': 325},
#  {'entity': 'DISO',
#   'score': 0.9998354,
#   'index': 63,
#   'word': 'хронической',
#   'start': 326,
#   'end': 337},
#  {'entity': 'DISO',
#   'score': 0.99923265,
#   'index': 64,
#   'word': 'почечной',
#   'start': 338,
#   'end': 346},
#  {'entity': 'DISO',
#   'score': 0.99973875,
#   'index': 65,
#   'word': 'недостаточности',
#   'start': 347,
#   'end': 362},
#  {'entity': 'DISO',
#   'score': 0.9950099,
#   'index': 66,
#   'word': '(',
#   'start': 363,
#   'end': 364},
#  {'entity': 'DISO',
#   'score': 0.9998172,
#   'index': 67,
#   'word': 'т',
#   'start': 364,
#   'end': 365},
#  {'entity': 'DISO',
#   'score': 0.9996675,
#   'index': 68,
#   'word': '##Х',
#   'start': 365,
#   'end': 366},
#  {'entity': 'DISO',
#   'score': 0.999613,
#   'index': 69,
#   'word': '##П',
#   'start': 366,
#   'end': 367},
#  {'entity': 'DISO',
#   'score': 0.9996388,
#   'index': 70,
#   'word': '##Н',
#   'start': 367,
#   'end': 368},
#  {'entity': 'DISO',
#   'score': 0.81322604,
#   'index': 71,
#   'word': ')',
#   'start': 368,
#   'end': 369},
#  {'entity': 'FINDING',
#   'score': 0.53452677,
#   'index': 72,
#   'word': 'диагностировали',
#   'start': 370,
#   'end': 385},
#  {'entity': 'SCIPROC',
#   'score': 0.29310966,
#   'index': 73,
#   'word': 'в',
#   'start': 386,
#   'end': 387},
#  {'entity': 'SCIPROC',
#   'score': 0.44847354,
#   'index': 74,
#   'word': 'соответствии',
#   'start': 388,
#   'end': 400},
#  {'entity': 'SCIPROC',
#   'score': 0.9819633,
#   'index': 75,
#   'word': 'с',
#   'start': 401,
#   'end': 402},
#  {'entity': 'SCIPROC',
#   'score': 0.982625,
#   'index': 76,
#   'word': 'рекомендациями',
#   'start': 403,
#   'end': 417},
#  {'entity': 'ORGANIZATION',
#   'score': 0.9993849,
#   'index': 77,
#   'word': 'Научного',
#   'start': 418,
#   'end': 426},
#  {'entity': 'ORGANIZATION',
#   'score': 0.9991326,
#   'index': 78,
#   'word': 'общества',
#   'start': 427,
#   'end': 435},
#  {'entity': 'PROFESSION',
#   'score': 0.8836056,
#   'index': 79,
#   'word': 'неф',
#   'start': 436,
#   'end': 439},
#  {'entity': 'PROFESSION',
#   'score': 0.9829348,
#   'index': 80,
#   'word': '##рол',
#   'start': 439,
#   'end': 442},
#  {'entity': 'PROFESSION',
#   'score': 0.99447155,
#   'index': 81,
#   'word': '##ого',
#   'start': 442,
#   'end': 445},
#  {'entity': 'PROFESSION',
#   'score': 0.9751984,
#   'index': 82,
#   'word': '##в',
#   'start': 445,
#   'end': 446},
#  {'entity': 'COUNTRY',
#   'score': 0.9996032,
#   'index': 83,
#   'word': 'России',
#   'start': 447,
#   'end': 453},
#  {'entity': 'DATE',
#   'score': 0.997218,
#   'index': 84,
#   'word': '(',
#   'start': 454,
#   'end': 455},
#  {'entity': 'DATE',
#   'score': 0.99835724,
#   'index': 85,
#   'word': '2016',
#   'start': 455,
#   'end': 459},
#  {'entity': 'DATE',
#   'score': 0.45725843,
#   'index': 86,
#   'word': ')',
#   'start': 459,
#   'end': 460},
#  {'entity': 'SCIPROC',
#   'score': 0.9955173,
#   'index': 87,
#   'word': 'и',
#   'start': 461,
#   'end': 462},
#  {'entity': 'SCIPROC',
#   'score': 0.99835455,
#   'index': 88,
#   'word': 'K',
#   'start': 463,
#   'end': 464},
#  {'entity': 'SCIPROC',
#   'score': 0.99899143,
#   'index': 89,
#   'word': '##DI',
#   'start': 464,
#   'end': 466},
#  {'entity': 'SCIPROC',
#   'score': 0.98935974,
#   'index': 90,
#   'word': '##GO',
#   'start': 466,
#   'end': 468},
#  {'entity': 'DATE',
#   'score': 0.99336374,
#   'index': 91,
#   'word': '(',
#   'start': 469,
#   'end': 470},
#  {'entity': 'DATE',
#   'score': 0.9970125,
#   'index': 92,
#   'word': '2012',
#   'start': 470,
#   'end': 474},
#  {'entity': 'ORDINAL',
#   'score': 0.35106644,
#   'index': 93,
#   'word': ')',
#   'start': 474,
#   'end': 475},
#  {'entity': 'FINDING',
#   'score': 0.25735527,
#   'index': 94,
#   'word': '.',
#   'start': 475,
#   'end': 476},
#  {'entity': 'SCIPROC',
#   'score': 0.40824068,
#   'index': 95,
#   'word': 'На',
#   'start': 477,
#   'end': 479},
#  {'entity': 'MEDPROC',
#   'score': 0.60479647,
#   'index': 96,
#   'word': 'основании',
#   'start': 480,
#   'end': 489},
#  {'entity': 'MEDPROC',
#   'score': 0.79069936,
#   'index': 97,
#   'word': 'опроса',
#   'start': 490,
#   'end': 496},
#  {'entity': 'PERSON',
#   'score': 0.9937283,
#   'index': 98,
#   'word': 'проба',
#   'start': 497,
#   'end': 502},
#  {'entity': 'PERSON',
#   'score': 0.9031981,
#   'index': 99,
#   'word': '##ндо',
#   'start': 502,
#   'end': 505},
#  {'entity': 'PERSON',
#   'score': 0.95567137,
#   'index': 100,
#   'word': '##в',
#   'start': 505,
#   'end': 506},
#  {'entity': 'FINDING',
#   'score': 0.9493177,
#   'index': 101,
#   'word': 'выявля',
#   'start': 507,
#   'end': 513},
#  {'entity': 'FINDING',
#   'score': 0.9006502,
#   'index': 102,
#   'word': '##ли',
#   'start': 513,
#   'end': 515},
#  {'entity': 'GENE',
#   'score': 0.6772768,
#   'index': 103,
#   'word': 'его',
#   'start': 516,
#   'end': 519},
#  {'entity': 'PERSON',
#   'score': 0.6054574,
#   'index': 104,
#   'word': 'родственников',
#   'start': 520,
#   'end': 533},
#  {'entity': 'FINDING',
#   'score': 0.50111604,
#   'index': 105,
#   'word': ',',
#   'start': 533,
#   'end': 534},
#  {'entity': 'GENE',
#   'score': 0.25355154,
#   'index': 106,
#   'word': 'которые',
#   'start': 535,
#   'end': 542},
#  {'entity': 'FINDING',
#   'score': 0.70191073,
#   'index': 107,
#   'word': 'могли',
#   'start': 543,
#   'end': 548},
#  {'entity': 'GENE',
#   'score': 0.9171637,
#   'index': 108,
#   'word': 'унаследова',
#   'start': 549,
#   'end': 559},
#  {'entity': 'GENE',
#   'score': 0.7113846,
#   'index': 109,
#   'word': '##ть',
#   'start': 559,
#   'end': 561},
#  {'entity': 'GENE',
#   'score': 0.6608671,
#   'index': 110,
#   'word': 'мутант',
#   'start': 562,
#   'end': 568},
#  {'entity': 'GENE',
#   'score': 0.955192,
#   'index': 111,
#   'word': '##ный',
#   'start': 568,
#   'end': 571},
#  {'entity': 'GENE',
#   'score': 0.9984824,
#   'index': 112,
#   'word': 'ген',
#   'start': 572,
#   'end': 575},
#  {'entity': 'ORDINAL',
#   'score': 0.23006977,
#   'index': 113,
#   'word': '.',
#   'start': 575,
#   'end': 576},
#  {'entity': 'FINDING',
#   'score': 0.99122226,
#   'index': 114,
#   'word': 'Результаты',
#   'start': 577,
#   'end': 587},
#  {'entity': 'FINDING',
#   'score': 0.5759111,
#   'index': 115,
#   'word': '.',
#   'start': 587,
#   'end': 588},
#  {'entity': 'DATE',
#   'score': 0.39722535,
#   'index': 116,
#   'word': 'У',
#   'start': 589,
#   'end': 590},
#  {'entity': 'NUMBER',
#   'score': 0.75959486,
#   'index': 117,
#   'word': '50',
#   'start': 591,
#   'end': 593},
#  {'entity': 'PERCENT',
#   'score': 0.9990268,
#   'index': 118,
#   'word': '(',
#   'start': 594,
#   'end': 595},
#  {'entity': 'PERCENT',
#   'score': 0.9997048,
#   'index': 119,
#   'word': '24',
#   'start': 595,
#   'end': 597},
#  {'entity': 'PERCENT',
#   'score': 0.9988619,
#   'index': 120,
#   'word': ',',
#   'start': 597,
#   'end': 598},
#  {'entity': 'PERCENT',
#   'score': 0.99876606,
#   'index': 121,
#   'word': '9',
#   'start': 598,
#   'end': 599},
#  {'entity': 'PERCENT',
#   'score': 0.99789774,
#   'index': 122,
#   'word': '%',
#   'start': 599,
#   'end': 600},
#  {'entity': 'PERCENT',
#   'score': 0.555585,
#   'index': 123,
#   'word': ')',
#   'start': 600,
#   'end': 601},
#  {'entity': 'DATE',
#   'score': 0.3246132,
#   'index': 124,
#   'word': 'из',
#   'start': 602,
#   'end': 604},
#  {'entity': 'NUMBER',
#   'score': 0.9992204,
#   'index': 125,
#   'word': '201',
#   'start': 605,
#   'end': 608},
#  {'entity': 'PERSON',
#   'score': 0.9995511,
#   'index': 126,
#   'word': 'обследова',
#   'start': 609,
#   'end': 618},
#  {'entity': 'PERSON',
#   'score': 0.9996495,
#   'index': 127,
#   'word': '##нных',
#   'start': 618,
#   'end': 622},
#  {'entity': 'PERSON',
#   'score': 0.99984074,
#   'index': 128,
#   'word': 'пациентов',
#   'start': 623,
#   'end': 632},
#  {'entity': 'DISO',
#   'score': 0.78178835,
#   'index': 129,
#   'word': 'с',
#   'start': 633,
#   'end': 634},
#  {'entity': 'DISO',
#   'score': 0.99976414,
#   'index': 130,
#   'word': 'БФ',
#   'start': 635,
#   'end': 637},
#  {'entity': 'FINDING',
#   'score': 0.99148965,
#   'index': 131,
#   'word': 'диагности',
#   'start': 638,
#   'end': 647},
#  {'entity': 'FINDING',
#   'score': 0.98655856,
#   'index': 132,
#   'word': '##рована',
#   'start': 647,
#   'end': 653},
#  {'entity': 'DISO',
#   'score': 0.9998085,
#   'index': 133,
#   'word': 'т',
#   'start': 654,
#   'end': 655},
#  {'entity': 'DISO',
#   'score': 0.99974066,
#   'index': 134,
#   'word': '##Х',
#   'start': 655,
#   'end': 656},
#  {'entity': 'DISO',
#   'score': 0.9996865,
#   'index': 135,
#   'word': '##П',
#   'start': 656,
#   'end': 657},
#  {'entity': 'DISO',
#   'score': 0.9996006,
#   'index': 136,
#   'word': '##Н',
#   'start': 657,
#   'end': 658},
#  {'entity': 'NUMBER',
#   'score': 0.5472091,
#   'index': 137,
#   'word': ',',
#   'start': 658,
#   'end': 659},
#  {'entity': 'PERCENT',
#   'score': 0.9193272,
#   'index': 138,
#   'word': 'в',
#   'start': 660,
#   'end': 661},
#  {'entity': 'PERCENT',
#   'score': 0.7029324,
#   'index': 139,
#   'word': 'том',
#   'start': 662,
#   'end': 665},
#  {'entity': 'NUMBER',
#   'score': 0.5164766,
#   'index': 140,
#   'word': 'числе',
#   'start': 666,
#   'end': 671},
#  {'entity': 'NUMBER',
#   'score': 0.70691925,
#   'index': 141,
#   'word': 'у',
#   'start': 672,
#   'end': 673},
#  {'entity': 'NUMBER',
#   'score': 0.9144322,
#   'index': 142,
#   'word': '48',
#   'start': 674,
#   'end': 676},
#  {'entity': 'PERCENT',
#   'score': 0.9994899,
#   'index': 143,
#   'word': '(',
#   'start': 677,
#   'end': 678},
#  {'entity': 'PERCENT',
#   'score': 0.9997631,
#   'index': 144,
#   'word': '40',
#   'start': 678,
#   'end': 680},
#  {'entity': 'PERCENT',
#   'score': 0.9987476,
#   'index': 145,
#   'word': '%',
#   'start': 680,
#   'end': 681},
#  {'entity': 'PERCENT',
#   'score': 0.82172954,
#   'index': 146,
#   'word': ')',
#   'start': 681,
#   'end': 682},
#  {'entity': 'NUMBER',
#   'score': 0.49821433,
#   'index': 147,
#   'word': 'из',
#   'start': 683,
#   'end': 685},
#  {'entity': 'NUMBER',
#   'score': 0.99888045,
#   'index': 148,
#   'word': '120',
#   'start': 686,
#   'end': 689},
#  {'entity': 'PERSON',
#   'score': 0.99684995,
#   'index': 149,
#   'word': 'мужчин',
#   'start': 690,
#   'end': 696},
#  {'entity': 'PERCENT',
#   'score': 0.48333362,
#   'index': 150,
#   'word': 'и',
#   'start': 697,
#   'end': 698},
#  {'entity': 'NUMBER',
#   'score': 0.99736834,
#   'index': 151,
#   'word': '2',
#   'start': 699,
#   'end': 700},
#  {'entity': 'PERCENT',
#   'score': 0.9988555,
#   'index': 152,
#   'word': '(',
#   'start': 701,
#   'end': 702},
#  {'entity': 'PERCENT',
#   'score': 0.99963784,
#   'index': 153,
#   'word': '2',
#   'start': 702,
#   'end': 703},
#  {'entity': 'PERCENT',
#   'score': 0.9995745,
#   'index': 154,
#   'word': ',',
#   'start': 703,
#   'end': 704},
#  {'entity': 'PERCENT',
#   'score': 0.9995283,
#   'index': 155,
#   'word': '7',
#   'start': 704,
#   'end': 705},
#  {'entity': 'PERCENT',
#   'score': 0.9992975,
#   'index': 156,
#   'word': '%',
#   'start': 705,
#   'end': 706},
#  {'entity': 'PERCENT',
#   'score': 0.76592994,
#   'index': 157,
#   'word': ')',
#   'start': 706,
#   'end': 707},
#  {'entity': 'NUMBER',
#   'score': 0.8326559,
#   'index': 158,
#   'word': 'из',
#   'start': 708,
#   'end': 710},
#  {'entity': 'NUMBER',
#   'score': 0.99907494,
#   'index': 159,
#   'word': '81',
#   'start': 711,
#   'end': 713},
#  {'entity': 'PERSON',
#   'score': 0.9920528,
#   'index': 160,
#   'word': 'женщин',
#   'start': 714,
#   'end': 720},
#  {'entity': 'FINDING',
#   'score': 0.2181106,
#   'index': 161,
#   'word': '.',
#   'start': 720,
#   'end': 721},
#  {'entity': 'FINDING',
#   'score': 0.7676628,
#   'index': 162,
#   'word': 'Оценка',
#   'start': 722,
#   'end': 728},
#  {'entity': 'FINDING',
#   'score': 0.9826568,
#   'index': 163,
#   'word': 'кумуля',
#   'start': 729,
#   'end': 735},
#  {'entity': 'PHYS',
#   'score': 0.833315,
#   'index': 164,
#   'word': '##тивной',
#   'start': 735,
#   'end': 741},
#  {'entity': 'PHYS',
#   'score': 0.5663773,
#   'index': 165,
#   'word': 'частоты',
#   'start': 742,
#   'end': 749},
#  {'entity': 'SCIPROC',
#   'score': 0.9991241,
#   'index': 166,
#   'word': 'методом',
#   'start': 750,
#   'end': 757},
#  {'entity': 'SCIPROC',
#   'score': 0.99966407,
#   'index': 167,
#   'word': 'Каплан',
#   'start': 758,
#   'end': 764},
#  {'entity': 'SCIPROC',
#   'score': 0.9993537,
#   'index': 168,
#   'word': '##а',
#   'start': 764,
#   'end': 765},
#  {'entity': 'SCIPROC',
#   'score': 0.9874472,
#   'index': 169,
#   'word': '-',
#   'start': 765,
#   'end': 766},
#  {'entity': 'SCIPROC',
#   'score': 0.9807839,
#   'index': 170,
#   'word': 'Майер',
#   'start': 766,
#   'end': 771},
#  {'entity': 'SCIPROC',
#   'score': 0.9981887,
#   'index': 171,
#   'word': '##а',
#   'start': 771,
#   'end': 772},
#  {'entity': 'FINDING',
#   'score': 0.9996618,
#   'index': 172,
#   'word': 'демонстрирует',
#   'start': 773,
#   'end': 786},
#  {'entity': 'FINDING',
#   'score': 0.99976116,
#   'index': 173,
#   'word': 'выраженное',
#   'start': 787,
#   'end': 797},
#  {'entity': 'FINDING',
#   'score': 0.9997415,
#   'index': 174,
#   'word': 'увеличение',
#   'start': 798,
#   'end': 808},
#  {'entity': 'PHYS',
#   'score': 0.7070331,
#   'index': 175,
#   'word': 'частоты',
#   'start': 809,
#   'end': 816},
#  {'entity': 'FINDING',
#   'score': 0.9920517,
#   'index': 176,
#   'word': 'регистрации',
#   'start': 817,
#   'end': 828},
#  {'entity': 'DISO',
#   'score': 0.9998379,
#   'index': 177,
#   'word': 'т',
#   'start': 829,
#   'end': 830},
#  {'entity': 'DISO',
#   'score': 0.9997824,
#   'index': 178,
#   'word': '##Х',
#   'start': 830,
#   'end': 831},
#  {'entity': 'DISO',
#   'score': 0.9997501,
#   'index': 179,
#   'word': '##П',
#   'start': 831,
#   'end': 832},
#  {'entity': 'DISO',
#   'score': 0.999648,
#   'index': 180,
#   'word': '##Н',
#   'start': 832,
#   'end': 833},
#  {'entity': 'FINDING',
#   'score': 0.719256,
#   'index': 181,
#   'word': 'к',
#   'start': 834,
#   'end': 835},
#  {'entity': 'PHYS',
#   'score': 0.99580413,
#   'index': 182,
#   'word': 'возрасту',
#   'start': 836,
#   'end': 844},
#  {'entity': 'AGE',
#   'score': 0.9996092,
#   'index': 183,
#   'word': '20',
#   'start': 845,
#   'end': 847},
#  {'entity': 'AGE',
#   'score': 0.9991025,
#   'index': 184,
#   'word': '-',
#   'start': 847,
#   'end': 848},
#  {'entity': 'AGE',
#   'score': 0.99885607,
#   'index': 185,
#   'word': '30',
#   'start': 848,
#   'end': 850},
#  {'entity': 'AGE',
#   'score': 0.9962752,
#   'index': 186,
#   'word': 'лет',
#   'start': 851,
#   'end': 854},
#  {'entity': 'FINDING',
#   'score': 0.95862347,
#   'index': 187,
#   'word': ',',
#   'start': 854,
#   'end': 855},
#  {'entity': 'FINDING',
#   'score': 0.46664113,
#   'index': 188,
#   'word': 'а',
#   'start': 856,
#   'end': 857},
#  {'entity': 'AGE',
#   'score': 0.91662925,
#   'index': 189,
#   'word': 'к',
#   'start': 858,
#   'end': 859},
#  {'entity': 'AGE',
#   'score': 0.9302186,
#   'index': 190,
#   'word': 'возрасту',
#   'start': 860,
#   'end': 868},
#  {'entity': 'AGE',
#   'score': 0.9996427,
#   'index': 191,
#   'word': '50',
#   'start': 869,
#   'end': 871},
#  {'entity': 'AGE',
#   'score': 0.99869376,
#   'index': 192,
#   'word': 'лет',
#   'start': 872,
#   'end': 875},
#  {'entity': 'FINDING',
#   'score': 0.99911636,
#   'index': 193,
#   'word': 'ожидаемо',
#   'start': 876,
#   'end': 884},
#  {'entity': 'FINDING',
#   'score': 0.99920434,
#   'index': 194,
#   'word': '##е',
#   'start': 884,
#   'end': 885},
#  {'entity': 'FINDING',
#   'score': 0.99668425,
#   'index': 195,
#   'word': 'количество',
#   'start': 886,
#   'end': 896},
#  {'entity': 'PERSON',
#   'score': 0.9904732,
#   'index': 196,
#   'word': 'пациентов',
#   'start': 897,
#   'end': 906},
#  {'entity': 'FINDING',
#   'score': 0.97740084,
#   'index': 197,
#   'word': 'с',
#   'start': 907,
#   'end': 908},
#  {'entity': 'DISO',
#   'score': 0.9998429,
#   'index': 198,
#   'word': 'т',
#   'start': 909,
#   'end': 910},
#  {'entity': 'DISO',
#   'score': 0.99975294,
#   'index': 199,
#   'word': '##Х',
#   'start': 910,
#   'end': 911},
#  {'entity': 'DISO',
#   'score': 0.9996996,
#   'index': 200,
#   'word': '##П',
#   'start': 911,
#   'end': 912},
#  {'entity': 'DISO',
#   'score': 0.9995158,
#   'index': 201,
#   'word': '##Н',
#   'start': 912,
#   'end': 913},
#  {'entity': 'FINDING',
#   'score': 0.9992906,
#   'index': 202,
#   'word': 'составляет',
#   'start': 914,
#   'end': 924},
#  {'entity': 'PERCENT',
#   'score': 0.9996959,
#   'index': 203,
#   'word': '95',
#   'start': 925,
#   'end': 927},
#  {'entity': 'PERCENT',
#   'score': 0.9977449,
#   'index': 204,
#   'word': '%',
#   'start': 927,
#   'end': 928},
#  {'entity': 'FINDING',
#   'score': 0.31690538,
#   'index': 205,
#   'word': '.',
#   'start': 928,
#   'end': 929},
#  {'entity': 'NUMBER',
#   'score': 0.9978733,
#   'index': 206,
#   'word': 'Пяти',
#   'start': 930,
#   'end': 934},
#  {'entity': 'NUMBER',
#   'score': 0.5283318,
#   'index': 207,
#   'word': 'из',
#   'start': 935,
#   'end': 937},
#  {'entity': 'NUMBER',
#   'score': 0.99787915,
#   'index': 208,
#   'word': '50',
#   'start': 938,
#   'end': 940},
#  {'entity': 'PERSON',
#   'score': 0.9989033,
#   'index': 209,
#   'word': 'больных',
#   'start': 941,
#   'end': 948},
#  {'entity': 'FINDING',
#   'score': 0.869343,
#   'index': 210,
#   'word': 'с',
#   'start': 949,
#   'end': 950},
#  {'entity': 'DISO',
#   'score': 0.99983215,
#   'index': 211,
#   'word': 'т',
#   'start': 951,
#   'end': 952},
#  {'entity': 'DISO',
#   'score': 0.9996395,
#   'index': 212,
#   'word': '##Х',
#   'start': 952,
#   'end': 953},
#  {'entity': 'DISO',
#   'score': 0.9996644,
#   'index': 213,
#   'word': '##П',
#   'start': 953,
#   'end': 954},
#  {'entity': 'DISO',
#   'score': 0.99958664,
#   'index': 214,
#   'word': '##Н',
#   'start': 954,
#   'end': 955},
#  {'entity': 'MEDPROC',
#   'score': 0.99897695,
#   'index': 215,
#   'word': 'была',
#   'start': 956,
#   'end': 960},
#  {'entity': 'MEDPROC',
#   'score': 0.9995621,
#   'index': 216,
#   'word': 'выполнена',
#   'start': 961,
#   'end': 970},
#  {'entity': 'MEDPROC',
#   'score': 0.9997812,
#   'index': 217,
#   'word': 'транспланта',
#   'start': 971,
#   'end': 982},
#  {'entity': 'MEDPROC',
#   'score': 0.99967885,
#   'index': 218,
#   'word': '##ция',
#   'start': 982,
#   'end': 985},
#  {'entity': 'ANATOMY',
#   'score': 0.9998227,
#   'index': 219,
#   'word': 'почки',
#   'start': 986,
#   'end': 991},
#  {'entity': 'FINDING',
#   'score': 0.34624332,
#   'index': 220,
#   'word': ',',
#   'start': 991,
#   'end': 992},
#  {'entity': 'DATE',
#   'score': 0.9721177,
#   'index': 221,
#   'word': 'в',
#   'start': 993,
#   'end': 994},
#  {'entity': 'DATE',
#   'score': 0.79915756,
#   'index': 222,
#   'word': 'среднем',
#   'start': 995,
#   'end': 1002},
#  {'entity': 'DATE',
#   'score': 0.62898356,
#   'index': 223,
#   'word': ',',
#   'start': 1002,
#   'end': 1003},
#  {'entity': 'DATE',
#   'score': 0.9997557,
#   'index': 224,
#   'word': 'через',
#   'start': 1004,
#   'end': 1009},
#  {'entity': 'DATE',
#   'score': 0.9994615,
#   'index': 225,
#   'word': '17',
#   'start': 1010,
#   'end': 1012},
#  {'entity': 'DATE',
#   'score': 0.99809736,
#   'index': 226,
#   'word': 'месяцев',
#   'start': 1013,
#   'end': 1020},
#  {'entity': 'DATE',
#   'score': 0.9979978,
#   'index': 227,
#   'word': '(',
#   'start': 1021,
#   'end': 1022},
#  {'entity': 'DATE',
#   'score': 0.9612792,
#   'index': 228,
#   'word': 'диапазон',
#   'start': 1022,
#   'end': 1030},
#  {'entity': 'DATE',
#   'score': 0.93279356,
#   'index': 229,
#   'word': 'от',
#   'start': 1031,
#   'end': 1033},
#  {'entity': 'DATE',
#   'score': 0.99935585,
#   'index': 230,
#   'word': '7',
#   'start': 1034,
#   'end': 1035},
#  {'entity': 'DATE',
#   'score': 0.99444455,
#   'index': 231,
#   'word': 'до',
#   'start': 1036,
#   'end': 1038},
#  {'entity': 'DATE',
#   'score': 0.99900097,
#   'index': 232,
#   'word': '70',
#   'start': 1039,
#   'end': 1041},
#  {'entity': 'DATE',
#   'score': 0.9975439,
#   'index': 233,
#   'word': 'месяцев',
#   'start': 1042,
#   'end': 1049},
#  {'entity': 'DATE',
#   'score': 0.9543555,
#   'index': 234,
#   'word': ')',
#   'start': 1049,
#   'end': 1050},
#  {'entity': 'DATE',
#   'score': 0.97552943,
#   'index': 235,
#   'word': 'после',
#   'start': 1051,
#   'end': 1056},
#  {'entity': 'MEDPROC',
#   'score': 0.9982327,
#   'index': 236,
#   'word': 'инициации',
#   'start': 1057,
#   'end': 1066},
#  {'entity': 'MEDPROC',
#   'score': 0.9997763,
#   'index': 237,
#   'word': 'лечения',
#   'start': 1067,
#   'end': 1074},
#  {'entity': 'MEDPROC',
#   'score': 0.9998265,
#   'index': 238,
#   'word': 'гемо',
#   'start': 1075,
#   'end': 1079},
#  {'entity': 'MEDPROC',
#   'score': 0.99981314,
#   'index': 239,
#   'word': '##диа',
#   'start': 1079,
#   'end': 1082},
#  {'entity': 'MEDPROC',
#   'score': 0.99977285,
#   'index': 240,
#   'word': '##лиз',
#   'start': 1082,
#   'end': 1085},
#  {'entity': 'MEDPROC',
#   'score': 0.9996294,
#   'index': 241,
#   'word': '##ом',
#   'start': 1085,
#   'end': 1087},
#  {'entity': 'DATE',
#   'score': 0.312361,
#   'index': 242,
#   'word': '.',
#   'start': 1087,
#   'end': 1088},
#  {'entity': 'FINDING',
#   'score': 0.7063044,
#   'index': 243,
#   'word': 'Умер',
#   'start': 1089,
#   'end': 1093},
#  {'entity': 'FINDING',
#   'score': 0.4612315,
#   'index': 244,
#   'word': '##ло',
#   'start': 1093,
#   'end': 1095},
#  {'entity': 'NUMBER',
#   'score': 0.9398521,
#   'index': 245,
#   'word': '15',
#   'start': 1096,
#   'end': 1098},
#  {'entity': 'PERCENT',
#   'score': 0.9979899,
#   'index': 246,
#   'word': '(',
#   'start': 1099,
#   'end': 1100},
#  {'entity': 'PERCENT',
#   'score': 0.99971586,
#   'index': 247,
#   'word': '30',
#   'start': 1100,
#   'end': 1102},
#  {'entity': 'PERCENT',
#   'score': 0.9954111,
#   'index': 248,
#   'word': '%',
#   'start': 1102,
#   'end': 1103},
#  {'entity': 'PERCENT',
#   'score': 0.4152637,
#   'index': 249,
#   'word': ')',
#   'start': 1103,
#   'end': 1104},
#  {'entity': 'NUMBER',
#   'score': 0.4665134,
#   'index': 250,
#   'word': 'из',
#   'start': 1105,
#   'end': 1107},
#  {'entity': 'NUMBER',
#   'score': 0.995808,
#   'index': 251,
#   'word': '50',
#   'start': 1108,
#   'end': 1110},
#  {'entity': 'PERSON',
#   'score': 0.99902546,
#   'index': 252,
#   'word': 'пациентов',
#   'start': 1111,
#   'end': 1120},
#  {'entity': 'PERSON',
#   'score': 0.740812,
#   'index': 253,
#   'word': ',',
#   'start': 1120,
#   'end': 1121},
#  {'entity': 'MEDPROC',
#   'score': 0.99628973,
#   'index': 254,
#   'word': 'получа',
#   'start': 1122,
#   'end': 1128},
#  {'entity': 'MEDPROC',
#   'score': 0.54054695,
#   'index': 255,
#   'word': '##вших',
#   'start': 1128,
#   'end': 1132},
#  {'entity': 'MEDPROC',
#   'score': 0.9998078,
#   'index': 256,
#   'word': 'лечение',
#   'start': 1133,
#   'end': 1140},
#  {'entity': 'MEDPROC',
#   'score': 0.9998348,
#   'index': 257,
#   'word': 'гемо',
#   'start': 1141,
#   'end': 1145},
#  {'entity': 'MEDPROC',
#   'score': 0.99982077,
#   'index': 258,
#   'word': '##диа',
#   'start': 1145,
#   'end': 1148},
#  {'entity': 'MEDPROC',
#   'score': 0.99979633,
#   'index': 259,
#   'word': '##лиз',
#   'start': 1148,
#   'end': 1151},
#  {'entity': 'MEDPROC',
#   'score': 0.99971944,
#   'index': 260,
#   'word': '##ом',
#   'start': 1151,
#   'end': 1153},
#  {'entity': 'DATE',
#   'score': 0.22932677,
#   'index': 261,
#   'word': '.',
#   'start': 1153,
#   'end': 1154},
#  {'entity': 'NUMBER',
#   'score': 0.42203632,
#   'index': 262,
#   'word': 'Все',
#   'start': 1155,
#   'end': 1158},
#  {'entity': 'PERSON',
#   'score': 0.95231247,
#   'index': 263,
#   'word': 'умер',
#   'start': 1159,
#   'end': 1163},
#  {'entity': 'PERSON',
#   'score': 0.8337899,
#   'index': 264,
#   'word': '##шие',
#   'start': 1163,
#   'end': 1166},
#  {'entity': 'PERSON',
#   'score': 0.9991008,
#   'index': 265,
#   'word': 'пациенты',
#   'start': 1167,
#   'end': 1175},
#  {'entity': 'FINDING',
#   'score': 0.93718207,
#   'index': 266,
#   'word': 'были',
#   'start': 1176,
#   'end': 1180},
#  {'entity': 'PHYS',
#   'score': 0.9995907,
#   'index': 267,
#   'word': 'мужского',
#   'start': 1181,
#   'end': 1189},
#  {'entity': 'PHYS',
#   'score': 0.9986588,
#   'index': 268,
#   'word': 'пола',
#   'start': 1190,
#   'end': 1194},
#  {'entity': 'FINDING',
#   'score': 0.538006,
#   'index': 269,
#   'word': '.',
#   'start': 1194,
#   'end': 1195},
#  {'entity': 'FINDING',
#   'score': 0.999196,
#   'index': 270,
#   'word': 'Медиа',
#   'start': 1196,
#   'end': 1201},
#  {'entity': 'FINDING',
#   'score': 0.9916578,
#   'index': 271,
#   'word': '##на',
#   'start': 1201,
#   'end': 1203},
#  {'entity': 'PHYS',
#   'score': 0.9992244,
#   'index': 272,
#   'word': 'возраста',
#   'start': 1204,
#   'end': 1212},
#  {'entity': 'DATE',
#   'score': 0.9990938,
#   'index': 273,
#   'word': 'на',
#   'start': 1213,
#   'end': 1215},
#  {'entity': 'DATE',
#   'score': 0.969959,
#   'index': 274,
#   'word': 'момент',
#   'start': 1216,
#   'end': 1222},
#  {'entity': 'FINDING',
#   'score': 0.9620677,
#   'index': 275,
#   'word': 'летального',
#   'start': 1223,
#   'end': 1233},
#  {'entity': 'FINDING',
#   'score': 0.97168624,
#   'index': 276,
#   'word': 'исхода',
#   'start': 1234,
#   'end': 1240},
#  {'entity': 'FINDING',
#   'score': 0.99819946,
#   'index': 277,
#   'word': 'составила',
#   'start': 1241,
#   'end': 1250},
#  {'entity': 'AGE',
#   'score': 0.99411243,
#   'index': 278,
#   'word': '45',
#   'start': 1251,
#   'end': 1253},
#  {'entity': 'AGE',
#   'score': 0.91263634,
#   'index': 279,
#   'word': '(',
#   'start': 1254,
#   'end': 1255},
#  {'entity': 'AGE',
#   'score': 0.99800974,
#   'index': 280,
#   'word': '39',
#   'start': 1255,
#   'end': 1257},
#  {'entity': 'AGE',
#   'score': 0.6289498,
#   'index': 281,
#   'word': ';',
#   'start': 1257,
#   'end': 1258},
#  {'entity': 'AGE',
#   'score': 0.86637074,
#   'index': 282,
#   'word': '58',
#   'start': 1259,
#   'end': 1261},
#  {'entity': 'AGE',
#   'score': 0.40790382,
#   'index': 283,
#   'word': ')',
#   'start': 1261,
#   'end': 1262},
#  {'entity': 'AGE',
#   'score': 0.90140855,
#   'index': 284,
#   'word': 'лет',
#   'start': 1263,
#   'end': 1266},
#  {'entity': 'FINDING',
#   'score': 0.36368057,
#   'index': 285,
#   'word': '.',
#   'start': 1266,
#   'end': 1267},
#  {'entity': 'FINDING',
#   'score': 0.80642337,
#   'index': 286,
#   'word': 'Среди',
#   'start': 1268,
#   'end': 1273},
#  {'entity': 'PERSON',
#   'score': 0.99891436,
#   'index': 287,
#   'word': 'пациентов',
#   'start': 1274,
#   'end': 1283},
#  {'entity': 'MEDPROC',
#   'score': 0.22565259,
#   'index': 288,
#   'word': ',',
#   'start': 1283,
#   'end': 1284},
#  {'entity': 'MEDPROC',
#   'score': 0.30792406,
#   'index': 289,
#   'word': 'которым',
#   'start': 1285,
#   'end': 1292},
#  {'entity': 'MEDPROC',
#   'score': 0.9996898,
#   'index': 290,
#   'word': 'проведена',
#   'start': 1293,
#   'end': 1302},
#  {'entity': 'MEDPROC',
#   'score': 0.9998111,
#   'index': 291,
#   'word': 'транспланта',
#   'start': 1303,
#   'end': 1314},
#  {'entity': 'MEDPROC',
#   'score': 0.99975353,
#   'index': 292,
#   'word': '##ция',
#   'start': 1314,
#   'end': 1317},
#  {'entity': 'ANATOMY',
#   'score': 0.999835,
#   'index': 293,
#   'word': 'почки',
#   'start': 1318,
#   'end': 1323},
#  {'entity': 'FINDING',
#   'score': 0.9983595,
#   'index': 294,
#   'word': ',',
#   'start': 1323,
#   'end': 1324},
#  {'entity': 'FINDING',
#   'score': 0.9995603,
#   'index': 295,
#   'word': 'летальных',
#   'start': 1325,
#   'end': 1334},
#  {'entity': 'FINDING',
#   'score': 0.9995648,
#   'index': 296,
#   'word': 'исход',
#   'start': 1335,
#   'end': 1340},
#  {'entity': 'FINDING',
#   'score': 0.999198,
#   'index': 297,
#   'word': '##ов',
#   'start': 1340,
#   'end': 1342},
#  {'entity': 'FINDING',
#   'score': 0.99954826,
#   'index': 298,
#   'word': 'зарегистрировано',
#   'start': 1343,
#   'end': 1359},
#  {'entity': 'FINDING',
#   'score': 0.9993488,
#   'index': 299,
#   'word': 'не',
#   'start': 1360,
#   'end': 1362},
#  {'entity': 'FINDING',
#   'score': 0.9992494,
#   'index': 300,
#   'word': 'было',
#   'start': 1363,
#   'end': 1367},
#  {'entity': 'FINDING',
#   'score': 0.32979313,
#   'index': 301,
#   'word': '.',
#   'start': 1367,
#   'end': 1368},
#  {'entity': 'FINDING',
#   'score': 0.41235682,
#   'index': 302,
#   'word': 'У',
#   'start': 1369,
#   'end': 1370},
#  {'entity': 'NUMBER',
#   'score': 0.8523246,
#   'index': 303,
#   'word': '44',
#   'start': 1371,
#   'end': 1373},
#  {'entity': 'PERCENT',
#   'score': 0.9961356,
#   'index': 304,
#   'word': '(',
#   'start': 1374,
#   'end': 1375},
#  {'entity': 'PERCENT',
#   'score': 0.99965405,
#   'index': 305,
#   'word': '88',
#   'start': 1375,
#   'end': 1377},
#  {'entity': 'PERCENT',
#   'score': 0.99017227,
#   'index': 306,
#   'word': '%',
#   'start': 1377,
#   'end': 1378},
#  {'entity': 'PERCENT',
#   'score': 0.3329404,
#   'index': 307,
#   'word': ')',
#   'start': 1378,
#   'end': 1379},
#  {'entity': 'DATE',
#   'score': 0.19027108,
#   'index': 308,
#   'word': 'из',
#   'start': 1380,
#   'end': 1382},
#  {'entity': 'NUMBER',
#   'score': 0.99823076,
#   'index': 309,
#   'word': '50',
#   'start': 1383,
#   'end': 1385},
#  {'entity': 'PERSON',
#   'score': 0.9995665,
#   'index': 310,
#   'word': 'пациентов',
#   'start': 1386,
#   'end': 1395},
#  {'entity': 'FINDING',
#   'score': 0.9979405,
#   'index': 311,
#   'word': 'диагноз',
#   'start': 1396,
#   'end': 1403},
#  {'entity': 'DISO',
#   'score': 0.9997482,
#   'index': 312,
#   'word': 'БФ',
#   'start': 1404,
#   'end': 1406},
#  {'entity': 'FINDING',
#   'score': 0.98342955,
#   'index': 313,
#   'word': 'установлен',
#   'start': 1407,
#   'end': 1417},
#  {'entity': 'FINDING',
#   'score': 0.830053,
#   'index': 314,
#   'word': ',',
#   'start': 1417,
#   'end': 1418},
#  {'entity': 'DATE',
#   'score': 0.86525196,
#   'index': 315,
#   'word': 'в',
#   'start': 1419,
#   'end': 1420},
#  {'entity': 'DATE',
#   'score': 0.3783839,
#   'index': 316,
#   'word': 'среднем',
#   'start': 1421,
#   'end': 1428},
#  {'entity': 'DATE',
#   'score': 0.49000207,
#   'index': 317,
#   'word': ',',
#   'start': 1428,
#   'end': 1429},
#  {'entity': 'DATE',
#   'score': 0.9996855,
#   'index': 318,
#   'word': 'через',
#   'start': 1430,
#   'end': 1435},
#  {'entity': 'DATE',
#   'score': 0.99962735,
#   'index': 319,
#   'word': '1',
#   'start': 1436,
#   'end': 1437},
#  {'entity': 'DATE',
#   'score': 0.99861085,
#   'index': 320,
#   'word': 'год',
#   'start': 1438,
#   'end': 1441},
#  {'entity': 'DATE',
#   'score': 0.97985405,
#   'index': 321,
#   'word': '(',
#   'start': 1442,
#   'end': 1443},
#  {'entity': 'DATE',
#   'score': 0.5922825,
#   'index': 322,
#   'word': 'диапазон',
#   'start': 1443,
#   'end': 1451},
#  {'entity': 'AGE',
#   'score': 0.60555655,
#   'index': 323,
#   'word': 'от',
#   'start': 1452,
#   'end': 1454},
#  {'entity': 'DATE',
#   'score': 0.81665456,
#   'index': 324,
#   'word': '0',
#   'start': 1455,
#   'end': 1456},
#  {'entity': 'DATE',
#   'score': 0.9388563,
#   'index': 325,
#   'word': 'до',
#   'start': 1457,
#   'end': 1459},
#  {'entity': 'DATE',
#   'score': 0.99864525,
#   'index': 326,
#   'word': '12',
#   'start': 1460,
#   'end': 1462},
#  {'entity': 'DATE',
#   'score': 0.9945563,
#   'index': 327,
#   'word': 'лет',
#   'start': 1463,
#   'end': 1466},
#  {'entity': 'DATE',
#   'score': 0.6552274,
#   'index': 328,
#   'word': ')',
#   'start': 1466,
#   'end': 1467},
#  {'entity': 'DATE',
#   'score': 0.92986315,
#   'index': 329,
#   'word': 'после',
#   'start': 1468,
#   'end': 1473},
#  {'entity': 'MEDPROC',
#   'score': 0.98854417,
#   'index': 330,
#   'word': 'начала',
#   'start': 1474,
#   'end': 1480},
#  {'entity': 'MEDPROC',
#   'score': 0.9998128,
#   'index': 331,
#   'word': 'лечения',
#   'start': 1481,
#   'end': 1488},
#  {'entity': 'MEDPROC',
#   'score': 0.9998374,
#   'index': 332,
#   'word': 'программным',
#   'start': 1489,
#   'end': 1500},
#  {'entity': 'MEDPROC',
#   'score': 0.9998258,
#   'index': 333,
#   'word': 'гемо',
#   'start': 1501,
#   'end': 1505},
#  {'entity': 'MEDPROC',
#   'score': 0.9998258,
#   'index': 334,
#   'word': '##диа',
#   'start': 1505,
#   'end': 1508},
#  {'entity': 'MEDPROC',
#   'score': 0.99979895,
#   'index': 335,
#   'word': '##лиз',
#   'start': 1508,
#   'end': 1511},
#  {'entity': 'MEDPROC',
#   'score': 0.99975353,
#   'index': 336,
#   'word': '##ом',
#   'start': 1511,
#   'end': 1513},
#  {'entity': 'FINDING',
#   'score': 0.38222292,
#   'index': 337,
#   'word': ',',
#   'start': 1513,
#   'end': 1514},
#  {'entity': 'NUMBER',
#   'score': 0.52041495,
#   'index': 338,
#   'word': 'в',
#   'start': 1515,
#   'end': 1516},
#  {'entity': 'NUMBER',
#   'score': 0.24392295,
#   'index': 339,
#   'word': 'том',
#   'start': 1517,
#   'end': 1520},
#  {'entity': 'NUMBER',
#   'score': 0.8625653,
#   'index': 340,
#   'word': 'числе',
#   'start': 1521,
#   'end': 1526},
#  {'entity': 'NUMBER',
#   'score': 0.4664273,
#   'index': 341,
#   'word': 'у',
#   'start': 1527,
#   'end': 1528},
#  {'entity': 'NUMBER',
#   'score': 0.99865544,
#   'index': 342,
#   'word': 'одного',
#   'start': 1529,
#   'end': 1535},
#  {'entity': 'PERSON',
#   'score': 0.99881256,
#   'index': 343,
#   'word': 'пациента',
#   'start': 1536,
#   'end': 1544},
#  {'entity': 'FINDING',
#   'score': 0.42125753,
#   'index': 344,
#   'word': '–',
#   'start': 1545,
#   'end': 1546},
#  {'entity': 'MEDPROC',
#   'score': 0.79244626,
#   'index': 345,
#   'word': 'после',
#   'start': 1547,
#   'end': 1552},
#  {'entity': 'MEDPROC',
#   'score': 0.9998006,
#   'index': 346,
#   'word': 'трансплантации',
#   'start': 1553,
#   'end': 1567},
#  {'entity': 'ANATOMY',
#   'score': 0.999856,
#   'index': 347,
#   'word': 'почки',
#   'start': 1568,
#   'end': 1573},
#  {'entity': 'DATE',
#   'score': 0.2267196,
#   'index': 348,
#   'word': '.',
#   'start': 1573,
#   'end': 1574},
#  {'entity': 'NUMBER',
#   'score': 0.2547548,
#   'index': 349,
#   'word': 'Среди',
#   'start': 1575,
#   'end': 1580},
#  {'entity': 'NUMBER',
#   'score': 0.99920636,
#   'index': 350,
#   'word': '44',
#   'start': 1581,
#   'end': 1583},
#  {'entity': 'PERSON',
#   'score': 0.9982262,
#   'index': 351,
#   'word': 'проба',
#   'start': 1584,
#   'end': 1589},
#  {'entity': 'PERSON',
#   'score': 0.98256207,
#   'index': 352,
#   'word': '##ндо',
#   'start': 1589,
#   'end': 1592},
#  {'entity': 'PERSON',
#   'score': 0.99710435,
#   'index': 353,
#   'word': '##в',
#   'start': 1592,
#   'end': 1593},
#  {'entity': 'PERSON',
#   'score': 0.6814051,
#   'index': 354,
#   'word': ',',
#   'start': 1593,
#   'end': 1594},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.41469872,
#   'index': 355,
#   'word': 'выявленных',
#   'start': 1595,
#   'end': 1605},
#  {'entity': 'MEDPROC',
#   'score': 0.9140305,
#   'index': 356,
#   'word': 'при',
#   'start': 1606,
#   'end': 1609},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.7027264,
#   'index': 357,
#   'word': 'всероссий',
#   'start': 1610,
#   'end': 1619},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.81995815,
#   'index': 358,
#   'word': '##ском',
#   'start': 1619,
#   'end': 1623},
#  {'entity': 'MEDPROC',
#   'score': 0.9978421,
#   'index': 359,
#   'word': 'диа',
#   'start': 1624,
#   'end': 1627},
#  {'entity': 'MEDPROC',
#   'score': 0.9986525,
#   'index': 360,
#   'word': '##лиз',
#   'start': 1627,
#   'end': 1630},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.7345295,
#   'index': 361,
#   'word': '##ном',
#   'start': 1630,
#   'end': 1633},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.50586355,
#   'index': 362,
#   'word': 'скрин',
#   'start': 1634,
#   'end': 1639},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.5614382,
#   'index': 363,
#   'word': '##инг',
#   'start': 1639,
#   'end': 1642},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.9433759,
#   'index': 364,
#   'word': '##е',
#   'start': 1642,
#   'end': 1643},
#  {'entity': 'MEDPROC',
#   'score': 0.78365505,
#   'index': 365,
#   'word': ',',
#   'start': 1643,
#   'end': 1644},
#  {'entity': 'MEDPROC',
#   'score': 0.9901759,
#   'index': 366,
#   'word': 'проведен',
#   'start': 1645,
#   'end': 1653},
#  {'entity': 'MEDPROC',
#   'score': 0.722908,
#   'index': 367,
#   'word': 'семейный',
#   'start': 1654,
#   'end': 1662},
#  {'entity': 'MEDPROC',
#   'score': 0.66417843,
#   'index': 368,
#   'word': 'скрин',
#   'start': 1663,
#   'end': 1668},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.53784853,
#   'index': 369,
#   'word': '##инг',
#   'start': 1668,
#   'end': 1671},
#  {'entity': 'FINDING',
#   'score': 0.44215477,
#   'index': 370,
#   'word': '.',
#   'start': 1671,
#   'end': 1672},
#  {'entity': 'FINDING',
#   'score': 0.8793783,
#   'index': 371,
#   'word': 'Пато',
#   'start': 1673,
#   'end': 1677},
#  {'entity': 'FINDING',
#   'score': 0.9710941,
#   'index': 372,
#   'word': '##генная',
#   'start': 1677,
#   'end': 1683},
#  {'entity': 'PHYS',
#   'score': 0.8032821,
#   'index': 373,
#   'word': 'мутация',
#   'start': 1684,
#   'end': 1691},
#  {'entity': 'GENE',
#   'score': 0.9966679,
#   'index': 374,
#   'word': 'в',
#   'start': 1692,
#   'end': 1693},
#  {'entity': 'GENE',
#   'score': 0.99931276,
#   'index': 375,
#   'word': 'гене',
#   'start': 1694,
#   'end': 1698},
#  {'entity': 'GENE',
#   'score': 0.99868983,
#   'index': 376,
#   'word': 'GL',
#   'start': 1699,
#   'end': 1701},
#  {'entity': 'GENE',
#   'score': 0.99874544,
#   'index': 377,
#   'word': '##A',
#   'start': 1701,
#   'end': 1702},
#  {'entity': 'FINDING',
#   'score': 0.9960198,
#   'index': 378,
#   'word': 'диагности',
#   'start': 1703,
#   'end': 1712},
#  {'entity': 'FINDING',
#   'score': 0.9969126,
#   'index': 379,
#   'word': '##рована',
#   'start': 1712,
#   'end': 1718},
#  {'entity': 'FINDING',
#   'score': 0.68318236,
#   'index': 380,
#   'word': 'у',
#   'start': 1719,
#   'end': 1720},
#  {'entity': 'PERCENT',
#   'score': 0.9116685,
#   'index': 381,
#   'word': '89',
#   'start': 1721,
#   'end': 1723},
#  {'entity': 'PERCENT',
#   'score': 0.9978411,
#   'index': 382,
#   'word': '(',
#   'start': 1724,
#   'end': 1725},
#  {'entity': 'PERCENT',
#   'score': 0.99970204,
#   'index': 383,
#   'word': '57',
#   'start': 1725,
#   'end': 1727},
#  {'entity': 'PERCENT',
#   'score': 0.99248403,
#   'index': 384,
#   'word': '%',
#   'start': 1727,
#   'end': 1728},
#  {'entity': 'PERSON',
#   'score': 0.30321953,
#   'index': 385,
#   'word': ')',
#   'start': 1728,
#   'end': 1729},
#  {'entity': 'NUMBER',
#   'score': 0.23722416,
#   'index': 386,
#   'word': 'из',
#   'start': 1730,
#   'end': 1732},
#  {'entity': 'NUMBER',
#   'score': 0.9993129,
#   'index': 387,
#   'word': '156',
#   'start': 1733,
#   'end': 1736},
#  {'entity': 'PERSON',
#   'score': 0.9996106,
#   'index': 388,
#   'word': 'обследова',
#   'start': 1737,
#   'end': 1746},
#  {'entity': 'PERSON',
#   'score': 0.99940467,
#   'index': 389,
#   'word': '##нных',
#   'start': 1746,
#   'end': 1750},
#  {'entity': 'PERSON',
#   'score': 0.9998462,
#   'index': 390,
#   'word': 'родственников',
#   'start': 1751,
#   'end': 1764},
#  {'entity': 'PERSON',
#   'score': 0.86246675,
#   'index': 391,
#   'word': 'диа',
#   'start': 1765,
#   'end': 1768},
#  {'entity': 'PERSON',
#   'score': 0.6660449,
#   'index': 392,
#   'word': '##лиз',
#   'start': 1768,
#   'end': 1771},
#  {'entity': 'PERSON',
#   'score': 0.99274,
#   'index': 393,
#   'word': '##ных',
#   'start': 1771,
#   'end': 1774},
#  {'entity': 'PERSON',
#   'score': 0.9911607,
#   'index': 394,
#   'word': 'проба',
#   'start': 1775,
#   'end': 1780},
#  {'entity': 'PERSON',
#   'score': 0.66762954,
#   'index': 395,
#   'word': '##ндо',
#   'start': 1780,
#   'end': 1783},
#  {'entity': 'PERSON',
#   'score': 0.8641608,
#   'index': 396,
#   'word': '##в',
#   'start': 1783,
#   'end': 1784},
#  {'entity': 'FINDING',
#   'score': 0.41834697,
#   'index': 397,
#   'word': ',',
#   'start': 1784,
#   'end': 1785},
#  {'entity': 'PERCENT',
#   'score': 0.35452843,
#   'index': 398,
#   'word': 'в',
#   'start': 1786,
#   'end': 1787},
#  {'entity': 'PERCENT',
#   'score': 0.38368198,
#   'index': 399,
#   'word': 'том',
#   'start': 1788,
#   'end': 1791},
#  {'entity': 'NUMBER',
#   'score': 0.39513987,
#   'index': 400,
#   'word': 'числе',
#   'start': 1792,
#   'end': 1797},
#  {'entity': 'NUMBER',
#   'score': 0.3904974,
#   'index': 401,
#   'word': 'у',
#   'start': 1798,
#   'end': 1799},
#  {'entity': 'NUMBER',
#   'score': 0.9989298,
#   'index': 402,
#   'word': '18',
#   'start': 1800,
#   'end': 1802},
#  {'entity': 'PERSON',
#   'score': 0.995999,
#   'index': 403,
#   'word': 'детей',
#   'start': 1803,
#   'end': 1808},
#  {'entity': 'AGE',
#   'score': 0.9994018,
#   'index': 404,
#   'word': 'моложе',
#   'start': 1809,
#   'end': 1815},
#  {'entity': 'AGE',
#   'score': 0.9993874,
#   'index': 405,
#   'word': '18',
#   'start': 1816,
#   'end': 1818},
#  {'entity': 'AGE',
#   'score': 0.9982204,
#   'index': 406,
#   'word': 'лет',
#   'start': 1819,
#   'end': 1822},
#  {'entity': 'FINDING',
#   'score': 0.99242955,
#   'index': 407,
#   'word': ',',
#   'start': 1822,
#   'end': 1823},
#  {'entity': 'FINDING',
#   'score': 0.94305915,
#   'index': 408,
#   'word': 'клинические',
#   'start': 1824,
#   'end': 1835},
#  {'entity': 'DISO',
#   'score': 0.52513045,
#   'index': 409,
#   'word': 'проявления',
#   'start': 1836,
#   'end': 1846},
#  {'entity': 'DISO',
#   'score': 0.9997781,
#   'index': 410,
#   'word': 'БФ',
#   'start': 1847,
#   'end': 1849},
#  {'entity': 'FINDING',
#   'score': 0.9959312,
#   'index': 411,
#   'word': 'имелись',
#   'start': 1850,
#   'end': 1857},
#  {'entity': 'FINDING',
#   'score': 0.6393383,
#   'index': 412,
#   'word': 'у',
#   'start': 1858,
#   'end': 1859},
#  {'entity': 'NUMBER',
#   'score': 0.9984218,
#   'index': 413,
#   'word': '48',
#   'start': 1860,
#   'end': 1862},
#  {'entity': 'PERSON',
#   'score': 0.9994616,
#   'index': 414,
#   'word': 'родственников',
#   'start': 1863,
#   'end': 1876},
#  {'entity': 'DATE',
#   'score': 0.2853002,
#   'index': 415,
#   'word': '.',
#   'start': 1876,
#   'end': 1877},
#  {'entity': 'FINDING',
#   'score': 0.5138469,
#   'index': 416,
#   'word': 'У',
#   'start': 1878,
#   'end': 1879},
#  {'entity': 'PERCENT',
#   'score': 0.9996338,
#   'index': 417,
#   'word': '80',
#   'start': 1880,
#   'end': 1882},
#  {'entity': 'PERCENT',
#   'score': 0.9972861,
#   'index': 418,
#   'word': ',',
#   'start': 1882,
#   'end': 1883},
#  {'entity': 'PERCENT',
#   'score': 0.9981091,
#   'index': 419,
#   'word': '4',
#   'start': 1883,
#   'end': 1884},
#  {'entity': 'PERCENT',
#   'score': 0.95383143,
#   'index': 420,
#   'word': '%',
#   'start': 1884,
#   'end': 1885},
#  {'entity': 'PERSON',
#   'score': 0.99984515,
#   'index': 421,
#   'word': 'обследова',
#   'start': 1886,
#   'end': 1895},
#  {'entity': 'PERSON',
#   'score': 0.99981445,
#   'index': 422,
#   'word': '##нных',
#   'start': 1895,
#   'end': 1899},
#  {'entity': 'PERSON',
#   'score': 0.9998753,
#   'index': 423,
#   'word': 'родственников',
#   'start': 1900,
#   'end': 1913},
#  {'entity': 'PERSON',
#   'score': 0.72137886,
#   'index': 424,
#   'word': 'диа',
#   'start': 1914,
#   'end': 1917},
#  {'entity': 'PERSON',
#   'score': 0.5733802,
#   'index': 425,
#   'word': '##лиз',
#   'start': 1917,
#   'end': 1920},
#  {'entity': 'PERSON',
#   'score': 0.97361267,
#   'index': 426,
#   'word': '##ных',
#   'start': 1920,
#   'end': 1923},
#  {'entity': 'PERSON',
#   'score': 0.958267,
#   'index': 427,
#   'word': 'проба',
#   'start': 1924,
#   'end': 1929},
#  {'entity': 'PERSON',
#   'score': 0.5914968,
#   'index': 428,
#   'word': '##ндо',
#   'start': 1929,
#   'end': 1932},
#  {'entity': 'PERSON',
#   'score': 0.74939376,
#   'index': 429,
#   'word': '##в',
#   'start': 1932,
#   'end': 1933},
#  {'entity': 'FINDING',
#   'score': 0.99903846,
#   'index': 430,
#   'word': 'обнаружено',
#   'start': 1934,
#   'end': 1944},
#  {'entity': 'DISO',
#   'score': 0.99749076,
#   'index': 431,
#   'word': 'поражение',
#   'start': 1945,
#   'end': 1954},
#  {'entity': 'ANATOMY',
#   'score': 0.9998729,
#   'index': 432,
#   'word': 'почек',
#   'start': 1955,
#   'end': 1960},
#  {'entity': 'FINDING',
#   'score': 0.48898238,
#   'index': 433,
#   'word': ',',
#   'start': 1960,
#   'end': 1961},
#  {'entity': 'DISO',
#   'score': 0.47346422,
#   'index': 434,
#   'word': 'преимущественно',
#   'start': 1962,
#   'end': 1977},
#  {'entity': 'DISO',
#   'score': 0.66528684,
#   'index': 435,
#   'word': 'на',
#   'start': 1978,
#   'end': 1980},
#  {'entity': 'DISO',
#   'score': 0.9230278,
#   'index': 436,
#   'word': 'ранних',
#   'start': 1981,
#   'end': 1987},
#  {'entity': 'DISO',
#   'score': 0.98349965,
#   'index': 437,
#   'word': 'стадиях',
#   'start': 1988,
#   'end': 1995},
#  {'entity': 'ORDINAL',
#   'score': 0.22628179,
#   'index': 438,
#   'word': '.',
#   'start': 1995,
#   'end': 1996},
#  {'entity': 'FINDING',
#   'score': 0.3878006,
#   'index': 439,
#   'word': 'Заключение',
#   'start': 1997,
#   'end': 2007},
#  {'entity': 'FINDING',
#   'score': 0.52115405,
#   'index': 440,
#   'word': '.',
#   'start': 2007,
#   'end': 2008},
#  {'entity': 'DISO',
#   'score': 0.9998524,
#   'index': 441,
#   'word': 'Т',
#   'start': 2009,
#   'end': 2010},
#  {'entity': 'DISO',
#   'score': 0.99976856,
#   'index': 442,
#   'word': '##Х',
#   'start': 2010,
#   'end': 2011},
#  {'entity': 'DISO',
#   'score': 0.9997161,
#   'index': 443,
#   'word': '##П',
#   'start': 2011,
#   'end': 2012},
#  {'entity': 'DISO',
#   'score': 0.99976355,
#   'index': 444,
#   'word': '##Н',
#   'start': 2012,
#   'end': 2013},
#  {'entity': 'DISO',
#   'score': 0.930401,
#   'index': 445,
#   'word': 'нередко',
#   'start': 2014,
#   'end': 2021},
#  {'entity': 'DISO',
#   'score': 0.8649778,
#   'index': 446,
#   'word': '##е',
#   'start': 2021,
#   'end': 2022},
#  {'entity': 'DISO',
#   'score': 0.9994741,
#   'index': 447,
#   'word': 'ослож',
#   'start': 2023,
#   'end': 2028},
#  {'entity': 'DISO',
#   'score': 0.9968856,
#   'index': 448,
#   'word': '##нение',
#   'start': 2028,
#   'end': 2033},
#  {'entity': 'DISO',
#   'score': 0.9998166,
#   'index': 449,
#   'word': 'БФ',
#   'start': 2034,
#   'end': 2036},
#  {'entity': 'FINDING',
#   'score': 0.6590828,
#   'index': 450,
#   'word': ',',
#   'start': 2036,
#   'end': 2037},
#  {'entity': 'FINDING',
#   'score': 0.97118676,
#   'index': 451,
#   'word': 'ассоции',
#   'start': 2038,
#   'end': 2045},
#  {'entity': 'DISO',
#   'score': 0.6599171,
#   'index': 452,
#   'word': '##рованное',
#   'start': 2045,
#   'end': 2053},
#  {'entity': 'FINDING',
#   'score': 0.9947707,
#   'index': 453,
#   'word': 'с',
#   'start': 2054,
#   'end': 2055},
#  {'entity': 'FINDING',
#   'score': 0.99769706,
#   'index': 454,
#   'word': 'неблагоприят',
#   'start': 2056,
#   'end': 2068},
#  {'entity': 'FINDING',
#   'score': 0.9883972,
#   'index': 455,
#   'word': '##ным',
#   'start': 2068,
#   'end': 2071},
#  {'entity': 'PHYS',
#   'score': 0.9034022,
#   'index': 456,
#   'word': 'прогнозом',
#   'start': 2072,
#   'end': 2081},
#  {'entity': 'ORDINAL',
#   'score': 0.22284845,
#   'index': 457,
#   'word': '.',
#   'start': 2081,
#   'end': 2082},
#  {'entity': 'FINDING',
#   'score': 0.98467666,
#   'index': 458,
#   'word': 'Однако',
#   'start': 2083,
#   'end': 2089},
#  {'entity': 'MEDPROC',
#   'score': 0.9996761,
#   'index': 459,
#   'word': 'диа',
#   'start': 2090,
#   'end': 2093},
#  {'entity': 'MEDPROC',
#   'score': 0.999236,
#   'index': 460,
#   'word': '##лиз',
#   'start': 2093,
#   'end': 2096},
#  {'entity': 'MEDPROC',
#   'score': 0.9957172,
#   'index': 461,
#   'word': '##ный',
#   'start': 2096,
#   'end': 2099},
#  {'entity': 'MEDPROC',
#   'score': 0.98952603,
#   'index': 462,
#   'word': 'скрин',
#   'start': 2100,
#   'end': 2105},
#  {'entity': 'MEDPROC',
#   'score': 0.97314364,
#   'index': 463,
#   'word': '##инг',
#   'start': 2105,
#   'end': 2108},
#  {'entity': 'FINDING',
#   'score': 0.99824405,
#   'index': 464,
#   'word': '–',
#   'start': 2109,
#   'end': 2110},
#  {'entity': 'FINDING',
#   'score': 0.9996495,
#   'index': 465,
#   'word': 'эффективный',
#   'start': 2112,
#   'end': 2123},
#  {'entity': 'FINDING',
#   'score': 0.99273324,
#   'index': 466,
#   'word': 'способ',
#   'start': 2124,
#   'end': 2130},
#  {'entity': 'FINDING',
#   'score': 0.58257145,
#   'index': 467,
#   'word': 'выявления',
#   'start': 2131,
#   'end': 2140},
#  {'entity': 'PERSON',
#   'score': 0.99918836,
#   'index': 468,
#   'word': 'проба',
#   'start': 2141,
#   'end': 2146},
#  {'entity': 'PERSON',
#   'score': 0.995993,
#   'index': 469,
#   'word': '##ндо',
#   'start': 2146,
#   'end': 2149},
#  {'entity': 'PERSON',
#   'score': 0.99723995,
#   'index': 470,
#   'word': '##в',
#   'start': 2149,
#   'end': 2150},
#  {'entity': 'DISO',
#   'score': 0.78113645,
#   'index': 471,
#   'word': 'с',
#   'start': 2151,
#   'end': 2152},
#  {'entity': 'DISO',
#   'score': 0.999803,
#   'index': 472,
#   'word': 'БФ',
#   'start': 2153,
#   'end': 2155},
#  {'entity': 'FINDING',
#   'score': 0.9971413,
#   'index': 473,
#   'word': ',',
#   'start': 2155,
#   'end': 2156},
#  {'entity': 'FINDING',
#   'score': 0.9986701,
#   'index': 474,
#   'word': 'открываю',
#   'start': 2157,
#   'end': 2165},
#  {'entity': 'FINDING',
#   'score': 0.9990306,
#   'index': 475,
#   'word': '##щий',
#   'start': 2165,
#   'end': 2168},
#  {'entity': 'FINDING',
#   'score': 0.9824448,
#   'index': 476,
#   'word': 'возможность',
#   'start': 2169,
#   'end': 2180},
#  {'entity': 'FINDING',
#   'score': 0.8793953,
#   'index': 477,
#   'word': 'установить',
#   'start': 2181,
#   'end': 2191},
#  {'entity': 'FINDING',
#   'score': 0.53138226,
#   'index': 478,
#   'word': 'диагноз',
#   'start': 2192,
#   'end': 2199},
#  {'entity': 'DISO',
#   'score': 0.99975306,
#   'index': 479,
#   'word': 'БФ',
#   'start': 2200,
#   'end': 2202},
#  {'entity': 'PERSON',
#   'score': 0.80282813,
#   'index': 480,
#   'word': 'у',
#   'start': 2203,
#   'end': 2204},
#  {'entity': 'PERSON',
#   'score': 0.9995534,
#   'index': 481,
#   'word': 'родственников',
#   'start': 2205,
#   'end': 2218},
#  {'entity': 'DATE',
#   'score': 0.34963718,
#   'index': 482,
#   'word': 'на',
#   'start': 2219,
#   'end': 2221},
#  {'entity': 'DISO',
#   'score': 0.46144977,
#   'index': 483,
#   'word': 'ранних',
#   'start': 2222,
#   'end': 2228},
#  {'entity': 'DISO',
#   'score': 0.9495721,
#   'index': 484,
#   'word': 'стадиях',
#   'start': 2229,
#   'end': 2236},
#  {'entity': 'FINDING',
#   'score': 0.86425745,
#   'index': 485,
#   'word': ',',
#   'start': 2236,
#   'end': 2237},
#  {'entity': 'FINDING',
#   'score': 0.69420314,
#   'index': 486,
#   'word': 'когда',
#   'start': 2238,
#   'end': 2243},
#  {'entity': 'MEDPROC',
#   'score': 0.998243,
#   'index': 487,
#   'word': 'лечение',
#   'start': 2244,
#   'end': 2251},
#  {'entity': 'FINDING',
#   'score': 0.99866736,
#   'index': 488,
#   'word': 'наиболее',
#   'start': 2252,
#   'end': 2260},
#  {'entity': 'FINDING',
#   'score': 0.99870443,
#   'index': 489,
#   'word': 'эффективно',
#   'start': 2261,
#   'end': 2271},
#  {'entity': 'ORDINAL',
#   'score': 0.31923488,
#   'index': 490,
#   'word': '.',
#   'start': 2271,
#   'end': 2272}]
