# %% [markdown]
# <a href="https://colab.research.google.com/github/ekaterinatao/NER_biomed_domain/blob/main/active_learning/%D0%92%D0%9A%D0%A0_nerel_bio_RuBioBERT_active_learning_v4_mnlp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Инструменты
# Предобработанный дасасет [NEREL-BIO](https://huggingface.co/datasets/ekaterinatao/nerel_bio_ner_unnested)
#
# Исходная модель [RuBioBERT](https://huggingface.co/alexyalunin/RuBioBERT)

# %% [markdown]
# ### Установка зависимостей

# %%
# !pip install datasets accelerate evaluate wandb seqeval -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 3.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 18.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 7.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 19.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 4.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 7.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 14.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 kB 3.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 22.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 34.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 25.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 810.2 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.3 MB/s eta 0:00:00
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /simple/nvidia-cufft-cu12/
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 10.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 2.7 MB/s eta 0:00:00
#   Building wheel for seqeval (setup.py) ... done

# %%
import numpy as np
import pandas as pd
import random
from dataclasses import dataclass
import torch
from torch.nn.functional import softmax
import datasets
from datasets import Dataset, DatasetDict, concatenate_datasets
from transformers import (AutoTokenizer,
                          DataCollatorForTokenClassification,
                          AutoModelForTokenClassification,
                          TrainingArguments, Trainer,
                          pipeline)
from transformers.trainer_utils import get_last_checkpoint
import evaluate

import warnings
warnings.filterwarnings("ignore")

# %%
@dataclass
class TrainingConfig:
    seed = 64
    dataset = 'ekaterinatao/nerel_bio_ner_unnested'
    checkpoint = 'alexyalunin/RuBioBERT'
    hf_repo_id = "ekaterinatao/nerel-bio-RuBioBERT-al"
    n_labels = 45
    n_epochs = 10
    train_batch_size = 4
    eval_batch_size = 4
    device = "cuda" if torch.cuda.is_available() else "cpu"
    l_rate = 5e-05
    w_decay = 0.1
    warm_up = 0.1
    run_name = "RuBioBERT_AL_v4"

config = TrainingConfig()

# %%
seed = config.seed

random.seed(seed)
np.random.seed(seed)

torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %% [markdown]
# ### Скачивание датасета

# %%
dataset = datasets.load_dataset(config.dataset)
dataset
# Out:
# Downloading readme:   0%|          | 0.00/1.56k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/603k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/76.2k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/70.8k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/612 [00:00<?, ? examples/s]
# Generating valid split:   0%|          | 0/77 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/77 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'words', 'ner_tags'],
#         num_rows: 612
#     })
#     valid: Dataset({
#         features: ['id', 'words', 'ner_tags'],
#         num_rows: 77
#     })
#     test: Dataset({
#         features: ['id', 'words', 'ner_tags'],
#         num_rows: 77
#     })
# })

# %%
# Labels
url = 'https://raw.githubusercontent.com/ekaterinatao/NER_biomed_domain/main/labels.txt'
tags = pd.read_csv(url, names=['tag']).values.tolist()
tags = [item for sublist in tags for item in sublist]
tag_to_id = {tag: i for i, tag in enumerate(tags)}
id_to_tag = {i: tag for i, tag in enumerate(tags)}

# %% [markdown]
# ___
# ### Токенизация

# %%
tokenizer = AutoTokenizer.from_pretrained(config.checkpoint)
# Out:
# tokenizer_config.json:   0%|          | 0.00/413 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/1.78M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.75M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(examples["words"], truncation=True, max_length=512, is_split_into_words=True)

    labels = []
    for i, label in enumerate(examples[f"ner_tags"]):
        word_idxs = tokenized_inputs.word_ids(batch_index=i)  # Map tokens to their respective word.
        previous_word_idx = None
        label_ids = []
        for word_idx in word_idxs:
            if word_idx is None:
                label_ids.append(-100) # Set the special tokens to -100.
            elif word_idx != previous_word_idx:  # Only label the first token of a given word.
                label_ids.append(label[word_idx])
            else:
                label_ids.append(-100)
            previous_word_idx = word_idx
        labels.append(label_ids)

    tokenized_inputs["labels"] = labels
    return tokenized_inputs

# %%
tokenized_dataset = dataset.map(
    tokenize_and_align_labels, batched=True,
    #remove_columns = ['id', 'words', 'ner_tags']
)
tokenized_dataset
# Out:
# Map:   0%|          | 0/612 [00:00<?, ? examples/s]
# Map:   0%|          | 0/77 [00:00<?, ? examples/s]
# Map:   0%|          | 0/77 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'words', 'ner_tags', 'input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 612
#     })
#     valid: Dataset({
#         features: ['id', 'words', 'ner_tags', 'input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 77
#     })
#     test: Dataset({
#         features: ['id', 'words', 'ner_tags', 'input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 77
#     })
# })

# %% [markdown]
# # Обучение модели

# %%
seqeval = evaluate.load("seqeval")

def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=2)

    true_predictions = [
        [tags[p] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]
    true_labels = [
        [tags[l] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]

    results = seqeval.compute(predictions=true_predictions, references=true_labels)
    return {
        "precision": results["overall_precision"],
        "recall": results["overall_recall"],
        "f1": results["overall_f1"],
        "accuracy": results["overall_accuracy"],
    }
# Out:
# Downloading builder script:   0%|          | 0.00/6.34k [00:00<?, ?B/s]

# %%
def choose_samples_mnlp(test_predictions, n_tokens) -> np.ndarray:
    """Функция для реализации стратеги отбора примеров для разметки
    на основе MNLP"""

    test_pred_pt = torch.from_numpy(test_predictions)
    probas = softmax(test_pred_pt, dim=-1).detach().cpu().numpy()
    scores = np.array([
        -np.sum(np.log(np.max(i, axis=1))) / len(i) for i in probas
    ])
    args = np.argsort(-scores)

    return args[:n_tokens]

# %%
data_collator = DataCollatorForTokenClassification(tokenizer=tokenizer)

# %%
model = AutoModelForTokenClassification.from_pretrained(
    config.checkpoint, num_labels=config.n_labels, id2label=id_to_tag, label2id=tag_to_id
)
# Out:
# config.json:   0%|          | 0.00/889 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at alexyalunin/RuBioBERT and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
print(f'device is {config.device}')
# Out:
# device is cuda

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
import wandb
wandb.login()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
import os
os.environ["WANDB_PROJECT"]="ner_bert_nerel_bio"

# %%
def train_and_predict(
    train_dataset, eval_dataset, test_dataset,
    model, tokenizer, data_collator, compute_metrics
):
    "Функция для тренировки модели, сохранения метрик и предсказаний"

    global config
    training_args = TrainingArguments(
        output_dir=hf_repo_id,
        num_train_epochs=config.n_epochs,
        learning_rate=config.l_rate,
        weight_decay=config.w_decay,
        warmup_ratio=config.warm_up,
        per_device_train_batch_size=config.train_batch_size,
        per_device_eval_batch_size=config.eval_batch_size,
        group_by_length=True,
        optim="adamw_torch",
        lr_scheduler_type="cosine",
        evaluation_strategy="epoch",
        seed = config.seed,
        data_seed = config.seed,
        push_to_hub=True,
        save_strategy="no",
        report_to="wandb",
        logging_steps=16,
        run_name=config.run_name,
    )

    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=eval_dataset,
        tokenizer=tokenizer,
        data_collator=data_collator,
        compute_metrics=compute_metrics,
    )

    train_result = trainer.train()
    test_predictions = trainer.predict(
        test_dataset, metric_key_prefix="pred"
    )
    metrics = {}
    metrics['train_loss'] = train_result.metrics['train_loss']
    metrics.update(trainer.evaluate(eval_dataset))
    metrics.update(test_predictions.metrics)
    probas = test_predictions.predictions

    return metrics, probas, trainer

# %%
def run_active_learning(
    dataset, al_iters, init_train_size, choose_tokens,
    model, tokenizer, data_collator, compute_metrics
):
    "Функция для реализации цикла активного обучения"

    train_dataset = dataset['train'].select(
        random.sample(
            range(dataset['train'].num_rows),
            int(dataset['train'].num_rows * init_train_size)
        )
    )
    test_dataset = dataset['train'].filter(
        lambda s: s['id'] not in train_dataset['id']
    )
    all_metrics = {}

    for iter in range(al_iters):
        train_size = train_dataset.num_rows
        print(f'Training using {train_size} samples')

        eval_metrics, test_predictions, trainer = train_and_predict(
            train_dataset, dataset['valid'], test_dataset,
            model, tokenizer, data_collator, compute_metrics
        )

        all_metrics[f'{iter}'] = {'metrics': eval_metrics, 'train_size': train_size}

        if test_dataset.num_rows >= choose_tokens:
            new_args = choose_samples_mnlp(test_predictions, choose_tokens)
            new_train_samples = test_dataset.select(new_args)
            extended_train_dataset = concatenate_datasets(
                [train_dataset, new_train_samples]
            )

            train_dataset = extended_train_dataset
            test_dataset = dataset['train'].filter(
                lambda s: s['id'] not in train_dataset['id']
            )

    return all_metrics, trainer

# %%
metrics, trainer = run_active_learning(
    dataset=tokenized_dataset, al_iters=10, init_train_size=0.1, choose_tokens=61,
    model=model, tokenizer=tokenizer,
    data_collator=data_collator, compute_metrics=compute_metrics
)
# Out:
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]
# Training using 61 samples
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# wandb: Currently logged in as: taoea. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.4
# Run data is saved locally in <code>/content/wandb/run-20240322_175955-s45oc3rb</code>
# Syncing run <strong><a href='https://wandb.ai/taoea/ner_bert_nerel_bio/runs/s45oc3rb' target="_blank">RuBioBERT_AL_v4</a></strong> to <a href='https://wandb.ai/taoea/ner_bert_nerel_bio' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/taoea/ner_bert_nerel_bio' target="_blank">https://wandb.ai/taoea/ner_bert_nerel_bio</a>
#  View run at <a href='https://wandb.ai/taoea/ner_bert_nerel_bio/runs/s45oc3rb' target="_blank">https://wandb.ai/taoea/ner_bert_nerel_bio/runs/s45oc3rb</a>
#     <div>
#
#       <progress value='160' max='160' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [160/160 00:25, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.385500</td>
#       <td>2.925789</td>
#       <td>0.049296</td>
#       <td>0.001642</td>
#       <td>0.003177</td>
#       <td>0.158042</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.267000</td>
#       <td>2.012529</td>
#       <td>0.420856</td>
#       <td>0.343574</td>
#       <td>0.378309</td>
#       <td>0.537685</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.350600</td>
#       <td>1.434593</td>
#       <td>0.603119</td>
#       <td>0.562383</td>
#       <td>0.582039</td>
#       <td>0.693551</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.860100</td>
#       <td>1.240490</td>
#       <td>0.645208</td>
#       <td>0.620544</td>
#       <td>0.632636</td>
#       <td>0.727894</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.663400</td>
#       <td>1.124020</td>
#       <td>0.660775</td>
#       <td>0.640009</td>
#       <td>0.650226</td>
#       <td>0.742191</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.472900</td>
#       <td>1.049967</td>
#       <td>0.691080</td>
#       <td>0.670497</td>
#       <td>0.680633</td>
#       <td>0.770319</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.396700</td>
#       <td>1.000270</td>
#       <td>0.703881</td>
#       <td>0.689024</td>
#       <td>0.696374</td>
#       <td>0.781974</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.322900</td>
#       <td>1.009882</td>
#       <td>0.695569</td>
#       <td>0.684803</td>
#       <td>0.690144</td>
#       <td>0.779021</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.295800</td>
#       <td>1.000625</td>
#       <td>0.702774</td>
#       <td>0.689259</td>
#       <td>0.695951</td>
#       <td>0.784771</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.282500</td>
#       <td>1.000039</td>
#       <td>0.702774</td>
#       <td>0.689259</td>
#       <td>0.695951</td>
#       <td>0.784771</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:00]
#     </div>
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]
# Training using 122 samples
#     <div>
#
#       <progress value='310' max='310' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [310/310 00:37, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.562800</td>
#       <td>0.865911</td>
#       <td>0.727535</td>
#       <td>0.710131</td>
#       <td>0.718728</td>
#       <td>0.802176</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.382100</td>
#       <td>0.800964</td>
#       <td>0.748732</td>
#       <td>0.726782</td>
#       <td>0.737594</td>
#       <td>0.818026</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.334200</td>
#       <td>0.806068</td>
#       <td>0.745331</td>
#       <td>0.720685</td>
#       <td>0.732801</td>
#       <td>0.817094</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.251400</td>
#       <td>0.762279</td>
#       <td>0.751892</td>
#       <td>0.745544</td>
#       <td>0.748705</td>
#       <td>0.826729</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.139700</td>
#       <td>0.761715</td>
#       <td>0.763252</td>
#       <td>0.753049</td>
#       <td>0.758116</td>
#       <td>0.833256</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.102800</td>
#       <td>0.812299</td>
#       <td>0.758490</td>
#       <td>0.749062</td>
#       <td>0.753746</td>
#       <td>0.830925</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.094600</td>
#       <td>0.809445</td>
#       <td>0.750351</td>
#       <td>0.751407</td>
#       <td>0.750879</td>
#       <td>0.828594</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.047600</td>
#       <td>0.812492</td>
#       <td>0.763028</td>
#       <td>0.758912</td>
#       <td>0.760964</td>
#       <td>0.837296</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.047100</td>
#       <td>0.819832</td>
#       <td>0.764998</td>
#       <td>0.759615</td>
#       <td>0.762297</td>
#       <td>0.837141</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.047900</td>
#       <td>0.823464</td>
#       <td>0.765304</td>
#       <td>0.759381</td>
#       <td>0.762331</td>
#       <td>0.836830</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:00]
#     </div>
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]
# Training using 183 samples
#     <div>
#
#       <progress value='460' max='460' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [460/460 00:49, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.193600</td>
#       <td>0.742198</td>
#       <td>0.755425</td>
#       <td>0.751173</td>
#       <td>0.753293</td>
#       <td>0.831857</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.135800</td>
#       <td>0.781195</td>
#       <td>0.751839</td>
#       <td>0.743199</td>
#       <td>0.747494</td>
#       <td>0.829060</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.110900</td>
#       <td>0.778787</td>
#       <td>0.750000</td>
#       <td>0.754925</td>
#       <td>0.752454</td>
#       <td>0.831857</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.071800</td>
#       <td>0.780028</td>
#       <td>0.769374</td>
#       <td>0.772983</td>
#       <td>0.771175</td>
#       <td>0.844289</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.042800</td>
#       <td>0.834578</td>
#       <td>0.766824</td>
#       <td>0.764306</td>
#       <td>0.765563</td>
#       <td>0.840404</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.032200</td>
#       <td>0.825753</td>
#       <td>0.765325</td>
#       <td>0.767120</td>
#       <td>0.766222</td>
#       <td>0.841803</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.023500</td>
#       <td>0.848445</td>
#       <td>0.758428</td>
#       <td>0.765009</td>
#       <td>0.761705</td>
#       <td>0.838850</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.016300</td>
#       <td>0.847994</td>
#       <td>0.771167</td>
#       <td>0.768996</td>
#       <td>0.770080</td>
#       <td>0.843978</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.011800</td>
#       <td>0.849698</td>
#       <td>0.772300</td>
#       <td>0.771576</td>
#       <td>0.771938</td>
#       <td>0.844911</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.008800</td>
#       <td>0.850637</td>
#       <td>0.772717</td>
#       <td>0.771811</td>
#       <td>0.772263</td>
#       <td>0.844911</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:00]
#     </div>
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]
# Training using 244 samples
#     <div>
#
#       <progress value='610' max='610' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [610/610 01:03, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.165400</td>
#       <td>0.680812</td>
#       <td>0.764939</td>
#       <td>0.768527</td>
#       <td>0.766729</td>
#       <td>0.842580</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.169700</td>
#       <td>0.732331</td>
#       <td>0.763895</td>
#       <td>0.767120</td>
#       <td>0.765504</td>
#       <td>0.839938</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.090200</td>
#       <td>0.766527</td>
#       <td>0.776319</td>
#       <td>0.776501</td>
#       <td>0.776410</td>
#       <td>0.849417</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.079000</td>
#       <td>0.775407</td>
#       <td>0.763287</td>
#       <td>0.764540</td>
#       <td>0.763913</td>
#       <td>0.842424</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.036400</td>
#       <td>0.761999</td>
#       <td>0.765766</td>
#       <td>0.777439</td>
#       <td>0.771558</td>
#       <td>0.846620</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.026300</td>
#       <td>0.796551</td>
#       <td>0.770195</td>
#       <td>0.778143</td>
#       <td>0.774148</td>
#       <td>0.848019</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.012900</td>
#       <td>0.819894</td>
#       <td>0.770557</td>
#       <td>0.775797</td>
#       <td>0.773168</td>
#       <td>0.848640</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.008500</td>
#       <td>0.833156</td>
#       <td>0.771860</td>
#       <td>0.778377</td>
#       <td>0.775105</td>
#       <td>0.850350</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.005700</td>
#       <td>0.836889</td>
#       <td>0.773129</td>
#       <td>0.780019</td>
#       <td>0.776558</td>
#       <td>0.850971</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.007000</td>
#       <td>0.838428</td>
#       <td>0.773488</td>
#       <td>0.780019</td>
#       <td>0.776740</td>
#       <td>0.851282</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:00]
#     </div>
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]
# Training using 305 samples
#     <div>
#
#       <progress value='770' max='770' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [770/770 01:16, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.142200</td>
#       <td>0.751495</td>
#       <td>0.747661</td>
#       <td>0.749765</td>
#       <td>0.748712</td>
#       <td>0.830769</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.092900</td>
#       <td>0.786132</td>
#       <td>0.763666</td>
#       <td>0.769934</td>
#       <td>0.766787</td>
#       <td>0.845221</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.077300</td>
#       <td>0.772859</td>
#       <td>0.765854</td>
#       <td>0.773218</td>
#       <td>0.769518</td>
#       <td>0.845221</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.056500</td>
#       <td>0.784471</td>
#       <td>0.778270</td>
#       <td>0.782833</td>
#       <td>0.780545</td>
#       <td>0.851593</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.022300</td>
#       <td>0.800218</td>
#       <td>0.769536</td>
#       <td>0.773687</td>
#       <td>0.771606</td>
#       <td>0.847397</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.018200</td>
#       <td>0.789694</td>
#       <td>0.780613</td>
#       <td>0.781895</td>
#       <td>0.781254</td>
#       <td>0.853458</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.015600</td>
#       <td>0.835446</td>
#       <td>0.782396</td>
#       <td>0.785882</td>
#       <td>0.784135</td>
#       <td>0.852370</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.006400</td>
#       <td>0.840614</td>
#       <td>0.782396</td>
#       <td>0.785882</td>
#       <td>0.784135</td>
#       <td>0.853302</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.004300</td>
#       <td>0.848809</td>
#       <td>0.782964</td>
#       <td>0.786820</td>
#       <td>0.784887</td>
#       <td>0.854079</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.003800</td>
#       <td>0.849244</td>
#       <td>0.782446</td>
#       <td>0.786116</td>
#       <td>0.784277</td>
#       <td>0.853768</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:00]
#     </div>
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]
# Training using 366 samples
#     <div>
#
#       <progress value='920' max='920' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [920/920 01:30, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.127000</td>
#       <td>0.746309</td>
#       <td>0.783656</td>
#       <td>0.778143</td>
#       <td>0.780890</td>
#       <td>0.853613</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.051400</td>
#       <td>0.826447</td>
#       <td>0.783164</td>
#       <td>0.776735</td>
#       <td>0.779936</td>
#       <td>0.847863</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.052400</td>
#       <td>0.797915</td>
#       <td>0.774602</td>
#       <td>0.775328</td>
#       <td>0.774965</td>
#       <td>0.846775</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.023000</td>
#       <td>0.821456</td>
#       <td>0.781279</td>
#       <td>0.779081</td>
#       <td>0.780178</td>
#       <td>0.851127</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.041700</td>
#       <td>0.821247</td>
#       <td>0.779312</td>
#       <td>0.780957</td>
#       <td>0.780134</td>
#       <td>0.852681</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.015000</td>
#       <td>0.869418</td>
#       <td>0.782548</td>
#       <td>0.782364</td>
#       <td>0.782456</td>
#       <td>0.854390</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.007000</td>
#       <td>0.862448</td>
#       <td>0.787565</td>
#       <td>0.784240</td>
#       <td>0.785899</td>
#       <td>0.855944</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.003200</td>
#       <td>0.859354</td>
#       <td>0.785932</td>
#       <td>0.786116</td>
#       <td>0.786024</td>
#       <td>0.856410</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.003100</td>
#       <td>0.865057</td>
#       <td>0.787189</td>
#       <td>0.786820</td>
#       <td>0.787004</td>
#       <td>0.857032</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.005300</td>
#       <td>0.866488</td>
#       <td>0.787474</td>
#       <td>0.787289</td>
#       <td>0.787381</td>
#       <td>0.857032</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:00]
#     </div>
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]
# Training using 427 samples
#     <div>
#
#       <progress value='1070' max='1070' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1070/1070 01:46, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.124600</td>
#       <td>0.739138</td>
#       <td>0.784123</td>
#       <td>0.792214</td>
#       <td>0.788147</td>
#       <td>0.858275</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.044100</td>
#       <td>0.707252</td>
#       <td>0.788163</td>
#       <td>0.787054</td>
#       <td>0.787609</td>
#       <td>0.858897</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.036200</td>
#       <td>0.724527</td>
#       <td>0.777518</td>
#       <td>0.778612</td>
#       <td>0.778064</td>
#       <td>0.854856</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.048400</td>
#       <td>0.713519</td>
#       <td>0.786533</td>
#       <td>0.788931</td>
#       <td>0.787730</td>
#       <td>0.861694</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.023900</td>
#       <td>0.788612</td>
#       <td>0.783322</td>
#       <td>0.784240</td>
#       <td>0.783781</td>
#       <td>0.855012</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.005900</td>
#       <td>0.789787</td>
#       <td>0.785351</td>
#       <td>0.797139</td>
#       <td>0.791201</td>
#       <td>0.861694</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.010200</td>
#       <td>0.824214</td>
#       <td>0.785034</td>
#       <td>0.792214</td>
#       <td>0.788607</td>
#       <td>0.860295</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.001600</td>
#       <td>0.821630</td>
#       <td>0.789131</td>
#       <td>0.796904</td>
#       <td>0.792999</td>
#       <td>0.864336</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.002500</td>
#       <td>0.830340</td>
#       <td>0.789865</td>
#       <td>0.796904</td>
#       <td>0.793369</td>
#       <td>0.864180</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.002100</td>
#       <td>0.832297</td>
#       <td>0.789682</td>
#       <td>0.796904</td>
#       <td>0.793277</td>
#       <td>0.864180</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:00]
#     </div>
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]
# Training using 488 samples
#     <div>
#
#       <progress value='1220' max='1220' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1220/1220 02:01, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.048100</td>
#       <td>0.779545</td>
#       <td>0.784282</td>
#       <td>0.788696</td>
#       <td>0.786483</td>
#       <td>0.855322</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.049600</td>
#       <td>0.780112</td>
#       <td>0.785714</td>
#       <td>0.791979</td>
#       <td>0.788834</td>
#       <td>0.858430</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.047800</td>
#       <td>0.741246</td>
#       <td>0.781003</td>
#       <td>0.788696</td>
#       <td>0.784831</td>
#       <td>0.854701</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.027200</td>
#       <td>0.719751</td>
#       <td>0.799675</td>
#       <td>0.807927</td>
#       <td>0.803780</td>
#       <td>0.866977</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.010900</td>
#       <td>0.777669</td>
#       <td>0.788230</td>
#       <td>0.797842</td>
#       <td>0.793007</td>
#       <td>0.861383</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.011500</td>
#       <td>0.779561</td>
#       <td>0.790644</td>
#       <td>0.800657</td>
#       <td>0.795619</td>
#       <td>0.862937</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.002600</td>
#       <td>0.806473</td>
#       <td>0.786893</td>
#       <td>0.794090</td>
#       <td>0.790475</td>
#       <td>0.861228</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.004600</td>
#       <td>0.815577</td>
#       <td>0.793071</td>
#       <td>0.799953</td>
#       <td>0.796497</td>
#       <td>0.863403</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.000800</td>
#       <td>0.823294</td>
#       <td>0.794753</td>
#       <td>0.802767</td>
#       <td>0.798740</td>
#       <td>0.865113</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.002500</td>
#       <td>0.824161</td>
#       <td>0.795217</td>
#       <td>0.803236</td>
#       <td>0.799207</td>
#       <td>0.865423</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:00]
#     </div>
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]
# Training using 549 samples
#     <div>
#
#       <progress value='1380' max='1380' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1380/1380 02:17, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.064400</td>
#       <td>0.657779</td>
#       <td>0.796356</td>
#       <td>0.809803</td>
#       <td>0.803023</td>
#       <td>0.868376</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.027900</td>
#       <td>0.735730</td>
#       <td>0.786281</td>
#       <td>0.790338</td>
#       <td>0.788304</td>
#       <td>0.858897</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.036400</td>
#       <td>0.812462</td>
#       <td>0.781337</td>
#       <td>0.789400</td>
#       <td>0.785348</td>
#       <td>0.857032</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.025400</td>
#       <td>0.752507</td>
#       <td>0.791482</td>
#       <td>0.797608</td>
#       <td>0.794533</td>
#       <td>0.864646</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.014800</td>
#       <td>0.804378</td>
#       <td>0.789401</td>
#       <td>0.799953</td>
#       <td>0.794642</td>
#       <td>0.861383</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.003900</td>
#       <td>0.827016</td>
#       <td>0.795890</td>
#       <td>0.799250</td>
#       <td>0.797566</td>
#       <td>0.864646</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.004800</td>
#       <td>0.830015</td>
#       <td>0.796551</td>
#       <td>0.801595</td>
#       <td>0.799065</td>
#       <td>0.866822</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.002000</td>
#       <td>0.862901</td>
#       <td>0.795857</td>
#       <td>0.801829</td>
#       <td>0.798832</td>
#       <td>0.866356</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.001200</td>
#       <td>0.859887</td>
#       <td>0.795015</td>
#       <td>0.800422</td>
#       <td>0.797709</td>
#       <td>0.865579</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.001000</td>
#       <td>0.860878</td>
#       <td>0.794734</td>
#       <td>0.799953</td>
#       <td>0.797335</td>
#       <td>0.865579</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:00]
#     </div>
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]
# Training using 610 samples
#     <div>
#
#       <progress value='1530' max='1530' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1530/1530 02:34, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.103700</td>
#       <td>0.744990</td>
#       <td>0.793304</td>
#       <td>0.800188</td>
#       <td>0.796731</td>
#       <td>0.863248</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.043000</td>
#       <td>0.753496</td>
#       <td>0.774246</td>
#       <td>0.788227</td>
#       <td>0.781174</td>
#       <td>0.855789</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.031400</td>
#       <td>0.799583</td>
#       <td>0.787367</td>
#       <td>0.798077</td>
#       <td>0.792686</td>
#       <td>0.860451</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.017300</td>
#       <td>0.843356</td>
#       <td>0.781409</td>
#       <td>0.790572</td>
#       <td>0.785964</td>
#       <td>0.857032</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.013300</td>
#       <td>0.794461</td>
#       <td>0.798836</td>
#       <td>0.804644</td>
#       <td>0.801729</td>
#       <td>0.867910</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.007000</td>
#       <td>0.836071</td>
#       <td>0.794670</td>
#       <td>0.804174</td>
#       <td>0.799394</td>
#       <td>0.867288</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.003100</td>
#       <td>0.861378</td>
#       <td>0.796879</td>
#       <td>0.802298</td>
#       <td>0.799579</td>
#       <td>0.866977</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.002800</td>
#       <td>0.858237</td>
#       <td>0.797115</td>
#       <td>0.803471</td>
#       <td>0.800280</td>
#       <td>0.868065</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.000500</td>
#       <td>0.858710</td>
#       <td>0.798929</td>
#       <td>0.805113</td>
#       <td>0.802009</td>
#       <td>0.868221</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000400</td>
#       <td>0.860010</td>
#       <td>0.798884</td>
#       <td>0.805816</td>
#       <td>0.802335</td>
#       <td>0.868531</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:00]
#     </div>
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]

# %%
wandb.finish()
# Out:
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>▁▆▇▇▇▇██████████████████████████████████</td></tr><tr><td>eval/f1</td><td>▁▆▇▇▇▇██████████████████████████████████</td></tr><tr><td>eval/loss</td><td>█▃▂▂▂▁▁▁▁▁▁▂▁▁▁▁▁▁▁▂▁▁▂▂▁▁▁▁▁▁▁▁▁▁▂▂▁▁▂▂</td></tr><tr><td>eval/precision</td><td>▁▆▇▇▇▇██████████████████████████████████</td></tr><tr><td>eval/recall</td><td>▁▆▇▇▇▇██████████████████████████████████</td></tr><tr><td>eval/runtime</td><td>▁▇▁▁▁▁▃▇▁▁▁▁▁█▁▁▁▂▁▃▁▁█▁▂▁▇▂▂▃▄▆▂▁▁▁▂▂▂█</td></tr><tr><td>eval/samples_per_second</td><td>▇▂██▇█▅▁▇▇█▇▇▁███▇▇▆██▁█▇█▂▇▇▆▅▃▇█▇█▇▇▇▁</td></tr><tr><td>eval/steps_per_second</td><td>▇▂██▇█▅▁▇▇█▇▇▁███▇▇▆██▁█▇█▂▇▇▆▅▃▇█▇█▇▇▇▁</td></tr><tr><td>train/epoch</td><td>▄▂▅▂▄▇▃▅▇▂▄▆█▂▄▆▇▂▃▅▆█▂▃▄▆▇▁▂▃▅▆▇█▂▃▄▅▆█</td></tr><tr><td>train/global_step</td><td>▁▁▂▁▂▃▂▃▃▁▂▃▄▂▃▄▅▁▂▃▅▆▂▃▄▅▆▁▂▃▄▅▆▇▂▃▄▅▆█</td></tr><tr><td>train/grad_norm</td><td>▂▃▃▂▂▂▂▃▂▂▁▂▄▃▁▂▂▂▁▁▁▂▂▂▂▂▃▁▃▁▁▁▂█▂▂▁▂▁▁</td></tr><tr><td>train/learning_rate</td><td>▂▇█▆▁▆▄▂▇▅▁█▇▄▃▁█▇▄▂▁█▆▅▃▁▃█▇▅▃▂▁██▆▅▄▂▁</td></tr><tr><td>train/loss</td><td>█▇▆▃▁▃▁▃▁▁▁▃▂▁▁▁▂▂▁▁▁▂▂▁▁▁▂▂▂▁▁▁▁▂▂▂▁▁▁▁</td></tr><tr><td>train/total_flos</td><td>▁▂▂▃▄▄▅▆▇█</td></tr><tr><td>train/train_loss</td><td>█▂▁▁▁▁▁▁▁▁</td></tr><tr><td>train/train_runtime</td><td>▁▁▂▃▄▄▅▆▇█</td></tr><tr><td>train/train_samples_per_second</td><td>▁▅▇▇██████</td></tr><tr><td>train/train_steps_per_second</td><td>▁▅▇▇██████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>0.86853</td></tr><tr><td>eval/f1</td><td>0.80234</td></tr><tr><td>eval/loss</td><td>0.86001</td></tr><tr><td>eval/precision</td><td>0.79888</td></tr><tr><td>eval/recall</td><td>0.80582</td></tr><tr><td>eval/runtime</td><td>1.1579</td></tr><tr><td>eval/samples_per_second</td><td>66.5</td></tr><tr><td>eval/steps_per_second</td><td>17.273</td></tr><tr><td>train/epoch</td><td>10.0</td></tr><tr><td>train/global_step</td><td>1530</td></tr><tr><td>train/grad_norm</td><td>0.00655</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>train/loss</td><td>0.0004</td></tr><tr><td>train/total_flos</td><td>861971232274200.0</td></tr><tr><td>train/train_loss</td><td>0.02069</td></tr><tr><td>train/train_runtime</td><td>154.2075</td></tr><tr><td>train/train_samples_per_second</td><td>39.557</td></tr><tr><td>train/train_steps_per_second</td><td>9.922</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">RuBioBERT_AL_v4</strong> at: <a href='https://wandb.ai/taoea/ner_bert_nerel_bio/runs/s45oc3rb' target="_blank">https://wandb.ai/taoea/ner_bert_nerel_bio/runs/s45oc3rb</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240322_175955-s45oc3rb/logs</code>

# %%
metrics
# Out:
# {'0': {'metrics': {'train_loss': 1.0297480553388596,
#    'eval_loss': 1.0000391006469727,
#    'eval_precision': 0.7027737924438068,
#    'eval_recall': 0.6892589118198874,
#    'eval_f1': 0.6959507459152261,
#    'eval_accuracy': 0.7847707847707848,
#    'eval_runtime': 0.9161,
#    'eval_samples_per_second': 84.053,
#    'eval_steps_per_second': 21.832,
#    'epoch': 10.0,
#    'pred_loss': 0.7819056510925293,
#    'pred_precision': 0.7273767885532592,
#    'pred_recall': 0.7065291247143122,
#    'pred_f1': 0.7168014037726389,
#    'pred_accuracy': 0.8206197854588796,
#    'pred_runtime': 7.7241,
#    'pred_samples_per_second': 71.335,
#    'pred_steps_per_second': 17.866},
#   'train_size': 61},
#  '1': {'metrics': {'train_loss': 0.2042718634490044,
#    'eval_loss': 0.8234638571739197,
#    'eval_precision': 0.7653037107066887,
#    'eval_recall': 0.7593808630393997,
#    'eval_f1': 0.7623307828134197,
#    'eval_accuracy': 0.8368298368298368,
#    'eval_runtime': 1.06,
#    'eval_samples_per_second': 72.644,
#    'eval_steps_per_second': 18.868,
#    'epoch': 10.0,
#    'pred_loss': 0.7084041833877563,
#    'pred_precision': 0.7735536047556508,
#    'pred_recall': 0.7615256370997925,
#    'pred_f1': 0.7674924989284183,
#    'pred_accuracy': 0.8589920256624574,
#    'pred_runtime': 6.1448,
#    'pred_samples_per_second': 79.742,
#    'pred_steps_per_second': 20.017},
#   'train_size': 122},
#  '2': {'metrics': {'train_loss': 0.07302638068795204,
#    'eval_loss': 0.8506368398666382,
#    'eval_precision': 0.7727166001408782,
#    'eval_recall': 0.7718105065666041,
#    'eval_f1': 0.7722632875747976,
#    'eval_accuracy': 0.8449106449106449,
#    'eval_runtime': 0.8902,
#    'eval_samples_per_second': 86.498,
#    'eval_steps_per_second': 22.467,
#    'epoch': 10.0,
#    'pred_loss': 0.7224091291427612,
#    'pred_precision': 0.7836482838411107,
#    'pred_recall': 0.7723886270336019,
#    'pred_f1': 0.7779777173704965,
#    'pred_accuracy': 0.8654055009723941,
#    'pred_runtime': 5.5308,
#    'pred_samples_per_second': 77.566,
#    'pred_steps_per_second': 19.527},
#   'train_size': 183},
#  '3': {'metrics': {'train_loss': 0.05767390375315654,
#    'eval_loss': 0.8384276628494263,
#    'eval_precision': 0.7734883720930232,
#    'eval_recall': 0.7800187617260788,
#    'eval_f1': 0.7767398411957028,
#    'eval_accuracy': 0.8512820512820513,
#    'eval_runtime': 0.8793,
#    'eval_samples_per_second': 87.566,
#    'eval_steps_per_second': 22.744,
#    'epoch': 10.0,
#    'pred_loss': 0.7046812176704407,
#    'pred_precision': 0.7935699226985242,
#    'pred_recall': 0.7839291912530372,
#    'pred_f1': 0.788720097782434,
#    'pred_accuracy': 0.8709445052728635,
#    'pred_runtime': 4.9446,
#    'pred_samples_per_second': 74.425,
#    'pred_steps_per_second': 18.606},
#   'train_size': 244},
#  '4': {'metrics': {'train_loss': 0.03976122820145124,
#    'eval_loss': 0.8492438793182373,
#    'eval_precision': 0.7824463118580766,
#    'eval_recall': 0.7861163227016885,
#    'eval_f1': 0.7842770238652316,
#    'eval_accuracy': 0.8537684537684538,
#    'eval_runtime': 0.8927,
#    'eval_samples_per_second': 86.252,
#    'eval_steps_per_second': 22.403,
#    'epoch': 10.0,
#    'pred_loss': 0.6882714629173279,
#    'pred_precision': 0.796788967220707,
#    'pred_recall': 0.789879100137734,
#    'pred_f1': 0.7933189876011886,
#    'pred_accuracy': 0.8757799588519005,
#    'pred_runtime': 4.1669,
#    'pred_samples_per_second': 73.676,
#    'pred_steps_per_second': 18.479},
#   'train_size': 305},
#  '5': {'metrics': {'train_loss': 0.03199033139111555,
#    'eval_loss': 0.8664875626564026,
#    'eval_precision': 0.7874736101337086,
#    'eval_recall': 0.7872889305816135,
#    'eval_f1': 0.7873812595285564,
#    'eval_accuracy': 0.857031857031857,
#    'eval_runtime': 0.8983,
#    'eval_samples_per_second': 85.715,
#    'eval_steps_per_second': 22.264,
#    'epoch': 10.0,
#    'pred_loss': 0.7256907820701599,
#    'pred_precision': 0.7980702528851611,
#    'pred_recall': 0.7863667433045424,
#    'pred_f1': 0.7921752738654148,
#    'pred_accuracy': 0.8763934021636296,
#    'pred_runtime': 3.442,
#    'pred_samples_per_second': 71.47,
#    'pred_steps_per_second': 18.013},
#   'train_size': 366},
#  '6': {'metrics': {'train_loss': 0.03133858731103556,
#    'eval_loss': 0.8322972059249878,
#    'eval_precision': 0.7896816174761794,
#    'eval_recall': 0.7969043151969981,
#    'eval_f1': 0.793276526205206,
#    'eval_accuracy': 0.8641802641802642,
#    'eval_runtime': 0.8822,
#    'eval_samples_per_second': 87.278,
#    'eval_steps_per_second': 22.67,
#    'epoch': 10.0,
#    'pred_loss': 0.6876980066299438,
#    'pred_precision': 0.8090612244897959,
#    'pred_recall': 0.803030303030303,
#    'pred_f1': 0.8060344827586207,
#    'pred_accuracy': 0.883503993995604,
#    'pred_runtime': 2.6626,
#    'pred_samples_per_second': 69.481,
#    'pred_steps_per_second': 17.652},
#   'train_size': 427},
#  '7': {'metrics': {'train_loss': 0.02765916019533074,
#    'eval_loss': 0.8241612911224365,
#    'eval_precision': 0.7952170884606454,
#    'eval_recall': 0.8032363977485929,
#    'eval_f1': 0.7992066269980166,
#    'eval_accuracy': 0.8654234654234654,
#    'eval_runtime': 0.9017,
#    'eval_samples_per_second': 85.395,
#    'eval_steps_per_second': 22.181,
#    'epoch': 10.0,
#    'pred_loss': 0.71869295835495,
#    'pred_precision': 0.8061600665953146,
#    'pred_recall': 0.797248030107021,
#    'pred_f1': 0.8016792809839167,
#    'pred_accuracy': 0.8836360813538271,
#    'pred_runtime': 1.8762,
#    'pred_samples_per_second': 66.093,
#    'pred_steps_per_second': 16.523},
#   'train_size': 488},
#  '8': {'metrics': {'train_loss': 0.023626599155123468,
#    'eval_loss': 0.8608779907226562,
#    'eval_precision': 0.7947343895619757,
#    'eval_recall': 0.799953095684803,
#    'eval_f1': 0.7973352033660589,
#    'eval_accuracy': 0.8655788655788655,
#    'eval_runtime': 1.1456,
#    'eval_samples_per_second': 67.212,
#    'eval_steps_per_second': 17.458,
#    'epoch': 10.0,
#    'pred_loss': 0.6936564445495605,
#    'pred_precision': 0.8044485634847081,
#    'pred_recall': 0.8,
#    'pred_f1': 0.8022181146025879,
#    'pred_accuracy': 0.8884609687453711,
#    'pred_runtime': 1.2465,
#    'pred_samples_per_second': 50.54,
#    'pred_steps_per_second': 12.836},
#   'train_size': 549},
#  '9': {'metrics': {'train_loss': 0.020688514524364685,
#    'eval_loss': 0.8600101470947266,
#    'eval_precision': 0.7988839804696583,
#    'eval_recall': 0.8058161350844277,
#    'eval_f1': 0.8023350846468185,
#    'eval_accuracy': 0.8685314685314686,
#    'eval_runtime': 1.1579,
#    'eval_samples_per_second': 66.5,
#    'eval_steps_per_second': 17.273,
#    'epoch': 10.0,
#    'pred_loss': 1.1506792306900024,
#    'pred_precision': 0.7291666666666666,
#    'pred_recall': 0.7035175879396985,
#    'pred_f1': 0.7161125319693094,
#    'pred_accuracy': 0.8520900321543409,
#    'pred_runtime': 0.0708,
#    'pred_samples_per_second': 28.232,
#    'pred_steps_per_second': 14.116},
#   'train_size': 610}}

# %% [markdown]
# ### Отчет об обучении [ссылка](https://api.wandb.ai/links/taoea/p5dhyh3j)

# %% [markdown]
# ![image.png](data:image/png;base64,...)  ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Вывод**: к 7 итерации активного обучения (70% датасета) достигается максимальное качество. Однако F1-score сопоставим с рандомной стратегией.

# %%
trainer.save_model(hf_repo_id)
# Out:
# model.safetensors:   0%|          | 0.00/711M [00:00<?, ?B/s]
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# training_args.bin:   0%|          | 0.00/4.98k [00:00<?, ?B/s]

# %% [markdown]
# ### Оценка качества на тестовой выборке

# %%
predictions = trainer.predict(test_dataset=tokenized_dataset["test"])

# %%
predictions.metrics
# Out:
# {'test_loss': 0.7938081622123718,
#  'test_precision': 0.8215488215488216,
#  'test_recall': 0.8162485065710872,
#  'test_f1': 0.8188900874985017,
#  'test_accuracy': 0.884684099399058,
#  'test_runtime': 0.8714,
#  'test_samples_per_second': 88.367,
#  'test_steps_per_second': 22.952}

# %% [markdown]
# Оценка модели на абстракте, которого не было в тестовом наборе

# %%
ner_bio = pipeline("ner", model=model, tokenizer=tokenizer, device=config.device)

# %%
abstract = """Цель. Оценить выживаемость у пациентов с болезнью Фабри (БФ) в зависимости от вида заместительной почечной терапии, и определить роль диализного скрининга в ранней диагностике БФ у родственников.
Материалы и методы. В исследование включали взрослых (старше 18 лет) пациентов с подтвержденным диагнозом БФ. Терминальная стадия хронической почечной недостаточности (тХПН) диагностировали в соответствии с рекомендациями Научного общества нефрологов России (2016) и KDIGO (2012). На основании опроса пробандов выявляли его родственников, которые могли унаследовать мутантный ген.
Результаты. У 50 (24,9%) из 201 обследованных пациентов с БФ диагностирована тХПН, в том числе у 48 (40%) из 120 мужчин и 2 (2,7%) из 81 женщин. Оценка кумулятивной частоты методом Каплана-Майера демонстрирует выраженное увеличение частоты регистрации тХПН к возрасту 20-30 лет, а к возрасту 50 лет ожидаемое количество пациентов с тХПН составляет 95%. Пяти из 50 больных с тХПН была выполнена трансплантация почки, в среднем, через 17 месяцев (диапазон от 7 до 70 месяцев) после инициации лечения гемодиализом. Умерло 15 (30%) из 50 пациентов, получавших лечение гемодиализом. Все умершие пациенты были мужского пола. Медиана возраста на момент летального исхода составила 45 (39; 58) лет. Среди пациентов, которым проведена трансплантация почки, летальных исходов зарегистрировано не было. У 44 (88%) из 50 пациентов диагноз БФ установлен, в среднем, через 1 год (диапазон от 0 до 12 лет) после начала лечения программным гемодиализом, в том числе у одного пациента – после трансплантации почки. Среди 44 пробандов, выявленных при всероссийском диализном скрининге, проведен семейный скрининг. Патогенная мутация в гене GLA диагностирована у 89 (57%) из 156 обследованных родственников диализных пробандов, в том числе у 18 детей моложе 18 лет, клинические проявления БФ имелись у 48 родственников. У 80,4% обследованных родственников диализных пробандов обнаружено поражение почек, преимущественно на ранних стадиях.
Заключение. ТХПН нередкое осложнение БФ, ассоциированное с неблагоприятным прогнозом. Однако диализный скрининг –  эффективный способ выявления пробандов с БФ, открывающий возможность установить диагноз БФ у родственников на ранних стадиях, когда лечение наиболее эффективно.
"""

# %%
ner_bio(abstract)
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# [{'entity': 'LABPROC',
#   'score': 0.16733162,
#   'index': 1,
#   'word': 'Цель',
#   'start': 0,
#   'end': 4},
#  {'entity': 'SCIPROC',
#   'score': 0.2725317,
#   'index': 2,
#   'word': '.',
#   'start': 4,
#   'end': 5},
#  {'entity': 'SCIPROC',
#   'score': 0.964882,
#   'index': 3,
#   'word': 'Оцени',
#   'start': 6,
#   'end': 11},
#  {'entity': 'FINDING',
#   'score': 0.6013314,
#   'index': 4,
#   'word': '##ть',
#   'start': 11,
#   'end': 13},
#  {'entity': 'PHYS',
#   'score': 0.99228865,
#   'index': 5,
#   'word': 'выжи',
#   'start': 14,
#   'end': 18},
#  {'entity': 'PHYS',
#   'score': 0.9954373,
#   'index': 6,
#   'word': '##ваемость',
#   'start': 18,
#   'end': 26},
#  {'entity': 'PERSON',
#   'score': 0.5901527,
#   'index': 7,
#   'word': 'у',
#   'start': 27,
#   'end': 28},
#  {'entity': 'PERSON',
#   'score': 0.99945766,
#   'index': 8,
#   'word': 'пациентов',
#   'start': 29,
#   'end': 38},
#  {'entity': 'DISO',
#   'score': 0.9986034,
#   'index': 9,
#   'word': 'с',
#   'start': 39,
#   'end': 40},
#  {'entity': 'DISO',
#   'score': 0.99985003,
#   'index': 10,
#   'word': 'болезнью',
#   'start': 41,
#   'end': 49},
#  {'entity': 'DISO',
#   'score': 0.37761405,
#   'index': 11,
#   'word': 'Фабри',
#   'start': 50,
#   'end': 55},
#  {'entity': 'DISO',
#   'score': 0.5809376,
#   'index': 12,
#   'word': '(',
#   'start': 56,
#   'end': 57},
#  {'entity': 'DISO',
#   'score': 0.999877,
#   'index': 13,
#   'word': 'БФ',
#   'start': 57,
#   'end': 59},
#  {'entity': 'DISO',
#   'score': 0.60834813,
#   'index': 14,
#   'word': ')',
#   'start': 59,
#   'end': 60},
#  {'entity': 'DATE',
#   'score': 0.46302125,
#   'index': 15,
#   'word': 'в',
#   'start': 61,
#   'end': 62},
#  {'entity': 'FINDING',
#   'score': 0.32770103,
#   'index': 16,
#   'word': 'зависимости',
#   'start': 63,
#   'end': 74},
#  {'entity': 'PHYS',
#   'score': 0.4860157,
#   'index': 17,
#   'word': 'от',
#   'start': 75,
#   'end': 77},
#  {'entity': 'MEDPROC',
#   'score': 0.9856392,
#   'index': 18,
#   'word': 'вида',
#   'start': 78,
#   'end': 82},
#  {'entity': 'MEDPROC',
#   'score': 0.99981755,
#   'index': 19,
#   'word': 'заместитель',
#   'start': 83,
#   'end': 94},
#  {'entity': 'MEDPROC',
#   'score': 0.9997869,
#   'index': 20,
#   'word': '##ной',
#   'start': 94,
#   'end': 97},
#  {'entity': 'MEDPROC',
#   'score': 0.98091197,
#   'index': 21,
#   'word': 'почечной',
#   'start': 98,
#   'end': 106},
#  {'entity': 'MEDPROC',
#   'score': 0.9998103,
#   'index': 22,
#   'word': 'терапии',
#   'start': 107,
#   'end': 114},
#  {'entity': 'FINDING',
#   'score': 0.22589682,
#   'index': 23,
#   'word': ',',
#   'start': 114,
#   'end': 115},
#  {'entity': 'SCIPROC',
#   'score': 0.6031828,
#   'index': 24,
#   'word': 'и',
#   'start': 116,
#   'end': 117},
#  {'entity': 'FINDING',
#   'score': 0.4960783,
#   'index': 25,
#   'word': 'определить',
#   'start': 118,
#   'end': 128},
#  {'entity': 'FINDING',
#   'score': 0.85380566,
#   'index': 26,
#   'word': 'роль',
#   'start': 129,
#   'end': 133},
#  {'entity': 'MEDPROC',
#   'score': 0.99951327,
#   'index': 27,
#   'word': 'диа',
#   'start': 134,
#   'end': 137},
#  {'entity': 'MEDPROC',
#   'score': 0.998985,
#   'index': 28,
#   'word': '##лиз',
#   'start': 137,
#   'end': 140},
#  {'entity': 'MEDPROC',
#   'score': 0.9984267,
#   'index': 29,
#   'word': '##ного',
#   'start': 140,
#   'end': 144},
#  {'entity': 'MEDPROC',
#   'score': 0.9990319,
#   'index': 30,
#   'word': 'скрин',
#   'start': 145,
#   'end': 150},
#  {'entity': 'MEDPROC',
#   'score': 0.9981419,
#   'index': 31,
#   'word': '##инга',
#   'start': 150,
#   'end': 154},
#  {'entity': 'FINDING',
#   'score': 0.9858009,
#   'index': 32,
#   'word': 'в',
#   'start': 155,
#   'end': 156},
#  {'entity': 'FINDING',
#   'score': 0.9604286,
#   'index': 33,
#   'word': 'ранней',
#   'start': 157,
#   'end': 163},
#  {'entity': 'FINDING',
#   'score': 0.6553239,
#   'index': 34,
#   'word': 'диагностике',
#   'start': 164,
#   'end': 175},
#  {'entity': 'DISO',
#   'score': 0.99989784,
#   'index': 35,
#   'word': 'БФ',
#   'start': 176,
#   'end': 178},
#  {'entity': 'PERSON',
#   'score': 0.9577387,
#   'index': 36,
#   'word': 'у',
#   'start': 179,
#   'end': 180},
#  {'entity': 'PERSON',
#   'score': 0.99962044,
#   'index': 37,
#   'word': 'родственников',
#   'start': 181,
#   'end': 194},
#  {'entity': 'FINDING',
#   'score': 0.278437,
#   'index': 38,
#   'word': '.',
#   'start': 194,
#   'end': 195},
#  {'entity': 'SCIPROC',
#   'score': 0.23350406,
#   'index': 39,
#   'word': 'Материалы',
#   'start': 196,
#   'end': 205},
#  {'entity': 'SCIPROC',
#   'score': 0.27374178,
#   'index': 40,
#   'word': 'и',
#   'start': 206,
#   'end': 207},
#  {'entity': 'SCIPROC',
#   'score': 0.1992037,
#   'index': 41,
#   'word': 'методы',
#   'start': 208,
#   'end': 214},
#  {'entity': 'NUMBER',
#   'score': 0.113644734,
#   'index': 42,
#   'word': '.',
#   'start': 214,
#   'end': 215},
#  {'entity': 'SCIPROC',
#   'score': 0.37234908,
#   'index': 43,
#   'word': 'В',
#   'start': 216,
#   'end': 217},
#  {'entity': 'SCIPROC',
#   'score': 0.95595866,
#   'index': 44,
#   'word': 'исследование',
#   'start': 218,
#   'end': 230},
#  {'entity': 'PERSON',
#   'score': 0.72098917,
#   'index': 45,
#   'word': 'включали',
#   'start': 231,
#   'end': 239},
#  {'entity': 'PERSON',
#   'score': 0.9994209,
#   'index': 46,
#   'word': 'взрослых',
#   'start': 240,
#   'end': 248},
#  {'entity': 'PERSON',
#   'score': 0.6655451,
#   'index': 47,
#   'word': '(',
#   'start': 249,
#   'end': 250},
#  {'entity': 'AGE',
#   'score': 0.99980575,
#   'index': 48,
#   'word': 'старше',
#   'start': 250,
#   'end': 256},
#  {'entity': 'AGE',
#   'score': 0.9997477,
#   'index': 49,
#   'word': '18',
#   'start': 257,
#   'end': 259},
#  {'entity': 'AGE',
#   'score': 0.99923944,
#   'index': 50,
#   'word': 'лет',
#   'start': 260,
#   'end': 263},
#  {'entity': 'PERSON',
#   'score': 0.99372333,
#   'index': 51,
#   'word': ')',
#   'start': 263,
#   'end': 264},
#  {'entity': 'PERSON',
#   'score': 0.9996859,
#   'index': 52,
#   'word': 'пациентов',
#   'start': 265,
#   'end': 274},
#  {'entity': 'PERSON',
#   'score': 0.46656105,
#   'index': 53,
#   'word': 'с',
#   'start': 275,
#   'end': 276},
#  {'entity': 'FINDING',
#   'score': 0.6220575,
#   'index': 54,
#   'word': 'подтвержден',
#   'start': 277,
#   'end': 288},
#  {'entity': 'FINDING',
#   'score': 0.49702388,
#   'index': 55,
#   'word': '##ным',
#   'start': 288,
#   'end': 291},
#  {'entity': 'DISO',
#   'score': 0.879063,
#   'index': 56,
#   'word': 'диагнозом',
#   'start': 292,
#   'end': 301},
#  {'entity': 'DISO',
#   'score': 0.9998952,
#   'index': 57,
#   'word': 'БФ',
#   'start': 302,
#   'end': 304},
#  {'entity': 'ORDINAL',
#   'score': 0.1351206,
#   'index': 58,
#   'word': '.',
#   'start': 304,
#   'end': 305},
#  {'entity': 'DISO',
#   'score': 0.9997297,
#   'index': 59,
#   'word': 'Терминал',
#   'start': 306,
#   'end': 314},
#  {'entity': 'DISO',
#   'score': 0.9996635,
#   'index': 60,
#   'word': '##ь',
#   'start': 314,
#   'end': 315},
#  {'entity': 'DISO',
#   'score': 0.99932396,
#   'index': 61,
#   'word': '##ная',
#   'start': 315,
#   'end': 318},
#  {'entity': 'DISO',
#   'score': 0.9996799,
#   'index': 62,
#   'word': 'стадия',
#   'start': 319,
#   'end': 325},
#  {'entity': 'DISO',
#   'score': 0.9998491,
#   'index': 63,
#   'word': 'хронической',
#   'start': 326,
#   'end': 337},
#  {'entity': 'DISO',
#   'score': 0.9972459,
#   'index': 64,
#   'word': 'почечной',
#   'start': 338,
#   'end': 346},
#  {'entity': 'DISO',
#   'score': 0.99959475,
#   'index': 65,
#   'word': 'недостаточности',
#   'start': 347,
#   'end': 362},
#  {'entity': 'DISO',
#   'score': 0.9963689,
#   'index': 66,
#   'word': '(',
#   'start': 363,
#   'end': 364},
#  {'entity': 'DISO',
#   'score': 0.99987745,
#   'index': 67,
#   'word': 'т',
#   'start': 364,
#   'end': 365},
#  {'entity': 'DISO',
#   'score': 0.9998066,
#   'index': 68,
#   'word': '##Х',
#   'start': 365,
#   'end': 366},
#  {'entity': 'DISO',
#   'score': 0.9997031,
#   'index': 69,
#   'word': '##П',
#   'start': 366,
#   'end': 367},
#  {'entity': 'DISO',
#   'score': 0.9995409,
#   'index': 70,
#   'word': '##Н',
#   'start': 367,
#   'end': 368},
#  {'entity': 'DISO',
#   'score': 0.396417,
#   'index': 71,
#   'word': ')',
#   'start': 368,
#   'end': 369},
#  {'entity': 'FINDING',
#   'score': 0.8589774,
#   'index': 72,
#   'word': 'диагностировали',
#   'start': 370,
#   'end': 385},
#  {'entity': 'SCIPROC',
#   'score': 0.92824435,
#   'index': 73,
#   'word': 'в',
#   'start': 386,
#   'end': 387},
#  {'entity': 'SCIPROC',
#   'score': 0.99094754,
#   'index': 74,
#   'word': 'соответствии',
#   'start': 388,
#   'end': 400},
#  {'entity': 'SCIPROC',
#   'score': 0.996808,
#   'index': 75,
#   'word': 'с',
#   'start': 401,
#   'end': 402},
#  {'entity': 'SCIPROC',
#   'score': 0.9931924,
#   'index': 76,
#   'word': 'рекомендациями',
#   'start': 403,
#   'end': 417},
#  {'entity': 'ORGANIZATION',
#   'score': 0.9995765,
#   'index': 77,
#   'word': 'Научного',
#   'start': 418,
#   'end': 426},
#  {'entity': 'ORGANIZATION',
#   'score': 0.9994143,
#   'index': 78,
#   'word': 'общества',
#   'start': 427,
#   'end': 435},
#  {'entity': 'PROFESSION',
#   'score': 0.82796144,
#   'index': 79,
#   'word': 'неф',
#   'start': 436,
#   'end': 439},
#  {'entity': 'PROFESSION',
#   'score': 0.98181915,
#   'index': 80,
#   'word': '##рол',
#   'start': 439,
#   'end': 442},
#  {'entity': 'PROFESSION',
#   'score': 0.98603535,
#   'index': 81,
#   'word': '##ого',
#   'start': 442,
#   'end': 445},
#  {'entity': 'PROFESSION',
#   'score': 0.94414634,
#   'index': 82,
#   'word': '##в',
#   'start': 445,
#   'end': 446},
#  {'entity': 'COUNTRY',
#   'score': 0.999764,
#   'index': 83,
#   'word': 'России',
#   'start': 447,
#   'end': 453},
#  {'entity': 'DATE',
#   'score': 0.9954958,
#   'index': 84,
#   'word': '(',
#   'start': 454,
#   'end': 455},
#  {'entity': 'DATE',
#   'score': 0.98663694,
#   'index': 85,
#   'word': '2016',
#   'start': 455,
#   'end': 459},
#  {'entity': 'DATE',
#   'score': 0.22998774,
#   'index': 86,
#   'word': ')',
#   'start': 459,
#   'end': 460},
#  {'entity': 'SCIPROC',
#   'score': 0.9980678,
#   'index': 87,
#   'word': 'и',
#   'start': 461,
#   'end': 462},
#  {'entity': 'SCIPROC',
#   'score': 0.9984432,
#   'index': 88,
#   'word': 'K',
#   'start': 463,
#   'end': 464},
#  {'entity': 'SCIPROC',
#   'score': 0.99850345,
#   'index': 89,
#   'word': '##DI',
#   'start': 464,
#   'end': 466},
#  {'entity': 'SCIPROC',
#   'score': 0.99275804,
#   'index': 90,
#   'word': '##GO',
#   'start': 466,
#   'end': 468},
#  {'entity': 'DATE',
#   'score': 0.97926396,
#   'index': 91,
#   'word': '(',
#   'start': 469,
#   'end': 470},
#  {'entity': 'DATE',
#   'score': 0.96197844,
#   'index': 92,
#   'word': '2012',
#   'start': 470,
#   'end': 474},
#  {'entity': 'DATE',
#   'score': 0.17414689,
#   'index': 93,
#   'word': ')',
#   'start': 474,
#   'end': 475},
#  {'entity': 'MEDPROC',
#   'score': 0.21327038,
#   'index': 94,
#   'word': '.',
#   'start': 475,
#   'end': 476},
#  {'entity': 'SCIPROC',
#   'score': 0.81849843,
#   'index': 95,
#   'word': 'На',
#   'start': 477,
#   'end': 479},
#  {'entity': 'SCIPROC',
#   'score': 0.7996143,
#   'index': 96,
#   'word': 'основании',
#   'start': 480,
#   'end': 489},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.7370125,
#   'index': 97,
#   'word': 'опроса',
#   'start': 490,
#   'end': 496},
#  {'entity': 'PERSON',
#   'score': 0.9945884,
#   'index': 98,
#   'word': 'проба',
#   'start': 497,
#   'end': 502},
#  {'entity': 'PERSON',
#   'score': 0.96966827,
#   'index': 99,
#   'word': '##ндо',
#   'start': 502,
#   'end': 505},
#  {'entity': 'PERSON',
#   'score': 0.97979593,
#   'index': 100,
#   'word': '##в',
#   'start': 505,
#   'end': 506},
#  {'entity': 'FINDING',
#   'score': 0.9430872,
#   'index': 101,
#   'word': 'выявля',
#   'start': 507,
#   'end': 513},
#  {'entity': 'FINDING',
#   'score': 0.83115935,
#   'index': 102,
#   'word': '##ли',
#   'start': 513,
#   'end': 515},
#  {'entity': 'PERSON',
#   'score': 0.9627475,
#   'index': 103,
#   'word': 'его',
#   'start': 516,
#   'end': 519},
#  {'entity': 'PERSON',
#   'score': 0.9986407,
#   'index': 104,
#   'word': 'родственников',
#   'start': 520,
#   'end': 533},
#  {'entity': 'FINDING',
#   'score': 0.7370298,
#   'index': 105,
#   'word': ',',
#   'start': 533,
#   'end': 534},
#  {'entity': 'PERSON',
#   'score': 0.6171739,
#   'index': 106,
#   'word': 'которые',
#   'start': 535,
#   'end': 542},
#  {'entity': 'FINDING',
#   'score': 0.6464953,
#   'index': 107,
#   'word': 'могли',
#   'start': 543,
#   'end': 548},
#  {'entity': 'PHYS',
#   'score': 0.78057927,
#   'index': 108,
#   'word': 'унаследова',
#   'start': 549,
#   'end': 559},
#  {'entity': 'PHYS',
#   'score': 0.41190898,
#   'index': 109,
#   'word': '##ть',
#   'start': 559,
#   'end': 561},
#  {'entity': 'GENE',
#   'score': 0.87835187,
#   'index': 110,
#   'word': 'мутант',
#   'start': 562,
#   'end': 568},
#  {'entity': 'GENE',
#   'score': 0.9903501,
#   'index': 111,
#   'word': '##ный',
#   'start': 568,
#   'end': 571},
#  {'entity': 'GENE',
#   'score': 0.99819165,
#   'index': 112,
#   'word': 'ген',
#   'start': 572,
#   'end': 575},
#  {'entity': 'FINDING',
#   'score': 0.2279437,
#   'index': 113,
#   'word': '.',
#   'start': 575,
#   'end': 576},
#  {'entity': 'FINDING',
#   'score': 0.97246784,
#   'index': 114,
#   'word': 'Результаты',
#   'start': 577,
#   'end': 587},
#  {'entity': 'FINDING',
#   'score': 0.47133574,
#   'index': 115,
#   'word': '.',
#   'start': 587,
#   'end': 588},
#  {'entity': 'FINDING',
#   'score': 0.79730684,
#   'index': 116,
#   'word': 'У',
#   'start': 589,
#   'end': 590},
#  {'entity': 'NUMBER',
#   'score': 0.9590901,
#   'index': 117,
#   'word': '50',
#   'start': 591,
#   'end': 593},
#  {'entity': 'PERCENT',
#   'score': 0.9984339,
#   'index': 118,
#   'word': '(',
#   'start': 594,
#   'end': 595},
#  {'entity': 'PERCENT',
#   'score': 0.9998945,
#   'index': 119,
#   'word': '24',
#   'start': 595,
#   'end': 597},
#  {'entity': 'PERCENT',
#   'score': 0.999542,
#   'index': 120,
#   'word': ',',
#   'start': 597,
#   'end': 598},
#  {'entity': 'PERCENT',
#   'score': 0.99889827,
#   'index': 121,
#   'word': '9',
#   'start': 598,
#   'end': 599},
#  {'entity': 'PERCENT',
#   'score': 0.9906866,
#   'index': 122,
#   'word': '%',
#   'start': 599,
#   'end': 600},
#  {'entity': 'PERSON',
#   'score': 0.7781713,
#   'index': 123,
#   'word': ')',
#   'start': 600,
#   'end': 601},
#  {'entity': 'PERSON',
#   'score': 0.7106601,
#   'index': 124,
#   'word': 'из',
#   'start': 602,
#   'end': 604},
#  {'entity': 'NUMBER',
#   'score': 0.9911402,
#   'index': 125,
#   'word': '201',
#   'start': 605,
#   'end': 608},
#  {'entity': 'PERSON',
#   'score': 0.99976605,
#   'index': 126,
#   'word': 'обследова',
#   'start': 609,
#   'end': 618},
#  {'entity': 'PERSON',
#   'score': 0.9997148,
#   'index': 127,
#   'word': '##нных',
#   'start': 618,
#   'end': 622},
#  {'entity': 'PERSON',
#   'score': 0.9995017,
#   'index': 128,
#   'word': 'пациентов',
#   'start': 623,
#   'end': 632},
#  {'entity': 'DISO',
#   'score': 0.9237859,
#   'index': 129,
#   'word': 'с',
#   'start': 633,
#   'end': 634},
#  {'entity': 'DISO',
#   'score': 0.99989057,
#   'index': 130,
#   'word': 'БФ',
#   'start': 635,
#   'end': 637},
#  {'entity': 'FINDING',
#   'score': 0.99296254,
#   'index': 131,
#   'word': 'диагности',
#   'start': 638,
#   'end': 647},
#  {'entity': 'FINDING',
#   'score': 0.97266,
#   'index': 132,
#   'word': '##рована',
#   'start': 647,
#   'end': 653},
#  {'entity': 'DISO',
#   'score': 0.99989843,
#   'index': 133,
#   'word': 'т',
#   'start': 654,
#   'end': 655},
#  {'entity': 'DISO',
#   'score': 0.9998447,
#   'index': 134,
#   'word': '##Х',
#   'start': 655,
#   'end': 656},
#  {'entity': 'DISO',
#   'score': 0.99982697,
#   'index': 135,
#   'word': '##П',
#   'start': 656,
#   'end': 657},
#  {'entity': 'DISO',
#   'score': 0.9997812,
#   'index': 136,
#   'word': '##Н',
#   'start': 657,
#   'end': 658},
#  {'entity': 'FINDING',
#   'score': 0.5289897,
#   'index': 137,
#   'word': ',',
#   'start': 658,
#   'end': 659},
#  {'entity': 'PERCENT',
#   'score': 0.8703515,
#   'index': 138,
#   'word': 'в',
#   'start': 660,
#   'end': 661},
#  {'entity': 'PERCENT',
#   'score': 0.44457054,
#   'index': 139,
#   'word': 'том',
#   'start': 662,
#   'end': 665},
#  {'entity': 'PERCENT',
#   'score': 0.37343106,
#   'index': 140,
#   'word': 'числе',
#   'start': 666,
#   'end': 671},
#  {'entity': 'NUMBER',
#   'score': 0.65682346,
#   'index': 141,
#   'word': 'у',
#   'start': 672,
#   'end': 673},
#  {'entity': 'NUMBER',
#   'score': 0.85200995,
#   'index': 142,
#   'word': '48',
#   'start': 674,
#   'end': 676},
#  {'entity': 'PERCENT',
#   'score': 0.9994419,
#   'index': 143,
#   'word': '(',
#   'start': 677,
#   'end': 678},
#  {'entity': 'PERCENT',
#   'score': 0.9998814,
#   'index': 144,
#   'word': '40',
#   'start': 678,
#   'end': 680},
#  {'entity': 'PERCENT',
#   'score': 0.9980804,
#   'index': 145,
#   'word': '%',
#   'start': 680,
#   'end': 681},
#  {'entity': 'PERCENT',
#   'score': 0.38341582,
#   'index': 146,
#   'word': ')',
#   'start': 681,
#   'end': 682},
#  {'entity': 'PERSON',
#   'score': 0.4848612,
#   'index': 147,
#   'word': 'из',
#   'start': 683,
#   'end': 685},
#  {'entity': 'NUMBER',
#   'score': 0.997891,
#   'index': 148,
#   'word': '120',
#   'start': 686,
#   'end': 689},
#  {'entity': 'PERSON',
#   'score': 0.9987809,
#   'index': 149,
#   'word': 'мужчин',
#   'start': 690,
#   'end': 696},
#  {'entity': 'NUMBER',
#   'score': 0.49920294,
#   'index': 150,
#   'word': 'и',
#   'start': 697,
#   'end': 698},
#  {'entity': 'NUMBER',
#   'score': 0.99265397,
#   'index': 151,
#   'word': '2',
#   'start': 699,
#   'end': 700},
#  {'entity': 'PERCENT',
#   'score': 0.99925405,
#   'index': 152,
#   'word': '(',
#   'start': 701,
#   'end': 702},
#  {'entity': 'PERCENT',
#   'score': 0.9998877,
#   'index': 153,
#   'word': '2',
#   'start': 702,
#   'end': 703},
#  {'entity': 'PERCENT',
#   'score': 0.9998005,
#   'index': 154,
#   'word': ',',
#   'start': 703,
#   'end': 704},
#  {'entity': 'PERCENT',
#   'score': 0.999833,
#   'index': 155,
#   'word': '7',
#   'start': 704,
#   'end': 705},
#  {'entity': 'PERCENT',
#   'score': 0.9990133,
#   'index': 156,
#   'word': '%',
#   'start': 705,
#   'end': 706},
#  {'entity': 'PERSON',
#   'score': 0.38868698,
#   'index': 157,
#   'word': ')',
#   'start': 706,
#   'end': 707},
#  {'entity': 'NUMBER',
#   'score': 0.7215625,
#   'index': 158,
#   'word': 'из',
#   'start': 708,
#   'end': 710},
#  {'entity': 'NUMBER',
#   'score': 0.99639183,
#   'index': 159,
#   'word': '81',
#   'start': 711,
#   'end': 713},
#  {'entity': 'PERSON',
#   'score': 0.99843305,
#   'index': 160,
#   'word': 'женщин',
#   'start': 714,
#   'end': 720},
#  {'entity': 'FINDING',
#   'score': 0.28829876,
#   'index': 161,
#   'word': '.',
#   'start': 720,
#   'end': 721},
#  {'entity': 'SCIPROC',
#   'score': 0.9953945,
#   'index': 162,
#   'word': 'Оценка',
#   'start': 722,
#   'end': 728},
#  {'entity': 'FINDING',
#   'score': 0.906992,
#   'index': 163,
#   'word': 'кумуля',
#   'start': 729,
#   'end': 735},
#  {'entity': 'PHYS',
#   'score': 0.9437939,
#   'index': 164,
#   'word': '##тивной',
#   'start': 735,
#   'end': 741},
#  {'entity': 'PHYS',
#   'score': 0.99107355,
#   'index': 165,
#   'word': 'частоты',
#   'start': 742,
#   'end': 749},
#  {'entity': 'SCIPROC',
#   'score': 0.9986368,
#   'index': 166,
#   'word': 'методом',
#   'start': 750,
#   'end': 757},
#  {'entity': 'SCIPROC',
#   'score': 0.99892455,
#   'index': 167,
#   'word': 'Каплан',
#   'start': 758,
#   'end': 764},
#  {'entity': 'SCIPROC',
#   'score': 0.6890433,
#   'index': 168,
#   'word': '##а',
#   'start': 764,
#   'end': 765},
#  {'entity': 'SCIPROC',
#   'score': 0.41145605,
#   'index': 169,
#   'word': '-',
#   'start': 765,
#   'end': 766},
#  {'entity': 'PERSON',
#   'score': 0.46980786,
#   'index': 170,
#   'word': 'Майер',
#   'start': 766,
#   'end': 771},
#  {'entity': 'SCIPROC',
#   'score': 0.6422668,
#   'index': 171,
#   'word': '##а',
#   'start': 771,
#   'end': 772},
#  {'entity': 'FINDING',
#   'score': 0.9995536,
#   'index': 172,
#   'word': 'демонстрирует',
#   'start': 773,
#   'end': 786},
#  {'entity': 'FINDING',
#   'score': 0.99975854,
#   'index': 173,
#   'word': 'выраженное',
#   'start': 787,
#   'end': 797},
#  {'entity': 'FINDING',
#   'score': 0.9996878,
#   'index': 174,
#   'word': 'увеличение',
#   'start': 798,
#   'end': 808},
#  {'entity': 'PHYS',
#   'score': 0.9896333,
#   'index': 175,
#   'word': 'частоты',
#   'start': 809,
#   'end': 816},
#  {'entity': 'FINDING',
#   'score': 0.9129008,
#   'index': 176,
#   'word': 'регистрации',
#   'start': 817,
#   'end': 828},
#  {'entity': 'DISO',
#   'score': 0.99990165,
#   'index': 177,
#   'word': 'т',
#   'start': 829,
#   'end': 830},
#  {'entity': 'DISO',
#   'score': 0.9998591,
#   'index': 178,
#   'word': '##Х',
#   'start': 830,
#   'end': 831},
#  {'entity': 'DISO',
#   'score': 0.9998553,
#   'index': 179,
#   'word': '##П',
#   'start': 831,
#   'end': 832},
#  {'entity': 'DISO',
#   'score': 0.9998307,
#   'index': 180,
#   'word': '##Н',
#   'start': 832,
#   'end': 833},
#  {'entity': 'PHYS',
#   'score': 0.5045118,
#   'index': 181,
#   'word': 'к',
#   'start': 834,
#   'end': 835},
#  {'entity': 'PHYS',
#   'score': 0.7880164,
#   'index': 182,
#   'word': 'возрасту',
#   'start': 836,
#   'end': 844},
#  {'entity': 'AGE',
#   'score': 0.9997738,
#   'index': 183,
#   'word': '20',
#   'start': 845,
#   'end': 847},
#  {'entity': 'AGE',
#   'score': 0.9997396,
#   'index': 184,
#   'word': '-',
#   'start': 847,
#   'end': 848},
#  {'entity': 'AGE',
#   'score': 0.9996494,
#   'index': 185,
#   'word': '30',
#   'start': 848,
#   'end': 850},
#  {'entity': 'AGE',
#   'score': 0.9993222,
#   'index': 186,
#   'word': 'лет',
#   'start': 851,
#   'end': 854},
#  {'entity': 'FINDING',
#   'score': 0.89867723,
#   'index': 187,
#   'word': ',',
#   'start': 854,
#   'end': 855},
#  {'entity': 'FINDING',
#   'score': 0.421436,
#   'index': 188,
#   'word': 'а',
#   'start': 856,
#   'end': 857},
#  {'entity': 'AGE',
#   'score': 0.8535359,
#   'index': 189,
#   'word': 'к',
#   'start': 858,
#   'end': 859},
#  {'entity': 'AGE',
#   'score': 0.7308344,
#   'index': 190,
#   'word': 'возрасту',
#   'start': 860,
#   'end': 868},
#  {'entity': 'AGE',
#   'score': 0.99970406,
#   'index': 191,
#   'word': '50',
#   'start': 869,
#   'end': 871},
#  {'entity': 'AGE',
#   'score': 0.9983215,
#   'index': 192,
#   'word': 'лет',
#   'start': 872,
#   'end': 875},
#  {'entity': 'FINDING',
#   'score': 0.9996376,
#   'index': 193,
#   'word': 'ожидаемо',
#   'start': 876,
#   'end': 884},
#  {'entity': 'FINDING',
#   'score': 0.9996948,
#   'index': 194,
#   'word': '##е',
#   'start': 884,
#   'end': 885},
#  {'entity': 'FINDING',
#   'score': 0.9214606,
#   'index': 195,
#   'word': 'количество',
#   'start': 886,
#   'end': 896},
#  {'entity': 'PERSON',
#   'score': 0.9980526,
#   'index': 196,
#   'word': 'пациентов',
#   'start': 897,
#   'end': 906},
#  {'entity': 'DISO',
#   'score': 0.79497176,
#   'index': 197,
#   'word': 'с',
#   'start': 907,
#   'end': 908},
#  {'entity': 'DISO',
#   'score': 0.99990404,
#   'index': 198,
#   'word': 'т',
#   'start': 909,
#   'end': 910},
#  {'entity': 'DISO',
#   'score': 0.9998777,
#   'index': 199,
#   'word': '##Х',
#   'start': 910,
#   'end': 911},
#  {'entity': 'DISO',
#   'score': 0.9998272,
#   'index': 200,
#   'word': '##П',
#   'start': 911,
#   'end': 912},
#  {'entity': 'DISO',
#   'score': 0.99985576,
#   'index': 201,
#   'word': '##Н',
#   'start': 912,
#   'end': 913},
#  {'entity': 'FINDING',
#   'score': 0.9995726,
#   'index': 202,
#   'word': 'составляет',
#   'start': 914,
#   'end': 924},
#  {'entity': 'PERCENT',
#   'score': 0.999889,
#   'index': 203,
#   'word': '95',
#   'start': 925,
#   'end': 927},
#  {'entity': 'FINDING',
#   'score': 0.5883823,
#   'index': 204,
#   'word': '%',
#   'start': 927,
#   'end': 928},
#  {'entity': 'FINDING',
#   'score': 0.20035025,
#   'index': 205,
#   'word': '.',
#   'start': 928,
#   'end': 929},
#  {'entity': 'NUMBER',
#   'score': 0.9950304,
#   'index': 206,
#   'word': 'Пяти',
#   'start': 930,
#   'end': 934},
#  {'entity': 'NUMBER',
#   'score': 0.5106778,
#   'index': 207,
#   'word': 'из',
#   'start': 935,
#   'end': 937},
#  {'entity': 'NUMBER',
#   'score': 0.99757725,
#   'index': 208,
#   'word': '50',
#   'start': 938,
#   'end': 940},
#  {'entity': 'PERSON',
#   'score': 0.9984388,
#   'index': 209,
#   'word': 'больных',
#   'start': 941,
#   'end': 948},
#  {'entity': 'DISO',
#   'score': 0.8980398,
#   'index': 210,
#   'word': 'с',
#   'start': 949,
#   'end': 950},
#  {'entity': 'DISO',
#   'score': 0.9998969,
#   'index': 211,
#   'word': 'т',
#   'start': 951,
#   'end': 952},
#  {'entity': 'DISO',
#   'score': 0.9998547,
#   'index': 212,
#   'word': '##Х',
#   'start': 952,
#   'end': 953},
#  {'entity': 'DISO',
#   'score': 0.9998337,
#   'index': 213,
#   'word': '##П',
#   'start': 953,
#   'end': 954},
#  {'entity': 'DISO',
#   'score': 0.99977,
#   'index': 214,
#   'word': '##Н',
#   'start': 954,
#   'end': 955},
#  {'entity': 'MEDPROC',
#   'score': 0.9994067,
#   'index': 215,
#   'word': 'была',
#   'start': 956,
#   'end': 960},
#  {'entity': 'MEDPROC',
#   'score': 0.9997439,
#   'index': 216,
#   'word': 'выполнена',
#   'start': 961,
#   'end': 970},
#  {'entity': 'MEDPROC',
#   'score': 0.9998031,
#   'index': 217,
#   'word': 'транспланта',
#   'start': 971,
#   'end': 982},
#  {'entity': 'MEDPROC',
#   'score': 0.9997136,
#   'index': 218,
#   'word': '##ция',
#   'start': 982,
#   'end': 985},
#  {'entity': 'ANATOMY',
#   'score': 0.9997414,
#   'index': 219,
#   'word': 'почки',
#   'start': 986,
#   'end': 991},
#  {'entity': 'FINDING',
#   'score': 0.391694,
#   'index': 220,
#   'word': ',',
#   'start': 991,
#   'end': 992},
#  {'entity': 'DATE',
#   'score': 0.99161786,
#   'index': 221,
#   'word': 'в',
#   'start': 993,
#   'end': 994},
#  {'entity': 'DATE',
#   'score': 0.88162315,
#   'index': 222,
#   'word': 'среднем',
#   'start': 995,
#   'end': 1002},
#  {'entity': 'DATE',
#   'score': 0.77424777,
#   'index': 223,
#   'word': ',',
#   'start': 1002,
#   'end': 1003},
#  {'entity': 'DATE',
#   'score': 0.99975556,
#   'index': 224,
#   'word': 'через',
#   'start': 1004,
#   'end': 1009},
#  {'entity': 'DATE',
#   'score': 0.9993818,
#   'index': 225,
#   'word': '17',
#   'start': 1010,
#   'end': 1012},
#  {'entity': 'DATE',
#   'score': 0.9987607,
#   'index': 226,
#   'word': 'месяцев',
#   'start': 1013,
#   'end': 1020},
#  {'entity': 'DATE',
#   'score': 0.99415696,
#   'index': 227,
#   'word': '(',
#   'start': 1021,
#   'end': 1022},
#  {'entity': 'SCIPROC',
#   'score': 0.9504472,
#   'index': 228,
#   'word': 'диапазон',
#   'start': 1022,
#   'end': 1030},
#  {'entity': 'DATE',
#   'score': 0.99673456,
#   'index': 229,
#   'word': 'от',
#   'start': 1031,
#   'end': 1033},
#  {'entity': 'DATE',
#   'score': 0.9990305,
#   'index': 230,
#   'word': '7',
#   'start': 1034,
#   'end': 1035},
#  {'entity': 'DATE',
#   'score': 0.9957449,
#   'index': 231,
#   'word': 'до',
#   'start': 1036,
#   'end': 1038},
#  {'entity': 'DATE',
#   'score': 0.9933169,
#   'index': 232,
#   'word': '70',
#   'start': 1039,
#   'end': 1041},
#  {'entity': 'DATE',
#   'score': 0.99561656,
#   'index': 233,
#   'word': 'месяцев',
#   'start': 1042,
#   'end': 1049},
#  {'entity': 'DATE',
#   'score': 0.94916624,
#   'index': 234,
#   'word': ')',
#   'start': 1049,
#   'end': 1050},
#  {'entity': 'DATE',
#   'score': 0.5944119,
#   'index': 235,
#   'word': 'после',
#   'start': 1051,
#   'end': 1056},
#  {'entity': 'MEDPROC',
#   'score': 0.98969907,
#   'index': 236,
#   'word': 'инициации',
#   'start': 1057,
#   'end': 1066},
#  {'entity': 'MEDPROC',
#   'score': 0.9996879,
#   'index': 237,
#   'word': 'лечения',
#   'start': 1067,
#   'end': 1074},
#  {'entity': 'MEDPROC',
#   'score': 0.999765,
#   'index': 238,
#   'word': 'гемо',
#   'start': 1075,
#   'end': 1079},
#  {'entity': 'MEDPROC',
#   'score': 0.9997962,
#   'index': 239,
#   'word': '##диа',
#   'start': 1079,
#   'end': 1082},
#  {'entity': 'MEDPROC',
#   'score': 0.9997255,
#   'index': 240,
#   'word': '##лиз',
#   'start': 1082,
#   'end': 1085},
#  {'entity': 'MEDPROC',
#   'score': 0.99952364,
#   'index': 241,
#   'word': '##ом',
#   'start': 1085,
#   'end': 1087},
#  {'entity': 'FINDING',
#   'score': 0.24698883,
#   'index': 242,
#   'word': '.',
#   'start': 1087,
#   'end': 1088},
#  {'entity': 'PHYS',
#   'score': 0.94994146,
#   'index': 243,
#   'word': 'Умер',
#   'start': 1089,
#   'end': 1093},
#  {'entity': 'FINDING',
#   'score': 0.41624838,
#   'index': 244,
#   'word': '##ло',
#   'start': 1093,
#   'end': 1095},
#  {'entity': 'NUMBER',
#   'score': 0.7558142,
#   'index': 245,
#   'word': '15',
#   'start': 1096,
#   'end': 1098},
#  {'entity': 'PERCENT',
#   'score': 0.99929047,
#   'index': 246,
#   'word': '(',
#   'start': 1099,
#   'end': 1100},
#  {'entity': 'PERCENT',
#   'score': 0.9998642,
#   'index': 247,
#   'word': '30',
#   'start': 1100,
#   'end': 1102},
#  {'entity': 'PERCENT',
#   'score': 0.98972565,
#   'index': 248,
#   'word': '%',
#   'start': 1102,
#   'end': 1103},
#  {'entity': 'PERSON',
#   'score': 0.5686456,
#   'index': 249,
#   'word': ')',
#   'start': 1103,
#   'end': 1104},
#  {'entity': 'NUMBER',
#   'score': 0.4415744,
#   'index': 250,
#   'word': 'из',
#   'start': 1105,
#   'end': 1107},
#  {'entity': 'NUMBER',
#   'score': 0.99493533,
#   'index': 251,
#   'word': '50',
#   'start': 1108,
#   'end': 1110},
#  {'entity': 'PERSON',
#   'score': 0.999498,
#   'index': 252,
#   'word': 'пациентов',
#   'start': 1111,
#   'end': 1120},
#  {'entity': 'PERSON',
#   'score': 0.90724903,
#   'index': 253,
#   'word': ',',
#   'start': 1120,
#   'end': 1121},
#  {'entity': 'MEDPROC',
#   'score': 0.9974577,
#   'index': 254,
#   'word': 'получа',
#   'start': 1122,
#   'end': 1128},
#  {'entity': 'PERSON',
#   'score': 0.7785595,
#   'index': 255,
#   'word': '##вших',
#   'start': 1128,
#   'end': 1132},
#  {'entity': 'MEDPROC',
#   'score': 0.99975556,
#   'index': 256,
#   'word': 'лечение',
#   'start': 1133,
#   'end': 1140},
#  {'entity': 'MEDPROC',
#   'score': 0.9998074,
#   'index': 257,
#   'word': 'гемо',
#   'start': 1141,
#   'end': 1145},
#  {'entity': 'MEDPROC',
#   'score': 0.9998128,
#   'index': 258,
#   'word': '##диа',
#   'start': 1145,
#   'end': 1148},
#  {'entity': 'MEDPROC',
#   'score': 0.99977,
#   'index': 259,
#   'word': '##лиз',
#   'start': 1148,
#   'end': 1151},
#  {'entity': 'MEDPROC',
#   'score': 0.9996037,
#   'index': 260,
#   'word': '##ом',
#   'start': 1151,
#   'end': 1153},
#  {'entity': 'FINDING',
#   'score': 0.25441673,
#   'index': 261,
#   'word': '.',
#   'start': 1153,
#   'end': 1154},
#  {'entity': 'FINDING',
#   'score': 0.6309756,
#   'index': 262,
#   'word': 'Все',
#   'start': 1155,
#   'end': 1158},
#  {'entity': 'PHYS',
#   'score': 0.7379972,
#   'index': 263,
#   'word': 'умер',
#   'start': 1159,
#   'end': 1163},
#  {'entity': 'PERSON',
#   'score': 0.90409195,
#   'index': 264,
#   'word': '##шие',
#   'start': 1163,
#   'end': 1166},
#  {'entity': 'PERSON',
#   'score': 0.9989028,
#   'index': 265,
#   'word': 'пациенты',
#   'start': 1167,
#   'end': 1175},
#  {'entity': 'FINDING',
#   'score': 0.52852356,
#   'index': 266,
#   'word': 'были',
#   'start': 1176,
#   'end': 1180},
#  {'entity': 'PHYS',
#   'score': 0.9993981,
#   'index': 267,
#   'word': 'мужского',
#   'start': 1181,
#   'end': 1189},
#  {'entity': 'PHYS',
#   'score': 0.998934,
#   'index': 268,
#   'word': 'пола',
#   'start': 1190,
#   'end': 1194},
#  {'entity': 'FINDING',
#   'score': 0.43735874,
#   'index': 269,
#   'word': '.',
#   'start': 1194,
#   'end': 1195},
#  {'entity': 'FINDING',
#   'score': 0.8514539,
#   'index': 270,
#   'word': 'Медиа',
#   'start': 1196,
#   'end': 1201},
#  {'entity': 'PHYS',
#   'score': 0.91938424,
#   'index': 271,
#   'word': '##на',
#   'start': 1201,
#   'end': 1203},
#  {'entity': 'PHYS',
#   'score': 0.9992762,
#   'index': 272,
#   'word': 'возраста',
#   'start': 1204,
#   'end': 1212},
#  {'entity': 'DATE',
#   'score': 0.99912864,
#   'index': 273,
#   'word': 'на',
#   'start': 1213,
#   'end': 1215},
#  {'entity': 'DATE',
#   'score': 0.9080462,
#   'index': 274,
#   'word': 'момент',
#   'start': 1216,
#   'end': 1222},
#  {'entity': 'PHYS',
#   'score': 0.65348333,
#   'index': 275,
#   'word': 'летального',
#   'start': 1223,
#   'end': 1233},
#  {'entity': 'FINDING',
#   'score': 0.7392653,
#   'index': 276,
#   'word': 'исхода',
#   'start': 1234,
#   'end': 1240},
#  {'entity': 'FINDING',
#   'score': 0.99427694,
#   'index': 277,
#   'word': 'составила',
#   'start': 1241,
#   'end': 1250},
#  {'entity': 'AGE',
#   'score': 0.9994868,
#   'index': 278,
#   'word': '45',
#   'start': 1251,
#   'end': 1253},
#  {'entity': 'AGE',
#   'score': 0.99683964,
#   'index': 279,
#   'word': '(',
#   'start': 1254,
#   'end': 1255},
#  {'entity': 'AGE',
#   'score': 0.9996269,
#   'index': 280,
#   'word': '39',
#   'start': 1255,
#   'end': 1257},
#  {'entity': 'AGE',
#   'score': 0.79600966,
#   'index': 281,
#   'word': ';',
#   'start': 1257,
#   'end': 1258},
#  {'entity': 'AGE',
#   'score': 0.9863794,
#   'index': 282,
#   'word': '58',
#   'start': 1259,
#   'end': 1261},
#  {'entity': 'PHYS',
#   'score': 0.2196855,
#   'index': 283,
#   'word': ')',
#   'start': 1261,
#   'end': 1262},
#  {'entity': 'AGE',
#   'score': 0.99183524,
#   'index': 284,
#   'word': 'лет',
#   'start': 1263,
#   'end': 1266},
#  {'entity': 'FINDING',
#   'score': 0.3798128,
#   'index': 285,
#   'word': '.',
#   'start': 1266,
#   'end': 1267},
#  {'entity': 'FINDING',
#   'score': 0.48666227,
#   'index': 286,
#   'word': 'Среди',
#   'start': 1268,
#   'end': 1273},
#  {'entity': 'PERSON',
#   'score': 0.9986584,
#   'index': 287,
#   'word': 'пациентов',
#   'start': 1274,
#   'end': 1283},
#  {'entity': 'MEDPROC',
#   'score': 0.40923408,
#   'index': 288,
#   'word': ',',
#   'start': 1283,
#   'end': 1284},
#  {'entity': 'MEDPROC',
#   'score': 0.4741614,
#   'index': 289,
#   'word': 'которым',
#   'start': 1285,
#   'end': 1292},
#  {'entity': 'MEDPROC',
#   'score': 0.9997758,
#   'index': 290,
#   'word': 'проведена',
#   'start': 1293,
#   'end': 1302},
#  {'entity': 'MEDPROC',
#   'score': 0.99981064,
#   'index': 291,
#   'word': 'транспланта',
#   'start': 1303,
#   'end': 1314},
#  {'entity': 'MEDPROC',
#   'score': 0.99976903,
#   'index': 292,
#   'word': '##ция',
#   'start': 1314,
#   'end': 1317},
#  {'entity': 'ANATOMY',
#   'score': 0.9997316,
#   'index': 293,
#   'word': 'почки',
#   'start': 1318,
#   'end': 1323},
#  {'entity': 'FINDING',
#   'score': 0.99840814,
#   'index': 294,
#   'word': ',',
#   'start': 1323,
#   'end': 1324},
#  {'entity': 'FINDING',
#   'score': 0.99955696,
#   'index': 295,
#   'word': 'летальных',
#   'start': 1325,
#   'end': 1334},
#  {'entity': 'FINDING',
#   'score': 0.9996228,
#   'index': 296,
#   'word': 'исход',
#   'start': 1335,
#   'end': 1340},
#  {'entity': 'FINDING',
#   'score': 0.9987991,
#   'index': 297,
#   'word': '##ов',
#   'start': 1340,
#   'end': 1342},
#  {'entity': 'FINDING',
#   'score': 0.9994597,
#   'index': 298,
#   'word': 'зарегистрировано',
#   'start': 1343,
#   'end': 1359},
#  {'entity': 'FINDING',
#   'score': 0.9990711,
#   'index': 299,
#   'word': 'не',
#   'start': 1360,
#   'end': 1362},
#  {'entity': 'FINDING',
#   'score': 0.9992061,
#   'index': 300,
#   'word': 'было',
#   'start': 1363,
#   'end': 1367},
#  {'entity': 'FINDING',
#   'score': 0.26747635,
#   'index': 301,
#   'word': '.',
#   'start': 1367,
#   'end': 1368},
#  {'entity': 'FINDING',
#   'score': 0.5885812,
#   'index': 302,
#   'word': 'У',
#   'start': 1369,
#   'end': 1370},
#  {'entity': 'NUMBER',
#   'score': 0.97704405,
#   'index': 303,
#   'word': '44',
#   'start': 1371,
#   'end': 1373},
#  {'entity': 'PERCENT',
#   'score': 0.99483114,
#   'index': 304,
#   'word': '(',
#   'start': 1374,
#   'end': 1375},
#  {'entity': 'PERCENT',
#   'score': 0.99986136,
#   'index': 305,
#   'word': '88',
#   'start': 1375,
#   'end': 1377},
#  {'entity': 'PERCENT',
#   'score': 0.98927736,
#   'index': 306,
#   'word': '%',
#   'start': 1377,
#   'end': 1378},
#  {'entity': 'PERSON',
#   'score': 0.7181732,
#   'index': 307,
#   'word': ')',
#   'start': 1378,
#   'end': 1379},
#  {'entity': 'PERSON',
#   'score': 0.41101447,
#   'index': 308,
#   'word': 'из',
#   'start': 1380,
#   'end': 1382},
#  {'entity': 'NUMBER',
#   'score': 0.99783933,
#   'index': 309,
#   'word': '50',
#   'start': 1383,
#   'end': 1385},
#  {'entity': 'PERSON',
#   'score': 0.9987675,
#   'index': 310,
#   'word': 'пациентов',
#   'start': 1386,
#   'end': 1395},
#  {'entity': 'FINDING',
#   'score': 0.993287,
#   'index': 311,
#   'word': 'диагноз',
#   'start': 1396,
#   'end': 1403},
#  {'entity': 'DISO',
#   'score': 0.9998454,
#   'index': 312,
#   'word': 'БФ',
#   'start': 1404,
#   'end': 1406},
#  {'entity': 'FINDING',
#   'score': 0.9616075,
#   'index': 313,
#   'word': 'установлен',
#   'start': 1407,
#   'end': 1417},
#  {'entity': 'FINDING',
#   'score': 0.4604483,
#   'index': 314,
#   'word': ',',
#   'start': 1417,
#   'end': 1418},
#  {'entity': 'DATE',
#   'score': 0.9261484,
#   'index': 315,
#   'word': 'в',
#   'start': 1419,
#   'end': 1420},
#  {'entity': 'DATE',
#   'score': 0.72108537,
#   'index': 316,
#   'word': 'среднем',
#   'start': 1421,
#   'end': 1428},
#  {'entity': 'DATE',
#   'score': 0.81826967,
#   'index': 317,
#   'word': ',',
#   'start': 1428,
#   'end': 1429},
#  {'entity': 'DATE',
#   'score': 0.9996315,
#   'index': 318,
#   'word': 'через',
#   'start': 1430,
#   'end': 1435},
#  {'entity': 'DATE',
#   'score': 0.9997025,
#   'index': 319,
#   'word': '1',
#   'start': 1436,
#   'end': 1437},
#  {'entity': 'DATE',
#   'score': 0.9990515,
#   'index': 320,
#   'word': 'год',
#   'start': 1438,
#   'end': 1441},
#  {'entity': 'DATE',
#   'score': 0.97894806,
#   'index': 321,
#   'word': '(',
#   'start': 1442,
#   'end': 1443},
#  {'entity': 'SCIPROC',
#   'score': 0.9833149,
#   'index': 322,
#   'word': 'диапазон',
#   'start': 1443,
#   'end': 1451},
#  {'entity': 'DATE',
#   'score': 0.9642999,
#   'index': 323,
#   'word': 'от',
#   'start': 1452,
#   'end': 1454},
#  {'entity': 'DATE',
#   'score': 0.87013304,
#   'index': 324,
#   'word': '0',
#   'start': 1455,
#   'end': 1456},
#  {'entity': 'DATE',
#   'score': 0.9891215,
#   'index': 325,
#   'word': 'до',
#   'start': 1457,
#   'end': 1459},
#  {'entity': 'DATE',
#   'score': 0.99707174,
#   'index': 326,
#   'word': '12',
#   'start': 1460,
#   'end': 1462},
#  {'entity': 'DATE',
#   'score': 0.9905481,
#   'index': 327,
#   'word': 'лет',
#   'start': 1463,
#   'end': 1466},
#  {'entity': 'DATE',
#   'score': 0.7720791,
#   'index': 328,
#   'word': ')',
#   'start': 1466,
#   'end': 1467},
#  {'entity': 'DATE',
#   'score': 0.8214661,
#   'index': 329,
#   'word': 'после',
#   'start': 1468,
#   'end': 1473},
#  {'entity': 'MEDPROC',
#   'score': 0.9752261,
#   'index': 330,
#   'word': 'начала',
#   'start': 1474,
#   'end': 1480},
#  {'entity': 'MEDPROC',
#   'score': 0.99978393,
#   'index': 331,
#   'word': 'лечения',
#   'start': 1481,
#   'end': 1488},
#  {'entity': 'MEDPROC',
#   'score': 0.9997749,
#   'index': 332,
#   'word': 'программным',
#   'start': 1489,
#   'end': 1500},
#  {'entity': 'MEDPROC',
#   'score': 0.99977154,
#   'index': 333,
#   'word': 'гемо',
#   'start': 1501,
#   'end': 1505},
#  {'entity': 'MEDPROC',
#   'score': 0.9997855,
#   'index': 334,
#   'word': '##диа',
#   'start': 1505,
#   'end': 1508},
#  {'entity': 'MEDPROC',
#   'score': 0.9996762,
#   'index': 335,
#   'word': '##лиз',
#   'start': 1508,
#   'end': 1511},
#  {'entity': 'MEDPROC',
#   'score': 0.99960846,
#   'index': 336,
#   'word': '##ом',
#   'start': 1511,
#   'end': 1513},
#  {'entity': 'FINDING',
#   'score': 0.62016493,
#   'index': 337,
#   'word': ',',
#   'start': 1513,
#   'end': 1514},
#  {'entity': 'DATE',
#   'score': 0.4079683,
#   'index': 338,
#   'word': 'в',
#   'start': 1515,
#   'end': 1516},
#  {'entity': 'NUMBER',
#   'score': 0.16509487,
#   'index': 339,
#   'word': 'том',
#   'start': 1517,
#   'end': 1520},
#  {'entity': 'NUMBER',
#   'score': 0.6737863,
#   'index': 340,
#   'word': 'числе',
#   'start': 1521,
#   'end': 1526},
#  {'entity': 'NUMBER',
#   'score': 0.6120394,
#   'index': 341,
#   'word': 'у',
#   'start': 1527,
#   'end': 1528},
#  {'entity': 'NUMBER',
#   'score': 0.9916191,
#   'index': 342,
#   'word': 'одного',
#   'start': 1529,
#   'end': 1535},
#  {'entity': 'PERSON',
#   'score': 0.99926895,
#   'index': 343,
#   'word': 'пациента',
#   'start': 1536,
#   'end': 1544},
#  {'entity': 'DATE',
#   'score': 0.22028913,
#   'index': 344,
#   'word': '–',
#   'start': 1545,
#   'end': 1546},
#  {'entity': 'MEDPROC',
#   'score': 0.90311265,
#   'index': 345,
#   'word': 'после',
#   'start': 1547,
#   'end': 1552},
#  {'entity': 'MEDPROC',
#   'score': 0.9998165,
#   'index': 346,
#   'word': 'трансплантации',
#   'start': 1553,
#   'end': 1567},
#  {'entity': 'ANATOMY',
#   'score': 0.999723,
#   'index': 347,
#   'word': 'почки',
#   'start': 1568,
#   'end': 1573},
#  {'entity': 'FINDING',
#   'score': 0.16096182,
#   'index': 348,
#   'word': '.',
#   'start': 1573,
#   'end': 1574},
#  {'entity': 'PERSON',
#   'score': 0.6860587,
#   'index': 349,
#   'word': 'Среди',
#   'start': 1575,
#   'end': 1580},
#  {'entity': 'NUMBER',
#   'score': 0.99439985,
#   'index': 350,
#   'word': '44',
#   'start': 1581,
#   'end': 1583},
#  {'entity': 'PERSON',
#   'score': 0.99866676,
#   'index': 351,
#   'word': 'проба',
#   'start': 1584,
#   'end': 1589},
#  {'entity': 'PERSON',
#   'score': 0.99370027,
#   'index': 352,
#   'word': '##ндо',
#   'start': 1589,
#   'end': 1592},
#  {'entity': 'PERSON',
#   'score': 0.99656916,
#   'index': 353,
#   'word': '##в',
#   'start': 1592,
#   'end': 1593},
#  {'entity': 'PERSON',
#   'score': 0.60971224,
#   'index': 354,
#   'word': ',',
#   'start': 1593,
#   'end': 1594},
#  {'entity': 'PERSON',
#   'score': 0.4474528,
#   'index': 355,
#   'word': 'выявленных',
#   'start': 1595,
#   'end': 1605},
#  {'entity': 'MEDPROC',
#   'score': 0.9927342,
#   'index': 356,
#   'word': 'при',
#   'start': 1606,
#   'end': 1609},
#  {'entity': 'CITY',
#   'score': 0.2960952,
#   'index': 357,
#   'word': 'всероссий',
#   'start': 1610,
#   'end': 1619},
#  {'entity': 'MEDPROC',
#   'score': 0.921458,
#   'index': 358,
#   'word': '##ском',
#   'start': 1619,
#   'end': 1623},
#  {'entity': 'MEDPROC',
#   'score': 0.99908626,
#   'index': 359,
#   'word': 'диа',
#   'start': 1624,
#   'end': 1627},
#  {'entity': 'MEDPROC',
#   'score': 0.99785906,
#   'index': 360,
#   'word': '##лиз',
#   'start': 1627,
#   'end': 1630},
#  {'entity': 'MEDPROC',
#   'score': 0.9842039,
#   'index': 361,
#   'word': '##ном',
#   'start': 1630,
#   'end': 1633},
#  {'entity': 'MEDPROC',
#   'score': 0.99693596,
#   'index': 362,
#   'word': 'скрин',
#   'start': 1634,
#   'end': 1639},
#  {'entity': 'MEDPROC',
#   'score': 0.953549,
#   'index': 363,
#   'word': '##инг',
#   'start': 1639,
#   'end': 1642},
#  {'entity': 'MEDPROC',
#   'score': 0.89078057,
#   'index': 364,
#   'word': '##е',
#   'start': 1642,
#   'end': 1643},
#  {'entity': 'MEDPROC',
#   'score': 0.62996346,
#   'index': 365,
#   'word': ',',
#   'start': 1643,
#   'end': 1644},
#  {'entity': 'MEDPROC',
#   'score': 0.98609877,
#   'index': 366,
#   'word': 'проведен',
#   'start': 1645,
#   'end': 1653},
#  {'entity': 'MEDPROC',
#   'score': 0.37662816,
#   'index': 367,
#   'word': 'семейный',
#   'start': 1654,
#   'end': 1662},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.5957535,
#   'index': 368,
#   'word': 'скрин',
#   'start': 1663,
#   'end': 1668},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.80325025,
#   'index': 369,
#   'word': '##инг',
#   'start': 1668,
#   'end': 1671},
#  {'entity': 'FINDING',
#   'score': 0.25322676,
#   'index': 370,
#   'word': '.',
#   'start': 1671,
#   'end': 1672},
#  {'entity': 'PHYS',
#   'score': 0.58876145,
#   'index': 371,
#   'word': 'Пато',
#   'start': 1673,
#   'end': 1677},
#  {'entity': 'PHYS',
#   'score': 0.9372868,
#   'index': 372,
#   'word': '##генная',
#   'start': 1677,
#   'end': 1683},
#  {'entity': 'PHYS',
#   'score': 0.99210054,
#   'index': 373,
#   'word': 'мутация',
#   'start': 1684,
#   'end': 1691},
#  {'entity': 'GENE',
#   'score': 0.9966444,
#   'index': 374,
#   'word': 'в',
#   'start': 1692,
#   'end': 1693},
#  {'entity': 'GENE',
#   'score': 0.99917245,
#   'index': 375,
#   'word': 'гене',
#   'start': 1694,
#   'end': 1698},
#  {'entity': 'GENE',
#   'score': 0.98762965,
#   'index': 376,
#   'word': 'GL',
#   'start': 1699,
#   'end': 1701},
#  {'entity': 'GENE',
#   'score': 0.99588084,
#   'index': 377,
#   'word': '##A',
#   'start': 1701,
#   'end': 1702},
#  {'entity': 'FINDING',
#   'score': 0.9979867,
#   'index': 378,
#   'word': 'диагности',
#   'start': 1703,
#   'end': 1712},
#  {'entity': 'FINDING',
#   'score': 0.99660325,
#   'index': 379,
#   'word': '##рована',
#   'start': 1712,
#   'end': 1718},
#  {'entity': 'FINDING',
#   'score': 0.88509655,
#   'index': 380,
#   'word': 'у',
#   'start': 1719,
#   'end': 1720},
#  {'entity': 'NUMBER',
#   'score': 0.76102656,
#   'index': 381,
#   'word': '89',
#   'start': 1721,
#   'end': 1723},
#  {'entity': 'PERCENT',
#   'score': 0.9977449,
#   'index': 382,
#   'word': '(',
#   'start': 1724,
#   'end': 1725},
#  {'entity': 'PERCENT',
#   'score': 0.99986625,
#   'index': 383,
#   'word': '57',
#   'start': 1725,
#   'end': 1727},
#  {'entity': 'PERCENT',
#   'score': 0.992923,
#   'index': 384,
#   'word': '%',
#   'start': 1727,
#   'end': 1728},
#  {'entity': 'PERSON',
#   'score': 0.74509436,
#   'index': 385,
#   'word': ')',
#   'start': 1728,
#   'end': 1729},
#  {'entity': 'PERSON',
#   'score': 0.52253157,
#   'index': 386,
#   'word': 'из',
#   'start': 1730,
#   'end': 1732},
#  {'entity': 'NUMBER',
#   'score': 0.99357384,
#   'index': 387,
#   'word': '156',
#   'start': 1733,
#   'end': 1736},
#  {'entity': 'PERSON',
#   'score': 0.99974793,
#   'index': 388,
#   'word': 'обследова',
#   'start': 1737,
#   'end': 1746},
#  {'entity': 'PERSON',
#   'score': 0.9996797,
#   'index': 389,
#   'word': '##нных',
#   'start': 1746,
#   'end': 1750},
#  {'entity': 'PERSON',
#   'score': 0.9998247,
#   'index': 390,
#   'word': 'родственников',
#   'start': 1751,
#   'end': 1764},
#  {'entity': 'PERSON',
#   'score': 0.9633987,
#   'index': 391,
#   'word': 'диа',
#   'start': 1765,
#   'end': 1768},
#  {'entity': 'PERSON',
#   'score': 0.9711439,
#   'index': 392,
#   'word': '##лиз',
#   'start': 1768,
#   'end': 1771},
#  {'entity': 'PERSON',
#   'score': 0.9983284,
#   'index': 393,
#   'word': '##ных',
#   'start': 1771,
#   'end': 1774},
#  {'entity': 'PERSON',
#   'score': 0.9902474,
#   'index': 394,
#   'word': 'проба',
#   'start': 1775,
#   'end': 1780},
#  {'entity': 'PERSON',
#   'score': 0.96650356,
#   'index': 395,
#   'word': '##ндо',
#   'start': 1780,
#   'end': 1783},
#  {'entity': 'PERSON',
#   'score': 0.9890275,
#   'index': 396,
#   'word': '##в',
#   'start': 1783,
#   'end': 1784},
#  {'entity': 'FINDING',
#   'score': 0.47521532,
#   'index': 397,
#   'word': ',',
#   'start': 1784,
#   'end': 1785},
#  {'entity': 'NUMBER',
#   'score': 0.28268477,
#   'index': 398,
#   'word': 'в',
#   'start': 1786,
#   'end': 1787},
#  {'entity': 'PERSON',
#   'score': 0.22764578,
#   'index': 399,
#   'word': 'том',
#   'start': 1788,
#   'end': 1791},
#  {'entity': 'PERSON',
#   'score': 0.5189126,
#   'index': 400,
#   'word': 'числе',
#   'start': 1792,
#   'end': 1797},
#  {'entity': 'FINDING',
#   'score': 0.68401456,
#   'index': 401,
#   'word': 'у',
#   'start': 1798,
#   'end': 1799},
#  {'entity': 'NUMBER',
#   'score': 0.99267685,
#   'index': 402,
#   'word': '18',
#   'start': 1800,
#   'end': 1802},
#  {'entity': 'PERSON',
#   'score': 0.99910754,
#   'index': 403,
#   'word': 'детей',
#   'start': 1803,
#   'end': 1808},
#  {'entity': 'AGE',
#   'score': 0.9987208,
#   'index': 404,
#   'word': 'моложе',
#   'start': 1809,
#   'end': 1815},
#  {'entity': 'AGE',
#   'score': 0.99930894,
#   'index': 405,
#   'word': '18',
#   'start': 1816,
#   'end': 1818},
#  {'entity': 'AGE',
#   'score': 0.9964813,
#   'index': 406,
#   'word': 'лет',
#   'start': 1819,
#   'end': 1822},
#  {'entity': 'FINDING',
#   'score': 0.9972149,
#   'index': 407,
#   'word': ',',
#   'start': 1822,
#   'end': 1823},
#  {'entity': 'FINDING',
#   'score': 0.9845509,
#   'index': 408,
#   'word': 'клинические',
#   'start': 1824,
#   'end': 1835},
#  {'entity': 'FINDING',
#   'score': 0.9434439,
#   'index': 409,
#   'word': 'проявления',
#   'start': 1836,
#   'end': 1846},
#  {'entity': 'DISO',
#   'score': 0.99988484,
#   'index': 410,
#   'word': 'БФ',
#   'start': 1847,
#   'end': 1849},
#  {'entity': 'FINDING',
#   'score': 0.9983956,
#   'index': 411,
#   'word': 'имелись',
#   'start': 1850,
#   'end': 1857},
#  {'entity': 'FINDING',
#   'score': 0.9885512,
#   'index': 412,
#   'word': 'у',
#   'start': 1858,
#   'end': 1859},
#  {'entity': 'NUMBER',
#   'score': 0.9913127,
#   'index': 413,
#   'word': '48',
#   'start': 1860,
#   'end': 1862},
#  {'entity': 'PERSON',
#   'score': 0.9994504,
#   'index': 414,
#   'word': 'родственников',
#   'start': 1863,
#   'end': 1876},
#  {'entity': 'FINDING',
#   'score': 0.3139819,
#   'index': 415,
#   'word': '.',
#   'start': 1876,
#   'end': 1877},
#  {'entity': 'FINDING',
#   'score': 0.90824264,
#   'index': 416,
#   'word': 'У',
#   'start': 1878,
#   'end': 1879},
#  {'entity': 'PERCENT',
#   'score': 0.99991703,
#   'index': 417,
#   'word': '80',
#   'start': 1880,
#   'end': 1882},
#  {'entity': 'PERCENT',
#   'score': 0.9986438,
#   'index': 418,
#   'word': ',',
#   'start': 1882,
#   'end': 1883},
#  {'entity': 'PERCENT',
#   'score': 0.99952674,
#   'index': 419,
#   'word': '4',
#   'start': 1883,
#   'end': 1884},
#  {'entity': 'PERCENT',
#   'score': 0.53855944,
#   'index': 420,
#   'word': '%',
#   'start': 1884,
#   'end': 1885},
#  {'entity': 'PERSON',
#   'score': 0.99985397,
#   'index': 421,
#   'word': 'обследова',
#   'start': 1886,
#   'end': 1895},
#  {'entity': 'PERSON',
#   'score': 0.99984825,
#   'index': 422,
#   'word': '##нных',
#   'start': 1895,
#   'end': 1899},
#  {'entity': 'PERSON',
#   'score': 0.99986184,
#   'index': 423,
#   'word': 'родственников',
#   'start': 1900,
#   'end': 1913},
#  {'entity': 'PERSON',
#   'score': 0.9863782,
#   'index': 424,
#   'word': 'диа',
#   'start': 1914,
#   'end': 1917},
#  {'entity': 'PERSON',
#   'score': 0.9767969,
#   'index': 425,
#   'word': '##лиз',
#   'start': 1917,
#   'end': 1920},
#  {'entity': 'PERSON',
#   'score': 0.99887115,
#   'index': 426,
#   'word': '##ных',
#   'start': 1920,
#   'end': 1923},
#  {'entity': 'PERSON',
#   'score': 0.9957319,
#   'index': 427,
#   'word': 'проба',
#   'start': 1924,
#   'end': 1929},
#  {'entity': 'PERSON',
#   'score': 0.98852056,
#   'index': 428,
#   'word': '##ндо',
#   'start': 1929,
#   'end': 1932},
#  {'entity': 'PERSON',
#   'score': 0.99537414,
#   'index': 429,
#   'word': '##в',
#   'start': 1932,
#   'end': 1933},
#  {'entity': 'FINDING',
#   'score': 0.9973247,
#   'index': 430,
#   'word': 'обнаружено',
#   'start': 1934,
#   'end': 1944},
#  {'entity': 'DISO',
#   'score': 0.9452951,
#   'index': 431,
#   'word': 'поражение',
#   'start': 1945,
#   'end': 1954},
#  {'entity': 'ANATOMY',
#   'score': 0.99982506,
#   'index': 432,
#   'word': 'почек',
#   'start': 1955,
#   'end': 1960},
#  {'entity': 'FINDING',
#   'score': 0.6613846,
#   'index': 433,
#   'word': ',',
#   'start': 1960,
#   'end': 1961},
#  {'entity': 'FINDING',
#   'score': 0.7920316,
#   'index': 434,
#   'word': 'преимущественно',
#   'start': 1962,
#   'end': 1977},
#  {'entity': 'DISO',
#   'score': 0.86930716,
#   'index': 435,
#   'word': 'на',
#   'start': 1978,
#   'end': 1980},
#  {'entity': 'DISO',
#   'score': 0.75682205,
#   'index': 436,
#   'word': 'ранних',
#   'start': 1981,
#   'end': 1987},
#  {'entity': 'DISO',
#   'score': 0.9033201,
#   'index': 437,
#   'word': 'стадиях',
#   'start': 1988,
#   'end': 1995},
#  {'entity': 'PERSON',
#   'score': 0.15029386,
#   'index': 438,
#   'word': '.',
#   'start': 1995,
#   'end': 1996},
#  {'entity': 'FINDING',
#   'score': 0.20550378,
#   'index': 439,
#   'word': 'Заключение',
#   'start': 1997,
#   'end': 2007},
#  {'entity': 'FINDING',
#   'score': 0.60564893,
#   'index': 440,
#   'word': '.',
#   'start': 2007,
#   'end': 2008},
#  {'entity': 'DISO',
#   'score': 0.9998965,
#   'index': 441,
#   'word': 'Т',
#   'start': 2009,
#   'end': 2010},
#  {'entity': 'DISO',
#   'score': 0.99982375,
#   'index': 442,
#   'word': '##Х',
#   'start': 2010,
#   'end': 2011},
#  {'entity': 'DISO',
#   'score': 0.99983895,
#   'index': 443,
#   'word': '##П',
#   'start': 2011,
#   'end': 2012},
#  {'entity': 'DISO',
#   'score': 0.99982446,
#   'index': 444,
#   'word': '##Н',
#   'start': 2012,
#   'end': 2013},
#  {'entity': 'DISO',
#   'score': 0.91610026,
#   'index': 445,
#   'word': 'нередко',
#   'start': 2014,
#   'end': 2021},
#  {'entity': 'DISO',
#   'score': 0.8410978,
#   'index': 446,
#   'word': '##е',
#   'start': 2021,
#   'end': 2022},
#  {'entity': 'DISO',
#   'score': 0.9996146,
#   'index': 447,
#   'word': 'ослож',
#   'start': 2023,
#   'end': 2028},
#  {'entity': 'DISO',
#   'score': 0.9983783,
#   'index': 448,
#   'word': '##нение',
#   'start': 2028,
#   'end': 2033},
#  {'entity': 'DISO',
#   'score': 0.99990094,
#   'index': 449,
#   'word': 'БФ',
#   'start': 2034,
#   'end': 2036},
#  {'entity': 'FINDING',
#   'score': 0.9735267,
#   'index': 450,
#   'word': ',',
#   'start': 2036,
#   'end': 2037},
#  {'entity': 'FINDING',
#   'score': 0.9986773,
#   'index': 451,
#   'word': 'ассоции',
#   'start': 2038,
#   'end': 2045},
#  {'entity': 'FINDING',
#   'score': 0.9177637,
#   'index': 452,
#   'word': '##рованное',
#   'start': 2045,
#   'end': 2053},
#  {'entity': 'FINDING',
#   'score': 0.99861693,
#   'index': 453,
#   'word': 'с',
#   'start': 2054,
#   'end': 2055},
#  {'entity': 'FINDING',
#   'score': 0.99953234,
#   'index': 454,
#   'word': 'неблагоприят',
#   'start': 2056,
#   'end': 2068},
#  {'entity': 'FINDING',
#   'score': 0.99787307,
#   'index': 455,
#   'word': '##ным',
#   'start': 2068,
#   'end': 2071},
#  {'entity': 'PHYS',
#   'score': 0.980591,
#   'index': 456,
#   'word': 'прогнозом',
#   'start': 2072,
#   'end': 2081},
#  {'entity': 'FINDING',
#   'score': 0.15613855,
#   'index': 457,
#   'word': '.',
#   'start': 2081,
#   'end': 2082},
#  {'entity': 'FINDING',
#   'score': 0.9711307,
#   'index': 458,
#   'word': 'Однако',
#   'start': 2083,
#   'end': 2089},
#  {'entity': 'MEDPROC',
#   'score': 0.99933237,
#   'index': 459,
#   'word': 'диа',
#   'start': 2090,
#   'end': 2093},
#  {'entity': 'MEDPROC',
#   'score': 0.99808073,
#   'index': 460,
#   'word': '##лиз',
#   'start': 2093,
#   'end': 2096},
#  {'entity': 'MEDPROC',
#   'score': 0.9976382,
#   'index': 461,
#   'word': '##ный',
#   'start': 2096,
#   'end': 2099},
#  {'entity': 'MEDPROC',
#   'score': 0.9922301,
#   'index': 462,
#   'word': 'скрин',
#   'start': 2100,
#   'end': 2105},
#  {'entity': 'MEDPROC',
#   'score': 0.92348135,
#   'index': 463,
#   'word': '##инг',
#   'start': 2105,
#   'end': 2108},
#  {'entity': 'FINDING',
#   'score': 0.992673,
#   'index': 464,
#   'word': '–',
#   'start': 2109,
#   'end': 2110},
#  {'entity': 'FINDING',
#   'score': 0.99953425,
#   'index': 465,
#   'word': 'эффективный',
#   'start': 2112,
#   'end': 2123},
#  {'entity': 'FINDING',
#   'score': 0.9844939,
#   'index': 466,
#   'word': 'способ',
#   'start': 2124,
#   'end': 2130},
#  {'entity': 'FINDING',
#   'score': 0.7428144,
#   'index': 467,
#   'word': 'выявления',
#   'start': 2131,
#   'end': 2140},
#  {'entity': 'PERSON',
#   'score': 0.99947006,
#   'index': 468,
#   'word': 'проба',
#   'start': 2141,
#   'end': 2146},
#  {'entity': 'PERSON',
#   'score': 0.99848133,
#   'index': 469,
#   'word': '##ндо',
#   'start': 2146,
#   'end': 2149},
#  {'entity': 'PERSON',
#   'score': 0.9990907,
#   'index': 470,
#   'word': '##в',
#   'start': 2149,
#   'end': 2150},
#  {'entity': 'DISO',
#   'score': 0.96203077,
#   'index': 471,
#   'word': 'с',
#   'start': 2151,
#   'end': 2152},
#  {'entity': 'DISO',
#   'score': 0.99989665,
#   'index': 472,
#   'word': 'БФ',
#   'start': 2153,
#   'end': 2155},
#  {'entity': 'FINDING',
#   'score': 0.99057543,
#   'index': 473,
#   'word': ',',
#   'start': 2155,
#   'end': 2156},
#  {'entity': 'FINDING',
#   'score': 0.9971788,
#   'index': 474,
#   'word': 'открываю',
#   'start': 2157,
#   'end': 2165},
#  {'entity': 'FINDING',
#   'score': 0.9979673,
#   'index': 475,
#   'word': '##щий',
#   'start': 2165,
#   'end': 2168},
#  {'entity': 'FINDING',
#   'score': 0.97481185,
#   'index': 476,
#   'word': 'возможность',
#   'start': 2169,
#   'end': 2180},
#  {'entity': 'FINDING',
#   'score': 0.98919386,
#   'index': 477,
#   'word': 'установить',
#   'start': 2181,
#   'end': 2191},
#  {'entity': 'FINDING',
#   'score': 0.6949554,
#   'index': 478,
#   'word': 'диагноз',
#   'start': 2192,
#   'end': 2199},
#  {'entity': 'DISO',
#   'score': 0.9998951,
#   'index': 479,
#   'word': 'БФ',
#   'start': 2200,
#   'end': 2202},
#  {'entity': 'PERSON',
#   'score': 0.95411545,
#   'index': 480,
#   'word': 'у',
#   'start': 2203,
#   'end': 2204},
#  {'entity': 'PERSON',
#   'score': 0.9994516,
#   'index': 481,
#   'word': 'родственников',
#   'start': 2205,
#   'end': 2218},
#  {'entity': 'DISO',
#   'score': 0.52186614,
#   'index': 482,
#   'word': 'на',
#   'start': 2219,
#   'end': 2221},
#  {'entity': 'PHYS',
#   'score': 0.7506803,
#   'index': 483,
#   'word': 'ранних',
#   'start': 2222,
#   'end': 2228},
#  {'entity': 'DISO',
#   'score': 0.52845675,
#   'index': 484,
#   'word': 'стадиях',
#   'start': 2229,
#   'end': 2236},
#  {'entity': 'FINDING',
#   'score': 0.97692966,
#   'index': 485,
#   'word': ',',
#   'start': 2236,
#   'end': 2237},
#  {'entity': 'FINDING',
#   'score': 0.936029,
#   'index': 486,
#   'word': 'когда',
#   'start': 2238,
#   'end': 2243},
#  {'entity': 'MEDPROC',
#   'score': 0.8259252,
#   'index': 487,
#   'word': 'лечение',
#   'start': 2244,
#   'end': 2251},
#  {'entity': 'FINDING',
#   'score': 0.9991923,
#   'index': 488,
#   'word': 'наиболее',
#   'start': 2252,
#   'end': 2260},
#  {'entity': 'FINDING',
#   'score': 0.9990318,
#   'index': 489,
#   'word': 'эффективно',
#   'start': 2261,
#   'end': 2271},
#  {'entity': 'FINDING',
#   'score': 0.18281466,
#   'index': 490,
#   'word': '.',
#   'start': 2271,
#   'end': 2272}]
