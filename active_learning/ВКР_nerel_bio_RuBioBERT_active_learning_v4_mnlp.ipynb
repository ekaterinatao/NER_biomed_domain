# %% [markdown]
# <a href="https://colab.research.google.com/github/ekaterinatao/NER_biomed_domain/blob/main/active_learning/%D0%92%D0%9A%D0%A0_nerel_bio_RuBioBERT_active_learning_v4_mnlp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Инструменты
# Предобработанный дасасет [NEREL-BIO](https://huggingface.co/datasets/ekaterinatao/nerel_bio_ner_unnested)
#
# Исходная модель [RuBioBERT](https://huggingface.co/alexyalunin/RuBioBERT)

# %% [markdown]
# ### Установка зависимостей

# %%
# !pip install datasets accelerate evaluate wandb seqeval -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 3.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 18.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 19.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 263.5/263.5 kB 12.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 20.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 33.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 39.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 1.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 2.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 4.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 4.4 MB/s eta 0:00:00
#   Building wheel for seqeval (setup.py) ... done

# %%
import numpy as np
import pandas as pd
import random
from dataclasses import dataclass

import torch
from torch.nn.functional import softmax
import datasets
from datasets import Dataset, DatasetDict, concatenate_datasets
from transformers import (AutoTokenizer,
                          DataCollatorForTokenClassification,
                          AutoModelForTokenClassification,
                          TrainingArguments, Trainer,
                          pipeline)
from transformers.trainer_utils import get_last_checkpoint
import evaluate

import warnings
warnings.filterwarnings("ignore")

# %%
@dataclass
class TrainingConfig:
    seed = 64
    dataset = 'ekaterinatao/nerel_bio_ner_unnested'
    checkpoint = 'alexyalunin/RuBioBERT'
    n_labels = 45
    n_epochs = 10
    train_batch_size = 4
    eval_batch_size = 4
    device = "cuda" if torch.cuda.is_available() else "cpu"
    l_rate = 5e-05
    w_decay = 0.1
    warm_up = 0.1

config = TrainingConfig()

# %%
seed = config.seed

random.seed(seed)
np.random.seed(seed)

torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %% [markdown]
# ### Скачивание датасета

# %%
dataset = datasets.load_dataset(config.dataset)
dataset
# Out:
# Downloading readme:   0%|          | 0.00/1.56k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/603k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/76.2k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/70.8k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/612 [00:00<?, ? examples/s]
# Generating valid split:   0%|          | 0/77 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/77 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'words', 'ner_tags'],
#         num_rows: 612
#     })
#     valid: Dataset({
#         features: ['id', 'words', 'ner_tags'],
#         num_rows: 77
#     })
#     test: Dataset({
#         features: ['id', 'words', 'ner_tags'],
#         num_rows: 77
#     })
# })

# %%
# Labels
url = 'https://raw.githubusercontent.com/ekaterinatao/NER_biomed_domain/main/labels.txt'
tags = pd.read_csv(url, names=['tag']).values.tolist()
tags = [item for sublist in tags for item in sublist]
tag_to_id = {tag: i for i, tag in enumerate(tags)}
id_to_tag = {i: tag for i, tag in enumerate(tags)}

# %% [markdown]
# ___
# ### Токенизация

# %%
tokenizer = AutoTokenizer.from_pretrained(config.checkpoint)
# Out:
# tokenizer_config.json:   0%|          | 0.00/413 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/1.78M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.75M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(examples["words"], truncation=True, max_length=512, is_split_into_words=True)

    labels = []
    for i, label in enumerate(examples[f"ner_tags"]):
        word_idxs = tokenized_inputs.word_ids(batch_index=i)  # Map tokens to their respective word.
        previous_word_idx = None
        label_ids = []
        for word_idx in word_idxs:
            if word_idx is None:
                label_ids.append(-100) # Set the special tokens to -100.
            elif word_idx != previous_word_idx:  # Only label the first token of a given word.
                label_ids.append(label[word_idx])
            else:
                label_ids.append(-100)
            previous_word_idx = word_idx
        labels.append(label_ids)

    tokenized_inputs["labels"] = labels
    return tokenized_inputs

# %%
tokenized_dataset = dataset.map(
    tokenize_and_align_labels, batched=True,
    #remove_columns = ['id', 'words', 'ner_tags']
)
tokenized_dataset
# Out:
# Map:   0%|          | 0/612 [00:00<?, ? examples/s]
# Map:   0%|          | 0/77 [00:00<?, ? examples/s]
# Map:   0%|          | 0/77 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'words', 'ner_tags', 'input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 612
#     })
#     valid: Dataset({
#         features: ['id', 'words', 'ner_tags', 'input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 77
#     })
#     test: Dataset({
#         features: ['id', 'words', 'ner_tags', 'input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 77
#     })
# })

# %% [markdown]
# # Обучение модели

# %%
seqeval = evaluate.load("seqeval")

def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=2)

    true_predictions = [
        [tags[p] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]
    true_labels = [
        [tags[l] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]

    results = seqeval.compute(predictions=true_predictions, references=true_labels)
    return {
        "precision": results["overall_precision"],
        "recall": results["overall_recall"],
        "f1": results["overall_f1"],
        "accuracy": results["overall_accuracy"],
    }
# Out:
# Downloading builder script:   0%|          | 0.00/6.34k [00:00<?, ?B/s]

# %%
def choose_samples_mnlp(test_predictions, n_tokens) -> np.ndarray:
    """Функция для реализации стратеги отбора примеров для разметки
    на основе MNLP"""

    test_pred_pt = torch.from_numpy(test_predictions)
    probas = softmax(test_pred_pt, dim=-1).detach().cpu().numpy()
    scores = np.array([
        -np.sum(np.log(np.max(i, axis=1))) / len(i) for i in probas
    ])
    args = np.argsort(-scores)

    return args[:n_tokens]

# %%
data_collator = DataCollatorForTokenClassification(tokenizer=tokenizer)

# %%
model = AutoModelForTokenClassification.from_pretrained(
    config.checkpoint, num_labels=config.n_labels, id2label=id_to_tag, label2id=tag_to_id
)
# Out:
# config.json:   0%|          | 0.00/889 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at alexyalunin/RuBioBERT and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
print(f'device is {config.device}')
# Out:
# device is cuda

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
import wandb
wandb.login()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
import os
os.environ["WANDB_PROJECT"]="ner_bert_nerel_bio"
hf_repo_id = "ekaterinatao/nerel-bio-RuBioBERT-al"

# %%
def train_and_predict(
    train_dataset, eval_dataset, test_dataset,
    model, tokenizer, data_collator, compute_metrics
):
    "Функция для тренировки модели, сохранения метрик и предсказаний"

    global config
    training_args = TrainingArguments(
        output_dir=hf_repo_id,
        num_train_epochs=config.n_epochs,
        learning_rate=config.l_rate,
        weight_decay=config.w_decay,
        warmup_ratio=config.warm_up,
        per_device_train_batch_size=config.train_batch_size,
        per_device_eval_batch_size=config.eval_batch_size,
        group_by_length=True,
        optim="adamw_torch",
        lr_scheduler_type="cosine",
        evaluation_strategy="epoch",
        seed = config.seed,
        data_seed = config.seed,
        #use_cpu=True,
        push_to_hub=True,
        save_strategy="no",
        report_to="wandb",
        logging_steps=16,
        run_name="RuBioBERT_AL_v4",
    )

    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=eval_dataset,
        tokenizer=tokenizer,
        data_collator=data_collator,
        compute_metrics=compute_metrics,
    )

    train_result = trainer.train()
    test_predictions = trainer.predict(
        test_dataset, metric_key_prefix="pred"
    )
    metrics = {}
    metrics['train_loss'] = train_result.metrics['train_loss']
    metrics.update(trainer.evaluate(eval_dataset))
    metrics.update(test_predictions.metrics)
    probas = test_predictions.predictions

    return metrics, probas, trainer

# %%
def run_active_learning(
    dataset, al_iters, init_train_size, choose_tokens,
    model, tokenizer, data_collator, compute_metrics
):
    "Функция для реализации цикла активного обучения"

    train_dataset = dataset['train'].select(
        random.sample(
            range(dataset['train'].num_rows),
            int(dataset['train'].num_rows * init_train_size)
        )
    )
    test_dataset = dataset['train'].filter(
        lambda s: s['id'] not in train_dataset['id']
    )
    all_metrics = {}

    for iter in range(al_iters):
        print(f'Training using {train_dataset.num_rows} samples')

        eval_metrics, test_predictions, trainer = train_and_predict(
            train_dataset, dataset['valid'], test_dataset,
            model, tokenizer, data_collator, compute_metrics
        )

        new_args = choose_samples_mnlp(test_predictions, choose_tokens)
        new_train_samples = test_dataset.select(new_args)
        extended_train_dataset = concatenate_datasets(
            [train_dataset, new_train_samples]
        )

        train_dataset = extended_train_dataset
        test_dataset = dataset['train'].filter(
            lambda s: s['id'] not in train_dataset['id']
        )

        all_metrics[f'{iter}'] = {'metrics': eval_metrics, 'train_size': train_dataset.num_rows}

    return all_metrics, trainer

# %%
metrics, trainer = run_active_learning(
    dataset=tokenized_dataset, al_iters=7, init_train_size=0.1, choose_tokens=61,
    model=model, tokenizer=tokenizer,
    data_collator=data_collator, compute_metrics=compute_metrics
)
# Out:
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]
# Training using 61 samples
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# wandb: Currently logged in as: taoea. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.4
# Run data is saved locally in <code>/content/wandb/run-20240318_174144-wgll4mr8</code>
# Syncing run <strong><a href='https://wandb.ai/taoea/ner_bert_nerel_bio/runs/wgll4mr8' target="_blank">RuBioBERT_AL_v4</a></strong> to <a href='https://wandb.ai/taoea/ner_bert_nerel_bio' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/taoea/ner_bert_nerel_bio' target="_blank">https://wandb.ai/taoea/ner_bert_nerel_bio</a>
#  View run at <a href='https://wandb.ai/taoea/ner_bert_nerel_bio/runs/wgll4mr8' target="_blank">https://wandb.ai/taoea/ner_bert_nerel_bio/runs/wgll4mr8</a>
#     <div>
#
#       <progress value='160' max='160' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [160/160 00:25, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.385500</td>
#       <td>2.925789</td>
#       <td>0.049296</td>
#       <td>0.001642</td>
#       <td>0.003177</td>
#       <td>0.158042</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.267000</td>
#       <td>2.012529</td>
#       <td>0.420856</td>
#       <td>0.343574</td>
#       <td>0.378309</td>
#       <td>0.537685</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.350600</td>
#       <td>1.434593</td>
#       <td>0.603119</td>
#       <td>0.562383</td>
#       <td>0.582039</td>
#       <td>0.693551</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.860100</td>
#       <td>1.240490</td>
#       <td>0.645208</td>
#       <td>0.620544</td>
#       <td>0.632636</td>
#       <td>0.727894</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.663400</td>
#       <td>1.124020</td>
#       <td>0.660775</td>
#       <td>0.640009</td>
#       <td>0.650226</td>
#       <td>0.742191</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.472900</td>
#       <td>1.049967</td>
#       <td>0.691080</td>
#       <td>0.670497</td>
#       <td>0.680633</td>
#       <td>0.770319</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.396700</td>
#       <td>1.000270</td>
#       <td>0.703881</td>
#       <td>0.689024</td>
#       <td>0.696374</td>
#       <td>0.781974</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.322900</td>
#       <td>1.009882</td>
#       <td>0.695569</td>
#       <td>0.684803</td>
#       <td>0.690144</td>
#       <td>0.779021</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.295800</td>
#       <td>1.000625</td>
#       <td>0.702774</td>
#       <td>0.689259</td>
#       <td>0.695951</td>
#       <td>0.784771</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.282500</td>
#       <td>1.000039</td>
#       <td>0.702774</td>
#       <td>0.689259</td>
#       <td>0.695951</td>
#       <td>0.784771</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:00]
#     </div>
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]
# Training using 122 samples
#     <div>
#
#       <progress value='310' max='310' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [310/310 00:37, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.562800</td>
#       <td>0.865911</td>
#       <td>0.727535</td>
#       <td>0.710131</td>
#       <td>0.718728</td>
#       <td>0.802176</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.382100</td>
#       <td>0.800964</td>
#       <td>0.748732</td>
#       <td>0.726782</td>
#       <td>0.737594</td>
#       <td>0.818026</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.334200</td>
#       <td>0.806068</td>
#       <td>0.745331</td>
#       <td>0.720685</td>
#       <td>0.732801</td>
#       <td>0.817094</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.251400</td>
#       <td>0.762279</td>
#       <td>0.751892</td>
#       <td>0.745544</td>
#       <td>0.748705</td>
#       <td>0.826729</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.139700</td>
#       <td>0.761715</td>
#       <td>0.763252</td>
#       <td>0.753049</td>
#       <td>0.758116</td>
#       <td>0.833256</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.102800</td>
#       <td>0.812299</td>
#       <td>0.758490</td>
#       <td>0.749062</td>
#       <td>0.753746</td>
#       <td>0.830925</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.094600</td>
#       <td>0.809445</td>
#       <td>0.750351</td>
#       <td>0.751407</td>
#       <td>0.750879</td>
#       <td>0.828594</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.047600</td>
#       <td>0.812492</td>
#       <td>0.763028</td>
#       <td>0.758912</td>
#       <td>0.760964</td>
#       <td>0.837296</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.047100</td>
#       <td>0.819832</td>
#       <td>0.764998</td>
#       <td>0.759615</td>
#       <td>0.762297</td>
#       <td>0.837141</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.047900</td>
#       <td>0.823464</td>
#       <td>0.765304</td>
#       <td>0.759381</td>
#       <td>0.762331</td>
#       <td>0.836830</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:00]
#     </div>
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]
# Training using 183 samples
#     <div>
#
#       <progress value='460' max='460' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [460/460 00:49, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.193600</td>
#       <td>0.742198</td>
#       <td>0.755425</td>
#       <td>0.751173</td>
#       <td>0.753293</td>
#       <td>0.831857</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.135800</td>
#       <td>0.781195</td>
#       <td>0.751839</td>
#       <td>0.743199</td>
#       <td>0.747494</td>
#       <td>0.829060</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.110900</td>
#       <td>0.778787</td>
#       <td>0.750000</td>
#       <td>0.754925</td>
#       <td>0.752454</td>
#       <td>0.831857</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.071800</td>
#       <td>0.780028</td>
#       <td>0.769374</td>
#       <td>0.772983</td>
#       <td>0.771175</td>
#       <td>0.844289</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.042800</td>
#       <td>0.834578</td>
#       <td>0.766824</td>
#       <td>0.764306</td>
#       <td>0.765563</td>
#       <td>0.840404</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.032200</td>
#       <td>0.825753</td>
#       <td>0.765325</td>
#       <td>0.767120</td>
#       <td>0.766222</td>
#       <td>0.841803</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.023500</td>
#       <td>0.848445</td>
#       <td>0.758428</td>
#       <td>0.765009</td>
#       <td>0.761705</td>
#       <td>0.838850</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.016300</td>
#       <td>0.847994</td>
#       <td>0.771167</td>
#       <td>0.768996</td>
#       <td>0.770080</td>
#       <td>0.843978</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.011800</td>
#       <td>0.849698</td>
#       <td>0.772300</td>
#       <td>0.771576</td>
#       <td>0.771938</td>
#       <td>0.844911</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.008800</td>
#       <td>0.850637</td>
#       <td>0.772717</td>
#       <td>0.771811</td>
#       <td>0.772263</td>
#       <td>0.844911</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:00]
#     </div>
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]
# Training using 244 samples
#     <div>
#
#       <progress value='610' max='610' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [610/610 01:03, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.165400</td>
#       <td>0.680812</td>
#       <td>0.764939</td>
#       <td>0.768527</td>
#       <td>0.766729</td>
#       <td>0.842580</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.169700</td>
#       <td>0.732331</td>
#       <td>0.763895</td>
#       <td>0.767120</td>
#       <td>0.765504</td>
#       <td>0.839938</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.090200</td>
#       <td>0.766527</td>
#       <td>0.776319</td>
#       <td>0.776501</td>
#       <td>0.776410</td>
#       <td>0.849417</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.079000</td>
#       <td>0.775407</td>
#       <td>0.763287</td>
#       <td>0.764540</td>
#       <td>0.763913</td>
#       <td>0.842424</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.036400</td>
#       <td>0.761999</td>
#       <td>0.765766</td>
#       <td>0.777439</td>
#       <td>0.771558</td>
#       <td>0.846620</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.026300</td>
#       <td>0.796551</td>
#       <td>0.770195</td>
#       <td>0.778143</td>
#       <td>0.774148</td>
#       <td>0.848019</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.012900</td>
#       <td>0.819894</td>
#       <td>0.770557</td>
#       <td>0.775797</td>
#       <td>0.773168</td>
#       <td>0.848640</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.008500</td>
#       <td>0.833156</td>
#       <td>0.771860</td>
#       <td>0.778377</td>
#       <td>0.775105</td>
#       <td>0.850350</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.005700</td>
#       <td>0.836889</td>
#       <td>0.773129</td>
#       <td>0.780019</td>
#       <td>0.776558</td>
#       <td>0.850971</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.007000</td>
#       <td>0.838428</td>
#       <td>0.773488</td>
#       <td>0.780019</td>
#       <td>0.776740</td>
#       <td>0.851282</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:00]
#     </div>
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]
# Training using 305 samples
#     <div>
#
#       <progress value='770' max='770' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [770/770 01:16, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.142200</td>
#       <td>0.751495</td>
#       <td>0.747661</td>
#       <td>0.749765</td>
#       <td>0.748712</td>
#       <td>0.830769</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.092900</td>
#       <td>0.786132</td>
#       <td>0.763666</td>
#       <td>0.769934</td>
#       <td>0.766787</td>
#       <td>0.845221</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.077300</td>
#       <td>0.772859</td>
#       <td>0.765854</td>
#       <td>0.773218</td>
#       <td>0.769518</td>
#       <td>0.845221</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.056500</td>
#       <td>0.784471</td>
#       <td>0.778270</td>
#       <td>0.782833</td>
#       <td>0.780545</td>
#       <td>0.851593</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.022300</td>
#       <td>0.800218</td>
#       <td>0.769536</td>
#       <td>0.773687</td>
#       <td>0.771606</td>
#       <td>0.847397</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.018200</td>
#       <td>0.789694</td>
#       <td>0.780613</td>
#       <td>0.781895</td>
#       <td>0.781254</td>
#       <td>0.853458</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.015600</td>
#       <td>0.835446</td>
#       <td>0.782396</td>
#       <td>0.785882</td>
#       <td>0.784135</td>
#       <td>0.852370</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.006400</td>
#       <td>0.840614</td>
#       <td>0.782396</td>
#       <td>0.785882</td>
#       <td>0.784135</td>
#       <td>0.853302</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.004300</td>
#       <td>0.848809</td>
#       <td>0.782964</td>
#       <td>0.786820</td>
#       <td>0.784887</td>
#       <td>0.854079</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.003800</td>
#       <td>0.849244</td>
#       <td>0.782446</td>
#       <td>0.786116</td>
#       <td>0.784277</td>
#       <td>0.853768</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:00]
#     </div>
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]
# Training using 366 samples
#     <div>
#
#       <progress value='920' max='920' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [920/920 01:31, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.127000</td>
#       <td>0.746309</td>
#       <td>0.783656</td>
#       <td>0.778143</td>
#       <td>0.780890</td>
#       <td>0.853613</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.051400</td>
#       <td>0.826447</td>
#       <td>0.783164</td>
#       <td>0.776735</td>
#       <td>0.779936</td>
#       <td>0.847863</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.052400</td>
#       <td>0.797915</td>
#       <td>0.774602</td>
#       <td>0.775328</td>
#       <td>0.774965</td>
#       <td>0.846775</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.023000</td>
#       <td>0.821456</td>
#       <td>0.781279</td>
#       <td>0.779081</td>
#       <td>0.780178</td>
#       <td>0.851127</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.041700</td>
#       <td>0.821247</td>
#       <td>0.779312</td>
#       <td>0.780957</td>
#       <td>0.780134</td>
#       <td>0.852681</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.015000</td>
#       <td>0.869418</td>
#       <td>0.782548</td>
#       <td>0.782364</td>
#       <td>0.782456</td>
#       <td>0.854390</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.007000</td>
#       <td>0.862448</td>
#       <td>0.787565</td>
#       <td>0.784240</td>
#       <td>0.785899</td>
#       <td>0.855944</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.003200</td>
#       <td>0.859354</td>
#       <td>0.785932</td>
#       <td>0.786116</td>
#       <td>0.786024</td>
#       <td>0.856410</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.003100</td>
#       <td>0.865057</td>
#       <td>0.787189</td>
#       <td>0.786820</td>
#       <td>0.787004</td>
#       <td>0.857032</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.005300</td>
#       <td>0.866488</td>
#       <td>0.787474</td>
#       <td>0.787289</td>
#       <td>0.787381</td>
#       <td>0.857032</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:00]
#     </div>
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]
# Training using 427 samples
#     <div>
#
#       <progress value='1070' max='1070' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1070/1070 01:46, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.124600</td>
#       <td>0.739138</td>
#       <td>0.784123</td>
#       <td>0.792214</td>
#       <td>0.788147</td>
#       <td>0.858275</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.044100</td>
#       <td>0.707252</td>
#       <td>0.788163</td>
#       <td>0.787054</td>
#       <td>0.787609</td>
#       <td>0.858897</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.036200</td>
#       <td>0.724527</td>
#       <td>0.777518</td>
#       <td>0.778612</td>
#       <td>0.778064</td>
#       <td>0.854856</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.048400</td>
#       <td>0.713519</td>
#       <td>0.786533</td>
#       <td>0.788931</td>
#       <td>0.787730</td>
#       <td>0.861694</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.023900</td>
#       <td>0.788612</td>
#       <td>0.783322</td>
#       <td>0.784240</td>
#       <td>0.783781</td>
#       <td>0.855012</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.005900</td>
#       <td>0.789787</td>
#       <td>0.785351</td>
#       <td>0.797139</td>
#       <td>0.791201</td>
#       <td>0.861694</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.010200</td>
#       <td>0.824214</td>
#       <td>0.785034</td>
#       <td>0.792214</td>
#       <td>0.788607</td>
#       <td>0.860295</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.001600</td>
#       <td>0.821630</td>
#       <td>0.789131</td>
#       <td>0.796904</td>
#       <td>0.792999</td>
#       <td>0.864336</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.002500</td>
#       <td>0.830340</td>
#       <td>0.789865</td>
#       <td>0.796904</td>
#       <td>0.793369</td>
#       <td>0.864180</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.002100</td>
#       <td>0.832297</td>
#       <td>0.789682</td>
#       <td>0.796904</td>
#       <td>0.793277</td>
#       <td>0.864180</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:00]
#     </div>
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]

# %%
wandb.finish()
# Out:
# VBox(children=(Label(value='0.023 MB of 0.023 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>▁▅▇▇▇▇▇█████████████████████████████████</td></tr><tr><td>eval/f1</td><td>▁▄▇▇▇▇▇▇████████████████████████████████</td></tr><tr><td>eval/loss</td><td>█▅▃▂▂▂▂▁▁▁▁▁▁▁▁▂▂▁▁▁▁▁▁▁▁▁▁▂▂▁▁▂▂▂▁▁▁▁▁▁</td></tr><tr><td>eval/precision</td><td>▁▅▇▇▇▇▇█████████████████████████████████</td></tr><tr><td>eval/recall</td><td>▁▄▆▇▇▇▇▇████████████████████████████████</td></tr><tr><td>eval/runtime</td><td>▁▁▃▂▆▁▁▄▁▁▅▂▁▁▂▁▂▁▁▂▇█▆▁▁▆▂▁▁▁▂▂▁▂▂▁▂▇▂▂</td></tr><tr><td>eval/samples_per_second</td><td>▇█▆▇▃█▇▅██▃▇██▇█▇██▇▁▁▃██▃▇▇█▇▇▇█▇▇█▇▂▇▇</td></tr><tr><td>eval/steps_per_second</td><td>▇█▆▇▃█▇▅██▃▇██▇█▇██▇▁▁▃██▃▇▇█▇▇▇█▇▇█▇▂▇▇</td></tr><tr><td>train/epoch</td><td>▂▅█▂▄▇▂▃▄▆█▂▃▄▆▇▁▂▃▄▅▇▇▁▂▃▄▅▆▇█▁▂▃▄▅▅▆▇█</td></tr><tr><td>train/global_step</td><td>▁▂▂▁▂▃▁▂▂▃▄▂▂▃▄▅▁▂▂▃▄▅▆▁▂▃▄▄▅▆▇▁▂▃▄▅▅▆▇█</td></tr><tr><td>train/grad_norm</td><td>▃▃▅▂▃▃▁▃▄▆▃▄▁▁▅▄▄▂▅▁▁▆▃█▂▃▄▂▅▁▄▁▃▂▂▁▁▁▂▁</td></tr><tr><td>train/learning_rate</td><td>▆▂▇▂▁█▅▃▁█▇▅▃▂▂█▇▆▄▃▁▂▇█▇▆▄▃▂▁▅██▇▆▅▃▃▂▁</td></tr><tr><td>train/loss</td><td>█▄▃▂▁▂▁▁▁▂▂▁▁▁▂▂▁▁▁▁▁▂▂▁▁▁▁▁▁▁▂▁▂▁▁▁▁▁▁▁</td></tr><tr><td>train/total_flos</td><td>▁▂▃▄▅▇█</td></tr><tr><td>train/train_loss</td><td>█▂▁▁▁▁▁</td></tr><tr><td>train/train_runtime</td><td>▁▂▃▄▅▇█</td></tr><tr><td>train/train_samples_per_second</td><td>▁▅▇▇███</td></tr><tr><td>train/train_steps_per_second</td><td>▁▅▇▇███</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>0.86418</td></tr><tr><td>eval/f1</td><td>0.79328</td></tr><tr><td>eval/loss</td><td>0.8323</td></tr><tr><td>eval/precision</td><td>0.78968</td></tr><tr><td>eval/recall</td><td>0.7969</td></tr><tr><td>eval/runtime</td><td>0.9082</td></tr><tr><td>eval/samples_per_second</td><td>84.785</td></tr><tr><td>eval/steps_per_second</td><td>22.022</td></tr><tr><td>train/epoch</td><td>10.0</td></tr><tr><td>train/global_step</td><td>1070</td></tr><tr><td>train/grad_norm</td><td>0.02337</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>train/loss</td><td>0.0021</td></tr><tr><td>train/total_flos</td><td>561070601430210.0</td></tr><tr><td>train/train_loss</td><td>0.03134</td></tr><tr><td>train/train_runtime</td><td>106.3189</td></tr><tr><td>train/train_samples_per_second</td><td>40.162</td></tr><tr><td>train/train_steps_per_second</td><td>10.064</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">RuBioBERT_AL_v4</strong> at: <a href='https://wandb.ai/taoea/ner_bert_nerel_bio/runs/wgll4mr8' target="_blank">https://wandb.ai/taoea/ner_bert_nerel_bio/runs/wgll4mr8</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240318_174144-wgll4mr8/logs</code>

# %%
metrics
# Out:
# {'0': {'metrics': {'train_loss': 1.0297480553388596,
#    'eval_loss': 1.0000391006469727,
#    'eval_precision': 0.7027737924438068,
#    'eval_recall': 0.6892589118198874,
#    'eval_f1': 0.6959507459152261,
#    'eval_accuracy': 0.7847707847707848,
#    'eval_runtime': 1.201,
#    'eval_samples_per_second': 64.113,
#    'eval_steps_per_second': 16.653,
#    'epoch': 10.0,
#    'pred_loss': 0.7819056510925293,
#    'pred_precision': 0.7273767885532592,
#    'pred_recall': 0.7065291247143122,
#    'pred_f1': 0.7168014037726389,
#    'pred_accuracy': 0.8206197854588796,
#    'pred_runtime': 6.7995,
#    'pred_samples_per_second': 81.035,
#    'pred_steps_per_second': 20.296},
#   'train_size': 122},
#  '1': {'metrics': {'train_loss': 0.2042718634490044,
#    'eval_loss': 0.8234638571739197,
#    'eval_precision': 0.7653037107066887,
#    'eval_recall': 0.7593808630393997,
#    'eval_f1': 0.7623307828134197,
#    'eval_accuracy': 0.8368298368298368,
#    'eval_runtime': 0.8978,
#    'eval_samples_per_second': 85.765,
#    'eval_steps_per_second': 22.277,
#    'epoch': 10.0,
#    'pred_loss': 0.7084041833877563,
#    'pred_precision': 0.7735536047556508,
#    'pred_recall': 0.7615256370997925,
#    'pred_f1': 0.7674924989284183,
#    'pred_accuracy': 0.8589920256624574,
#    'pred_runtime': 6.1681,
#    'pred_samples_per_second': 79.44,
#    'pred_steps_per_second': 19.941},
#   'train_size': 183},
#  '2': {'metrics': {'train_loss': 0.07302638068795204,
#    'eval_loss': 0.8506368398666382,
#    'eval_precision': 0.7727166001408782,
#    'eval_recall': 0.7718105065666041,
#    'eval_f1': 0.7722632875747976,
#    'eval_accuracy': 0.8449106449106449,
#    'eval_runtime': 0.8827,
#    'eval_samples_per_second': 87.229,
#    'eval_steps_per_second': 22.657,
#    'epoch': 10.0,
#    'pred_loss': 0.7224091291427612,
#    'pred_precision': 0.7836482838411107,
#    'pred_recall': 0.7723886270336019,
#    'pred_f1': 0.7779777173704965,
#    'pred_accuracy': 0.8654055009723941,
#    'pred_runtime': 5.5371,
#    'pred_samples_per_second': 77.478,
#    'pred_steps_per_second': 19.505},
#   'train_size': 244},
#  '3': {'metrics': {'train_loss': 0.05767390375315654,
#    'eval_loss': 0.8384276628494263,
#    'eval_precision': 0.7734883720930232,
#    'eval_recall': 0.7800187617260788,
#    'eval_f1': 0.7767398411957028,
#    'eval_accuracy': 0.8512820512820513,
#    'eval_runtime': 0.8986,
#    'eval_samples_per_second': 85.686,
#    'eval_steps_per_second': 22.256,
#    'epoch': 10.0,
#    'pred_loss': 0.7046812176704407,
#    'pred_precision': 0.7935699226985242,
#    'pred_recall': 0.7839291912530372,
#    'pred_f1': 0.788720097782434,
#    'pred_accuracy': 0.8709445052728635,
#    'pred_runtime': 4.9055,
#    'pred_samples_per_second': 75.017,
#    'pred_steps_per_second': 18.754},
#   'train_size': 305},
#  '4': {'metrics': {'train_loss': 0.03976122820145124,
#    'eval_loss': 0.8492438793182373,
#    'eval_precision': 0.7824463118580766,
#    'eval_recall': 0.7861163227016885,
#    'eval_f1': 0.7842770238652316,
#    'eval_accuracy': 0.8537684537684538,
#    'eval_runtime': 0.8908,
#    'eval_samples_per_second': 86.441,
#    'eval_steps_per_second': 22.452,
#    'epoch': 10.0,
#    'pred_loss': 0.6882714629173279,
#    'pred_precision': 0.796788967220707,
#    'pred_recall': 0.789879100137734,
#    'pred_f1': 0.7933189876011886,
#    'pred_accuracy': 0.8757799588519005,
#    'pred_runtime': 4.1788,
#    'pred_samples_per_second': 73.467,
#    'pred_steps_per_second': 18.427},
#   'train_size': 366},
#  '5': {'metrics': {'train_loss': 0.03199033139111555,
#    'eval_loss': 0.8664875626564026,
#    'eval_precision': 0.7874736101337086,
#    'eval_recall': 0.7872889305816135,
#    'eval_f1': 0.7873812595285564,
#    'eval_accuracy': 0.857031857031857,
#    'eval_runtime': 0.9027,
#    'eval_samples_per_second': 85.298,
#    'eval_steps_per_second': 22.155,
#    'epoch': 10.0,
#    'pred_loss': 0.7256907820701599,
#    'pred_precision': 0.7980702528851611,
#    'pred_recall': 0.7863667433045424,
#    'pred_f1': 0.7921752738654148,
#    'pred_accuracy': 0.8763934021636296,
#    'pred_runtime': 3.4354,
#    'pred_samples_per_second': 71.607,
#    'pred_steps_per_second': 18.047},
#   'train_size': 427},
#  '6': {'metrics': {'train_loss': 0.03133858731103556,
#    'eval_loss': 0.8322972059249878,
#    'eval_precision': 0.7896816174761794,
#    'eval_recall': 0.7969043151969981,
#    'eval_f1': 0.793276526205206,
#    'eval_accuracy': 0.8641802641802642,
#    'eval_runtime': 0.9082,
#    'eval_samples_per_second': 84.785,
#    'eval_steps_per_second': 22.022,
#    'epoch': 10.0,
#    'pred_loss': 0.6876980066299438,
#    'pred_precision': 0.8090612244897959,
#    'pred_recall': 0.803030303030303,
#    'pred_f1': 0.8060344827586207,
#    'pred_accuracy': 0.883503993995604,
#    'pred_runtime': 2.6833,
#    'pred_samples_per_second': 68.944,
#    'pred_steps_per_second': 17.516},
#   'train_size': 488}}

# %% [markdown]
# **Вывод**: к 5 итерации активного обучения (50% датасета) достигается максимальное качество.

# %% [markdown]
# ### Оценка качества на тестовой выборке

# %%
predictions = trainer.predict(test_dataset=tokenized_dataset["test"])

# %%
predictions.metrics
# Out:
# {'test_loss': 0.7540450692176819,
#  'test_precision': 0.8198219870098629,
#  'test_recall': 0.814336917562724,
#  'test_f1': 0.817070246943179,
#  'test_accuracy': 0.8851713496832874,
#  'test_runtime': 1.6279,
#  'test_samples_per_second': 47.301,
#  'test_steps_per_second': 12.286}

# %% [markdown]
# Оценка модели на абстракте, которого не было в тестовом наборе

# %%
ner_bio = pipeline("ner", model=model, tokenizer=tokenizer, device=config.device)

# %%
abstract = """Цель. Оценить выживаемость у пациентов с болезнью Фабри (БФ) в зависимости от вида заместительной почечной терапии, и определить роль диализного скрининга в ранней диагностике БФ у родственников.
Материалы и методы. В исследование включали взрослых (старше 18 лет) пациентов с подтвержденным диагнозом БФ. Терминальная стадия хронической почечной недостаточности (тХПН) диагностировали в соответствии с рекомендациями Научного общества нефрологов России (2016) и KDIGO (2012). На основании опроса пробандов выявляли его родственников, которые могли унаследовать мутантный ген.
Результаты. У 50 (24,9%) из 201 обследованных пациентов с БФ диагностирована тХПН, в том числе у 48 (40%) из 120 мужчин и 2 (2,7%) из 81 женщин. Оценка кумулятивной частоты методом Каплана-Майера демонстрирует выраженное увеличение частоты регистрации тХПН к возрасту 20-30 лет, а к возрасту 50 лет ожидаемое количество пациентов с тХПН составляет 95%. Пяти из 50 больных с тХПН была выполнена трансплантация почки, в среднем, через 17 месяцев (диапазон от 7 до 70 месяцев) после инициации лечения гемодиализом. Умерло 15 (30%) из 50 пациентов, получавших лечение гемодиализом. Все умершие пациенты были мужского пола. Медиана возраста на момент летального исхода составила 45 (39; 58) лет. Среди пациентов, которым проведена трансплантация почки, летальных исходов зарегистрировано не было. У 44 (88%) из 50 пациентов диагноз БФ установлен, в среднем, через 1 год (диапазон от 0 до 12 лет) после начала лечения программным гемодиализом, в том числе у одного пациента – после трансплантации почки. Среди 44 пробандов, выявленных при всероссийском диализном скрининге, проведен семейный скрининг. Патогенная мутация в гене GLA диагностирована у 89 (57%) из 156 обследованных родственников диализных пробандов, в том числе у 18 детей моложе 18 лет, клинические проявления БФ имелись у 48 родственников. У 80,4% обследованных родственников диализных пробандов обнаружено поражение почек, преимущественно на ранних стадиях.
Заключение. ТХПН нередкое осложнение БФ, ассоциированное с неблагоприятным прогнозом. Однако диализный скрининг –  эффективный способ выявления пробандов с БФ, открывающий возможность установить диагноз БФ у родственников на ранних стадиях, когда лечение наиболее эффективно.
"""

# %%
ner_bio(abstract)
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# [{'entity': 'DATE',
#   'score': 0.10373853,
#   'index': 1,
#   'word': 'Цель',
#   'start': 0,
#   'end': 4},
#  {'entity': 'FINDING',
#   'score': 0.13174264,
#   'index': 2,
#   'word': '.',
#   'start': 4,
#   'end': 5},
#  {'entity': 'SCIPROC',
#   'score': 0.53618705,
#   'index': 3,
#   'word': 'Оцени',
#   'start': 6,
#   'end': 11},
#  {'entity': 'FINDING',
#   'score': 0.83551633,
#   'index': 4,
#   'word': '##ть',
#   'start': 11,
#   'end': 13},
#  {'entity': 'PHYS',
#   'score': 0.9970161,
#   'index': 5,
#   'word': 'выжи',
#   'start': 14,
#   'end': 18},
#  {'entity': 'PHYS',
#   'score': 0.9975267,
#   'index': 6,
#   'word': '##ваемость',
#   'start': 18,
#   'end': 26},
#  {'entity': 'PERSON',
#   'score': 0.79657394,
#   'index': 7,
#   'word': 'у',
#   'start': 27,
#   'end': 28},
#  {'entity': 'PERSON',
#   'score': 0.99926406,
#   'index': 8,
#   'word': 'пациентов',
#   'start': 29,
#   'end': 38},
#  {'entity': 'DISO',
#   'score': 0.9991222,
#   'index': 9,
#   'word': 'с',
#   'start': 39,
#   'end': 40},
#  {'entity': 'DISO',
#   'score': 0.9995628,
#   'index': 10,
#   'word': 'болезнью',
#   'start': 41,
#   'end': 49},
#  {'entity': 'PERSON',
#   'score': 0.68976647,
#   'index': 11,
#   'word': 'Фабри',
#   'start': 50,
#   'end': 55},
#  {'entity': 'DISO',
#   'score': 0.65774083,
#   'index': 12,
#   'word': '(',
#   'start': 56,
#   'end': 57},
#  {'entity': 'DISO',
#   'score': 0.9995432,
#   'index': 13,
#   'word': 'БФ',
#   'start': 57,
#   'end': 59},
#  {'entity': 'DISO',
#   'score': 0.57222074,
#   'index': 14,
#   'word': ')',
#   'start': 59,
#   'end': 60},
#  {'entity': 'DATE',
#   'score': 0.9645657,
#   'index': 15,
#   'word': 'в',
#   'start': 61,
#   'end': 62},
#  {'entity': 'DATE',
#   'score': 0.4008355,
#   'index': 16,
#   'word': 'зависимости',
#   'start': 63,
#   'end': 74},
#  {'entity': 'PHYS',
#   'score': 0.3638963,
#   'index': 17,
#   'word': 'от',
#   'start': 75,
#   'end': 77},
#  {'entity': 'MEDPROC',
#   'score': 0.9987224,
#   'index': 18,
#   'word': 'вида',
#   'start': 78,
#   'end': 82},
#  {'entity': 'MEDPROC',
#   'score': 0.9995372,
#   'index': 19,
#   'word': 'заместитель',
#   'start': 83,
#   'end': 94},
#  {'entity': 'MEDPROC',
#   'score': 0.99952364,
#   'index': 20,
#   'word': '##ной',
#   'start': 94,
#   'end': 97},
#  {'entity': 'MEDPROC',
#   'score': 0.9946524,
#   'index': 21,
#   'word': 'почечной',
#   'start': 98,
#   'end': 106},
#  {'entity': 'MEDPROC',
#   'score': 0.99945885,
#   'index': 22,
#   'word': 'терапии',
#   'start': 107,
#   'end': 114},
#  {'entity': 'PERSON',
#   'score': 0.1327958,
#   'index': 23,
#   'word': ',',
#   'start': 114,
#   'end': 115},
#  {'entity': 'SCIPROC',
#   'score': 0.42385098,
#   'index': 24,
#   'word': 'и',
#   'start': 116,
#   'end': 117},
#  {'entity': 'FINDING',
#   'score': 0.77773553,
#   'index': 25,
#   'word': 'определить',
#   'start': 118,
#   'end': 128},
#  {'entity': 'PHYS',
#   'score': 0.4696265,
#   'index': 26,
#   'word': 'роль',
#   'start': 129,
#   'end': 133},
#  {'entity': 'MEDPROC',
#   'score': 0.99529654,
#   'index': 27,
#   'word': 'диа',
#   'start': 134,
#   'end': 137},
#  {'entity': 'MEDPROC',
#   'score': 0.9740922,
#   'index': 28,
#   'word': '##лиз',
#   'start': 137,
#   'end': 140},
#  {'entity': 'MEDPROC',
#   'score': 0.9830641,
#   'index': 29,
#   'word': '##ного',
#   'start': 140,
#   'end': 144},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.5943612,
#   'index': 30,
#   'word': 'скрин',
#   'start': 145,
#   'end': 150},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.50168854,
#   'index': 31,
#   'word': '##инга',
#   'start': 150,
#   'end': 154},
#  {'entity': 'FINDING',
#   'score': 0.8745676,
#   'index': 32,
#   'word': 'в',
#   'start': 155,
#   'end': 156},
#  {'entity': 'FINDING',
#   'score': 0.6690607,
#   'index': 33,
#   'word': 'ранней',
#   'start': 157,
#   'end': 163},
#  {'entity': 'MEDPROC',
#   'score': 0.4255053,
#   'index': 34,
#   'word': 'диагностике',
#   'start': 164,
#   'end': 175},
#  {'entity': 'DISO',
#   'score': 0.9996599,
#   'index': 35,
#   'word': 'БФ',
#   'start': 176,
#   'end': 178},
#  {'entity': 'PERSON',
#   'score': 0.95666194,
#   'index': 36,
#   'word': 'у',
#   'start': 179,
#   'end': 180},
#  {'entity': 'PERSON',
#   'score': 0.9994344,
#   'index': 37,
#   'word': 'родственников',
#   'start': 181,
#   'end': 194},
#  {'entity': 'PERSON',
#   'score': 0.13172571,
#   'index': 38,
#   'word': '.',
#   'start': 194,
#   'end': 195},
#  {'entity': 'SCIPROC',
#   'score': 0.39359245,
#   'index': 39,
#   'word': 'Материалы',
#   'start': 196,
#   'end': 205},
#  {'entity': 'SCIPROC',
#   'score': 0.33191258,
#   'index': 40,
#   'word': 'и',
#   'start': 206,
#   'end': 207},
#  {'entity': 'SCIPROC',
#   'score': 0.1980334,
#   'index': 41,
#   'word': 'методы',
#   'start': 208,
#   'end': 214},
#  {'entity': 'MEDPROC',
#   'score': 0.26191938,
#   'index': 42,
#   'word': '.',
#   'start': 214,
#   'end': 215},
#  {'entity': 'SCIPROC',
#   'score': 0.28701475,
#   'index': 43,
#   'word': 'В',
#   'start': 216,
#   'end': 217},
#  {'entity': 'SCIPROC',
#   'score': 0.5627644,
#   'index': 44,
#   'word': 'исследование',
#   'start': 218,
#   'end': 230},
#  {'entity': 'PERSON',
#   'score': 0.8724768,
#   'index': 45,
#   'word': 'включали',
#   'start': 231,
#   'end': 239},
#  {'entity': 'PERSON',
#   'score': 0.99906033,
#   'index': 46,
#   'word': 'взрослых',
#   'start': 240,
#   'end': 248},
#  {'entity': 'AGE',
#   'score': 0.8937939,
#   'index': 47,
#   'word': '(',
#   'start': 249,
#   'end': 250},
#  {'entity': 'AGE',
#   'score': 0.9993192,
#   'index': 48,
#   'word': 'старше',
#   'start': 250,
#   'end': 256},
#  {'entity': 'AGE',
#   'score': 0.9992157,
#   'index': 49,
#   'word': '18',
#   'start': 257,
#   'end': 259},
#  {'entity': 'AGE',
#   'score': 0.9987363,
#   'index': 50,
#   'word': 'лет',
#   'start': 260,
#   'end': 263},
#  {'entity': 'PERSON',
#   'score': 0.9977678,
#   'index': 51,
#   'word': ')',
#   'start': 263,
#   'end': 264},
#  {'entity': 'PERSON',
#   'score': 0.9996691,
#   'index': 52,
#   'word': 'пациентов',
#   'start': 265,
#   'end': 274},
#  {'entity': 'FINDING',
#   'score': 0.7558342,
#   'index': 53,
#   'word': 'с',
#   'start': 275,
#   'end': 276},
#  {'entity': 'FINDING',
#   'score': 0.42424443,
#   'index': 54,
#   'word': 'подтвержден',
#   'start': 277,
#   'end': 288},
#  {'entity': 'PHYS',
#   'score': 0.33794466,
#   'index': 55,
#   'word': '##ным',
#   'start': 288,
#   'end': 291},
#  {'entity': 'DISO',
#   'score': 0.91884667,
#   'index': 56,
#   'word': 'диагнозом',
#   'start': 292,
#   'end': 301},
#  {'entity': 'DISO',
#   'score': 0.9996265,
#   'index': 57,
#   'word': 'БФ',
#   'start': 302,
#   'end': 304},
#  {'entity': 'DISO',
#   'score': 0.14648905,
#   'index': 58,
#   'word': '.',
#   'start': 304,
#   'end': 305},
#  {'entity': 'DISO',
#   'score': 0.99933535,
#   'index': 59,
#   'word': 'Терминал',
#   'start': 306,
#   'end': 314},
#  {'entity': 'DISO',
#   'score': 0.99936634,
#   'index': 60,
#   'word': '##ь',
#   'start': 314,
#   'end': 315},
#  {'entity': 'DISO',
#   'score': 0.9993616,
#   'index': 61,
#   'word': '##ная',
#   'start': 315,
#   'end': 318},
#  {'entity': 'DISO',
#   'score': 0.99947315,
#   'index': 62,
#   'word': 'стадия',
#   'start': 319,
#   'end': 325},
#  {'entity': 'DISO',
#   'score': 0.99958247,
#   'index': 63,
#   'word': 'хронической',
#   'start': 326,
#   'end': 337},
#  {'entity': 'DISO',
#   'score': 0.99523395,
#   'index': 64,
#   'word': 'почечной',
#   'start': 338,
#   'end': 346},
#  {'entity': 'DISO',
#   'score': 0.99901235,
#   'index': 65,
#   'word': 'недостаточности',
#   'start': 347,
#   'end': 362},
#  {'entity': 'DISO',
#   'score': 0.96706736,
#   'index': 66,
#   'word': '(',
#   'start': 363,
#   'end': 364},
#  {'entity': 'DISO',
#   'score': 0.9995597,
#   'index': 67,
#   'word': 'т',
#   'start': 364,
#   'end': 365},
#  {'entity': 'DISO',
#   'score': 0.99891186,
#   'index': 68,
#   'word': '##Х',
#   'start': 365,
#   'end': 366},
#  {'entity': 'DISO',
#   'score': 0.99692565,
#   'index': 69,
#   'word': '##П',
#   'start': 366,
#   'end': 367},
#  {'entity': 'DISO',
#   'score': 0.996082,
#   'index': 70,
#   'word': '##Н',
#   'start': 367,
#   'end': 368},
#  {'entity': 'DISO',
#   'score': 0.5584627,
#   'index': 71,
#   'word': ')',
#   'start': 368,
#   'end': 369},
#  {'entity': 'MEDPROC',
#   'score': 0.55643,
#   'index': 72,
#   'word': 'диагностировали',
#   'start': 370,
#   'end': 385},
#  {'entity': 'SCIPROC',
#   'score': 0.9690982,
#   'index': 73,
#   'word': 'в',
#   'start': 386,
#   'end': 387},
#  {'entity': 'SCIPROC',
#   'score': 0.98686165,
#   'index': 74,
#   'word': 'соответствии',
#   'start': 388,
#   'end': 400},
#  {'entity': 'SCIPROC',
#   'score': 0.99521244,
#   'index': 75,
#   'word': 'с',
#   'start': 401,
#   'end': 402},
#  {'entity': 'SCIPROC',
#   'score': 0.9972541,
#   'index': 76,
#   'word': 'рекомендациями',
#   'start': 403,
#   'end': 417},
#  {'entity': 'ORGANIZATION',
#   'score': 0.9972029,
#   'index': 77,
#   'word': 'Научного',
#   'start': 418,
#   'end': 426},
#  {'entity': 'ORGANIZATION',
#   'score': 0.9968683,
#   'index': 78,
#   'word': 'общества',
#   'start': 427,
#   'end': 435},
#  {'entity': 'PROFESSION',
#   'score': 0.9302797,
#   'index': 79,
#   'word': 'неф',
#   'start': 436,
#   'end': 439},
#  {'entity': 'PROFESSION',
#   'score': 0.99537057,
#   'index': 80,
#   'word': '##рол',
#   'start': 439,
#   'end': 442},
#  {'entity': 'PROFESSION',
#   'score': 0.99463296,
#   'index': 81,
#   'word': '##ого',
#   'start': 442,
#   'end': 445},
#  {'entity': 'PROFESSION',
#   'score': 0.98148155,
#   'index': 82,
#   'word': '##в',
#   'start': 445,
#   'end': 446},
#  {'entity': 'COUNTRY',
#   'score': 0.99926263,
#   'index': 83,
#   'word': 'России',
#   'start': 447,
#   'end': 453},
#  {'entity': 'DATE',
#   'score': 0.98852473,
#   'index': 84,
#   'word': '(',
#   'start': 454,
#   'end': 455},
#  {'entity': 'DATE',
#   'score': 0.973505,
#   'index': 85,
#   'word': '2016',
#   'start': 455,
#   'end': 459},
#  {'entity': 'DATE',
#   'score': 0.21104456,
#   'index': 86,
#   'word': ')',
#   'start': 459,
#   'end': 460},
#  {'entity': 'SCIPROC',
#   'score': 0.9986033,
#   'index': 87,
#   'word': 'и',
#   'start': 461,
#   'end': 462},
#  {'entity': 'SCIPROC',
#   'score': 0.99908054,
#   'index': 88,
#   'word': 'K',
#   'start': 463,
#   'end': 464},
#  {'entity': 'SCIPROC',
#   'score': 0.9984415,
#   'index': 89,
#   'word': '##DI',
#   'start': 464,
#   'end': 466},
#  {'entity': 'SCIPROC',
#   'score': 0.99606967,
#   'index': 90,
#   'word': '##GO',
#   'start': 466,
#   'end': 468},
#  {'entity': 'DATE',
#   'score': 0.97983414,
#   'index': 91,
#   'word': '(',
#   'start': 469,
#   'end': 470},
#  {'entity': 'DATE',
#   'score': 0.9622952,
#   'index': 92,
#   'word': '2012',
#   'start': 470,
#   'end': 474},
#  {'entity': 'PERSON',
#   'score': 0.16676162,
#   'index': 93,
#   'word': ')',
#   'start': 474,
#   'end': 475},
#  {'entity': 'SCIPROC',
#   'score': 0.19279315,
#   'index': 94,
#   'word': '.',
#   'start': 475,
#   'end': 476},
#  {'entity': 'SCIPROC',
#   'score': 0.67102754,
#   'index': 95,
#   'word': 'На',
#   'start': 477,
#   'end': 479},
#  {'entity': 'SCIPROC',
#   'score': 0.7598291,
#   'index': 96,
#   'word': 'основании',
#   'start': 480,
#   'end': 489},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.8784779,
#   'index': 97,
#   'word': 'опроса',
#   'start': 490,
#   'end': 496},
#  {'entity': 'PERSON',
#   'score': 0.993772,
#   'index': 98,
#   'word': 'проба',
#   'start': 497,
#   'end': 502},
#  {'entity': 'PERSON',
#   'score': 0.9835137,
#   'index': 99,
#   'word': '##ндо',
#   'start': 502,
#   'end': 505},
#  {'entity': 'PERSON',
#   'score': 0.8927279,
#   'index': 100,
#   'word': '##в',
#   'start': 505,
#   'end': 506},
#  {'entity': 'FINDING',
#   'score': 0.5557403,
#   'index': 101,
#   'word': 'выявля',
#   'start': 507,
#   'end': 513},
#  {'entity': 'FINDING',
#   'score': 0.59442675,
#   'index': 102,
#   'word': '##ли',
#   'start': 513,
#   'end': 515},
#  {'entity': 'PERSON',
#   'score': 0.9815338,
#   'index': 103,
#   'word': 'его',
#   'start': 516,
#   'end': 519},
#  {'entity': 'PERSON',
#   'score': 0.99851996,
#   'index': 104,
#   'word': 'родственников',
#   'start': 520,
#   'end': 533},
#  {'entity': 'FINDING',
#   'score': 0.31948474,
#   'index': 105,
#   'word': ',',
#   'start': 533,
#   'end': 534},
#  {'entity': 'PERSON',
#   'score': 0.26989794,
#   'index': 106,
#   'word': 'которые',
#   'start': 535,
#   'end': 542},
#  {'entity': 'FINDING',
#   'score': 0.3451324,
#   'index': 107,
#   'word': 'могли',
#   'start': 543,
#   'end': 548},
#  {'entity': 'PHYS',
#   'score': 0.7810179,
#   'index': 108,
#   'word': 'унаследова',
#   'start': 549,
#   'end': 559},
#  {'entity': 'PHYS',
#   'score': 0.42677593,
#   'index': 109,
#   'word': '##ть',
#   'start': 559,
#   'end': 561},
#  {'entity': 'PHYS',
#   'score': 0.8063095,
#   'index': 110,
#   'word': 'мутант',
#   'start': 562,
#   'end': 568},
#  {'entity': 'GENE',
#   'score': 0.7213429,
#   'index': 111,
#   'word': '##ный',
#   'start': 568,
#   'end': 571},
#  {'entity': 'GENE',
#   'score': 0.99526703,
#   'index': 112,
#   'word': 'ген',
#   'start': 572,
#   'end': 575},
#  {'entity': 'DATE',
#   'score': 0.14473325,
#   'index': 113,
#   'word': '.',
#   'start': 575,
#   'end': 576},
#  {'entity': 'FINDING',
#   'score': 0.96747565,
#   'index': 114,
#   'word': 'Результаты',
#   'start': 577,
#   'end': 587},
#  {'entity': 'FINDING',
#   'score': 0.24056146,
#   'index': 115,
#   'word': '.',
#   'start': 587,
#   'end': 588},
#  {'entity': 'DATE',
#   'score': 0.43524587,
#   'index': 116,
#   'word': 'У',
#   'start': 589,
#   'end': 590},
#  {'entity': 'NUMBER',
#   'score': 0.9555686,
#   'index': 117,
#   'word': '50',
#   'start': 591,
#   'end': 593},
#  {'entity': 'PERCENT',
#   'score': 0.9929941,
#   'index': 118,
#   'word': '(',
#   'start': 594,
#   'end': 595},
#  {'entity': 'PERCENT',
#   'score': 0.9997155,
#   'index': 119,
#   'word': '24',
#   'start': 595,
#   'end': 597},
#  {'entity': 'PERCENT',
#   'score': 0.99852836,
#   'index': 120,
#   'word': ',',
#   'start': 597,
#   'end': 598},
#  {'entity': 'PERCENT',
#   'score': 0.9972921,
#   'index': 121,
#   'word': '9',
#   'start': 598,
#   'end': 599},
#  {'entity': 'PERCENT',
#   'score': 0.962082,
#   'index': 122,
#   'word': '%',
#   'start': 599,
#   'end': 600},
#  {'entity': 'PERSON',
#   'score': 0.8056957,
#   'index': 123,
#   'word': ')',
#   'start': 600,
#   'end': 601},
#  {'entity': 'PERSON',
#   'score': 0.5658354,
#   'index': 124,
#   'word': 'из',
#   'start': 602,
#   'end': 604},
#  {'entity': 'NUMBER',
#   'score': 0.9858819,
#   'index': 125,
#   'word': '201',
#   'start': 605,
#   'end': 608},
#  {'entity': 'PERSON',
#   'score': 0.9996942,
#   'index': 126,
#   'word': 'обследова',
#   'start': 609,
#   'end': 618},
#  {'entity': 'PERSON',
#   'score': 0.9997042,
#   'index': 127,
#   'word': '##нных',
#   'start': 618,
#   'end': 622},
#  {'entity': 'PERSON',
#   'score': 0.9997415,
#   'index': 128,
#   'word': 'пациентов',
#   'start': 623,
#   'end': 632},
#  {'entity': 'DISO',
#   'score': 0.9808055,
#   'index': 129,
#   'word': 'с',
#   'start': 633,
#   'end': 634},
#  {'entity': 'DISO',
#   'score': 0.9996666,
#   'index': 130,
#   'word': 'БФ',
#   'start': 635,
#   'end': 637},
#  {'entity': 'FINDING',
#   'score': 0.9642986,
#   'index': 131,
#   'word': 'диагности',
#   'start': 638,
#   'end': 647},
#  {'entity': 'FINDING',
#   'score': 0.9468837,
#   'index': 132,
#   'word': '##рована',
#   'start': 647,
#   'end': 653},
#  {'entity': 'DISO',
#   'score': 0.9997415,
#   'index': 133,
#   'word': 'т',
#   'start': 654,
#   'end': 655},
#  {'entity': 'DISO',
#   'score': 0.99938977,
#   'index': 134,
#   'word': '##Х',
#   'start': 655,
#   'end': 656},
#  {'entity': 'DISO',
#   'score': 0.9983316,
#   'index': 135,
#   'word': '##П',
#   'start': 656,
#   'end': 657},
#  {'entity': 'DISO',
#   'score': 0.9986534,
#   'index': 136,
#   'word': '##Н',
#   'start': 657,
#   'end': 658},
#  {'entity': 'DATE',
#   'score': 0.46900582,
#   'index': 137,
#   'word': ',',
#   'start': 658,
#   'end': 659},
#  {'entity': 'DATE',
#   'score': 0.36116555,
#   'index': 138,
#   'word': 'в',
#   'start': 660,
#   'end': 661},
#  {'entity': 'PERCENT',
#   'score': 0.2348279,
#   'index': 139,
#   'word': 'том',
#   'start': 662,
#   'end': 665},
#  {'entity': 'PERCENT',
#   'score': 0.3543997,
#   'index': 140,
#   'word': 'числе',
#   'start': 666,
#   'end': 671},
#  {'entity': 'DATE',
#   'score': 0.28138512,
#   'index': 141,
#   'word': 'у',
#   'start': 672,
#   'end': 673},
#  {'entity': 'NUMBER',
#   'score': 0.83374757,
#   'index': 142,
#   'word': '48',
#   'start': 674,
#   'end': 676},
#  {'entity': 'PERCENT',
#   'score': 0.9979467,
#   'index': 143,
#   'word': '(',
#   'start': 677,
#   'end': 678},
#  {'entity': 'PERCENT',
#   'score': 0.9996056,
#   'index': 144,
#   'word': '40',
#   'start': 678,
#   'end': 680},
#  {'entity': 'PERCENT',
#   'score': 0.9896908,
#   'index': 145,
#   'word': '%',
#   'start': 680,
#   'end': 681},
#  {'entity': 'PERSON',
#   'score': 0.57751405,
#   'index': 146,
#   'word': ')',
#   'start': 681,
#   'end': 682},
#  {'entity': 'PERSON',
#   'score': 0.5432873,
#   'index': 147,
#   'word': 'из',
#   'start': 683,
#   'end': 685},
#  {'entity': 'NUMBER',
#   'score': 0.9942643,
#   'index': 148,
#   'word': '120',
#   'start': 686,
#   'end': 689},
#  {'entity': 'PERSON',
#   'score': 0.9982339,
#   'index': 149,
#   'word': 'мужчин',
#   'start': 690,
#   'end': 696},
#  {'entity': 'PERSON',
#   'score': 0.37618893,
#   'index': 150,
#   'word': 'и',
#   'start': 697,
#   'end': 698},
#  {'entity': 'NUMBER',
#   'score': 0.8893921,
#   'index': 151,
#   'word': '2',
#   'start': 699,
#   'end': 700},
#  {'entity': 'PERCENT',
#   'score': 0.99865305,
#   'index': 152,
#   'word': '(',
#   'start': 701,
#   'end': 702},
#  {'entity': 'PERCENT',
#   'score': 0.99971515,
#   'index': 153,
#   'word': '2',
#   'start': 702,
#   'end': 703},
#  {'entity': 'PERCENT',
#   'score': 0.9993845,
#   'index': 154,
#   'word': ',',
#   'start': 703,
#   'end': 704},
#  {'entity': 'PERCENT',
#   'score': 0.9995586,
#   'index': 155,
#   'word': '7',
#   'start': 704,
#   'end': 705},
#  {'entity': 'PERCENT',
#   'score': 0.9939972,
#   'index': 156,
#   'word': '%',
#   'start': 705,
#   'end': 706},
#  {'entity': 'PERSON',
#   'score': 0.7673917,
#   'index': 157,
#   'word': ')',
#   'start': 706,
#   'end': 707},
#  {'entity': 'PERSON',
#   'score': 0.4171364,
#   'index': 158,
#   'word': 'из',
#   'start': 708,
#   'end': 710},
#  {'entity': 'NUMBER',
#   'score': 0.9873454,
#   'index': 159,
#   'word': '81',
#   'start': 711,
#   'end': 713},
#  {'entity': 'PERSON',
#   'score': 0.99921906,
#   'index': 160,
#   'word': 'женщин',
#   'start': 714,
#   'end': 720},
#  {'entity': 'DATE',
#   'score': 0.20442647,
#   'index': 161,
#   'word': '.',
#   'start': 720,
#   'end': 721},
#  {'entity': 'SCIPROC',
#   'score': 0.99622834,
#   'index': 162,
#   'word': 'Оценка',
#   'start': 722,
#   'end': 728},
#  {'entity': 'SCIPROC',
#   'score': 0.6288242,
#   'index': 163,
#   'word': 'кумуля',
#   'start': 729,
#   'end': 735},
#  {'entity': 'SCIPROC',
#   'score': 0.5698352,
#   'index': 164,
#   'word': '##тивной',
#   'start': 735,
#   'end': 741},
#  {'entity': 'PHYS',
#   'score': 0.8791578,
#   'index': 165,
#   'word': 'частоты',
#   'start': 742,
#   'end': 749},
#  {'entity': 'SCIPROC',
#   'score': 0.9983949,
#   'index': 166,
#   'word': 'методом',
#   'start': 750,
#   'end': 757},
#  {'entity': 'SCIPROC',
#   'score': 0.9982256,
#   'index': 167,
#   'word': 'Каплан',
#   'start': 758,
#   'end': 764},
#  {'entity': 'SCIPROC',
#   'score': 0.9792442,
#   'index': 168,
#   'word': '##а',
#   'start': 764,
#   'end': 765},
#  {'entity': 'SCIPROC',
#   'score': 0.6808918,
#   'index': 169,
#   'word': '-',
#   'start': 765,
#   'end': 766},
#  {'entity': 'SCIPROC',
#   'score': 0.88776785,
#   'index': 170,
#   'word': 'Майер',
#   'start': 766,
#   'end': 771},
#  {'entity': 'SCIPROC',
#   'score': 0.88560534,
#   'index': 171,
#   'word': '##а',
#   'start': 771,
#   'end': 772},
#  {'entity': 'FINDING',
#   'score': 0.9989048,
#   'index': 172,
#   'word': 'демонстрирует',
#   'start': 773,
#   'end': 786},
#  {'entity': 'FINDING',
#   'score': 0.99926966,
#   'index': 173,
#   'word': 'выраженное',
#   'start': 787,
#   'end': 797},
#  {'entity': 'FINDING',
#   'score': 0.99923575,
#   'index': 174,
#   'word': 'увеличение',
#   'start': 798,
#   'end': 808},
#  {'entity': 'PHYS',
#   'score': 0.84363765,
#   'index': 175,
#   'word': 'частоты',
#   'start': 809,
#   'end': 816},
#  {'entity': 'PHYS',
#   'score': 0.7167052,
#   'index': 176,
#   'word': 'регистрации',
#   'start': 817,
#   'end': 828},
#  {'entity': 'DISO',
#   'score': 0.9997329,
#   'index': 177,
#   'word': 'т',
#   'start': 829,
#   'end': 830},
#  {'entity': 'DISO',
#   'score': 0.9994475,
#   'index': 178,
#   'word': '##Х',
#   'start': 830,
#   'end': 831},
#  {'entity': 'DISO',
#   'score': 0.99903727,
#   'index': 179,
#   'word': '##П',
#   'start': 831,
#   'end': 832},
#  {'entity': 'DISO',
#   'score': 0.9990895,
#   'index': 180,
#   'word': '##Н',
#   'start': 832,
#   'end': 833},
#  {'entity': 'AGE',
#   'score': 0.6747166,
#   'index': 181,
#   'word': 'к',
#   'start': 834,
#   'end': 835},
#  {'entity': 'AGE',
#   'score': 0.9954678,
#   'index': 182,
#   'word': 'возрасту',
#   'start': 836,
#   'end': 844},
#  {'entity': 'AGE',
#   'score': 0.9993814,
#   'index': 183,
#   'word': '20',
#   'start': 845,
#   'end': 847},
#  {'entity': 'AGE',
#   'score': 0.9990758,
#   'index': 184,
#   'word': '-',
#   'start': 847,
#   'end': 848},
#  {'entity': 'AGE',
#   'score': 0.99912995,
#   'index': 185,
#   'word': '30',
#   'start': 848,
#   'end': 850},
#  {'entity': 'AGE',
#   'score': 0.99898404,
#   'index': 186,
#   'word': 'лет',
#   'start': 851,
#   'end': 854},
#  {'entity': 'FINDING',
#   'score': 0.8825834,
#   'index': 187,
#   'word': ',',
#   'start': 854,
#   'end': 855},
#  {'entity': 'DATE',
#   'score': 0.5372426,
#   'index': 188,
#   'word': 'а',
#   'start': 856,
#   'end': 857},
#  {'entity': 'DATE',
#   'score': 0.5099805,
#   'index': 189,
#   'word': 'к',
#   'start': 858,
#   'end': 859},
#  {'entity': 'AGE',
#   'score': 0.9974184,
#   'index': 190,
#   'word': 'возрасту',
#   'start': 860,
#   'end': 868},
#  {'entity': 'AGE',
#   'score': 0.9992848,
#   'index': 191,
#   'word': '50',
#   'start': 869,
#   'end': 871},
#  {'entity': 'AGE',
#   'score': 0.9989035,
#   'index': 192,
#   'word': 'лет',
#   'start': 872,
#   'end': 875},
#  {'entity': 'FINDING',
#   'score': 0.99261594,
#   'index': 193,
#   'word': 'ожидаемо',
#   'start': 876,
#   'end': 884},
#  {'entity': 'FINDING',
#   'score': 0.9977043,
#   'index': 194,
#   'word': '##е',
#   'start': 884,
#   'end': 885},
#  {'entity': 'FINDING',
#   'score': 0.9607347,
#   'index': 195,
#   'word': 'количество',
#   'start': 886,
#   'end': 896},
#  {'entity': 'PERSON',
#   'score': 0.9993981,
#   'index': 196,
#   'word': 'пациентов',
#   'start': 897,
#   'end': 906},
#  {'entity': 'DISO',
#   'score': 0.9885309,
#   'index': 197,
#   'word': 'с',
#   'start': 907,
#   'end': 908},
#  {'entity': 'DISO',
#   'score': 0.99974877,
#   'index': 198,
#   'word': 'т',
#   'start': 909,
#   'end': 910},
#  {'entity': 'DISO',
#   'score': 0.99942684,
#   'index': 199,
#   'word': '##Х',
#   'start': 910,
#   'end': 911},
#  {'entity': 'DISO',
#   'score': 0.9987809,
#   'index': 200,
#   'word': '##П',
#   'start': 911,
#   'end': 912},
#  {'entity': 'DISO',
#   'score': 0.99908876,
#   'index': 201,
#   'word': '##Н',
#   'start': 912,
#   'end': 913},
#  {'entity': 'FINDING',
#   'score': 0.9972281,
#   'index': 202,
#   'word': 'составляет',
#   'start': 914,
#   'end': 924},
#  {'entity': 'PERCENT',
#   'score': 0.9996644,
#   'index': 203,
#   'word': '95',
#   'start': 925,
#   'end': 927},
#  {'entity': 'PERCENT',
#   'score': 0.9930288,
#   'index': 204,
#   'word': '%',
#   'start': 927,
#   'end': 928},
#  {'entity': 'DATE',
#   'score': 0.33659285,
#   'index': 205,
#   'word': '.',
#   'start': 928,
#   'end': 929},
#  {'entity': 'NUMBER',
#   'score': 0.9724753,
#   'index': 206,
#   'word': 'Пяти',
#   'start': 930,
#   'end': 934},
#  {'entity': 'PERSON',
#   'score': 0.20921935,
#   'index': 207,
#   'word': 'из',
#   'start': 935,
#   'end': 937},
#  {'entity': 'NUMBER',
#   'score': 0.9945194,
#   'index': 208,
#   'word': '50',
#   'start': 938,
#   'end': 940},
#  {'entity': 'PERSON',
#   'score': 0.99918693,
#   'index': 209,
#   'word': 'больных',
#   'start': 941,
#   'end': 948},
#  {'entity': 'DISO',
#   'score': 0.9960877,
#   'index': 210,
#   'word': 'с',
#   'start': 949,
#   'end': 950},
#  {'entity': 'DISO',
#   'score': 0.9997503,
#   'index': 211,
#   'word': 'т',
#   'start': 951,
#   'end': 952},
#  {'entity': 'DISO',
#   'score': 0.9995363,
#   'index': 212,
#   'word': '##Х',
#   'start': 952,
#   'end': 953},
#  {'entity': 'DISO',
#   'score': 0.99914813,
#   'index': 213,
#   'word': '##П',
#   'start': 953,
#   'end': 954},
#  {'entity': 'DISO',
#   'score': 0.9991047,
#   'index': 214,
#   'word': '##Н',
#   'start': 954,
#   'end': 955},
#  {'entity': 'MEDPROC',
#   'score': 0.99874604,
#   'index': 215,
#   'word': 'была',
#   'start': 956,
#   'end': 960},
#  {'entity': 'MEDPROC',
#   'score': 0.9993943,
#   'index': 216,
#   'word': 'выполнена',
#   'start': 961,
#   'end': 970},
#  {'entity': 'MEDPROC',
#   'score': 0.9995043,
#   'index': 217,
#   'word': 'транспланта',
#   'start': 971,
#   'end': 982},
#  {'entity': 'MEDPROC',
#   'score': 0.9994079,
#   'index': 218,
#   'word': '##ция',
#   'start': 982,
#   'end': 985},
#  {'entity': 'ANATOMY',
#   'score': 0.9996147,
#   'index': 219,
#   'word': 'почки',
#   'start': 986,
#   'end': 991},
#  {'entity': 'DATE',
#   'score': 0.72504425,
#   'index': 220,
#   'word': ',',
#   'start': 991,
#   'end': 992},
#  {'entity': 'DATE',
#   'score': 0.9944457,
#   'index': 221,
#   'word': 'в',
#   'start': 993,
#   'end': 994},
#  {'entity': 'DATE',
#   'score': 0.9915098,
#   'index': 222,
#   'word': 'среднем',
#   'start': 995,
#   'end': 1002},
#  {'entity': 'DATE',
#   'score': 0.9850272,
#   'index': 223,
#   'word': ',',
#   'start': 1002,
#   'end': 1003},
#  {'entity': 'DATE',
#   'score': 0.9995371,
#   'index': 224,
#   'word': 'через',
#   'start': 1004,
#   'end': 1009},
#  {'entity': 'DATE',
#   'score': 0.9993304,
#   'index': 225,
#   'word': '17',
#   'start': 1010,
#   'end': 1012},
#  {'entity': 'DATE',
#   'score': 0.999099,
#   'index': 226,
#   'word': 'месяцев',
#   'start': 1013,
#   'end': 1020},
#  {'entity': 'DATE',
#   'score': 0.9985434,
#   'index': 227,
#   'word': '(',
#   'start': 1021,
#   'end': 1022},
#  {'entity': 'DATE',
#   'score': 0.9402846,
#   'index': 228,
#   'word': 'диапазон',
#   'start': 1022,
#   'end': 1030},
#  {'entity': 'DATE',
#   'score': 0.9982266,
#   'index': 229,
#   'word': 'от',
#   'start': 1031,
#   'end': 1033},
#  {'entity': 'DATE',
#   'score': 0.9992078,
#   'index': 230,
#   'word': '7',
#   'start': 1034,
#   'end': 1035},
#  {'entity': 'DATE',
#   'score': 0.9980623,
#   'index': 231,
#   'word': 'до',
#   'start': 1036,
#   'end': 1038},
#  {'entity': 'DATE',
#   'score': 0.9972844,
#   'index': 232,
#   'word': '70',
#   'start': 1039,
#   'end': 1041},
#  {'entity': 'DATE',
#   'score': 0.9985587,
#   'index': 233,
#   'word': 'месяцев',
#   'start': 1042,
#   'end': 1049},
#  {'entity': 'DATE',
#   'score': 0.9359522,
#   'index': 234,
#   'word': ')',
#   'start': 1049,
#   'end': 1050},
#  {'entity': 'DATE',
#   'score': 0.8031884,
#   'index': 235,
#   'word': 'после',
#   'start': 1051,
#   'end': 1056},
#  {'entity': 'MEDPROC',
#   'score': 0.9945529,
#   'index': 236,
#   'word': 'инициации',
#   'start': 1057,
#   'end': 1066},
#  {'entity': 'MEDPROC',
#   'score': 0.9992926,
#   'index': 237,
#   'word': 'лечения',
#   'start': 1067,
#   'end': 1074},
#  {'entity': 'MEDPROC',
#   'score': 0.99920267,
#   'index': 238,
#   'word': 'гемо',
#   'start': 1075,
#   'end': 1079},
#  {'entity': 'MEDPROC',
#   'score': 0.9991671,
#   'index': 239,
#   'word': '##диа',
#   'start': 1079,
#   'end': 1082},
#  {'entity': 'MEDPROC',
#   'score': 0.99817514,
#   'index': 240,
#   'word': '##лиз',
#   'start': 1082,
#   'end': 1085},
#  {'entity': 'MEDPROC',
#   'score': 0.9985581,
#   'index': 241,
#   'word': '##ом',
#   'start': 1085,
#   'end': 1087},
#  {'entity': 'DATE',
#   'score': 0.4293288,
#   'index': 242,
#   'word': '.',
#   'start': 1087,
#   'end': 1088},
#  {'entity': 'PHYS',
#   'score': 0.80171824,
#   'index': 243,
#   'word': 'Умер',
#   'start': 1089,
#   'end': 1093},
#  {'entity': 'NUMBER',
#   'score': 0.28912106,
#   'index': 244,
#   'word': '##ло',
#   'start': 1093,
#   'end': 1095},
#  {'entity': 'NUMBER',
#   'score': 0.8528401,
#   'index': 245,
#   'word': '15',
#   'start': 1096,
#   'end': 1098},
#  {'entity': 'PERCENT',
#   'score': 0.9976821,
#   'index': 246,
#   'word': '(',
#   'start': 1099,
#   'end': 1100},
#  {'entity': 'PERCENT',
#   'score': 0.99963915,
#   'index': 247,
#   'word': '30',
#   'start': 1100,
#   'end': 1102},
#  {'entity': 'PERCENT',
#   'score': 0.9734977,
#   'index': 248,
#   'word': '%',
#   'start': 1102,
#   'end': 1103},
#  {'entity': 'PERSON',
#   'score': 0.7124412,
#   'index': 249,
#   'word': ')',
#   'start': 1103,
#   'end': 1104},
#  {'entity': 'PERSON',
#   'score': 0.49401256,
#   'index': 250,
#   'word': 'из',
#   'start': 1105,
#   'end': 1107},
#  {'entity': 'NUMBER',
#   'score': 0.98419315,
#   'index': 251,
#   'word': '50',
#   'start': 1108,
#   'end': 1110},
#  {'entity': 'PERSON',
#   'score': 0.9993716,
#   'index': 252,
#   'word': 'пациентов',
#   'start': 1111,
#   'end': 1120},
#  {'entity': 'PERSON',
#   'score': 0.9881676,
#   'index': 253,
#   'word': ',',
#   'start': 1120,
#   'end': 1121},
#  {'entity': 'MEDPROC',
#   'score': 0.9983986,
#   'index': 254,
#   'word': 'получа',
#   'start': 1122,
#   'end': 1128},
#  {'entity': 'MEDPROC',
#   'score': 0.92494386,
#   'index': 255,
#   'word': '##вших',
#   'start': 1128,
#   'end': 1132},
#  {'entity': 'MEDPROC',
#   'score': 0.99946135,
#   'index': 256,
#   'word': 'лечение',
#   'start': 1133,
#   'end': 1140},
#  {'entity': 'MEDPROC',
#   'score': 0.9994223,
#   'index': 257,
#   'word': 'гемо',
#   'start': 1141,
#   'end': 1145},
#  {'entity': 'MEDPROC',
#   'score': 0.999315,
#   'index': 258,
#   'word': '##диа',
#   'start': 1145,
#   'end': 1148},
#  {'entity': 'MEDPROC',
#   'score': 0.99903595,
#   'index': 259,
#   'word': '##лиз',
#   'start': 1148,
#   'end': 1151},
#  {'entity': 'MEDPROC',
#   'score': 0.99922514,
#   'index': 260,
#   'word': '##ом',
#   'start': 1151,
#   'end': 1153},
#  {'entity': 'DATE',
#   'score': 0.19321856,
#   'index': 261,
#   'word': '.',
#   'start': 1153,
#   'end': 1154},
#  {'entity': 'NUMBER',
#   'score': 0.30127957,
#   'index': 262,
#   'word': 'Все',
#   'start': 1155,
#   'end': 1158},
#  {'entity': 'PHYS',
#   'score': 0.42306337,
#   'index': 263,
#   'word': 'умер',
#   'start': 1159,
#   'end': 1163},
#  {'entity': 'PERSON',
#   'score': 0.7929582,
#   'index': 264,
#   'word': '##шие',
#   'start': 1163,
#   'end': 1166},
#  {'entity': 'PERSON',
#   'score': 0.99930024,
#   'index': 265,
#   'word': 'пациенты',
#   'start': 1167,
#   'end': 1175},
#  {'entity': 'PHYS',
#   'score': 0.4413654,
#   'index': 266,
#   'word': 'были',
#   'start': 1176,
#   'end': 1180},
#  {'entity': 'PHYS',
#   'score': 0.9983736,
#   'index': 267,
#   'word': 'мужского',
#   'start': 1181,
#   'end': 1189},
#  {'entity': 'PHYS',
#   'score': 0.9978211,
#   'index': 268,
#   'word': 'пола',
#   'start': 1190,
#   'end': 1194},
#  {'entity': 'DATE',
#   'score': 0.2244908,
#   'index': 269,
#   'word': '.',
#   'start': 1194,
#   'end': 1195},
#  {'entity': 'FINDING',
#   'score': 0.7352933,
#   'index': 270,
#   'word': 'Медиа',
#   'start': 1196,
#   'end': 1201},
#  {'entity': 'FINDING',
#   'score': 0.6756587,
#   'index': 271,
#   'word': '##на',
#   'start': 1201,
#   'end': 1203},
#  {'entity': 'PHYS',
#   'score': 0.99847335,
#   'index': 272,
#   'word': 'возраста',
#   'start': 1204,
#   'end': 1212},
#  {'entity': 'DATE',
#   'score': 0.99812895,
#   'index': 273,
#   'word': 'на',
#   'start': 1213,
#   'end': 1215},
#  {'entity': 'DATE',
#   'score': 0.9553844,
#   'index': 274,
#   'word': 'момент',
#   'start': 1216,
#   'end': 1222},
#  {'entity': 'PHYS',
#   'score': 0.90827787,
#   'index': 275,
#   'word': 'летального',
#   'start': 1223,
#   'end': 1233},
#  {'entity': 'PHYS',
#   'score': 0.7486283,
#   'index': 276,
#   'word': 'исхода',
#   'start': 1234,
#   'end': 1240},
#  {'entity': 'FINDING',
#   'score': 0.95772,
#   'index': 277,
#   'word': 'составила',
#   'start': 1241,
#   'end': 1250},
#  {'entity': 'AGE',
#   'score': 0.99930346,
#   'index': 278,
#   'word': '45',
#   'start': 1251,
#   'end': 1253},
#  {'entity': 'AGE',
#   'score': 0.9983047,
#   'index': 279,
#   'word': '(',
#   'start': 1254,
#   'end': 1255},
#  {'entity': 'AGE',
#   'score': 0.99930835,
#   'index': 280,
#   'word': '39',
#   'start': 1255,
#   'end': 1257},
#  {'entity': 'AGE',
#   'score': 0.7813075,
#   'index': 281,
#   'word': ';',
#   'start': 1257,
#   'end': 1258},
#  {'entity': 'AGE',
#   'score': 0.9958477,
#   'index': 282,
#   'word': '58',
#   'start': 1259,
#   'end': 1261},
#  {'entity': 'AGE',
#   'score': 0.4903937,
#   'index': 283,
#   'word': ')',
#   'start': 1261,
#   'end': 1262},
#  {'entity': 'AGE',
#   'score': 0.9977182,
#   'index': 284,
#   'word': 'лет',
#   'start': 1263,
#   'end': 1266},
#  {'entity': 'DATE',
#   'score': 0.14125249,
#   'index': 285,
#   'word': '.',
#   'start': 1266,
#   'end': 1267},
#  {'entity': 'PERSON',
#   'score': 0.8412653,
#   'index': 286,
#   'word': 'Среди',
#   'start': 1268,
#   'end': 1273},
#  {'entity': 'PERSON',
#   'score': 0.99951994,
#   'index': 287,
#   'word': 'пациентов',
#   'start': 1274,
#   'end': 1283},
#  {'entity': 'PERSON',
#   'score': 0.6055626,
#   'index': 288,
#   'word': ',',
#   'start': 1283,
#   'end': 1284},
#  {'entity': 'PERSON',
#   'score': 0.46755442,
#   'index': 289,
#   'word': 'которым',
#   'start': 1285,
#   'end': 1292},
#  {'entity': 'MEDPROC',
#   'score': 0.9994832,
#   'index': 290,
#   'word': 'проведена',
#   'start': 1293,
#   'end': 1302},
#  {'entity': 'MEDPROC',
#   'score': 0.99955946,
#   'index': 291,
#   'word': 'транспланта',
#   'start': 1303,
#   'end': 1314},
#  {'entity': 'MEDPROC',
#   'score': 0.99948704,
#   'index': 292,
#   'word': '##ция',
#   'start': 1314,
#   'end': 1317},
#  {'entity': 'ANATOMY',
#   'score': 0.99965394,
#   'index': 293,
#   'word': 'почки',
#   'start': 1318,
#   'end': 1323},
#  {'entity': 'FINDING',
#   'score': 0.9927416,
#   'index': 294,
#   'word': ',',
#   'start': 1323,
#   'end': 1324},
#  {'entity': 'FINDING',
#   'score': 0.99884546,
#   'index': 295,
#   'word': 'летальных',
#   'start': 1325,
#   'end': 1334},
#  {'entity': 'FINDING',
#   'score': 0.9981337,
#   'index': 296,
#   'word': 'исход',
#   'start': 1335,
#   'end': 1340},
#  {'entity': 'FINDING',
#   'score': 0.99544996,
#   'index': 297,
#   'word': '##ов',
#   'start': 1340,
#   'end': 1342},
#  {'entity': 'FINDING',
#   'score': 0.997035,
#   'index': 298,
#   'word': 'зарегистрировано',
#   'start': 1343,
#   'end': 1359},
#  {'entity': 'FINDING',
#   'score': 0.99417454,
#   'index': 299,
#   'word': 'не',
#   'start': 1360,
#   'end': 1362},
#  {'entity': 'FINDING',
#   'score': 0.9961027,
#   'index': 300,
#   'word': 'было',
#   'start': 1363,
#   'end': 1367},
#  {'entity': 'DATE',
#   'score': 0.14602423,
#   'index': 301,
#   'word': '.',
#   'start': 1367,
#   'end': 1368},
#  {'entity': 'DATE',
#   'score': 0.27172896,
#   'index': 302,
#   'word': 'У',
#   'start': 1369,
#   'end': 1370},
#  {'entity': 'NUMBER',
#   'score': 0.87810266,
#   'index': 303,
#   'word': '44',
#   'start': 1371,
#   'end': 1373},
#  {'entity': 'PERCENT',
#   'score': 0.98163706,
#   'index': 304,
#   'word': '(',
#   'start': 1374,
#   'end': 1375},
#  {'entity': 'PERCENT',
#   'score': 0.9990721,
#   'index': 305,
#   'word': '88',
#   'start': 1375,
#   'end': 1377},
#  {'entity': 'PERCENT',
#   'score': 0.93654716,
#   'index': 306,
#   'word': '%',
#   'start': 1377,
#   'end': 1378},
#  {'entity': 'PERSON',
#   'score': 0.93604743,
#   'index': 307,
#   'word': ')',
#   'start': 1378,
#   'end': 1379},
#  {'entity': 'PERSON',
#   'score': 0.7323733,
#   'index': 308,
#   'word': 'из',
#   'start': 1380,
#   'end': 1382},
#  {'entity': 'NUMBER',
#   'score': 0.9884588,
#   'index': 309,
#   'word': '50',
#   'start': 1383,
#   'end': 1385},
#  {'entity': 'PERSON',
#   'score': 0.99938273,
#   'index': 310,
#   'word': 'пациентов',
#   'start': 1386,
#   'end': 1395},
#  {'entity': 'FINDING',
#   'score': 0.9219151,
#   'index': 311,
#   'word': 'диагноз',
#   'start': 1396,
#   'end': 1403},
#  {'entity': 'DISO',
#   'score': 0.999445,
#   'index': 312,
#   'word': 'БФ',
#   'start': 1404,
#   'end': 1406},
#  {'entity': 'FINDING',
#   'score': 0.7951115,
#   'index': 313,
#   'word': 'установлен',
#   'start': 1407,
#   'end': 1417},
#  {'entity': 'DATE',
#   'score': 0.27316287,
#   'index': 314,
#   'word': ',',
#   'start': 1417,
#   'end': 1418},
#  {'entity': 'DATE',
#   'score': 0.9798553,
#   'index': 315,
#   'word': 'в',
#   'start': 1419,
#   'end': 1420},
#  {'entity': 'DATE',
#   'score': 0.9351227,
#   'index': 316,
#   'word': 'среднем',
#   'start': 1421,
#   'end': 1428},
#  {'entity': 'DATE',
#   'score': 0.96439373,
#   'index': 317,
#   'word': ',',
#   'start': 1428,
#   'end': 1429},
#  {'entity': 'DATE',
#   'score': 0.99919015,
#   'index': 318,
#   'word': 'через',
#   'start': 1430,
#   'end': 1435},
#  {'entity': 'DATE',
#   'score': 0.9993057,
#   'index': 319,
#   'word': '1',
#   'start': 1436,
#   'end': 1437},
#  {'entity': 'DATE',
#   'score': 0.99792683,
#   'index': 320,
#   'word': 'год',
#   'start': 1438,
#   'end': 1441},
#  {'entity': 'DATE',
#   'score': 0.9653799,
#   'index': 321,
#   'word': '(',
#   'start': 1442,
#   'end': 1443},
#  {'entity': 'AGE',
#   'score': 0.6161637,
#   'index': 322,
#   'word': 'диапазон',
#   'start': 1443,
#   'end': 1451},
#  {'entity': 'AGE',
#   'score': 0.9512044,
#   'index': 323,
#   'word': 'от',
#   'start': 1452,
#   'end': 1454},
#  {'entity': 'AGE',
#   'score': 0.9937926,
#   'index': 324,
#   'word': '0',
#   'start': 1455,
#   'end': 1456},
#  {'entity': 'DATE',
#   'score': 0.9297915,
#   'index': 325,
#   'word': 'до',
#   'start': 1457,
#   'end': 1459},
#  {'entity': 'DATE',
#   'score': 0.8405525,
#   'index': 326,
#   'word': '12',
#   'start': 1460,
#   'end': 1462},
#  {'entity': 'AGE',
#   'score': 0.9546875,
#   'index': 327,
#   'word': 'лет',
#   'start': 1463,
#   'end': 1466},
#  {'entity': 'DATE',
#   'score': 0.69829607,
#   'index': 328,
#   'word': ')',
#   'start': 1466,
#   'end': 1467},
#  {'entity': 'DATE',
#   'score': 0.79550177,
#   'index': 329,
#   'word': 'после',
#   'start': 1468,
#   'end': 1473},
#  {'entity': 'MEDPROC',
#   'score': 0.99463356,
#   'index': 330,
#   'word': 'начала',
#   'start': 1474,
#   'end': 1480},
#  {'entity': 'MEDPROC',
#   'score': 0.9994531,
#   'index': 331,
#   'word': 'лечения',
#   'start': 1481,
#   'end': 1488},
#  {'entity': 'MEDPROC',
#   'score': 0.9995135,
#   'index': 332,
#   'word': 'программным',
#   'start': 1489,
#   'end': 1500},
#  {'entity': 'MEDPROC',
#   'score': 0.99937207,
#   'index': 333,
#   'word': 'гемо',
#   'start': 1501,
#   'end': 1505},
#  {'entity': 'MEDPROC',
#   'score': 0.99934584,
#   'index': 334,
#   'word': '##диа',
#   'start': 1505,
#   'end': 1508},
#  {'entity': 'MEDPROC',
#   'score': 0.99902046,
#   'index': 335,
#   'word': '##лиз',
#   'start': 1508,
#   'end': 1511},
#  {'entity': 'MEDPROC',
#   'score': 0.99918133,
#   'index': 336,
#   'word': '##ом',
#   'start': 1511,
#   'end': 1513},
#  {'entity': 'DATE',
#   'score': 0.47573373,
#   'index': 337,
#   'word': ',',
#   'start': 1513,
#   'end': 1514},
#  {'entity': 'DATE',
#   'score': 0.6136508,
#   'index': 338,
#   'word': 'в',
#   'start': 1515,
#   'end': 1516},
#  {'entity': 'DATE',
#   'score': 0.16714236,
#   'index': 339,
#   'word': 'том',
#   'start': 1517,
#   'end': 1520},
#  {'entity': 'NUMBER',
#   'score': 0.4234838,
#   'index': 340,
#   'word': 'числе',
#   'start': 1521,
#   'end': 1526},
#  {'entity': 'NUMBER',
#   'score': 0.32638633,
#   'index': 341,
#   'word': 'у',
#   'start': 1527,
#   'end': 1528},
#  {'entity': 'NUMBER',
#   'score': 0.9666876,
#   'index': 342,
#   'word': 'одного',
#   'start': 1529,
#   'end': 1535},
#  {'entity': 'PERSON',
#   'score': 0.99924797,
#   'index': 343,
#   'word': 'пациента',
#   'start': 1536,
#   'end': 1544},
#  {'entity': 'DATE',
#   'score': 0.35293847,
#   'index': 344,
#   'word': '–',
#   'start': 1545,
#   'end': 1546},
#  {'entity': 'MEDPROC',
#   'score': 0.93763775,
#   'index': 345,
#   'word': 'после',
#   'start': 1547,
#   'end': 1552},
#  {'entity': 'MEDPROC',
#   'score': 0.99952686,
#   'index': 346,
#   'word': 'трансплантации',
#   'start': 1553,
#   'end': 1567},
#  {'entity': 'ANATOMY',
#   'score': 0.999699,
#   'index': 347,
#   'word': 'почки',
#   'start': 1568,
#   'end': 1573},
#  {'entity': 'DATE',
#   'score': 0.13342421,
#   'index': 348,
#   'word': '.',
#   'start': 1573,
#   'end': 1574},
#  {'entity': 'PERSON',
#   'score': 0.91627216,
#   'index': 349,
#   'word': 'Среди',
#   'start': 1575,
#   'end': 1580},
#  {'entity': 'NUMBER',
#   'score': 0.98427343,
#   'index': 350,
#   'word': '44',
#   'start': 1581,
#   'end': 1583},
#  {'entity': 'PERSON',
#   'score': 0.9988201,
#   'index': 351,
#   'word': 'проба',
#   'start': 1584,
#   'end': 1589},
#  {'entity': 'PERSON',
#   'score': 0.9973634,
#   'index': 352,
#   'word': '##ндо',
#   'start': 1589,
#   'end': 1592},
#  {'entity': 'PERSON',
#   'score': 0.9964921,
#   'index': 353,
#   'word': '##в',
#   'start': 1592,
#   'end': 1593},
#  {'entity': 'PERSON',
#   'score': 0.94206727,
#   'index': 354,
#   'word': ',',
#   'start': 1593,
#   'end': 1594},
#  {'entity': 'PERSON',
#   'score': 0.6569641,
#   'index': 355,
#   'word': 'выявленных',
#   'start': 1595,
#   'end': 1605},
#  {'entity': 'MEDPROC',
#   'score': 0.8091746,
#   'index': 356,
#   'word': 'при',
#   'start': 1606,
#   'end': 1609},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.39119303,
#   'index': 357,
#   'word': 'всероссий',
#   'start': 1610,
#   'end': 1619},
#  {'entity': 'MEDPROC',
#   'score': 0.4890655,
#   'index': 358,
#   'word': '##ском',
#   'start': 1619,
#   'end': 1623},
#  {'entity': 'MEDPROC',
#   'score': 0.96640176,
#   'index': 359,
#   'word': 'диа',
#   'start': 1624,
#   'end': 1627},
#  {'entity': 'MEDPROC',
#   'score': 0.9418625,
#   'index': 360,
#   'word': '##лиз',
#   'start': 1627,
#   'end': 1630},
#  {'entity': 'MEDPROC',
#   'score': 0.4982186,
#   'index': 361,
#   'word': '##ном',
#   'start': 1630,
#   'end': 1633},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.81709415,
#   'index': 362,
#   'word': 'скрин',
#   'start': 1634,
#   'end': 1639},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.8484916,
#   'index': 363,
#   'word': '##инг',
#   'start': 1639,
#   'end': 1642},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.84353524,
#   'index': 364,
#   'word': '##е',
#   'start': 1642,
#   'end': 1643},
#  {'entity': 'SCIPROC',
#   'score': 0.44380918,
#   'index': 365,
#   'word': ',',
#   'start': 1643,
#   'end': 1644},
#  {'entity': 'MEDPROC',
#   'score': 0.69907,
#   'index': 366,
#   'word': 'проведен',
#   'start': 1645,
#   'end': 1653},
#  {'entity': 'SCIPROC',
#   'score': 0.3949827,
#   'index': 367,
#   'word': 'семейный',
#   'start': 1654,
#   'end': 1662},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.8482232,
#   'index': 368,
#   'word': 'скрин',
#   'start': 1663,
#   'end': 1668},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.50351024,
#   'index': 369,
#   'word': '##инг',
#   'start': 1668,
#   'end': 1671},
#  {'entity': 'MEDPROC',
#   'score': 0.12444801,
#   'index': 370,
#   'word': '.',
#   'start': 1671,
#   'end': 1672},
#  {'entity': 'DISO',
#   'score': 0.8474462,
#   'index': 371,
#   'word': 'Пато',
#   'start': 1673,
#   'end': 1677},
#  {'entity': 'PHYS',
#   'score': 0.4820364,
#   'index': 372,
#   'word': '##генная',
#   'start': 1677,
#   'end': 1683},
#  {'entity': 'PHYS',
#   'score': 0.9664729,
#   'index': 373,
#   'word': 'мутация',
#   'start': 1684,
#   'end': 1691},
#  {'entity': 'GENE',
#   'score': 0.9796535,
#   'index': 374,
#   'word': 'в',
#   'start': 1692,
#   'end': 1693},
#  {'entity': 'GENE',
#   'score': 0.9981439,
#   'index': 375,
#   'word': 'гене',
#   'start': 1694,
#   'end': 1698},
#  {'entity': 'GENE',
#   'score': 0.9955636,
#   'index': 376,
#   'word': 'GL',
#   'start': 1699,
#   'end': 1701},
#  {'entity': 'GENE',
#   'score': 0.99495584,
#   'index': 377,
#   'word': '##A',
#   'start': 1701,
#   'end': 1702},
#  {'entity': 'FINDING',
#   'score': 0.9865884,
#   'index': 378,
#   'word': 'диагности',
#   'start': 1703,
#   'end': 1712},
#  {'entity': 'FINDING',
#   'score': 0.9727595,
#   'index': 379,
#   'word': '##рована',
#   'start': 1712,
#   'end': 1718},
#  {'entity': 'FINDING',
#   'score': 0.5046862,
#   'index': 380,
#   'word': 'у',
#   'start': 1719,
#   'end': 1720},
#  {'entity': 'NUMBER',
#   'score': 0.84491986,
#   'index': 381,
#   'word': '89',
#   'start': 1721,
#   'end': 1723},
#  {'entity': 'PERCENT',
#   'score': 0.94310755,
#   'index': 382,
#   'word': '(',
#   'start': 1724,
#   'end': 1725},
#  {'entity': 'PERCENT',
#   'score': 0.99891186,
#   'index': 383,
#   'word': '57',
#   'start': 1725,
#   'end': 1727},
#  {'entity': 'PERCENT',
#   'score': 0.9329262,
#   'index': 384,
#   'word': '%',
#   'start': 1727,
#   'end': 1728},
#  {'entity': 'PERSON',
#   'score': 0.9342998,
#   'index': 385,
#   'word': ')',
#   'start': 1728,
#   'end': 1729},
#  {'entity': 'PERSON',
#   'score': 0.717152,
#   'index': 386,
#   'word': 'из',
#   'start': 1730,
#   'end': 1732},
#  {'entity': 'NUMBER',
#   'score': 0.97779274,
#   'index': 387,
#   'word': '156',
#   'start': 1733,
#   'end': 1736},
#  {'entity': 'PERSON',
#   'score': 0.9995552,
#   'index': 388,
#   'word': 'обследова',
#   'start': 1737,
#   'end': 1746},
#  {'entity': 'PERSON',
#   'score': 0.9995447,
#   'index': 389,
#   'word': '##нных',
#   'start': 1746,
#   'end': 1750},
#  {'entity': 'PERSON',
#   'score': 0.9996902,
#   'index': 390,
#   'word': 'родственников',
#   'start': 1751,
#   'end': 1764},
#  {'entity': 'PERSON',
#   'score': 0.86510825,
#   'index': 391,
#   'word': 'диа',
#   'start': 1765,
#   'end': 1768},
#  {'entity': 'PERSON',
#   'score': 0.9965609,
#   'index': 392,
#   'word': '##лиз',
#   'start': 1768,
#   'end': 1771},
#  {'entity': 'PERSON',
#   'score': 0.9994579,
#   'index': 393,
#   'word': '##ных',
#   'start': 1771,
#   'end': 1774},
#  {'entity': 'PERSON',
#   'score': 0.9992071,
#   'index': 394,
#   'word': 'проба',
#   'start': 1775,
#   'end': 1780},
#  {'entity': 'PERSON',
#   'score': 0.9981792,
#   'index': 395,
#   'word': '##ндо',
#   'start': 1780,
#   'end': 1783},
#  {'entity': 'PERSON',
#   'score': 0.9979323,
#   'index': 396,
#   'word': '##в',
#   'start': 1783,
#   'end': 1784},
#  {'entity': 'FINDING',
#   'score': 0.25313675,
#   'index': 397,
#   'word': ',',
#   'start': 1784,
#   'end': 1785},
#  {'entity': 'DATE',
#   'score': 0.21011667,
#   'index': 398,
#   'word': 'в',
#   'start': 1786,
#   'end': 1787},
#  {'entity': 'PERSON',
#   'score': 0.26789054,
#   'index': 399,
#   'word': 'том',
#   'start': 1788,
#   'end': 1791},
#  {'entity': 'PERSON',
#   'score': 0.46698472,
#   'index': 400,
#   'word': 'числе',
#   'start': 1792,
#   'end': 1797},
#  {'entity': 'DATE',
#   'score': 0.22633807,
#   'index': 401,
#   'word': 'у',
#   'start': 1798,
#   'end': 1799},
#  {'entity': 'NUMBER',
#   'score': 0.9884266,
#   'index': 402,
#   'word': '18',
#   'start': 1800,
#   'end': 1802},
#  {'entity': 'PERSON',
#   'score': 0.999241,
#   'index': 403,
#   'word': 'детей',
#   'start': 1803,
#   'end': 1808},
#  {'entity': 'AGE',
#   'score': 0.99929464,
#   'index': 404,
#   'word': 'моложе',
#   'start': 1809,
#   'end': 1815},
#  {'entity': 'AGE',
#   'score': 0.9991203,
#   'index': 405,
#   'word': '18',
#   'start': 1816,
#   'end': 1818},
#  {'entity': 'AGE',
#   'score': 0.9988462,
#   'index': 406,
#   'word': 'лет',
#   'start': 1819,
#   'end': 1822},
#  {'entity': 'FINDING',
#   'score': 0.9553363,
#   'index': 407,
#   'word': ',',
#   'start': 1822,
#   'end': 1823},
#  {'entity': 'DISO',
#   'score': 0.76749843,
#   'index': 408,
#   'word': 'клинические',
#   'start': 1824,
#   'end': 1835},
#  {'entity': 'DISO',
#   'score': 0.95167816,
#   'index': 409,
#   'word': 'проявления',
#   'start': 1836,
#   'end': 1846},
#  {'entity': 'DISO',
#   'score': 0.99963677,
#   'index': 410,
#   'word': 'БФ',
#   'start': 1847,
#   'end': 1849},
#  {'entity': 'FINDING',
#   'score': 0.9644548,
#   'index': 411,
#   'word': 'имелись',
#   'start': 1850,
#   'end': 1857},
#  {'entity': 'FINDING',
#   'score': 0.59477013,
#   'index': 412,
#   'word': 'у',
#   'start': 1858,
#   'end': 1859},
#  {'entity': 'NUMBER',
#   'score': 0.96870863,
#   'index': 413,
#   'word': '48',
#   'start': 1860,
#   'end': 1862},
#  {'entity': 'PERSON',
#   'score': 0.9993636,
#   'index': 414,
#   'word': 'родственников',
#   'start': 1863,
#   'end': 1876},
#  {'entity': 'DATE',
#   'score': 0.19658302,
#   'index': 415,
#   'word': '.',
#   'start': 1876,
#   'end': 1877},
#  {'entity': 'FINDING',
#   'score': 0.36532253,
#   'index': 416,
#   'word': 'У',
#   'start': 1878,
#   'end': 1879},
#  {'entity': 'PERCENT',
#   'score': 0.99970007,
#   'index': 417,
#   'word': '80',
#   'start': 1880,
#   'end': 1882},
#  {'entity': 'PERCENT',
#   'score': 0.99152476,
#   'index': 418,
#   'word': ',',
#   'start': 1882,
#   'end': 1883},
#  {'entity': 'PERCENT',
#   'score': 0.99582565,
#   'index': 419,
#   'word': '4',
#   'start': 1883,
#   'end': 1884},
#  {'entity': 'PERSON',
#   'score': 0.7482074,
#   'index': 420,
#   'word': '%',
#   'start': 1884,
#   'end': 1885},
#  {'entity': 'PERSON',
#   'score': 0.9997384,
#   'index': 421,
#   'word': 'обследова',
#   'start': 1886,
#   'end': 1895},
#  {'entity': 'PERSON',
#   'score': 0.9997496,
#   'index': 422,
#   'word': '##нных',
#   'start': 1895,
#   'end': 1899},
#  {'entity': 'PERSON',
#   'score': 0.99975806,
#   'index': 423,
#   'word': 'родственников',
#   'start': 1900,
#   'end': 1913},
#  {'entity': 'PERSON',
#   'score': 0.9890109,
#   'index': 424,
#   'word': 'диа',
#   'start': 1914,
#   'end': 1917},
#  {'entity': 'PERSON',
#   'score': 0.99621433,
#   'index': 425,
#   'word': '##лиз',
#   'start': 1917,
#   'end': 1920},
#  {'entity': 'PERSON',
#   'score': 0.99935025,
#   'index': 426,
#   'word': '##ных',
#   'start': 1920,
#   'end': 1923},
#  {'entity': 'PERSON',
#   'score': 0.9991115,
#   'index': 427,
#   'word': 'проба',
#   'start': 1924,
#   'end': 1929},
#  {'entity': 'PERSON',
#   'score': 0.9984426,
#   'index': 428,
#   'word': '##ндо',
#   'start': 1929,
#   'end': 1932},
#  {'entity': 'PERSON',
#   'score': 0.9975655,
#   'index': 429,
#   'word': '##в',
#   'start': 1932,
#   'end': 1933},
#  {'entity': 'FINDING',
#   'score': 0.9849332,
#   'index': 430,
#   'word': 'обнаружено',
#   'start': 1934,
#   'end': 1944},
#  {'entity': 'DISO',
#   'score': 0.89683276,
#   'index': 431,
#   'word': 'поражение',
#   'start': 1945,
#   'end': 1954},
#  {'entity': 'ANATOMY',
#   'score': 0.9996855,
#   'index': 432,
#   'word': 'почек',
#   'start': 1955,
#   'end': 1960},
#  {'entity': 'DISO',
#   'score': 0.8560027,
#   'index': 433,
#   'word': ',',
#   'start': 1960,
#   'end': 1961},
#  {'entity': 'DISO',
#   'score': 0.91883,
#   'index': 434,
#   'word': 'преимущественно',
#   'start': 1962,
#   'end': 1977},
#  {'entity': 'DISO',
#   'score': 0.78129596,
#   'index': 435,
#   'word': 'на',
#   'start': 1978,
#   'end': 1980},
#  {'entity': 'DISO',
#   'score': 0.76445293,
#   'index': 436,
#   'word': 'ранних',
#   'start': 1981,
#   'end': 1987},
#  {'entity': 'DISO',
#   'score': 0.9640115,
#   'index': 437,
#   'word': 'стадиях',
#   'start': 1988,
#   'end': 1995},
#  {'entity': 'ORDINAL',
#   'score': 0.17158568,
#   'index': 438,
#   'word': '.',
#   'start': 1995,
#   'end': 1996},
#  {'entity': 'PERSON',
#   'score': 0.21930045,
#   'index': 439,
#   'word': 'Заключение',
#   'start': 1997,
#   'end': 2007},
#  {'entity': 'MEDPROC',
#   'score': 0.31354722,
#   'index': 440,
#   'word': '.',
#   'start': 2007,
#   'end': 2008},
#  {'entity': 'DISO',
#   'score': 0.9996965,
#   'index': 441,
#   'word': 'Т',
#   'start': 2009,
#   'end': 2010},
#  {'entity': 'DISO',
#   'score': 0.9992893,
#   'index': 442,
#   'word': '##Х',
#   'start': 2010,
#   'end': 2011},
#  {'entity': 'DISO',
#   'score': 0.9980477,
#   'index': 443,
#   'word': '##П',
#   'start': 2011,
#   'end': 2012},
#  {'entity': 'DISO',
#   'score': 0.9991247,
#   'index': 444,
#   'word': '##Н',
#   'start': 2012,
#   'end': 2013},
#  {'entity': 'DISO',
#   'score': 0.99132335,
#   'index': 445,
#   'word': 'нередко',
#   'start': 2014,
#   'end': 2021},
#  {'entity': 'DISO',
#   'score': 0.9790699,
#   'index': 446,
#   'word': '##е',
#   'start': 2021,
#   'end': 2022},
#  {'entity': 'DISO',
#   'score': 0.99893755,
#   'index': 447,
#   'word': 'ослож',
#   'start': 2023,
#   'end': 2028},
#  {'entity': 'DISO',
#   'score': 0.9969199,
#   'index': 448,
#   'word': '##нение',
#   'start': 2028,
#   'end': 2033},
#  {'entity': 'DISO',
#   'score': 0.99965096,
#   'index': 449,
#   'word': 'БФ',
#   'start': 2034,
#   'end': 2036},
#  {'entity': 'DISO',
#   'score': 0.67188126,
#   'index': 450,
#   'word': ',',
#   'start': 2036,
#   'end': 2037},
#  {'entity': 'FINDING',
#   'score': 0.99622834,
#   'index': 451,
#   'word': 'ассоции',
#   'start': 2038,
#   'end': 2045},
#  {'entity': 'DISO',
#   'score': 0.6797378,
#   'index': 452,
#   'word': '##рованное',
#   'start': 2045,
#   'end': 2053},
#  {'entity': 'FINDING',
#   'score': 0.99520195,
#   'index': 453,
#   'word': 'с',
#   'start': 2054,
#   'end': 2055},
#  {'entity': 'FINDING',
#   'score': 0.997546,
#   'index': 454,
#   'word': 'неблагоприят',
#   'start': 2056,
#   'end': 2068},
#  {'entity': 'FINDING',
#   'score': 0.99337775,
#   'index': 455,
#   'word': '##ным',
#   'start': 2068,
#   'end': 2071},
#  {'entity': 'PHYS',
#   'score': 0.9529869,
#   'index': 456,
#   'word': 'прогнозом',
#   'start': 2072,
#   'end': 2081},
#  {'entity': 'ORDINAL',
#   'score': 0.1425359,
#   'index': 457,
#   'word': '.',
#   'start': 2081,
#   'end': 2082},
#  {'entity': 'FINDING',
#   'score': 0.8060666,
#   'index': 458,
#   'word': 'Однако',
#   'start': 2083,
#   'end': 2089},
#  {'entity': 'MEDPROC',
#   'score': 0.98108,
#   'index': 459,
#   'word': 'диа',
#   'start': 2090,
#   'end': 2093},
#  {'entity': 'MEDPROC',
#   'score': 0.9201804,
#   'index': 460,
#   'word': '##лиз',
#   'start': 2093,
#   'end': 2096},
#  {'entity': 'MEDPROC',
#   'score': 0.9604058,
#   'index': 461,
#   'word': '##ный',
#   'start': 2096,
#   'end': 2099},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.89397955,
#   'index': 462,
#   'word': 'скрин',
#   'start': 2100,
#   'end': 2105},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.8871753,
#   'index': 463,
#   'word': '##инг',
#   'start': 2105,
#   'end': 2108},
#  {'entity': 'FINDING',
#   'score': 0.9884879,
#   'index': 464,
#   'word': '–',
#   'start': 2109,
#   'end': 2110},
#  {'entity': 'FINDING',
#   'score': 0.99885595,
#   'index': 465,
#   'word': 'эффективный',
#   'start': 2112,
#   'end': 2123},
#  {'entity': 'FINDING',
#   'score': 0.989929,
#   'index': 466,
#   'word': 'способ',
#   'start': 2124,
#   'end': 2130},
#  {'entity': 'FINDING',
#   'score': 0.39059067,
#   'index': 467,
#   'word': 'выявления',
#   'start': 2131,
#   'end': 2140},
#  {'entity': 'PERSON',
#   'score': 0.99929535,
#   'index': 468,
#   'word': 'проба',
#   'start': 2141,
#   'end': 2146},
#  {'entity': 'PERSON',
#   'score': 0.9989937,
#   'index': 469,
#   'word': '##ндо',
#   'start': 2146,
#   'end': 2149},
#  {'entity': 'PERSON',
#   'score': 0.9979982,
#   'index': 470,
#   'word': '##в',
#   'start': 2149,
#   'end': 2150},
#  {'entity': 'DISO',
#   'score': 0.9760014,
#   'index': 471,
#   'word': 'с',
#   'start': 2151,
#   'end': 2152},
#  {'entity': 'DISO',
#   'score': 0.9996767,
#   'index': 472,
#   'word': 'БФ',
#   'start': 2153,
#   'end': 2155},
#  {'entity': 'FINDING',
#   'score': 0.99415624,
#   'index': 473,
#   'word': ',',
#   'start': 2155,
#   'end': 2156},
#  {'entity': 'FINDING',
#   'score': 0.99705553,
#   'index': 474,
#   'word': 'открываю',
#   'start': 2157,
#   'end': 2165},
#  {'entity': 'FINDING',
#   'score': 0.9973345,
#   'index': 475,
#   'word': '##щий',
#   'start': 2165,
#   'end': 2168},
#  {'entity': 'FINDING',
#   'score': 0.9681677,
#   'index': 476,
#   'word': 'возможность',
#   'start': 2169,
#   'end': 2180},
#  {'entity': 'FINDING',
#   'score': 0.8891164,
#   'index': 477,
#   'word': 'установить',
#   'start': 2181,
#   'end': 2191},
#  {'entity': 'DISO',
#   'score': 0.5644145,
#   'index': 478,
#   'word': 'диагноз',
#   'start': 2192,
#   'end': 2199},
#  {'entity': 'DISO',
#   'score': 0.99967873,
#   'index': 479,
#   'word': 'БФ',
#   'start': 2200,
#   'end': 2202},
#  {'entity': 'PERSON',
#   'score': 0.9035811,
#   'index': 480,
#   'word': 'у',
#   'start': 2203,
#   'end': 2204},
#  {'entity': 'PERSON',
#   'score': 0.9993755,
#   'index': 481,
#   'word': 'родственников',
#   'start': 2205,
#   'end': 2218},
#  {'entity': 'DISO',
#   'score': 0.30522335,
#   'index': 482,
#   'word': 'на',
#   'start': 2219,
#   'end': 2221},
#  {'entity': 'PHYS',
#   'score': 0.294804,
#   'index': 483,
#   'word': 'ранних',
#   'start': 2222,
#   'end': 2228},
#  {'entity': 'DISO',
#   'score': 0.8232675,
#   'index': 484,
#   'word': 'стадиях',
#   'start': 2229,
#   'end': 2236},
#  {'entity': 'FINDING',
#   'score': 0.8664123,
#   'index': 485,
#   'word': ',',
#   'start': 2236,
#   'end': 2237},
#  {'entity': 'FINDING',
#   'score': 0.8408099,
#   'index': 486,
#   'word': 'когда',
#   'start': 2238,
#   'end': 2243},
#  {'entity': 'MEDPROC',
#   'score': 0.9984939,
#   'index': 487,
#   'word': 'лечение',
#   'start': 2244,
#   'end': 2251},
#  {'entity': 'FINDING',
#   'score': 0.9972861,
#   'index': 488,
#   'word': 'наиболее',
#   'start': 2252,
#   'end': 2260},
#  {'entity': 'FINDING',
#   'score': 0.9959728,
#   'index': 489,
#   'word': 'эффективно',
#   'start': 2261,
#   'end': 2271},
#  {'entity': 'ORDINAL',
#   'score': 0.18444878,
#   'index': 490,
#   'word': '.',
#   'start': 2271,
#   'end': 2272}]
