# %% [markdown]
# <a href="https://colab.research.google.com/github/ekaterinatao/NER_biomed_domain/blob/main/active_learning/%D0%92%D0%9A%D0%A0_nerel_bio_RuBioBERT_active_learning_v3_acc_score.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Инструменты
# Предобработанный дасасет [NEREL-BIO](https://huggingface.co/datasets/ekaterinatao/nerel_bio_ner_unnested)
#
# Исходная модель [RuBioBERT](https://huggingface.co/alexyalunin/RuBioBERT)

# %% [markdown]
# ### Установка зависимостей

# %%
# !pip install datasets accelerate evaluate wandb seqeval -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 11.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 7.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 19.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 4.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 7.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 9.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 12.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.9/264.9 kB 14.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 27.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 41.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 29.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 893.2 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 10.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 3.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 11.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 50.8 MB/s eta 0:00:00
#   Building wheel for seqeval (setup.py) ... done

# %%
import numpy as np
import pandas as pd
import random
from dataclasses import dataclass
import torch
from torch.nn.functional import softmax
import datasets
from datasets import Dataset, DatasetDict, concatenate_datasets
from transformers import (AutoTokenizer,
                          DataCollatorForTokenClassification,
                          AutoModelForTokenClassification,
                          TrainingArguments, Trainer,
                          pipeline)
from transformers.trainer_utils import get_last_checkpoint
import evaluate

import warnings
warnings.filterwarnings("ignore")

# %%
@dataclass
class TrainingConfig:
    seed = 64
    dataset = 'ekaterinatao/nerel_bio_ner_unnested'
    checkpoint = 'alexyalunin/RuBioBERT'
    hf_repo_id = "ekaterinatao/nerel-bio-RuBioBERT-al"
    n_labels = 45
    n_epochs = 10
    train_batch_size = 4
    eval_batch_size = 4
    device = "cuda" if torch.cuda.is_available() else "cpu"
    l_rate = 5e-05
    w_decay = 0.1
    warm_up = 0.1
    run_name = "RuBioBERT_AL_v3_1"

config = TrainingConfig()

# %%
seed = config.seed

random.seed(seed)
np.random.seed(seed)

torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %% [markdown]
# ### Скачивание датасета

# %%
dataset = datasets.load_dataset(config.dataset)
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'words', 'ner_tags'],
#         num_rows: 612
#     })
#     valid: Dataset({
#         features: ['id', 'words', 'ner_tags'],
#         num_rows: 77
#     })
#     test: Dataset({
#         features: ['id', 'words', 'ner_tags'],
#         num_rows: 77
#     })
# })

# %%
# Labels
url = 'https://raw.githubusercontent.com/ekaterinatao/NER_biomed_domain/main/labels.txt'
tags = pd.read_csv(url, names=['tag']).values.tolist()
tags = [item for sublist in tags for item in sublist]
tag_to_id = {tag: i for i, tag in enumerate(tags)}
id_to_tag = {i: tag for i, tag in enumerate(tags)}

# %% [markdown]
# ___
# ### Токенизация

# %%
tokenizer = AutoTokenizer.from_pretrained(config.checkpoint)

# %%
def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(examples["words"], truncation=True, max_length=512, is_split_into_words=True)

    labels = []
    for i, label in enumerate(examples[f"ner_tags"]):
        word_idxs = tokenized_inputs.word_ids(batch_index=i)  # Map tokens to their respective word.
        previous_word_idx = None
        label_ids = []
        for word_idx in word_idxs:
            if word_idx is None:
                label_ids.append(-100) # Set the special tokens to -100.
            elif word_idx != previous_word_idx:  # Only label the first token of a given word.
                label_ids.append(label[word_idx])
            else:
                label_ids.append(-100)
            previous_word_idx = word_idx
        labels.append(label_ids)

    tokenized_inputs["labels"] = labels
    return tokenized_inputs

# %%
tokenized_dataset = dataset.map(
    tokenize_and_align_labels, batched=True,
    #remove_columns = ['id', 'words', 'ner_tags']
)
tokenized_dataset
# Out:
# Map:   0%|          | 0/77 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'words', 'ner_tags', 'input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 612
#     })
#     valid: Dataset({
#         features: ['id', 'words', 'ner_tags', 'input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 77
#     })
#     test: Dataset({
#         features: ['id', 'words', 'ner_tags', 'input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 77
#     })
# })

# %% [markdown]
# # Обучение модели

# %%
seqeval = evaluate.load("seqeval")

def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=2)

    true_predictions = [
        [tags[p] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]
    true_labels = [
        [tags[l] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]

    results = seqeval.compute(predictions=true_predictions, references=true_labels)
    return {
        "precision": results["overall_precision"],
        "recall": results["overall_recall"],
        "f1": results["overall_f1"],
        "accuracy": results["overall_accuracy"],
    }

# %%
def choose_samples_accuracy(test_predictions, n_tokens, test_dataset) -> np.ndarray:
    """Функция для реализации стратеги отбора примеров для разметки
    на основе доли правильно предсказанных тэгов"""

    predictions = np.argmax(test_predictions, axis=2)
    pred_tags = [
        [tags[p] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, test_dataset['labels'])
    ]
    real_tags = [
        [tags[l] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, test_dataset['labels'])
    ]
    scores = [
        sum([p == l for p, l in zip(prediction, label)]) / len(label)
        for prediction, label in zip(pred_tags, real_tags)
    ]
    args = np.argsort(scores)

    return args[:n_tokens]

# %%
data_collator = DataCollatorForTokenClassification(tokenizer=tokenizer)

# %%
model = AutoModelForTokenClassification.from_pretrained(
    config.checkpoint, num_labels=config.n_labels, id2label=id_to_tag, label2id=tag_to_id
)
# Out:
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at alexyalunin/RuBioBERT and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
print(f'device is {config.device}')
# Out:
# device is cuda

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
import wandb
wandb.login()
# Out:
# wandb: Currently logged in as: taoea. Use `wandb login --relogin` to force relogin
# True

# %%
import os
os.environ["WANDB_PROJECT"]="ner_bert_nerel_bio"

# %%
def train_and_predict(
    al_train_dataset, eval_dataset, al_test_dataset, test_dataset,
    model, tokenizer, data_collator, compute_metrics
):
    "Функция для тренировки модели, сохранения метрик и предсказаний"

    global config
    training_args = TrainingArguments(
        output_dir=config.hf_repo_id,
        num_train_epochs=config.n_epochs,
        learning_rate=config.l_rate,
        weight_decay=config.w_decay,
        warmup_ratio=config.warm_up,
        per_device_train_batch_size=config.train_batch_size,
        per_device_eval_batch_size=config.eval_batch_size,
        group_by_length=True,
        optim="adamw_torch",
        lr_scheduler_type="cosine",
        evaluation_strategy="epoch",
        seed = config.seed,
        data_seed = config.seed,
        push_to_hub=True,
        save_strategy="no",
        report_to="wandb",
        logging_steps=16,
        run_name=config.run_name,
    )
    metrics = {}
    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=al_train_dataset,
        eval_dataset=eval_dataset,
        tokenizer=tokenizer,
        data_collator=data_collator,
        compute_metrics=compute_metrics,
    )
    train_result = trainer.train()
    metrics['train_loss'] = train_result.metrics['train_loss']
    metrics.update(trainer.evaluate(eval_dataset))
    if al_test_dataset.num_rows > 0:
        al_test_predictions = trainer.predict(
            al_test_dataset, metric_key_prefix="pred"
        )
        probas = al_test_predictions.predictions
        metrics.update(al_test_predictions.metrics)
    else:
        probas = None
    test_predictions = trainer.predict(test_dataset, metric_key_prefix="test")
    metrics.update(test_predictions.metrics)

    return metrics, probas, trainer

# %%
def run_active_learning(
    dataset, al_iters, init_train_size, choose_tokens,
    model, tokenizer, data_collator, compute_metrics
):
    "Функция для реализации цикла активного обучения"

    train_dataset = dataset['train'].select(
        random.sample(
            range(dataset['train'].num_rows),
            int(dataset['train'].num_rows * init_train_size)
        )
    )
    test_dataset = dataset['train'].filter(
        lambda s: s['id'] not in train_dataset['id']
    )
    all_metrics = {}

    for iter in range(al_iters):
        train_size = train_dataset.num_rows
        print(f'\nIteration: {iter}. Training using {train_size} samples')

        eval_metrics, test_predictions, trainer = train_and_predict(
            train_dataset, dataset['valid'], test_dataset, dataset['test'],
            model, tokenizer, data_collator, compute_metrics
        )

        all_metrics[f'{iter}'] = {'train_size': train_size, 'metrics': eval_metrics}

        if test_dataset.num_rows >= choose_tokens:
            assert test_predictions is not None, "test_predictions is None, must be array"
            new_args = choose_samples_accuracy(test_predictions, choose_tokens, test_dataset)
            new_train_samples = test_dataset.select(new_args)
            extended_train_dataset = concatenate_datasets(
                [train_dataset, new_train_samples]
            )

            train_dataset = extended_train_dataset
            test_dataset = dataset['train'].filter(
                lambda s: s['id'] not in train_dataset['id']
            )

    return all_metrics, trainer

# %%
metrics, trainer = run_active_learning(
    dataset=tokenized_dataset, al_iters=21, init_train_size=0.053, choose_tokens=29,
    model=model, tokenizer=tokenizer,
    data_collator=data_collator, compute_metrics=compute_metrics
)
# Out:
# Iteration: 0. Training using 32 samples
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# Tracking run with wandb version 0.16.5
# Run data is saved locally in <code>/content/wandb/run-20240330_182338-vhy7vpx9</code>
# Syncing run <strong><a href='https://wandb.ai/taoea/ner_bert_nerel_bio/runs/vhy7vpx9/workspace' target="_blank">RuBioBERT_AL_v3_1</a></strong> to <a href='https://wandb.ai/taoea/ner_bert_nerel_bio' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/taoea/ner_bert_nerel_bio' target="_blank">https://wandb.ai/taoea/ner_bert_nerel_bio</a>
#  View run at <a href='https://wandb.ai/taoea/ner_bert_nerel_bio/runs/vhy7vpx9/workspace' target="_blank">https://wandb.ai/taoea/ner_bert_nerel_bio/runs/vhy7vpx9/workspace</a>
#     <div>
#
#       <progress value='80' max='80' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [80/80 00:18, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>3.158710</td>
#       <td>0.110070</td>
#       <td>0.033068</td>
#       <td>0.050857</td>
#       <td>0.189433</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.193900</td>
#       <td>2.667733</td>
#       <td>0.280090</td>
#       <td>0.145169</td>
#       <td>0.191226</td>
#       <td>0.332246</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.193900</td>
#       <td>2.152820</td>
#       <td>0.392949</td>
#       <td>0.287523</td>
#       <td>0.332069</td>
#       <td>0.484538</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.885600</td>
#       <td>1.701899</td>
#       <td>0.537736</td>
#       <td>0.481238</td>
#       <td>0.507921</td>
#       <td>0.629992</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.885600</td>
#       <td>1.506504</td>
#       <td>0.588412</td>
#       <td>0.552533</td>
#       <td>0.569908</td>
#       <td>0.684071</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.062400</td>
#       <td>1.396091</td>
#       <td>0.617433</td>
#       <td>0.576454</td>
#       <td>0.596240</td>
#       <td>0.703030</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.062400</td>
#       <td>1.313948</td>
#       <td>0.625792</td>
#       <td>0.602017</td>
#       <td>0.613674</td>
#       <td>0.716550</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.754500</td>
#       <td>1.285901</td>
#       <td>0.635892</td>
#       <td>0.604128</td>
#       <td>0.619603</td>
#       <td>0.720124</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.754500</td>
#       <td>1.270809</td>
#       <td>0.633810</td>
#       <td>0.603189</td>
#       <td>0.618121</td>
#       <td>0.720124</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.658200</td>
#       <td>1.267163</td>
#       <td>0.632538</td>
#       <td>0.602720</td>
#       <td>0.617269</td>
#       <td>0.719969</td>
#     </tr>
#   </tbody>
# </table><p>
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]
# Iteration: 1. Training using 61 samples
#     <div>
#
#       <progress value='160' max='160' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [160/160 00:25, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.359300</td>
#       <td>1.175120</td>
#       <td>0.664228</td>
#       <td>0.638837</td>
#       <td>0.651285</td>
#       <td>0.750583</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1
�▇▃▇▁▇▂▇▇▇▇▇▇▇█▇▃███▇█▇█▂▇▇▂█▇▂</td></tr><tr><td>eval/steps_per_second</td><td>██▇▇▃████▇▇▃▇▁▇▂▇▇▇▇▇▇▇█▇▃███▇█▇█▂▇▇▂█▇▂</td></tr><tr><td>train/epoch</td><td>█▃▄▄▃▁▇▅▂▇▃█▄█▄█▃▇▂▆▃▆▁▄▇▂▅█▂▅█▂▅█▂▅▇▂▄▇</td></tr><tr><td>train/global_step</td><td>▁▁▁▂▁▁▃▂▁▃▂▄▃▅▃▅▃▅▂▄▂▅▁▃▆▂▄▇▃▅▇▃▅▇▃▅▇▂▄█</td></tr><tr><td>train/grad_norm</td><td>█▂▂▃▄▁▂▂▆▁▄▁▂▁▂▁▂▃▃▁▁▆▁▁▃▁▁▂▆▁▄▁▁▁▁▁▁▄▁▁</td></tr><tr><td>train/learning_rate</td><td>▆█▂▇▆▆▂▄▇▃▇▂▇▁█▃█▅▁▆▃█▄▂█▃▁█▆▂█▆▂█▇▃▂█▅▁</td></tr><tr><td>train/loss</td><td>█▄▁▂▂▁▁▁▂▁▁▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/total_flos</td><td>▁▁▂▂▂▃▃▃▄▄▄▅▅▆▆▆▇▇▇██</td></tr><tr><td>train/train_loss</td><td>█▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/train_runtime</td><td>▁▁▂▂▂▃▃▃▄▄▄▅▅▆▆▆▇▇▇██</td></tr><tr><td>train/train_samples_per_second</td><td>▁▄▅▆▆▆▇▇▇▇▇▇▇████████</td></tr><tr><td>train/train_steps_per_second</td><td>▁▄▅▆▆▇▇▇▇▇▇▇▇████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>0.85144</td></tr><tr><td>eval/f1</td><td>0.78296</td></tr><tr><td>eval/loss</td><td>1.07908</td></tr><tr><td>eval/precision</td><td>0.77915</td></tr><tr><td>eval/recall</td><td>0.78682</td></tr><tr><td>eval/runtime</td><td>0.9679</td></tr><tr><td>eval/samples_per_second</td><td>79.556</td></tr><tr><td>eval/steps_per_second</td><td>20.664</td></tr><tr><td>train/epoch</td><td>10.0</td></tr><tr><td>train/global_step</td><td>1530</td></tr><tr><td>train/grad_norm</td><td>0.01313</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>train/loss</td><td>0.0015</td></tr><tr><td>train/total_flos</td><td>868512317261760.0</td></tr><tr><td>train/train_loss</td><td>0.00568</td></tr><tr><td>train/train_runtime</td><td>159.295</td></tr><tr><td>train/train_samples_per_second</td><td>38.419</td></tr><tr><td>train/train_steps_per_second</td><td>9.605</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">RuBioBERT_AL_v3_1</strong> at: <a href='https://wandb.ai/taoea/ner_bert_nerel_bio/runs/vhy7vpx9/workspace' target="_blank">https://wandb.ai/taoea/ner_bert_nerel_bio/runs/vhy7vpx9/workspace</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240330_182338-vhy7vpx9/logs</code>

# %%
metrics
# Out:
# {'0': {'train_size': 32,
#   'metrics': {'train_loss': 1.5109140276908875,
#    'eval_loss': 1.2671629190444946,
#    'eval_precision': 0.6325375338419886,
#    'eval_recall': 0.6027204502814258,
#    'eval_f1': 0.6172691245346462,
#    'eval_accuracy': 0.71996891996892,
#    'eval_runtime': 0.8805,
#    'eval_samples_per_second': 87.455,
#    'eval_steps_per_second': 22.715,
#    'epoch': 10.0,
#    'pred_loss': 1.0020442008972168,
#    'pred_precision': 0.6842626706709186,
#    'pred_recall': 0.6508717163387914,
#    'pred_f1': 0.6671496490830879,
#    'pred_accuracy': 0.7820673453406422,
#    'pred_runtime': 8.2713,
#    'pred_samples_per_second': 70.122,
#    'pred_steps_per_second': 17.53,
#    'test_loss': 1.2137835025787354,
#    'test_precision': 0.6519645120405577,
#    'test_recall': 0.6145758661887694,
#    'test_f1': 0.6327183271832719,
#    'test_accuracy': 0.7409452655514049,
#    'test_runtime': 0.8344,
#    'test_samples_per_second': 92.282,
#    'test_steps_per_second': 23.969}},
#  '1': {'train_size': 61,
#   'metrics': {'train_loss': 0.49822489023208616,
#    'eval_loss': 0.7945339679718018,
#    'eval_precision': 0.7504793863854267,
#    'eval_recall': 0.7342870544090057,
#    'eval_f1': 0.7422949265054528,
#    'eval_accuracy': 0.8212898212898213,
#    'eval_runtime': 0.8937,
#    'eval_samples_per_second': 86.155,
#    'eval_steps_per_second': 22.378,
#    'epoch': 10.0,
#    'pred_loss': 0.6767028570175171,
#    'pred_precision': 0.7599330427641968,
#    'pred_recall': 0.7427610051244058,
#    'pred_f1': 0.7512489072061946,
#    'pred_accuracy': 0.8504106776180698,
#    'pred_runtime': 7.8547,
#    'pred_samples_per_second': 70.149,
#    'pred_steps_per_second': 17.569,
#    'test_loss': 0.7452346682548523,
#    'test_precision': 0.7593984962406015,
#    'test_recall': 0.7481481481481481,
#    'test_f1': 0.753731343283582,
#    'test_accuracy': 0.83936982296573,
#    'test_runtime': 0.8565,
#    'test_samples_per_second': 89.906,
#    'test_steps_per_second': 23.352}},
#  '2': {'train_size': 90,
#   'metrics': {'train_loss': 0.17206377814645352,
#    'eval_loss': 0.7878968119621277,
#    'eval_precision': 0.764831009217679,
#    'eval_recall': 0.7589118198874296,
#    'eval_f1': 0.7618599175985875,
#    'eval_accuracy': 0.84009324009324,
#    'eval_runtime': 1.0368,
#    'eval_samples_per_second': 74.27,
#    'eval_steps_per_second': 19.291,
#    'epoch': 10.0,
#    'pred_loss': 0.6426048278808594,
#    'pred_precision': 0.7840518511244231,
#    'pred_recall': 0.7745440434613892,
#    'pred_f1': 0.7792689473427359,
#    'pred_accuracy': 0.8662937062937063,
#    'pred_runtime': 6.9224,
#    'pred_samples_per_second': 75.407,
#    'pred_steps_per_second': 18.924,
#    'test_loss': 0.7380275726318359,
#    'test_precision': 0.7738439306358381,
#    'test_recall': 0.7677419354838709,
#    'test_f1': 0.7707808564231737,
#    'test_accuracy': 0.8500893292187753,
#    'test_runtime': 0.8335,
#    'test_samples_per_second': 92.383,
#    'test_steps_per_second': 23.996}},
#  '3': {'train_size': 119,
#   'metrics': {'train_loss': 0.09929727762937546,
#    'eval_loss': 0.8144626617431641,
#    'eval_precision': 0.7631208997188379,
#    'eval_recall': 0.7638367729831145,
#    'eval_f1': 0.7634786685419598,
#    'eval_accuracy': 0.8427350427350427,
#    'eval_runtime': 0.9057,
#    'eval_samples_per_second': 85.014,
#    'eval_steps_per_second': 22.081,
#    'epoch': 10.0,
#    'pred_loss': 0.6227977871894836,
#    'pred_precision': 0.7979157227004984,
#    'pred_recall': 0.7874316376018987,
#    'pred_f1': 0.7926390139187036,
#    'pred_accuracy': 0.8783041029032773,
#    'pred_runtime': 6.5613,
#    'pred_samples_per_second': 75.138,
#    'pred_steps_per_second': 18.899,
#    'test_loss': 0.7814421057701111,
#    'test_precision': 0.7702865398507104,
#    'test_recall': 0.7643966547192353,
#    'test_f1': 0.7673302950347806,
#    'test_accuracy': 0.8486275783660874,
#    'test_runtime': 0.8411,
#    'test_samples_per_second': 91.551,
#    'test_steps_per_second': 23.779}},
#  '4': {'train_size': 148,
#   'metrics': {'train_loss': 0.06940460442187818,
#    'eval_loss': 0.8233525156974792,
#    'eval_precision': 0.7767171129220023,
#    'eval_recall': 0.7823639774859287,
#    'eval_f1': 0.7795303189624956,
#    'eval_accuracy': 0.8540792540792541,
#    'eval_runtime': 0.924,
#    'eval_samples_per_second': 83.33,
#    'eval_steps_per_second': 21.644,
#    'epoch': 10.0,
#    'pred_loss': 0.603242039680481,
#    'pred_precision': 0.8082827167310878,
#    'pred_recall': 0.8034322514544989,
#    'pred_f1': 0.8058501853415054,
#    'pred_accuracy': 0.8868276379840643,
#    'pred_runtime': 6.3518,
#    'pred_samples_per_second': 73.05,
#    'pred_steps_per_second': 18.263,
#    'test_loss': 0.7470006346702576,
#    'test_precision': 0.7838291746641075,
#    'test_recall': 0.7806451612903226,
#    'test_f1': 0.7822339279300851,
#    'test_accuracy': 0.8583725840506741,
#    'test_runtime': 0.8427,
#    'test_samples_per_second': 91.371,
#    'test_steps_per_second': 23.733}},
#  '5': {'train_size': 177,
#   'metrics': {'train_loss': 0.051393166615938145,
#    'eval_loss': 0.8456090092658997,
#    'eval_precision': 0.7720897615708275,
#    'eval_recall': 0.774624765478424,
#    'eval_f1': 0.7733551861390776,
#    'eval_accuracy': 0.8492618492618492,
#    'eval_runtime': 1.1347,
#    'eval_samples_per_second': 67.859,
#    'eval_steps_per_second': 17.626,
#    'epoch': 10.0,
#    'pred_loss': 0.5691261291503906,
#    'pred_precision': 0.8215139754596417,
#    'pred_recall': 0.8169343520973024,
#    'pred_f1': 0.8192177635308144,
#    'pred_accuracy': 0.8963691767379403,
#    'pred_runtime': 5.8859,
#    'pred_samples_per_second': 73.905,
#    'pred_steps_per_second': 18.519,
#    'test_loss': 0.768846869468689,
#    'test_precision': 0.7933094384707288,
#    'test_recall': 0.7933094384707288,
#    'test_f1': 0.7933094384707288,
#    'test_accuracy': 0.8638947539386065,
#    'test_runtime': 0.8328,
#    'test_samples_per_second': 92.455,
#    'test_steps_per_second': 24.014}},
#  '6': {'train_size': 206,
#   'metrics': {'train_loss': 0.04186553926780247,
#    'eval_loss': 0.8752738833427429,
#    'eval_precision': 0.7701575532900834,
#    'eval_recall': 0.7795497185741088,
#    'eval_f1': 0.7748251748251749,
#    'eval_accuracy': 0.8514374514374514,
#    'eval_runtime': 0.9213,
#    'eval_samples_per_second': 83.575,
#    'eval_steps_per_second': 21.708,
#    'epoch': 10.0,
#    'pred_loss': 0.5555117726325989,
#    'pred_precision': 0.8297558922558923,
#    'pred_recall': 0.8257245769810688,
#    'pred_f1': 0.8277353262238644,
#    'pred_accuracy': 0.9003581443127239,
#    'pred_runtime': 5.8694,
#    'pred_samples_per_second': 69.173,
#    'pred_steps_per_second': 17.378,
#    'test_loss': 0.8166986107826233,
#    'test_precision': 0.7883610451306413,
#    'test_recall': 0.7930704898446834,
#    'test_f1': 0.7907087552114354,
#    'test_accuracy': 0.86129608575605,
#    'test_runtime': 0.8458,
#    'test_samples_per_second': 91.041,
#    'test_steps_per_second': 23.647}},
#  '7': {'train_size': 235,
#   'metrics': {'train_loss': 0.031570910327767925,
#    'eval_loss': 0.9316156506538391,
#    'eval_precision': 0.7746446049871825,
#    'eval_recall': 0.7795497185741088,
#    'eval_f1': 0.7770894213909993,
#    'eval_accuracy': 0.8528360528360528,
#    'eval_runtime': 1.2321,
#    'eval_samples_per_second': 62.495,
#    'eval_steps_per_second': 16.233,
#    'epoch': 10.0,
#    'pred_loss': 0.5310630202293396,
#    'pred_precision': 0.8414279217826285,
#    'pred_recall': 0.8337313567341054,
#    'pred_f1': 0.8375619582192245,
#    'pred_accuracy': 0.9082196279819664,
#    'pred_runtime': 5.1113,
#    'pred_samples_per_second': 73.758,
#    'pred_steps_per_second': 18.586,
#    'test_loss': 0.8075730204582214,
#    'test_precision': 0.7907253269916765,
#    'test_recall': 0.7945041816009558,
#    'test_f1': 0.7926102502979736,
#    'test_accuracy': 0.8651940880298847,
#    'test_runtime': 0.8461,
#    'test_samples_per_second': 91.007,
#    'test_steps_per_second': 23.638}},
#  '8': {'train_size': 264,
#   'metrics': {'train_loss': 0.028207524603402073,
#    'eval_loss': 0.8580588102340698,
#    'eval_precision': 0.7830429732868758,
#    'eval_recall': 0.7905722326454033,
#    'eval_f1': 0.7867895903839421,
#    'eval_accuracy': 0.8560994560994561,
#    'eval_runtime': 0.9265,
#    'eval_samples_per_second': 83.109,
#    'eval_steps_per_second': 21.587,
#    'epoch': 10.0,
#    'pred_loss': 0.4967472553253174,
#    'pred_precision': 0.8511478647247593,
#    'pred_recall': 0.84601040337619,
#    'pred_f1': 0.848571358255605,
#    'pred_accuracy': 0.9149873647378993,
#    'pred_runtime': 4.8804,
#    'pred_samples_per_second': 71.306,
#    'pred_steps_per_second': 17.826,
#    'test_loss': 0.7469676733016968,
#    'test_precision': 0.8099904397705545,
#    'test_recall': 0.8097968936678615,
#    'test_f1': 0.8098936551559326,
#    'test_accuracy': 0.8775377618970278,
#    'test_runtime': 0.855,
#    'test_samples_per_second': 90.061,
#    'test_steps_per_second': 23.393}},
#  '9': {'train_size': 293,
#   'metrics': {'train_loss': 0.021974057637822085,
#    'eval_loss': 0.8775386810302734,
#    'eval_precision': 0.778675282714055,
#    'eval_recall': 0.7912757973733584,
#    'eval_f1': 0.7849249738280797,
#    'eval_accuracy': 0.8573426573426574,
#    'eval_runtime': 0.9079,
#    'eval_samples_per_second': 84.807,
#    'eval_steps_per_second': 22.028,
#    'epoch': 10.0,
#    'pred_loss': 0.48808953166007996,
#    'pred_precision': 0.8595639032815199,
#    'pred_recall': 0.8526152363616896,
#    'pred_f1': 0.8560754696696858,
#    'pred_accuracy': 0.9200296840766132,
#    'pred_runtime': 4.3125,
#    'pred_samples_per_second': 73.971,
#    'pred_steps_per_second': 18.551,
#    'test_loss': 0.7759624123573303,
#    'test_precision': 0.806766738146295,
#    'test_recall': 0.8090800477897252,
#    'test_f1': 0.8079217370555953,
#    'test_accuracy': 0.8749390937144713,
#    'test_runtime': 0.8567,
#    'test_samples_per_second': 89.881,
#    'test_steps_per_second': 23.346}},
#  '10': {'train_size': 322,
#   'metrics': {'train_loss': 0.018584527914630777,
#    'eval_loss': 0.9325570464134216,
#    'eval_precision': 0.7952737482452036,
#    'eval_recall': 0.7971388367729831,
#    'eval_f1': 0.7962052002810962,
#    'eval_accuracy': 0.8609168609168609,
#    'eval_runtime': 0.9379,
#    'eval_samples_per_second': 82.098,
#    'eval_steps_per_second': 21.324,
#    'epoch': 10.0,
#    'pred_loss': 0.4727185070514679,
#    'pred_precision': 0.8692174535904017,
#    'pred_recall': 0.858861692716013,
#    'pred_f1': 0.8640085439658242,
#    'pred_accuracy': 0.9255951225195138,
#    'pred_runtime': 3.8841,
#    'pred_samples_per_second': 74.662,
#    'pred_steps_per_second': 18.794,
#    'test_loss': 0.8501108288764954,
#    'test_precision': 0.7988974113135187,
#    'test_recall': 0.796415770609319,
#    'test_f1': 0.7976546607634318,
#    'test_accuracy': 0.8699041741107683,
#    'test_runtime': 0.857,
#    'test_samples_per_second': 89.847,
#    'test_steps_per_second': 23.337}},
#  '11': {'train_size': 351,
#   'metrics': {'train_loss': 0.017454954229337585,
#    'eval_loss': 0.8507005572319031,
#    'eval_precision': 0.793063583815029,
#    'eval_recall': 0.8044090056285178,
#    'eval_f1': 0.7986960065199675,
#    'eval_accuracy': 0.8668220668220669,
#    'eval_runtime': 0.9343,
#    'eval_samples_per_second': 82.418,
#    'eval_steps_per_second': 21.407,
#    'epoch': 10.0,
#    'pred_loss': 0.42977187037467957,
#    'pred_precision': 0.8812040133779264,
#    'pred_recall': 0.8706053396775046,
#    'pred_f1': 0.8758726148527359,
#    'pred_accuracy': 0.9327252985884907,
#    'pred_runtime': 4.3399,
#    'pred_samples_per_second': 60.14,
#    'pred_steps_per_second': 15.208,
#    'test_loss': 0.8207505345344543,
#    'test_precision': 0.8078665077473183,
#    'test_recall': 0.8097968936678615,
#    'test_f1': 0.8088305489260145,
#    'test_accuracy': 0.8757511775215202,
#    'test_runtime': 0.8925,
#    'test_samples_per_second': 86.27,
#    'test_steps_per_second': 22.408}},
#  '12': {'train_size': 380,
#   'metrics': {'train_loss': 0.016442672382844123,
#    'eval_loss': 0.9195043444633484,
#    'eval_precision': 0.7927738927738928,
#    'eval_recall': 0.7976078799249531,
#    'eval_f1': 0.7951835398643909,
#    'eval_accuracy': 0.8609168609168609,
#    'eval_runtime': 0.9093,
#    'eval_samples_per_second': 84.678,
#    'eval_steps_per_second': 21.994,
#    'epoch': 10.0,
#    'pred_loss': 0.41552191972732544,
#    'pred_precision': 0.8859875512372856,
#    'pred_recall': 0.8770005259598768,
#    'pred_f1': 0.8814711324245742,
#    'pred_accuracy': 0.9355970739422697,
#    'pred_runtime': 3.573,
#    'pred_samples_per_second': 64.931,
#    'pred_steps_per_second': 16.233,
#    'test_loss': 0.8287411332130432,
#    'test_precision': 0.8133524766690596,
#    'test_recall': 0.8121863799283154,
#    'test_f1': 0.8127690100430417,
#    'test_accuracy': 0.8793243462725353,
#    'test_runtime': 0.8541,
#    'test_samples_per_second': 90.156,
#    'test_steps_per_second': 23.417}},
#  '13': {'train_size': 409,
#   'metrics': {'train_loss': 0.013425432439007371,
#    'eval_loss': 0.9795480966567993,
#    'eval_precision': 0.7749077490774908,
#    'eval_recall': 0.7879924953095685,
#    'eval_f1': 0.7813953488372092,
#    'eval_accuracy': 0.8520590520590521,
#    'eval_runtime': 0.9126,
#    'eval_samples_per_second': 84.379,
#    'eval_steps_per_second': 21.917,
#    'epoch': 10.0,
#    'pred_loss': 0.4044598340988159,
#    'pred_precision': 0.8917823575062516,
#    'pred_recall': 0.8838560806768653,
#    'pred_f1': 0.8878015280281569,
#    'pred_accuracy': 0.9389587073608617,
#    'pred_runtime': 2.6744,
#    'pred_samples_per_second': 75.905,
#    'pred_steps_per_second': 19.07,
#    'test_loss': 0.8477356433868408,
#    'test_precision': 0.8145679600095216,
#    'test_recall': 0.8176821983273597,
#    'test_f1': 0.8161221082756976,
#    'test_accuracy': 0.8807860971252234,
#    'test_runtime': 0.8286,
#    'test_samples_per_second': 92.928,
#    'test_steps_per_second': 24.137}},
#  '14': {'train_size': 438,
#   'metrics': {'train_loss': 0.012753121747889302,
#    'eval_loss': 0.9292687773704529,
#    'eval_precision': 0.7887421820708825,
#    'eval_recall': 0.7985459662288931,
#    'eval_f1': 0.7936137979256497,
#    'eval_accuracy': 0.8602952602952603,
#    'eval_runtime': 0.8956,
#    'eval_samples_per_second': 85.972,
#    'eval_steps_per_second': 22.33,
#    'epoch': 10.0,
#    'pred_loss': 0.35505837202072144,
#    'pred_precision': 0.9033596437968022,
#    'pred_recall': 0.8968253968253969,
#    'pred_f1': 0.9000806614236742,
#    'pred_accuracy': 0.9446139559564871,
#    'pred_runtime': 2.2689,
#    'pred_samples_per_second': 76.69,
#    'pred_steps_per_second': 19.393,
#    'test_loss': 0.8495686650276184,
#    'test_precision': 0.8177257525083612,
#    'test_recall': 0.817921146953405,
#    'test_f1': 0.8178234380599688,
#    'test_accuracy': 0.8830599317849602,
#    'test_runtime': 0.8402,
#    'test_samples_per_second': 91.643,
#    'test_steps_per_second': 23.803}},
#  '15': {'train_size': 467,
#   'metrics': {'train_loss': 0.011906351171121494,
#    'eval_loss': 0.9208129048347473,
#    'eval_precision': 0.7929906542056074,
#    'eval_recall': 0.7959662288930581,
#    'eval_f1': 0.7944756554307116,
#    'eval_accuracy': 0.8623154623154623,
#    'eval_runtime': 0.9108,
#    'eval_samples_per_second': 84.54,
#    'eval_steps_per_second': 21.958,
#    'epoch': 10.0,
#    'pred_loss': 0.3226501941680908,
#    'pred_precision': 0.9111814089305268,
#    'pred_recall': 0.9042501811156726,
#    'pred_f1': 0.9077025634810012,
#    'pred_accuracy': 0.9495898701919249,
#    'pred_runtime': 1.8428,
#    'pred_samples_per_second': 78.683,
#    'pred_steps_per_second': 20.078,
#    'test_loss': 0.8338008522987366,
#    'test_precision': 0.8089780324737345,
#    'test_recall': 0.809557945041816,
#    'test_f1': 0.8092678848680283,
#    'test_accuracy': 0.8767256780899789,
#    'test_runtime': 0.8294,
#    'test_samples_per_second': 92.839,
#    'test_steps_per_second': 24.114}},
#  '16': {'train_size': 496,
#   'metrics': {'train_loss': 0.010535804226979494,
#    'eval_loss': 0.9785351157188416,
#    'eval_precision': 0.7769533967076281,
#    'eval_recall': 0.7858818011257036,
#    'eval_f1': 0.7813920951381602,
#    'eval_accuracy': 0.8543900543900544,
#    'eval_runtime': 0.9124,
#    'eval_samples_per_second': 84.391,
#    'eval_steps_per_second': 21.92,
#    'epoch': 10.0,
#    'pred_loss': 0.2833791673183441,
#    'pred_precision': 0.9220679012345679,
#    'pred_recall': 0.9131896683478526,
#    'pred_f1': 0.9176073101435921,
#    'pred_accuracy': 0.9557158601342551,
#    'pred_runtime': 1.4924,
#    'pred_samples_per_second': 77.725,
#    'pred_steps_per_second': 19.431,
#    'test_loss': 0.8506984114646912,
#    'test_precision': 0.8096836049856184,
#    'test_recall': 0.807168458781362,
#    'test_f1': 0.8084240756252244,
#    'test_accuracy': 0.8772129283742082,
#    'test_runtime': 0.859,
#    'test_samples_per_second': 89.643,
#    'test_steps_per_second': 23.284}},
#  '17': {'train_size': 525,
#   'metrics': {'train_loss': 0.00990333911401897,
#    'eval_loss': 1.0341355800628662,
#    'eval_precision': 0.7820542545791792,
#    'eval_recall': 0.7910412757973734,
#    'eval_f1': 0.7865220939722514,
#    'eval_accuracy': 0.855944055944056,
#    'eval_runtime': 0.918,
#    'eval_samples_per_second': 83.876,
#    'eval_steps_per_second': 21.786,
#    'epoch': 10.0,
#    'pred_loss': 0.2528599798679352,
#    'pred_precision': 0.92588769611891,
#    'pred_recall': 0.92,
#    'pred_f1': 0.9229344582776006,
#    'pred_accuracy': 0.9599894011658717,
#    'pred_runtime': 1.1532,
#    'pred_samples_per_second': 75.444,
#    'pred_steps_per_second': 19.078,
#    'test_loss': 0.8808549046516418,
#    'test_precision': 0.820863309352518,
#    'test_recall': 0.817921146953405,
#    'test_f1': 0.8193895870736085,
#    'test_accuracy': 0.882410264739321,
#    'test_runtime': 0.8605,
#    'test_samples_per_second': 89.487,
#    'test_steps_per_second': 23.243}},
#  '18': {'train_size': 554,
#   'metrics': {'train_loss': 0.00801820974652957,
#    'eval_loss': 1.0456159114837646,
#    'eval_precision': 0.7846723778652466,
#    'eval_recall': 0.7947936210131332,
#    'eval_f1': 0.789700570895957,
#    'eval_accuracy': 0.8587412587412587,
#    'eval_runtime': 0.9153,
#    'eval_samples_per_second': 84.129,
#    'eval_steps_per_second': 21.852,
#    'epoch': 10.0,
#    'pred_loss': 0.21417327225208282,
#    'pred_precision': 0.9415259537210757,
#    'pred_recall': 0.9316212871287128,
#    'pred_f1': 0.936547433903577,
#    'pred_accuracy': 0.9673804282569541,
#    'pred_runtime': 0.7652,
#    'pred_samples_per_second': 75.793,
#    'pred_steps_per_second': 19.602,
#    'test_loss': 0.9302597045898438,
#    'test_precision': 0.8077567632271966,
#    'test_recall': 0.8062126642771804,
#    'test_f1': 0.8069839751255681,
#    'test_accuracy': 0.8760760110443397,
#    'test_runtime': 0.8467,
#    'test_samples_per_second': 90.94,
#    'test_steps_per_second': 23.621}},
#  '19': {'train_size': 583,
#   'metrics': {'train_loss': 0.007450638191969045,
#    'eval_loss': 1.0591105222702026,
#    'eval_precision': 0.7832443722441401,
#    'eval_recall': 0.7915103189493433,
#    'eval_f1': 0.7873556514638983,
#    'eval_accuracy': 0.8553224553224553,
#    'eval_runtime': 0.9174,
#    'eval_samples_per_second': 83.929,
#    'eval_steps_per_second': 21.8,
#    'epoch': 10.0,
#    'pred_loss': 0.12956464290618896,
#    'pred_precision': 0.9560439560439561,
#    'pred_recall': 0.9541935483870968,
#    'pred_f1': 0.9551178559896675,
#    'pred_accuracy': 0.9752679307502061,
#    'pred_runtime': 0.3885,
#    'pred_samples_per_second': 74.637,
#    'pred_steps_per_second': 20.59,
#    'test_loss': 0.9196150898933411,
#    'test_precision': 0.8134777376654633,
#    'test_recall': 0.8076463560334528,
#    'test_f1': 0.8105515587529976,
#    'test_accuracy': 0.8751015104758811,
#    'test_runtime': 0.8389,
#    'test_samples_per_second': 91.783,
#    'test_steps_per_second': 23.84}},
#  '20': {'train_size': 612,
#   'metrics': {'train_loss': 0.0056783890002407135,
#    'eval_loss': 1.0790849924087524,
#    'eval_precision': 0.77914537854157,
#    'eval_recall': 0.7868198874296435,
#    'eval_f1': 0.7829638273045508,
#    'eval_accuracy': 0.8514374514374514,
#    'eval_runtime': 0.9679,
#    'eval_samples_per_second': 79.556,
#    'eval_steps_per_second': 20.664,
#    'epoch': 10.0,
#    'test_loss': 0.913298487663269,
#    'test_precision': 0.8146107784431138,
#    'test_recall': 0.8126642771804062,
#    'test_f1': 0.8136363636363637,
#    'test_accuracy': 0.8806236803638136,
#    'test_runtime': 0.9045,
#    'test_samples_per_second': 85.132,
#    'test_steps_per_second': 22.112}}}

# %%
import json
with open('/content/drive/MyDrive/data/VKR/metrics_accuracy.json', 'w') as file:
    json.dump(metrics, file)

# %% [markdown]
# ### Отчет об обучении [ссылка](https://api.wandb.ai/links/taoea/xjrs73qf)

# %% [markdown]
# ![image.png](data:image/png;base64,...)   ![image.png](data:image/png;base64,...)
