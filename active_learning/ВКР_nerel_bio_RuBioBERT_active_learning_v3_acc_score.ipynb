# %% [markdown]
# <a href="https://colab.research.google.com/github/ekaterinatao/NER_biomed_domain/blob/main/active_learning/%D0%92%D0%9A%D0%A0_nerel_bio_RuBioBERT_active_learning_v3_acc_score.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Инструменты
# Предобработанный дасасет [NEREL-BIO](https://huggingface.co/datasets/ekaterinatao/nerel_bio_ner_unnested)
#
# Исходная модель [RuBioBERT](https://huggingface.co/alexyalunin/RuBioBERT)

# %% [markdown]
# ### Установка зависимостей

# %%
# !pip install datasets accelerate evaluate wandb seqeval -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 8.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 12.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 14.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 11.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 kB 11.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 20.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 13.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 37.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 11.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 13.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 73.4 MB/s eta 0:00:00
#   Building wheel for seqeval (setup.py) ... done

# %%
import numpy as np
import pandas as pd
import random
from dataclasses import dataclass
import torch
from torch.nn.functional import softmax
import datasets
from datasets import Dataset, DatasetDict, concatenate_datasets
from transformers import (AutoTokenizer,
                          DataCollatorForTokenClassification,
                          AutoModelForTokenClassification,
                          TrainingArguments, Trainer,
                          pipeline)
from transformers.trainer_utils import get_last_checkpoint
import evaluate

import warnings
warnings.filterwarnings("ignore")

# %%
@dataclass
class TrainingConfig:
    seed = 64
    dataset = 'ekaterinatao/nerel_bio_ner_unnested'
    checkpoint = 'alexyalunin/RuBioBERT'
    hf_repo_id = "ekaterinatao/nerel-bio-RuBioBERT-al"
    n_labels = 45
    n_epochs = 10
    train_batch_size = 4
    eval_batch_size = 4
    device = "cuda" if torch.cuda.is_available() else "cpu"
    l_rate = 5e-05
    w_decay = 0.1
    warm_up = 0.1
    run_name = "RuBioBERT_AL_v3"

config = TrainingConfig()

# %%
seed = config.seed

random.seed(seed)
np.random.seed(seed)

torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %% [markdown]
# ### Скачивание датасета

# %%
dataset = datasets.load_dataset(config.dataset)
dataset
# Out:
# Downloading readme:   0%|          | 0.00/1.56k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/603k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/76.2k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/70.8k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/612 [00:00<?, ? examples/s]
# Generating valid split:   0%|          | 0/77 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/77 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'words', 'ner_tags'],
#         num_rows: 612
#     })
#     valid: Dataset({
#         features: ['id', 'words', 'ner_tags'],
#         num_rows: 77
#     })
#     test: Dataset({
#         features: ['id', 'words', 'ner_tags'],
#         num_rows: 77
#     })
# })

# %%
# Labels
url = 'https://raw.githubusercontent.com/ekaterinatao/NER_biomed_domain/main/labels.txt'
tags = pd.read_csv(url, names=['tag']).values.tolist()
tags = [item for sublist in tags for item in sublist]
tag_to_id = {tag: i for i, tag in enumerate(tags)}
id_to_tag = {i: tag for i, tag in enumerate(tags)}

# %% [markdown]
# ___
# ### Токенизация

# %%
tokenizer = AutoTokenizer.from_pretrained(config.checkpoint)
# Out:
# tokenizer_config.json:   0%|          | 0.00/413 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/1.78M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.75M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(examples["words"], truncation=True, max_length=512, is_split_into_words=True)

    labels = []
    for i, label in enumerate(examples[f"ner_tags"]):
        word_idxs = tokenized_inputs.word_ids(batch_index=i)  # Map tokens to their respective word.
        previous_word_idx = None
        label_ids = []
        for word_idx in word_idxs:
            if word_idx is None:
                label_ids.append(-100) # Set the special tokens to -100.
            elif word_idx != previous_word_idx:  # Only label the first token of a given word.
                label_ids.append(label[word_idx])
            else:
                label_ids.append(-100)
            previous_word_idx = word_idx
        labels.append(label_ids)

    tokenized_inputs["labels"] = labels
    return tokenized_inputs

# %%
tokenized_dataset = dataset.map(
    tokenize_and_align_labels, batched=True,
    #remove_columns = ['id', 'words', 'ner_tags']
)
tokenized_dataset
# Out:
# Map:   0%|          | 0/612 [00:00<?, ? examples/s]
# Map:   0%|          | 0/77 [00:00<?, ? examples/s]
# Map:   0%|          | 0/77 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'words', 'ner_tags', 'input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 612
#     })
#     valid: Dataset({
#         features: ['id', 'words', 'ner_tags', 'input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 77
#     })
#     test: Dataset({
#         features: ['id', 'words', 'ner_tags', 'input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 77
#     })
# })

# %% [markdown]
# # Обучение модели

# %%
seqeval = evaluate.load("seqeval")

def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=2)

    true_predictions = [
        [tags[p] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]
    true_labels = [
        [tags[l] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]

    results = seqeval.compute(predictions=true_predictions, references=true_labels)
    return {
        "precision": results["overall_precision"],
        "recall": results["overall_recall"],
        "f1": results["overall_f1"],
        "accuracy": results["overall_accuracy"],
    }
# Out:
# Downloading builder script:   0%|          | 0.00/6.34k [00:00<?, ?B/s]

# %%
def choose_samples_accuracy(test_predictions, n_tokens, test_dataset) -> np.ndarray:
    """Функция для реализации стратеги отбора примеров для разметки
    на основе доли правильно предсказанных тэгов"""

    predictions = np.argmax(test_predictions, axis=2)
    pred_tags = [
        [tags[p] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, test_dataset['labels'])
    ]
    real_tags = [
        [tags[l] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, test_dataset['labels'])
    ]
    scores = [
        sum([p == l for p, l in zip(prediction, label)]) / len(label)
        for prediction, label in zip(pred_tags, real_tags)
    ]
    args = np.argsort(scores)

    return args[:n_tokens]

# %%
data_collator = DataCollatorForTokenClassification(tokenizer=tokenizer)

# %%
model = AutoModelForTokenClassification.from_pretrained(
    config.checkpoint, num_labels=config.n_labels, id2label=id_to_tag, label2id=tag_to_id
)
# Out:
# config.json:   0%|          | 0.00/889 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at alexyalunin/RuBioBERT and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
print(f'device is {config.device}')
# Out:
# device is cuda

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
import wandb
wandb.login()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
import os
os.environ["WANDB_PROJECT"]="ner_bert_nerel_bio"

# %%
def train_and_predict(
    train_dataset, eval_dataset, test_dataset,
    model, tokenizer, data_collator, compute_metrics
):
    "Функция для тренировки модели, сохранения метрик и предсказаний"

    global config
    training_args = TrainingArguments(
        output_dir=config.hf_repo_id,
        num_train_epochs=config.n_epochs,
        learning_rate=config.l_rate,
        weight_decay=config.w_decay,
        warmup_ratio=config.warm_up,
        per_device_train_batch_size=config.train_batch_size,
        per_device_eval_batch_size=config.eval_batch_size,
        group_by_length=True,
        optim="adamw_torch",
        lr_scheduler_type="cosine",
        evaluation_strategy="epoch",
        seed = config.seed,
        data_seed = config.seed,
        push_to_hub=True,
        save_strategy="no",
        report_to="wandb",
        logging_steps=16,
        run_name=config.run_name,
    )

    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=eval_dataset,
        tokenizer=tokenizer,
        data_collator=data_collator,
        compute_metrics=compute_metrics,
    )

    train_result = trainer.train()
    test_predictions = trainer.predict(
        test_dataset, metric_key_prefix="pred"
    )
    metrics = {}
    metrics['train_loss'] = train_result.metrics['train_loss']
    metrics.update(trainer.evaluate(eval_dataset))
    metrics.update(test_predictions.metrics)
    probas = test_predictions.predictions

    return metrics, probas, trainer

# %%
def run_active_learning(
    dataset, al_iters, init_train_size, choose_tokens,
    model, tokenizer, data_collator, compute_metrics
):
    "Функция для реализации цикла активного обучения"

    train_dataset = dataset['train'].select(
        random.sample(
            range(dataset['train'].num_rows),
            int(dataset['train'].num_rows * init_train_size)
        )
    )
    test_dataset = dataset['train'].filter(
        lambda s: s['id'] not in train_dataset['id']
    )
    all_metrics = {}

    for iter in range(al_iters):
        train_size = train_dataset.num_rows
        print(f'Training using {train_size} samples')

        eval_metrics, test_predictions, trainer = train_and_predict(
            train_dataset, dataset['valid'], test_dataset,
            model, tokenizer, data_collator, compute_metrics
        )

        all_metrics[f'{iter}'] = {'metrics': eval_metrics, 'train_size': train_size}

        if test_dataset.num_rows >= choose_tokens:
            new_args = choose_samples_accuracy(test_predictions, choose_tokens, test_dataset)
            new_train_samples = test_dataset.select(new_args)
            extended_train_dataset = concatenate_datasets(
                [train_dataset, new_train_samples]
            )

            train_dataset = extended_train_dataset
            test_dataset = dataset['train'].filter(
                lambda s: s['id'] not in train_dataset['id']
            )

    return all_metrics, trainer

# %%
metrics, trainer = run_active_learning(
    dataset=tokenized_dataset, al_iters=10, init_train_size=0.1, choose_tokens=61,
    model=model, tokenizer=tokenizer,
    data_collator=data_collator, compute_metrics=compute_metrics
)
# Out:
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]
# Training using 61 samples
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# wandb: Currently logged in as: taoea. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.4
# Run data is saved locally in <code>/content/wandb/run-20240323_092642-1519b6jv</code>
# Syncing run <strong><a href='https://wandb.ai/taoea/ner_bert_nerel_bio/runs/1519b6jv' target="_blank">RuBioBERT_AL_v3</a></strong> to <a href='https://wandb.ai/taoea/ner_bert_nerel_bio' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/taoea/ner_bert_nerel_bio' target="_blank">https://wandb.ai/taoea/ner_bert_nerel_bio</a>
#  View run at <a href='https://wandb.ai/taoea/ner_bert_nerel_bio/runs/1519b6jv' target="_blank">https://wandb.ai/taoea/ner_bert_nerel_bio/runs/1519b6jv</a>
#     <div>
#
#       <progress value='160' max='160' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [160/160 00:26, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.385500</td>
#       <td>2.925789</td>
#       <td>0.049296</td>
#       <td>0.001642</td>
#       <td>0.003177</td>
#       <td>0.158042</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.267000</td>
#       <td>2.012529</td>
#       <td>0.420856</td>
#       <td>0.343574</td>
#       <td>0.378309</td>
#       <td>0.537685</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.350600</td>
#       <td>1.434593</td>
#       <td>0.603119</td>
#       <td>0.562383</td>
#       <td>0.582039</td>
#       <td>0.693551</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.860100</td>
#       <td>1.240490</td>
#       <td>0.645208</td>
#       <td>0.620544</td>
#       <td>0.632636</td>
#       <td>0.727894</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.663400</td>
#       <td>1.124020</td>
#       <td>0.660775</td>
#       <td>0.640009</td>
#       <td>0.650226</td>
#       <td>0.742191</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.472900</td>
#       <td>1.049967</td>
#       <td>0.691080</td>
#       <td>0.670497</td>
#       <td>0.680633</td>
#       <td>0.770319</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.396700</td>
#       <td>1.000270</td>
#       <td>0.703881</td>
#       <td>0.689024</td>
#       <td>0.696374</td>
#       <td>0.781974</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.322900</td>
#       <td>1.009882</td>
#       <td>0.695569</td>
#       <td>0.684803</td>
#       <td>0.690144</td>
#       <td>0.779021</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.295800</td>
#       <td>1.000625</td>
#       <td>0.702774</td>
#       <td>0.689259</td>
#       <td>0.695951</td>
#       <td>0.784771</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.282500</td>
#       <td>1.000039</td>
#       <td>0.702774</td>
#       <td>0.689259</td>
#       <td>0.695951</td>
#       <td>0.784771</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:00]
#     </div>
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]
# Training using 122 samples
#     <div>
#
#       <progress value='310' max='310' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [310/310 00:39, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.892500</td>
#       <td>0.862837</td>
#       <td>0.718928</td>
#       <td>0.710835</td>
#       <td>0.714858</td>
#       <td>0.801399</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.531600</td>
#       <td>0.761602</td>
#       <td>0.738276</td>
#       <td>0.731004</td>
#       <td>0.734622</td>
#       <td>0.818026</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.403200</td>
#       <td>0.688453</td>
#       <td>0.761600</td>
#       <td>0.754456</td>
#       <td>0.758011</td>
#       <td>0.835742</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.303700</td>
#       <td>0.711213</td>
#       <td>0.767887</td>
#       <td>0.762664</td>
#       <td>0.765267</td>
#       <td>0.838850</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.200600</td>
#       <td>0.718724</td>
#       <td>0.766745</td>
#       <td>0.762430</td>
#       <td>0.764581</td>
#       <td>0.840249</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.148800</td>
#       <td>0.732842</td>
#       <td>0.767589</td>
#       <td>0.767589</td>
#       <td>0.767589</td>
#       <td>0.842890</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.126200</td>
#       <td>0.728804</td>
#       <td>0.763418</td>
#       <td>0.760553</td>
#       <td>0.761983</td>
#       <td>0.840559</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.085600</td>
#       <td>0.737690</td>
#       <td>0.774817</td>
#       <td>0.770638</td>
#       <td>0.772722</td>
#       <td>0.846620</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.065800</td>
#       <td>0.737290</td>
#       <td>0.777096</td>
#       <td>0.771811</td>
#       <td>0.774444</td>
#       <td>0.847397</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.068600</td>
#       <td>0.737839</td>
#       <td>0.779064</td>
#       <td>0.773218</td>
#       <td>0.776130</td>
#       <td>0.848329</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:00]
#     </div>
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]
# Training using 183 samples
#     <div>
#
#       <progress value='460' max='460' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [460/460 00:54, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.366900</td>
#       <td>0.618802</td>
#       <td>0.763765</td>
#       <td>0.761257</td>
#       <td>0.762509</td>
#       <td>0.840559</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.224400</td>
#       <td>0.693709</td>
#       <td>0.762879</td>
#       <td>0.760553</td>
#       <td>0.761715</td>
#       <td>0.838228</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.155000</td>
#       <td>0.726641</td>
#       <td>0.761176</td>
#       <td>0.758677</td>
#       <td>0.759925</td>
#       <td>0.839627</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.162800</td>
#       <td>0.693101</td>
#       <td>0.766386</td>
#       <td>0.767824</td>
#       <td>0.767104</td>
#       <td>0.844444</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.090000</td>
#       <td>0.706359</td>
#       <td>0.769737</td>
#       <td>0.768293</td>
#       <td>0.769014</td>
#       <td>0.847242</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.064900</td>
#       <td>0.768746</td>
#       <td>0.765435</td>
#       <td>0.767589</td>
#       <td>0.766511</td>
#       <td>0.843357</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.043400</td>
#       <td>0.752074</td>
#       <td>0.771897</td>
#       <td>0.772983</td>
#       <td>0.772440</td>
#       <td>0.847086</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.029000</td>
#       <td>0.774639</td>
#       <td>0.774315</td>
#       <td>0.774859</td>
#       <td>0.774587</td>
#       <td>0.848019</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.022400</td>
#       <td>0.772168</td>
#       <td>0.773412</td>
#       <td>0.770872</td>
#       <td>0.772140</td>
#       <td>0.848174</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.024400</td>
#       <td>0.771453</td>
#       <td>0.772375</td>
#       <td>0.771107</td>
#       <td>0.771740</td>
#       <td>0.848019</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:00]
#     </div>
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]
# Training using 244 samples
#     <div>
#
#       <progress value='610' max='610' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [610/610 01:08, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.188200</td>
#       <td>0.654249</td>
#       <td>0.776551</td>
#       <td>0.775094</td>
#       <td>0.775822</td>
#       <td>0.851437</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.158800</td>
#       <td>0.694528</td>
#       <td>0.767561</td>
#       <td>0.771341</td>
#       <td>0.769447</td>
#       <td>0.845843</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.101700</td>
#       <td>0.715318</td>
#       <td>0.774224</td>
#       <td>0.777674</td>
#       <td>0.775945</td>
#       <td>0.850505</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.072100</td>
#       <td>0.724942</td>
#       <td>0.778665</td>
#       <td>0.777205</td>
#       <td>0.777934</td>
#       <td>0.851282</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.042600</td>
#       <td>0.729689</td>
#       <td>0.782813</td>
#       <td>0.781895</td>
#       <td>0.782354</td>
#       <td>0.854390</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.024200</td>
#       <td>0.739479</td>
#       <td>0.782791</td>
#       <td>0.789400</td>
#       <td>0.786081</td>
#       <td>0.857498</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.012000</td>
#       <td>0.757628</td>
#       <td>0.788271</td>
#       <td>0.784944</td>
#       <td>0.786604</td>
#       <td>0.857187</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.015800</td>
#       <td>0.766086</td>
#       <td>0.788340</td>
#       <td>0.789634</td>
#       <td>0.788987</td>
#       <td>0.857498</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.009100</td>
#       <td>0.774953</td>
#       <td>0.788106</td>
#       <td>0.789400</td>
#       <td>0.788752</td>
#       <td>0.857187</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.006400</td>
#       <td>0.776533</td>
#       <td>0.787035</td>
#       <td>0.788696</td>
#       <td>0.787865</td>
#       <td>0.856721</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:00]
#     </div>
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]
# Training using 305 samples
#     <div>
#
#       <progress value='770' max='770' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [770/770 01:23, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.171100</td>
#       <td>0.681767</td>
#       <td>0.778794</td>
#       <td>0.778612</td>
#       <td>0.778703</td>
#       <td>0.852370</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.101400</td>
#       <td>0.701981</td>
#       <td>0.785914</td>
#       <td>0.792917</td>
#       <td>0.789400</td>
#       <td>0.855944</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.083900</td>
#       <td>0.760848</td>
#       <td>0.766954</td>
#       <td>0.771811</td>
#       <td>0.769375</td>
#       <td>0.845998</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.049400</td>
#       <td>0.746608</td>
#       <td>0.779227</td>
#       <td>0.784709</td>
#       <td>0.781958</td>
#       <td>0.855012</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.032900</td>
#       <td>0.792578</td>
#       <td>0.780988</td>
#       <td>0.786116</td>
#       <td>0.783544</td>
#       <td>0.854856</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.026700</td>
#       <td>0.767220</td>
#       <td>0.783993</td>
#       <td>0.785647</td>
#       <td>0.784819</td>
#       <td>0.858741</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.014500</td>
#       <td>0.768825</td>
#       <td>0.792075</td>
#       <td>0.796904</td>
#       <td>0.794482</td>
#       <td>0.862471</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.008100</td>
#       <td>0.780437</td>
#       <td>0.790135</td>
#       <td>0.796435</td>
#       <td>0.793273</td>
#       <td>0.861849</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.005500</td>
#       <td>0.787321</td>
#       <td>0.793240</td>
#       <td>0.798077</td>
#       <td>0.795651</td>
#       <td>0.862626</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.004300</td>
#       <td>0.788893</td>
#       <td>0.793569</td>
#       <td>0.798780</td>
#       <td>0.796166</td>
#       <td>0.863092</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:00]
#     </div>
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]
# Training using 366 samples
#     <div>
#
#       <progress value='920' max='920' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [920/920 01:38, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.109300</td>
#       <td>0.729461</td>
#       <td>0.787985</td>
#       <td>0.790572</td>
#       <td>0.789277</td>
#       <td>0.857809</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.074900</td>
#       <td>0.699326</td>
#       <td>0.791520</td>
#       <td>0.792448</td>
#       <td>0.791984</td>
#       <td>0.861849</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.049800</td>
#       <td>0.646951</td>
#       <td>0.794303</td>
#       <td>0.797842</td>
#       <td>0.796069</td>
#       <td>0.865734</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.031400</td>
#       <td>0.793443</td>
#       <td>0.779641</td>
#       <td>0.774156</td>
#       <td>0.776889</td>
#       <td>0.851593</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.027000</td>
#       <td>0.754071</td>
#       <td>0.786079</td>
#       <td>0.794559</td>
#       <td>0.790296</td>
#       <td>0.860140</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.012100</td>
#       <td>0.770574</td>
#       <td>0.789981</td>
#       <td>0.787758</td>
#       <td>0.788868</td>
#       <td>0.861694</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.007400</td>
#       <td>0.794862</td>
#       <td>0.786048</td>
#       <td>0.790103</td>
#       <td>0.788070</td>
#       <td>0.859829</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.005100</td>
#       <td>0.809426</td>
#       <td>0.791034</td>
#       <td>0.794559</td>
#       <td>0.792793</td>
#       <td>0.862315</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.004100</td>
#       <td>0.809111</td>
#       <td>0.792532</td>
#       <td>0.796435</td>
#       <td>0.794479</td>
#       <td>0.863092</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.003800</td>
#       <td>0.809617</td>
#       <td>0.792202</td>
#       <td>0.795732</td>
#       <td>0.793963</td>
#       <td>0.863092</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:00]
#     </div>
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]
# Training using 427 samples
#     <div>
#
#       <progress value='1070' max='1070' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1070/1070 01:54, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.075000</td>
#       <td>0.674878</td>
#       <td>0.788993</td>
#       <td>0.790103</td>
#       <td>0.789548</td>
#       <td>0.860295</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.053300</td>
#       <td>0.798707</td>
#       <td>0.769698</td>
#       <td>0.772045</td>
#       <td>0.770870</td>
#       <td>0.847086</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.038300</td>
#       <td>0.786772</td>
#       <td>0.770571</td>
#       <td>0.788462</td>
#       <td>0.779413</td>
#       <td>0.853458</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.033400</td>
#       <td>0.776150</td>
#       <td>0.791774</td>
#       <td>0.790103</td>
#       <td>0.790938</td>
#       <td>0.862315</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.012100</td>
#       <td>0.761294</td>
#       <td>0.791570</td>
#       <td>0.801595</td>
#       <td>0.796551</td>
#       <td>0.864957</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.009700</td>
#       <td>0.790013</td>
#       <td>0.794943</td>
#       <td>0.803705</td>
#       <td>0.799300</td>
#       <td>0.866511</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.009400</td>
#       <td>0.797814</td>
#       <td>0.791832</td>
#       <td>0.795732</td>
#       <td>0.793777</td>
#       <td>0.863714</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.002600</td>
#       <td>0.786524</td>
#       <td>0.793377</td>
#       <td>0.797842</td>
#       <td>0.795603</td>
#       <td>0.865579</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.003700</td>
#       <td>0.793651</td>
#       <td>0.794824</td>
#       <td>0.799484</td>
#       <td>0.797147</td>
#       <td>0.866356</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.003100</td>
#       <td>0.795001</td>
#       <td>0.795243</td>
#       <td>0.799719</td>
#       <td>0.797474</td>
#       <td>0.866511</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:00]
#     </div>
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]
# Training using 488 samples
#     <div>
#
#       <progress value='1220' max='1220' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1220/1220 02:08, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.060300</td>
#       <td>0.829178</td>
#       <td>0.781827</td>
#       <td>0.784944</td>
#       <td>0.783382</td>
#       <td>0.855167</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.058900</td>
#       <td>0.763631</td>
#       <td>0.772134</td>
#       <td>0.777205</td>
#       <td>0.774661</td>
#       <td>0.851904</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.046800</td>
#       <td>0.779507</td>
#       <td>0.789251</td>
#       <td>0.788696</td>
#       <td>0.788974</td>
#       <td>0.860761</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.029200</td>
#       <td>0.846488</td>
#       <td>0.779940</td>
#       <td>0.789634</td>
#       <td>0.784757</td>
#       <td>0.855944</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.020100</td>
#       <td>0.882174</td>
#       <td>0.782313</td>
#       <td>0.782129</td>
#       <td>0.782221</td>
#       <td>0.854390</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.012500</td>
#       <td>0.873278</td>
#       <td>0.798126</td>
#       <td>0.799250</td>
#       <td>0.798688</td>
#       <td>0.864646</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.002500</td>
#       <td>0.832597</td>
#       <td>0.798733</td>
#       <td>0.798546</td>
#       <td>0.798640</td>
#       <td>0.866667</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.004000</td>
#       <td>0.846504</td>
#       <td>0.795885</td>
#       <td>0.798311</td>
#       <td>0.797096</td>
#       <td>0.866511</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.001000</td>
#       <td>0.856797</td>
#       <td>0.795285</td>
#       <td>0.799015</td>
#       <td>0.797146</td>
#       <td>0.866200</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.001900</td>
#       <td>0.856876</td>
#       <td>0.795470</td>
#       <td>0.799015</td>
#       <td>0.797239</td>
#       <td>0.866200</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:00]
#     </div>
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]
# Training using 549 samples
#     <div>
#
#       <progress value='1380' max='1380' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1380/1380 02:22, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.057400</td>
#       <td>0.765631</td>
#       <td>0.793737</td>
#       <td>0.790572</td>
#       <td>0.792151</td>
#       <td>0.864025</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.036500</td>
#       <td>0.921860</td>
#       <td>0.794914</td>
#       <td>0.791745</td>
#       <td>0.793326</td>
#       <td>0.859207</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.032800</td>
#       <td>0.901742</td>
#       <td>0.760725</td>
#       <td>0.777674</td>
#       <td>0.769106</td>
#       <td>0.843823</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.024500</td>
#       <td>0.876880</td>
#       <td>0.786493</td>
#       <td>0.794794</td>
#       <td>0.790622</td>
#       <td>0.860761</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.010100</td>
#       <td>0.874497</td>
#       <td>0.788873</td>
#       <td>0.794794</td>
#       <td>0.791822</td>
#       <td>0.860917</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.005800</td>
#       <td>0.890423</td>
#       <td>0.794734</td>
#       <td>0.799953</td>
#       <td>0.797335</td>
#       <td>0.864802</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.004400</td>
#       <td>0.951699</td>
#       <td>0.792105</td>
#       <td>0.795263</td>
#       <td>0.793681</td>
#       <td>0.861694</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.002300</td>
#       <td>0.951262</td>
#       <td>0.793980</td>
#       <td>0.798077</td>
#       <td>0.796023</td>
#       <td>0.863403</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.000600</td>
#       <td>0.954089</td>
#       <td>0.794687</td>
#       <td>0.799719</td>
#       <td>0.797195</td>
#       <td>0.863714</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000700</td>
#       <td>0.953952</td>
#       <td>0.795057</td>
#       <td>0.799719</td>
#       <td>0.797381</td>
#       <td>0.863714</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:00]
#     </div>
# Filter:   0%|          | 0/612 [00:00<?, ? examples/s]
# Training using 610 samples
#     <div>
#
#       <progress value='1530' max='1530' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1530/1530 02:35, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.041300</td>
#       <td>0.910394</td>
#       <td>0.789176</td>
#       <td>0.786585</td>
#       <td>0.787879</td>
#       <td>0.856099</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.021100</td>
#       <td>0.839491</td>
#       <td>0.790556</td>
#       <td>0.793152</td>
#       <td>0.791852</td>
#       <td>0.859829</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.027400</td>
#       <td>0.825306</td>
#       <td>0.786367</td>
#       <td>0.787289</td>
#       <td>0.786828</td>
#       <td>0.857809</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.015800</td>
#       <td>0.850739</td>
#       <td>0.795300</td>
#       <td>0.793621</td>
#       <td>0.794459</td>
#       <td>0.862471</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.010000</td>
#       <td>0.922433</td>
#       <td>0.791170</td>
#       <td>0.794325</td>
#       <td>0.792744</td>
#       <td>0.859363</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.003100</td>
#       <td>0.859136</td>
#       <td>0.806649</td>
#       <td>0.802298</td>
#       <td>0.804468</td>
#       <td>0.868065</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.002900</td>
#       <td>0.910564</td>
#       <td>0.800657</td>
#       <td>0.800657</td>
#       <td>0.800657</td>
#       <td>0.865268</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.001000</td>
#       <td>0.924482</td>
#       <td>0.798135</td>
#       <td>0.803002</td>
#       <td>0.800561</td>
#       <td>0.864802</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.000400</td>
#       <td>0.928383</td>
#       <td>0.800467</td>
#       <td>0.803471</td>
#       <td>0.801966</td>
#       <td>0.865113</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000900</td>
#       <td>0.928529</td>
#       <td>0.800280</td>
#       <td>0.803471</td>
#       <td>0.801872</td>
#       <td>0.865113</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:00]
#     </div>

# %%
wandb.finish()
# Out:
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>▁▆▇▇▇███████████████████████████████████</td></tr><tr><td>eval/f1</td><td>▁▆▇▇▇███████████████████████████████████</td></tr><tr><td>eval/loss</td><td>█▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▂▂▂▂▁▂▂▁▂▂▂▂▂▂▂▂▂▂▂</td></tr><tr><td>eval/precision</td><td>▁▆▇▇▇███████████████████████████████████</td></tr><tr><td>eval/recall</td><td>▁▆▇▇▇███████████████████████████████████</td></tr><tr><td>eval/runtime</td><td>▂▁▁▁▁▁▂▁▁▁▁▁▁▁▇▂▂▁▁▁▂▁▂█▂▂▁█▂▂▁█▁▁▂▁▁▂▇▁</td></tr><tr><td>eval/samples_per_second</td><td>▇███▇█▇███▇▇██▁▇▆██▇▇█▇▁▇▇▇▁▇▇▇▁██▇▇█▇▂█</td></tr><tr><td>eval/steps_per_second</td><td>▇███▇█▇███▇▇██▁▇▆██▇▇█▇▁▇▇▇▁▇▇▇▁██▆▇█▇▂█</td></tr><tr><td>train/epoch</td><td>▄▂▅▂▄▇▃▅▇▂▄▆█▂▄▆▇▂▃▅▆█▂▃▄▆▇▁▂▃▅▆▇█▂▃▄▅▆█</td></tr><tr><td>train/global_step</td><td>▁▁▂▁▂▃▂▃▃▁▂▃▄▂▃▄▅▁▂▃▅▆▂▃▄▅▆▁▂▃▄▅▆▇▂▃▄▅▆█</td></tr><tr><td>train/grad_norm</td><td>▅▅▆█▃▂▄▂▆▄▁▄▂▃▁▂▃▁▁▁▁▆▂▁▁▂▁▇▇▅▁▁▁▅▄▁▄▆▁▁</td></tr><tr><td>train/learning_rate</td><td>▂▇█▆▁▆▄▂▇▅▁█▇▄▃▁█▇▄▂▁█▆▅▃▁▃█▇▅▃▂▁██▆▅▄▂▁</td></tr><tr><td>train/loss</td><td>▇██▄▁▂▁▃▂▁▁▂▂▁▁▁▂▂▁▁▁▂▂▁▁▁▂▁▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/total_flos</td><td>▁▂▃▃▄▅▆▇▇█</td></tr><tr><td>train/train_loss</td><td>█▃▂▁▁▁▁▁▁▁</td></tr><tr><td>train/train_runtime</td><td>▁▁▂▃▄▅▆▇▇█</td></tr><tr><td>train/train_samples_per_second</td><td>▁▅▆▇▇▇▇███</td></tr><tr><td>train/train_steps_per_second</td><td>▁▅▆▇▇▇▇▇██</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>0.86511</td></tr><tr><td>eval/f1</td><td>0.80187</td></tr><tr><td>eval/loss</td><td>0.92853</td></tr><tr><td>eval/precision</td><td>0.80028</td></tr><tr><td>eval/recall</td><td>0.80347</td></tr><tr><td>eval/runtime</td><td>0.9094</td></tr><tr><td>eval/samples_per_second</td><td>84.67</td></tr><tr><td>eval/steps_per_second</td><td>21.992</td></tr><tr><td>train/epoch</td><td>10.0</td></tr><tr><td>train/global_step</td><td>1530</td></tr><tr><td>train/grad_norm</td><td>0.00555</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>train/loss</td><td>0.0009</td></tr><tr><td>train/total_flos</td><td>865533805724340.0</td></tr><tr><td>train/train_loss</td><td>0.01002</td></tr><tr><td>train/train_runtime</td><td>155.6053</td></tr><tr><td>train/train_samples_per_second</td><td>39.202</td></tr><tr><td>train/train_steps_per_second</td><td>9.833</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">RuBioBERT_AL_v3</strong> at: <a href='https://wandb.ai/taoea/ner_bert_nerel_bio/runs/1519b6jv' target="_blank">https://wandb.ai/taoea/ner_bert_nerel_bio/runs/1519b6jv</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240323_092642-1519b6jv/logs</code>

# %%
metrics
# Out:
# {'0': {'metrics': {'train_loss': 1.0297480553388596,
#    'eval_loss': 1.0000391006469727,
#    'eval_precision': 0.7027737924438068,
#    'eval_recall': 0.6892589118198874,
#    'eval_f1': 0.6959507459152261,
#    'eval_accuracy': 0.7847707847707848,
#    'eval_runtime': 0.8848,
#    'eval_samples_per_second': 87.028,
#    'eval_steps_per_second': 22.605,
#    'epoch': 10.0,
#    'pred_loss': 0.7819056510925293,
#    'pred_precision': 0.7273767885532592,
#    'pred_recall': 0.7065291247143122,
#    'pred_f1': 0.7168014037726389,
#    'pred_accuracy': 0.8206197854588796,
#    'pred_runtime': 6.9011,
#    'pred_samples_per_second': 79.843,
#    'pred_steps_per_second': 19.997},
#   'train_size': 61},
#  '1': {'metrics': {'train_loss': 0.280717154472105,
#    'eval_loss': 0.737838864326477,
#    'eval_precision': 0.7790642722117203,
#    'eval_recall': 0.773217636022514,
#    'eval_f1': 0.7761299435028248,
#    'eval_accuracy': 0.8483294483294483,
#    'eval_runtime': 0.8975,
#    'eval_samples_per_second': 85.795,
#    'eval_steps_per_second': 22.284,
#    'epoch': 10.0,
#    'pred_loss': 0.5893173813819885,
#    'pred_precision': 0.789895665569638,
#    'pred_recall': 0.7851400730816078,
#    'pred_f1': 0.7875106899139571,
#    'pred_accuracy': 0.8742797879695783,
#    'pred_runtime': 6.0746,
#    'pred_samples_per_second': 80.664,
#    'pred_steps_per_second': 20.248},
#   'train_size': 122},
#  '2': {'metrics': {'train_loss': 0.12239772593197615,
#    'eval_loss': 0.7714526057243347,
#    'eval_precision': 0.7723749119097957,
#    'eval_recall': 0.7711069418386491,
#    'eval_f1': 0.7717404060556273,
#    'eval_accuracy': 0.848018648018648,
#    'eval_runtime': 0.889,
#    'eval_samples_per_second': 86.615,
#    'eval_steps_per_second': 22.497,
#    'epoch': 10.0,
#    'pred_loss': 0.5337297916412354,
#    'pred_precision': 0.8236618812080267,
#    'pred_recall': 0.8157884255386944,
#    'pred_f1': 0.8197062472485693,
#    'pred_accuracy': 0.8959608966441542,
#    'pred_runtime': 5.293,
#    'pred_samples_per_second': 81.051,
#    'pred_steps_per_second': 20.404},
#   'train_size': 183},
#  '3': {'metrics': {'train_loss': 0.07019776925139251,
#    'eval_loss': 0.7765334248542786,
#    'eval_precision': 0.7870348701146735,
#    'eval_recall': 0.7886960600375235,
#    'eval_f1': 0.7878645894342274,
#    'eval_accuracy': 0.8567210567210567,
#    'eval_runtime': 0.9008,
#    'eval_samples_per_second': 85.477,
#    'eval_steps_per_second': 22.202,
#    'epoch': 10.0,
#    'pred_loss': 0.48065534234046936,
#    'pred_precision': 0.843560287662277,
#    'pred_recall': 0.8351749965324333,
#    'pred_f1': 0.8393466998118161,
#    'pred_accuracy': 0.9096793893129771,
#    'pred_runtime': 5.1317,
#    'pred_samples_per_second': 71.711,
#    'pred_steps_per_second': 17.928},
#   'train_size': 244},
#  '4': {'metrics': {'train_loss': 0.04641841920576506,
#    'eval_loss': 0.7888930439949036,
#    'eval_precision': 0.793569431500466,
#    'eval_recall': 0.7987804878048781,
#    'eval_f1': 0.796166432912576,
#    'eval_accuracy': 0.8630924630924631,
#    'eval_runtime': 0.9198,
#    'eval_samples_per_second': 83.716,
#    'eval_steps_per_second': 21.744,
#    'epoch': 10.0,
#    'pred_loss': 0.430457204580307,
#    'pred_precision': 0.8624950850980172,
#    'pred_recall': 0.8555270782259862,
#    'pred_f1': 0.858996951134234,
#    'pred_accuracy': 0.9215216910952346,
#    'pred_runtime': 3.7492,
#    'pred_samples_per_second': 81.884,
#    'pred_steps_per_second': 20.538},
#   'train_size': 305},
#  '5': {'metrics': {'train_loss': 0.03385218148646147,
#    'eval_loss': 0.8096169233322144,
#    'eval_precision': 0.7922017277609152,
#    'eval_recall': 0.7957317073170732,
#    'eval_f1': 0.793962793962794,
#    'eval_accuracy': 0.8630924630924631,
#    'eval_runtime': 0.9227,
#    'eval_samples_per_second': 83.454,
#    'eval_steps_per_second': 21.676,
#    'epoch': 10.0,
#    'pred_loss': 0.39870545268058777,
#    'pred_precision': 0.8777589134125636,
#    'pred_recall': 0.8689684151551229,
#    'pred_f1': 0.8733415449586487,
#    'pred_accuracy': 0.9306789413118527,
#    'pred_runtime': 3.0312,
#    'pred_samples_per_second': 81.155,
#    'pred_steps_per_second': 20.454},
#   'train_size': 366},
#  '6': {'metrics': {'train_loss': 0.026681044978028704,
#    'eval_loss': 0.7950012683868408,
#    'eval_precision': 0.7952425373134329,
#    'eval_recall': 0.799718574108818,
#    'eval_f1': 0.7974742750233864,
#    'eval_accuracy': 0.8665112665112665,
#    'eval_runtime': 0.9025,
#    'eval_samples_per_second': 85.323,
#    'eval_steps_per_second': 22.162,
#    'epoch': 10.0,
#    'pred_loss': 0.33053717017173767,
#    'pred_precision': 0.8950634966103314,
#    'pred_recall': 0.889205084424208,
#    'pred_f1': 0.8921246728527243,
#    'pred_accuracy': 0.9417433474260134,
#    'pred_runtime': 2.3626,
#    'pred_samples_per_second': 78.303,
#    'pred_steps_per_second': 19.893},
#   'train_size': 427},
#  '7': {'metrics': {'train_loss': 0.021636163099615482,
#    'eval_loss': 0.8568755388259888,
#    'eval_precision': 0.7954704646275975,
#    'eval_recall': 0.799015009380863,
#    'eval_f1': 0.7972387972387972,
#    'eval_accuracy': 0.8662004662004662,
#    'eval_runtime': 0.8768,
#    'eval_samples_per_second': 87.824,
#    'eval_steps_per_second': 22.812,
#    'epoch': 10.0,
#    'pred_loss': 0.2854444980621338,
#    'pred_precision': 0.9067571555030982,
#    'pred_recall': 0.9028940796239165,
#    'pred_f1': 0.9048214942951784,
#    'pred_accuracy': 0.9505736137667304,
#    'pred_runtime': 1.4527,
#    'pred_samples_per_second': 85.361,
#    'pred_steps_per_second': 21.34},
#   'train_size': 488},
#  '8': {'metrics': {'train_loss': 0.015087803609945907,
#    'eval_loss': 0.9539515376091003,
#    'eval_precision': 0.7950571228724644,
#    'eval_recall': 0.799718574108818,
#    'eval_f1': 0.7973810358938384,
#    'eval_accuracy': 0.8637140637140637,
#    'eval_runtime': 0.8995,
#    'eval_samples_per_second': 85.604,
#    'eval_steps_per_second': 22.235,
#    'epoch': 10.0,
#    'pred_loss': 0.19890588521957397,
#    'pred_precision': 0.9394923258559622,
#    'pred_recall': 0.9320644216691069,
#    'pred_f1': 0.9357636336910188,
#    'pred_accuracy': 0.9675847854599963,
#    'pred_runtime': 0.6952,
#    'pred_samples_per_second': 90.62,
#    'pred_steps_per_second': 23.014},
#   'train_size': 549},
#  '9': {'metrics': {'train_loss': 0.01001789163177212,
#    'eval_loss': 0.928528904914856,
#    'eval_precision': 0.8002803083391731,
#    'eval_recall': 0.8034709193245778,
#    'eval_f1': 0.8018724400234055,
#    'eval_accuracy': 0.8651126651126652,
#    'eval_runtime': 0.9094,
#    'eval_samples_per_second': 84.67,
#    'eval_steps_per_second': 21.992,
#    'epoch': 10.0,
#    'pred_loss': 0.0008994060917757452,
#    'pred_precision': 1.0,
#    'pred_recall': 1.0,
#    'pred_f1': 1.0,
#    'pred_accuracy': 1.0,
#    'pred_runtime': 0.0369,
#    'pred_samples_per_second': 54.187,
#    'pred_steps_per_second': 27.094},
#   'train_size': 610}}

# %% [markdown]
# ### Отчет об обучении [ссылка](https://api.wandb.ai/links/taoea/xjrs73qf)

# %% [markdown]
# ![image.png](data:image/png;base64,...)   ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Оценка качества на тестовой выборке

# %%
predictions = trainer.predict(test_dataset=tokenized_dataset["test"])

# %%
predictions.metrics
# Out:
# {'test_loss': 0.7905441522598267,
#  'test_precision': 0.8297616181073922,
#  'test_recall': 0.8234169653524492,
#  'test_f1': 0.8265771168145839,
#  'test_accuracy': 0.8877700178658438,
#  'test_runtime': 1.1864,
#  'test_samples_per_second': 64.901,
#  'test_steps_per_second': 16.857}

# %% [markdown]
# Оценка модели на абстракте, которого не было в тестовом наборе

# %%
ner_bio = pipeline("ner", model=model, tokenizer=tokenizer, device=config.device)

# %%
abstract = """Цель. Оценить выживаемость у пациентов с болезнью Фабри (БФ) в зависимости от вида заместительной почечной терапии, и определить роль диализного скрининга в ранней диагностике БФ у родственников.
Материалы и методы. В исследование включали взрослых (старше 18 лет) пациентов с подтвержденным диагнозом БФ. Терминальная стадия хронической почечной недостаточности (тХПН) диагностировали в соответствии с рекомендациями Научного общества нефрологов России (2016) и KDIGO (2012). На основании опроса пробандов выявляли его родственников, которые могли унаследовать мутантный ген.
Результаты. У 50 (24,9%) из 201 обследованных пациентов с БФ диагностирована тХПН, в том числе у 48 (40%) из 120 мужчин и 2 (2,7%) из 81 женщин. Оценка кумулятивной частоты методом Каплана-Майера демонстрирует выраженное увеличение частоты регистрации тХПН к возрасту 20-30 лет, а к возрасту 50 лет ожидаемое количество пациентов с тХПН составляет 95%. Пяти из 50 больных с тХПН была выполнена трансплантация почки, в среднем, через 17 месяцев (диапазон от 7 до 70 месяцев) после инициации лечения гемодиализом. Умерло 15 (30%) из 50 пациентов, получавших лечение гемодиализом. Все умершие пациенты были мужского пола. Медиана возраста на момент летального исхода составила 45 (39; 58) лет. Среди пациентов, которым проведена трансплантация почки, летальных исходов зарегистрировано не было. У 44 (88%) из 50 пациентов диагноз БФ установлен, в среднем, через 1 год (диапазон от 0 до 12 лет) после начала лечения программным гемодиализом, в том числе у одного пациента – после трансплантации почки. Среди 44 пробандов, выявленных при всероссийском диализном скрининге, проведен семейный скрининг. Патогенная мутация в гене GLA диагностирована у 89 (57%) из 156 обследованных родственников диализных пробандов, в том числе у 18 детей моложе 18 лет, клинические проявления БФ имелись у 48 родственников. У 80,4% обследованных родственников диализных пробандов обнаружено поражение почек, преимущественно на ранних стадиях.
Заключение. ТХПН нередкое осложнение БФ, ассоциированное с неблагоприятным прогнозом. Однако диализный скрининг –  эффективный способ выявления пробандов с БФ, открывающий возможность установить диагноз БФ у родственников на ранних стадиях, когда лечение наиболее эффективно.
"""

# %%
ner_bio(abstract)
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# [{'entity': 'DATE',
#   'score': 0.2442471,
#   'index': 1,
#   'word': 'Цель',
#   'start': 0,
#   'end': 4},
#  {'entity': 'SCIPROC',
#   'score': 0.5220004,
#   'index': 2,
#   'word': '.',
#   'start': 4,
#   'end': 5},
#  {'entity': 'SCIPROC',
#   'score': 0.7540705,
#   'index': 3,
#   'word': 'Оцени',
#   'start': 6,
#   'end': 11},
#  {'entity': 'SCIPROC',
#   'score': 0.5385823,
#   'index': 4,
#   'word': '##ть',
#   'start': 11,
#   'end': 13},
#  {'entity': 'PHYS',
#   'score': 0.9912661,
#   'index': 5,
#   'word': 'выжи',
#   'start': 14,
#   'end': 18},
#  {'entity': 'PHYS',
#   'score': 0.9951473,
#   'index': 6,
#   'word': '##ваемость',
#   'start': 18,
#   'end': 26},
#  {'entity': 'PERSON',
#   'score': 0.77325106,
#   'index': 7,
#   'word': 'у',
#   'start': 27,
#   'end': 28},
#  {'entity': 'PERSON',
#   'score': 0.99989057,
#   'index': 8,
#   'word': 'пациентов',
#   'start': 29,
#   'end': 38},
#  {'entity': 'DISO',
#   'score': 0.9990433,
#   'index': 9,
#   'word': 'с',
#   'start': 39,
#   'end': 40},
#  {'entity': 'DISO',
#   'score': 0.9998499,
#   'index': 10,
#   'word': 'болезнью',
#   'start': 41,
#   'end': 49},
#  {'entity': 'PERSON',
#   'score': 0.94577104,
#   'index': 11,
#   'word': 'Фабри',
#   'start': 50,
#   'end': 55},
#  {'entity': 'DISO',
#   'score': 0.5139892,
#   'index': 12,
#   'word': '(',
#   'start': 56,
#   'end': 57},
#  {'entity': 'DISO',
#   'score': 0.9999031,
#   'index': 13,
#   'word': 'БФ',
#   'start': 57,
#   'end': 59},
#  {'entity': 'PERSON',
#   'score': 0.38036144,
#   'index': 14,
#   'word': ')',
#   'start': 59,
#   'end': 60},
#  {'entity': 'DATE',
#   'score': 0.84629995,
#   'index': 15,
#   'word': 'в',
#   'start': 61,
#   'end': 62},
#  {'entity': 'FINDING',
#   'score': 0.4896314,
#   'index': 16,
#   'word': 'зависимости',
#   'start': 63,
#   'end': 74},
#  {'entity': 'FINDING',
#   'score': 0.4301569,
#   'index': 17,
#   'word': 'от',
#   'start': 75,
#   'end': 77},
#  {'entity': 'MEDPROC',
#   'score': 0.8913818,
#   'index': 18,
#   'word': 'вида',
#   'start': 78,
#   'end': 82},
#  {'entity': 'MEDPROC',
#   'score': 0.9998128,
#   'index': 19,
#   'word': 'заместитель',
#   'start': 83,
#   'end': 94},
#  {'entity': 'MEDPROC',
#   'score': 0.99974614,
#   'index': 20,
#   'word': '##ной',
#   'start': 94,
#   'end': 97},
#  {'entity': 'MEDPROC',
#   'score': 0.9995402,
#   'index': 21,
#   'word': 'почечной',
#   'start': 98,
#   'end': 106},
#  {'entity': 'MEDPROC',
#   'score': 0.99975854,
#   'index': 22,
#   'word': 'терапии',
#   'start': 107,
#   'end': 114},
#  {'entity': 'MEDPROC',
#   'score': 0.4460316,
#   'index': 23,
#   'word': ',',
#   'start': 114,
#   'end': 115},
#  {'entity': 'SCIPROC',
#   'score': 0.6321978,
#   'index': 24,
#   'word': 'и',
#   'start': 116,
#   'end': 117},
#  {'entity': 'SCIPROC',
#   'score': 0.54269165,
#   'index': 25,
#   'word': 'определить',
#   'start': 118,
#   'end': 128},
#  {'entity': 'FINDING',
#   'score': 0.98370576,
#   'index': 26,
#   'word': 'роль',
#   'start': 129,
#   'end': 133},
#  {'entity': 'MEDPROC',
#   'score': 0.94885725,
#   'index': 27,
#   'word': 'диа',
#   'start': 134,
#   'end': 137},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.85268754,
#   'index': 28,
#   'word': '##лиз',
#   'start': 137,
#   'end': 140},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.8311412,
#   'index': 29,
#   'word': '##ного',
#   'start': 140,
#   'end': 144},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.9994886,
#   'index': 30,
#   'word': 'скрин',
#   'start': 145,
#   'end': 150},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.9964301,
#   'index': 31,
#   'word': '##инга',
#   'start': 150,
#   'end': 154},
#  {'entity': 'FINDING',
#   'score': 0.9981774,
#   'index': 32,
#   'word': 'в',
#   'start': 155,
#   'end': 156},
#  {'entity': 'FINDING',
#   'score': 0.98823315,
#   'index': 33,
#   'word': 'ранней',
#   'start': 157,
#   'end': 163},
#  {'entity': 'MEDPROC',
#   'score': 0.80329937,
#   'index': 34,
#   'word': 'диагностике',
#   'start': 164,
#   'end': 175},
#  {'entity': 'DISO',
#   'score': 0.9999113,
#   'index': 35,
#   'word': 'БФ',
#   'start': 176,
#   'end': 178},
#  {'entity': 'PERSON',
#   'score': 0.80503416,
#   'index': 36,
#   'word': 'у',
#   'start': 179,
#   'end': 180},
#  {'entity': 'PERSON',
#   'score': 0.99984145,
#   'index': 37,
#   'word': 'родственников',
#   'start': 181,
#   'end': 194},
#  {'entity': 'FINDING',
#   'score': 0.23653474,
#   'index': 38,
#   'word': '.',
#   'start': 194,
#   'end': 195},
#  {'entity': 'SCIPROC',
#   'score': 0.51419294,
#   'index': 39,
#   'word': 'Материалы',
#   'start': 196,
#   'end': 205},
#  {'entity': 'SCIPROC',
#   'score': 0.3677065,
#   'index': 40,
#   'word': 'и',
#   'start': 206,
#   'end': 207},
#  {'entity': 'SCIPROC',
#   'score': 0.3075853,
#   'index': 41,
#   'word': 'методы',
#   'start': 208,
#   'end': 214},
#  {'entity': 'FINDING',
#   'score': 0.43152666,
#   'index': 42,
#   'word': '.',
#   'start': 214,
#   'end': 215},
#  {'entity': 'SCIPROC',
#   'score': 0.48899075,
#   'index': 43,
#   'word': 'В',
#   'start': 216,
#   'end': 217},
#  {'entity': 'SCIPROC',
#   'score': 0.9688418,
#   'index': 44,
#   'word': 'исследование',
#   'start': 218,
#   'end': 230},
#  {'entity': 'PERSON',
#   'score': 0.40156063,
#   'index': 45,
#   'word': 'включали',
#   'start': 231,
#   'end': 239},
#  {'entity': 'PERSON',
#   'score': 0.99984837,
#   'index': 46,
#   'word': 'взрослых',
#   'start': 240,
#   'end': 248},
#  {'entity': 'AGE',
#   'score': 0.78349733,
#   'index': 47,
#   'word': '(',
#   'start': 249,
#   'end': 250},
#  {'entity': 'AGE',
#   'score': 0.9997954,
#   'index': 48,
#   'word': 'старше',
#   'start': 250,
#   'end': 256},
#  {'entity': 'AGE',
#   'score': 0.999716,
#   'index': 49,
#   'word': '18',
#   'start': 257,
#   'end': 259},
#  {'entity': 'AGE',
#   'score': 0.9985447,
#   'index': 50,
#   'word': 'лет',
#   'start': 260,
#   'end': 263},
#  {'entity': 'PERSON',
#   'score': 0.9979534,
#   'index': 51,
#   'word': ')',
#   'start': 263,
#   'end': 264},
#  {'entity': 'PERSON',
#   'score': 0.99991393,
#   'index': 52,
#   'word': 'пациентов',
#   'start': 265,
#   'end': 274},
#  {'entity': 'FINDING',
#   'score': 0.9121183,
#   'index': 53,
#   'word': 'с',
#   'start': 275,
#   'end': 276},
#  {'entity': 'FINDING',
#   'score': 0.9084145,
#   'index': 54,
#   'word': 'подтвержден',
#   'start': 277,
#   'end': 288},
#  {'entity': 'FINDING',
#   'score': 0.55951446,
#   'index': 55,
#   'word': '##ным',
#   'start': 288,
#   'end': 291},
#  {'entity': 'DISO',
#   'score': 0.92379814,
#   'index': 56,
#   'word': 'диагнозом',
#   'start': 292,
#   'end': 301},
#  {'entity': 'DISO',
#   'score': 0.9999095,
#   'index': 57,
#   'word': 'БФ',
#   'start': 302,
#   'end': 304},
#  {'entity': 'FINDING',
#   'score': 0.5126273,
#   'index': 58,
#   'word': '.',
#   'start': 304,
#   'end': 305},
#  {'entity': 'DISO',
#   'score': 0.99989927,
#   'index': 59,
#   'word': 'Терминал',
#   'start': 306,
#   'end': 314},
#  {'entity': 'DISO',
#   'score': 0.9998621,
#   'index': 60,
#   'word': '##ь',
#   'start': 314,
#   'end': 315},
#  {'entity': 'DISO',
#   'score': 0.99987745,
#   'index': 61,
#   'word': '##ная',
#   'start': 315,
#   'end': 318},
#  {'entity': 'DISO',
#   'score': 0.9998419,
#   'index': 62,
#   'word': 'стадия',
#   'start': 319,
#   'end': 325},
#  {'entity': 'DISO',
#   'score': 0.99990976,
#   'index': 63,
#   'word': 'хронической',
#   'start': 326,
#   'end': 337},
#  {'entity': 'DISO',
#   'score': 0.9994165,
#   'index': 64,
#   'word': 'почечной',
#   'start': 338,
#   'end': 346},
#  {'entity': 'DISO',
#   'score': 0.9998135,
#   'index': 65,
#   'word': 'недостаточности',
#   'start': 347,
#   'end': 362},
#  {'entity': 'DISO',
#   'score': 0.99453366,
#   'index': 66,
#   'word': '(',
#   'start': 363,
#   'end': 364},
#  {'entity': 'DISO',
#   'score': 0.9999025,
#   'index': 67,
#   'word': 'т',
#   'start': 364,
#   'end': 365},
#  {'entity': 'DISO',
#   'score': 0.9998802,
#   'index': 68,
#   'word': '##Х',
#   'start': 365,
#   'end': 366},
#  {'entity': 'DISO',
#   'score': 0.99982435,
#   'index': 69,
#   'word': '##П',
#   'start': 366,
#   'end': 367},
#  {'entity': 'DISO',
#   'score': 0.99973124,
#   'index': 70,
#   'word': '##Н',
#   'start': 367,
#   'end': 368},
#  {'entity': 'DISO',
#   'score': 0.6151482,
#   'index': 71,
#   'word': ')',
#   'start': 368,
#   'end': 369},
#  {'entity': 'MEDPROC',
#   'score': 0.93546546,
#   'index': 72,
#   'word': 'диагностировали',
#   'start': 370,
#   'end': 385},
#  {'entity': 'DATE',
#   'score': 0.46141836,
#   'index': 73,
#   'word': 'в',
#   'start': 386,
#   'end': 387},
#  {'entity': 'SCIPROC',
#   'score': 0.4356496,
#   'index': 74,
#   'word': 'соответствии',
#   'start': 388,
#   'end': 400},
#  {'entity': 'SCIPROC',
#   'score': 0.9547877,
#   'index': 75,
#   'word': 'с',
#   'start': 401,
#   'end': 402},
#  {'entity': 'SCIPROC',
#   'score': 0.9912384,
#   'index': 76,
#   'word': 'рекомендациями',
#   'start': 403,
#   'end': 417},
#  {'entity': 'ORGANIZATION',
#   'score': 0.9997367,
#   'index': 77,
#   'word': 'Научного',
#   'start': 418,
#   'end': 426},
#  {'entity': 'ORGANIZATION',
#   'score': 0.99961555,
#   'index': 78,
#   'word': 'общества',
#   'start': 427,
#   'end': 435},
#  {'entity': 'PROFESSION',
#   'score': 0.8360256,
#   'index': 79,
#   'word': 'неф',
#   'start': 436,
#   'end': 439},
#  {'entity': 'PROFESSION',
#   'score': 0.9889443,
#   'index': 80,
#   'word': '##рол',
#   'start': 439,
#   'end': 442},
#  {'entity': 'PROFESSION',
#   'score': 0.9968689,
#   'index': 81,
#   'word': '##ого',
#   'start': 442,
#   'end': 445},
#  {'entity': 'PROFESSION',
#   'score': 0.9832109,
#   'index': 82,
#   'word': '##в',
#   'start': 445,
#   'end': 446},
#  {'entity': 'COUNTRY',
#   'score': 0.9999225,
#   'index': 83,
#   'word': 'России',
#   'start': 447,
#   'end': 453},
#  {'entity': 'DATE',
#   'score': 0.99271953,
#   'index': 84,
#   'word': '(',
#   'start': 454,
#   'end': 455},
#  {'entity': 'DATE',
#   'score': 0.99457765,
#   'index': 85,
#   'word': '2016',
#   'start': 455,
#   'end': 459},
#  {'entity': 'DATE',
#   'score': 0.35705778,
#   'index': 86,
#   'word': ')',
#   'start': 459,
#   'end': 460},
#  {'entity': 'SCIPROC',
#   'score': 0.9915981,
#   'index': 87,
#   'word': 'и',
#   'start': 461,
#   'end': 462},
#  {'entity': 'SCIPROC',
#   'score': 0.99701947,
#   'index': 88,
#   'word': 'K',
#   'start': 463,
#   'end': 464},
#  {'entity': 'SCIPROC',
#   'score': 0.96677667,
#   'index': 89,
#   'word': '##DI',
#   'start': 464,
#   'end': 466},
#  {'entity': 'SCIPROC',
#   'score': 0.9670445,
#   'index': 90,
#   'word': '##GO',
#   'start': 466,
#   'end': 468},
#  {'entity': 'DATE',
#   'score': 0.9875179,
#   'index': 91,
#   'word': '(',
#   'start': 469,
#   'end': 470},
#  {'entity': 'DATE',
#   'score': 0.9856808,
#   'index': 92,
#   'word': '2012',
#   'start': 470,
#   'end': 474},
#  {'entity': 'DATE',
#   'score': 0.35243607,
#   'index': 93,
#   'word': ')',
#   'start': 474,
#   'end': 475},
#  {'entity': 'FINDING',
#   'score': 0.39014402,
#   'index': 94,
#   'word': '.',
#   'start': 475,
#   'end': 476},
#  {'entity': 'FINDING',
#   'score': 0.92176795,
#   'index': 95,
#   'word': 'На',
#   'start': 477,
#   'end': 479},
#  {'entity': 'SCIPROC',
#   'score': 0.53820586,
#   'index': 96,
#   'word': 'основании',
#   'start': 480,
#   'end': 489},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.9988507,
#   'index': 97,
#   'word': 'опроса',
#   'start': 490,
#   'end': 496},
#  {'entity': 'PERSON',
#   'score': 0.9357967,
#   'index': 98,
#   'word': 'проба',
#   'start': 497,
#   'end': 502},
#  {'entity': 'PERSON',
#   'score': 0.89034754,
#   'index': 99,
#   'word': '##ндо',
#   'start': 502,
#   'end': 505},
#  {'entity': 'PERSON',
#   'score': 0.9547514,
#   'index': 100,
#   'word': '##в',
#   'start': 505,
#   'end': 506},
#  {'entity': 'FINDING',
#   'score': 0.8170341,
#   'index': 101,
#   'word': 'выявля',
#   'start': 507,
#   'end': 513},
#  {'entity': 'FINDING',
#   'score': 0.6640068,
#   'index': 102,
#   'word': '##ли',
#   'start': 513,
#   'end': 515},
#  {'entity': 'PERSON',
#   'score': 0.9706641,
#   'index': 103,
#   'word': 'его',
#   'start': 516,
#   'end': 519},
#  {'entity': 'PERSON',
#   'score': 0.9995914,
#   'index': 104,
#   'word': 'родственников',
#   'start': 520,
#   'end': 533},
#  {'entity': 'PERSON',
#   'score': 0.604667,
#   'index': 105,
#   'word': ',',
#   'start': 533,
#   'end': 534},
#  {'entity': 'PERSON',
#   'score': 0.59510076,
#   'index': 106,
#   'word': 'которые',
#   'start': 535,
#   'end': 542},
#  {'entity': 'FINDING',
#   'score': 0.33303335,
#   'index': 107,
#   'word': 'могли',
#   'start': 543,
#   'end': 548},
#  {'entity': 'GENE',
#   'score': 0.4913257,
#   'index': 108,
#   'word': 'унаследова',
#   'start': 549,
#   'end': 559},
#  {'entity': 'GENE',
#   'score': 0.29283163,
#   'index': 109,
#   'word': '##ть',
#   'start': 559,
#   'end': 561},
#  {'entity': 'GENE',
#   'score': 0.78118867,
#   'index': 110,
#   'word': 'мутант',
#   'start': 562,
#   'end': 568},
#  {'entity': 'GENE',
#   'score': 0.9892162,
#   'index': 111,
#   'word': '##ный',
#   'start': 568,
#   'end': 571},
#  {'entity': 'GENE',
#   'score': 0.9993606,
#   'index': 112,
#   'word': 'ген',
#   'start': 572,
#   'end': 575},
#  {'entity': 'FINDING',
#   'score': 0.21622454,
#   'index': 113,
#   'word': '.',
#   'start': 575,
#   'end': 576},
#  {'entity': 'FINDING',
#   'score': 0.99619687,
#   'index': 114,
#   'word': 'Результаты',
#   'start': 577,
#   'end': 587},
#  {'entity': 'FINDING',
#   'score': 0.9816958,
#   'index': 115,
#   'word': '.',
#   'start': 587,
#   'end': 588},
#  {'entity': 'FINDING',
#   'score': 0.3992865,
#   'index': 116,
#   'word': 'У',
#   'start': 589,
#   'end': 590},
#  {'entity': 'NUMBER',
#   'score': 0.9931636,
#   'index': 117,
#   'word': '50',
#   'start': 591,
#   'end': 593},
#  {'entity': 'PERCENT',
#   'score': 0.99880576,
#   'index': 118,
#   'word': '(',
#   'start': 594,
#   'end': 595},
#  {'entity': 'PERCENT',
#   'score': 0.9998529,
#   'index': 119,
#   'word': '24',
#   'start': 595,
#   'end': 597},
#  {'entity': 'PERCENT',
#   'score': 0.9997172,
#   'index': 120,
#   'word': ',',
#   'start': 597,
#   'end': 598},
#  {'entity': 'PERCENT',
#   'score': 0.99960023,
#   'index': 121,
#   'word': '9',
#   'start': 598,
#   'end': 599},
#  {'entity': 'PERCENT',
#   'score': 0.9974354,
#   'index': 122,
#   'word': '%',
#   'start': 599,
#   'end': 600},
#  {'entity': 'PERSON',
#   'score': 0.90576035,
#   'index': 123,
#   'word': ')',
#   'start': 600,
#   'end': 601},
#  {'entity': 'PERSON',
#   'score': 0.6809838,
#   'index': 124,
#   'word': 'из',
#   'start': 602,
#   'end': 604},
#  {'entity': 'NUMBER',
#   'score': 0.9975581,
#   'index': 125,
#   'word': '201',
#   'start': 605,
#   'end': 608},
#  {'entity': 'PERSON',
#   'score': 0.99982005,
#   'index': 126,
#   'word': 'обследова',
#   'start': 609,
#   'end': 618},
#  {'entity': 'PERSON',
#   'score': 0.99983203,
#   'index': 127,
#   'word': '##нных',
#   'start': 618,
#   'end': 622},
#  {'entity': 'PERSON',
#   'score': 0.9999094,
#   'index': 128,
#   'word': 'пациентов',
#   'start': 623,
#   'end': 632},
#  {'entity': 'DISO',
#   'score': 0.9195561,
#   'index': 129,
#   'word': 'с',
#   'start': 633,
#   'end': 634},
#  {'entity': 'DISO',
#   'score': 0.99990606,
#   'index': 130,
#   'word': 'БФ',
#   'start': 635,
#   'end': 637},
#  {'entity': 'FINDING',
#   'score': 0.9821291,
#   'index': 131,
#   'word': 'диагности',
#   'start': 638,
#   'end': 647},
#  {'entity': 'FINDING',
#   'score': 0.97645164,
#   'index': 132,
#   'word': '##рована',
#   'start': 647,
#   'end': 653},
#  {'entity': 'DISO',
#   'score': 0.9999063,
#   'index': 133,
#   'word': 'т',
#   'start': 654,
#   'end': 655},
#  {'entity': 'DISO',
#   'score': 0.9998648,
#   'index': 134,
#   'word': '##Х',
#   'start': 655,
#   'end': 656},
#  {'entity': 'DISO',
#   'score': 0.9998215,
#   'index': 135,
#   'word': '##П',
#   'start': 656,
#   'end': 657},
#  {'entity': 'DISO',
#   'score': 0.9996258,
#   'index': 136,
#   'word': '##Н',
#   'start': 657,
#   'end': 658},
#  {'entity': 'DATE',
#   'score': 0.35625544,
#   'index': 137,
#   'word': ',',
#   'start': 658,
#   'end': 659},
#  {'entity': 'DATE',
#   'score': 0.78512746,
#   'index': 138,
#   'word': 'в',
#   'start': 660,
#   'end': 661},
#  {'entity': 'DATE',
#   'score': 0.33215085,
#   'index': 139,
#   'word': 'том',
#   'start': 662,
#   'end': 665},
#  {'entity': 'NUMBER',
#   'score': 0.44962713,
#   'index': 140,
#   'word': 'числе',
#   'start': 666,
#   'end': 671},
#  {'entity': 'DATE',
#   'score': 0.46479556,
#   'index': 141,
#   'word': 'у',
#   'start': 672,
#   'end': 673},
#  {'entity': 'PERCENT',
#   'score': 0.5338112,
#   'index': 142,
#   'word': '48',
#   'start': 674,
#   'end': 676},
#  {'entity': 'PERCENT',
#   'score': 0.9994273,
#   'index': 143,
#   'word': '(',
#   'start': 677,
#   'end': 678},
#  {'entity': 'PERCENT',
#   'score': 0.9998305,
#   'index': 144,
#   'word': '40',
#   'start': 678,
#   'end': 680},
#  {'entity': 'PERCENT',
#   'score': 0.9985367,
#   'index': 145,
#   'word': '%',
#   'start': 680,
#   'end': 681},
#  {'entity': 'PERSON',
#   'score': 0.32826883,
#   'index': 146,
#   'word': ')',
#   'start': 681,
#   'end': 682},
#  {'entity': 'NUMBER',
#   'score': 0.3737091,
#   'index': 147,
#   'word': 'из',
#   'start': 683,
#   'end': 685},
#  {'entity': 'NUMBER',
#   'score': 0.99923646,
#   'index': 148,
#   'word': '120',
#   'start': 686,
#   'end': 689},
#  {'entity': 'PERSON',
#   'score': 0.99969745,
#   'index': 149,
#   'word': 'мужчин',
#   'start': 690,
#   'end': 696},
#  {'entity': 'NUMBER',
#   'score': 0.3400178,
#   'index': 150,
#   'word': 'и',
#   'start': 697,
#   'end': 698},
#  {'entity': 'NUMBER',
#   'score': 0.9826204,
#   'index': 151,
#   'word': '2',
#   'start': 699,
#   'end': 700},
#  {'entity': 'PERCENT',
#   'score': 0.99961036,
#   'index': 152,
#   'word': '(',
#   'start': 701,
#   'end': 702},
#  {'entity': 'PERCENT',
#   'score': 0.9998807,
#   'index': 153,
#   'word': '2',
#   'start': 702,
#   'end': 703},
#  {'entity': 'PERCENT',
#   'score': 0.9998259,
#   'index': 154,
#   'word': ',',
#   'start': 703,
#   'end': 704},
#  {'entity': 'PERCENT',
#   'score': 0.999803,
#   'index': 155,
#   'word': '7',
#   'start': 704,
#   'end': 705},
#  {'entity': 'PERCENT',
#   'score': 0.999246,
#   'index': 156,
#   'word': '%',
#   'start': 705,
#   'end': 706},
#  {'entity': 'NUMBER',
#   'score': 0.45611054,
#   'index': 157,
#   'word': ')',
#   'start': 706,
#   'end': 707},
#  {'entity': 'NUMBER',
#   'score': 0.8556336,
#   'index': 158,
#   'word': 'из',
#   'start': 708,
#   'end': 710},
#  {'entity': 'NUMBER',
#   'score': 0.99929667,
#   'index': 159,
#   'word': '81',
#   'start': 711,
#   'end': 713},
#  {'entity': 'PERSON',
#   'score': 0.99986625,
#   'index': 160,
#   'word': 'женщин',
#   'start': 714,
#   'end': 720},
#  {'entity': 'FINDING',
#   'score': 0.60351807,
#   'index': 161,
#   'word': '.',
#   'start': 720,
#   'end': 721},
#  {'entity': 'SCIPROC',
#   'score': 0.95655274,
#   'index': 162,
#   'word': 'Оценка',
#   'start': 722,
#   'end': 728},
#  {'entity': 'FINDING',
#   'score': 0.9878066,
#   'index': 163,
#   'word': 'кумуля',
#   'start': 729,
#   'end': 735},
#  {'entity': 'PHYS',
#   'score': 0.7419425,
#   'index': 164,
#   'word': '##тивной',
#   'start': 735,
#   'end': 741},
#  {'entity': 'PHYS',
#   'score': 0.98584324,
#   'index': 165,
#   'word': 'частоты',
#   'start': 742,
#   'end': 749},
#  {'entity': 'SCIPROC',
#   'score': 0.9996915,
#   'index': 166,
#   'word': 'методом',
#   'start': 750,
#   'end': 757},
#  {'entity': 'SCIPROC',
#   'score': 0.9996457,
#   'index': 167,
#   'word': 'Каплан',
#   'start': 758,
#   'end': 764},
#  {'entity': 'SCIPROC',
#   'score': 0.99855036,
#   'index': 168,
#   'word': '##а',
#   'start': 764,
#   'end': 765},
#  {'entity': 'SCIPROC',
#   'score': 0.98339415,
#   'index': 169,
#   'word': '-',
#   'start': 765,
#   'end': 766},
#  {'entity': 'PERSON',
#   'score': 0.76294297,
#   'index': 170,
#   'word': 'Майер',
#   'start': 766,
#   'end': 771},
#  {'entity': 'SCIPROC',
#   'score': 0.9944565,
#   'index': 171,
#   'word': '##а',
#   'start': 771,
#   'end': 772},
#  {'entity': 'FINDING',
#   'score': 0.99952364,
#   'index': 172,
#   'word': 'демонстрирует',
#   'start': 773,
#   'end': 786},
#  {'entity': 'FINDING',
#   'score': 0.99972373,
#   'index': 173,
#   'word': 'выраженное',
#   'start': 787,
#   'end': 797},
#  {'entity': 'FINDING',
#   'score': 0.99973744,
#   'index': 174,
#   'word': 'увеличение',
#   'start': 798,
#   'end': 808},
#  {'entity': 'PHYS',
#   'score': 0.99300706,
#   'index': 175,
#   'word': 'частоты',
#   'start': 809,
#   'end': 816},
#  {'entity': 'FINDING',
#   'score': 0.97859955,
#   'index': 176,
#   'word': 'регистрации',
#   'start': 817,
#   'end': 828},
#  {'entity': 'DISO',
#   'score': 0.9999192,
#   'index': 177,
#   'word': 'т',
#   'start': 829,
#   'end': 830},
#  {'entity': 'DISO',
#   'score': 0.9998938,
#   'index': 178,
#   'word': '##Х',
#   'start': 830,
#   'end': 831},
#  {'entity': 'DISO',
#   'score': 0.999851,
#   'index': 179,
#   'word': '##П',
#   'start': 831,
#   'end': 832},
#  {'entity': 'DISO',
#   'score': 0.9998209,
#   'index': 180,
#   'word': '##Н',
#   'start': 832,
#   'end': 833},
#  {'entity': 'AGE',
#   'score': 0.9484024,
#   'index': 181,
#   'word': 'к',
#   'start': 834,
#   'end': 835},
#  {'entity': 'PHYS',
#   'score': 0.99623704,
#   'index': 182,
#   'word': 'возрасту',
#   'start': 836,
#   'end': 844},
#  {'entity': 'AGE',
#   'score': 0.99983203,
#   'index': 183,
#   'word': '20',
#   'start': 845,
#   'end': 847},
#  {'entity': 'AGE',
#   'score': 0.9995994,
#   'index': 184,
#   'word': '-',
#   'start': 847,
#   'end': 848},
#  {'entity': 'AGE',
#   'score': 0.9989182,
#   'index': 185,
#   'word': '30',
#   'start': 848,
#   'end': 850},
#  {'entity': 'AGE',
#   'score': 0.9979177,
#   'index': 186,
#   'word': 'лет',
#   'start': 851,
#   'end': 854},
#  {'entity': 'FINDING',
#   'score': 0.7700644,
#   'index': 187,
#   'word': ',',
#   'start': 854,
#   'end': 855},
#  {'entity': 'DATE',
#   'score': 0.20458628,
#   'index': 188,
#   'word': 'а',
#   'start': 856,
#   'end': 857},
#  {'entity': 'AGE',
#   'score': 0.97601503,
#   'index': 189,
#   'word': 'к',
#   'start': 858,
#   'end': 859},
#  {'entity': 'PHYS',
#   'score': 0.9116498,
#   'index': 190,
#   'word': 'возрасту',
#   'start': 860,
#   'end': 868},
#  {'entity': 'AGE',
#   'score': 0.99977535,
#   'index': 191,
#   'word': '50',
#   'start': 869,
#   'end': 871},
#  {'entity': 'AGE',
#   'score': 0.999111,
#   'index': 192,
#   'word': 'лет',
#   'start': 872,
#   'end': 875},
#  {'entity': 'FINDING',
#   'score': 0.9984395,
#   'index': 193,
#   'word': 'ожидаемо',
#   'start': 876,
#   'end': 884},
#  {'entity': 'FINDING',
#   'score': 0.99700266,
#   'index': 194,
#   'word': '##е',
#   'start': 884,
#   'end': 885},
#  {'entity': 'PHYS',
#   'score': 0.9099418,
#   'index': 195,
#   'word': 'количество',
#   'start': 886,
#   'end': 896},
#  {'entity': 'PERSON',
#   'score': 0.99990106,
#   'index': 196,
#   'word': 'пациентов',
#   'start': 897,
#   'end': 906},
#  {'entity': 'DISO',
#   'score': 0.77669835,
#   'index': 197,
#   'word': 'с',
#   'start': 907,
#   'end': 908},
#  {'entity': 'DISO',
#   'score': 0.9999156,
#   'index': 198,
#   'word': 'т',
#   'start': 909,
#   'end': 910},
#  {'entity': 'DISO',
#   'score': 0.99987054,
#   'index': 199,
#   'word': '##Х',
#   'start': 910,
#   'end': 911},
#  {'entity': 'DISO',
#   'score': 0.99982786,
#   'index': 200,
#   'word': '##П',
#   'start': 911,
#   'end': 912},
#  {'entity': 'DISO',
#   'score': 0.9996301,
#   'index': 201,
#   'word': '##Н',
#   'start': 912,
#   'end': 913},
#  {'entity': 'FINDING',
#   'score': 0.9941643,
#   'index': 202,
#   'word': 'составляет',
#   'start': 914,
#   'end': 924},
#  {'entity': 'PERCENT',
#   'score': 0.9998815,
#   'index': 203,
#   'word': '95',
#   'start': 925,
#   'end': 927},
#  {'entity': 'PERCENT',
#   'score': 0.99919707,
#   'index': 204,
#   'word': '%',
#   'start': 927,
#   'end': 928},
#  {'entity': 'DATE',
#   'score': 0.2315582,
#   'index': 205,
#   'word': '.',
#   'start': 928,
#   'end': 929},
#  {'entity': 'NUMBER',
#   'score': 0.99794,
#   'index': 206,
#   'word': 'Пяти',
#   'start': 930,
#   'end': 934},
#  {'entity': 'NUMBER',
#   'score': 0.39308754,
#   'index': 207,
#   'word': 'из',
#   'start': 935,
#   'end': 937},
#  {'entity': 'NUMBER',
#   'score': 0.99820995,
#   'index': 208,
#   'word': '50',
#   'start': 938,
#   'end': 940},
#  {'entity': 'PERSON',
#   'score': 0.99989533,
#   'index': 209,
#   'word': 'больных',
#   'start': 941,
#   'end': 948},
#  {'entity': 'DISO',
#   'score': 0.87167186,
#   'index': 210,
#   'word': 'с',
#   'start': 949,
#   'end': 950},
#  {'entity': 'DISO',
#   'score': 0.99990535,
#   'index': 211,
#   'word': 'т',
#   'start': 951,
#   'end': 952},
#  {'entity': 'DISO',
#   'score': 0.9997429,
#   'index': 212,
#   'word': '##Х',
#   'start': 952,
#   'end': 953},
#  {'entity': 'DISO',
#   'score': 0.9997638,
#   'index': 213,
#   'word': '##П',
#   'start': 953,
#   'end': 954},
#  {'entity': 'DISO',
#   'score': 0.9994523,
#   'index': 214,
#   'word': '##Н',
#   'start': 954,
#   'end': 955},
#  {'entity': 'MEDPROC',
#   'score': 0.99879384,
#   'index': 215,
#   'word': 'была',
#   'start': 956,
#   'end': 960},
#  {'entity': 'MEDPROC',
#   'score': 0.9994554,
#   'index': 216,
#   'word': 'выполнена',
#   'start': 961,
#   'end': 970},
#  {'entity': 'MEDPROC',
#   'score': 0.9996363,
#   'index': 217,
#   'word': 'транспланта',
#   'start': 971,
#   'end': 982},
#  {'entity': 'MEDPROC',
#   'score': 0.9993019,
#   'index': 218,
#   'word': '##ция',
#   'start': 982,
#   'end': 985},
#  {'entity': 'ANATOMY',
#   'score': 0.9997483,
#   'index': 219,
#   'word': 'почки',
#   'start': 986,
#   'end': 991},
#  {'entity': 'DATE',
#   'score': 0.58384466,
#   'index': 220,
#   'word': ',',
#   'start': 991,
#   'end': 992},
#  {'entity': 'DATE',
#   'score': 0.99898964,
#   'index': 221,
#   'word': 'в',
#   'start': 993,
#   'end': 994},
#  {'entity': 'DATE',
#   'score': 0.9897668,
#   'index': 222,
#   'word': 'среднем',
#   'start': 995,
#   'end': 1002},
#  {'entity': 'DATE',
#   'score': 0.9524501,
#   'index': 223,
#   'word': ',',
#   'start': 1002,
#   'end': 1003},
#  {'entity': 'DATE',
#   'score': 0.99977654,
#   'index': 224,
#   'word': 'через',
#   'start': 1004,
#   'end': 1009},
#  {'entity': 'DATE',
#   'score': 0.9996842,
#   'index': 225,
#   'word': '17',
#   'start': 1010,
#   'end': 1012},
#  {'entity': 'DATE',
#   'score': 0.9986935,
#   'index': 226,
#   'word': 'месяцев',
#   'start': 1013,
#   'end': 1020},
#  {'entity': 'DATE',
#   'score': 0.9983375,
#   'index': 227,
#   'word': '(',
#   'start': 1021,
#   'end': 1022},
#  {'entity': 'DATE',
#   'score': 0.8803336,
#   'index': 228,
#   'word': 'диапазон',
#   'start': 1022,
#   'end': 1030},
#  {'entity': 'DATE',
#   'score': 0.99881196,
#   'index': 229,
#   'word': 'от',
#   'start': 1031,
#   'end': 1033},
#  {'entity': 'DATE',
#   'score': 0.99950147,
#   'index': 230,
#   'word': '7',
#   'start': 1034,
#   'end': 1035},
#  {'entity': 'DATE',
#   'score': 0.9942151,
#   'index': 231,
#   'word': 'до',
#   'start': 1036,
#   'end': 1038},
#  {'entity': 'DATE',
#   'score': 0.9990765,
#   'index': 232,
#   'word': '70',
#   'start': 1039,
#   'end': 1041},
#  {'entity': 'DATE',
#   'score': 0.99544513,
#   'index': 233,
#   'word': 'месяцев',
#   'start': 1042,
#   'end': 1049},
#  {'entity': 'DATE',
#   'score': 0.9790942,
#   'index': 234,
#   'word': ')',
#   'start': 1049,
#   'end': 1050},
#  {'entity': 'DATE',
#   'score': 0.92576635,
#   'index': 235,
#   'word': 'после',
#   'start': 1051,
#   'end': 1056},
#  {'entity': 'MEDPROC',
#   'score': 0.99954623,
#   'index': 236,
#   'word': 'инициации',
#   'start': 1057,
#   'end': 1066},
#  {'entity': 'MEDPROC',
#   'score': 0.99971515,
#   'index': 237,
#   'word': 'лечения',
#   'start': 1067,
#   'end': 1074},
#  {'entity': 'MEDPROC',
#   'score': 0.99979466,
#   'index': 238,
#   'word': 'гемо',
#   'start': 1075,
#   'end': 1079},
#  {'entity': 'MEDPROC',
#   'score': 0.999759,
#   'index': 239,
#   'word': '##диа',
#   'start': 1079,
#   'end': 1082},
#  {'entity': 'MEDPROC',
#   'score': 0.99903,
#   'index': 240,
#   'word': '##лиз',
#   'start': 1082,
#   'end': 1085},
#  {'entity': 'MEDPROC',
#   'score': 0.99838936,
#   'index': 241,
#   'word': '##ом',
#   'start': 1085,
#   'end': 1087},
#  {'entity': 'FINDING',
#   'score': 0.30808374,
#   'index': 242,
#   'word': '.',
#   'start': 1087,
#   'end': 1088},
#  {'entity': 'PHYS',
#   'score': 0.97159684,
#   'index': 243,
#   'word': 'Умер',
#   'start': 1089,
#   'end': 1093},
#  {'entity': 'FINDING',
#   'score': 0.6897277,
#   'index': 244,
#   'word': '##ло',
#   'start': 1093,
#   'end': 1095},
#  {'entity': 'NUMBER',
#   'score': 0.90436506,
#   'index': 245,
#   'word': '15',
#   'start': 1096,
#   'end': 1098},
#  {'entity': 'PERCENT',
#   'score': 0.9996668,
#   'index': 246,
#   'word': '(',
#   'start': 1099,
#   'end': 1100},
#  {'entity': 'PERCENT',
#   'score': 0.99986553,
#   'index': 247,
#   'word': '30',
#   'start': 1100,
#   'end': 1102},
#  {'entity': 'PERCENT',
#   'score': 0.9988004,
#   'index': 248,
#   'word': '%',
#   'start': 1102,
#   'end': 1103},
#  {'entity': 'PERSON',
#   'score': 0.33787006,
#   'index': 249,
#   'word': ')',
#   'start': 1103,
#   'end': 1104},
#  {'entity': 'NUMBER',
#   'score': 0.43766358,
#   'index': 250,
#   'word': 'из',
#   'start': 1105,
#   'end': 1107},
#  {'entity': 'NUMBER',
#   'score': 0.9983417,
#   'index': 251,
#   'word': '50',
#   'start': 1108,
#   'end': 1110},
#  {'entity': 'PERSON',
#   'score': 0.9998721,
#   'index': 252,
#   'word': 'пациентов',
#   'start': 1111,
#   'end': 1120},
#  {'entity': 'PERSON',
#   'score': 0.9463034,
#   'index': 253,
#   'word': ',',
#   'start': 1120,
#   'end': 1121},
#  {'entity': 'MEDPROC',
#   'score': 0.9994615,
#   'index': 254,
#   'word': 'получа',
#   'start': 1122,
#   'end': 1128},
#  {'entity': 'MEDPROC',
#   'score': 0.9236964,
#   'index': 255,
#   'word': '##вших',
#   'start': 1128,
#   'end': 1132},
#  {'entity': 'MEDPROC',
#   'score': 0.9997446,
#   'index': 256,
#   'word': 'лечение',
#   'start': 1133,
#   'end': 1140},
#  {'entity': 'MEDPROC',
#   'score': 0.99980944,
#   'index': 257,
#   'word': 'гемо',
#   'start': 1141,
#   'end': 1145},
#  {'entity': 'MEDPROC',
#   'score': 0.99979585,
#   'index': 258,
#   'word': '##диа',
#   'start': 1145,
#   'end': 1148},
#  {'entity': 'MEDPROC',
#   'score': 0.9995689,
#   'index': 259,
#   'word': '##лиз',
#   'start': 1148,
#   'end': 1151},
#  {'entity': 'MEDPROC',
#   'score': 0.99896276,
#   'index': 260,
#   'word': '##ом',
#   'start': 1151,
#   'end': 1153},
#  {'entity': 'FINDING',
#   'score': 0.40537798,
#   'index': 261,
#   'word': '.',
#   'start': 1153,
#   'end': 1154},
#  {'entity': 'PERSON',
#   'score': 0.69508684,
#   'index': 262,
#   'word': 'Все',
#   'start': 1155,
#   'end': 1158},
#  {'entity': 'PERSON',
#   'score': 0.9974673,
#   'index': 263,
#   'word': 'умер',
#   'start': 1159,
#   'end': 1163},
#  {'entity': 'PERSON',
#   'score': 0.99733007,
#   'index': 264,
#   'word': '##шие',
#   'start': 1163,
#   'end': 1166},
#  {'entity': 'PERSON',
#   'score': 0.9998733,
#   'index': 265,
#   'word': 'пациенты',
#   'start': 1167,
#   'end': 1175},
#  {'entity': 'FINDING',
#   'score': 0.85392696,
#   'index': 266,
#   'word': 'были',
#   'start': 1176,
#   'end': 1180},
#  {'entity': 'PHYS',
#   'score': 0.9996736,
#   'index': 267,
#   'word': 'мужского',
#   'start': 1181,
#   'end': 1189},
#  {'entity': 'PHYS',
#   'score': 0.99971694,
#   'index': 268,
#   'word': 'пола',
#   'start': 1190,
#   'end': 1194},
#  {'entity': 'FINDING',
#   'score': 0.5698224,
#   'index': 269,
#   'word': '.',
#   'start': 1194,
#   'end': 1195},
#  {'entity': 'FINDING',
#   'score': 0.9980458,
#   'index': 270,
#   'word': 'Медиа',
#   'start': 1196,
#   'end': 1201},
#  {'entity': 'FINDING',
#   'score': 0.8488355,
#   'index': 271,
#   'word': '##на',
#   'start': 1201,
#   'end': 1203},
#  {'entity': 'PHYS',
#   'score': 0.99959844,
#   'index': 272,
#   'word': 'возраста',
#   'start': 1204,
#   'end': 1212},
#  {'entity': 'DATE',
#   'score': 0.99848926,
#   'index': 273,
#   'word': 'на',
#   'start': 1213,
#   'end': 1215},
#  {'entity': 'DATE',
#   'score': 0.9566744,
#   'index': 274,
#   'word': 'момент',
#   'start': 1216,
#   'end': 1222},
#  {'entity': 'PHYS',
#   'score': 0.88668835,
#   'index': 275,
#   'word': 'летального',
#   'start': 1223,
#   'end': 1233},
#  {'entity': 'PHYS',
#   'score': 0.4930281,
#   'index': 276,
#   'word': 'исхода',
#   'start': 1234,
#   'end': 1240},
#  {'entity': 'FINDING',
#   'score': 0.9964275,
#   'index': 277,
#   'word': 'составила',
#   'start': 1241,
#   'end': 1250},
#  {'entity': 'AGE',
#   'score': 0.99957544,
#   'index': 278,
#   'word': '45',
#   'start': 1251,
#   'end': 1253},
#  {'entity': 'AGE',
#   'score': 0.98576087,
#   'index': 279,
#   'word': '(',
#   'start': 1254,
#   'end': 1255},
#  {'entity': 'AGE',
#   'score': 0.9995221,
#   'index': 280,
#   'word': '39',
#   'start': 1255,
#   'end': 1257},
#  {'entity': 'AGE',
#   'score': 0.43427235,
#   'index': 281,
#   'word': ';',
#   'start': 1257,
#   'end': 1258},
#  {'entity': 'AGE',
#   'score': 0.9372322,
#   'index': 282,
#   'word': '58',
#   'start': 1259,
#   'end': 1261},
#  {'entity': 'DATE',
#   'score': 0.7681163,
#   'index': 283,
#   'word': ')',
#   'start': 1261,
#   'end': 1262},
#  {'entity': 'AGE',
#   'score': 0.94032526,
#   'index': 284,
#   'word': 'лет',
#   'start': 1263,
#   'end': 1266},
#  {'entity': 'FINDING',
#   'score': 0.30980825,
#   'index': 285,
#   'word': '.',
#   'start': 1266,
#   'end': 1267},
#  {'entity': 'FINDING',
#   'score': 0.5825051,
#   'index': 286,
#   'word': 'Среди',
#   'start': 1268,
#   'end': 1273},
#  {'entity': 'PERSON',
#   'score': 0.99989367,
#   'index': 287,
#   'word': 'пациентов',
#   'start': 1274,
#   'end': 1283},
#  {'entity': 'PERSON',
#   'score': 0.6564433,
#   'index': 288,
#   'word': ',',
#   'start': 1283,
#   'end': 1284},
#  {'entity': 'PERSON',
#   'score': 0.87906307,
#   'index': 289,
#   'word': 'которым',
#   'start': 1285,
#   'end': 1292},
#  {'entity': 'MEDPROC',
#   'score': 0.9996377,
#   'index': 290,
#   'word': 'проведена',
#   'start': 1293,
#   'end': 1302},
#  {'entity': 'MEDPROC',
#   'score': 0.9997327,
#   'index': 291,
#   'word': 'транспланта',
#   'start': 1303,
#   'end': 1314},
#  {'entity': 'MEDPROC',
#   'score': 0.9994981,
#   'index': 292,
#   'word': '##ция',
#   'start': 1314,
#   'end': 1317},
#  {'entity': 'ANATOMY',
#   'score': 0.999742,
#   'index': 293,
#   'word': 'почки',
#   'start': 1318,
#   'end': 1323},
#  {'entity': 'FINDING',
#   'score': 0.9984994,
#   'index': 294,
#   'word': ',',
#   'start': 1323,
#   'end': 1324},
#  {'entity': 'FINDING',
#   'score': 0.99910337,
#   'index': 295,
#   'word': 'летальных',
#   'start': 1325,
#   'end': 1334},
#  {'entity': 'FINDING',
#   'score': 0.9994374,
#   'index': 296,
#   'word': 'исход',
#   'start': 1335,
#   'end': 1340},
#  {'entity': 'FINDING',
#   'score': 0.99923134,
#   'index': 297,
#   'word': '##ов',
#   'start': 1340,
#   'end': 1342},
#  {'entity': 'FINDING',
#   'score': 0.9995295,
#   'index': 298,
#   'word': 'зарегистрировано',
#   'start': 1343,
#   'end': 1359},
#  {'entity': 'FINDING',
#   'score': 0.99922264,
#   'index': 299,
#   'word': 'не',
#   'start': 1360,
#   'end': 1362},
#  {'entity': 'FINDING',
#   'score': 0.999311,
#   'index': 300,
#   'word': 'было',
#   'start': 1363,
#   'end': 1367},
#  {'entity': 'FINDING',
#   'score': 0.3807112,
#   'index': 301,
#   'word': '.',
#   'start': 1367,
#   'end': 1368},
#  {'entity': 'FINDING',
#   'score': 0.7092769,
#   'index': 302,
#   'word': 'У',
#   'start': 1369,
#   'end': 1370},
#  {'entity': 'NUMBER',
#   'score': 0.9271578,
#   'index': 303,
#   'word': '44',
#   'start': 1371,
#   'end': 1373},
#  {'entity': 'PERCENT',
#   'score': 0.99741095,
#   'index': 304,
#   'word': '(',
#   'start': 1374,
#   'end': 1375},
#  {'entity': 'PERCENT',
#   'score': 0.9998184,
#   'index': 305,
#   'word': '88',
#   'start': 1375,
#   'end': 1377},
#  {'entity': 'PERCENT',
#   'score': 0.99169487,
#   'index': 306,
#   'word': '%',
#   'start': 1377,
#   'end': 1378},
#  {'entity': 'PERSON',
#   'score': 0.9033629,
#   'index': 307,
#   'word': ')',
#   'start': 1378,
#   'end': 1379},
#  {'entity': 'PERSON',
#   'score': 0.48355234,
#   'index': 308,
#   'word': 'из',
#   'start': 1380,
#   'end': 1382},
#  {'entity': 'NUMBER',
#   'score': 0.99889475,
#   'index': 309,
#   'word': '50',
#   'start': 1383,
#   'end': 1385},
#  {'entity': 'PERSON',
#   'score': 0.99990153,
#   'index': 310,
#   'word': 'пациентов',
#   'start': 1386,
#   'end': 1395},
#  {'entity': 'FINDING',
#   'score': 0.9493163,
#   'index': 311,
#   'word': 'диагноз',
#   'start': 1396,
#   'end': 1403},
#  {'entity': 'DISO',
#   'score': 0.9998888,
#   'index': 312,
#   'word': 'БФ',
#   'start': 1404,
#   'end': 1406},
#  {'entity': 'FINDING',
#   'score': 0.8245242,
#   'index': 313,
#   'word': 'установлен',
#   'start': 1407,
#   'end': 1417},
#  {'entity': 'FINDING',
#   'score': 0.69330347,
#   'index': 314,
#   'word': ',',
#   'start': 1417,
#   'end': 1418},
#  {'entity': 'DATE',
#   'score': 0.99518824,
#   'index': 315,
#   'word': 'в',
#   'start': 1419,
#   'end': 1420},
#  {'entity': 'DATE',
#   'score': 0.74366486,
#   'index': 316,
#   'word': 'среднем',
#   'start': 1421,
#   'end': 1428},
#  {'entity': 'DATE',
#   'score': 0.8951626,
#   'index': 317,
#   'word': ',',
#   'start': 1428,
#   'end': 1429},
#  {'entity': 'DATE',
#   'score': 0.99964345,
#   'index': 318,
#   'word': 'через',
#   'start': 1430,
#   'end': 1435},
#  {'entity': 'DATE',
#   'score': 0.9993656,
#   'index': 319,
#   'word': '1',
#   'start': 1436,
#   'end': 1437},
#  {'entity': 'DATE',
#   'score': 0.9980572,
#   'index': 320,
#   'word': 'год',
#   'start': 1438,
#   'end': 1441},
#  {'entity': 'DATE',
#   'score': 0.9477739,
#   'index': 321,
#   'word': '(',
#   'start': 1442,
#   'end': 1443},
#  {'entity': 'SCIPROC',
#   'score': 0.45014095,
#   'index': 322,
#   'word': 'диапазон',
#   'start': 1443,
#   'end': 1451},
#  {'entity': 'DATE',
#   'score': 0.9890939,
#   'index': 323,
#   'word': 'от',
#   'start': 1452,
#   'end': 1454},
#  {'entity': 'DATE',
#   'score': 0.9954833,
#   'index': 324,
#   'word': '0',
#   'start': 1455,
#   'end': 1456},
#  {'entity': 'DATE',
#   'score': 0.9583884,
#   'index': 325,
#   'word': 'до',
#   'start': 1457,
#   'end': 1459},
#  {'entity': 'DATE',
#   'score': 0.9972851,
#   'index': 326,
#   'word': '12',
#   'start': 1460,
#   'end': 1462},
#  {'entity': 'DATE',
#   'score': 0.993606,
#   'index': 327,
#   'word': 'лет',
#   'start': 1463,
#   'end': 1466},
#  {'entity': 'DATE',
#   'score': 0.7085762,
#   'index': 328,
#   'word': ')',
#   'start': 1466,
#   'end': 1467},
#  {'entity': 'DATE',
#   'score': 0.9711303,
#   'index': 329,
#   'word': 'после',
#   'start': 1468,
#   'end': 1473},
#  {'entity': 'MEDPROC',
#   'score': 0.9947792,
#   'index': 330,
#   'word': 'начала',
#   'start': 1474,
#   'end': 1480},
#  {'entity': 'MEDPROC',
#   'score': 0.9997534,
#   'index': 331,
#   'word': 'лечения',
#   'start': 1481,
#   'end': 1488},
#  {'entity': 'MEDPROC',
#   'score': 0.9998264,
#   'index': 332,
#   'word': 'программным',
#   'start': 1489,
#   'end': 1500},
#  {'entity': 'MEDPROC',
#   'score': 0.9998061,
#   'index': 333,
#   'word': 'гемо',
#   'start': 1501,
#   'end': 1505},
#  {'entity': 'MEDPROC',
#   'score': 0.9997805,
#   'index': 334,
#   'word': '##диа',
#   'start': 1505,
#   'end': 1508},
#  {'entity': 'MEDPROC',
#   'score': 0.99968195,
#   'index': 335,
#   'word': '##лиз',
#   'start': 1508,
#   'end': 1511},
#  {'entity': 'MEDPROC',
#   'score': 0.99942636,
#   'index': 336,
#   'word': '##ом',
#   'start': 1511,
#   'end': 1513},
#  {'entity': 'DATE',
#   'score': 0.66232395,
#   'index': 337,
#   'word': ',',
#   'start': 1513,
#   'end': 1514},
#  {'entity': 'DATE',
#   'score': 0.6542254,
#   'index': 338,
#   'word': 'в',
#   'start': 1515,
#   'end': 1516},
#  {'entity': 'DATE',
#   'score': 0.3626929,
#   'index': 339,
#   'word': 'том',
#   'start': 1517,
#   'end': 1520},
#  {'entity': 'NUMBER',
#   'score': 0.8594993,
#   'index': 340,
#   'word': 'числе',
#   'start': 1521,
#   'end': 1526},
#  {'entity': 'NUMBER',
#   'score': 0.60006756,
#   'index': 341,
#   'word': 'у',
#   'start': 1527,
#   'end': 1528},
#  {'entity': 'NUMBER',
#   'score': 0.9958241,
#   'index': 342,
#   'word': 'одного',
#   'start': 1529,
#   'end': 1535},
#  {'entity': 'PERSON',
#   'score': 0.99988806,
#   'index': 343,
#   'word': 'пациента',
#   'start': 1536,
#   'end': 1544},
#  {'entity': 'DATE',
#   'score': 0.35896093,
#   'index': 344,
#   'word': '–',
#   'start': 1545,
#   'end': 1546},
#  {'entity': 'MEDPROC',
#   'score': 0.5959054,
#   'index': 345,
#   'word': 'после',
#   'start': 1547,
#   'end': 1552},
#  {'entity': 'MEDPROC',
#   'score': 0.99971944,
#   'index': 346,
#   'word': 'трансплантации',
#   'start': 1553,
#   'end': 1567},
#  {'entity': 'ANATOMY',
#   'score': 0.99972314,
#   'index': 347,
#   'word': 'почки',
#   'start': 1568,
#   'end': 1573},
#  {'entity': 'FINDING',
#   'score': 0.24860668,
#   'index': 348,
#   'word': '.',
#   'start': 1573,
#   'end': 1574},
#  {'entity': 'FINDING',
#   'score': 0.65242255,
#   'index': 349,
#   'word': 'Среди',
#   'start': 1575,
#   'end': 1580},
#  {'entity': 'NUMBER',
#   'score': 0.99947196,
#   'index': 350,
#   'word': '44',
#   'start': 1581,
#   'end': 1583},
#  {'entity': 'PERSON',
#   'score': 0.9968065,
#   'index': 351,
#   'word': 'проба',
#   'start': 1584,
#   'end': 1589},
#  {'entity': 'PERSON',
#   'score': 0.9923915,
#   'index': 352,
#   'word': '##ндо',
#   'start': 1589,
#   'end': 1592},
#  {'entity': 'PERSON',
#   'score': 0.9970241,
#   'index': 353,
#   'word': '##в',
#   'start': 1592,
#   'end': 1593},
#  {'entity': 'FINDING',
#   'score': 0.40926257,
#   'index': 354,
#   'word': ',',
#   'start': 1593,
#   'end': 1594},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.46950904,
#   'index': 355,
#   'word': 'выявленных',
#   'start': 1595,
#   'end': 1605},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.9934841,
#   'index': 356,
#   'word': 'при',
#   'start': 1606,
#   'end': 1609},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.95631284,
#   'index': 357,
#   'word': 'всероссий',
#   'start': 1610,
#   'end': 1619},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.9783427,
#   'index': 358,
#   'word': '##ском',
#   'start': 1619,
#   'end': 1623},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.93438786,
#   'index': 359,
#   'word': 'диа',
#   'start': 1624,
#   'end': 1627},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.988267,
#   'index': 360,
#   'word': '##лиз',
#   'start': 1627,
#   'end': 1630},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.9988802,
#   'index': 361,
#   'word': '##ном',
#   'start': 1630,
#   'end': 1633},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.99958473,
#   'index': 362,
#   'word': 'скрин',
#   'start': 1634,
#   'end': 1639},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.9991007,
#   'index': 363,
#   'word': '##инг',
#   'start': 1639,
#   'end': 1642},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.998776,
#   'index': 364,
#   'word': '##е',
#   'start': 1642,
#   'end': 1643},
#  {'entity': 'FINDING',
#   'score': 0.89320374,
#   'index': 365,
#   'word': ',',
#   'start': 1643,
#   'end': 1644},
#  {'entity': 'MEDPROC',
#   'score': 0.93825704,
#   'index': 366,
#   'word': 'проведен',
#   'start': 1645,
#   'end': 1653},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.9835171,
#   'index': 367,
#   'word': 'семейный',
#   'start': 1654,
#   'end': 1662},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.9995011,
#   'index': 368,
#   'word': 'скрин',
#   'start': 1663,
#   'end': 1668},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.9989104,
#   'index': 369,
#   'word': '##инг',
#   'start': 1668,
#   'end': 1671},
#  {'entity': 'FINDING',
#   'score': 0.5979778,
#   'index': 370,
#   'word': '.',
#   'start': 1671,
#   'end': 1672},
#  {'entity': 'DISO',
#   'score': 0.94741964,
#   'index': 371,
#   'word': 'Пато',
#   'start': 1673,
#   'end': 1677},
#  {'entity': 'FINDING',
#   'score': 0.6112623,
#   'index': 372,
#   'word': '##генная',
#   'start': 1677,
#   'end': 1683},
#  {'entity': 'PHYS',
#   'score': 0.86654073,
#   'index': 373,
#   'word': 'мутация',
#   'start': 1684,
#   'end': 1691},
#  {'entity': 'GENE',
#   'score': 0.9991979,
#   'index': 374,
#   'word': 'в',
#   'start': 1692,
#   'end': 1693},
#  {'entity': 'GENE',
#   'score': 0.9997552,
#   'index': 375,
#   'word': 'гене',
#   'start': 1694,
#   'end': 1698},
#  {'entity': 'GENE',
#   'score': 0.999716,
#   'index': 376,
#   'word': 'GL',
#   'start': 1699,
#   'end': 1701},
#  {'entity': 'GENE',
#   'score': 0.99975306,
#   'index': 377,
#   'word': '##A',
#   'start': 1701,
#   'end': 1702},
#  {'entity': 'FINDING',
#   'score': 0.9988569,
#   'index': 378,
#   'word': 'диагности',
#   'start': 1703,
#   'end': 1712},
#  {'entity': 'FINDING',
#   'score': 0.9991037,
#   'index': 379,
#   'word': '##рована',
#   'start': 1712,
#   'end': 1718},
#  {'entity': 'FINDING',
#   'score': 0.9263978,
#   'index': 380,
#   'word': 'у',
#   'start': 1719,
#   'end': 1720},
#  {'entity': 'PERCENT',
#   'score': 0.6582034,
#   'index': 381,
#   'word': '89',
#   'start': 1721,
#   'end': 1723},
#  {'entity': 'PERCENT',
#   'score': 0.996079,
#   'index': 382,
#   'word': '(',
#   'start': 1724,
#   'end': 1725},
#  {'entity': 'PERCENT',
#   'score': 0.99979585,
#   'index': 383,
#   'word': '57',
#   'start': 1725,
#   'end': 1727},
#  {'entity': 'PERCENT',
#   'score': 0.99036074,
#   'index': 384,
#   'word': '%',
#   'start': 1727,
#   'end': 1728},
#  {'entity': 'PERSON',
#   'score': 0.9501931,
#   'index': 385,
#   'word': ')',
#   'start': 1728,
#   'end': 1729},
#  {'entity': 'PERSON',
#   'score': 0.3662117,
#   'index': 386,
#   'word': 'из',
#   'start': 1730,
#   'end': 1732},
#  {'entity': 'NUMBER',
#   'score': 0.9988192,
#   'index': 387,
#   'word': '156',
#   'start': 1733,
#   'end': 1736},
#  {'entity': 'PERSON',
#   'score': 0.9998104,
#   'index': 388,
#   'word': 'обследова',
#   'start': 1737,
#   'end': 1746},
#  {'entity': 'PERSON',
#   'score': 0.9996648,
#   'index': 389,
#   'word': '##нных',
#   'start': 1746,
#   'end': 1750},
#  {'entity': 'PERSON',
#   'score': 0.99988437,
#   'index': 390,
#   'word': 'родственников',
#   'start': 1751,
#   'end': 1764},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.76328653,
#   'index': 391,
#   'word': 'диа',
#   'start': 1765,
#   'end': 1768},
#  {'entity': 'PERSON',
#   'score': 0.8889136,
#   'index': 392,
#   'word': '##лиз',
#   'start': 1768,
#   'end': 1771},
#  {'entity': 'PERSON',
#   'score': 0.9981907,
#   'index': 393,
#   'word': '##ных',
#   'start': 1771,
#   'end': 1774},
#  {'entity': 'PERSON',
#   'score': 0.99751496,
#   'index': 394,
#   'word': 'проба',
#   'start': 1775,
#   'end': 1780},
#  {'entity': 'PERSON',
#   'score': 0.9971232,
#   'index': 395,
#   'word': '##ндо',
#   'start': 1780,
#   'end': 1783},
#  {'entity': 'PERSON',
#   'score': 0.99854654,
#   'index': 396,
#   'word': '##в',
#   'start': 1783,
#   'end': 1784},
#  {'entity': 'FINDING',
#   'score': 0.4863591,
#   'index': 397,
#   'word': ',',
#   'start': 1784,
#   'end': 1785},
#  {'entity': 'DATE',
#   'score': 0.41846436,
#   'index': 398,
#   'word': 'в',
#   'start': 1786,
#   'end': 1787},
#  {'entity': 'FINDING',
#   'score': 0.16050069,
#   'index': 399,
#   'word': 'том',
#   'start': 1788,
#   'end': 1791},
#  {'entity': 'PERSON',
#   'score': 0.6032083,
#   'index': 400,
#   'word': 'числе',
#   'start': 1792,
#   'end': 1797},
#  {'entity': 'FINDING',
#   'score': 0.5236166,
#   'index': 401,
#   'word': 'у',
#   'start': 1798,
#   'end': 1799},
#  {'entity': 'NUMBER',
#   'score': 0.99707913,
#   'index': 402,
#   'word': '18',
#   'start': 1800,
#   'end': 1802},
#  {'entity': 'PERSON',
#   'score': 0.9997002,
#   'index': 403,
#   'word': 'детей',
#   'start': 1803,
#   'end': 1808},
#  {'entity': 'AGE',
#   'score': 0.9987286,
#   'index': 404,
#   'word': 'моложе',
#   'start': 1809,
#   'end': 1815},
#  {'entity': 'AGE',
#   'score': 0.9995004,
#   'index': 405,
#   'word': '18',
#   'start': 1816,
#   'end': 1818},
#  {'entity': 'AGE',
#   'score': 0.9879302,
#   'index': 406,
#   'word': 'лет',
#   'start': 1819,
#   'end': 1822},
#  {'entity': 'FINDING',
#   'score': 0.9811793,
#   'index': 407,
#   'word': ',',
#   'start': 1822,
#   'end': 1823},
#  {'entity': 'DISO',
#   'score': 0.80605173,
#   'index': 408,
#   'word': 'клинические',
#   'start': 1824,
#   'end': 1835},
#  {'entity': 'DISO',
#   'score': 0.8510169,
#   'index': 409,
#   'word': 'проявления',
#   'start': 1836,
#   'end': 1846},
#  {'entity': 'DISO',
#   'score': 0.99990153,
#   'index': 410,
#   'word': 'БФ',
#   'start': 1847,
#   'end': 1849},
#  {'entity': 'FINDING',
#   'score': 0.9892167,
#   'index': 411,
#   'word': 'имелись',
#   'start': 1850,
#   'end': 1857},
#  {'entity': 'FINDING',
#   'score': 0.62576604,
#   'index': 412,
#   'word': 'у',
#   'start': 1858,
#   'end': 1859},
#  {'entity': 'NUMBER',
#   'score': 0.9993266,
#   'index': 413,
#   'word': '48',
#   'start': 1860,
#   'end': 1862},
#  {'entity': 'PERSON',
#   'score': 0.999744,
#   'index': 414,
#   'word': 'родственников',
#   'start': 1863,
#   'end': 1876},
#  {'entity': 'FINDING',
#   'score': 0.68187857,
#   'index': 415,
#   'word': '.',
#   'start': 1876,
#   'end': 1877},
#  {'entity': 'FINDING',
#   'score': 0.9118078,
#   'index': 416,
#   'word': 'У',
#   'start': 1878,
#   'end': 1879},
#  {'entity': 'PERCENT',
#   'score': 0.999887,
#   'index': 417,
#   'word': '80',
#   'start': 1880,
#   'end': 1882},
#  {'entity': 'PERCENT',
#   'score': 0.9994973,
#   'index': 418,
#   'word': ',',
#   'start': 1882,
#   'end': 1883},
#  {'entity': 'PERCENT',
#   'score': 0.9996761,
#   'index': 419,
#   'word': '4',
#   'start': 1883,
#   'end': 1884},
#  {'entity': 'PERCENT',
#   'score': 0.941918,
#   'index': 420,
#   'word': '%',
#   'start': 1884,
#   'end': 1885},
#  {'entity': 'PERSON',
#   'score': 0.9998807,
#   'index': 421,
#   'word': 'обследова',
#   'start': 1886,
#   'end': 1895},
#  {'entity': 'PERSON',
#   'score': 0.9998419,
#   'index': 422,
#   'word': '##нных',
#   'start': 1895,
#   'end': 1899},
#  {'entity': 'PERSON',
#   'score': 0.99988925,
#   'index': 423,
#   'word': 'родственников',
#   'start': 1900,
#   'end': 1913},
#  {'entity': 'PERSON',
#   'score': 0.37938687,
#   'index': 424,
#   'word': 'диа',
#   'start': 1914,
#   'end': 1917},
#  {'entity': 'PERSON',
#   'score': 0.531556,
#   'index': 425,
#   'word': '##лиз',
#   'start': 1917,
#   'end': 1920},
#  {'entity': 'PERSON',
#   'score': 0.9776818,
#   'index': 426,
#   'word': '##ных',
#   'start': 1920,
#   'end': 1923},
#  {'entity': 'PERSON',
#   'score': 0.971073,
#   'index': 427,
#   'word': 'проба',
#   'start': 1924,
#   'end': 1929},
#  {'entity': 'PERSON',
#   'score': 0.87070787,
#   'index': 428,
#   'word': '##ндо',
#   'start': 1929,
#   'end': 1932},
#  {'entity': 'PERSON',
#   'score': 0.9310238,
#   'index': 429,
#   'word': '##в',
#   'start': 1932,
#   'end': 1933},
#  {'entity': 'FINDING',
#   'score': 0.9993579,
#   'index': 430,
#   'word': 'обнаружено',
#   'start': 1934,
#   'end': 1944},
#  {'entity': 'DISO',
#   'score': 0.99867994,
#   'index': 431,
#   'word': 'поражение',
#   'start': 1945,
#   'end': 1954},
#  {'entity': 'ANATOMY',
#   'score': 0.9998306,
#   'index': 432,
#   'word': 'почек',
#   'start': 1955,
#   'end': 1960},
#  {'entity': 'FINDING',
#   'score': 0.5450444,
#   'index': 433,
#   'word': ',',
#   'start': 1960,
#   'end': 1961},
#  {'entity': 'DISO',
#   'score': 0.72869956,
#   'index': 434,
#   'word': 'преимущественно',
#   'start': 1962,
#   'end': 1977},
#  {'entity': 'DISO',
#   'score': 0.7879851,
#   'index': 435,
#   'word': 'на',
#   'start': 1978,
#   'end': 1980},
#  {'entity': 'DISO',
#   'score': 0.7854724,
#   'index': 436,
#   'word': 'ранних',
#   'start': 1981,
#   'end': 1987},
#  {'entity': 'DISO',
#   'score': 0.94063663,
#   'index': 437,
#   'word': 'стадиях',
#   'start': 1988,
#   'end': 1995},
#  {'entity': 'DATE',
#   'score': 0.1658803,
#   'index': 438,
#   'word': '.',
#   'start': 1995,
#   'end': 1996},
#  {'entity': 'FINDING',
#   'score': 0.3485619,
#   'index': 439,
#   'word': 'Заключение',
#   'start': 1997,
#   'end': 2007},
#  {'entity': 'FINDING',
#   'score': 0.95937234,
#   'index': 440,
#   'word': '.',
#   'start': 2007,
#   'end': 2008},
#  {'entity': 'DISO',
#   'score': 0.99991095,
#   'index': 441,
#   'word': 'Т',
#   'start': 2009,
#   'end': 2010},
#  {'entity': 'DISO',
#   'score': 0.9998816,
#   'index': 442,
#   'word': '##Х',
#   'start': 2010,
#   'end': 2011},
#  {'entity': 'DISO',
#   'score': 0.99982977,
#   'index': 443,
#   'word': '##П',
#   'start': 2011,
#   'end': 2012},
#  {'entity': 'DISO',
#   'score': 0.99975806,
#   'index': 444,
#   'word': '##Н',
#   'start': 2012,
#   'end': 2013},
#  {'entity': 'DISO',
#   'score': 0.96465445,
#   'index': 445,
#   'word': 'нередко',
#   'start': 2014,
#   'end': 2021},
#  {'entity': 'DISO',
#   'score': 0.94315135,
#   'index': 446,
#   'word': '##е',
#   'start': 2021,
#   'end': 2022},
#  {'entity': 'DISO',
#   'score': 0.9997048,
#   'index': 447,
#   'word': 'ослож',
#   'start': 2023,
#   'end': 2028},
#  {'entity': 'DISO',
#   'score': 0.998694,
#   'index': 448,
#   'word': '##нение',
#   'start': 2028,
#   'end': 2033},
#  {'entity': 'DISO',
#   'score': 0.99991107,
#   'index': 449,
#   'word': 'БФ',
#   'start': 2034,
#   'end': 2036},
#  {'entity': 'FINDING',
#   'score': 0.83457035,
#   'index': 450,
#   'word': ',',
#   'start': 2036,
#   'end': 2037},
#  {'entity': 'FINDING',
#   'score': 0.99914527,
#   'index': 451,
#   'word': 'ассоции',
#   'start': 2038,
#   'end': 2045},
#  {'entity': 'FINDING',
#   'score': 0.5986831,
#   'index': 452,
#   'word': '##рованное',
#   'start': 2045,
#   'end': 2053},
#  {'entity': 'FINDING',
#   'score': 0.9987896,
#   'index': 453,
#   'word': 'с',
#   'start': 2054,
#   'end': 2055},
#  {'entity': 'FINDING',
#   'score': 0.9991849,
#   'index': 454,
#   'word': 'неблагоприят',
#   'start': 2056,
#   'end': 2068},
#  {'entity': 'FINDING',
#   'score': 0.8873732,
#   'index': 455,
#   'word': '##ным',
#   'start': 2068,
#   'end': 2071},
#  {'entity': 'PHYS',
#   'score': 0.9737593,
#   'index': 456,
#   'word': 'прогнозом',
#   'start': 2072,
#   'end': 2081},
#  {'entity': 'FINDING',
#   'score': 0.2157626,
#   'index': 457,
#   'word': '.',
#   'start': 2081,
#   'end': 2082},
#  {'entity': 'FINDING',
#   'score': 0.99282044,
#   'index': 458,
#   'word': 'Однако',
#   'start': 2083,
#   'end': 2089},
#  {'entity': 'MEDPROC',
#   'score': 0.97784984,
#   'index': 459,
#   'word': 'диа',
#   'start': 2090,
#   'end': 2093},
#  {'entity': 'MEDPROC',
#   'score': 0.51980454,
#   'index': 460,
#   'word': '##лиз',
#   'start': 2093,
#   'end': 2096},
#  {'entity': 'MEDPROC',
#   'score': 0.5587924,
#   'index': 461,
#   'word': '##ный',
#   'start': 2096,
#   'end': 2099},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.999331,
#   'index': 462,
#   'word': 'скрин',
#   'start': 2100,
#   'end': 2105},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.99796695,
#   'index': 463,
#   'word': '##инг',
#   'start': 2105,
#   'end': 2108},
#  {'entity': 'FINDING',
#   'score': 0.9971866,
#   'index': 464,
#   'word': '–',
#   'start': 2109,
#   'end': 2110},
#  {'entity': 'FINDING',
#   'score': 0.9995765,
#   'index': 465,
#   'word': 'эффективный',
#   'start': 2112,
#   'end': 2123},
#  {'entity': 'FINDING',
#   'score': 0.99412304,
#   'index': 466,
#   'word': 'способ',
#   'start': 2124,
#   'end': 2130},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.34389102,
#   'index': 467,
#   'word': 'выявления',
#   'start': 2131,
#   'end': 2140},
#  {'entity': 'PERSON',
#   'score': 0.99927515,
#   'index': 468,
#   'word': 'проба',
#   'start': 2141,
#   'end': 2146},
#  {'entity': 'PERSON',
#   'score': 0.99851185,
#   'index': 469,
#   'word': '##ндо',
#   'start': 2146,
#   'end': 2149},
#  {'entity': 'PERSON',
#   'score': 0.9993569,
#   'index': 470,
#   'word': '##в',
#   'start': 2149,
#   'end': 2150},
#  {'entity': 'DISO',
#   'score': 0.88616574,
#   'index': 471,
#   'word': 'с',
#   'start': 2151,
#   'end': 2152},
#  {'entity': 'DISO',
#   'score': 0.99990845,
#   'index': 472,
#   'word': 'БФ',
#   'start': 2153,
#   'end': 2155},
#  {'entity': 'FINDING',
#   'score': 0.99841774,
#   'index': 473,
#   'word': ',',
#   'start': 2155,
#   'end': 2156},
#  {'entity': 'FINDING',
#   'score': 0.99943095,
#   'index': 474,
#   'word': 'открываю',
#   'start': 2157,
#   'end': 2165},
#  {'entity': 'FINDING',
#   'score': 0.99888855,
#   'index': 475,
#   'word': '##щий',
#   'start': 2165,
#   'end': 2168},
#  {'entity': 'FINDING',
#   'score': 0.9956456,
#   'index': 476,
#   'word': 'возможность',
#   'start': 2169,
#   'end': 2180},
#  {'entity': 'FINDING',
#   'score': 0.7094188,
#   'index': 477,
#   'word': 'установить',
#   'start': 2181,
#   'end': 2191},
#  {'entity': 'MEDPROC',
#   'score': 0.5736632,
#   'index': 478,
#   'word': 'диагноз',
#   'start': 2192,
#   'end': 2199},
#  {'entity': 'DISO',
#   'score': 0.999907,
#   'index': 479,
#   'word': 'БФ',
#   'start': 2200,
#   'end': 2202},
#  {'entity': 'PERSON',
#   'score': 0.98781395,
#   'index': 480,
#   'word': 'у',
#   'start': 2203,
#   'end': 2204},
#  {'entity': 'PERSON',
#   'score': 0.9997845,
#   'index': 481,
#   'word': 'родственников',
#   'start': 2205,
#   'end': 2218},
#  {'entity': 'DATE',
#   'score': 0.40763676,
#   'index': 482,
#   'word': 'на',
#   'start': 2219,
#   'end': 2221},
#  {'entity': 'DISO',
#   'score': 0.3582385,
#   'index': 483,
#   'word': 'ранних',
#   'start': 2222,
#   'end': 2228},
#  {'entity': 'DISO',
#   'score': 0.6821047,
#   'index': 484,
#   'word': 'стадиях',
#   'start': 2229,
#   'end': 2236},
#  {'entity': 'FINDING',
#   'score': 0.806291,
#   'index': 485,
#   'word': ',',
#   'start': 2236,
#   'end': 2237},
#  {'entity': 'FINDING',
#   'score': 0.79915345,
#   'index': 486,
#   'word': 'когда',
#   'start': 2238,
#   'end': 2243},
#  {'entity': 'MEDPROC',
#   'score': 0.99104613,
#   'index': 487,
#   'word': 'лечение',
#   'start': 2244,
#   'end': 2251},
#  {'entity': 'FINDING',
#   'score': 0.99957603,
#   'index': 488,
#   'word': 'наиболее',
#   'start': 2252,
#   'end': 2260},
#  {'entity': 'FINDING',
#   'score': 0.9990734,
#   'index': 489,
#   'word': 'эффективно',
#   'start': 2261,
#   'end': 2271},
#  {'entity': 'FINDING',
#   'score': 0.34757012,
#   'index': 490,
#   'word': '.',
#   'start': 2271,
#   'end': 2272}]
