# %% [markdown]
# <a href="https://colab.research.google.com/github/ekaterinatao/NER_biomed_domain/blob/main/transformers_base/%D0%92%D0%9A%D0%A0_nerel_bio_RuBioBERT_base.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Инструменты
# Предобработанный дасасет [NEREL-BIO](https://huggingface.co/datasets/ekaterinatao/nerel_bio_ner_unnested)
# [Чек-пойнт](https://huggingface.co/ekaterinatao/nerel-bio-RuBioBERT-base) дообученной модели на всем датасете nerel-bio
#
# Исходная модель [RuBioBERT](https://huggingface.co/alexyalunin/RuBioBERT)

# %% [markdown]
# ### Установка зависимостей

# %%
# !pip install datasets accelerate evaluate wandb seqeval -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.7/536.7 kB 9.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 kB 11.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 10.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 24.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 5.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 13.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 17.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 17.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.5/258.5 kB 10.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.6 MB/s eta 0:00:00
#   Building wheel for seqeval (setup.py) ... done

# %%
import numpy as np
import pandas as pd
import random
from dataclasses import dataclass

import torch
import datasets
from datasets import Dataset, DatasetDict
from transformers import AutoTokenizer
from transformers import DataCollatorForTokenClassification
from transformers import AutoModelForTokenClassification
from transformers import TrainingArguments, Trainer
from transformers import pipeline
import evaluate

import warnings
warnings.filterwarnings("ignore")

# %%
@dataclass
class TrainingConfig:
    seed = 64
    dataset = 'ekaterinatao/nerel_bio_ner_unnested'
    checkpoint = 'alexyalunin/RuBioBERT'
    n_labels = 45
    n_epochs = 10
    train_batch_size = 4
    eval_batch_size = 4
    device = "cuda" if torch.cuda.is_available() else "cpu"
    l_rate = 5e-05
    w_decay = 0.1
    warm_up = 0.1

config = TrainingConfig()

# %%
seed = config.seed

random.seed(seed)
np.random.seed(seed)

torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %% [markdown]
# ### Скачивание датасета

# %%
dataset = datasets.load_dataset(config.dataset)
dataset
# Out:
# Downloading readme:   0%|          | 0.00/1.56k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/603k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/76.2k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/70.8k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/612 [00:00<?, ? examples/s]
# Generating valid split:   0%|          | 0/77 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/77 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'words', 'ner_tags'],
#         num_rows: 612
#     })
#     valid: Dataset({
#         features: ['id', 'words', 'ner_tags'],
#         num_rows: 77
#     })
#     test: Dataset({
#         features: ['id', 'words', 'ner_tags'],
#         num_rows: 77
#     })
# })

# %%
# Загрузка словаря токенов
url = 'https://raw.githubusercontent.com/ekaterinatao/NER_biomed_domain/main/labels.txt'
tags = pd.read_csv(url, names=['tag']).values.tolist()
tags = [item for sublist in tags for item in sublist]
tag_to_id = {tag: i for i, tag in enumerate(tags)}
id_to_tag = {i: tag for i, tag in enumerate(tags)}

# %%
tokenizer = AutoTokenizer.from_pretrained(config.checkpoint)
# Out:
# tokenizer_config.json:   0%|          | 0.00/413 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/1.78M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.75M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(examples["words"], truncation=True, max_length=512, is_split_into_words=True)

    labels = []
    for i, label in enumerate(examples[f"ner_tags"]):
        word_idxs = tokenized_inputs.word_ids(batch_index=i)  # Map tokens to their respective word.
        previous_word_idx = None
        label_ids = []
        for word_idx in word_idxs:
            if word_idx is None:
                label_ids.append(-100) # Set the special tokens to -100.
            elif word_idx != previous_word_idx:  # Only label the first token of a given word.
                label_ids.append(label[word_idx])
            else:
                label_ids.append(-100)
            previous_word_idx = word_idx
        labels.append(label_ids)

    tokenized_inputs["labels"] = labels
    return tokenized_inputs

# %%
tokenized_dataset = dataset.map(
    tokenize_and_align_labels, batched=True,
    remove_columns = ['id', 'words', 'ner_tags']
)
tokenized_dataset
# Out:
# Map:   0%|          | 0/612 [00:00<?, ? examples/s]
# Map:   0%|          | 0/77 [00:00<?, ? examples/s]
# Map:   0%|          | 0/77 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 612
#     })
#     valid: Dataset({
#         features: ['input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 77
#     })
#     test: Dataset({
#         features: ['input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 77
#     })
# })

# %% [markdown]
# # Обучение модели

# %%
seqeval = evaluate.load("seqeval")

def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=2)

    true_predictions = [
        [tags[p] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]
    true_labels = [
        [tags[l] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]

    results = seqeval.compute(predictions=true_predictions, references=true_labels)
    return {
        "precision": results["overall_precision"],
        "recall": results["overall_recall"],
        "f1": results["overall_f1"],
        "accuracy": results["overall_accuracy"],
    }
# Out:
# Downloading builder script:   0%|          | 0.00/6.34k [00:00<?, ?B/s]

# %%
data_collator = DataCollatorForTokenClassification(tokenizer=tokenizer)

# %%
print(f'device is {config.device}')
# Out:
# device is cuda

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
import wandb
wandb.login()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
import os
os.environ["WANDB_PROJECT"]="ner_bert_nerel_bio"
hf_repo_id = "ekaterinatao/nerel-bio-RuBioBERT-base"

# %% [markdown]
# # Обучение на полном датасете

# %%
model = AutoModelForTokenClassification.from_pretrained(
    config.checkpoint, num_labels=config.n_labels, id2label=id_to_tag, label2id=tag_to_id)

training_args = TrainingArguments(
    output_dir=hf_repo_id,
    num_train_epochs=config.n_epochs,
    learning_rate=config.l_rate,
    weight_decay=config.w_decay,
    warmup_ratio=config.warm_up,
    per_device_train_batch_size=config.train_batch_size,
    per_device_eval_batch_size=config.eval_batch_size,
    group_by_length=True,
    optim="adamw_torch",
    lr_scheduler_type="cosine",
    evaluation_strategy="epoch",
    seed = config.seed,
    data_seed = config.seed,
    push_to_hub=True,
    save_strategy="no",
    report_to="wandb",
    run_name="RuBioBERT-base_batch_4",
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset["train"],
    eval_dataset=tokenized_dataset["valid"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
# config.json:   0%|          | 0.00/889 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at alexyalunin/RuBioBERT and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# wandb: Currently logged in as: taoea. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.3
# Run data is saved locally in <code>/content/wandb/run-20240227_150109-rmemz8h4</code>
# Syncing run <strong><a href='https://wandb.ai/taoea/ner_bert_nerel_bio/runs/rmemz8h4' target="_blank">RuBioBERT-base_batch_4</a></strong> to <a href='https://wandb.ai/taoea/ner_bert_nerel_bio' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/taoea/ner_bert_nerel_bio' target="_blank">https://wandb.ai/taoea/ner_bert_nerel_bio</a>
#  View run at <a href='https://wandb.ai/taoea/ner_bert_nerel_bio/runs/rmemz8h4' target="_blank">https://wandb.ai/taoea/ner_bert_nerel_bio/runs/rmemz8h4</a>
#     <div>
#
#       <progress value='1530' max='1530' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1530/1530 02:31, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.893706</td>
#       <td>0.736277</td>
#       <td>0.707786</td>
#       <td>0.721751</td>
#       <td>0.799845</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.575283</td>
#       <td>0.790725</td>
#       <td>0.779784</td>
#       <td>0.785217</td>
#       <td>0.852681</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.530835</td>
#       <td>0.789350</td>
#       <td>0.785647</td>
#       <td>0.787494</td>
#       <td>0.855944</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.902500</td>
#       <td>0.547688</td>
#       <td>0.795641</td>
#       <td>0.796201</td>
#       <td>0.795921</td>
#       <td>0.861849</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.902500</td>
#       <td>0.573182</td>
#       <td>0.801075</td>
#       <td>0.803705</td>
#       <td>0.802388</td>
#       <td>0.864646</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.902500</td>
#       <td>0.555094</td>
#       <td>0.808541</td>
#       <td>0.808161</td>
#       <td>0.808351</td>
#       <td>0.869308</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.133000</td>
#       <td>0.581260</td>
#       <td>0.808161</td>
#       <td>0.808161</td>
#       <td>0.808161</td>
#       <td>0.870085</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.133000</td>
#       <td>0.600553</td>
#       <td>0.805343</td>
#       <td>0.813086</td>
#       <td>0.809196</td>
#       <td>0.868687</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.133000</td>
#       <td>0.618291</td>
#       <td>0.810389</td>
#       <td>0.815901</td>
#       <td>0.813135</td>
#       <td>0.872261</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.040600</td>
#       <td>0.618693</td>
#       <td>0.810723</td>
#       <td>0.815666</td>
#       <td>0.813187</td>
#       <td>0.872106</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1530, training_loss=0.3522425438453949, metrics={'train_runtime': 155.4088, 'train_samples_per_second': 39.38, 'train_steps_per_second': 9.845, 'total_flos': 868743082982520.0, 'train_loss': 0.3522425438453949, 'epoch': 10.0})

# %%
wandb.finish()
# Out:
# VBox(children=(Label(value='0.022 MB of 0.022 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>▁▆▆▇▇█████</td></tr><tr><td>eval/f1</td><td>▁▆▆▇▇█████</td></tr><tr><td>eval/loss</td><td>█▂▁▁▂▁▂▂▃▃</td></tr><tr><td>eval/precision</td><td>▁▆▆▇▇██▇██</td></tr><tr><td>eval/recall</td><td>▁▆▆▇▇▇▇███</td></tr><tr><td>eval/runtime</td><td>▃▂▂▂▁█▁▂▁█</td></tr><tr><td>eval/samples_per_second</td><td>▆▇▇▇█▁▇▇█▁</td></tr><tr><td>eval/steps_per_second</td><td>▆▇▇▇█▁▇▇█▁</td></tr><tr><td>train/epoch</td><td>▁▂▃▃▃▄▅▅▆▆▇███</td></tr><tr><td>train/global_step</td><td>▁▂▃▃▃▄▅▅▆▆▇███</td></tr><tr><td>train/learning_rate</td><td>█▄▁</td></tr><tr><td>train/loss</td><td>█▂▁</td></tr><tr><td>train/total_flos</td><td>▁</td></tr><tr><td>train/train_loss</td><td>▁</td></tr><tr><td>train/train_runtime</td><td>▁</td></tr><tr><td>train/train_samples_per_second</td><td>▁</td></tr><tr><td>train/train_steps_per_second</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>0.87211</td></tr><tr><td>eval/f1</td><td>0.81319</td></tr><tr><td>eval/loss</td><td>0.61869</td></tr><tr><td>eval/precision</td><td>0.81072</td></tr><tr><td>eval/recall</td><td>0.81567</td></tr><tr><td>eval/runtime</td><td>1.1608</td></tr><tr><td>eval/samples_per_second</td><td>66.332</td></tr><tr><td>eval/steps_per_second</td><td>17.229</td></tr><tr><td>train/epoch</td><td>10.0</td></tr><tr><td>train/global_step</td><td>1530</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>train/loss</td><td>0.0406</td></tr><tr><td>train/total_flos</td><td>868743082982520.0</td></tr><tr><td>train/train_loss</td><td>0.35224</td></tr><tr><td>train/train_runtime</td><td>155.4088</td></tr><tr><td>train/train_samples_per_second</td><td>39.38</td></tr><tr><td>train/train_steps_per_second</td><td>9.845</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">RuBioBERT-base_batch_4</strong> at: <a href='https://wandb.ai/taoea/ner_bert_nerel_bio/runs/rmemz8h4' target="_blank">https://wandb.ai/taoea/ner_bert_nerel_bio/runs/rmemz8h4</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240227_150109-rmemz8h4/logs</code>

# %%
trainer.save_model(hf_repo_id)
# Out:
# model.safetensors:   0%|          | 0.00/711M [00:00<?, ?B/s]
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# training_args.bin:   0%|          | 0.00/4.79k [00:00<?, ?B/s]

# %% [markdown]
# ### Оценка качества на тестовой выборке

# %%
predictions = trainer.predict(test_dataset=tokenized_dataset["test"])

# %%
predictions.metrics
# Out:
# {'test_loss': 0.5603048801422119,
#  'test_precision': 0.8299205010840761,
#  'test_recall': 0.8231780167264038,
#  'test_f1': 0.8265355086372361,
#  'test_accuracy': 0.8898814357641709,
#  'test_runtime': 0.8317,
#  'test_samples_per_second': 92.578,
#  'test_steps_per_second': 24.046}

# %% [markdown]
# Оценка модели на абстракте, которого не было в тестовом наборе

# %%
ner_bio = pipeline("ner", model=model, tokenizer=tokenizer, device=config.device)

# %%
abstract = """Цель. Оценить выживаемость у пациентов с болезнью Фабри (БФ) в зависимости от вида заместительной почечной терапии, и определить роль диализного скрининга в ранней диагностике БФ у родственников.
Материалы и методы. В исследование включали взрослых (старше 18 лет) пациентов с подтвержденным диагнозом БФ. Терминальная стадия хронической почечной недостаточности (тХПН) диагностировали в соответствии с рекомендациями Научного общества нефрологов России (2016) и KDIGO (2012). На основании опроса пробандов выявляли его родственников, которые могли унаследовать мутантный ген.
Результаты. У 50 (24,9%) из 201 обследованных пациентов с БФ диагностирована тХПН, в том числе у 48 (40%) из 120 мужчин и 2 (2,7%) из 81 женщин. Оценка кумулятивной частоты методом Каплана-Майера демонстрирует выраженное увеличение частоты регистрации тХПН к возрасту 20-30 лет, а к возрасту 50 лет ожидаемое количество пациентов с тХПН составляет 95%. Пяти из 50 больных с тХПН была выполнена трансплантация почки, в среднем, через 17 месяцев (диапазон от 7 до 70 месяцев) после инициации лечения гемодиализом. Умерло 15 (30%) из 50 пациентов, получавших лечение гемодиализом. Все умершие пациенты были мужского пола. Медиана возраста на момент летального исхода составила 45 (39; 58) лет. Среди пациентов, которым проведена трансплантация почки, летальных исходов зарегистрировано не было. У 44 (88%) из 50 пациентов диагноз БФ установлен, в среднем, через 1 год (диапазон от 0 до 12 лет) после начала лечения программным гемодиализом, в том числе у одного пациента – после трансплантации почки. Среди 44 пробандов, выявленных при всероссийском диализном скрининге, проведен семейный скрининг. Патогенная мутация в гене GLA диагностирована у 89 (57%) из 156 обследованных родственников диализных пробандов, в том числе у 18 детей моложе 18 лет, клинические проявления БФ имелись у 48 родственников. У 80,4% обследованных родственников диализных пробандов обнаружено поражение почек, преимущественно на ранних стадиях.
Заключение. ТХПН нередкое осложнение БФ, ассоциированное с неблагоприятным прогнозом. Однако диализный скрининг –  эффективный способ выявления пробандов с БФ, открывающий возможность установить диагноз БФ у родственников на ранних стадиях, когда лечение наиболее эффективно.
"""

# %%
ner_bio(abstract)
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# [{'entity': 'SCIPROC',
#   'score': 0.16079731,
#   'index': 1,
#   'word': 'Цель',
#   'start': 0,
#   'end': 4},
#  {'entity': 'SCIPROC',
#   'score': 0.23720512,
#   'index': 2,
#   'word': '.',
#   'start': 4,
#   'end': 5},
#  {'entity': 'SCIPROC',
#   'score': 0.5926297,
#   'index': 3,
#   'word': 'Оцени',
#   'start': 6,
#   'end': 11},
#  {'entity': 'FINDING',
#   'score': 0.66653377,
#   'index': 4,
#   'word': '##ть',
#   'start': 11,
#   'end': 13},
#  {'entity': 'PHYS',
#   'score': 0.91353697,
#   'index': 5,
#   'word': 'выжи',
#   'start': 14,
#   'end': 18},
#  {'entity': 'PHYS',
#   'score': 0.8990054,
#   'index': 6,
#   'word': '##ваемость',
#   'start': 18,
#   'end': 26},
#  {'entity': 'PERSON',
#   'score': 0.34884652,
#   'index': 7,
#   'word': 'у',
#   'start': 27,
#   'end': 28},
#  {'entity': 'PERSON',
#   'score': 0.98654556,
#   'index': 8,
#   'word': 'пациентов',
#   'start': 29,
#   'end': 38},
#  {'entity': 'DISO',
#   'score': 0.98012084,
#   'index': 9,
#   'word': 'с',
#   'start': 39,
#   'end': 40},
#  {'entity': 'DISO',
#   'score': 0.9962953,
#   'index': 10,
#   'word': 'болезнью',
#   'start': 41,
#   'end': 49},
#  {'entity': 'DISO',
#   'score': 0.39411256,
#   'index': 11,
#   'word': 'Фабри',
#   'start': 50,
#   'end': 55},
#  {'entity': 'DISO',
#   'score': 0.66622704,
#   'index': 12,
#   'word': '(',
#   'start': 56,
#   'end': 57},
#  {'entity': 'DISO',
#   'score': 0.99598324,
#   'index': 13,
#   'word': 'БФ',
#   'start': 57,
#   'end': 59},
#  {'entity': 'DISO',
#   'score': 0.6351465,
#   'index': 14,
#   'word': ')',
#   'start': 59,
#   'end': 60},
#  {'entity': 'DATE',
#   'score': 0.506448,
#   'index': 15,
#   'word': 'в',
#   'start': 61,
#   'end': 62},
#  {'entity': 'SCIPROC',
#   'score': 0.15617378,
#   'index': 16,
#   'word': 'зависимости',
#   'start': 63,
#   'end': 74},
#  {'entity': 'PHYS',
#   'score': 0.18806036,
#   'index': 17,
#   'word': 'от',
#   'start': 75,
#   'end': 77},
#  {'entity': 'MEDPROC',
#   'score': 0.9919749,
#   'index': 18,
#   'word': 'вида',
#   'start': 78,
#   'end': 82},
#  {'entity': 'MEDPROC',
#   'score': 0.9959728,
#   'index': 19,
#   'word': 'заместитель',
#   'start': 83,
#   'end': 94},
#  {'entity': 'MEDPROC',
#   'score': 0.9958877,
#   'index': 20,
#   'word': '##ной',
#   'start': 94,
#   'end': 97},
#  {'entity': 'MEDPROC',
#   'score': 0.98811626,
#   'index': 21,
#   'word': 'почечной',
#   'start': 98,
#   'end': 106},
#  {'entity': 'MEDPROC',
#   'score': 0.9953818,
#   'index': 22,
#   'word': 'терапии',
#   'start': 107,
#   'end': 114},
#  {'entity': 'SCIPROC',
#   'score': 0.111347675,
#   'index': 23,
#   'word': ',',
#   'start': 114,
#   'end': 115},
#  {'entity': 'SCIPROC',
#   'score': 0.6238902,
#   'index': 24,
#   'word': 'и',
#   'start': 116,
#   'end': 117},
#  {'entity': 'FINDING',
#   'score': 0.4459193,
#   'index': 25,
#   'word': 'определить',
#   'start': 118,
#   'end': 128},
#  {'entity': 'FINDING',
#   'score': 0.65452963,
#   'index': 26,
#   'word': 'роль',
#   'start': 129,
#   'end': 133},
#  {'entity': 'MEDPROC',
#   'score': 0.9927983,
#   'index': 27,
#   'word': 'диа',
#   'start': 134,
#   'end': 137},
#  {'entity': 'MEDPROC',
#   'score': 0.98664004,
#   'index': 28,
#   'word': '##лиз',
#   'start': 137,
#   'end': 140},
#  {'entity': 'MEDPROC',
#   'score': 0.9779041,
#   'index': 29,
#   'word': '##ного',
#   'start': 140,
#   'end': 144},
#  {'entity': 'MEDPROC',
#   'score': 0.90445936,
#   'index': 30,
#   'word': 'скрин',
#   'start': 145,
#   'end': 150},
#  {'entity': 'MEDPROC',
#   'score': 0.90975577,
#   'index': 31,
#   'word': '##инга',
#   'start': 150,
#   'end': 154},
#  {'entity': 'FINDING',
#   'score': 0.89444005,
#   'index': 32,
#   'word': 'в',
#   'start': 155,
#   'end': 156},
#  {'entity': 'FINDING',
#   'score': 0.9298661,
#   'index': 33,
#   'word': 'ранней',
#   'start': 157,
#   'end': 163},
#  {'entity': 'FINDING',
#   'score': 0.51362145,
#   'index': 34,
#   'word': 'диагностике',
#   'start': 164,
#   'end': 175},
#  {'entity': 'DISO',
#   'score': 0.996865,
#   'index': 35,
#   'word': 'БФ',
#   'start': 176,
#   'end': 178},
#  {'entity': 'PERSON',
#   'score': 0.5242029,
#   'index': 36,
#   'word': 'у',
#   'start': 179,
#   'end': 180},
#  {'entity': 'PERSON',
#   'score': 0.9843717,
#   'index': 37,
#   'word': 'родственников',
#   'start': 181,
#   'end': 194},
#  {'entity': 'SCIPROC',
#   'score': 0.15774941,
#   'index': 38,
#   'word': '.',
#   'start': 194,
#   'end': 195},
#  {'entity': 'SCIPROC',
#   'score': 0.46235552,
#   'index': 39,
#   'word': 'Материалы',
#   'start': 196,
#   'end': 205},
#  {'entity': 'SCIPROC',
#   'score': 0.32755888,
#   'index': 40,
#   'word': 'и',
#   'start': 206,
#   'end': 207},
#  {'entity': 'SCIPROC',
#   'score': 0.32706785,
#   'index': 41,
#   'word': 'методы',
#   'start': 208,
#   'end': 214},
#  {'entity': 'MEDPROC',
#   'score': 0.30038574,
#   'index': 42,
#   'word': '.',
#   'start': 214,
#   'end': 215},
#  {'entity': 'SCIPROC',
#   'score': 0.55853254,
#   'index': 43,
#   'word': 'В',
#   'start': 216,
#   'end': 217},
#  {'entity': 'SCIPROC',
#   'score': 0.9214151,
#   'index': 44,
#   'word': 'исследование',
#   'start': 218,
#   'end': 230},
#  {'entity': 'PERSON',
#   'score': 0.4579199,
#   'index': 45,
#   'word': 'включали',
#   'start': 231,
#   'end': 239},
#  {'entity': 'PERSON',
#   'score': 0.9822404,
#   'index': 46,
#   'word': 'взрослых',
#   'start': 240,
#   'end': 248},
#  {'entity': 'PERSON',
#   'score': 0.44378304,
#   'index': 47,
#   'word': '(',
#   'start': 249,
#   'end': 250},
#  {'entity': 'AGE',
#   'score': 0.9916433,
#   'index': 48,
#   'word': 'старше',
#   'start': 250,
#   'end': 256},
#  {'entity': 'AGE',
#   'score': 0.9917389,
#   'index': 49,
#   'word': '18',
#   'start': 257,
#   'end': 259},
#  {'entity': 'AGE',
#   'score': 0.9876172,
#   'index': 50,
#   'word': 'лет',
#   'start': 260,
#   'end': 263},
#  {'entity': 'PERSON',
#   'score': 0.97162735,
#   'index': 51,
#   'word': ')',
#   'start': 263,
#   'end': 264},
#  {'entity': 'PERSON',
#   'score': 0.9915889,
#   'index': 52,
#   'word': 'пациентов',
#   'start': 265,
#   'end': 274},
#  {'entity': 'FINDING',
#   'score': 0.51896405,
#   'index': 53,
#   'word': 'с',
#   'start': 275,
#   'end': 276},
#  {'entity': 'DISO',
#   'score': 0.4042433,
#   'index': 54,
#   'word': 'подтвержден',
#   'start': 277,
#   'end': 288},
#  {'entity': 'DISO',
#   'score': 0.40830615,
#   'index': 55,
#   'word': '##ным',
#   'start': 288,
#   'end': 291},
#  {'entity': 'DISO',
#   'score': 0.88892555,
#   'index': 56,
#   'word': 'диагнозом',
#   'start': 292,
#   'end': 301},
#  {'entity': 'DISO',
#   'score': 0.9966642,
#   'index': 57,
#   'word': 'БФ',
#   'start': 302,
#   'end': 304},
#  {'entity': 'DISO',
#   'score': 0.26159322,
#   'index': 58,
#   'word': '.',
#   'start': 304,
#   'end': 305},
#  {'entity': 'DISO',
#   'score': 0.9965654,
#   'index': 59,
#   'word': 'Терминал',
#   'start': 306,
#   'end': 314},
#  {'entity': 'DISO',
#   'score': 0.99656916,
#   'index': 60,
#   'word': '##ь',
#   'start': 314,
#   'end': 315},
#  {'entity': 'DISO',
#   'score': 0.996384,
#   'index': 61,
#   'word': '##ная',
#   'start': 315,
#   'end': 318},
#  {'entity': 'DISO',
#   'score': 0.99576867,
#   'index': 62,
#   'word': 'стадия',
#   'start': 319,
#   'end': 325},
#  {'entity': 'DISO',
#   'score': 0.9968045,
#   'index': 63,
#   'word': 'хронической',
#   'start': 326,
#   'end': 337},
#  {'entity': 'DISO',
#   'score': 0.99146605,
#   'index': 64,
#   'word': 'почечной',
#   'start': 338,
#   'end': 346},
#  {'entity': 'DISO',
#   'score': 0.9946371,
#   'index': 65,
#   'word': 'недостаточности',
#   'start': 347,
#   'end': 362},
#  {'entity': 'DISO',
#   'score': 0.9786854,
#   'index': 66,
#   'word': '(',
#   'start': 363,
#   'end': 364},
#  {'entity': 'DISO',
#   'score': 0.9968939,
#   'index': 67,
#   'word': 'т',
#   'start': 364,
#   'end': 365},
#  {'entity': 'DISO',
#   'score': 0.9957694,
#   'index': 68,
#   'word': '##Х',
#   'start': 365,
#   'end': 366},
#  {'entity': 'DISO',
#   'score': 0.9930408,
#   'index': 69,
#   'word': '##П',
#   'start': 366,
#   'end': 367},
#  {'entity': 'DISO',
#   'score': 0.9933084,
#   'index': 70,
#   'word': '##Н',
#   'start': 367,
#   'end': 368},
#  {'entity': 'DISO',
#   'score': 0.8750878,
#   'index': 71,
#   'word': ')',
#   'start': 368,
#   'end': 369},
#  {'entity': 'DISO',
#   'score': 0.5870834,
#   'index': 72,
#   'word': 'диагностировали',
#   'start': 370,
#   'end': 385},
#  {'entity': 'SCIPROC',
#   'score': 0.64993817,
#   'index': 73,
#   'word': 'в',
#   'start': 386,
#   'end': 387},
#  {'entity': 'SCIPROC',
#   'score': 0.8249243,
#   'index': 74,
#   'word': 'соответствии',
#   'start': 388,
#   'end': 400},
#  {'entity': 'SCIPROC',
#   'score': 0.8799799,
#   'index': 75,
#   'word': 'с',
#   'start': 401,
#   'end': 402},
#  {'entity': 'SCIPROC',
#   'score': 0.95572275,
#   'index': 76,
#   'word': 'рекомендациями',
#   'start': 403,
#   'end': 417},
#  {'entity': 'ORGANIZATION',
#   'score': 0.9757193,
#   'index': 77,
#   'word': 'Научного',
#   'start': 418,
#   'end': 426},
#  {'entity': 'ORGANIZATION',
#   'score': 0.96733487,
#   'index': 78,
#   'word': 'общества',
#   'start': 427,
#   'end': 435},
#  {'entity': 'PROFESSION',
#   'score': 0.7025518,
#   'index': 79,
#   'word': 'неф',
#   'start': 436,
#   'end': 439},
#  {'entity': 'PROFESSION',
#   'score': 0.9160019,
#   'index': 80,
#   'word': '##рол',
#   'start': 439,
#   'end': 442},
#  {'entity': 'PROFESSION',
#   'score': 0.91588986,
#   'index': 81,
#   'word': '##ого',
#   'start': 442,
#   'end': 445},
#  {'entity': 'PROFESSION',
#   'score': 0.84585476,
#   'index': 82,
#   'word': '##в',
#   'start': 445,
#   'end': 446},
#  {'entity': 'COUNTRY',
#   'score': 0.97616106,
#   'index': 83,
#   'word': 'России',
#   'start': 447,
#   'end': 453},
#  {'entity': 'DATE',
#   'score': 0.803617,
#   'index': 84,
#   'word': '(',
#   'start': 454,
#   'end': 455},
#  {'entity': 'DATE',
#   'score': 0.89157796,
#   'index': 85,
#   'word': '2016',
#   'start': 455,
#   'end': 459},
#  {'entity': 'SCIPROC',
#   'score': 0.2787098,
#   'index': 86,
#   'word': ')',
#   'start': 459,
#   'end': 460},
#  {'entity': 'SCIPROC',
#   'score': 0.9544636,
#   'index': 87,
#   'word': 'и',
#   'start': 461,
#   'end': 462},
#  {'entity': 'SCIPROC',
#   'score': 0.9682053,
#   'index': 88,
#   'word': 'K',
#   'start': 463,
#   'end': 464},
#  {'entity': 'SCIPROC',
#   'score': 0.9157486,
#   'index': 89,
#   'word': '##DI',
#   'start': 464,
#   'end': 466},
#  {'entity': 'SCIPROC',
#   'score': 0.7675328,
#   'index': 90,
#   'word': '##GO',
#   'start': 466,
#   'end': 468},
#  {'entity': 'DATE',
#   'score': 0.7035299,
#   'index': 91,
#   'word': '(',
#   'start': 469,
#   'end': 470},
#  {'entity': 'DATE',
#   'score': 0.7599494,
#   'index': 92,
#   'word': '2012',
#   'start': 470,
#   'end': 474},
#  {'entity': 'SCIPROC',
#   'score': 0.561007,
#   'index': 93,
#   'word': ')',
#   'start': 474,
#   'end': 475},
#  {'entity': 'SCIPROC',
#   'score': 0.5971493,
#   'index': 94,
#   'word': '.',
#   'start': 475,
#   'end': 476},
#  {'entity': 'SCIPROC',
#   'score': 0.70268846,
#   'index': 95,
#   'word': 'На',
#   'start': 477,
#   'end': 479},
#  {'entity': 'SCIPROC',
#   'score': 0.8148696,
#   'index': 96,
#   'word': 'основании',
#   'start': 480,
#   'end': 489},
#  {'entity': 'MEDPROC',
#   'score': 0.44244403,
#   'index': 97,
#   'word': 'опроса',
#   'start': 490,
#   'end': 496},
#  {'entity': 'PERSON',
#   'score': 0.40286657,
#   'index': 98,
#   'word': 'проба',
#   'start': 497,
#   'end': 502},
#  {'entity': 'PROFESSION',
#   'score': 0.5467749,
#   'index': 99,
#   'word': '##ндо',
#   'start': 502,
#   'end': 505},
#  {'entity': 'PROFESSION',
#   'score': 0.63338274,
#   'index': 100,
#   'word': '##в',
#   'start': 505,
#   'end': 506},
#  {'entity': 'FINDING',
#   'score': 0.37173712,
#   'index': 101,
#   'word': 'выявля',
#   'start': 507,
#   'end': 513},
#  {'entity': 'FINDING',
#   'score': 0.3806657,
#   'index': 102,
#   'word': '##ли',
#   'start': 513,
#   'end': 515},
#  {'entity': 'PERSON',
#   'score': 0.902057,
#   'index': 103,
#   'word': 'его',
#   'start': 516,
#   'end': 519},
#  {'entity': 'PERSON',
#   'score': 0.9549242,
#   'index': 104,
#   'word': 'родственников',
#   'start': 520,
#   'end': 533},
#  {'entity': 'FINDING',
#   'score': 0.2630266,
#   'index': 105,
#   'word': ',',
#   'start': 533,
#   'end': 534},
#  {'entity': 'PERSON',
#   'score': 0.34311062,
#   'index': 106,
#   'word': 'которые',
#   'start': 535,
#   'end': 542},
#  {'entity': 'PHYS',
#   'score': 0.23557355,
#   'index': 107,
#   'word': 'могли',
#   'start': 543,
#   'end': 548},
#  {'entity': 'PHYS',
#   'score': 0.5247907,
#   'index': 108,
#   'word': 'унаследова',
#   'start': 549,
#   'end': 559},
#  {'entity': 'PHYS',
#   'score': 0.40536073,
#   'index': 109,
#   'word': '##ть',
#   'start': 559,
#   'end': 561},
#  {'entity': 'GENE',
#   'score': 0.44801822,
#   'index': 110,
#   'word': 'мутант',
#   'start': 562,
#   'end': 568},
#  {'entity': 'GENE',
#   'score': 0.772544,
#   'index': 111,
#   'word': '##ный',
#   'start': 568,
#   'end': 571},
#  {'entity': 'GENE',
#   'score': 0.9545818,
#   'index': 112,
#   'word': 'ген',
#   'start': 572,
#   'end': 575},
#  {'entity': 'SCIPROC',
#   'score': 0.22721727,
#   'index': 113,
#   'word': '.',
#   'start': 575,
#   'end': 576},
#  {'entity': 'FINDING',
#   'score': 0.5315558,
#   'index': 114,
#   'word': 'Результаты',
#   'start': 577,
#   'end': 587},
#  {'entity': 'FINDING',
#   'score': 0.43340865,
#   'index': 115,
#   'word': '.',
#   'start': 587,
#   'end': 588},
#  {'entity': 'DATE',
#   'score': 0.1713733,
#   'index': 116,
#   'word': 'У',
#   'start': 589,
#   'end': 590},
#  {'entity': 'NUMBER',
#   'score': 0.5753701,
#   'index': 117,
#   'word': '50',
#   'start': 591,
#   'end': 593},
#  {'entity': 'PERCENT',
#   'score': 0.8686823,
#   'index': 118,
#   'word': '(',
#   'start': 594,
#   'end': 595},
#  {'entity': 'PERCENT',
#   'score': 0.9926726,
#   'index': 119,
#   'word': '24',
#   'start': 595,
#   'end': 597},
#  {'entity': 'PERCENT',
#   'score': 0.96865743,
#   'index': 120,
#   'word': ',',
#   'start': 597,
#   'end': 598},
#  {'entity': 'PERCENT',
#   'score': 0.9643832,
#   'index': 121,
#   'word': '9',
#   'start': 598,
#   'end': 599},
#  {'entity': 'PERCENT',
#   'score': 0.86809635,
#   'index': 122,
#   'word': '%',
#   'start': 599,
#   'end': 600},
#  {'entity': 'PERSON',
#   'score': 0.6405567,
#   'index': 123,
#   'word': ')',
#   'start': 600,
#   'end': 601},
#  {'entity': 'PERSON',
#   'score': 0.3004636,
#   'index': 124,
#   'word': 'из',
#   'start': 602,
#   'end': 604},
#  {'entity': 'NUMBER',
#   'score': 0.8208506,
#   'index': 125,
#   'word': '201',
#   'start': 605,
#   'end': 608},
#  {'entity': 'PERSON',
#   'score': 0.98623776,
#   'index': 126,
#   'word': 'обследова',
#   'start': 609,
#   'end': 618},
#  {'entity': 'PERSON',
#   'score': 0.99125284,
#   'index': 127,
#   'word': '##нных',
#   'start': 618,
#   'end': 622},
#  {'entity': 'PERSON',
#   'score': 0.99268734,
#   'index': 128,
#   'word': 'пациентов',
#   'start': 623,
#   'end': 632},
#  {'entity': 'DISO',
#   'score': 0.7045186,
#   'index': 129,
#   'word': 'с',
#   'start': 633,
#   'end': 634},
#  {'entity': 'DISO',
#   'score': 0.99703574,
#   'index': 130,
#   'word': 'БФ',
#   'start': 635,
#   'end': 637},
#  {'entity': 'FINDING',
#   'score': 0.6643677,
#   'index': 131,
#   'word': 'диагности',
#   'start': 638,
#   'end': 647},
#  {'entity': 'DISO',
#   'score': 0.6195331,
#   'index': 132,
#   'word': '##рована',
#   'start': 647,
#   'end': 653},
#  {'entity': 'DISO',
#   'score': 0.9969361,
#   'index': 133,
#   'word': 'т',
#   'start': 654,
#   'end': 655},
#  {'entity': 'DISO',
#   'score': 0.9959586,
#   'index': 134,
#   'word': '##Х',
#   'start': 655,
#   'end': 656},
#  {'entity': 'DISO',
#   'score': 0.99276334,
#   'index': 135,
#   'word': '##П',
#   'start': 656,
#   'end': 657},
#  {'entity': 'DISO',
#   'score': 0.9942514,
#   'index': 136,
#   'word': '##Н',
#   'start': 657,
#   'end': 658},
#  {'entity': 'FINDING',
#   'score': 0.43233344,
#   'index': 137,
#   'word': ',',
#   'start': 658,
#   'end': 659},
#  {'entity': 'PERCENT',
#   'score': 0.399396,
#   'index': 138,
#   'word': 'в',
#   'start': 660,
#   'end': 661},
#  {'entity': 'PERCENT',
#   'score': 0.26394883,
#   'index': 139,
#   'word': 'том',
#   'start': 662,
#   'end': 665},
#  {'entity': 'PERCENT',
#   'score': 0.2836843,
#   'index': 140,
#   'word': 'числе',
#   'start': 666,
#   'end': 671},
#  {'entity': 'NUMBER',
#   'score': 0.14832345,
#   'index': 141,
#   'word': 'у',
#   'start': 672,
#   'end': 673},
#  {'entity': 'PERCENT',
#   'score': 0.6269758,
#   'index': 142,
#   'word': '48',
#   'start': 674,
#   'end': 676},
#  {'entity': 'PERCENT',
#   'score': 0.977775,
#   'index': 143,
#   'word': '(',
#   'start': 677,
#   'end': 678},
#  {'entity': 'PERCENT',
#   'score': 0.9934203,
#   'index': 144,
#   'word': '40',
#   'start': 678,
#   'end': 680},
#  {'entity': 'PERCENT',
#   'score': 0.95010275,
#   'index': 145,
#   'word': '%',
#   'start': 680,
#   'end': 681},
#  {'entity': 'PERSON',
#   'score': 0.3083789,
#   'index': 146,
#   'word': ')',
#   'start': 681,
#   'end': 682},
#  {'entity': 'PERSON',
#   'score': 0.23970665,
#   'index': 147,
#   'word': 'из',
#   'start': 683,
#   'end': 685},
#  {'entity': 'NUMBER',
#   'score': 0.9437666,
#   'index': 148,
#   'word': '120',
#   'start': 686,
#   'end': 689},
#  {'entity': 'PERSON',
#   'score': 0.9721681,
#   'index': 149,
#   'word': 'мужчин',
#   'start': 690,
#   'end': 696},
#  {'entity': 'PERSON',
#   'score': 0.399808,
#   'index': 150,
#   'word': 'и',
#   'start': 697,
#   'end': 698},
#  {'entity': 'NUMBER',
#   'score': 0.4986533,
#   'index': 151,
#   'word': '2',
#   'start': 699,
#   'end': 700},
#  {'entity': 'PERCENT',
#   'score': 0.9736111,
#   'index': 152,
#   'word': '(',
#   'start': 701,
#   'end': 702},
#  {'entity': 'PERCENT',
#   'score': 0.99326235,
#   'index': 153,
#   'word': '2',
#   'start': 702,
#   'end': 703},
#  {'entity': 'PERCENT',
#   'score': 0.98511326,
#   'index': 154,
#   'word': ',',
#   'start': 703,
#   'end': 704},
#  {'entity': 'PERCENT',
#   'score': 0.9905509,
#   'index': 155,
#   'word': '7',
#   'start': 704,
#   'end': 705},
#  {'entity': 'PERCENT',
#   'score': 0.97075224,
#   'index': 156,
#   'word': '%',
#   'start': 705,
#   'end': 706},
#  {'entity': 'PERSON',
#   'score': 0.31203747,
#   'index': 157,
#   'word': ')',
#   'start': 706,
#   'end': 707},
#  {'entity': 'PERCENT',
#   'score': 0.15792355,
#   'index': 158,
#   'word': 'из',
#   'start': 708,
#   'end': 710},
#  {'entity': 'NUMBER',
#   'score': 0.9518535,
#   'index': 159,
#   'word': '81',
#   'start': 711,
#   'end': 713},
#  {'entity': 'PERSON',
#   'score': 0.9483068,
#   'index': 160,
#   'word': 'женщин',
#   'start': 714,
#   'end': 720},
#  {'entity': 'SCIPROC',
#   'score': 0.24730393,
#   'index': 161,
#   'word': '.',
#   'start': 720,
#   'end': 721},
#  {'entity': 'SCIPROC',
#   'score': 0.94439685,
#   'index': 162,
#   'word': 'Оценка',
#   'start': 722,
#   'end': 728},
#  {'entity': 'SCIPROC',
#   'score': 0.6364645,
#   'index': 163,
#   'word': 'кумуля',
#   'start': 729,
#   'end': 735},
#  {'entity': 'SCIPROC',
#   'score': 0.8666294,
#   'index': 164,
#   'word': '##тивной',
#   'start': 735,
#   'end': 741},
#  {'entity': 'SCIPROC',
#   'score': 0.699222,
#   'index': 165,
#   'word': 'частоты',
#   'start': 742,
#   'end': 749},
#  {'entity': 'SCIPROC',
#   'score': 0.99018455,
#   'index': 166,
#   'word': 'методом',
#   'start': 750,
#   'end': 757},
#  {'entity': 'SCIPROC',
#   'score': 0.9899671,
#   'index': 167,
#   'word': 'Каплан',
#   'start': 758,
#   'end': 764},
#  {'entity': 'SCIPROC',
#   'score': 0.9832538,
#   'index': 168,
#   'word': '##а',
#   'start': 764,
#   'end': 765},
#  {'entity': 'SCIPROC',
#   'score': 0.9298903,
#   'index': 169,
#   'word': '-',
#   'start': 765,
#   'end': 766},
#  {'entity': 'SCIPROC',
#   'score': 0.9685551,
#   'index': 170,
#   'word': 'Майер',
#   'start': 766,
#   'end': 771},
#  {'entity': 'SCIPROC',
#   'score': 0.9803525,
#   'index': 171,
#   'word': '##а',
#   'start': 771,
#   'end': 772},
#  {'entity': 'FINDING',
#   'score': 0.96301645,
#   'index': 172,
#   'word': 'демонстрирует',
#   'start': 773,
#   'end': 786},
#  {'entity': 'FINDING',
#   'score': 0.991314,
#   'index': 173,
#   'word': 'выраженное',
#   'start': 787,
#   'end': 797},
#  {'entity': 'FINDING',
#   'score': 0.9926416,
#   'index': 174,
#   'word': 'увеличение',
#   'start': 798,
#   'end': 808},
#  {'entity': 'PHYS',
#   'score': 0.49820054,
#   'index': 175,
#   'word': 'частоты',
#   'start': 809,
#   'end': 816},
#  {'entity': 'FINDING',
#   'score': 0.9474223,
#   'index': 176,
#   'word': 'регистрации',
#   'start': 817,
#   'end': 828},
#  {'entity': 'DISO',
#   'score': 0.99686867,
#   'index': 177,
#   'word': 'т',
#   'start': 829,
#   'end': 830},
#  {'entity': 'DISO',
#   'score': 0.9955682,
#   'index': 178,
#   'word': '##Х',
#   'start': 830,
#   'end': 831},
#  {'entity': 'DISO',
#   'score': 0.9934924,
#   'index': 179,
#   'word': '##П',
#   'start': 831,
#   'end': 832},
#  {'entity': 'DISO',
#   'score': 0.9941836,
#   'index': 180,
#   'word': '##Н',
#   'start': 832,
#   'end': 833},
#  {'entity': 'AGE',
#   'score': 0.7126922,
#   'index': 181,
#   'word': 'к',
#   'start': 834,
#   'end': 835},
#  {'entity': 'AGE',
#   'score': 0.97260565,
#   'index': 182,
#   'word': 'возрасту',
#   'start': 836,
#   'end': 844},
#  {'entity': 'AGE',
#   'score': 0.99358565,
#   'index': 183,
#   'word': '20',
#   'start': 845,
#   'end': 847},
#  {'entity': 'AGE',
#   'score': 0.989748,
#   'index': 184,
#   'word': '-',
#   'start': 847,
#   'end': 848},
#  {'entity': 'AGE',
#   'score': 0.9913284,
#   'index': 185,
#   'word': '30',
#   'start': 848,
#   'end': 850},
#  {'entity': 'AGE',
#   'score': 0.98859954,
#   'index': 186,
#   'word': 'лет',
#   'start': 851,
#   'end': 854},
#  {'entity': 'FINDING',
#   'score': 0.7898696,
#   'index': 187,
#   'word': ',',
#   'start': 854,
#   'end': 855},
#  {'entity': 'FINDING',
#   'score': 0.5590511,
#   'index': 188,
#   'word': 'а',
#   'start': 856,
#   'end': 857},
#  {'entity': 'AGE',
#   'score': 0.88733804,
#   'index': 189,
#   'word': 'к',
#   'start': 858,
#   'end': 859},
#  {'entity': 'AGE',
#   'score': 0.98507535,
#   'index': 190,
#   'word': 'возрасту',
#   'start': 860,
#   'end': 868},
#  {'entity': 'AGE',
#   'score': 0.9926882,
#   'index': 191,
#   'word': '50',
#   'start': 869,
#   'end': 871},
#  {'entity': 'AGE',
#   'score': 0.98958415,
#   'index': 192,
#   'word': 'лет',
#   'start': 872,
#   'end': 875},
#  {'entity': 'FINDING',
#   'score': 0.9873165,
#   'index': 193,
#   'word': 'ожидаемо',
#   'start': 876,
#   'end': 884},
#  {'entity': 'FINDING',
#   'score': 0.99000907,
#   'index': 194,
#   'word': '##е',
#   'start': 884,
#   'end': 885},
#  {'entity': 'FINDING',
#   'score': 0.9743497,
#   'index': 195,
#   'word': 'количество',
#   'start': 886,
#   'end': 896},
#  {'entity': 'PERSON',
#   'score': 0.95828396,
#   'index': 196,
#   'word': 'пациентов',
#   'start': 897,
#   'end': 906},
#  {'entity': 'FINDING',
#   'score': 0.5843735,
#   'index': 197,
#   'word': 'с',
#   'start': 907,
#   'end': 908},
#  {'entity': 'DISO',
#   'score': 0.9973876,
#   'index': 198,
#   'word': 'т',
#   'start': 909,
#   'end': 910},
#  {'entity': 'DISO',
#   'score': 0.9956197,
#   'index': 199,
#   'word': '##Х',
#   'start': 910,
#   'end': 911},
#  {'entity': 'DISO',
#   'score': 0.98903906,
#   'index': 200,
#   'word': '##П',
#   'start': 911,
#   'end': 912},
#  {'entity': 'DISO',
#   'score': 0.99391115,
#   'index': 201,
#   'word': '##Н',
#   'start': 912,
#   'end': 913},
#  {'entity': 'FINDING',
#   'score': 0.9778952,
#   'index': 202,
#   'word': 'составляет',
#   'start': 914,
#   'end': 924},
#  {'entity': 'PERCENT',
#   'score': 0.9904163,
#   'index': 203,
#   'word': '95',
#   'start': 925,
#   'end': 927},
#  {'entity': 'PERCENT',
#   'score': 0.8758903,
#   'index': 204,
#   'word': '%',
#   'start': 927,
#   'end': 928},
#  {'entity': 'FINDING',
#   'score': 0.24250512,
#   'index': 205,
#   'word': '.',
#   'start': 928,
#   'end': 929},
#  {'entity': 'NUMBER',
#   'score': 0.9223065,
#   'index': 206,
#   'word': 'Пяти',
#   'start': 930,
#   'end': 934},
#  {'entity': 'PERCENT',
#   'score': 0.17431681,
#   'index': 207,
#   'word': 'из',
#   'start': 935,
#   'end': 937},
#  {'entity': 'NUMBER',
#   'score': 0.94928056,
#   'index': 208,
#   'word': '50',
#   'start': 938,
#   'end': 940},
#  {'entity': 'PERSON',
#   'score': 0.9892352,
#   'index': 209,
#   'word': 'больных',
#   'start': 941,
#   'end': 948},
#  {'entity': 'DISO',
#   'score': 0.68771076,
#   'index': 210,
#   'word': 'с',
#   'start': 949,
#   'end': 950},
#  {'entity': 'DISO',
#   'score': 0.99731976,
#   'index': 211,
#   'word': 'т',
#   'start': 951,
#   'end': 952},
#  {'entity': 'DISO',
#   'score': 0.9956589,
#   'index': 212,
#   'word': '##Х',
#   'start': 952,
#   'end': 953},
#  {'entity': 'DISO',
#   'score': 0.9908529,
#   'index': 213,
#   'word': '##П',
#   'start': 953,
#   'end': 954},
#  {'entity': 'DISO',
#   'score': 0.9934974,
#   'index': 214,
#   'word': '##Н',
#   'start': 954,
#   'end': 955},
#  {'entity': 'MEDPROC',
#   'score': 0.99091995,
#   'index': 215,
#   'word': 'была',
#   'start': 956,
#   'end': 960},
#  {'entity': 'MEDPROC',
#   'score': 0.99446326,
#   'index': 216,
#   'word': 'выполнена',
#   'start': 961,
#   'end': 970},
#  {'entity': 'MEDPROC',
#   'score': 0.9956458,
#   'index': 217,
#   'word': 'транспланта',
#   'start': 971,
#   'end': 982},
#  {'entity': 'MEDPROC',
#   'score': 0.99517256,
#   'index': 218,
#   'word': '##ция',
#   'start': 982,
#   'end': 985},
#  {'entity': 'ANATOMY',
#   'score': 0.99541265,
#   'index': 219,
#   'word': 'почки',
#   'start': 986,
#   'end': 991},
#  {'entity': 'FINDING',
#   'score': 0.31315058,
#   'index': 220,
#   'word': ',',
#   'start': 991,
#   'end': 992},
#  {'entity': 'DATE',
#   'score': 0.94203246,
#   'index': 221,
#   'word': 'в',
#   'start': 993,
#   'end': 994},
#  {'entity': 'DATE',
#   'score': 0.8758253,
#   'index': 222,
#   'word': 'среднем',
#   'start': 995,
#   'end': 1002},
#  {'entity': 'DATE',
#   'score': 0.5429586,
#   'index': 223,
#   'word': ',',
#   'start': 1002,
#   'end': 1003},
#  {'entity': 'DATE',
#   'score': 0.98966974,
#   'index': 224,
#   'word': 'через',
#   'start': 1004,
#   'end': 1009},
#  {'entity': 'DATE',
#   'score': 0.99003637,
#   'index': 225,
#   'word': '17',
#   'start': 1010,
#   'end': 1012},
#  {'entity': 'DATE',
#   'score': 0.9872541,
#   'index': 226,
#   'word': 'месяцев',
#   'start': 1013,
#   'end': 1020},
#  {'entity': 'DATE',
#   'score': 0.9719017,
#   'index': 227,
#   'word': '(',
#   'start': 1021,
#   'end': 1022},
#  {'entity': 'DATE',
#   'score': 0.55231124,
#   'index': 228,
#   'word': 'диапазон',
#   'start': 1022,
#   'end': 1030},
#  {'entity': 'DATE',
#   'score': 0.96326727,
#   'index': 229,
#   'word': 'от',
#   'start': 1031,
#   'end': 1033},
#  {'entity': 'DATE',
#   'score': 0.9898588,
#   'index': 230,
#   'word': '7',
#   'start': 1034,
#   'end': 1035},
#  {'entity': 'DATE',
#   'score': 0.9318302,
#   'index': 231,
#   'word': 'до',
#   'start': 1036,
#   'end': 1038},
#  {'entity': 'DATE',
#   'score': 0.9768897,
#   'index': 232,
#   'word': '70',
#   'start': 1039,
#   'end': 1041},
#  {'entity': 'DATE',
#   'score': 0.9802941,
#   'index': 233,
#   'word': 'месяцев',
#   'start': 1042,
#   'end': 1049},
#  {'entity': 'DATE',
#   'score': 0.8394915,
#   'index': 234,
#   'word': ')',
#   'start': 1049,
#   'end': 1050},
#  {'entity': 'DATE',
#   'score': 0.4231242,
#   'index': 235,
#   'word': 'после',
#   'start': 1051,
#   'end': 1056},
#  {'entity': 'MEDPROC',
#   'score': 0.99287486,
#   'index': 236,
#   'word': 'инициации',
#   'start': 1057,
#   'end': 1066},
#  {'entity': 'MEDPROC',
#   'score': 0.9946778,
#   'index': 237,
#   'word': 'лечения',
#   'start': 1067,
#   'end': 1074},
#  {'entity': 'MEDPROC',
#   'score': 0.9940538,
#   'index': 238,
#   'word': 'гемо',
#   'start': 1075,
#   'end': 1079},
#  {'entity': 'MEDPROC',
#   'score': 0.994105,
#   'index': 239,
#   'word': '##диа',
#   'start': 1079,
#   'end': 1082},
#  {'entity': 'MEDPROC',
#   'score': 0.992781,
#   'index': 240,
#   'word': '##лиз',
#   'start': 1082,
#   'end': 1085},
#  {'entity': 'MEDPROC',
#   'score': 0.99064016,
#   'index': 241,
#   'word': '##ом',
#   'start': 1085,
#   'end': 1087},
#  {'entity': 'FINDING',
#   'score': 0.21878114,
#   'index': 242,
#   'word': '.',
#   'start': 1087,
#   'end': 1088},
#  {'entity': 'FINDING',
#   'score': 0.40503165,
#   'index': 243,
#   'word': 'Умер',
#   'start': 1089,
#   'end': 1093},
#  {'entity': 'FINDING',
#   'score': 0.44350463,
#   'index': 244,
#   'word': '##ло',
#   'start': 1093,
#   'end': 1095},
#  {'entity': 'NUMBER',
#   'score': 0.4886471,
#   'index': 245,
#   'word': '15',
#   'start': 1096,
#   'end': 1098},
#  {'entity': 'PERCENT',
#   'score': 0.9575347,
#   'index': 246,
#   'word': '(',
#   'start': 1099,
#   'end': 1100},
#  {'entity': 'PERCENT',
#   'score': 0.9931977,
#   'index': 247,
#   'word': '30',
#   'start': 1100,
#   'end': 1102},
#  {'entity': 'PERCENT',
#   'score': 0.9148354,
#   'index': 248,
#   'word': '%',
#   'start': 1102,
#   'end': 1103},
#  {'entity': 'PERSON',
#   'score': 0.31296164,
#   'index': 249,
#   'word': ')',
#   'start': 1103,
#   'end': 1104},
#  {'entity': 'PERSON',
#   'score': 0.14757034,
#   'index': 250,
#   'word': 'из',
#   'start': 1105,
#   'end': 1107},
#  {'entity': 'NUMBER',
#   'score': 0.91284674,
#   'index': 251,
#   'word': '50',
#   'start': 1108,
#   'end': 1110},
#  {'entity': 'PERSON',
#   'score': 0.9831445,
#   'index': 252,
#   'word': 'пациентов',
#   'start': 1111,
#   'end': 1120},
#  {'entity': 'PERSON',
#   'score': 0.6669116,
#   'index': 253,
#   'word': ',',
#   'start': 1120,
#   'end': 1121},
#  {'entity': 'MEDPROC',
#   'score': 0.9916045,
#   'index': 254,
#   'word': 'получа',
#   'start': 1122,
#   'end': 1128},
#  {'entity': 'MEDPROC',
#   'score': 0.7827737,
#   'index': 255,
#   'word': '##вших',
#   'start': 1128,
#   'end': 1132},
#  {'entity': 'MEDPROC',
#   'score': 0.9955023,
#   'index': 256,
#   'word': 'лечение',
#   'start': 1133,
#   'end': 1140},
#  {'entity': 'MEDPROC',
#   'score': 0.99513185,
#   'index': 257,
#   'word': 'гемо',
#   'start': 1141,
#   'end': 1145},
#  {'entity': 'MEDPROC',
#   'score': 0.9949851,
#   'index': 258,
#   'word': '##диа',
#   'start': 1145,
#   'end': 1148},
#  {'entity': 'MEDPROC',
#   'score': 0.9946679,
#   'index': 259,
#   'word': '##лиз',
#   'start': 1148,
#   'end': 1151},
#  {'entity': 'MEDPROC',
#   'score': 0.99344504,
#   'index': 260,
#   'word': '##ом',
#   'start': 1151,
#   'end': 1153},
#  {'entity': 'SCIPROC',
#   'score': 0.13105673,
#   'index': 261,
#   'word': '.',
#   'start': 1153,
#   'end': 1154},
#  {'entity': 'PERSON',
#   'score': 0.26216674,
#   'index': 262,
#   'word': 'Все',
#   'start': 1155,
#   'end': 1158},
#  {'entity': 'PERSON',
#   'score': 0.6993784,
#   'index': 263,
#   'word': 'умер',
#   'start': 1159,
#   'end': 1163},
#  {'entity': 'PERSON',
#   'score': 0.8191883,
#   'index': 264,
#   'word': '##шие',
#   'start': 1163,
#   'end': 1166},
#  {'entity': 'PERSON',
#   'score': 0.98588413,
#   'index': 265,
#   'word': 'пациенты',
#   'start': 1167,
#   'end': 1175},
#  {'entity': 'PHYS',
#   'score': 0.45722318,
#   'index': 266,
#   'word': 'были',
#   'start': 1176,
#   'end': 1180},
#  {'entity': 'PHYS',
#   'score': 0.98768383,
#   'index': 267,
#   'word': 'мужского',
#   'start': 1181,
#   'end': 1189},
#  {'entity': 'PHYS',
#   'score': 0.984335,
#   'index': 268,
#   'word': 'пола',
#   'start': 1190,
#   'end': 1194},
#  {'entity': 'FINDING',
#   'score': 0.2571666,
#   'index': 269,
#   'word': '.',
#   'start': 1194,
#   'end': 1195},
#  {'entity': 'FINDING',
#   'score': 0.881756,
#   'index': 270,
#   'word': 'Медиа',
#   'start': 1196,
#   'end': 1201},
#  {'entity': 'FINDING',
#   'score': 0.80937594,
#   'index': 271,
#   'word': '##на',
#   'start': 1201,
#   'end': 1203},
#  {'entity': 'PHYS',
#   'score': 0.9799597,
#   'index': 272,
#   'word': 'возраста',
#   'start': 1204,
#   'end': 1212},
#  {'entity': 'DATE',
#   'score': 0.8106098,
#   'index': 273,
#   'word': 'на',
#   'start': 1213,
#   'end': 1215},
#  {'entity': 'PHYS',
#   'score': 0.26525477,
#   'index': 274,
#   'word': 'момент',
#   'start': 1216,
#   'end': 1222},
#  {'entity': 'FINDING',
#   'score': 0.456427,
#   'index': 275,
#   'word': 'летального',
#   'start': 1223,
#   'end': 1233},
#  {'entity': 'FINDING',
#   'score': 0.6148817,
#   'index': 276,
#   'word': 'исхода',
#   'start': 1234,
#   'end': 1240},
#  {'entity': 'FINDING',
#   'score': 0.9144435,
#   'index': 277,
#   'word': 'составила',
#   'start': 1241,
#   'end': 1250},
#  {'entity': 'AGE',
#   'score': 0.9880827,
#   'index': 278,
#   'word': '45',
#   'start': 1251,
#   'end': 1253},
#  {'entity': 'AGE',
#   'score': 0.86485267,
#   'index': 279,
#   'word': '(',
#   'start': 1254,
#   'end': 1255},
#  {'entity': 'AGE',
#   'score': 0.98987633,
#   'index': 280,
#   'word': '39',
#   'start': 1255,
#   'end': 1257},
#  {'entity': 'AGE',
#   'score': 0.1691762,
#   'index': 281,
#   'word': ';',
#   'start': 1257,
#   'end': 1258},
#  {'entity': 'AGE',
#   'score': 0.95492667,
#   'index': 282,
#   'word': '58',
#   'start': 1259,
#   'end': 1261},
#  {'entity': 'AGE',
#   'score': 0.15894693,
#   'index': 283,
#   'word': ')',
#   'start': 1261,
#   'end': 1262},
#  {'entity': 'AGE',
#   'score': 0.95430636,
#   'index': 284,
#   'word': 'лет',
#   'start': 1263,
#   'end': 1266},
#  {'entity': 'FINDING',
#   'score': 0.12595956,
#   'index': 285,
#   'word': '.',
#   'start': 1266,
#   'end': 1267},
#  {'entity': 'FINDING',
#   'score': 0.3186374,
#   'index': 286,
#   'word': 'Среди',
#   'start': 1268,
#   'end': 1273},
#  {'entity': 'PERSON',
#   'score': 0.98361325,
#   'index': 287,
#   'word': 'пациентов',
#   'start': 1274,
#   'end': 1283},
#  {'entity': 'PERSON',
#   'score': 0.2714977,
#   'index': 288,
#   'word': ',',
#   'start': 1283,
#   'end': 1284},
#  {'entity': 'PERSON',
#   'score': 0.5766645,
#   'index': 289,
#   'word': 'которым',
#   'start': 1285,
#   'end': 1292},
#  {'entity': 'MEDPROC',
#   'score': 0.995369,
#   'index': 290,
#   'word': 'проведена',
#   'start': 1293,
#   'end': 1302},
#  {'entity': 'MEDPROC',
#   'score': 0.9957475,
#   'index': 291,
#   'word': 'транспланта',
#   'start': 1303,
#   'end': 1314},
#  {'entity': 'MEDPROC',
#   'score': 0.995526,
#   'index': 292,
#   'word': '##ция',
#   'start': 1314,
#   'end': 1317},
#  {'entity': 'ANATOMY',
#   'score': 0.995167,
#   'index': 293,
#   'word': 'почки',
#   'start': 1318,
#   'end': 1323},
#  {'entity': 'FINDING',
#   'score': 0.9470645,
#   'index': 294,
#   'word': ',',
#   'start': 1323,
#   'end': 1324},
#  {'entity': 'FINDING',
#   'score': 0.9834062,
#   'index': 295,
#   'word': 'летальных',
#   'start': 1325,
#   'end': 1334},
#  {'entity': 'FINDING',
#   'score': 0.98339474,
#   'index': 296,
#   'word': 'исход',
#   'start': 1335,
#   'end': 1340},
#  {'entity': 'FINDING',
#   'score': 0.97418255,
#   'index': 297,
#   'word': '##ов',
#   'start': 1340,
#   'end': 1342},
#  {'entity': 'FINDING',
#   'score': 0.98238856,
#   'index': 298,
#   'word': 'зарегистрировано',
#   'start': 1343,
#   'end': 1359},
#  {'entity': 'FINDING',
#   'score': 0.9500921,
#   'index': 299,
#   'word': 'не',
#   'start': 1360,
#   'end': 1362},
#  {'entity': 'FINDING',
#   'score': 0.9683284,
#   'index': 300,
#   'word': 'было',
#   'start': 1363,
#   'end': 1367},
#  {'entity': 'FINDING',
#   'score': 0.2359871,
#   'index': 301,
#   'word': '.',
#   'start': 1367,
#   'end': 1368},
#  {'entity': 'FINDING',
#   'score': 0.16166742,
#   'index': 302,
#   'word': 'У',
#   'start': 1369,
#   'end': 1370},
#  {'entity': 'NUMBER',
#   'score': 0.60989803,
#   'index': 303,
#   'word': '44',
#   'start': 1371,
#   'end': 1373},
#  {'entity': 'PERCENT',
#   'score': 0.9171461,
#   'index': 304,
#   'word': '(',
#   'start': 1374,
#   'end': 1375},
#  {'entity': 'PERCENT',
#   'score': 0.99147475,
#   'index': 305,
#   'word': '88',
#   'start': 1375,
#   'end': 1377},
#  {'entity': 'PERCENT',
#   'score': 0.88197,
#   'index': 306,
#   'word': '%',
#   'start': 1377,
#   'end': 1378},
#  {'entity': 'PERSON',
#   'score': 0.5761748,
#   'index': 307,
#   'word': ')',
#   'start': 1378,
#   'end': 1379},
#  {'entity': 'PERSON',
#   'score': 0.25702456,
#   'index': 308,
#   'word': 'из',
#   'start': 1380,
#   'end': 1382},
#  {'entity': 'NUMBER',
#   'score': 0.9403822,
#   'index': 309,
#   'word': '50',
#   'start': 1383,
#   'end': 1385},
#  {'entity': 'PERSON',
#   'score': 0.9892039,
#   'index': 310,
#   'word': 'пациентов',
#   'start': 1386,
#   'end': 1395},
#  {'entity': 'FINDING',
#   'score': 0.7966474,
#   'index': 311,
#   'word': 'диагноз',
#   'start': 1396,
#   'end': 1403},
#  {'entity': 'DISO',
#   'score': 0.99443805,
#   'index': 312,
#   'word': 'БФ',
#   'start': 1404,
#   'end': 1406},
#  {'entity': 'FINDING',
#   'score': 0.7702129,
#   'index': 313,
#   'word': 'установлен',
#   'start': 1407,
#   'end': 1417},
#  {'entity': 'FINDING',
#   'score': 0.5226715,
#   'index': 314,
#   'word': ',',
#   'start': 1417,
#   'end': 1418},
#  {'entity': 'DATE',
#   'score': 0.82972413,
#   'index': 315,
#   'word': 'в',
#   'start': 1419,
#   'end': 1420},
#  {'entity': 'DATE',
#   'score': 0.62120074,
#   'index': 316,
#   'word': 'среднем',
#   'start': 1421,
#   'end': 1428},
#  {'entity': 'DATE',
#   'score': 0.4030324,
#   'index': 317,
#   'word': ',',
#   'start': 1428,
#   'end': 1429},
#  {'entity': 'DATE',
#   'score': 0.9791058,
#   'index': 318,
#   'word': 'через',
#   'start': 1430,
#   'end': 1435},
#  {'entity': 'DATE',
#   'score': 0.9906365,
#   'index': 319,
#   'word': '1',
#   'start': 1436,
#   'end': 1437},
#  {'entity': 'DATE',
#   'score': 0.9786694,
#   'index': 320,
#   'word': 'год',
#   'start': 1438,
#   'end': 1441},
#  {'entity': 'DATE',
#   'score': 0.9363945,
#   'index': 321,
#   'word': '(',
#   'start': 1442,
#   'end': 1443},
#  {'entity': 'DATE',
#   'score': 0.36420295,
#   'index': 322,
#   'word': 'диапазон',
#   'start': 1443,
#   'end': 1451},
#  {'entity': 'DATE',
#   'score': 0.8324953,
#   'index': 323,
#   'word': 'от',
#   'start': 1452,
#   'end': 1454},
#  {'entity': 'DATE',
#   'score': 0.78500026,
#   'index': 324,
#   'word': '0',
#   'start': 1455,
#   'end': 1456},
#  {'entity': 'DATE',
#   'score': 0.9040528,
#   'index': 325,
#   'word': 'до',
#   'start': 1457,
#   'end': 1459},
#  {'entity': 'DATE',
#   'score': 0.9678872,
#   'index': 326,
#   'word': '12',
#   'start': 1460,
#   'end': 1462},
#  {'entity': 'DATE',
#   'score': 0.96045256,
#   'index': 327,
#   'word': 'лет',
#   'start': 1463,
#   'end': 1466},
#  {'entity': 'DATE',
#   'score': 0.59768623,
#   'index': 328,
#   'word': ')',
#   'start': 1466,
#   'end': 1467},
#  {'entity': 'DATE',
#   'score': 0.6610944,
#   'index': 329,
#   'word': 'после',
#   'start': 1468,
#   'end': 1473},
#  {'entity': 'MEDPROC',
#   'score': 0.977002,
#   'index': 330,
#   'word': 'начала',
#   'start': 1474,
#   'end': 1480},
#  {'entity': 'MEDPROC',
#   'score': 0.9954572,
#   'index': 331,
#   'word': 'лечения',
#   'start': 1481,
#   'end': 1488},
#  {'entity': 'MEDPROC',
#   'score': 0.9955095,
#   'index': 332,
#   'word': 'программным',
#   'start': 1489,
#   'end': 1500},
#  {'entity': 'MEDPROC',
#   'score': 0.99369335,
#   'index': 333,
#   'word': 'гемо',
#   'start': 1501,
#   'end': 1505},
#  {'entity': 'MEDPROC',
#   'score': 0.9942326,
#   'index': 334,
#   'word': '##диа',
#   'start': 1505,
#   'end': 1508},
#  {'entity': 'MEDPROC',
#   'score': 0.9937691,
#   'index': 335,
#   'word': '##лиз',
#   'start': 1508,
#   'end': 1511},
#  {'entity': 'MEDPROC',
#   'score': 0.9934388,
#   'index': 336,
#   'word': '##ом',
#   'start': 1511,
#   'end': 1513},
#  {'entity': 'DATE',
#   'score': 0.20974159,
#   'index': 337,
#   'word': ',',
#   'start': 1513,
#   'end': 1514},
#  {'entity': 'DATE',
#   'score': 0.28692383,
#   'index': 338,
#   'word': 'в',
#   'start': 1515,
#   'end': 1516},
#  {'entity': 'NUMBER',
#   'score': 0.134061,
#   'index': 339,
#   'word': 'том',
#   'start': 1517,
#   'end': 1520},
#  {'entity': 'NUMBER',
#   'score': 0.34907573,
#   'index': 340,
#   'word': 'числе',
#   'start': 1521,
#   'end': 1526},
#  {'entity': 'NUMBER',
#   'score': 0.24061967,
#   'index': 341,
#   'word': 'у',
#   'start': 1527,
#   'end': 1528},
#  {'entity': 'NUMBER',
#   'score': 0.93443793,
#   'index': 342,
#   'word': 'одного',
#   'start': 1529,
#   'end': 1535},
#  {'entity': 'PERSON',
#   'score': 0.9900765,
#   'index': 343,
#   'word': 'пациента',
#   'start': 1536,
#   'end': 1544},
#  {'entity': 'PERSON',
#   'score': 0.21465519,
#   'index': 344,
#   'word': '–',
#   'start': 1545,
#   'end': 1546},
#  {'entity': 'MEDPROC',
#   'score': 0.9130173,
#   'index': 345,
#   'word': 'после',
#   'start': 1547,
#   'end': 1552},
#  {'entity': 'MEDPROC',
#   'score': 0.99575126,
#   'index': 346,
#   'word': 'трансплантации',
#   'start': 1553,
#   'end': 1567},
#  {'entity': 'ANATOMY',
#   'score': 0.9953584,
#   'index': 347,
#   'word': 'почки',
#   'start': 1568,
#   'end': 1573},
#  {'entity': 'SCIPROC',
#   'score': 0.17175478,
#   'index': 348,
#   'word': '.',
#   'start': 1573,
#   'end': 1574},
#  {'entity': 'PERSON',
#   'score': 0.20424716,
#   'index': 349,
#   'word': 'Среди',
#   'start': 1575,
#   'end': 1580},
#  {'entity': 'NUMBER',
#   'score': 0.9638382,
#   'index': 350,
#   'word': '44',
#   'start': 1581,
#   'end': 1583},
#  {'entity': 'PERSON',
#   'score': 0.5249766,
#   'index': 351,
#   'word': 'проба',
#   'start': 1584,
#   'end': 1589},
#  {'entity': 'PERSON',
#   'score': 0.42620736,
#   'index': 352,
#   'word': '##ндо',
#   'start': 1589,
#   'end': 1592},
#  {'entity': 'PERSON',
#   'score': 0.64774317,
#   'index': 353,
#   'word': '##в',
#   'start': 1592,
#   'end': 1593},
#  {'entity': 'PERSON',
#   'score': 0.36729008,
#   'index': 354,
#   'word': ',',
#   'start': 1593,
#   'end': 1594},
#  {'entity': 'MEDPROC',
#   'score': 0.30785277,
#   'index': 355,
#   'word': 'выявленных',
#   'start': 1595,
#   'end': 1605},
#  {'entity': 'MEDPROC',
#   'score': 0.8247997,
#   'index': 356,
#   'word': 'при',
#   'start': 1606,
#   'end': 1609},
#  {'entity': 'HEALTH_CARE_ACTIVITY',
#   'score': 0.38318732,
#   'index': 357,
#   'word': 'всероссий',
#   'start': 1610,
#   'end': 1619},
#  {'entity': 'MEDPROC',
#   'score': 0.43635368,
#   'index': 358,
#   'word': '##ском',
#   'start': 1619,
#   'end': 1623},
#  {'entity': 'MEDPROC',
#   'score': 0.9851494,
#   'index': 359,
#   'word': 'диа',
#   'start': 1624,
#   'end': 1627},
#  {'entity': 'MEDPROC',
#   'score': 0.9638271,
#   'index': 360,
#   'word': '##лиз',
#   'start': 1627,
#   'end': 1630},
#  {'entity': 'MEDPROC',
#   'score': 0.7409989,
#   'index': 361,
#   'word': '##ном',
#   'start': 1630,
#   'end': 1633},
#  {'entity': 'MEDPROC',
#   'score': 0.71613383,
#   'index': 362,
#   'word': 'скрин',
#   'start': 1634,
#   'end': 1639},
#  {'entity': 'MEDPROC',
#   'score': 0.5753188,
#   'index': 363,
#   'word': '##инг',
#   'start': 1639,
#   'end': 1642},
#  {'entity': 'MEDPROC',
#   'score': 0.5889233,
#   'index': 364,
#   'word': '##е',
#   'start': 1642,
#   'end': 1643},
#  {'entity': 'MEDPROC',
#   'score': 0.84712726,
#   'index': 365,
#   'word': ',',
#   'start': 1643,
#   'end': 1644},
#  {'entity': 'MEDPROC',
#   'score': 0.9012759,
#   'index': 366,
#   'word': 'проведен',
#   'start': 1645,
#   'end': 1653},
#  {'entity': 'MEDPROC',
#   'score': 0.6339988,
#   'index': 367,
#   'word': 'семейный',
#   'start': 1654,
#   'end': 1662},
#  {'entity': 'MEDPROC',
#   'score': 0.68627995,
#   'index': 368,
#   'word': 'скрин',
#   'start': 1663,
#   'end': 1668},
#  {'entity': 'MEDPROC',
#   'score': 0.60233796,
#   'index': 369,
#   'word': '##инг',
#   'start': 1668,
#   'end': 1671},
#  {'entity': 'MEDPROC',
#   'score': 0.22498891,
#   'index': 370,
#   'word': '.',
#   'start': 1671,
#   'end': 1672},
#  {'entity': 'DISO',
#   'score': 0.6622605,
#   'index': 371,
#   'word': 'Пато',
#   'start': 1673,
#   'end': 1677},
#  {'entity': 'PHYS',
#   'score': 0.4927303,
#   'index': 372,
#   'word': '##генная',
#   'start': 1677,
#   'end': 1683},
#  {'entity': 'PHYS',
#   'score': 0.70464164,
#   'index': 373,
#   'word': 'мутация',
#   'start': 1684,
#   'end': 1691},
#  {'entity': 'GENE',
#   'score': 0.9379702,
#   'index': 374,
#   'word': 'в',
#   'start': 1692,
#   'end': 1693},
#  {'entity': 'GENE',
#   'score': 0.9750063,
#   'index': 375,
#   'word': 'гене',
#   'start': 1694,
#   'end': 1698},
#  {'entity': 'GENE',
#   'score': 0.9744237,
#   'index': 376,
#   'word': 'GL',
#   'start': 1699,
#   'end': 1701},
#  {'entity': 'GENE',
#   'score': 0.9739735,
#   'index': 377,
#   'word': '##A',
#   'start': 1701,
#   'end': 1702},
#  {'entity': 'FINDING',
#   'score': 0.89792055,
#   'index': 378,
#   'word': 'диагности',
#   'start': 1703,
#   'end': 1712},
#  {'entity': 'FINDING',
#   'score': 0.8333495,
#   'index': 379,
#   'word': '##рована',
#   'start': 1712,
#   'end': 1718},
#  {'entity': 'FINDING',
#   'score': 0.47902995,
#   'index': 380,
#   'word': 'у',
#   'start': 1719,
#   'end': 1720},
#  {'entity': 'PERCENT',
#   'score': 0.79621476,
#   'index': 381,
#   'word': '89',
#   'start': 1721,
#   'end': 1723},
#  {'entity': 'PERCENT',
#   'score': 0.82981277,
#   'index': 382,
#   'word': '(',
#   'start': 1724,
#   'end': 1725},
#  {'entity': 'PERCENT',
#   'score': 0.99127454,
#   'index': 383,
#   'word': '57',
#   'start': 1725,
#   'end': 1727},
#  {'entity': 'PERCENT',
#   'score': 0.8806085,
#   'index': 384,
#   'word': '%',
#   'start': 1727,
#   'end': 1728},
#  {'entity': 'PERSON',
#   'score': 0.5930414,
#   'index': 385,
#   'word': ')',
#   'start': 1728,
#   'end': 1729},
#  {'entity': 'PERSON',
#   'score': 0.3516517,
#   'index': 386,
#   'word': 'из',
#   'start': 1730,
#   'end': 1732},
#  {'entity': 'NUMBER',
#   'score': 0.896482,
#   'index': 387,
#   'word': '156',
#   'start': 1733,
#   'end': 1736},
#  {'entity': 'PERSON',
#   'score': 0.97557914,
#   'index': 388,
#   'word': 'обследова',
#   'start': 1737,
#   'end': 1746},
#  {'entity': 'PERSON',
#   'score': 0.9866867,
#   'index': 389,
#   'word': '##нных',
#   'start': 1746,
#   'end': 1750},
#  {'entity': 'PERSON',
#   'score': 0.9900163,
#   'index': 390,
#   'word': 'родственников',
#   'start': 1751,
#   'end': 1764},
#  {'entity': 'CHEM',
#   'score': 0.35717976,
#   'index': 391,
#   'word': 'диа',
#   'start': 1765,
#   'end': 1768},
#  {'entity': 'CHEM',
#   'score': 0.42476562,
#   'index': 392,
#   'word': '##лиз',
#   'start': 1768,
#   'end': 1771},
#  {'entity': 'PERSON',
#   'score': 0.52310264,
#   'index': 393,
#   'word': '##ных',
#   'start': 1771,
#   'end': 1774},
#  {'entity': 'CHEM',
#   'score': 0.4076266,
#   'index': 394,
#   'word': 'проба',
#   'start': 1775,
#   'end': 1780},
#  {'entity': 'PROFESSION',
#   'score': 0.37385458,
#   'index': 395,
#   'word': '##ндо',
#   'start': 1780,
#   'end': 1783},
#  {'entity': 'PROFESSION',
#   'score': 0.3500698,
#   'index': 396,
#   'word': '##в',
#   'start': 1783,
#   'end': 1784},
#  {'entity': 'FINDING',
#   'score': 0.40127122,
#   'index': 397,
#   'word': ',',
#   'start': 1784,
#   'end': 1785},
#  {'entity': 'PERCENT',
#   'score': 0.11753423,
#   'index': 398,
#   'word': 'в',
#   'start': 1786,
#   'end': 1787},
#  {'entity': 'PERCENT',
#   'score': 0.14914356,
#   'index': 399,
#   'word': 'том',
#   'start': 1788,
#   'end': 1791},
#  {'entity': 'PERSON',
#   'score': 0.25988683,
#   'index': 400,
#   'word': 'числе',
#   'start': 1792,
#   'end': 1797},
#  {'entity': 'NUMBER',
#   'score': 0.16353758,
#   'index': 401,
#   'word': 'у',
#   'start': 1798,
#   'end': 1799},
#  {'entity': 'NUMBER',
#   'score': 0.9548947,
#   'index': 402,
#   'word': '18',
#   'start': 1800,
#   'end': 1802},
#  {'entity': 'PERSON',
#   'score': 0.9856091,
#   'index': 403,
#   'word': 'детей',
#   'start': 1803,
#   'end': 1808},
#  {'entity': 'AGE',
#   'score': 0.987665,
#   'index': 404,
#   'word': 'моложе',
#   'start': 1809,
#   'end': 1815},
#  {'entity': 'AGE',
#   'score': 0.9907397,
#   'index': 405,
#   'word': '18',
#   'start': 1816,
#   'end': 1818},
#  {'entity': 'AGE',
#   'score': 0.9878368,
#   'index': 406,
#   'word': 'лет',
#   'start': 1819,
#   'end': 1822},
#  {'entity': 'FINDING',
#   'score': 0.63132757,
#   'index': 407,
#   'word': ',',
#   'start': 1822,
#   'end': 1823},
#  {'entity': 'DISO',
#   'score': 0.37424406,
#   'index': 408,
#   'word': 'клинические',
#   'start': 1824,
#   'end': 1835},
#  {'entity': 'DISO',
#   'score': 0.45956957,
#   'index': 409,
#   'word': 'проявления',
#   'start': 1836,
#   'end': 1846},
#  {'entity': 'DISO',
#   'score': 0.99620664,
#   'index': 410,
#   'word': 'БФ',
#   'start': 1847,
#   'end': 1849},
#  {'entity': 'FINDING',
#   'score': 0.8318428,
#   'index': 411,
#   'word': 'имелись',
#   'start': 1850,
#   'end': 1857},
#  {'entity': 'FINDING',
#   'score': 0.42319882,
#   'index': 412,
#   'word': 'у',
#   'start': 1858,
#   'end': 1859},
#  {'entity': 'NUMBER',
#   'score': 0.893043,
#   'index': 413,
#   'word': '48',
#   'start': 1860,
#   'end': 1862},
#  {'entity': 'PERSON',
#   'score': 0.9833892,
#   'index': 414,
#   'word': 'родственников',
#   'start': 1863,
#   'end': 1876},
#  {'entity': 'FINDING',
#   'score': 0.30116448,
#   'index': 415,
#   'word': '.',
#   'start': 1876,
#   'end': 1877},
#  {'entity': 'FINDING',
#   'score': 0.25334206,
#   'index': 416,
#   'word': 'У',
#   'start': 1878,
#   'end': 1879},
#  {'entity': 'PERCENT',
#   'score': 0.99360764,
#   'index': 417,
#   'word': '80',
#   'start': 1880,
#   'end': 1882},
#  {'entity': 'PERCENT',
#   'score': 0.9187722,
#   'index': 418,
#   'word': ',',
#   'start': 1882,
#   'end': 1883},
#  {'entity': 'PERCENT',
#   'score': 0.9742579,
#   'index': 419,
#   'word': '4',
#   'start': 1883,
#   'end': 1884},
#  {'entity': 'PERCENT',
#   'score': 0.50018877,
#   'index': 420,
#   'word': '%',
#   'start': 1884,
#   'end': 1885},
#  {'entity': 'PERSON',
#   'score': 0.99312496,
#   'index': 421,
#   'word': 'обследова',
#   'start': 1886,
#   'end': 1895},
#  {'entity': 'PERSON',
#   'score': 0.993447,
#   'index': 422,
#   'word': '##нных',
#   'start': 1895,
#   'end': 1899},
#  {'entity': 'PERSON',
#   'score': 0.99208426,
#   'index': 423,
#   'word': 'родственников',
#   'start': 1900,
#   'end': 1913},
#  {'entity': 'CHEM',
#   'score': 0.712157,
#   'index': 424,
#   'word': 'диа',
#   'start': 1914,
#   'end': 1917},
#  {'entity': 'CHEM',
#   'score': 0.6197759,
#   'index': 425,
#   'word': '##лиз',
#   'start': 1917,
#   'end': 1920},
#  {'entity': 'CHEM',
#   'score': 0.4874844,
#   'index': 426,
#   'word': '##ных',
#   'start': 1920,
#   'end': 1923},
#  {'entity': 'CHEM',
#   'score': 0.65338206,
#   'index': 427,
#   'word': 'проба',
#   'start': 1924,
#   'end': 1929},
#  {'entity': 'CHEM',
#   'score': 0.42236495,
#   'index': 428,
#   'word': '##ндо',
#   'start': 1929,
#   'end': 1932},
#  {'entity': 'CHEM',
#   'score': 0.4843192,
#   'index': 429,
#   'word': '##в',
#   'start': 1932,
#   'end': 1933},
#  {'entity': 'FINDING',
#   'score': 0.92447895,
#   'index': 430,
#   'word': 'обнаружено',
#   'start': 1934,
#   'end': 1944},
#  {'entity': 'DISO',
#   'score': 0.93969,
#   'index': 431,
#   'word': 'поражение',
#   'start': 1945,
#   'end': 1954},
#  {'entity': 'ANATOMY',
#   'score': 0.99506,
#   'index': 432,
#   'word': 'почек',
#   'start': 1955,
#   'end': 1960},
#  {'entity': 'DISO',
#   'score': 0.45147097,
#   'index': 433,
#   'word': ',',
#   'start': 1960,
#   'end': 1961},
#  {'entity': 'DISO',
#   'score': 0.43872967,
#   'index': 434,
#   'word': 'преимущественно',
#   'start': 1962,
#   'end': 1977},
#  {'entity': 'DISO',
#   'score': 0.5724841,
#   'index': 435,
#   'word': 'на',
#   'start': 1978,
#   'end': 1980},
#  {'entity': 'DISO',
#   'score': 0.51710457,
#   'index': 436,
#   'word': 'ранних',
#   'start': 1981,
#   'end': 1987},
#  {'entity': 'DISO',
#   'score': 0.6691112,
#   'index': 437,
#   'word': 'стадиях',
#   'start': 1988,
#   'end': 1995},
#  {'entity': 'DISO',
#   'score': 0.11728065,
#   'index': 438,
#   'word': '.',
#   'start': 1995,
#   'end': 1996},
#  {'entity': 'SCIPROC',
#   'score': 0.2947313,
#   'index': 439,
#   'word': 'Заключение',
#   'start': 1997,
#   'end': 2007},
#  {'entity': 'FINDING',
#   'score': 0.26373303,
#   'index': 440,
#   'word': '.',
#   'start': 2007,
#   'end': 2008},
#  {'entity': 'DISO',
#   'score': 0.9964641,
#   'index': 441,
#   'word': 'Т',
#   'start': 2009,
#   'end': 2010},
#  {'entity': 'DISO',
#   'score': 0.9951982,
#   'index': 442,
#   'word': '##Х',
#   'start': 2010,
#   'end': 2011},
#  {'entity': 'DISO',
#   'score': 0.99062973,
#   'index': 443,
#   'word': '##П',
#   'start': 2011,
#   'end': 2012},
#  {'entity': 'DISO',
#   'score': 0.9925344,
#   'index': 444,
#   'word': '##Н',
#   'start': 2012,
#   'end': 2013},
#  {'entity': 'DISO',
#   'score': 0.7469677,
#   'index': 445,
#   'word': 'нередко',
#   'start': 2014,
#   'end': 2021},
#  {'entity': 'DISO',
#   'score': 0.64362013,
#   'index': 446,
#   'word': '##е',
#   'start': 2021,
#   'end': 2022},
#  {'entity': 'DISO',
#   'score': 0.9868183,
#   'index': 447,
#   'word': 'ослож',
#   'start': 2023,
#   'end': 2028},
#  {'entity': 'DISO',
#   'score': 0.9527055,
#   'index': 448,
#   'word': '##нение',
#   'start': 2028,
#   'end': 2033},
#  {'entity': 'DISO',
#   'score': 0.9968796,
#   'index': 449,
#   'word': 'БФ',
#   'start': 2034,
#   'end': 2036},
#  {'entity': 'DISO',
#   'score': 0.44826907,
#   'index': 450,
#   'word': ',',
#   'start': 2036,
#   'end': 2037},
#  {'entity': 'FINDING',
#   'score': 0.9633257,
#   'index': 451,
#   'word': 'ассоции',
#   'start': 2038,
#   'end': 2045},
#  {'entity': 'DISO',
#   'score': 0.44676366,
#   'index': 452,
#   'word': '##рованное',
#   'start': 2045,
#   'end': 2053},
#  {'entity': 'FINDING',
#   'score': 0.9221915,
#   'index': 453,
#   'word': 'с',
#   'start': 2054,
#   'end': 2055},
#  {'entity': 'FINDING',
#   'score': 0.937435,
#   'index': 454,
#   'word': 'неблагоприят',
#   'start': 2056,
#   'end': 2068},
#  {'entity': 'FINDING',
#   'score': 0.9287333,
#   'index': 455,
#   'word': '##ным',
#   'start': 2068,
#   'end': 2071},
#  {'entity': 'FINDING',
#   'score': 0.45659307,
#   'index': 456,
#   'word': 'прогнозом',
#   'start': 2072,
#   'end': 2081},
#  {'entity': 'SCIPROC',
#   'score': 0.11181167,
#   'index': 457,
#   'word': '.',
#   'start': 2081,
#   'end': 2082},
#  {'entity': 'FINDING',
#   'score': 0.65220386,
#   'index': 458,
#   'word': 'Однако',
#   'start': 2083,
#   'end': 2089},
#  {'entity': 'MEDPROC',
#   'score': 0.994005,
#   'index': 459,
#   'word': 'диа',
#   'start': 2090,
#   'end': 2093},
#  {'entity': 'MEDPROC',
#   'score': 0.99076205,
#   'index': 460,
#   'word': '##лиз',
#   'start': 2093,
#   'end': 2096},
#  {'entity': 'MEDPROC',
#   'score': 0.9751133,
#   'index': 461,
#   'word': '##ный',
#   'start': 2096,
#   'end': 2099},
#  {'entity': 'MEDPROC',
#   'score': 0.9224087,
#   'index': 462,
#   'word': 'скрин',
#   'start': 2100,
#   'end': 2105},
#  {'entity': 'MEDPROC',
#   'score': 0.8640954,
#   'index': 463,
#   'word': '##инг',
#   'start': 2105,
#   'end': 2108},
#  {'entity': 'FINDING',
#   'score': 0.8538457,
#   'index': 464,
#   'word': '–',
#   'start': 2109,
#   'end': 2110},
#  {'entity': 'FINDING',
#   'score': 0.9710206,
#   'index': 465,
#   'word': 'эффективный',
#   'start': 2112,
#   'end': 2123},
#  {'entity': 'FINDING',
#   'score': 0.80424714,
#   'index': 466,
#   'word': 'способ',
#   'start': 2124,
#   'end': 2130},
#  {'entity': 'FINDING',
#   'score': 0.58797455,
#   'index': 467,
#   'word': 'выявления',
#   'start': 2131,
#   'end': 2140},
#  {'entity': 'PERSON',
#   'score': 0.55561846,
#   'index': 468,
#   'word': 'проба',
#   'start': 2141,
#   'end': 2146},
#  {'entity': 'PERSON',
#   'score': 0.36209607,
#   'index': 469,
#   'word': '##ндо',
#   'start': 2146,
#   'end': 2149},
#  {'entity': 'PERSON',
#   'score': 0.4609933,
#   'index': 470,
#   'word': '##в',
#   'start': 2149,
#   'end': 2150},
#  {'entity': 'DISO',
#   'score': 0.9201672,
#   'index': 471,
#   'word': 'с',
#   'start': 2151,
#   'end': 2152},
#  {'entity': 'DISO',
#   'score': 0.99696463,
#   'index': 472,
#   'word': 'БФ',
#   'start': 2153,
#   'end': 2155},
#  {'entity': 'FINDING',
#   'score': 0.85674,
#   'index': 473,
#   'word': ',',
#   'start': 2155,
#   'end': 2156},
#  {'entity': 'FINDING',
#   'score': 0.94668734,
#   'index': 474,
#   'word': 'открываю',
#   'start': 2157,
#   'end': 2165},
#  {'entity': 'FINDING',
#   'score': 0.9396719,
#   'index': 475,
#   'word': '##щий',
#   'start': 2165,
#   'end': 2168},
#  {'entity': 'FINDING',
#   'score': 0.84074455,
#   'index': 476,
#   'word': 'возможность',
#   'start': 2169,
#   'end': 2180},
#  {'entity': 'FINDING',
#   'score': 0.79156184,
#   'index': 477,
#   'word': 'установить',
#   'start': 2181,
#   'end': 2191},
#  {'entity': 'DISO',
#   'score': 0.7082785,
#   'index': 478,
#   'word': 'диагноз',
#   'start': 2192,
#   'end': 2199},
#  {'entity': 'DISO',
#   'score': 0.99697924,
#   'index': 479,
#   'word': 'БФ',
#   'start': 2200,
#   'end': 2202},
#  {'entity': 'PERSON',
#   'score': 0.7526889,
#   'index': 480,
#   'word': 'у',
#   'start': 2203,
#   'end': 2204},
#  {'entity': 'PERSON',
#   'score': 0.97919446,
#   'index': 481,
#   'word': 'родственников',
#   'start': 2205,
#   'end': 2218},
#  {'entity': 'FINDING',
#   'score': 0.2583943,
#   'index': 482,
#   'word': 'на',
#   'start': 2219,
#   'end': 2221},
#  {'entity': 'PHYS',
#   'score': 0.48295113,
#   'index': 483,
#   'word': 'ранних',
#   'start': 2222,
#   'end': 2228},
#  {'entity': 'DISO',
#   'score': 0.4809324,
#   'index': 484,
#   'word': 'стадиях',
#   'start': 2229,
#   'end': 2236},
#  {'entity': 'FINDING',
#   'score': 0.62080777,
#   'index': 485,
#   'word': ',',
#   'start': 2236,
#   'end': 2237},
#  {'entity': 'FINDING',
#   'score': 0.6216499,
#   'index': 486,
#   'word': 'когда',
#   'start': 2238,
#   'end': 2243},
#  {'entity': 'MEDPROC',
#   'score': 0.93236935,
#   'index': 487,
#   'word': 'лечение',
#   'start': 2244,
#   'end': 2251},
#  {'entity': 'FINDING',
#   'score': 0.967451,
#   'index': 488,
#   'word': 'наиболее',
#   'start': 2252,
#   'end': 2260},
#  {'entity': 'FINDING',
#   'score': 0.97430295,
#   'index': 489,
#   'word': 'эффективно',
#   'start': 2261,
#   'end': 2271},
#  {'entity': 'FINDING',
#   'score': 0.23015024,
#   'index': 490,
#   'word': '.',
#   'start': 2271,
#   'end': 2272}]

# %% [markdown]
# #_____
# ___
# # Обучение на 70% датасета

# %%
train_dataset_70 = tokenized_dataset['train'].select(
    random.sample(
        range(tokenized_dataset['train'].num_rows),
        int(tokenized_dataset['train'].num_rows * 0.7)
    )
)

# %%
model = AutoModelForTokenClassification.from_pretrained(
    config.checkpoint, num_labels=config.n_labels, id2label=id_to_tag, label2id=tag_to_id)

training_args = TrainingArguments(
    output_dir=hf_repo_id,
    num_train_epochs=config.n_epochs,
    learning_rate=config.l_rate,
    weight_decay=config.w_decay,
    warmup_ratio=config.warm_up,
    per_device_train_batch_size=config.train_batch_size,
    per_device_eval_batch_size=config.eval_batch_size,
    group_by_length=True,
    optim="adamw_torch",
    lr_scheduler_type="cosine",
    evaluation_strategy="epoch",
    seed = config.seed,
    data_seed = config.seed,
    push_to_hub=True,
    save_strategy="no",
    report_to="wandb",
    run_name="RuBioBERT-base_70%_of_data",
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset_70,
    eval_dataset=tokenized_dataset["valid"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
# config.json:   0%|          | 0.00/889 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at alexyalunin/RuBioBERT and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# wandb: Currently logged in as: taoea. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.3
# Run data is saved locally in <code>/content/wandb/run-20240229_194757-bkqi4cih</code>
# Syncing run <strong><a href='https://wandb.ai/taoea/ner_bert_nerel_bio/runs/bkqi4cih' target="_blank">RuBioBERT-base_70%_of_data</a></strong> to <a href='https://wandb.ai/taoea/ner_bert_nerel_bio' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/taoea/ner_bert_nerel_bio' target="_blank">https://wandb.ai/taoea/ner_bert_nerel_bio</a>
#  View run at <a href='https://wandb.ai/taoea/ner_bert_nerel_bio/runs/bkqi4cih' target="_blank">https://wandb.ai/taoea/ner_bert_nerel_bio/runs/bkqi4cih</a>
#     <div>
#
#       <progress value='1070' max='1070' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1070/1070 02:04, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>1.082770</td>
#       <td>0.676427</td>
#       <td>0.644700</td>
#       <td>0.660183</td>
#       <td>0.747786</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.673041</td>
#       <td>0.765089</td>
#       <td>0.743199</td>
#       <td>0.753985</td>
#       <td>0.834188</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.597802</td>
#       <td>0.777434</td>
#       <td>0.765947</td>
#       <td>0.771648</td>
#       <td>0.845688</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.634298</td>
#       <td>0.773210</td>
#       <td>0.767589</td>
#       <td>0.770390</td>
#       <td>0.844755</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.782300</td>
#       <td>0.599693</td>
#       <td>0.798863</td>
#       <td>0.790807</td>
#       <td>0.794814</td>
#       <td>0.861538</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.782300</td>
#       <td>0.623642</td>
#       <td>0.787411</td>
#       <td>0.777439</td>
#       <td>0.782393</td>
#       <td>0.853924</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.782300</td>
#       <td>0.633060</td>
#       <td>0.790939</td>
#       <td>0.786116</td>
#       <td>0.788520</td>
#       <td>0.856721</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.782300</td>
#       <td>0.666185</td>
#       <td>0.789028</td>
#       <td>0.785882</td>
#       <td>0.787452</td>
#       <td>0.855944</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.782300</td>
#       <td>0.670574</td>
#       <td>0.793673</td>
#       <td>0.788462</td>
#       <td>0.791059</td>
#       <td>0.858430</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.077000</td>
#       <td>0.671194</td>
#       <td>0.793673</td>
#       <td>0.788462</td>
#       <td>0.791059</td>
#       <td>0.858120</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1070, training_loss=0.4041379315830837, metrics={'train_runtime': 129.6103, 'train_samples_per_second': 33.022, 'train_steps_per_second': 8.256, 'total_flos': 606938351693040.0, 'train_loss': 0.4041379315830837, 'epoch': 10.0})

# %%
wandb.finish()
# Out:
# VBox(children=(Label(value='0.022 MB of 0.022 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>▁▆▇▇██████</td></tr><tr><td>eval/f1</td><td>▁▆▇▇█▇████</td></tr><tr><td>eval/loss</td><td>█▂▁▂▁▁▂▂▂▂</td></tr><tr><td>eval/precision</td><td>▁▆▇▇█▇█▇██</td></tr><tr><td>eval/recall</td><td>▁▆▇▇█▇████</td></tr><tr><td>eval/runtime</td><td>▁▁▁▁▁█▅▅▅▁</td></tr><tr><td>eval/samples_per_second</td><td>▇███▇▁▃▃▃▇</td></tr><tr><td>eval/steps_per_second</td><td>▇███▇▁▃▃▃▇</td></tr><tr><td>train/epoch</td><td>▁▂▃▃▄▄▅▆▆▇▇██</td></tr><tr><td>train/global_step</td><td>▁▂▃▃▄▄▅▆▆▇▇██</td></tr><tr><td>train/grad_norm</td><td>█▁</td></tr><tr><td>train/learning_rate</td><td>█▁</td></tr><tr><td>train/loss</td><td>█▁</td></tr><tr><td>train/total_flos</td><td>▁</td></tr><tr><td>train/train_loss</td><td>▁</td></tr><tr><td>train/train_runtime</td><td>▁</td></tr><tr><td>train/train_samples_per_second</td><td>▁</td></tr><tr><td>train/train_steps_per_second</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>0.85812</td></tr><tr><td>eval/f1</td><td>0.79106</td></tr><tr><td>eval/loss</td><td>0.67119</td></tr><tr><td>eval/precision</td><td>0.79367</td></tr><tr><td>eval/recall</td><td>0.78846</td></tr><tr><td>eval/runtime</td><td>0.9356</td></tr><tr><td>eval/samples_per_second</td><td>82.3</td></tr><tr><td>eval/steps_per_second</td><td>21.377</td></tr><tr><td>train/epoch</td><td>10.0</td></tr><tr><td>train/global_step</td><td>1070</td></tr><tr><td>train/grad_norm</td><td>1.95997</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>train/loss</td><td>0.077</td></tr><tr><td>train/total_flos</td><td>606938351693040.0</td></tr><tr><td>train/train_loss</td><td>0.40414</td></tr><tr><td>train/train_runtime</td><td>129.6103</td></tr><tr><td>train/train_samples_per_second</td><td>33.022</td></tr><tr><td>train/train_steps_per_second</td><td>8.256</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">RuBioBERT-base_70%_of_data</strong> at: <a href='https://wandb.ai/taoea/ner_bert_nerel_bio/runs/bkqi4cih' target="_blank">https://wandb.ai/taoea/ner_bert_nerel_bio/runs/bkqi4cih</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240229_194757-bkqi4cih/logs</code>

# %%
predictions = trainer.predict(test_dataset=tokenized_dataset["test"])

# %%
predictions.metrics
# Out:
# {'test_loss': 0.5828642249107361,
#  'test_precision': 0.8193939393939393,
#  'test_recall': 0.8076463560334528,
#  'test_f1': 0.8134777376654632,
#  'test_accuracy': 0.881760597693682,
#  'test_runtime': 1.9576,
#  'test_samples_per_second': 39.335,
#  'test_steps_per_second': 10.217}

# %% [markdown]
# #_____
# ___
# # Обучение на 50% датасета

# %%
train_dataset_50 = tokenized_dataset['train'].select(
    random.sample(
        range(tokenized_dataset['train'].num_rows),
        int(tokenized_dataset['train'].num_rows * 0.5)
    )
)

# %%
model = AutoModelForTokenClassification.from_pretrained(
    config.checkpoint, num_labels=config.n_labels, id2label=id_to_tag, label2id=tag_to_id)

training_args = TrainingArguments(
    output_dir=hf_repo_id,
    num_train_epochs=config.n_epochs,
    learning_rate=config.l_rate,
    weight_decay=config.w_decay,
    warmup_ratio=config.warm_up,
    per_device_train_batch_size=config.train_batch_size,
    per_device_eval_batch_size=config.eval_batch_size,
    group_by_length=True,
    optim="adamw_torch",
    lr_scheduler_type="cosine",
    evaluation_strategy="epoch",
    seed = config.seed,
    data_seed = config.seed,
    push_to_hub=True,
    save_strategy="no",
    report_to="wandb",
    logging_steps=16,
    run_name="RuBioBERT-base_50%_of_data",
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset_50,
    eval_dataset=tokenized_dataset["valid"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
# config.json:   0%|          | 0.00/889 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at alexyalunin/RuBioBERT and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# wandb: Currently logged in as: taoea. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.3
# Run data is saved locally in <code>/content/wandb/run-20240229_195933-us28qleh</code>
# Syncing run <strong><a href='https://wandb.ai/taoea/ner_bert_nerel_bio/runs/us28qleh' target="_blank">RuBioBERT-base_50%_of_data</a></strong> to <a href='https://wandb.ai/taoea/ner_bert_nerel_bio' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/taoea/ner_bert_nerel_bio' target="_blank">https://wandb.ai/taoea/ner_bert_nerel_bio</a>
#  View run at <a href='https://wandb.ai/taoea/ner_bert_nerel_bio/runs/us28qleh' target="_blank">https://wandb.ai/taoea/ner_bert_nerel_bio/runs/us28qleh</a>
#     <div>
#
#       <progress value='770' max='770' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [770/770 01:41, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.808800</td>
#       <td>1.402433</td>
#       <td>0.597264</td>
#       <td>0.553002</td>
#       <td>0.574282</td>
#       <td>0.683605</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.720300</td>
#       <td>0.758823</td>
#       <td>0.763879</td>
#       <td>0.738977</td>
#       <td>0.751222</td>
#       <td>0.820824</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.460100</td>
#       <td>0.636499</td>
#       <td>0.771572</td>
#       <td>0.754925</td>
#       <td>0.763158</td>
#       <td>0.835742</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.267800</td>
#       <td>0.595391</td>
#       <td>0.792940</td>
#       <td>0.784944</td>
#       <td>0.788922</td>
#       <td>0.853458</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.176500</td>
#       <td>0.606268</td>
#       <td>0.794362</td>
#       <td>0.786351</td>
#       <td>0.790336</td>
#       <td>0.856410</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.146600</td>
#       <td>0.644648</td>
#       <td>0.779920</td>
#       <td>0.777908</td>
#       <td>0.778913</td>
#       <td>0.849106</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.108400</td>
#       <td>0.656092</td>
#       <td>0.788805</td>
#       <td>0.786585</td>
#       <td>0.787694</td>
#       <td>0.854701</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.078100</td>
#       <td>0.648455</td>
#       <td>0.792982</td>
#       <td>0.789634</td>
#       <td>0.791304</td>
#       <td>0.855322</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.055600</td>
#       <td>0.671400</td>
#       <td>0.792413</td>
#       <td>0.788696</td>
#       <td>0.790550</td>
#       <td>0.856410</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.050000</td>
#       <td>0.675577</td>
#       <td>0.793307</td>
#       <td>0.789400</td>
#       <td>0.791348</td>
#       <td>0.856876</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=770, training_loss=0.4690267160147816, metrics={'train_runtime': 107.7234, 'train_samples_per_second': 28.406, 'train_steps_per_second': 7.148, 'total_flos': 440698198154220.0, 'train_loss': 0.4690267160147816, 'epoch': 10.0})

# %%
wandb.finish()
# Out:
# VBox(children=(Label(value='0.001 MB of 0.022 MB uploaded\r'), FloatProgress(value=0.05494930400412442, max=1.…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>▁▇▇███████</td></tr><tr><td>eval/f1</td><td>▁▇▇███████</td></tr><tr><td>eval/loss</td><td>█▂▁▁▁▁▂▁▂▂</td></tr><tr><td>eval/precision</td><td>▁▇▇██▇████</td></tr><tr><td>eval/recall</td><td>▁▇▇███████</td></tr><tr><td>eval/runtime</td><td>▇▃▅▃▄▆█▁▁▁</td></tr><tr><td>eval/samples_per_second</td><td>▁▅▃▄▄▂▁███</td></tr><tr><td>eval/steps_per_second</td><td>▁▅▃▄▄▂▁███</td></tr><tr><td>train/epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>train/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>train/grad_norm</td><td>▇▅▅▇▅▄██▃▄▄▆▇▃▅▅▄▅▂▄▃▃▁▂▂▂▁▂▃▃▂▂▂▁▂▂▂▁▁▂</td></tr><tr><td>train/learning_rate</td><td>▂▄▅▇██████▇▇▇▇▇▆▆▆▆▅▅▅▄▄▄▃▃▃▃▂▂▂▂▂▁▁▁▁▁▁</td></tr><tr><td>train/loss</td><td>█▇▆▄▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/total_flos</td><td>▁</td></tr><tr><td>train/train_loss</td><td>▁</td></tr><tr><td>train/train_runtime</td><td>▁</td></tr><tr><td>train/train_samples_per_second</td><td>▁</td></tr><tr><td>train/train_steps_per_second</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>0.85688</td></tr><tr><td>eval/f1</td><td>0.79135</td></tr><tr><td>eval/loss</td><td>0.67558</td></tr><tr><td>eval/precision</td><td>0.79331</td></tr><tr><td>eval/recall</td><td>0.7894</td></tr><tr><td>eval/runtime</td><td>0.9033</td></tr><tr><td>eval/samples_per_second</td><td>85.245</td></tr><tr><td>eval/steps_per_second</td><td>22.142</td></tr><tr><td>train/epoch</td><td>10.0</td></tr><tr><td>train/global_step</td><td>770</td></tr><tr><td>train/grad_norm</td><td>1.33619</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>train/loss</td><td>0.05</td></tr><tr><td>train/total_flos</td><td>440698198154220.0</td></tr><tr><td>train/train_loss</td><td>0.46903</td></tr><tr><td>train/train_runtime</td><td>107.7234</td></tr><tr><td>train/train_samples_per_second</td><td>28.406</td></tr><tr><td>train/train_steps_per_second</td><td>7.148</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">RuBioBERT-base_50%_of_data</strong> at: <a href='https://wandb.ai/taoea/ner_bert_nerel_bio/runs/us28qleh' target="_blank">https://wandb.ai/taoea/ner_bert_nerel_bio/runs/us28qleh</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240229_195933-us28qleh/logs</code>

# %%
predictions = trainer.predict(test_dataset=tokenized_dataset["test"])

# %%
predictions.metrics
# Out:
# {'test_loss': 0.5908907055854797,
#  'test_precision': 0.8163512857836002,
#  'test_recall': 0.8040621266427718,
#  'test_f1': 0.8101601059347538,
#  'test_accuracy': 0.8777001786584375,
#  'test_runtime': 0.8572,
#  'test_samples_per_second': 89.824,
#  'test_steps_per_second': 23.331}

# %% [markdown]
# **Вывод**: в первом приближении качество обучения на 100%, 70% и 50% датасета не различается.
