# %% [markdown]
# <a href="https://colab.research.google.com/github/ekaterinatao/NER_biomed_domain/blob/main/transformers_base/%D0%92%D0%9A%D0%A0_nerel_bio_ruBERT_base.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Инструменты
# Предобработанный дасасет [NEREL-BIO](https://huggingface.co/datasets/ekaterinatao/nerel_bio_ner_unnested)
# [Чек-пойнт](https://huggingface.co/ekaterinatao/nerel-bio-rubert-base) дообученной модели на всем датасете nerel-bio
#
# Исходная модель [RuBERT](https://huggingface.co/DeepPavlov/rubert-base-cased)

# %% [markdown]
# ### Установка зависимостей

# %%
# !pip install datasets accelerate evaluate wandb seqeval -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.7/536.7 kB 11.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 kB 17.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 11.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 17.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 5.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 14.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 20.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.5/258.5 kB 17.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.1 MB/s eta 0:00:00
#   Building wheel for seqeval (setup.py) ... done

# %%
import numpy as np
import pandas as pd
import random
from dataclasses import dataclass

import torch
import datasets
from datasets import Dataset, DatasetDict
from transformers import AutoTokenizer
from transformers import DataCollatorForTokenClassification
from transformers import AutoModelForTokenClassification
from transformers import TrainingArguments, Trainer
from transformers import pipeline
import evaluate

import warnings
warnings.filterwarnings("ignore")

# %%
@dataclass
class TrainingConfig:
    seed = 64
    dataset = 'ekaterinatao/nerel_bio_ner_unnested'
    checkpoint = 'DeepPavlov/rubert-base-cased'
    n_labels = 45
    n_epochs = 10
    train_batch_size = 6
    eval_batch_size = 6
    device = "cuda" if torch.cuda.is_available() else "cpu"
    l_rate = 5e-05
    w_decay = 0.1
    warm_up = 0.1

config = TrainingConfig()

# %%
seed = config.seed

random.seed(seed)
np.random.seed(seed)

torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %% [markdown]
# ### Скачивание датасета

# %%
dataset = datasets.load_dataset(config.dataset)
dataset
# Out:
# Downloading readme:   0%|          | 0.00/1.56k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/603k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/76.2k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/70.8k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/612 [00:00<?, ? examples/s]
# Generating valid split:   0%|          | 0/77 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/77 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'words', 'ner_tags'],
#         num_rows: 612
#     })
#     valid: Dataset({
#         features: ['id', 'words', 'ner_tags'],
#         num_rows: 77
#     })
#     test: Dataset({
#         features: ['id', 'words', 'ner_tags'],
#         num_rows: 77
#     })
# })

# %%
for token, ner_tag in zip(dataset['train'][0]['words'], dataset['train'][0]['ner_tags']):
    print(f'{token:_<60}{ner_tag}')
# Out:
# 161_________________________________________________________28
# ОКБ_________________________________________________________30
# 12-275 мес__________________________________________________20
# 95,65±8,4 мес_______________________________________________20
# 23__________________________________________________________28
# 14,29%______________________________________________________31
# 8___________________________________________________________28
# 23,13 мес___________________________________________________20
# 11 мес______________________________________________________20
# Более 36 мес________________________________________________20
# 142_________________________________________________________28
# 104,87 мес__________________________________________________20
# 15__________________________________________________________28
# 80,27 мес___________________________________________________20
# 3___________________________________________________________28
# 13,45%______________________________________________________31
# 19,51%______________________________________________________31
# 10 мм_______________________________________________________28
# более 15 мм_________________________________________________28
# гематогенным метастазированием______________________________5
# брахитерапии________________________________________________13
# БТ__________________________________________________________13
# больших меланом хориоидеи___________________________________5
# МХ__________________________________________________________5
# витального прогноза_________________________________________6
# больных_____________________________________________________32
# человек_____________________________________________________32
# офтальмоонкологическом центре_______________________________30
# пациентов___________________________________________________32
# больными____________________________________________________32
# МХ__________________________________________________________5
# БТ__________________________________________________________13
# человек_____________________________________________________32
# больных_____________________________________________________32
# метастазы___________________________________________________5
# печень______________________________________________________2
# больных_____________________________________________________32
# человека____________________________________________________32
# метастазы___________________________________________________5
# человек_____________________________________________________32
# БТ__________________________________________________________13
# пациентов___________________________________________________32
# метастазы___________________________________________________5
# средних МХ__________________________________________________5
# пациентов___________________________________________________32
# метастазирования____________________________________________5
# пациентов___________________________________________________32
# большими МХ_________________________________________________5
# БТ__________________________________________________________13
# МХ__________________________________________________________5
# гематогенных метастазов_____________________________________5
# локального лечения__________________________________________13
# меланом_____________________________________________________5
# меланом_____________________________________________________5
# хориоидеи___________________________________________________2
# меланом хориоидеи___________________________________________5
# МХ__________________________________________________________5
# БТ__________________________________________________________13
# Офтальмологической клинической больнице_____________________30
# медицинских центрах_________________________________________30
# Москвы______________________________________________________18
# ОКБ_________________________________________________________30
# онкологическом______________________________________________5
# 56,89±1,93 года_____________________________________________17
# 17-84 года__________________________________________________17
# метастазы___________________________________________________5
# гематогенные метастазы______________________________________5
# метастазы в печень__________________________________________5
# Продолжительность жизни_____________________________________15
# метастатической болезни_____________________________________5
# 37-167 мес__________________________________________________20
# МХ__________________________________________________________5
# начальными МХ_______________________________________________5
# 99,96±12,47 мес_____________________________________________20
# метастазы___________________________________________________5
# продолжительность жизни_____________________________________15
# 20,66 мес___________________________________________________20
# продолжительность жизни_____________________________________15
# 13,5 мес____________________________________________________20
# более 7- 8 лет______________________________________________20
# метастазов__________________________________________________5
# опухоли_____________________________________________________5
# МХ__________________________________________________________5
# МХ__________________________________________________________5
# метастазированием___________________________________________5
# МХ__________________________________________________________5
# клинической больнице________________________________________30
# больнице____________________________________________________30
# метастатической болезни_____________________________________5
# группы______________________________________________________32
# ретроспективного исследования_______________________________16
# продолжительности жизни_____________________________________15
# 30,8 мес____________________________________________________20
# 2,8_________________________________________________________28
# классификации J. Schields___________________________________16
# МХ__________________________________________________________5
# МХ__________________________________________________________5
# МХ__________________________________________________________5
# размеров опухоли____________________________________________15
# частота гематогенных метастазов_____________________________15
# частота гематогенных метастазов повышается__________________6
# увеличения размеров опухоли_________________________________6
# максимальный диаметр МХ_____________________________________15
# пятый_______________________________________________________29

# %%
# Labels
url = 'https://raw.githubusercontent.com/ekaterinatao/NER_biomed_domain/main/labels.txt'
tags = pd.read_csv(url, names=['tag']).values.tolist()
tags = [item for sublist in tags for item in sublist]
tag_to_id = {tag: i for i, tag in enumerate(tags)}
id_to_tag = {i: tag for i, tag in enumerate(tags)}

# %% [markdown]
# ___
# ### Токенизация

# %%
tokenizer = AutoTokenizer.from_pretrained(config.checkpoin)
# Out:
# tokenizer_config.json:   0%|          | 0.00/24.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/642 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/1.65M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
example = dataset["train"][64]
tokenized_input = tokenizer(example["words"], truncation=True, max_length=512, is_split_into_words=True)
tokens = tokenizer.convert_ids_to_tokens(tokenized_input["input_ids"])

print(f'Token len initial tokens__{len(example["words"])}\n')
print(f'Token len from BERT tokenizer__{len(tokens)}')
print(' '.join(tokens))
# Out:
# Token len initial tokens__77
#
# Token len from BERT tokenizer__189
# [CLS] И ##БС тремя ишем ##ической болезни сердца 301 1066 США 1517 США транс ##жи ##р ##ных кислот пище ишем ##ической болезни сердца пищевых калорий Т ##ЖК жир ##ы масла Т ##ЖК Т ##ЖК И ##БС лип ##идов плазме лип ##идам биом ##арке ##рам воспал ##ительного процесса лип ##идов смерть Т ##ЖК смертей Т ##ЖК населения ответственных лиц населения Т ##ЖК Аргентине сердца до 2004 года 1 , 5 % Т ##ЖК пищевых снижения уровня Т ##ЖК И ##БС процентной доли снижения И ##БС И ##БС сердца И ##БС 523 ##7 лет ежегодных 17 млн долл . США пищевых Т ##ЖК пищевых проспект ##ивных кого ##рт ##ных исследованиях проспект ##ивных кого ##рт ##ных исследований ежегодно 537 ##3 И ##БС 26 394 года острых случаев И ##БС острых случая И ##БС 87 млн долл . США Аргентине болезни сердца калорий уровень потребления риски возникновения И ##БС популя ##ционной выборки профиля ##м лип ##идов болезни сердца профил ##е лип ##идов предотвратить спасти 523 ##7 лет жизни сэкономить 17 млн долл . США предотвратить спасти 26 394 года жизни сэкономить 87 млн долл . США употребления Т ##ЖК здоровье лиц здоровье [SEP]

# %%
def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(examples["words"], truncation=True, max_length=512, is_split_into_words=True)

    labels = []
    for i, label in enumerate(examples[f"ner_tags"]):
        word_idxs = tokenized_inputs.word_ids(batch_index=i)  # Map tokens to their respective word.
        previous_word_idx = None
        label_ids = []
        for word_idx in word_idxs:
            if word_idx is None:
                label_ids.append(-100) # Set the special tokens to -100.
            elif word_idx != previous_word_idx:  # Only label the first token of a given word.
                label_ids.append(label[word_idx])
            else:
                label_ids.append(-100)
            previous_word_idx = word_idx
        labels.append(label_ids)

    tokenized_inputs["labels"] = labels
    return tokenized_inputs

# %%
tokenized_dataset = dataset.map(tokenize_and_align_labels, batched=True)
tokenized_dataset
# Out:
# Map:   0%|          | 0/612 [00:00<?, ? examples/s]
# Map:   0%|          | 0/77 [00:00<?, ? examples/s]
# Map:   0%|          | 0/77 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'words', 'ner_tags', 'input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 612
#     })
#     valid: Dataset({
#         features: ['id', 'words', 'ner_tags', 'input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 77
#     })
#     test: Dataset({
#         features: ['id', 'words', 'ner_tags', 'input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 77
#     })
# })

# %%
df = tokenized_dataset['train']
pd.DataFrame({
    'words': df['words'], 'ner_tags': df['ner_tags'],
    'input_ids': df['input_ids'], 'labels': df['labels']
}).head(5)
# Out:
#                                                words  \
# 0  [161, ОКБ, 12-275 мес, 95,65±8,4 мес, 23, 14,2...
# 1  [ИМО, 201, от 2 мес до 18 лет, до 74%, 5,5%, И...
# 2  [ОФТГ, 2,5-3,0 кг, ВПГ, 1-го, Панавир, 6 инсти...
# 3  [29, целиакией, 8, ИГ, целиакией, 7, 18, АГД, ...
# 4  [ОА, 248, РА, от 38 до 65 лет, II, четыре, 1-я...
#
#                                             ner_tags  \
# 0  [28, 30, 20, 20, 28, 31, 28, 20, 20, 20, 28, 2...
# 1  [5, 28, 17, 31, 31, 5, 5, 2, 5, 32, 32, 5, 32,...
# 2  [5, 28, 12, 29, 3, 28, 20, 5, 12, 5, 5, 15, 15...
# 3  [28, 5, 28, 3, 5, 28, 28, 7, 28, 28, 28, 28, 5...
# 4  [5, 28, 5, 17, 29, 28, 29, 29, 29, 29, 3, 29, ...
#
#                                            input_ids  \
# 0  [101, 20132, 39736, 4367, 130, 24408, 57175, 1...
# 1  [101, 61991, 806, 2777, 1641, 140, 57175, 2785...
# 2  [101, 96813, 814, 784, 140, 128, 146, 130, 142...
# 3  [101, 7688, 16934, 87843, 152, 24481, 16934, 8...
# 4  [101, 805, 778, 25401, 34662, 1641, 11683, 278...
#
#                                               labels
# 0  [-100, 28, 30, 20, -100, -100, -100, 20, -100,...
# 1  [-100, 5, -100, 28, 17, -100, -100, -100, -100...
# 2  [-100, 5, -100, -100, 28, -100, -100, -100, -1...
# 3  [-100, 28, 5, -100, 28, 3, 5, -100, 28, 28, 7,...
# 4  [-100, 5, -100, 28, 5, 17, -100, -100, -100, -...

# %%
tokenized_dataset = tokenized_dataset.map(remove_columns = ['id', 'words', 'ner_tags'])
tokenized_dataset
# Out:
# Map:   0%|          | 0/612 [00:00<?, ? examples/s]
# Map:   0%|          | 0/77 [00:00<?, ? examples/s]
# Map:   0%|          | 0/77 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 612
#     })
#     valid: Dataset({
#         features: ['input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 77
#     })
#     test: Dataset({
#         features: ['input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 77
#     })
# })

# %% [markdown]
# ### Обучение модели с различными гиперпараметрами (`learning rate`, `decay weight`)

# %%
seqeval = evaluate.load("seqeval")

def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=2)

    true_predictions = [
        [tags[p] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]
    true_labels = [
        [tags[l] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]

    results = seqeval.compute(predictions=true_predictions, references=true_labels)
    return {
        "precision": results["overall_precision"],
        "recall": results["overall_recall"],
        "f1": results["overall_f1"],
        "accuracy": results["overall_accuracy"],
    }
# Out:
# Downloading builder script:   0%|          | 0.00/6.34k [00:00<?, ?B/s]

# %%
data_collator = DataCollatorForTokenClassification(tokenizer=tokenizer)

# %%
print(f'device is {config.device}')
# Out:
# device is cuda

# %% [markdown]
# ____
# # Подбор гиперпараметров

# %%
LR_VALUES = (1e-5, 2e-5, 5e-5)
DECAY_VALUES = (1e-4, 0.1)
WARM_UP_VALUES = (0, 0.1)

# %%
for i, LR in enumerate(LR_VALUES):
    for j, WD in enumerate(DECAY_VALUES):
        for y, WU in enumerate(WARM_UP_VALUES):

            model = AutoModelForTokenClassification.from_pretrained(
                config.checkpoint, num_labels=config.n_labels,
                id2label=id_to_tag, label2id=tag_to_id
            )
            print(f'Log: training for l_r:{LR}, w_d:{WD}, w_up:{WU}...')

            training_args = TrainingArguments(
                output_dir="token_class_model",
                num_train_epochs=config.n_epochs,
                learning_rate=LR,
                weight_decay=WD,
                warmup_ratio=WU,
                per_device_train_batch_size=config.train_batch_size,
                per_device_eval_batch_size=config.eval_batch_size,
                group_by_length=True,
                optim="adamw_torch",
                lr_scheduler_type="cosine",
                evaluation_strategy="epoch",
                seed = config.seed,
                data_seed = config.seed,
                push_to_hub=False,
                save_strategy="no"
            )

            trainer = Trainer(
                model=model,
                args=training_args,
                train_dataset=tokenized_dataset["train"],
                eval_dataset=tokenized_dataset["valid"],
                tokenizer=tokenizer,
                data_collator=data_collator,
                compute_metrics=compute_metrics,
            )

            trainer.train()
# Out:
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at DeepPavlov/rubert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Log: training for l_r:1e-05, w_d:0.0001, w_up:0...
#     <div>
#
#       <progress value='1020' max='1020' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1020/1020 01:40, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>1.497717</td>
#       <td>0.520128</td>
#       <td>0.457552</td>
#       <td>0.486837</td>
#       <td>0.627972</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>1.058169</td>
#       <td>0.643254</td>
#       <td>0.597092</td>
#       <td>0.619314</td>
#       <td>0.727428</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.841241</td>
#       <td>0.697225</td>
#       <td>0.659944</td>
#       <td>0.678072</td>
#       <td>0.778089</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.750172</td>
#       <td>0.715015</td>
#       <td>0.690197</td>
#       <td>0.702387</td>
#       <td>0.797669</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.063100</td>
#       <td>0.704931</td>
#       <td>0.729736</td>
#       <td>0.707317</td>
#       <td>0.718352</td>
#       <td>0.805439</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.063100</td>
#       <td>0.666475</td>
#       <td>0.736410</td>
#       <td>0.714822</td>
#       <td>0.725455</td>
#       <td>0.812587</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.063100</td>
#       <td>0.654234</td>
#       <td>0.732614</td>
#       <td>0.716463</td>
#       <td>0.724449</td>
#       <td>0.812898</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.063100</td>
#       <td>0.646552</td>
#       <td>0.739518</td>
#       <td>0.719747</td>
#       <td>0.729498</td>
#       <td>0.816628</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.063100</td>
#       <td>0.647828</td>
#       <td>0.738232</td>
#       <td>0.720919</td>
#       <td>0.729473</td>
#       <td>0.815540</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.420600</td>
#       <td>0.647565</td>
#       <td>0.738015</td>
#       <td>0.722092</td>
#       <td>0.729967</td>
#       <td>0.815385</td>
#     </tr>
#   </tbody>
# </table><p>
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at DeepPavlov/rubert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Log: training for l_r:1e-05, w_d:0.0001, w_up:0.1...
#     <div>
#
#       <progress value='1020' max='1020' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1020/1020 01:40, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>2.167491</td>
#       <td>0.258602</td>
#       <td>0.163931</td>
#       <td>0.200660</td>
#       <td>0.437451</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>1.228741</td>
#       <td>0.599041</td>
#       <td>0.556754</td>
#       <td>0.577124</td>
#       <td>0.692618</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.931805</td>
#       <td>0.681116</td>
#       <td>0.641182</td>
#       <td>0.660546</td>
#       <td>0.760995</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.804476</td>
#       <td>0.705396</td>
#       <td>0.680582</td>
#       <td>0.692767</td>
#       <td>0.788345</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.322100</td>
#       <td>0.727224</td>
#       <td>0.721272</td>
#       <td>0.702158</td>
#       <td>0.711586</td>
#       <td>0.801709</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.322100</td>
#       <td>0.681360</td>
#       <td>0.738307</td>
#       <td>0.721857</td>
#       <td>0.729989</td>
#       <td>0.813986</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.322100</td>
#       <td>0.670152</td>
#       <td>0.739851</td>
#       <td>0.722326</td>
#       <td>0.730984</td>
#       <td>0.816628</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.322100</td>
#       <td>0.650956</td>
#       <td>0.745215</td>
#       <td>0.730535</td>
#       <td>0.737802</td>
#       <td>0.822222</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.322100</td>
#       <td>0.651183</td>
#       <td>0.744347</td>
#       <td>0.733349</td>
#       <td>0.738807</td>
#       <td>0.822222</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.415900</td>
#       <td>0.650567</td>
#       <td>0.744291</td>
#       <td>0.733818</td>
#       <td>0.739017</td>
#       <td>0.822999</td>
#     </tr>
#   </tbody>
# </table><p>
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at DeepPavlov/rubert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Log: training for l_r:1e-05, w_d:0.1, w_up:0...
#     <div>
#
#       <progress value='1020' max='1020' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1020/1020 01:40, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>1.568406</td>
#       <td>0.494294</td>
#       <td>0.416510</td>
#       <td>0.452081</td>
#       <td>0.609635</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>1.098555</td>
#       <td>0.622239</td>
#       <td>0.587946</td>
#       <td>0.604606</td>
#       <td>0.711888</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.870704</td>
#       <td>0.694335</td>
#       <td>0.661116</td>
#       <td>0.677319</td>
#       <td>0.773737</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.769822</td>
#       <td>0.710922</td>
#       <td>0.686914</td>
#       <td>0.698712</td>
#       <td>0.792075</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.087400</td>
#       <td>0.715900</td>
#       <td>0.719615</td>
#       <td>0.701220</td>
#       <td>0.710298</td>
#       <td>0.801088</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.087400</td>
#       <td>0.676004</td>
#       <td>0.735831</td>
#       <td>0.718574</td>
#       <td>0.727100</td>
#       <td>0.813986</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.087400</td>
#       <td>0.660523</td>
#       <td>0.738215</td>
#       <td>0.723499</td>
#       <td>0.730783</td>
#       <td>0.818337</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.087400</td>
#       <td>0.650194</td>
#       <td>0.742461</td>
#       <td>0.727486</td>
#       <td>0.734897</td>
#       <td>0.821445</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.087400</td>
#       <td>0.649826</td>
#       <td>0.741059</td>
#       <td>0.728893</td>
#       <td>0.734926</td>
#       <td>0.820824</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.414800</td>
#       <td>0.649129</td>
#       <td>0.743082</td>
#       <td>0.730535</td>
#       <td>0.736755</td>
#       <td>0.822378</td>
#     </tr>
#   </tbody>
# </table><p>
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at DeepPavlov/rubert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Log: training for l_r:1e-05, w_d:0.1, w_up:0.1...
#     <div>
#
#       <progress value='1020' max='1020' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1020/1020 01:40, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>2.167506</td>
#       <td>0.258602</td>
#       <td>0.163931</td>
#       <td>0.200660</td>
#       <td>0.437451</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>1.228689</td>
#       <td>0.598890</td>
#       <td>0.556754</td>
#       <td>0.577054</td>
#       <td>0.692463</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.931587</td>
#       <td>0.679920</td>
#       <td>0.641651</td>
#       <td>0.660232</td>
#       <td>0.760528</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.802212</td>
#       <td>0.707270</td>
#       <td>0.682223</td>
#       <td>0.694521</td>
#       <td>0.788500</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.322200</td>
#       <td>0.726597</td>
#       <td>0.721620</td>
#       <td>0.702158</td>
#       <td>0.711756</td>
#       <td>0.801865</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.322200</td>
#       <td>0.681729</td>
#       <td>0.735527</td>
#       <td>0.718105</td>
#       <td>0.726712</td>
#       <td>0.811500</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.322200</td>
#       <td>0.671547</td>
#       <td>0.738890</td>
#       <td>0.721388</td>
#       <td>0.730034</td>
#       <td>0.816472</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.322200</td>
#       <td>0.651006</td>
#       <td>0.746290</td>
#       <td>0.731238</td>
#       <td>0.738688</td>
#       <td>0.822222</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.322200</td>
#       <td>0.651092</td>
#       <td>0.745359</td>
#       <td>0.734522</td>
#       <td>0.739901</td>
#       <td>0.823155</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.416100</td>
#       <td>0.650467</td>
#       <td>0.745896</td>
#       <td>0.735225</td>
#       <td>0.740522</td>
#       <td>0.822999</td>
#     </tr>
#   </tbody>
# </table><p>
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at DeepPavlov/rubert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Log: training for l_r:2e-05, w_d:0.0001, w_up:0...
#     <div>
#
#       <progress value='1020' max='1020' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1020/1020 01:40, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>1.177941</td>
#       <td>0.599654</td>
#       <td>0.568715</td>
#       <td>0.583775</td>
#       <td>0.699145</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.789737</td>
#       <td>0.709701</td>
#       <td>0.689728</td>
#       <td>0.699572</td>
#       <td>0.794406</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.645379</td>
#       <td>0.735047</td>
#       <td>0.717636</td>
#       <td>0.726237</td>
#       <td>0.816006</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.621908</td>
#       <td>0.745625</td>
#       <td>0.729362</td>
#       <td>0.737404</td>
#       <td>0.822533</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.792800</td>
#       <td>0.606606</td>
#       <td>0.759924</td>
#       <td>0.749765</td>
#       <td>0.754811</td>
#       <td>0.831857</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.792800</td>
#       <td>0.589996</td>
#       <td>0.764999</td>
#       <td>0.756567</td>
#       <td>0.760759</td>
#       <td>0.838228</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.792800</td>
#       <td>0.581318</td>
#       <td>0.767166</td>
#       <td>0.757270</td>
#       <td>0.762186</td>
#       <td>0.840093</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.792800</td>
#       <td>0.575676</td>
#       <td>0.771368</td>
#       <td>0.761961</td>
#       <td>0.766635</td>
#       <td>0.842269</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.792800</td>
#       <td>0.580757</td>
#       <td>0.770655</td>
#       <td>0.761257</td>
#       <td>0.765927</td>
#       <td>0.841958</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.223700</td>
#       <td>0.582098</td>
#       <td>0.770655</td>
#       <td>0.761257</td>
#       <td>0.765927</td>
#       <td>0.842113</td>
#     </tr>
#   </tbody>
# </table><p>
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at DeepPavlov/rubert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Log: training for l_r:2e-05, w_d:0.0001, w_up:0.1...
#     <div>
#
#       <progress value='1020' max='1020' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1020/1020 01:41, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>1.586825</td>
#       <td>0.502390</td>
#       <td>0.419090</td>
#       <td>0.456975</td>
#       <td>0.610412</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.884827</td>
#       <td>0.686836</td>
#       <td>0.652205</td>
#       <td>0.669073</td>
#       <td>0.770474</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.681562</td>
#       <td>0.728846</td>
#       <td>0.711069</td>
#       <td>0.719848</td>
#       <td>0.812743</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.643673</td>
#       <td>0.746462</td>
#       <td>0.729831</td>
#       <td>0.738053</td>
#       <td>0.820513</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.035000</td>
#       <td>0.618301</td>
#       <td>0.759686</td>
#       <td>0.749531</td>
#       <td>0.754574</td>
#       <td>0.829060</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.035000</td>
#       <td>0.602772</td>
#       <td>0.761939</td>
#       <td>0.752111</td>
#       <td>0.756993</td>
#       <td>0.833722</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.035000</td>
#       <td>0.588415</td>
#       <td>0.764106</td>
#       <td>0.755863</td>
#       <td>0.759962</td>
#       <td>0.839472</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.035000</td>
#       <td>0.580502</td>
#       <td>0.771842</td>
#       <td>0.762430</td>
#       <td>0.767107</td>
#       <td>0.841492</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.035000</td>
#       <td>0.586383</td>
#       <td>0.769742</td>
#       <td>0.761257</td>
#       <td>0.765476</td>
#       <td>0.841647</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.227200</td>
#       <td>0.587188</td>
#       <td>0.769888</td>
#       <td>0.760319</td>
#       <td>0.765074</td>
#       <td>0.841647</td>
#     </tr>
#   </tbody>
# </table><p>
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at DeepPavlov/rubert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Log: training for l_r:2e-05, w_d:0.1, w_up:0...
#     <div>
#
#       <progress value='1020' max='1020' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1020/1020 01:41, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>1.177909</td>
#       <td>0.599654</td>
#       <td>0.568715</td>
#       <td>0.583775</td>
#       <td>0.699145</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.789881</td>
#       <td>0.710907</td>
#       <td>0.690901</td>
#       <td>0.700761</td>
#       <td>0.795027</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.646175</td>
#       <td>0.734532</td>
#       <td>0.718340</td>
#       <td>0.726346</td>
#       <td>0.815851</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.618923</td>
#       <td>0.746344</td>
#       <td>0.730066</td>
#       <td>0.738115</td>
#       <td>0.822999</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.792800</td>
#       <td>0.605060</td>
#       <td>0.758842</td>
#       <td>0.749765</td>
#       <td>0.754276</td>
#       <td>0.831857</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.792800</td>
#       <td>0.590085</td>
#       <td>0.763843</td>
#       <td>0.757036</td>
#       <td>0.760424</td>
#       <td>0.837918</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.792800</td>
#       <td>0.580731</td>
#       <td>0.769194</td>
#       <td>0.758912</td>
#       <td>0.764018</td>
#       <td>0.840870</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.792800</td>
#       <td>0.574004</td>
#       <td>0.772846</td>
#       <td>0.763602</td>
#       <td>0.768196</td>
#       <td>0.843046</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.792800</td>
#       <td>0.578525</td>
#       <td>0.769888</td>
#       <td>0.760319</td>
#       <td>0.765074</td>
#       <td>0.842113</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.223500</td>
#       <td>0.579906</td>
#       <td>0.770052</td>
#       <td>0.761023</td>
#       <td>0.765511</td>
#       <td>0.841958</td>
#     </tr>
#   </tbody>
# </table><p>
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at DeepPavlov/rubert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Log: training for l_r:2e-05, w_d:0.1, w_up:0.1...
#     <div>
#
#       <progress value='1020' max='1020' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1020/1020 01:41, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>1.583525</td>
#       <td>0.501682</td>
#       <td>0.419794</td>
#       <td>0.457099</td>
#       <td>0.612121</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.886042</td>
#       <td>0.689970</td>
#       <td>0.655019</td>
#       <td>0.672040</td>
#       <td>0.771096</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.679105</td>
#       <td>0.731121</td>
#       <td>0.712946</td>
#       <td>0.721919</td>
#       <td>0.812121</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.636498</td>
#       <td>0.742384</td>
#       <td>0.725844</td>
#       <td>0.734021</td>
#       <td>0.818493</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.034600</td>
#       <td>0.624545</td>
#       <td>0.758464</td>
#       <td>0.746013</td>
#       <td>0.752187</td>
#       <td>0.827506</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.034600</td>
#       <td>0.595410</td>
#       <td>0.770457</td>
#       <td>0.759615</td>
#       <td>0.764998</td>
#       <td>0.839161</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.034600</td>
#       <td>0.585721</td>
#       <td>0.767591</td>
#       <td>0.759850</td>
#       <td>0.763701</td>
#       <td>0.841336</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.034600</td>
#       <td>0.580062</td>
#       <td>0.767921</td>
#       <td>0.761257</td>
#       <td>0.764574</td>
#       <td>0.841958</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.034600</td>
#       <td>0.586209</td>
#       <td>0.769067</td>
#       <td>0.761492</td>
#       <td>0.765260</td>
#       <td>0.842424</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.226700</td>
#       <td>0.586446</td>
#       <td>0.769614</td>
#       <td>0.761492</td>
#       <td>0.765531</td>
#       <td>0.842424</td>
#     </tr>
#   </tbody>
# </table><p>
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at DeepPavlov/rubert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Log: training for l_r:5e-05, w_d:0.0001, w_up:0...
#     <div>
#
#       <progress value='1020' max='1020' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1020/1020 01:41, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.802316</td>
#       <td>0.690891</td>
#       <td>0.668856</td>
#       <td>0.679695</td>
#       <td>0.781507</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.590580</td>
#       <td>0.765114</td>
#       <td>0.750938</td>
#       <td>0.757960</td>
#       <td>0.838850</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.552147</td>
#       <td>0.768201</td>
#       <td>0.767120</td>
#       <td>0.767660</td>
#       <td>0.845688</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.578454</td>
#       <td>0.767929</td>
#       <td>0.765947</td>
#       <td>0.766937</td>
#       <td>0.845221</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.529600</td>
#       <td>0.593931</td>
#       <td>0.785459</td>
#       <td>0.772749</td>
#       <td>0.779052</td>
#       <td>0.853768</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.529600</td>
#       <td>0.584552</td>
#       <td>0.783828</td>
#       <td>0.786585</td>
#       <td>0.785204</td>
#       <td>0.854545</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.529600</td>
#       <td>0.612773</td>
#       <td>0.786689</td>
#       <td>0.784475</td>
#       <td>0.785580</td>
#       <td>0.855167</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.529600</td>
#       <td>0.613842</td>
#       <td>0.786283</td>
#       <td>0.787758</td>
#       <td>0.787020</td>
#       <td>0.856566</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.529600</td>
#       <td>0.623049</td>
#       <td>0.785346</td>
#       <td>0.786820</td>
#       <td>0.786082</td>
#       <td>0.856566</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.079800</td>
#       <td>0.624380</td>
#       <td>0.785047</td>
#       <td>0.787992</td>
#       <td>0.786517</td>
#       <td>0.856255</td>
#     </tr>
#   </tbody>
# </table><p>
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at DeepPavlov/rubert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Log: training for l_r:5e-05, w_d:0.0001, w_up:0.1...
#     <div>
#
#       <progress value='1020' max='1020' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1020/1020 01:41, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>1.149979</td>
#       <td>0.613824</td>
#       <td>0.574812</td>
#       <td>0.593678</td>
#       <td>0.707226</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.677157</td>
#       <td>0.728023</td>
#       <td>0.703096</td>
#       <td>0.715342</td>
#       <td>0.813054</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.565484</td>
#       <td>0.768240</td>
#       <td>0.755629</td>
#       <td>0.761882</td>
#       <td>0.838073</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.561818</td>
#       <td>0.764412</td>
#       <td>0.752580</td>
#       <td>0.758450</td>
#       <td>0.840249</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.806500</td>
#       <td>0.616475</td>
#       <td>0.768688</td>
#       <td>0.766886</td>
#       <td>0.767786</td>
#       <td>0.841492</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.806500</td>
#       <td>0.599701</td>
#       <td>0.779838</td>
#       <td>0.769231</td>
#       <td>0.774498</td>
#       <td>0.847552</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.806500</td>
#       <td>0.605144</td>
#       <td>0.781672</td>
#       <td>0.774156</td>
#       <td>0.777896</td>
#       <td>0.850194</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.806500</td>
#       <td>0.607227</td>
#       <td>0.783917</td>
#       <td>0.781895</td>
#       <td>0.782905</td>
#       <td>0.854545</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.806500</td>
#       <td>0.621410</td>
#       <td>0.787429</td>
#       <td>0.784475</td>
#       <td>0.785949</td>
#       <td>0.854856</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.101200</td>
#       <td>0.623333</td>
#       <td>0.786638</td>
#       <td>0.784240</td>
#       <td>0.785437</td>
#       <td>0.855167</td>
#     </tr>
#   </tbody>
# </table><p>
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at DeepPavlov/rubert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Log: training for l_r:5e-05, w_d:0.1, w_up:0...
#     <div>
#
#       <progress value='1020' max='1020' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1020/1020 01:41, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.805948</td>
#       <td>0.683666</td>
#       <td>0.666510</td>
#       <td>0.674979</td>
#       <td>0.779176</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.575234</td>
#       <td>0.765000</td>
#       <td>0.753518</td>
#       <td>0.759216</td>
#       <td>0.842113</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.544066</td>
#       <td>0.766209</td>
#       <td>0.759381</td>
#       <td>0.762780</td>
#       <td>0.843357</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.584620</td>
#       <td>0.766047</td>
#       <td>0.764071</td>
#       <td>0.765058</td>
#       <td>0.843667</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.531200</td>
#       <td>0.600345</td>
#       <td>0.771388</td>
#       <td>0.767589</td>
#       <td>0.769484</td>
#       <td>0.850505</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.531200</td>
#       <td>0.603919</td>
#       <td>0.777856</td>
#       <td>0.774390</td>
#       <td>0.776119</td>
#       <td>0.849728</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.531200</td>
#       <td>0.618860</td>
#       <td>0.778590</td>
#       <td>0.774390</td>
#       <td>0.776484</td>
#       <td>0.850971</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.531200</td>
#       <td>0.628763</td>
#       <td>0.782283</td>
#       <td>0.782833</td>
#       <td>0.782558</td>
#       <td>0.853147</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.531200</td>
#       <td>0.631612</td>
#       <td>0.784471</td>
#       <td>0.781895</td>
#       <td>0.783181</td>
#       <td>0.853924</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.080500</td>
#       <td>0.635425</td>
#       <td>0.782895</td>
#       <td>0.781426</td>
#       <td>0.782160</td>
#       <td>0.853613</td>
#     </tr>
#   </tbody>
# </table><p>
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at DeepPavlov/rubert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Log: training for l_r:5e-05, w_d:0.1, w_up:0.1...
#     <div>
#
#       <progress value='1020' max='1020' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1020/1020 01:41, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>1.149250</td>
#       <td>0.614612</td>
#       <td>0.574109</td>
#       <td>0.593670</td>
#       <td>0.708003</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.661019</td>
#       <td>0.727294</td>
#       <td>0.715525</td>
#       <td>0.721362</td>
#       <td>0.813675</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.575303</td>
#       <td>0.758038</td>
#       <td>0.757505</td>
#       <td>0.757771</td>
#       <td>0.838384</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.562447</td>
#       <td>0.773137</td>
#       <td>0.764071</td>
#       <td>0.768577</td>
#       <td>0.845688</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.795100</td>
#       <td>0.621142</td>
#       <td>0.766604</td>
#       <td>0.768762</td>
#       <td>0.767681</td>
#       <td>0.841026</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.795100</td>
#       <td>0.625854</td>
#       <td>0.777517</td>
#       <td>0.776970</td>
#       <td>0.777243</td>
#       <td>0.848485</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.795100</td>
#       <td>0.619768</td>
#       <td>0.783714</td>
#       <td>0.780957</td>
#       <td>0.782333</td>
#       <td>0.851593</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.795100</td>
#       <td>0.626221</td>
#       <td>0.783032</td>
#       <td>0.792214</td>
#       <td>0.787596</td>
#       <td>0.853147</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.795100</td>
#       <td>0.634473</td>
#       <td>0.785398</td>
#       <td>0.789634</td>
#       <td>0.787510</td>
#       <td>0.855633</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.093900</td>
#       <td>0.637206</td>
#       <td>0.787328</td>
#       <td>0.792683</td>
#       <td>0.789996</td>
#       <td>0.856410</td>
#     </tr>
#   </tbody>
# </table><p>

# %% [markdown]
# ___
# # Обучение с подобранными гиперпараметрами
# Лучшими оказались гиперпараметры: `learning_rate`= 5e-5, `weight_decay` = 0.1, `warm_up` = 0.1

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
import wandb
wandb.login()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
import os
os.environ["WANDB_PROJECT"]="ner_bert_nerel_bio"
hf_repo_id = "ekaterinatao/nerel-bio-rubert-base"

# %%
model = AutoModelForTokenClassification.from_pretrained(
    config.checkpoint, num_labels=config.n_labels, id2label=id_to_tag, label2id=tag_to_id)

training_args = TrainingArguments(
    output_dir=hf_repo_id,
    num_train_epochs=config.n_epochs,
    learning_rate=config.l_rate,
    weight_decay=config.w_decay,
    warmup_ratio=config.warm_up,
    per_device_train_batch_size=config.train_batch_size,
    per_device_eval_batch_size=config.eval_batch_size,
    group_by_length=True,
    optim="adamw_torch",
    lr_scheduler_type="cosine",
    evaluation_strategy="epoch",
    seed = config.seed,
    data_seed = config.seed,
    push_to_hub=True,
    save_strategy="no",
    report_to="wandb",
    run_name="rubert-base",
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset["train"],
    eval_dataset=tokenized_dataset["valid"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
# pytorch_model.bin:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at DeepPavlov/rubert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# wandb: Currently logged in as: taoea. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.3
# Run data is saved locally in <code>/content/wandb/run-20240227_083858-h1j872uv</code>
# Syncing run <strong><a href='https://wandb.ai/taoea/ner_bert_nerel_bio/runs/h1j872uv' target="_blank">rubert-base</a></strong> to <a href='https://wandb.ai/taoea/ner_bert_nerel_bio' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/taoea/ner_bert_nerel_bio' target="_blank">https://wandb.ai/taoea/ner_bert_nerel_bio</a>
#  View run at <a href='https://wandb.ai/taoea/ner_bert_nerel_bio/runs/h1j872uv' target="_blank">https://wandb.ai/taoea/ner_bert_nerel_bio/runs/h1j872uv</a>
#     <div>
#
#       <progress value='1020' max='1020' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1020/1020 02:12, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>1.121077</td>
#       <td>0.619560</td>
#       <td>0.580910</td>
#       <td>0.599613</td>
#       <td>0.712510</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.679956</td>
#       <td>0.733317</td>
#       <td>0.716463</td>
#       <td>0.724792</td>
#       <td>0.813675</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.598507</td>
#       <td>0.744463</td>
#       <td>0.748827</td>
#       <td>0.746639</td>
#       <td>0.830303</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.567296</td>
#       <td>0.760768</td>
#       <td>0.762195</td>
#       <td>0.761481</td>
#       <td>0.840249</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.795400</td>
#       <td>0.566465</td>
#       <td>0.775077</td>
#       <td>0.770169</td>
#       <td>0.772615</td>
#       <td>0.848485</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.795400</td>
#       <td>0.593402</td>
#       <td>0.782598</td>
#       <td>0.774156</td>
#       <td>0.778354</td>
#       <td>0.854390</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.795400</td>
#       <td>0.580425</td>
#       <td>0.779481</td>
#       <td>0.775094</td>
#       <td>0.777281</td>
#       <td>0.852681</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.795400</td>
#       <td>0.607486</td>
#       <td>0.783897</td>
#       <td>0.787758</td>
#       <td>0.785823</td>
#       <td>0.857653</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.795400</td>
#       <td>0.613945</td>
#       <td>0.788746</td>
#       <td>0.788931</td>
#       <td>0.788838</td>
#       <td>0.861383</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.102400</td>
#       <td>0.612167</td>
#       <td>0.787304</td>
#       <td>0.788227</td>
#       <td>0.787765</td>
#       <td>0.860140</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1020, training_loss=0.4412419216305602, metrics={'train_runtime': 139.794, 'train_samples_per_second': 43.779, 'train_steps_per_second': 7.296, 'total_flos': 856255185792720.0, 'train_loss': 0.4412419216305602, 'epoch': 10.0})

# %%
wandb.finish()
# Out:
# VBox(children=(Label(value='0.001 MB of 0.022 MB uploaded\r'), FloatProgress(value=0.05566678272980501, max=1.…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>▁▆▇▇▇█████</td></tr><tr><td>eval/f1</td><td>▁▆▆▇▇█████</td></tr><tr><td>eval/loss</td><td>█▂▁▁▁▁▁▂▂▂</td></tr><tr><td>eval/precision</td><td>▁▆▆▇▇█████</td></tr><tr><td>eval/recall</td><td>▁▆▇▇▇█████</td></tr><tr><td>eval/runtime</td><td>█▄▆▃▅▁▃▅▁▁</td></tr><tr><td>eval/samples_per_second</td><td>▁▅▃▆▄█▆▄██</td></tr><tr><td>eval/steps_per_second</td><td>▁▅▃▆▄█▆▄██</td></tr><tr><td>train/epoch</td><td>▁▂▃▃▄▄▅▆▆▇███</td></tr><tr><td>train/global_step</td><td>▁▂▃▃▄▄▅▆▆▇███</td></tr><tr><td>train/learning_rate</td><td>█▁</td></tr><tr><td>train/loss</td><td>█▁</td></tr><tr><td>train/total_flos</td><td>▁</td></tr><tr><td>train/train_loss</td><td>▁</td></tr><tr><td>train/train_runtime</td><td>▁</td></tr><tr><td>train/train_samples_per_second</td><td>▁</td></tr><tr><td>train/train_steps_per_second</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>0.86014</td></tr><tr><td>eval/f1</td><td>0.78777</td></tr><tr><td>eval/loss</td><td>0.61217</td></tr><tr><td>eval/precision</td><td>0.7873</td></tr><tr><td>eval/recall</td><td>0.78823</td></tr><tr><td>eval/runtime</td><td>0.8926</td></tr><tr><td>eval/samples_per_second</td><td>86.265</td></tr><tr><td>eval/steps_per_second</td><td>14.564</td></tr><tr><td>train/epoch</td><td>10.0</td></tr><tr><td>train/global_step</td><td>1020</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>train/loss</td><td>0.1024</td></tr><tr><td>train/total_flos</td><td>856255185792720.0</td></tr><tr><td>train/train_loss</td><td>0.44124</td></tr><tr><td>train/train_runtime</td><td>139.794</td></tr><tr><td>train/train_samples_per_second</td><td>43.779</td></tr><tr><td>train/train_steps_per_second</td><td>7.296</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">rubert-base</strong> at: <a href='https://wandb.ai/taoea/ner_bert_nerel_bio/runs/h1j872uv' target="_blank">https://wandb.ai/taoea/ner_bert_nerel_bio/runs/h1j872uv</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240227_083858-h1j872uv/logs</code>

# %%
trainer.save_model(hf_repo_id)
# Out:
# training_args.bin:   0%|          | 0.00/4.73k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/709M [00:00<?, ?B/s]
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# ### Оценка качества на тестовой выборке

# %%
predictions = trainer.predict(test_dataset=tokenized_dataset["test"])

# %%
predictions.metrics
# Out:
# {'test_loss': 0.6296454071998596,
#  'test_precision': 0.7918465227817746,
#  'test_recall': 0.7890083632019116,
#  'test_f1': 0.7904248952722921,
#  'test_accuracy': 0.8646103896103896,
#  'test_runtime': 0.8113,
#  'test_samples_per_second': 94.915,
#  'test_steps_per_second': 16.025}

# %% [markdown]
# Оценка модели на абстракте, которого не было в тестовом наборе

# %%
ner_bio = pipeline("ner", model=model, tokenizer=tokenizer, device=config.device)

# %%
abstract = """Цель. Оценить выживаемость у пациентов с болезнью Фабри (БФ) в зависимости от вида заместительной почечной терапии, и определить роль диализного скрининга в ранней диагностике БФ у родственников.
Материалы и методы. В исследование включали взрослых (старше 18 лет) пациентов с подтвержденным диагнозом БФ. Терминальная стадия хронической почечной недостаточности (тХПН) диагностировали в соответствии с рекомендациями Научного общества нефрологов России (2016) и KDIGO (2012). На основании опроса пробандов выявляли его родственников, которые могли унаследовать мутантный ген.
Результаты. У 50 (24,9%) из 201 обследованных пациентов с БФ диагностирована тХПН, в том числе у 48 (40%) из 120 мужчин и 2 (2,7%) из 81 женщин. Оценка кумулятивной частоты методом Каплана-Майера демонстрирует выраженное увеличение частоты регистрации тХПН к возрасту 20-30 лет, а к возрасту 50 лет ожидаемое количество пациентов с тХПН составляет 95%. Пяти из 50 больных с тХПН была выполнена трансплантация почки, в среднем, через 17 месяцев (диапазон от 7 до 70 месяцев) после инициации лечения гемодиализом. Умерло 15 (30%) из 50 пациентов, получавших лечение гемодиализом. Все умершие пациенты были мужского пола. Медиана возраста на момент летального исхода составила 45 (39; 58) лет. Среди пациентов, которым проведена трансплантация почки, летальных исходов зарегистрировано не было. У 44 (88%) из 50 пациентов диагноз БФ установлен, в среднем, через 1 год (диапазон от 0 до 12 лет) после начала лечения программным гемодиализом, в том числе у одного пациента – после трансплантации почки. Среди 44 пробандов, выявленных при всероссийском диализном скрининге, проведен семейный скрининг. Патогенная мутация в гене GLA диагностирована у 89 (57%) из 156 обследованных родственников диализных пробандов, в том числе у 18 детей моложе 18 лет, клинические проявления БФ имелись у 48 родственников. У 80,4% обследованных родственников диализных пробандов обнаружено поражение почек, преимущественно на ранних стадиях.
Заключение. ТХПН нередкое осложнение БФ, ассоциированное с неблагоприятным прогнозом. Однако диализный скрининг –  эффективный способ выявления пробандов с БФ, открывающий возможность установить диагноз БФ у родственников на ранних стадиях, когда лечение наиболее эффективно.
"""

# %%
ner_bio(abstract)
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# [{'entity': 'SCIPROC',
#   'score': 0.76758903,
#   'index': 1,
#   'word': 'Цель',
#   'start': 0,
#   'end': 4},
#  {'entity': 'SCIPROC',
#   'score': 0.5501071,
#   'index': 2,
#   'word': '.',
#   'start': 4,
#   'end': 5},
#  {'entity': 'FINDING',
#   'score': 0.8515094,
#   'index': 3,
#   'word': 'Оцен',
#   'start': 6,
#   'end': 10},
#  {'entity': 'FINDING',
#   'score': 0.9006018,
#   'index': 4,
#   'word': '##ить',
#   'start': 10,
#   'end': 13},
#  {'entity': 'PHYS',
#   'score': 0.77701473,
#   'index': 5,
#   'word': 'выжив',
#   'start': 14,
#   'end': 19},
#  {'entity': 'PHYS',
#   'score': 0.7618812,
#   'index': 6,
#   'word': '##аемость',
#   'start': 19,
#   'end': 26},
#  {'entity': 'PERSON',
#   'score': 0.9907691,
#   'index': 7,
#   'word': 'у',
#   'start': 27,
#   'end': 28},
#  {'entity': 'PERSON',
#   'score': 0.9979462,
#   'index': 8,
#   'word': 'пациентов',
#   'start': 29,
#   'end': 38},
#  {'entity': 'PERSON',
#   'score': 0.85923153,
#   'index': 9,
#   'word': 'с',
#   'start': 39,
#   'end': 40},
#  {'entity': 'DISO',
#   'score': 0.99781764,
#   'index': 10,
#   'word': 'болезнью',
#   'start': 41,
#   'end': 49},
#  {'entity': 'DISO',
#   'score': 0.3717766,
#   'index': 11,
#   'word': 'Фабри',
#   'start': 50,
#   'end': 55},
#  {'entity': 'DISO',
#   'score': 0.92830485,
#   'index': 12,
#   'word': '(',
#   'start': 56,
#   'end': 57},
#  {'entity': 'DISO',
#   'score': 0.9554268,
#   'index': 13,
#   'word': 'БФ',
#   'start': 57,
#   'end': 59},
#  {'entity': 'DISO',
#   'score': 0.7737331,
#   'index': 14,
#   'word': ')',
#   'start': 59,
#   'end': 60},
#  {'entity': 'FINDING',
#   'score': 0.45309386,
#   'index': 15,
#   'word': 'в',
#   'start': 61,
#   'end': 62},
#  {'entity': 'PHYS',
#   'score': 0.54714435,
#   'index': 16,
#   'word': 'зависимости',
#   'start': 63,
#   'end': 74},
#  {'entity': 'PHYS',
#   'score': 0.8822615,
#   'index': 17,
#   'word': 'от',
#   'start': 75,
#   'end': 77},
#  {'entity': 'PHYS',
#   'score': 0.9847046,
#   'index': 18,
#   'word': 'вида',
#   'start': 78,
#   'end': 82},
#  {'entity': 'MEDPROC',
#   'score': 0.9978676,
#   'index': 19,
#   'word': 'заместитель',
#   'start': 83,
#   'end': 94},
#  {'entity': 'MEDPROC',
#   'score': 0.9979584,
#   'index': 20,
#   'word': '##ной',
#   'start': 94,
#   'end': 97},
#  {'entity': 'MEDPROC',
#   'score': 0.9978666,
#   'index': 21,
#   'word': 'почечной',
#   'start': 98,
#   'end': 106},
#  {'entity': 'MEDPROC',
#   'score': 0.99815553,
#   'index': 22,
#   'word': 'терапии',
#   'start': 107,
#   'end': 114},
#  {'entity': 'FINDING',
#   'score': 0.7118839,
#   'index': 23,
#   'word': ',',
#   'start': 114,
#   'end': 115},
#  {'entity': 'FINDING',
#   'score': 0.65590614,
#   'index': 24,
#   'word': 'и',
#   'start': 116,
#   'end': 117},
#  {'entity': 'FINDING',
#   'score': 0.9051391,
#   'index': 25,
#   'word': 'определить',
#   'start': 118,
#   'end': 128},
#  {'entity': 'PHYS',
#   'score': 0.50847304,
#   'index': 26,
#   'word': 'роль',
#   'start': 129,
#   'end': 133},
#  {'entity': 'MEDPROC',
#   'score': 0.99527246,
#   'index': 27,
#   'word': 'диал',
#   'start': 134,
#   'end': 138},
#  {'entity': 'MEDPROC',
#   'score': 0.9939173,
#   'index': 28,
#   'word': '##изн',
#   'start': 138,
#   'end': 141},
#  {'entity': 'MEDPROC',
#   'score': 0.9930987,
#   'index': 29,
#   'word': '##ого',
#   'start': 141,
#   'end': 144},
#  {'entity': 'MEDPROC',
#   'score': 0.9863798,
#   'index': 30,
#   'word': 'скрин',
#   'start': 145,
#   'end': 150},
#  {'entity': 'MEDPROC',
#   'score': 0.9839219,
#   'index': 31,
#   'word': '##инга',
#   'start': 150,
#   'end': 154},
#  {'entity': 'MEDPROC',
#   'score': 0.7950134,
#   'index': 32,
#   'word': 'в',
#   'start': 155,
#   'end': 156},
#  {'entity': 'MEDPROC',
#   'score': 0.9298044,
#   'index': 33,
#   'word': 'ранней',
#   'start': 157,
#   'end': 163},
#  {'entity': 'MEDPROC',
#   'score': 0.889665,
#   'index': 34,
#   'word': 'диагностике',
#   'start': 164,
#   'end': 175},
#  {'entity': 'DISO',
#   'score': 0.9960426,
#   'index': 35,
#   'word': 'БФ',
#   'start': 176,
#   'end': 178},
#  {'entity': 'PERSON',
#   'score': 0.9768818,
#   'index': 36,
#   'word': 'у',
#   'start': 179,
#   'end': 180},
#  {'entity': 'PERSON',
#   'score': 0.99465346,
#   'index': 37,
#   'word': 'родственников',
#   'start': 181,
#   'end': 194},
#  {'entity': 'SCIPROC',
#   'score': 0.93063575,
#   'index': 38,
#   'word': '.',
#   'start': 194,
#   'end': 195},
#  {'entity': 'SCIPROC',
#   'score': 0.94960666,
#   'index': 39,
#   'word': 'Материалы',
#   'start': 196,
#   'end': 205},
#  {'entity': 'SCIPROC',
#   'score': 0.9446515,
#   'index': 40,
#   'word': 'и',
#   'start': 206,
#   'end': 207},
#  {'entity': 'SCIPROC',
#   'score': 0.75649685,
#   'index': 41,
#   'word': 'методы',
#   'start': 208,
#   'end': 214},
#  {'entity': 'SCIPROC',
#   'score': 0.9751211,
#   'index': 42,
#   'word': '.',
#   'start': 214,
#   'end': 215},
#  {'entity': 'SCIPROC',
#   'score': 0.95200413,
#   'index': 43,
#   'word': 'В',
#   'start': 216,
#   'end': 217},
#  {'entity': 'SCIPROC',
#   'score': 0.98355514,
#   'index': 44,
#   'word': 'исследование',
#   'start': 218,
#   'end': 230},
#  {'entity': 'SCIPROC',
#   'score': 0.6224985,
#   'index': 45,
#   'word': 'включали',
#   'start': 231,
#   'end': 239},
#  {'entity': 'PERSON',
#   'score': 0.9973686,
#   'index': 46,
#   'word': 'взрослых',
#   'start': 240,
#   'end': 248},
#  {'entity': 'PERSON',
#   'score': 0.9697176,
#   'index': 47,
#   'word': '(',
#   'start': 249,
#   'end': 250},
#  {'entity': 'AGE',
#   'score': 0.9945544,
#   'index': 48,
#   'word': 'старше',
#   'start': 250,
#   'end': 256},
#  {'entity': 'AGE',
#   'score': 0.9950566,
#   'index': 49,
#   'word': '18',
#   'start': 257,
#   'end': 259},
#  {'entity': 'AGE',
#   'score': 0.9943749,
#   'index': 50,
#   'word': 'лет',
#   'start': 260,
#   'end': 263},
#  {'entity': 'PERSON',
#   'score': 0.9935596,
#   'index': 51,
#   'word': ')',
#   'start': 263,
#   'end': 264},
#  {'entity': 'PERSON',
#   'score': 0.9981831,
#   'index': 52,
#   'word': 'пациентов',
#   'start': 265,
#   'end': 274},
#  {'entity': 'PERSON',
#   'score': 0.7368442,
#   'index': 53,
#   'word': 'с',
#   'start': 275,
#   'end': 276},
#  {'entity': 'DISO',
#   'score': 0.89059854,
#   'index': 54,
#   'word': 'подтвержден',
#   'start': 277,
#   'end': 288},
#  {'entity': 'DISO',
#   'score': 0.67907155,
#   'index': 55,
#   'word': '##ным',
#   'start': 288,
#   'end': 291},
#  {'entity': 'DISO',
#   'score': 0.8871363,
#   'index': 56,
#   'word': 'диагнозом',
#   'start': 292,
#   'end': 301},
#  {'entity': 'DISO',
#   'score': 0.9588692,
#   'index': 57,
#   'word': 'БФ',
#   'start': 302,
#   'end': 304},
#  {'entity': 'NUMBER',
#   'score': 0.6033684,
#   'index': 58,
#   'word': '.',
#   'start': 304,
#   'end': 305},
#  {'entity': 'DISO',
#   'score': 0.9950081,
#   'index': 59,
#   'word': 'Терминал',
#   'start': 306,
#   'end': 314},
#  {'entity': 'DISO',
#   'score': 0.9937615,
#   'index': 60,
#   'word': '##ь',
#   'start': 314,
#   'end': 315},
#  {'entity': 'DISO',
#   'score': 0.99461406,
#   'index': 61,
#   'word': '##ная',
#   'start': 315,
#   'end': 318},
#  {'entity': 'DISO',
#   'score': 0.9972506,
#   'index': 62,
#   'word': 'стадия',
#   'start': 319,
#   'end': 325},
#  {'entity': 'DISO',
#   'score': 0.99870455,
#   'index': 63,
#   'word': 'хронической',
#   'start': 326,
#   'end': 337},
#  {'entity': 'DISO',
#   'score': 0.9985238,
#   'index': 64,
#   'word': 'почечной',
#   'start': 338,
#   'end': 346},
#  {'entity': 'DISO',
#   'score': 0.9986066,
#   'index': 65,
#   'word': 'недостаточности',
#   'start': 347,
#   'end': 362},
#  {'entity': 'DISO',
#   'score': 0.99098396,
#   'index': 66,
#   'word': '(',
#   'start': 363,
#   'end': 364},
#  {'entity': 'DISO',
#   'score': 0.97912955,
#   'index': 67,
#   'word': 'т',
#   'start': 364,
#   'end': 365},
#  {'entity': 'DISO',
#   'score': 0.9877752,
#   'index': 68,
#   'word': '##Х',
#   'start': 365,
#   'end': 366},
#  {'entity': 'DISO',
#   'score': 0.99009377,
#   'index': 69,
#   'word': '##П',
#   'start': 366,
#   'end': 367},
#  {'entity': 'DISO',
#   'score': 0.99647874,
#   'index': 70,
#   'word': '##Н',
#   'start': 367,
#   'end': 368},
#  {'entity': 'DISO',
#   'score': 0.54148334,
#   'index': 71,
#   'word': ')',
#   'start': 368,
#   'end': 369},
#  {'entity': 'MEDPROC',
#   'score': 0.99062634,
#   'index': 72,
#   'word': 'диагностировали',
#   'start': 370,
#   'end': 385},
#  {'entity': 'SCIPROC',
#   'score': 0.7154324,
#   'index': 73,
#   'word': 'в',
#   'start': 386,
#   'end': 387},
#  {'entity': 'SCIPROC',
#   'score': 0.92304456,
#   'index': 74,
#   'word': 'соответствии',
#   'start': 388,
#   'end': 400},
#  {'entity': 'SCIPROC',
#   'score': 0.8958253,
#   'index': 75,
#   'word': 'с',
#   'start': 401,
#   'end': 402},
#  {'entity': 'SCIPROC',
#   'score': 0.9076434,
#   'index': 76,
#   'word': 'рекомендациями',
#   'start': 403,
#   'end': 417},
#  {'entity': 'ORGANIZATION',
#   'score': 0.9461687,
#   'index': 77,
#   'word': 'Научного',
#   'start': 418,
#   'end': 426},
#  {'entity': 'ORGANIZATION',
#   'score': 0.93570524,
#   'index': 78,
#   'word': 'общества',
#   'start': 427,
#   'end': 435},
#  {'entity': 'PROFESSION',
#   'score': 0.88500905,
#   'index': 79,
#   'word': 'неф',
#   'start': 436,
#   'end': 439},
#  {'entity': 'PROFESSION',
#   'score': 0.8653272,
#   'index': 80,
#   'word': '##рол',
#   'start': 439,
#   'end': 442},
#  {'entity': 'PROFESSION',
#   'score': 0.92862475,
#   'index': 81,
#   'word': '##огов',
#   'start': 442,
#   'end': 446},
#  {'entity': 'COUNTRY',
#   'score': 0.9132191,
#   'index': 82,
#   'word': 'России',
#   'start': 447,
#   'end': 453},
#  {'entity': 'DATE',
#   'score': 0.97770464,
#   'index': 83,
#   'word': '(',
#   'start': 454,
#   'end': 455},
#  {'entity': 'DATE',
#   'score': 0.9550639,
#   'index': 84,
#   'word': '2016',
#   'start': 455,
#   'end': 459},
#  {'entity': 'DATE',
#   'score': 0.52047104,
#   'index': 85,
#   'word': ')',
#   'start': 459,
#   'end': 460},
#  {'entity': 'ORGANIZATION',
#   'score': 0.91472787,
#   'index': 86,
#   'word': 'и',
#   'start': 461,
#   'end': 462},
#  {'entity': 'ORGANIZATION',
#   'score': 0.69360465,
#   'index': 87,
#   'word': 'K',
#   'start': 463,
#   'end': 464},
#  {'entity': 'ORGANIZATION',
#   'score': 0.5082951,
#   'index': 88,
#   'word': '##DI',
#   'start': 464,
#   'end': 466},
#  {'entity': 'ORGANIZATION',
#   'score': 0.3427907,
#   'index': 89,
#   'word': '##GO',
#   'start': 466,
#   'end': 468},
#  {'entity': 'DATE',
#   'score': 0.95531785,
#   'index': 90,
#   'word': '(',
#   'start': 469,
#   'end': 470},
#  {'entity': 'DATE',
#   'score': 0.93301386,
#   'index': 91,
#   'word': '2012',
#   'start': 470,
#   'end': 474},
#  {'entity': 'DATE',
#   'score': 0.6501143,
#   'index': 92,
#   'word': ')',
#   'start': 474,
#   'end': 475},
#  {'entity': 'SCIPROC',
#   'score': 0.89448905,
#   'index': 93,
#   'word': '.',
#   'start': 475,
#   'end': 476},
#  {'entity': 'SCIPROC',
#   'score': 0.90174013,
#   'index': 94,
#   'word': 'На',
#   'start': 477,
#   'end': 479},
#  {'entity': 'SCIPROC',
#   'score': 0.97273636,
#   'index': 95,
#   'word': 'основании',
#   'start': 480,
#   'end': 489},
#  {'entity': 'SCIPROC',
#   'score': 0.98908585,
#   'index': 96,
#   'word': 'опроса',
#   'start': 490,
#   'end': 496},
#  {'entity': 'CHEM',
#   'score': 0.9058602,
#   'index': 97,
#   'word': 'проба',
#   'start': 497,
#   'end': 502},
#  {'entity': 'CHEM',
#   'score': 0.83509886,
#   'index': 98,
#   'word': '##нд',
#   'start': 502,
#   'end': 504},
#  {'entity': 'CHEM',
#   'score': 0.77384365,
#   'index': 99,
#   'word': '##ов',
#   'start': 504,
#   'end': 506},
#  {'entity': 'MEDPROC',
#   'score': 0.86094075,
#   'index': 100,
#   'word': 'выявля',
#   'start': 507,
#   'end': 513},
#  {'entity': 'MEDPROC',
#   'score': 0.9335086,
#   'index': 101,
#   'word': '##ли',
#   'start': 513,
#   'end': 515},
#  {'entity': 'PHYS',
#   'score': 0.4705844,
#   'index': 102,
#   'word': 'его',
#   'start': 516,
#   'end': 519},
#  {'entity': 'PERSON',
#   'score': 0.9910944,
#   'index': 103,
#   'word': 'родственников',
#   'start': 520,
#   'end': 533},
#  {'entity': 'PERSON',
#   'score': 0.99022466,
#   'index': 104,
#   'word': ',',
#   'start': 533,
#   'end': 534},
#  {'entity': 'PERSON',
#   'score': 0.9562398,
#   'index': 105,
#   'word': 'которые',
#   'start': 535,
#   'end': 542},
#  {'entity': 'FINDING',
#   'score': 0.91057616,
#   'index': 106,
#   'word': 'могли',
#   'start': 543,
#   'end': 548},
#  {'entity': 'FINDING',
#   'score': 0.5597472,
#   'index': 107,
#   'word': 'унаслед',
#   'start': 549,
#   'end': 556},
#  {'entity': 'FINDING',
#   'score': 0.69497967,
#   'index': 108,
#   'word': '##овать',
#   'start': 556,
#   'end': 561},
#  {'entity': 'GENE',
#   'score': 0.7284705,
#   'index': 109,
#   'word': 'мутант',
#   'start': 562,
#   'end': 568},
#  {'entity': 'GENE',
#   'score': 0.69516325,
#   'index': 110,
#   'word': '##ный',
#   'start': 568,
#   'end': 571},
#  {'entity': 'GENE',
#   'score': 0.8731948,
#   'index': 111,
#   'word': 'ген',
#   'start': 572,
#   'end': 575},
#  {'entity': 'SCIPROC',
#   'score': 0.8388236,
#   'index': 112,
#   'word': '.',
#   'start': 575,
#   'end': 576},
#  {'entity': 'SCIPROC',
#   'score': 0.6017699,
#   'index': 113,
#   'word': 'Результаты',
#   'start': 577,
#   'end': 587},
#  {'entity': 'SCIPROC',
#   'score': 0.3175806,
#   'index': 114,
#   'word': '.',
#   'start': 587,
#   'end': 588},
#  {'entity': 'NUMBER',
#   'score': 0.45378113,
#   'index': 115,
#   'word': 'У',
#   'start': 589,
#   'end': 590},
#  {'entity': 'PERCENT',
#   'score': 0.78540874,
#   'index': 116,
#   'word': '50',
#   'start': 591,
#   'end': 593},
#  {'entity': 'PERCENT',
#   'score': 0.896298,
#   'index': 117,
#   'word': '(',
#   'start': 594,
#   'end': 595},
#  {'entity': 'PERCENT',
#   'score': 0.99659014,
#   'index': 118,
#   'word': '24',
#   'start': 595,
#   'end': 597},
#  {'entity': 'PERCENT',
#   'score': 0.9861676,
#   'index': 119,
#   'word': ',',
#   'start': 597,
#   'end': 598},
#  {'entity': 'PERCENT',
#   'score': 0.99526703,
#   'index': 120,
#   'word': '9',
#   'start': 598,
#   'end': 599},
#  {'entity': 'PERCENT',
#   'score': 0.9693552,
#   'index': 121,
#   'word': '%',
#   'start': 599,
#   'end': 600},
#  {'entity': 'PERCENT',
#   'score': 0.5374671,
#   'index': 122,
#   'word': ')',
#   'start': 600,
#   'end': 601},
#  {'entity': 'NUMBER',
#   'score': 0.8786097,
#   'index': 123,
#   'word': 'из',
#   'start': 602,
#   'end': 604},
#  {'entity': 'NUMBER',
#   'score': 0.9720139,
#   'index': 124,
#   'word': '201',
#   'start': 605,
#   'end': 608},
#  {'entity': 'PERSON',
#   'score': 0.9973386,
#   'index': 125,
#   'word': 'обслед',
#   'start': 609,
#   'end': 615},
#  {'entity': 'PERSON',
#   'score': 0.9978649,
#   'index': 126,
#   'word': '##ованных',
#   'start': 615,
#   'end': 622},
#  {'entity': 'PERSON',
#   'score': 0.99826115,
#   'index': 127,
#   'word': 'пациентов',
#   'start': 623,
#   'end': 632},
#  {'entity': 'DISO',
#   'score': 0.7655562,
#   'index': 128,
#   'word': 'с',
#   'start': 633,
#   'end': 634},
#  {'entity': 'DISO',
#   'score': 0.9822865,
#   'index': 129,
#   'word': 'БФ',
#   'start': 635,
#   'end': 637},
#  {'entity': 'FINDING',
#   'score': 0.57205886,
#   'index': 130,
#   'word': 'диагностирован',
#   'start': 638,
#   'end': 652},
#  {'entity': 'FINDING',
#   'score': 0.76713204,
#   'index': 131,
#   'word': '##а',
#   'start': 652,
#   'end': 653},
#  {'entity': 'DISO',
#   'score': 0.9446516,
#   'index': 132,
#   'word': 'т',
#   'start': 654,
#   'end': 655},
#  {'entity': 'DISO',
#   'score': 0.9813286,
#   'index': 133,
#   'word': '##Х',
#   'start': 655,
#   'end': 656},
#  {'entity': 'DISO',
#   'score': 0.9878543,
#   'index': 134,
#   'word': '##П',
#   'start': 656,
#   'end': 657},
#  {'entity': 'DISO',
#   'score': 0.9945451,
#   'index': 135,
#   'word': '##Н',
#   'start': 657,
#   'end': 658},
#  {'entity': 'NUMBER',
#   'score': 0.6103177,
#   'index': 136,
#   'word': ',',
#   'start': 658,
#   'end': 659},
#  {'entity': 'PERSON',
#   'score': 0.20933916,
#   'index': 137,
#   'word': 'в',
#   'start': 660,
#   'end': 661},
#  {'entity': 'PERSON',
#   'score': 0.31293222,
#   'index': 138,
#   'word': 'том',
#   'start': 662,
#   'end': 665},
#  {'entity': 'NUMBER',
#   'score': 0.6143364,
#   'index': 139,
#   'word': 'числе',
#   'start': 666,
#   'end': 671},
#  {'entity': 'PERSON',
#   'score': 0.40521786,
#   'index': 140,
#   'word': 'у',
#   'start': 672,
#   'end': 673},
#  {'entity': 'NUMBER',
#   'score': 0.8277267,
#   'index': 141,
#   'word': '48',
#   'start': 674,
#   'end': 676},
#  {'entity': 'PERCENT',
#   'score': 0.83708954,
#   'index': 142,
#   'word': '(',
#   'start': 677,
#   'end': 678},
#  {'entity': 'PERCENT',
#   'score': 0.99638367,
#   'index': 143,
#   'word': '40',
#   'start': 678,
#   'end': 680},
#  {'entity': 'PERCENT',
#   'score': 0.94302064,
#   'index': 144,
#   'word': '%',
#   'start': 680,
#   'end': 681},
#  {'entity': 'NUMBER',
#   'score': 0.42798257,
#   'index': 145,
#   'word': ')',
#   'start': 681,
#   'end': 682},
#  {'entity': 'NUMBER',
#   'score': 0.87322575,
#   'index': 146,
#   'word': 'из',
#   'start': 683,
#   'end': 685},
#  {'entity': 'NUMBER',
#   'score': 0.96510845,
#   'index': 147,
#   'word': '120',
#   'start': 686,
#   'end': 689},
#  {'entity': 'PERSON',
#   'score': 0.9975803,
#   'index': 148,
#   'word': 'мужчин',
#   'start': 690,
#   'end': 696},
#  {'entity': 'NUMBER',
#   'score': 0.8629538,
#   'index': 149,
#   'word': 'и',
#   'start': 697,
#   'end': 698},
#  {'entity': 'PERCENT',
#   'score': 0.5765499,
#   'index': 150,
#   'word': '2',
#   'start': 699,
#   'end': 700},
#  {'entity': 'PERCENT',
#   'score': 0.8943062,
#   'index': 151,
#   'word': '(',
#   'start': 701,
#   'end': 702},
#  {'entity': 'PERCENT',
#   'score': 0.99620134,
#   'index': 152,
#   'word': '2',
#   'start': 702,
#   'end': 703},
#  {'entity': 'PERCENT',
#   'score': 0.9853277,
#   'index': 153,
#   'word': ',',
#   'start': 703,
#   'end': 704},
#  {'entity': 'PERCENT',
#   'score': 0.99386287,
#   'index': 154,
#   'word': '7',
#   'start': 704,
#   'end': 705},
#  {'entity': 'PERCENT',
#   'score': 0.9432987,
#   'index': 155,
#   'word': '%',
#   'start': 705,
#   'end': 706},
#  {'entity': 'NUMBER',
#   'score': 0.44360662,
#   'index': 156,
#   'word': ')',
#   'start': 706,
#   'end': 707},
#  {'entity': 'NUMBER',
#   'score': 0.86358595,
#   'index': 157,
#   'word': 'из',
#   'start': 708,
#   'end': 710},
#  {'entity': 'NUMBER',
#   'score': 0.9721061,
#   'index': 158,
#   'word': '81',
#   'start': 711,
#   'end': 713},
#  {'entity': 'PERSON',
#   'score': 0.99765295,
#   'index': 159,
#   'word': 'женщин',
#   'start': 714,
#   'end': 720},
#  {'entity': 'SCIPROC',
#   'score': 0.43599078,
#   'index': 160,
#   'word': '.',
#   'start': 720,
#   'end': 721},
#  {'entity': 'FINDING',
#   'score': 0.8229849,
#   'index': 161,
#   'word': 'Оценка',
#   'start': 722,
#   'end': 728},
#  {'entity': 'SCIPROC',
#   'score': 0.81431335,
#   'index': 162,
#   'word': 'кумулят',
#   'start': 729,
#   'end': 736},
#  {'entity': 'PHYS',
#   'score': 0.5067433,
#   'index': 163,
#   'word': '##ивной',
#   'start': 736,
#   'end': 741},
#  {'entity': 'PHYS',
#   'score': 0.74826825,
#   'index': 164,
#   'word': 'частоты',
#   'start': 742,
#   'end': 749},
#  {'entity': 'SCIPROC',
#   'score': 0.9800168,
#   'index': 165,
#   'word': 'методом',
#   'start': 750,
#   'end': 757},
#  {'entity': 'PERSON',
#   'score': 0.82668555,
#   'index': 166,
#   'word': 'Каплан',
#   'start': 758,
#   'end': 764},
#  {'entity': 'PERSON',
#   'score': 0.8729325,
#   'index': 167,
#   'word': '##а',
#   'start': 764,
#   'end': 765},
#  {'entity': 'PERSON',
#   'score': 0.89405036,
#   'index': 168,
#   'word': '-',
#   'start': 765,
#   'end': 766},
#  {'entity': 'PERSON',
#   'score': 0.7859722,
#   'index': 169,
#   'word': 'Майера',
#   'start': 766,
#   'end': 772},
#  {'entity': 'FINDING',
#   'score': 0.9975496,
#   'index': 170,
#   'word': 'демонстрирует',
#   'start': 773,
#   'end': 786},
#  {'entity': 'FINDING',
#   'score': 0.9974011,
#   'index': 171,
#   'word': 'выраженное',
#   'start': 787,
#   'end': 797},
#  {'entity': 'FINDING',
#   'score': 0.9965203,
#   'index': 172,
#   'word': 'увеличение',
#   'start': 798,
#   'end': 808},
#  {'entity': 'PHYS',
#   'score': 0.7699158,
#   'index': 173,
#   'word': 'частоты',
#   'start': 809,
#   'end': 816},
#  {'entity': 'PHYS',
#   'score': 0.35517246,
#   'index': 174,
#   'word': 'регистрации',
#   'start': 817,
#   'end': 828},
#  {'entity': 'DISO',
#   'score': 0.8587137,
#   'index': 175,
#   'word': 'т',
#   'start': 829,
#   'end': 830},
#  {'entity': 'DISO',
#   'score': 0.9427396,
#   'index': 176,
#   'word': '##Х',
#   'start': 830,
#   'end': 831},
#  {'entity': 'DISO',
#   'score': 0.9694788,
#   'index': 177,
#   'word': '##П',
#   'start': 831,
#   'end': 832},
#  {'entity': 'DISO',
#   'score': 0.989486,
#   'index': 178,
#   'word': '##Н',
#   'start': 832,
#   'end': 833},
#  {'entity': 'PHYS',
#   'score': 0.9918291,
#   'index': 179,
#   'word': 'к',
#   'start': 834,
#   'end': 835},
#  {'entity': 'PHYS',
#   'score': 0.97315335,
#   'index': 180,
#   'word': 'возрасту',
#   'start': 836,
#   'end': 844},
#  {'entity': 'AGE',
#   'score': 0.9940347,
#   'index': 181,
#   'word': '20',
#   'start': 845,
#   'end': 847},
#  {'entity': 'AGE',
#   'score': 0.99107283,
#   'index': 182,
#   'word': '-',
#   'start': 847,
#   'end': 848},
#  {'entity': 'AGE',
#   'score': 0.9927027,
#   'index': 183,
#   'word': '30',
#   'start': 848,
#   'end': 850},
#  {'entity': 'AGE',
#   'score': 0.9892014,
#   'index': 184,
#   'word': 'лет',
#   'start': 851,
#   'end': 854},
#  {'entity': 'FINDING',
#   'score': 0.74414295,
#   'index': 185,
#   'word': ',',
#   'start': 854,
#   'end': 855},
#  {'entity': 'PHYS',
#   'score': 0.763468,
#   'index': 186,
#   'word': 'а',
#   'start': 856,
#   'end': 857},
#  {'entity': 'PHYS',
#   'score': 0.9790363,
#   'index': 187,
#   'word': 'к',
#   'start': 858,
#   'end': 859},
#  {'entity': 'PHYS',
#   'score': 0.9742376,
#   'index': 188,
#   'word': 'возрасту',
#   'start': 860,
#   'end': 868},
#  {'entity': 'AGE',
#   'score': 0.9914619,
#   'index': 189,
#   'word': '50',
#   'start': 869,
#   'end': 871},
#  {'entity': 'AGE',
#   'score': 0.9861252,
#   'index': 190,
#   'word': 'лет',
#   'start': 872,
#   'end': 875},
#  {'entity': 'FINDING',
#   'score': 0.98281026,
#   'index': 191,
#   'word': 'ожид',
#   'start': 876,
#   'end': 880},
#  {'entity': 'FINDING',
#   'score': 0.99208635,
#   'index': 192,
#   'word': '##аемое',
#   'start': 880,
#   'end': 885},
#  {'entity': 'FINDING',
#   'score': 0.7280449,
#   'index': 193,
#   'word': 'количество',
#   'start': 886,
#   'end': 896},
#  {'entity': 'PERSON',
#   'score': 0.99813014,
#   'index': 194,
#   'word': 'пациентов',
#   'start': 897,
#   'end': 906},
#  {'entity': 'PERSON',
#   'score': 0.9666472,
#   'index': 195,
#   'word': 'с',
#   'start': 907,
#   'end': 908},
#  {'entity': 'DISO',
#   'score': 0.87082493,
#   'index': 196,
#   'word': 'т',
#   'start': 909,
#   'end': 910},
#  {'entity': 'DISO',
#   'score': 0.9510249,
#   'index': 197,
#   'word': '##Х',
#   'start': 910,
#   'end': 911},
#  {'entity': 'DISO',
#   'score': 0.9775533,
#   'index': 198,
#   'word': '##П',
#   'start': 911,
#   'end': 912},
#  {'entity': 'DISO',
#   'score': 0.992276,
#   'index': 199,
#   'word': '##Н',
#   'start': 912,
#   'end': 913},
#  {'entity': 'FINDING',
#   'score': 0.99510384,
#   'index': 200,
#   'word': 'составляет',
#   'start': 914,
#   'end': 924},
#  {'entity': 'PERCENT',
#   'score': 0.97977406,
#   'index': 201,
#   'word': '95',
#   'start': 925,
#   'end': 927},
#  {'entity': 'PERCENT',
#   'score': 0.502143,
#   'index': 202,
#   'word': '%',
#   'start': 927,
#   'end': 928},
#  {'entity': 'SCIPROC',
#   'score': 0.2826817,
#   'index': 203,
#   'word': '.',
#   'start': 928,
#   'end': 929},
#  {'entity': 'NUMBER',
#   'score': 0.91186565,
#   'index': 204,
#   'word': 'Пяти',
#   'start': 930,
#   'end': 934},
#  {'entity': 'NUMBER',
#   'score': 0.7506699,
#   'index': 205,
#   'word': 'из',
#   'start': 935,
#   'end': 937},
#  {'entity': 'NUMBER',
#   'score': 0.9318646,
#   'index': 206,
#   'word': '50',
#   'start': 938,
#   'end': 940},
#  {'entity': 'PERSON',
#   'score': 0.9981546,
#   'index': 207,
#   'word': 'больных',
#   'start': 941,
#   'end': 948},
#  {'entity': 'PERSON',
#   'score': 0.90157133,
#   'index': 208,
#   'word': 'с',
#   'start': 949,
#   'end': 950},
#  {'entity': 'DISO',
#   'score': 0.8877473,
#   'index': 209,
#   'word': 'т',
#   'start': 951,
#   'end': 952},
#  {'entity': 'DISO',
#   'score': 0.97299373,
#   'index': 210,
#   'word': '##Х',
#   'start': 952,
#   'end': 953},
#  {'entity': 'DISO',
#   'score': 0.9859753,
#   'index': 211,
#   'word': '##П',
#   'start': 953,
#   'end': 954},
#  {'entity': 'DISO',
#   'score': 0.9946167,
#   'index': 212,
#   'word': '##Н',
#   'start': 954,
#   'end': 955},
#  {'entity': 'MEDPROC',
#   'score': 0.8538173,
#   'index': 213,
#   'word': 'была',
#   'start': 956,
#   'end': 960},
#  {'entity': 'MEDPROC',
#   'score': 0.96523863,
#   'index': 214,
#   'word': 'выполнена',
#   'start': 961,
#   'end': 970},
#  {'entity': 'MEDPROC',
#   'score': 0.9949778,
#   'index': 215,
#   'word': 'трансплант',
#   'start': 971,
#   'end': 981},
#  {'entity': 'MEDPROC',
#   'score': 0.995017,
#   'index': 216,
#   'word': '##ация',
#   'start': 981,
#   'end': 985},
#  {'entity': 'ANATOMY',
#   'score': 0.998173,
#   'index': 217,
#   'word': 'почки',
#   'start': 986,
#   'end': 991},
#  {'entity': 'DATE',
#   'score': 0.3758143,
#   'index': 218,
#   'word': ',',
#   'start': 991,
#   'end': 992},
#  {'entity': 'DATE',
#   'score': 0.974426,
#   'index': 219,
#   'word': 'в',
#   'start': 993,
#   'end': 994},
#  {'entity': 'DATE',
#   'score': 0.7354433,
#   'index': 220,
#   'word': 'среднем',
#   'start': 995,
#   'end': 1002},
#  {'entity': 'DATE',
#   'score': 0.9872732,
#   'index': 221,
#   'word': ',',
#   'start': 1002,
#   'end': 1003},
#  {'entity': 'DATE',
#   'score': 0.9957579,
#   'index': 222,
#   'word': 'через',
#   'start': 1004,
#   'end': 1009},
#  {'entity': 'DATE',
#   'score': 0.99431276,
#   'index': 223,
#   'word': '17',
#   'start': 1010,
#   'end': 1012},
#  {'entity': 'DATE',
#   'score': 0.99271107,
#   'index': 224,
#   'word': 'месяцев',
#   'start': 1013,
#   'end': 1020},
#  {'entity': 'DATE',
#   'score': 0.97166914,
#   'index': 225,
#   'word': '(',
#   'start': 1021,
#   'end': 1022},
#  {'entity': 'DATE',
#   'score': 0.43584085,
#   'index': 226,
#   'word': 'диапазон',
#   'start': 1022,
#   'end': 1030},
#  {'entity': 'DATE',
#   'score': 0.97278225,
#   'index': 227,
#   'word': 'от',
#   'start': 1031,
#   'end': 1033},
#  {'entity': 'DATE',
#   'score': 0.98450583,
#   'index': 228,
#   'word': '7',
#   'start': 1034,
#   'end': 1035},
#  {'entity': 'DATE',
#   'score': 0.97933817,
#   'index': 229,
#   'word': 'до',
#   'start': 1036,
#   'end': 1038},
#  {'entity': 'DATE',
#   'score': 0.9794511,
#   'index': 230,
#   'word': '70',
#   'start': 1039,
#   'end': 1041},
#  {'entity': 'DATE',
#   'score': 0.9850581,
#   'index': 231,
#   'word': 'месяцев',
#   'start': 1042,
#   'end': 1049},
#  {'entity': 'DATE',
#   'score': 0.8416011,
#   'index': 232,
#   'word': ')',
#   'start': 1049,
#   'end': 1050},
#  {'entity': 'PHYS',
#   'score': 0.26539093,
#   'index': 233,
#   'word': 'после',
#   'start': 1051,
#   'end': 1056},
#  {'entity': 'MEDPROC',
#   'score': 0.98686105,
#   'index': 234,
#   'word': 'инициации',
#   'start': 1057,
#   'end': 1066},
#  {'entity': 'MEDPROC',
#   'score': 0.9976927,
#   'index': 235,
#   'word': 'лечения',
#   'start': 1067,
#   'end': 1074},
#  {'entity': 'MEDPROC',
#   'score': 0.9977926,
#   'index': 236,
#   'word': 'гем',
#   'start': 1075,
#   'end': 1078},
#  {'entity': 'MEDPROC',
#   'score': 0.9973339,
#   'index': 237,
#   'word': '##оди',
#   'start': 1078,
#   'end': 1081},
#  {'entity': 'MEDPROC',
#   'score': 0.9973936,
#   'index': 238,
#   'word': '##ализ',
#   'start': 1081,
#   'end': 1085},
#  {'entity': 'MEDPROC',
#   'score': 0.9973603,
#   'index': 239,
#   'word': '##ом',
#   'start': 1085,
#   'end': 1087},
#  {'entity': 'FINDING',
#   'score': 0.79595,
#   'index': 240,
#   'word': '.',
#   'start': 1087,
#   'end': 1088},
#  {'entity': 'FINDING',
#   'score': 0.49123695,
#   'index': 241,
#   'word': 'Умер',
#   'start': 1089,
#   'end': 1093},
#  {'entity': 'FINDING',
#   'score': 0.7378451,
#   'index': 242,
#   'word': '##ло',
#   'start': 1093,
#   'end': 1095},
#  {'entity': 'PERCENT',
#   'score': 0.9536329,
#   'index': 243,
#   'word': '15',
#   'start': 1096,
#   'end': 1098},
#  {'entity': 'PERCENT',
#   'score': 0.7514632,
#   'index': 244,
#   'word': '(',
#   'start': 1099,
#   'end': 1100},
#  {'entity': 'PERCENT',
#   'score': 0.9934488,
#   'index': 245,
#   'word': '30',
#   'start': 1100,
#   'end': 1102},
#  {'entity': 'PERCENT',
#   'score': 0.53047967,
#   'index': 246,
#   'word': '%',
#   'start': 1102,
#   'end': 1103},
#  {'entity': 'PERCENT',
#   'score': 0.28648296,
#   'index': 247,
#   'word': ')',
#   'start': 1103,
#   'end': 1104},
#  {'entity': 'NUMBER',
#   'score': 0.6315352,
#   'index': 248,
#   'word': 'из',
#   'start': 1105,
#   'end': 1107},
#  {'entity': 'NUMBER',
#   'score': 0.75734663,
#   'index': 249,
#   'word': '50',
#   'start': 1108,
#   'end': 1110},
#  {'entity': 'PERSON',
#   'score': 0.9978782,
#   'index': 250,
#   'word': 'пациентов',
#   'start': 1111,
#   'end': 1120},
#  {'entity': 'PERSON',
#   'score': 0.99337864,
#   'index': 251,
#   'word': ',',
#   'start': 1120,
#   'end': 1121},
#  {'entity': 'ACTIVITY',
#   'score': 0.3079676,
#   'index': 252,
#   'word': 'получ',
#   'start': 1122,
#   'end': 1127},
#  {'entity': 'PERSON',
#   'score': 0.8788902,
#   'index': 253,
#   'word': '##авших',
#   'start': 1127,
#   'end': 1132},
#  {'entity': 'MEDPROC',
#   'score': 0.9973157,
#   'index': 254,
#   'word': 'лечение',
#   'start': 1133,
#   'end': 1140},
#  {'entity': 'MEDPROC',
#   'score': 0.99783677,
#   'index': 255,
#   'word': 'гем',
#   'start': 1141,
#   'end': 1144},
#  {'entity': 'MEDPROC',
#   'score': 0.9974362,
#   'index': 256,
#   'word': '##оди',
#   'start': 1144,
#   'end': 1147},
#  {'entity': 'MEDPROC',
#   'score': 0.997493,
#   'index': 257,
#   'word': '##ализ',
#   'start': 1147,
#   'end': 1151},
#  {'entity': 'MEDPROC',
#   'score': 0.9975032,
#   'index': 258,
#   'word': '##ом',
#   'start': 1151,
#   'end': 1153},
#  {'entity': 'FINDING',
#   'score': 0.6068859,
#   'index': 259,
#   'word': '.',
#   'start': 1153,
#   'end': 1154},
#  {'entity': 'PERSON',
#   'score': 0.3242566,
#   'index': 260,
#   'word': 'Все',
#   'start': 1155,
#   'end': 1158},
#  {'entity': 'PERSON',
#   'score': 0.6028805,
#   'index': 261,
#   'word': 'умер',
#   'start': 1159,
#   'end': 1163},
#  {'entity': 'PERSON',
#   'score': 0.9731914,
#   'index': 262,
#   'word': '##шие',
#   'start': 1163,
#   'end': 1166},
#  {'entity': 'PERSON',
#   'score': 0.99658173,
#   'index': 263,
#   'word': 'пациенты',
#   'start': 1167,
#   'end': 1175},
#  {'entity': 'PHYS',
#   'score': 0.66556126,
#   'index': 264,
#   'word': 'были',
#   'start': 1176,
#   'end': 1180},
#  {'entity': 'PHYS',
#   'score': 0.99616075,
#   'index': 265,
#   'word': 'мужского',
#   'start': 1181,
#   'end': 1189},
#  {'entity': 'PHYS',
#   'score': 0.99643445,
#   'index': 266,
#   'word': 'пола',
#   'start': 1190,
#   'end': 1194},
#  {'entity': 'FINDING',
#   'score': 0.7099378,
#   'index': 267,
#   'word': '.',
#   'start': 1194,
#   'end': 1195},
#  {'entity': 'FINDING',
#   'score': 0.9928322,
#   'index': 268,
#   'word': 'Медиа',
#   'start': 1196,
#   'end': 1201},
#  {'entity': 'FINDING',
#   'score': 0.9871237,
#   'index': 269,
#   'word': '##на',
#   'start': 1201,
#   'end': 1203},
#  {'entity': 'PHYS',
#   'score': 0.99325836,
#   'index': 270,
#   'word': 'возраста',
#   'start': 1204,
#   'end': 1212},
#  {'entity': 'FINDING',
#   'score': 0.79107267,
#   'index': 271,
#   'word': 'на',
#   'start': 1213,
#   'end': 1215},
#  {'entity': 'FINDING',
#   'score': 0.86849815,
#   'index': 272,
#   'word': 'момент',
#   'start': 1216,
#   'end': 1222},
#  {'entity': 'FINDING',
#   'score': 0.965452,
#   'index': 273,
#   'word': 'летал',
#   'start': 1223,
#   'end': 1228},
#  {'entity': 'FINDING',
#   'score': 0.95390445,
#   'index': 274,
#   'word': '##ь',
#   'start': 1228,
#   'end': 1229},
#  {'entity': 'FINDING',
#   'score': 0.96665025,
#   'index': 275,
#   'word': '##ного',
#   'start': 1229,
#   'end': 1233},
#  {'entity': 'FINDING',
#   'score': 0.97841346,
#   'index': 276,
#   'word': 'исхода',
#   'start': 1234,
#   'end': 1240},
#  {'entity': 'FINDING',
#   'score': 0.99143124,
#   'index': 277,
#   'word': 'составила',
#   'start': 1241,
#   'end': 1250},
#  {'entity': 'AGE',
#   'score': 0.99448663,
#   'index': 278,
#   'word': '45',
#   'start': 1251,
#   'end': 1253},
#  {'entity': 'AGE',
#   'score': 0.5969515,
#   'index': 279,
#   'word': '(',
#   'start': 1254,
#   'end': 1255},
#  {'entity': 'AGE',
#   'score': 0.9950787,
#   'index': 280,
#   'word': '39',
#   'start': 1255,
#   'end': 1257},
#  {'entity': 'AGE',
#   'score': 0.4125715,
#   'index': 281,
#   'word': ';',
#   'start': 1257,
#   'end': 1258},
#  {'entity': 'AGE',
#   'score': 0.99501884,
#   'index': 282,
#   'word': '58',
#   'start': 1259,
#   'end': 1261},
#  {'entity': 'AGE',
#   'score': 0.9237021,
#   'index': 283,
#   'word': ')',
#   'start': 1261,
#   'end': 1262},
#  {'entity': 'AGE',
#   'score': 0.9806638,
#   'index': 284,
#   'word': 'лет',
#   'start': 1263,
#   'end': 1266},
#  {'entity': 'FINDING',
#   'score': 0.7113689,
#   'index': 285,
#   'word': '.',
#   'start': 1266,
#   'end': 1267},
#  {'entity': 'PERSON',
#   'score': 0.91025746,
#   'index': 286,
#   'word': 'Среди',
#   'start': 1268,
#   'end': 1273},
#  {'entity': 'PERSON',
#   'score': 0.9980058,
#   'index': 287,
#   'word': 'пациентов',
#   'start': 1274,
#   'end': 1283},
#  {'entity': 'PERSON',
#   'score': 0.99551517,
#   'index': 288,
#   'word': ',',
#   'start': 1283,
#   'end': 1284},
#  {'entity': 'PERSON',
#   'score': 0.9932253,
#   'index': 289,
#   'word': 'которым',
#   'start': 1285,
#   'end': 1292},
#  {'entity': 'MEDPROC',
#   'score': 0.99395967,
#   'index': 290,
#   'word': 'проведена',
#   'start': 1293,
#   'end': 1302},
#  {'entity': 'MEDPROC',
#   'score': 0.99719185,
#   'index': 291,
#   'word': 'трансплант',
#   'start': 1303,
#   'end': 1313},
#  {'entity': 'MEDPROC',
#   'score': 0.99722195,
#   'index': 292,
#   'word': '##ация',
#   'start': 1313,
#   'end': 1317},
#  {'entity': 'ANATOMY',
#   'score': 0.99813473,
#   'index': 293,
#   'word': 'почки',
#   'start': 1318,
#   'end': 1323},
#  {'entity': 'FINDING',
#   'score': 0.9955863,
#   'index': 294,
#   'word': ',',
#   'start': 1323,
#   'end': 1324},
#  {'entity': 'FINDING',
#   'score': 0.9915712,
#   'index': 295,
#   'word': 'летал',
#   'start': 1325,
#   'end': 1330},
#  {'entity': 'FINDING',
#   'score': 0.99392223,
#   'index': 296,
#   'word': '##ь',
#   'start': 1330,
#   'end': 1331},
#  {'entity': 'FINDING',
#   'score': 0.9944976,
#   'index': 297,
#   'word': '##ных',
#   'start': 1331,
#   'end': 1334},
#  {'entity': 'FINDING',
#   'score': 0.9926428,
#   'index': 298,
#   'word': 'исход',
#   'start': 1335,
#   'end': 1340},
#  {'entity': 'FINDING',
#   'score': 0.99423707,
#   'index': 299,
#   'word': '##ов',
#   'start': 1340,
#   'end': 1342},
#  {'entity': 'FINDING',
#   'score': 0.9958111,
#   'index': 300,
#   'word': 'зарегистрировано',
#   'start': 1343,
#   'end': 1359},
#  {'entity': 'FINDING',
#   'score': 0.99615496,
#   'index': 301,
#   'word': 'не',
#   'start': 1360,
#   'end': 1362},
#  {'entity': 'FINDING',
#   'score': 0.9963019,
#   'index': 302,
#   'word': 'было',
#   'start': 1363,
#   'end': 1367},
#  {'entity': 'FINDING',
#   'score': 0.8133507,
#   'index': 303,
#   'word': '.',
#   'start': 1367,
#   'end': 1368},
#  {'entity': 'PERSON',
#   'score': 0.44017145,
#   'index': 304,
#   'word': 'У',
#   'start': 1369,
#   'end': 1370},
#  {'entity': 'NUMBER',
#   'score': 0.66502154,
#   'index': 305,
#   'word': '44',
#   'start': 1371,
#   'end': 1373},
#  {'entity': 'NUMBER',
#   'score': 0.51378673,
#   'index': 306,
#   'word': '(',
#   'start': 1374,
#   'end': 1375},
#  {'entity': 'PERCENT',
#   'score': 0.9912314,
#   'index': 307,
#   'word': '88',
#   'start': 1375,
#   'end': 1377},
#  {'entity': 'PERCENT',
#   'score': 0.6605583,
#   'index': 308,
#   'word': '%',
#   'start': 1377,
#   'end': 1378},
#  {'entity': 'PERSON',
#   'score': 0.35276148,
#   'index': 309,
#   'word': ')',
#   'start': 1378,
#   'end': 1379},
#  {'entity': 'NUMBER',
#   'score': 0.4672339,
#   'index': 310,
#   'word': 'из',
#   'start': 1380,
#   'end': 1382},
#  {'entity': 'NUMBER',
#   'score': 0.85800064,
#   'index': 311,
#   'word': '50',
#   'start': 1383,
#   'end': 1385},
#  {'entity': 'PERSON',
#   'score': 0.998072,
#   'index': 312,
#   'word': 'пациентов',
#   'start': 1386,
#   'end': 1395},
#  {'entity': 'FINDING',
#   'score': 0.92835927,
#   'index': 313,
#   'word': 'диагноз',
#   'start': 1396,
#   'end': 1403},
#  {'entity': 'DISO',
#   'score': 0.8359117,
#   'index': 314,
#   'word': 'БФ',
#   'start': 1404,
#   'end': 1406},
#  {'entity': 'FINDING',
#   'score': 0.9951792,
#   'index': 315,
#   'word': 'установлен',
#   'start': 1407,
#   'end': 1417},
#  {'entity': 'FINDING',
#   'score': 0.974942,
#   'index': 316,
#   'word': ',',
#   'start': 1417,
#   'end': 1418},
#  {'entity': 'DATE',
#   'score': 0.97339636,
#   'index': 317,
#   'word': 'в',
#   'start': 1419,
#   'end': 1420},
#  {'entity': 'DATE',
#   'score': 0.6940118,
#   'index': 318,
#   'word': 'среднем',
#   'start': 1421,
#   'end': 1428},
#  {'entity': 'DATE',
#   'score': 0.89480186,
#   'index': 319,
#   'word': ',',
#   'start': 1428,
#   'end': 1429},
#  {'entity': 'DATE',
#   'score': 0.9932516,
#   'index': 320,
#   'word': 'через',
#   'start': 1430,
#   'end': 1435},
#  {'entity': 'DATE',
#   'score': 0.9932508,
#   'index': 321,
#   'word': '1',
#   'start': 1436,
#   'end': 1437},
#  {'entity': 'DATE',
#   'score': 0.99277747,
#   'index': 322,
#   'word': 'год',
#   'start': 1438,
#   'end': 1441},
#  {'entity': 'DATE',
#   'score': 0.9665415,
#   'index': 323,
#   'word': '(',
#   'start': 1442,
#   'end': 1443},
#  {'entity': 'PHYS',
#   'score': 0.4464981,
#   'index': 324,
#   'word': 'диапазон',
#   'start': 1443,
#   'end': 1451},
#  {'entity': 'DATE',
#   'score': 0.9733061,
#   'index': 325,
#   'word': 'от',
#   'start': 1452,
#   'end': 1454},
#  {'entity': 'DATE',
#   'score': 0.9789084,
#   'index': 326,
#   'word': '0',
#   'start': 1455,
#   'end': 1456},
#  {'entity': 'DATE',
#   'score': 0.9793578,
#   'index': 327,
#   'word': 'до',
#   'start': 1457,
#   'end': 1459},
#  {'entity': 'DATE',
#   'score': 0.9819864,
#   'index': 328,
#   'word': '12',
#   'start': 1460,
#   'end': 1462},
#  {'entity': 'DATE',
#   'score': 0.96850216,
#   'index': 329,
#   'word': 'лет',
#   'start': 1463,
#   'end': 1466},
#  {'entity': 'DATE',
#   'score': 0.97775537,
#   'index': 330,
#   'word': ')',
#   'start': 1466,
#   'end': 1467},
#  {'entity': 'DATE',
#   'score': 0.52238333,
#   'index': 331,
#   'word': 'после',
#   'start': 1468,
#   'end': 1473},
#  {'entity': 'MEDPROC',
#   'score': 0.9625288,
#   'index': 332,
#   'word': 'начала',
#   'start': 1474,
#   'end': 1480},
#  {'entity': 'MEDPROC',
#   'score': 0.99730754,
#   'index': 333,
#   'word': 'лечения',
#   'start': 1481,
#   'end': 1488},
#  {'entity': 'MEDPROC',
#   'score': 0.99591476,
#   'index': 334,
#   'word': 'программным',
#   'start': 1489,
#   'end': 1500},
#  {'entity': 'MEDPROC',
#   'score': 0.9977964,
#   'index': 335,
#   'word': 'гем',
#   'start': 1501,
#   'end': 1504},
#  {'entity': 'MEDPROC',
#   'score': 0.997407,
#   'index': 336,
#   'word': '##оди',
#   'start': 1504,
#   'end': 1507},
#  {'entity': 'MEDPROC',
#   'score': 0.9974904,
#   'index': 337,
#   'word': '##ализ',
#   'start': 1507,
#   'end': 1511},
#  {'entity': 'MEDPROC',
#   'score': 0.9973717,
#   'index': 338,
#   'word': '##ом',
#   'start': 1511,
#   'end': 1513},
#  {'entity': 'MEDPROC',
#   'score': 0.9452463,
#   'index': 339,
#   'word': ',',
#   'start': 1513,
#   'end': 1514},
#  {'entity': 'DATE',
#   'score': 0.2736978,
#   'index': 340,
#   'word': 'в',
#   'start': 1515,
#   'end': 1516},
#  {'entity': 'PERSON',
#   'score': 0.5774665,
#   'index': 341,
#   'word': 'том',
#   'start': 1517,
#   'end': 1520},
#  {'entity': 'NUMBER',
#   'score': 0.3026524,
#   'index': 342,
#   'word': 'числе',
#   'start': 1521,
#   'end': 1526},
#  {'entity': 'PERSON',
#   'score': 0.8478752,
#   'index': 343,
#   'word': 'у',
#   'start': 1527,
#   'end': 1528},
#  {'entity': 'NUMBER',
#   'score': 0.97118855,
#   'index': 344,
#   'word': 'одного',
#   'start': 1529,
#   'end': 1535},
#  {'entity': 'PERSON',
#   'score': 0.998166,
#   'index': 345,
#   'word': 'пациента',
#   'start': 1536,
#   'end': 1544},
#  {'entity': 'FINDING',
#   'score': 0.3734853,
#   'index': 346,
#   'word': '–',
#   'start': 1545,
#   'end': 1546},
#  {'entity': 'MEDPROC',
#   'score': 0.9942017,
#   'index': 347,
#   'word': 'после',
#   'start': 1547,
#   'end': 1552},
#  {'entity': 'MEDPROC',
#   'score': 0.9930536,
#   'index': 348,
#   'word': 'трансплантации',
#   'start': 1553,
#   'end': 1567},
#  {'entity': 'ANATOMY',
#   'score': 0.9981504,
#   'index': 349,
#   'word': 'почки',
#   'start': 1568,
#   'end': 1573},
#  {'entity': 'DISO',
#   'score': 0.12249153,
#   'index': 350,
#   'word': '.',
#   'start': 1573,
#   'end': 1574},
#  {'entity': 'FINDING',
#   'score': 0.6210212,
#   'index': 351,
#   'word': 'Среди',
#   'start': 1575,
#   'end': 1580},
#  {'entity': 'NUMBER',
#   'score': 0.9264261,
#   'index': 352,
#   'word': '44',
#   'start': 1581,
#   'end': 1583},
#  {'entity': 'CHEM',
#   'score': 0.90719575,
#   'index': 353,
#   'word': 'проба',
#   'start': 1584,
#   'end': 1589},
#  {'entity': 'CHEM',
#   'score': 0.832054,
#   'index': 354,
#   'word': '##нд',
#   'start': 1589,
#   'end': 1591},
#  {'entity': 'CHEM',
#   'score': 0.67555827,
#   'index': 355,
#   'word': '##ов',
#   'start': 1591,
#   'end': 1593},
#  {'entity': 'FINDING',
#   'score': 0.44769815,
#   'index': 356,
#   'word': ',',
#   'start': 1593,
#   'end': 1594},
#  {'entity': 'FINDING',
#   'score': 0.7777142,
#   'index': 357,
#   'word': 'выявленных',
#   'start': 1595,
#   'end': 1605},
#  {'entity': 'MEDPROC',
#   'score': 0.8253718,
#   'index': 358,
#   'word': 'при',
#   'start': 1606,
#   'end': 1609},
#  {'entity': 'MEDPROC',
#   'score': 0.5684193,
#   'index': 359,
#   'word': 'всероссий',
#   'start': 1610,
#   'end': 1619},
#  {'entity': 'MEDPROC',
#   'score': 0.8743992,
#   'index': 360,
#   'word': '##ском',
#   'start': 1619,
#   'end': 1623},
#  {'entity': 'MEDPROC',
#   'score': 0.9951049,
#   'index': 361,
#   'word': 'диал',
#   'start': 1624,
#   'end': 1628},
#  {'entity': 'MEDPROC',
#   'score': 0.99148375,
#   'index': 362,
#   'word': '##изн',
#   'start': 1628,
#   'end': 1631},
#  {'entity': 'MEDPROC',
#   'score': 0.9900653,
#   'index': 363,
#   'word': '##ом',
#   'start': 1631,
#   'end': 1633},
#  {'entity': 'MEDPROC',
#   'score': 0.9737186,
#   'index': 364,
#   'word': 'скрин',
#   'start': 1634,
#   'end': 1639},
#  {'entity': 'MEDPROC',
#   'score': 0.89229345,
#   'index': 365,
#   'word': '##инге',
#   'start': 1639,
#   'end': 1643},
#  {'entity': 'MEDPROC',
#   'score': 0.6409085,
#   'index': 366,
#   'word': ',',
#   'start': 1643,
#   'end': 1644},
#  {'entity': 'MEDPROC',
#   'score': 0.8820956,
#   'index': 367,
#   'word': 'проведен',
#   'start': 1645,
#   'end': 1653},
#  {'entity': 'MEDPROC',
#   'score': 0.7419057,
#   'index': 368,
#   'word': 'семейный',
#   'start': 1654,
#   'end': 1662},
#  {'entity': 'MEDPROC',
#   'score': 0.9215805,
#   'index': 369,
#   'word': 'скрин',
#   'start': 1663,
#   'end': 1668},
#  {'entity': 'MEDPROC',
#   'score': 0.8670584,
#   'index': 370,
#   'word': '##инг',
#   'start': 1668,
#   'end': 1671},
#  {'entity': 'FINDING',
#   'score': 0.628887,
#   'index': 371,
#   'word': '.',
#   'start': 1671,
#   'end': 1672},
#  {'entity': 'FINDING',
#   'score': 0.6561765,
#   'index': 372,
#   'word': 'Пат',
#   'start': 1673,
#   'end': 1676},
#  {'entity': 'FINDING',
#   'score': 0.5845309,
#   'index': 373,
#   'word': '##оген',
#   'start': 1676,
#   'end': 1680},
#  {'entity': 'FINDING',
#   'score': 0.60345936,
#   'index': 374,
#   'word': '##ная',
#   'start': 1680,
#   'end': 1683},
#  {'entity': 'PHYS',
#   'score': 0.50657725,
#   'index': 375,
#   'word': 'мутация',
#   'start': 1684,
#   'end': 1691},
#  {'entity': 'GENE',
#   'score': 0.90339327,
#   'index': 376,
#   'word': 'в',
#   'start': 1692,
#   'end': 1693},
#  {'entity': 'GENE',
#   'score': 0.9472599,
#   'index': 377,
#   'word': 'гене',
#   'start': 1694,
#   'end': 1698},
#  {'entity': 'GENE',
#   'score': 0.9289774,
#   'index': 378,
#   'word': 'GL',
#   'start': 1699,
#   'end': 1701},
#  {'entity': 'GENE',
#   'score': 0.9306014,
#   'index': 379,
#   'word': '##A',
#   'start': 1701,
#   'end': 1702},
#  {'entity': 'FINDING',
#   'score': 0.87445694,
#   'index': 380,
#   'word': 'диагностирован',
#   'start': 1703,
#   'end': 1717},
#  {'entity': 'FINDING',
#   'score': 0.9573946,
#   'index': 381,
#   'word': '##а',
#   'start': 1717,
#   'end': 1718},
#  {'entity': 'PERSON',
#   'score': 0.5037501,
#   'index': 382,
#   'word': 'у',
#   'start': 1719,
#   'end': 1720},
#  {'entity': 'PERCENT',
#   'score': 0.8028251,
#   'index': 383,
#   'word': '89',
#   'start': 1721,
#   'end': 1723},
#  {'entity': 'PERCENT',
#   'score': 0.87543136,
#   'index': 384,
#   'word': '(',
#   'start': 1724,
#   'end': 1725},
#  {'entity': 'PERCENT',
#   'score': 0.99396706,
#   'index': 385,
#   'word': '57',
#   'start': 1725,
#   'end': 1727},
#  {'entity': 'PERCENT',
#   'score': 0.91038316,
#   'index': 386,
#   'word': '%',
#   'start': 1727,
#   'end': 1728},
#  {'entity': 'NUMBER',
#   'score': 0.3598896,
#   'index': 387,
#   'word': ')',
#   'start': 1728,
#   'end': 1729},
#  {'entity': 'NUMBER',
#   'score': 0.76621723,
#   'index': 388,
#   'word': 'из',
#   'start': 1730,
#   'end': 1732},
#  {'entity': 'NUMBER',
#   'score': 0.9532523,
#   'index': 389,
#   'word': '156',
#   'start': 1733,
#   'end': 1736},
#  {'entity': 'PERSON',
#   'score': 0.99719304,
#   'index': 390,
#   'word': 'обслед',
#   'start': 1737,
#   'end': 1743},
#  {'entity': 'PERSON',
#   'score': 0.99723935,
#   'index': 391,
#   'word': '##ованных',
#   'start': 1743,
#   'end': 1750},
#  {'entity': 'PERSON',
#   'score': 0.9965379,
#   'index': 392,
#   'word': 'родственников',
#   'start': 1751,
#   'end': 1764},
#  {'entity': 'MEDPROC',
#   'score': 0.64793473,
#   'index': 393,
#   'word': 'диал',
#   'start': 1765,
#   'end': 1769},
#  {'entity': 'PHYS',
#   'score': 0.34598437,
#   'index': 394,
#   'word': '##изны',
#   'start': 1769,
#   'end': 1773},
#  {'entity': 'CHEM',
#   'score': 0.78629494,
#   'index': 395,
#   'word': '##х',
#   'start': 1773,
#   'end': 1774},
#  {'entity': 'CHEM',
#   'score': 0.89781183,
#   'index': 396,
#   'word': 'проба',
#   'start': 1775,
#   'end': 1780},
#  {'entity': 'CHEM',
#   'score': 0.8159902,
#   'index': 397,
#   'word': '##нд',
#   'start': 1780,
#   'end': 1782},
#  {'entity': 'CHEM',
#   'score': 0.7884151,
#   'index': 398,
#   'word': '##ов',
#   'start': 1782,
#   'end': 1784},
#  {'entity': 'PERSON',
#   'score': 0.31340668,
#   'index': 399,
#   'word': ',',
#   'start': 1784,
#   'end': 1785},
#  {'entity': 'DATE',
#   'score': 0.23152466,
#   'index': 400,
#   'word': 'в',
#   'start': 1786,
#   'end': 1787},
#  {'entity': 'PERSON',
#   'score': 0.2620423,
#   'index': 401,
#   'word': 'том',
#   'start': 1788,
#   'end': 1791},
#  {'entity': 'NUMBER',
#   'score': 0.41482776,
#   'index': 402,
#   'word': 'числе',
#   'start': 1792,
#   'end': 1797},
#  {'entity': 'PERSON',
#   'score': 0.6789588,
#   'index': 403,
#   'word': 'у',
#   'start': 1798,
#   'end': 1799},
#  {'entity': 'NUMBER',
#   'score': 0.7104878,
#   'index': 404,
#   'word': '18',
#   'start': 1800,
#   'end': 1802},
#  {'entity': 'PERSON',
#   'score': 0.99754757,
#   'index': 405,
#   'word': 'детей',
#   'start': 1803,
#   'end': 1808},
#  {'entity': 'AGE',
#   'score': 0.9905743,
#   'index': 406,
#   'word': 'моложе',
#   'start': 1809,
#   'end': 1815},
#  {'entity': 'AGE',
#   'score': 0.99213964,
#   'index': 407,
#   'word': '18',
#   'start': 1816,
#   'end': 1818},
#  {'entity': 'AGE',
#   'score': 0.9791612,
#   'index': 408,
#   'word': 'лет',
#   'start': 1819,
#   'end': 1822},
#  {'entity': 'FINDING',
#   'score': 0.986747,
#   'index': 409,
#   'word': ',',
#   'start': 1822,
#   'end': 1823},
#  {'entity': 'FINDING',
#   'score': 0.9169076,
#   'index': 410,
#   'word': 'клинические',
#   'start': 1824,
#   'end': 1835},
#  {'entity': 'FINDING',
#   'score': 0.84064555,
#   'index': 411,
#   'word': 'проявления',
#   'start': 1836,
#   'end': 1846},
#  {'entity': 'DISO',
#   'score': 0.93768805,
#   'index': 412,
#   'word': 'БФ',
#   'start': 1847,
#   'end': 1849},
#  {'entity': 'FINDING',
#   'score': 0.98170716,
#   'index': 413,
#   'word': 'имелись',
#   'start': 1850,
#   'end': 1857},
#  {'entity': 'FINDING',
#   'score': 0.87683403,
#   'index': 414,
#   'word': 'у',
#   'start': 1858,
#   'end': 1859},
#  {'entity': 'NUMBER',
#   'score': 0.8764439,
#   'index': 415,
#   'word': '48',
#   'start': 1860,
#   'end': 1862},
#  {'entity': 'PERSON',
#   'score': 0.9880436,
#   'index': 416,
#   'word': 'родственников',
#   'start': 1863,
#   'end': 1876},
#  {'entity': 'FINDING',
#   'score': 0.5963626,
#   'index': 417,
#   'word': '.',
#   'start': 1876,
#   'end': 1877},
#  {'entity': 'FINDING',
#   'score': 0.87860394,
#   'index': 418,
#   'word': 'У',
#   'start': 1878,
#   'end': 1879},
#  {'entity': 'PERCENT',
#   'score': 0.98946685,
#   'index': 419,
#   'word': '80',
#   'start': 1880,
#   'end': 1882},
#  {'entity': 'PERCENT',
#   'score': 0.8654986,
#   'index': 420,
#   'word': ',',
#   'start': 1882,
#   'end': 1883},
#  {'entity': 'PERCENT',
#   'score': 0.9546868,
#   'index': 421,
#   'word': '4',
#   'start': 1883,
#   'end': 1884},
#  {'entity': 'FINDING',
#   'score': 0.29112148,
#   'index': 422,
#   'word': '%',
#   'start': 1884,
#   'end': 1885},
#  {'entity': 'PERSON',
#   'score': 0.9973016,
#   'index': 423,
#   'word': 'обслед',
#   'start': 1886,
#   'end': 1892},
#  {'entity': 'PERSON',
#   'score': 0.99734133,
#   'index': 424,
#   'word': '##ованных',
#   'start': 1892,
#   'end': 1899},
#  {'entity': 'PERSON',
#   'score': 0.9973218,
#   'index': 425,
#   'word': 'родственников',
#   'start': 1900,
#   'end': 1913},
#  {'entity': 'MEDPROC',
#   'score': 0.80377203,
#   'index': 426,
#   'word': 'диал',
#   'start': 1914,
#   'end': 1918},
#  {'entity': 'DISO',
#   'score': 0.25024614,
#   'index': 427,
#   'word': '##изны',
#   'start': 1918,
#   'end': 1922},
#  {'entity': 'CHEM',
#   'score': 0.44587958,
#   'index': 428,
#   'word': '##х',
#   'start': 1922,
#   'end': 1923},
#  {'entity': 'CHEM',
#   'score': 0.92349005,
#   'index': 429,
#   'word': 'проба',
#   'start': 1924,
#   'end': 1929},
#  {'entity': 'CHEM',
#   'score': 0.8605073,
#   'index': 430,
#   'word': '##нд',
#   'start': 1929,
#   'end': 1931},
#  {'entity': 'CHEM',
#   'score': 0.80721885,
#   'index': 431,
#   'word': '##ов',
#   'start': 1931,
#   'end': 1933},
#  {'entity': 'FINDING',
#   'score': 0.9942966,
#   'index': 432,
#   'word': 'обнаружено',
#   'start': 1934,
#   'end': 1944},
#  {'entity': 'FINDING',
#   'score': 0.49184635,
#   'index': 433,
#   'word': 'поражение',
#   'start': 1945,
#   'end': 1954},
#  {'entity': 'ANATOMY',
#   'score': 0.998338,
#   'index': 434,
#   'word': 'почек',
#   'start': 1955,
#   'end': 1960},
#  {'entity': 'FINDING',
#   'score': 0.97192746,
#   'index': 435,
#   'word': ',',
#   'start': 1960,
#   'end': 1961},
#  {'entity': 'FINDING',
#   'score': 0.98503286,
#   'index': 436,
#   'word': 'преимущественно',
#   'start': 1962,
#   'end': 1977},
#  {'entity': 'FINDING',
#   'score': 0.3736187,
#   'index': 437,
#   'word': 'на',
#   'start': 1978,
#   'end': 1980},
#  {'entity': 'DISO',
#   'score': 0.631812,
#   'index': 438,
#   'word': 'ранних',
#   'start': 1981,
#   'end': 1987},
#  {'entity': 'DISO',
#   'score': 0.882018,
#   'index': 439,
#   'word': 'стадиях',
#   'start': 1988,
#   'end': 1995},
#  {'entity': 'SCIPROC',
#   'score': 0.85542065,
#   'index': 440,
#   'word': '.',
#   'start': 1995,
#   'end': 1996},
#  {'entity': 'SCIPROC',
#   'score': 0.83627784,
#   'index': 441,
#   'word': 'Заключение',
#   'start': 1997,
#   'end': 2007},
#  {'entity': 'SCIPROC',
#   'score': 0.836896,
#   'index': 442,
#   'word': '.',
#   'start': 2007,
#   'end': 2008},
#  {'entity': 'DISO',
#   'score': 0.8027819,
#   'index': 443,
#   'word': 'Т',
#   'start': 2009,
#   'end': 2010},
#  {'entity': 'DISO',
#   'score': 0.9381831,
#   'index': 444,
#   'word': '##Х',
#   'start': 2010,
#   'end': 2011},
#  {'entity': 'DISO',
#   'score': 0.9816989,
#   'index': 445,
#   'word': '##П',
#   'start': 2011,
#   'end': 2012},
#  {'entity': 'DISO',
#   'score': 0.9955454,
#   'index': 446,
#   'word': '##Н',
#   'start': 2012,
#   'end': 2013},
#  {'entity': 'FINDING',
#   'score': 0.8671324,
#   'index': 447,
#   'word': 'нередко',
#   'start': 2014,
#   'end': 2021},
#  {'entity': 'FINDING',
#   'score': 0.9440318,
#   'index': 448,
#   'word': '##е',
#   'start': 2021,
#   'end': 2022},
#  {'entity': 'DISO',
#   'score': 0.7112963,
#   'index': 449,
#   'word': 'осложн',
#   'start': 2023,
#   'end': 2029},
#  {'entity': 'FINDING',
#   'score': 0.6415507,
#   'index': 450,
#   'word': '##ение',
#   'start': 2029,
#   'end': 2033},
#  {'entity': 'DISO',
#   'score': 0.9649324,
#   'index': 451,
#   'word': 'БФ',
#   'start': 2034,
#   'end': 2036},
#  {'entity': 'FINDING',
#   'score': 0.9600186,
#   'index': 452,
#   'word': ',',
#   'start': 2036,
#   'end': 2037},
#  {'entity': 'FINDING',
#   'score': 0.9855186,
#   'index': 453,
#   'word': 'ассоцииров',
#   'start': 2038,
#   'end': 2048},
#  {'entity': 'FINDING',
#   'score': 0.9878342,
#   'index': 454,
#   'word': '##анное',
#   'start': 2048,
#   'end': 2053},
#  {'entity': 'FINDING',
#   'score': 0.9853055,
#   'index': 455,
#   'word': 'с',
#   'start': 2054,
#   'end': 2055},
#  {'entity': 'FINDING',
#   'score': 0.96050084,
#   'index': 456,
#   'word': 'неблагоприят',
#   'start': 2056,
#   'end': 2068},
#  {'entity': 'FINDING',
#   'score': 0.93467623,
#   'index': 457,
#   'word': '##ным',
#   'start': 2068,
#   'end': 2071},
#  {'entity': 'FINDING',
#   'score': 0.8261184,
#   'index': 458,
#   'word': 'прогнозом',
#   'start': 2072,
#   'end': 2081},
#  {'entity': 'FINDING',
#   'score': 0.9370826,
#   'index': 459,
#   'word': '.',
#   'start': 2081,
#   'end': 2082},
#  {'entity': 'FINDING',
#   'score': 0.99563473,
#   'index': 460,
#   'word': 'Однако',
#   'start': 2083,
#   'end': 2089},
#  {'entity': 'MEDPROC',
#   'score': 0.9864681,
#   'index': 461,
#   'word': 'диал',
#   'start': 2090,
#   'end': 2094},
#  {'entity': 'MEDPROC',
#   'score': 0.9746373,
#   'index': 462,
#   'word': '##изны',
#   'start': 2094,
#   'end': 2098},
#  {'entity': 'MEDPROC',
#   'score': 0.9716493,
#   'index': 463,
#   'word': '##й',
#   'start': 2098,
#   'end': 2099},
#  {'entity': 'MEDPROC',
#   'score': 0.97463,
#   'index': 464,
#   'word': 'скрин',
#   'start': 2100,
#   'end': 2105},
#  {'entity': 'MEDPROC',
#   'score': 0.9609046,
#   'index': 465,
#   'word': '##инг',
#   'start': 2105,
#   'end': 2108},
#  {'entity': 'FINDING',
#   'score': 0.9971034,
#   'index': 466,
#   'word': '–',
#   'start': 2109,
#   'end': 2110},
#  {'entity': 'FINDING',
#   'score': 0.9976229,
#   'index': 467,
#   'word': 'эффективный',
#   'start': 2112,
#   'end': 2123},
#  {'entity': 'FINDING',
#   'score': 0.9941375,
#   'index': 468,
#   'word': 'способ',
#   'start': 2124,
#   'end': 2130},
#  {'entity': 'FINDING',
#   'score': 0.67546535,
#   'index': 469,
#   'word': 'выявления',
#   'start': 2131,
#   'end': 2140},
#  {'entity': 'CHEM',
#   'score': 0.8999959,
#   'index': 470,
#   'word': 'проба',
#   'start': 2141,
#   'end': 2146},
#  {'entity': 'CHEM',
#   'score': 0.7708047,
#   'index': 471,
#   'word': '##нд',
#   'start': 2146,
#   'end': 2148},
#  {'entity': 'CHEM',
#   'score': 0.34384716,
#   'index': 472,
#   'word': '##ов',
#   'start': 2148,
#   'end': 2150},
#  {'entity': 'DISO',
#   'score': 0.41477066,
#   'index': 473,
#   'word': 'с',
#   'start': 2151,
#   'end': 2152},
#  {'entity': 'DISO',
#   'score': 0.9156513,
#   'index': 474,
#   'word': 'БФ',
#   'start': 2153,
#   'end': 2155},
#  {'entity': 'FINDING',
#   'score': 0.9974376,
#   'index': 475,
#   'word': ',',
#   'start': 2155,
#   'end': 2156},
#  {'entity': 'FINDING',
#   'score': 0.9977465,
#   'index': 476,
#   'word': 'открыв',
#   'start': 2157,
#   'end': 2163},
#  {'entity': 'FINDING',
#   'score': 0.99775714,
#   'index': 477,
#   'word': '##ающий',
#   'start': 2163,
#   'end': 2168},
#  {'entity': 'FINDING',
#   'score': 0.99706405,
#   'index': 478,
#   'word': 'возможность',
#   'start': 2169,
#   'end': 2180},
#  {'entity': 'FINDING',
#   'score': 0.9970753,
#   'index': 479,
#   'word': 'установить',
#   'start': 2181,
#   'end': 2191},
#  {'entity': 'FINDING',
#   'score': 0.8775176,
#   'index': 480,
#   'word': 'диагноз',
#   'start': 2192,
#   'end': 2199},
#  {'entity': 'DISO',
#   'score': 0.9734388,
#   'index': 481,
#   'word': 'БФ',
#   'start': 2200,
#   'end': 2202},
#  {'entity': 'PERSON',
#   'score': 0.9878875,
#   'index': 482,
#   'word': 'у',
#   'start': 2203,
#   'end': 2204},
#  {'entity': 'PERSON',
#   'score': 0.99426186,
#   'index': 483,
#   'word': 'родственников',
#   'start': 2205,
#   'end': 2218},
#  {'entity': 'FINDING',
#   'score': 0.6980517,
#   'index': 484,
#   'word': 'на',
#   'start': 2219,
#   'end': 2221},
#  {'entity': 'FINDING',
#   'score': 0.39061236,
#   'index': 485,
#   'word': 'ранних',
#   'start': 2222,
#   'end': 2228},
#  {'entity': 'DISO',
#   'score': 0.6747331,
#   'index': 486,
#   'word': 'стадиях',
#   'start': 2229,
#   'end': 2236},
#  {'entity': 'FINDING',
#   'score': 0.8577544,
#   'index': 487,
#   'word': ',',
#   'start': 2236,
#   'end': 2237},
#  {'entity': 'FINDING',
#   'score': 0.8895483,
#   'index': 488,
#   'word': 'когда',
#   'start': 2238,
#   'end': 2243},
#  {'entity': 'MEDPROC',
#   'score': 0.992853,
#   'index': 489,
#   'word': 'лечение',
#   'start': 2244,
#   'end': 2251},
#  {'entity': 'FINDING',
#   'score': 0.99635375,
#   'index': 490,
#   'word': 'наиболее',
#   'start': 2252,
#   'end': 2260},
#  {'entity': 'FINDING',
#   'score': 0.994756,
#   'index': 491,
#   'word': 'эффективно',
#   'start': 2261,
#   'end': 2271},
#  {'entity': 'FINDING',
#   'score': 0.8931047,
#   'index': 492,
#   'word': '.',
#   'start': 2271,
#   'end': 2272}]
