# %% [markdown]
# <a href="https://colab.research.google.com/github/ekaterinatao/NER_biomed_domain/blob/main/transformers_base/%D0%92%D0%9A%D0%A0_nerel_bio_BERT_base.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Инструменты
# Предобработанный дасасет [NEREL-BIO](https://huggingface.co/datasets/ekaterinatao/nerel_bio_ner_unnested)
# Чек-пойнт дообученной модели не сохраняли, т.к. качество низкое.
#
# Исходная модель [BERT](https://huggingface.co/google-bert/bert-base-uncased)

# %% [markdown]
# ### Установка зависимостей

# %%
# !pip install datasets accelerate evaluate wandb seqeval -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.7/536.7 kB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 kB 23.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 10.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 24.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 6.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 12.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.5/258.5 kB 14.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.7 MB/s eta 0:00:00
#   Building wheel for seqeval (setup.py) ... done

# %%
import numpy as np
import pandas as pd
import random
from dataclasses import dataclass

import torch
import datasets
from datasets import Dataset, DatasetDict
from transformers import AutoTokenizer
from transformers import DataCollatorForTokenClassification
from transformers import AutoModelForTokenClassification
from transformers import TrainingArguments, Trainer
from transformers import pipeline
import evaluate

import warnings
warnings.filterwarnings("ignore")

# %%
@dataclass
class TrainingConfig:
    seed = 64
    dataset = 'ekaterinatao/nerel_bio_ner_unnested'
    checkpoint = 'google-bert/bert-base-uncased'
    n_labels = 45
    token_length = 512
    n_epochs = 10
    train_batch_size = 6
    eval_batch_size = 6
    device = "cuda" if torch.cuda.is_available() else "cpu"
    l_rate = 5e-05
    w_decay = 0.1
    warm_up = 0.1

config = TrainingConfig()

# %%
seed = config.seed

random.seed(seed)
np.random.seed(seed)

torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %% [markdown]
# ### Скачивание датасета

# %%
dataset = datasets.load_dataset(config.dataset)
dataset
# Out:
# Downloading readme:   0%|          | 0.00/1.56k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/603k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/76.2k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/70.8k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/612 [00:00<?, ? examples/s]
# Generating valid split:   0%|          | 0/77 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/77 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'words', 'ner_tags'],
#         num_rows: 612
#     })
#     valid: Dataset({
#         features: ['id', 'words', 'ner_tags'],
#         num_rows: 77
#     })
#     test: Dataset({
#         features: ['id', 'words', 'ner_tags'],
#         num_rows: 77
#     })
# })

# %%
# Labels
url = 'https://raw.githubusercontent.com/ekaterinatao/NER_biomed_domain/main/labels.txt'
tags = pd.read_csv(url, names=['tag']).values.tolist()
tags = [item for sublist in tags for item in sublist]

# %%
tag_to_id = {tag: i for i, tag in enumerate(tags)}
id_to_tag = {i: tag for i, tag in enumerate(tags)}

# %% [markdown]
# ___
# ### Токенизация

# %%
tokenizer = AutoTokenizer.from_pretrained(config.checkpoint)
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(examples["words"], truncation=True,
                                 max_length=config.token_length, is_split_into_words=True)

    labels = []
    for i, label in enumerate(examples[f"ner_tags"]):
        word_idxs = tokenized_inputs.word_ids(batch_index=i)  # Map tokens to their respective word.
        previous_word_idx = None
        label_ids = []
        for word_idx in word_idxs:
            if word_idx is None:
                label_ids.append(-100) # Set the special tokens to -100.
            elif word_idx != previous_word_idx:  # Only label the first token of a given word.
                label_ids.append(label[word_idx])
            else:
                label_ids.append(-100)
            previous_word_idx = word_idx
        labels.append(label_ids)

    tokenized_inputs["labels"] = labels
    return tokenized_inputs

# %%
tokenized_dataset = dataset.map(tokenize_and_align_labels, batched=True,
                                remove_columns = ['id', 'words', 'ner_tags'])
tokenized_dataset
# Out:
# Map:   0%|          | 0/612 [00:00<?, ? examples/s]
# Map:   0%|          | 0/77 [00:00<?, ? examples/s]
# Map:   0%|          | 0/77 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 612
#     })
#     valid: Dataset({
#         features: ['input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 77
#     })
#     test: Dataset({
#         features: ['input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 77
#     })
# })

# %% [markdown]
# # Обучение модели

# %%
seqeval = evaluate.load("seqeval")

def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=2)

    true_predictions = [
        [tags[p] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]
    true_labels = [
        [tags[l] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]

    results = seqeval.compute(predictions=true_predictions, references=true_labels)
    return {
        "precision": results["overall_precision"],
        "recall": results["overall_recall"],
        "f1": results["overall_f1"],
        "accuracy": results["overall_accuracy"],
    }
# Out:
# Downloading builder script:   0%|          | 0.00/6.34k [00:00<?, ?B/s]

# %%
data_collator = DataCollatorForTokenClassification(tokenizer=tokenizer)

# %%
print(f'device is {config.device}')
# Out:
# device is cuda

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
import wandb
wandb.login()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
import os
os.environ["WANDB_PROJECT"]="ner_bert_nerel_bio"
hf_repo_id = "ekaterinatao/nerel-bio-bert-base"

# %%
model = AutoModelForTokenClassification.from_pretrained(
    config.checkpoint, num_labels=config.n_labels, id2label=id_to_tag, label2id=tag_to_id)

training_args = TrainingArguments(
    output_dir=hf_repo_id,
    num_train_epochs=config.n_epochs,
    learning_rate=config.l_rate,
    weight_decay=config.w_decay,
    warmup_ratio=config.warm_up,
    per_device_train_batch_size=config.train_batch_size,
    per_device_eval_batch_size=config.eval_batch_size,
    group_by_length=True,
    optim="adamw_torch",
    lr_scheduler_type="cosine",
    evaluation_strategy="epoch",
    seed = config.seed,
    data_seed = config.seed,
    push_to_hub=True,
    save_strategy="no",
    report_to="wandb",
    run_name="bert-base",
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset["train"],
    eval_dataset=tokenized_dataset["valid"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at google-bert/bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# wandb: Currently logged in as: taoea. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.3
# Run data is saved locally in <code>/content/wandb/run-20240227_144822-1nadiry4</code>
# Syncing run <strong><a href='https://wandb.ai/taoea/ner_bert_nerel_bio/runs/1nadiry4' target="_blank">bert-base</a></strong> to <a href='https://wandb.ai/taoea/ner_bert_nerel_bio' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/taoea/ner_bert_nerel_bio' target="_blank">https://wandb.ai/taoea/ner_bert_nerel_bio</a>
#  View run at <a href='https://wandb.ai/taoea/ner_bert_nerel_bio/runs/1nadiry4' target="_blank">https://wandb.ai/taoea/ner_bert_nerel_bio/runs/1nadiry4</a>
#     <div>
#
#       <progress value='1020' max='1020' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1020/1020 03:34, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>2.080138</td>
#       <td>0.323555</td>
#       <td>0.282699</td>
#       <td>0.301750</td>
#       <td>0.451067</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>1.704837</td>
#       <td>0.443204</td>
#       <td>0.433848</td>
#       <td>0.438476</td>
#       <td>0.579646</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>1.494528</td>
#       <td>0.497037</td>
#       <td>0.474180</td>
#       <td>0.485340</td>
#       <td>0.618428</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>1.358720</td>
#       <td>0.537353</td>
#       <td>0.534112</td>
#       <td>0.535728</td>
#       <td>0.659552</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.389000</td>
#       <td>1.301566</td>
#       <td>0.544700</td>
#       <td>0.544289</td>
#       <td>0.544495</td>
#       <td>0.670224</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.389000</td>
#       <td>1.246879</td>
#       <td>0.577502</td>
#       <td>0.578590</td>
#       <td>0.578046</td>
#       <td>0.694430</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.389000</td>
#       <td>1.200220</td>
#       <td>0.588169</td>
#       <td>0.592160</td>
#       <td>0.590158</td>
#       <td>0.709526</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.389000</td>
#       <td>1.216326</td>
#       <td>0.598647</td>
#       <td>0.600452</td>
#       <td>0.599548</td>
#       <td>0.716033</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.389000</td>
#       <td>1.222944</td>
#       <td>0.598952</td>
#       <td>0.603468</td>
#       <td>0.601202</td>
#       <td>0.715773</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.454200</td>
#       <td>1.220604</td>
#       <td>0.602018</td>
#       <td>0.607237</td>
#       <td>0.604616</td>
#       <td>0.717335</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1020, training_loss=0.9098702145557778, metrics={'train_runtime': 217.7753, 'train_samples_per_second': 28.102, 'train_steps_per_second': 4.684, 'total_flos': 1599739452416520.0, 'train_loss': 0.9098702145557778, 'epoch': 10.0})

# %%
wandb.finish()
# Out:
# VBox(children=(Label(value='0.022 MB of 0.022 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>▁▄▅▆▇▇████</td></tr><tr><td>eval/f1</td><td>▁▄▅▆▇▇████</td></tr><tr><td>eval/loss</td><td>█▅▃▂▂▁▁▁▁▁</td></tr><tr><td>eval/precision</td><td>▁▄▅▆▇▇████</td></tr><tr><td>eval/recall</td><td>▁▄▅▆▇▇████</td></tr><tr><td>eval/runtime</td><td>█▃▁▂▇▃▂▁█▂</td></tr><tr><td>eval/samples_per_second</td><td>▁▆█▇▂▆▇█▁▇</td></tr><tr><td>eval/steps_per_second</td><td>▁▆█▇▂▆▇█▁▇</td></tr><tr><td>train/epoch</td><td>▁▂▃▃▄▄▅▆▆▇███</td></tr><tr><td>train/global_step</td><td>▁▂▃▃▄▄▅▆▆▇███</td></tr><tr><td>train/learning_rate</td><td>█▁</td></tr><tr><td>train/loss</td><td>█▁</td></tr><tr><td>train/total_flos</td><td>▁</td></tr><tr><td>train/train_loss</td><td>▁</td></tr><tr><td>train/train_runtime</td><td>▁</td></tr><tr><td>train/train_samples_per_second</td><td>▁</td></tr><tr><td>train/train_steps_per_second</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>0.71733</td></tr><tr><td>eval/f1</td><td>0.60462</td></tr><tr><td>eval/loss</td><td>1.2206</td></tr><tr><td>eval/precision</td><td>0.60202</td></tr><tr><td>eval/recall</td><td>0.60724</td></tr><tr><td>eval/runtime</td><td>1.061</td></tr><tr><td>eval/samples_per_second</td><td>72.572</td></tr><tr><td>eval/steps_per_second</td><td>12.252</td></tr><tr><td>train/epoch</td><td>10.0</td></tr><tr><td>train/global_step</td><td>1020</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>train/loss</td><td>0.4542</td></tr><tr><td>train/total_flos</td><td>1599739452416520.0</td></tr><tr><td>train/train_loss</td><td>0.90987</td></tr><tr><td>train/train_runtime</td><td>217.7753</td></tr><tr><td>train/train_samples_per_second</td><td>28.102</td></tr><tr><td>train/train_steps_per_second</td><td>4.684</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">bert-base</strong> at: <a href='https://wandb.ai/taoea/ner_bert_nerel_bio/runs/1nadiry4' target="_blank">https://wandb.ai/taoea/ner_bert_nerel_bio/runs/1nadiry4</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240227_144822-1nadiry4/logs</code>

# %% [markdown]
# ### Оценка качества на тестовой выборке

# %%
predictions = trainer.predict(test_dataset=tokenized_dataset["test"])

# %%
predictions.metrics
# Out:
# {'test_loss': 1.103678584098816,
#  'test_precision': 0.6384785819793205,
#  'test_recall': 0.6380073800738008,
#  'test_f1': 0.6382428940568475,
#  'test_accuracy': 0.7440476190476191,
#  'test_runtime': 1.8899,
#  'test_samples_per_second': 40.743,
#  'test_steps_per_second': 6.879}

# %% [markdown]
# Оценка модели на абстракте, которого не было в тестовом наборе

# %%
ner_bio = pipeline("ner", model=model, tokenizer=tokenizer, device=config.device)

# %%
abstract = """Цель. Оценить выживаемость у пациентов с болезнью Фабри (БФ) в зависимости от вида заместительной почечной терапии, и определить роль диализного скрининга в ранней диагностике БФ у родственников.
Материалы и методы. В исследование включали взрослых (старше 18 лет) пациентов с подтвержденным диагнозом БФ. Терминальная стадия хронической почечной недостаточности (тХПН) диагностировали в соответствии с рекомендациями Научного общества нефрологов России (2016) и KDIGO (2012). На основании опроса пробандов выявляли его родственников, которые могли унаследовать мутантный ген.
Результаты. У 50 (24,9%) из 201 обследованных пациентов с БФ диагностирована тХПН, в том числе у 48 (40%) из 120 мужчин и 2 (2,7%) из 81 женщин. Оценка кумулятивной частоты методом Каплана-Майера демонстрирует выраженное увеличение частоты регистрации тХПН к возрасту 20-30 лет, а к возрасту 50 лет ожидаемое количество пациентов с тХПН составляет 95%. Пяти из 50 больных с тХПН была выполнена трансплантация почки, в среднем, через 17 месяцев (диапазон от 7 до 70 месяцев) после инициации лечения гемодиализом. Умерло 15 (30%) из 50 пациентов, получавших лечение гемодиализом. Все умершие пациенты были мужского пола. Медиана возраста на момент летального исхода составила 45 (39; 58) лет. Среди пациентов, которым проведена трансплантация почки, летальных исходов зарегистрировано не было. У 44 (88%) из 50 пациентов диагноз БФ установлен, в среднем, через 1 год (диапазон от 0 до 12 лет) после начала лечения программным гемодиализом, в том числе у одного пациента – после трансплантации почки. Среди 44 пробандов, выявленных при всероссийском диализном скрининге, проведен семейный скрининг. Патогенная мутация в гене GLA диагностирована у 89 (57%) из 156 обследованных родственников диализных пробандов, в том числе у 18 детей моложе 18 лет, клинические проявления БФ имелись у 48 родственников. У 80,4% обследованных родственников диализных пробандов обнаружено поражение почек, преимущественно на ранних стадиях.
Заключение. ТХПН нередкое осложнение БФ, ассоциированное с неблагоприятным прогнозом. Однако диализный скрининг –  эффективный способ выявления пробандов с БФ, открывающий возможность установить диагноз БФ у родственников на ранних стадиях, когда лечение наиболее эффективно.
"""

# %%
ner_bio(abstract)
# Out:
# [{'entity': 'ORGANIZATION',
#   'score': 0.25381884,
#   'index': 1,
#   'word': 'ц',
#   'start': 0,
#   'end': 1},
#  {'entity': 'NUMBER',
#   'score': 0.3261401,
#   'index': 2,
#   'word': '##е',
#   'start': 1,
#   'end': 2},
#  {'entity': 'NUMBER',
#   'score': 0.4578969,
#   'index': 3,
#   'word': '##л',
#   'start': 2,
#   'end': 3},
#  {'entity': 'NUMBER',
#   'score': 0.67935014,
#   'index': 4,
#   'word': '##ь',
#   'start': 3,
#   'end': 4},
#  {'entity': 'NUMBER',
#   'score': 0.30295014,
#   'index': 5,
#   'word': '.',
#   'start': 4,
#   'end': 5},
#  {'entity': 'DISO',
#   'score': 0.43278658,
#   'index': 6,
#   'word': 'о',
#   'start': 6,
#   'end': 7},
#  {'entity': 'ORGANIZATION',
#   'score': 0.18363403,
#   'index': 7,
#   'word': '##ц',
#   'start': 7,
#   'end': 8},
#  {'entity': 'ORGANIZATION',
#   'score': 0.19579095,
#   'index': 8,
#   'word': '##е',
#   'start': 8,
#   'end': 9},
#  {'entity': 'ORGANIZATION',
#   'score': 0.17745942,
#   'index': 9,
#   'word': '##н',
#   'start': 9,
#   'end': 10},
#  {'entity': 'ORGANIZATION',
#   'score': 0.16939902,
#   'index': 10,
#   'word': '##и',
#   'start': 10,
#   'end': 11},
#  {'entity': 'NUMBER',
#   'score': 0.32740796,
#   'index': 11,
#   'word': '##т',
#   'start': 11,
#   'end': 12},
#  {'entity': 'NUMBER',
#   'score': 0.46834528,
#   'index': 12,
#   'word': '##ь',
#   'start': 12,
#   'end': 13},
#  {'entity': 'PHYS',
#   'score': 0.8974763,
#   'index': 13,
#   'word': 'в',
#   'start': 14,
#   'end': 15},
#  {'entity': 'PHYS',
#   'score': 0.63281834,
#   'index': 14,
#   'word': '##ы',
#   'start': 15,
#   'end': 16},
#  {'entity': 'PHYS',
#   'score': 0.49008262,
#   'index': 15,
#   'word': '##ж',
#   'start': 16,
#   'end': 17},
#  {'entity': 'PHYS',
#   'score': 0.5713444,
#   'index': 16,
#   'word': '##и',
#   'start': 17,
#   'end': 18},
#  {'entity': 'PHYS',
#   'score': 0.6660599,
#   'index': 17,
#   'word': '##в',
#   'start': 18,
#   'end': 19},
#  {'entity': 'PHYS',
#   'score': 0.84848446,
#   'index': 18,
#   'word': '##а',
#   'start': 19,
#   'end': 20},
#  {'entity': 'PHYS',
#   'score': 0.78622293,
#   'index': 19,
#   'word': '##е',
#   'start': 20,
#   'end': 21},
#  {'entity': 'PHYS',
#   'score': 0.7529498,
#   'index': 20,
#   'word': '##м',
#   'start': 21,
#   'end': 22},
#  {'entity': 'PHYS',
#   'score': 0.55585057,
#   'index': 21,
#   'word': '##о',
#   'start': 22,
#   'end': 23},
#  {'entity': 'PHYS',
#   'score': 0.09478937,
#   'index': 22,
#   'word': '##с',
#   'start': 23,
#   'end': 24},
#  {'entity': 'ORGANIZATION',
#   'score': 0.08605779,
#   'index': 23,
#   'word': '##т',
#   'start': 24,
#   'end': 25},
#  {'entity': 'DATE',
#   'score': 0.1976327,
#   'index': 24,
#   'word': '##ь',
#   'start': 25,
#   'end': 26},
#  {'entity': 'DATE',
#   'score': 0.51766115,
#   'index': 25,
#   'word': 'у',
#   'start': 27,
#   'end': 28},
#  {'entity': 'PERSON',
#   'score': 0.99717546,
#   'index': 26,
#   'word': 'п',
#   'start': 29,
#   'end': 30},
#  {'entity': 'PERSON',
#   'score': 0.86619115,
#   'index': 27,
#   'word': '##а',
#   'start': 30,
#   'end': 31},
#  {'entity': 'PERSON',
#   'score': 0.5535592,
#   'index': 28,
#   'word': '##ц',
#   'start': 31,
#   'end': 32},
#  {'entity': 'PERSON',
#   'score': 0.45948294,
#   'index': 29,
#   'word': '##и',
#   'start': 32,
#   'end': 33},
#  {'entity': 'PERSON',
#   'score': 0.35412952,
#   'index': 30,
#   'word': '##е',
#   'start': 33,
#   'end': 34},
#  {'entity': 'PERSON',
#   'score': 0.2491416,
#   'index': 31,
#   'word': '##н',
#   'start': 34,
#   'end': 35},
#  {'entity': 'PERSON',
#   'score': 0.30406943,
#   'index': 32,
#   'word': '##т',
#   'start': 35,
#   'end': 36},
#  {'entity': 'DATE',
#   'score': 0.32961756,
#   'index': 33,
#   'word': '##ов',
#   'start': 36,
#   'end': 38},
#  {'entity': 'DATE',
#   'score': 0.89518845,
#   'index': 34,
#   'word': 'с',
#   'start': 39,
#   'end': 40},
#  {'entity': 'DISO',
#   'score': 0.9904156,
#   'index': 35,
#   'word': 'б',
#   'start': 41,
#   'end': 42},
#  {'entity': 'DISO',
#   'score': 0.9592683,
#   'index': 36,
#   'word': '##о',
#   'start': 42,
#   'end': 43},
#  {'entity': 'PHYS',
#   'score': 0.4006284,
#   'index': 37,
#   'word': '##л',
#   'start': 43,
#   'end': 44},
#  {'entity': 'PHYS',
#   'score': 0.3724859,
#   'index': 38,
#   'word': '##е',
#   'start': 44,
#   'end': 45},
#  {'entity': 'PHYS',
#   'score': 0.18826085,
#   'index': 39,
#   'word': '##з',
#   'start': 45,
#   'end': 46},
#  {'entity': 'ORGANIZATION',
#   'score': 0.18391973,
#   'index': 40,
#   'word': '##н',
#   'start': 46,
#   'end': 47},
#  {'entity': 'PHYS',
#   'score': 0.18545866,
#   'index': 41,
#   'word': '##ь',
#   'start': 47,
#   'end': 48},
#  {'entity': 'DISO',
#   'score': 0.25325906,
#   'index': 42,
#   'word': '##ю',
#   'start': 48,
#   'end': 49},
#  {'entity': 'PHYS',
#   'score': 0.6911519,
#   'index': 43,
#   'word': 'ф',
#   'start': 50,
#   'end': 51},
#  {'entity': 'PHYS',
#   'score': 0.20918863,
#   'index': 44,
#   'word': '##а',
#   'start': 51,
#   'end': 52},
#  {'entity': 'PHYS',
#   'score': 0.12541069,
#   'index': 45,
#   'word': '##б',
#   'start': 52,
#   'end': 53},
#  {'entity': 'PHYS',
#   'score': 0.11648467,
#   'index': 46,
#   'word': '##р',
#   'start': 53,
#   'end': 54},
#  {'entity': 'DATE',
#   'score': 0.1953782,
#   'index': 47,
#   'word': '##и',
#   'start': 54,
#   'end': 55},
#  {'entity': 'SCIPROC',
#   'score': 0.17208531,
#   'index': 48,
#   'word': '(',
#   'start': 56,
#   'end': 57},
#  {'entity': 'DISO',
#   'score': 0.29874384,
#   'index': 49,
#   'word': 'б',
#   'start': 57,
#   'end': 58},
#  {'entity': 'SCIPROC',
#   'score': 0.4497931,
#   'index': 50,
#   'word': '##ф',
#   'start': 58,
#   'end': 59},
#  {'entity': 'DATE',
#   'score': 0.1500432,
#   'index': 51,
#   'word': ')',
#   'start': 59,
#   'end': 60},
#  {'entity': 'DATE',
#   'score': 0.9556668,
#   'index': 52,
#   'word': 'в',
#   'start': 61,
#   'end': 62},
#  {'entity': 'PHYS',
#   'score': 0.92234033,
#   'index': 53,
#   'word': 'з',
#   'start': 63,
#   'end': 64},
#  {'entity': 'PHYS',
#   'score': 0.7471523,
#   'index': 54,
#   'word': '##а',
#   'start': 64,
#   'end': 65},
#  {'entity': 'PHYS',
#   'score': 0.46900997,
#   'index': 55,
#   'word': '##в',
#   'start': 65,
#   'end': 66},
#  {'entity': 'PHYS',
#   'score': 0.7438754,
#   'index': 56,
#   'word': '##и',
#   'start': 66,
#   'end': 67},
#  {'entity': 'PHYS',
#   'score': 0.6896265,
#   'index': 57,
#   'word': '##с',
#   'start': 67,
#   'end': 68},
#  {'entity': 'PHYS',
#   'score': 0.8245382,
#   'index': 58,
#   'word': '##и',
#   'start': 68,
#   'end': 69},
#  {'entity': 'PHYS',
#   'score': 0.7912907,
#   'index': 59,
#   'word': '##м',
#   'start': 69,
#   'end': 70},
#  {'entity': 'PHYS',
#   'score': 0.67892045,
#   'index': 60,
#   'word': '##о',
#   'start': 70,
#   'end': 71},
#  {'entity': 'PHYS',
#   'score': 0.0850827,
#   'index': 61,
#   'word': '##с',
#   'start': 71,
#   'end': 72},
#  {'entity': 'DATE',
#   'score': 0.10887159,
#   'index': 62,
#   'word': '##т',
#   'start': 72,
#   'end': 73},
#  {'entity': 'DATE',
#   'score': 0.5047405,
#   'index': 63,
#   'word': '##и',
#   'start': 73,
#   'end': 74},
#  {'entity': 'DISO',
#   'score': 0.86461234,
#   'index': 64,
#   'word': 'о',
#   'start': 75,
#   'end': 76},
#  {'entity': 'DATE',
#   'score': 0.34206522,
#   'index': 65,
#   'word': '##т',
#   'start': 76,
#   'end': 77},
#  {'entity': 'LIVB',
#   'score': 0.22960767,
#   'index': 66,
#   'word': 'в',
#   'start': 78,
#   'end': 79},
#  {'entity': 'PHYS',
#   'score': 0.18879522,
#   'index': 67,
#   'word': '##и',
#   'start': 79,
#   'end': 80},
#  {'entity': 'SCIPROC',
#   'score': 0.09168209,
#   'index': 68,
#   'word': '##д',
#   'start': 80,
#   'end': 81},
#  {'entity': 'DATE',
#   'score': 0.34577402,
#   'index': 69,
#   'word': '##а',
#   'start': 81,
#   'end': 82},
#  {'entity': 'MEDPROC',
#   'score': 0.98922694,
#   'index': 70,
#   'word': 'з',
#   'start': 83,
#   'end': 84},
#  {'entity': 'MEDPROC',
#   'score': 0.58454955,
#   'index': 71,
#   'word': '##а',
#   'start': 84,
#   'end': 85},
#  {'entity': 'MEDPROC',
#   'score': 0.73013467,
#   'index': 72,
#   'word': '##м',
#   'start': 85,
#   'end': 86},
#  {'entity': 'SCIPROC',
#   'score': 0.26354265,
#   'index': 73,
#   'word': '##е',
#   'start': 86,
#   'end': 87},
#  {'entity': 'SCIPROC',
#   'score': 0.3136287,
#   'index': 74,
#   'word': '##с',
#   'start': 87,
#   'end': 88},
#  {'entity': 'MEDPROC',
#   'score': 0.24930115,
#   'index': 75,
#   'word': '##т',
#   'start': 88,
#   'end': 89},
#  {'entity': 'MEDPROC',
#   'score': 0.17733361,
#   'index': 76,
#   'word': '##и',
#   'start': 89,
#   'end': 90},
#  {'entity': 'MEDPROC',
#   'score': 0.5113787,
#   'index': 77,
#   'word': '##т',
#   'start': 90,
#   'end': 91},
#  {'entity': 'PERSON',
#   'score': 0.19426675,
#   'index': 78,
#   'word': '##е',
#   'start': 91,
#   'end': 92},
#  {'entity': 'ORGANIZATION',
#   'score': 0.17500576,
#   'index': 79,
#   'word': '##л',
#   'start': 92,
#   'end': 93},
#  {'entity': 'MEDPROC',
#   'score': 0.20400809,
#   'index': 80,
#   'word': '##ь',
#   'start': 93,
#   'end': 94},
#  {'entity': 'PERSON',
#   'score': 0.3303854,
#   'index': 81,
#   'word': '##н',
#   'start': 94,
#   'end': 95},
#  {'entity': 'PHYS',
#   'score': 0.2876275,
#   'index': 82,
#   'word': '##о',
#   'start': 95,
#   'end': 96},
#  {'entity': 'DISO',
#   'score': 0.09374259,
#   'index': 83,
#   'word': '##и',
#   'start': 96,
#   'end': 97},
#  {'entity': 'MEDPROC',
#   'score': 0.9850004,
#   'index': 84,
#   'word': 'п',
#   'start': 98,
#   'end': 99},
#  {'entity': 'MEDPROC',
#   'score': 0.9679251,
#   'index': 85,
#   'word': '##о',
#   'start': 99,
#   'end': 100},
#  {'entity': 'MEDPROC',
#   'score': 0.97079974,
#   'index': 86,
#   'word': '##ч',
#   'start': 100,
#   'end': 101},
#  {'entity': 'MEDPROC',
#   'score': 0.7874585,
#   'index': 87,
#   'word': '##е',
#   'start': 101,
#   'end': 102},
#  {'entity': 'MEDPROC',
#   'score': 0.8601182,
#   'index': 88,
#   'word': '##ч',
#   'start': 102,
#   'end': 103},
#  {'entity': 'PHYS',
#   'score': 0.28457358,
#   'index': 89,
#   'word': '##н',
#   'start': 103,
#   'end': 104},
#  {'entity': 'PHYS',
#   'score': 0.33268398,
#   'index': 90,
#   'word': '##о',
#   'start': 104,
#   'end': 105},
#  {'entity': 'MEDPROC',
#   'score': 0.17212318,
#   'index': 91,
#   'word': '##и',
#   'start': 105,
#   'end': 106},
#  {'entity': 'MEDPROC',
#   'score': 0.98570806,
#   'index': 92,
#   'word': 'т',
#   'start': 107,
#   'end': 108},
#  {'entity': 'MEDPROC',
#   'score': 0.95956045,
#   'index': 93,
#   'word': '##е',
#   'start': 108,
#   'end': 109},
#  {'entity': 'MEDPROC',
#   'score': 0.7321586,
#   'index': 94,
#   'word': '##р',
#   'start': 109,
#   'end': 110},
#  {'entity': 'MEDPROC',
#   'score': 0.87698746,
#   'index': 95,
#   'word': '##а',
#   'start': 110,
#   'end': 111},
#  {'entity': 'MEDPROC',
#   'score': 0.1513218,
#   'index': 96,
#   'word': '##п',
#   'start': 111,
#   'end': 112},
#  {'entity': 'PHYS',
#   'score': 0.19695319,
#   'index': 97,
#   'word': '##ии',
#   'start': 112,
#   'end': 114},
#  {'entity': 'ORGANIZATION',
#   'score': 0.08787787,
#   'index': 98,
#   'word': ',',
#   'start': 114,
#   'end': 115},
#  {'entity': 'DISO',
#   'score': 0.60993445,
#   'index': 99,
#   'word': 'и',
#   'start': 116,
#   'end': 117},
#  {'entity': 'MEDPROC',
#   'score': 0.52365625,
#   'index': 100,
#   'word': 'о',
#   'start': 118,
#   'end': 119},
#  {'entity': 'SCIPROC',
#   'score': 0.27148986,
#   'index': 101,
#   'word': '##п',
#   'start': 119,
#   'end': 120},
#  {'entity': 'SCIPROC',
#   'score': 0.23703064,
#   'index': 102,
#   'word': '##р',
#   'start': 120,
#   'end': 121},
#  {'entity': 'SCIPROC',
#   'score': 0.1834425,
#   'index': 103,
#   'word': '##е',
#   'start': 121,
#   'end': 122},
#  {'entity': 'ORGANIZATION',
#   'score': 0.1549017,
#   'index': 104,
#   'word': '##д',
#   'start': 122,
#   'end': 123},
#  {'entity': 'PERSON',
#   'score': 0.15288523,
#   'index': 105,
#   'word': '##е',
#   'start': 123,
#   'end': 124},
#  {'entity': 'ORGANIZATION',
#   'score': 0.13986933,
#   'index': 106,
#   'word': '##л',
#   'start': 124,
#   'end': 125},
#  {'entity': 'ORGANIZATION',
#   'score': 0.10486151,
#   'index': 107,
#   'word': '##и',
#   'start': 125,
#   'end': 126},
#  {'entity': 'ORGANIZATION',
#   'score': 0.12933674,
#   'index': 108,
#   'word': '##т',
#   'start': 126,
#   'end': 127},
#  {'entity': 'DATE',
#   'score': 0.3986112,
#   'index': 109,
#   'word': '##ь',
#   'start': 127,
#   'end': 128},
#  {'entity': 'DISO',
#   'score': 0.9254416,
#   'index': 110,
#   'word': 'р',
#   'start': 129,
#   'end': 130},
#  {'entity': 'DISO',
#   'score': 0.4596011,
#   'index': 111,
#   'word': '##о',
#   'start': 130,
#   'end': 131},
#  {'entity': 'DISO',
#   'score': 0.47685164,
#   'index': 112,
#   'word': '##л',
#   'start': 131,
#   'end': 132},
#  {'entity': 'DATE',
#   'score': 0.49464837,
#   'index': 113,
#   'word': '##ь',
#   'start': 132,
#   'end': 133},
#  {'entity': 'PHYS',
#   'score': 0.2026416,
#   'index': 114,
#   'word': 'д',
#   'start': 134,
#   'end': 135},
#  {'entity': 'PHYS',
#   'score': 0.17604756,
#   'index': 115,
#   'word': '##и',
#   'start': 135,
#   'end': 136},
#  {'entity': 'PHYS',
#   'score': 0.73061913,
#   'index': 116,
#   'word': '##а',
#   'start': 136,
#   'end': 137},
#  {'entity': 'PHYS',
#   'score': 0.7948076,
#   'index': 117,
#   'word': '##л',
#   'start': 137,
#   'end': 138},
#  {'entity': 'PHYS',
#   'score': 0.46507347,
#   'index': 118,
#   'word': '##и',
#   'start': 138,
#   'end': 139},
#  {'entity': 'PHYS',
#   'score': 0.5077634,
#   'index': 119,
#   'word': '##з',
#   'start': 139,
#   'end': 140},
#  {'entity': 'PHYS',
#   'score': 0.14986363,
#   'index': 120,
#   'word': '##н',
#   'start': 140,
#   'end': 141},
#  {'entity': 'ORGANIZATION',
#   'score': 0.13226143,
#   'index': 121,
#   'word': '##о',
#   'start': 141,
#   'end': 142},
#  {'entity': 'PHYS',
#   'score': 0.13198361,
#   'index': 122,
#   'word': '##г',
#   'start': 142,
#   'end': 143},
#  {'entity': 'DATE',
#   'score': 0.48821378,
#   'index': 123,
#   'word': '##о',
#   'start': 143,
#   'end': 144},
#  {'entity': 'MEDPROC',
#   'score': 0.37010393,
#   'index': 124,
#   'word': 'с',
#   'start': 145,
#   'end': 146},
#  {'entity': 'DISO',
#   'score': 0.1858036,
#   'index': 125,
#   'word': '##к',
#   'start': 146,
#   'end': 147},
#  {'entity': 'SCIPROC',
#   'score': 0.17432031,
#   'index': 126,
#   'word': '##р',
#   'start': 147,
#   'end': 148},
#  {'entity': 'ORGANIZATION',
#   'score': 0.12816042,
#   'index': 127,
#   'word': '##и',
#   'start': 148,
#   'end': 149},
#  {'entity': 'LIVB',
#   'score': 0.22398292,
#   'index': 128,
#   'word': '##н',
#   'start': 149,
#   'end': 150},
#  {'entity': 'PERSON',
#   'score': 0.2101639,
#   'index': 129,
#   'word': '##и',
#   'start': 150,
#   'end': 151},
#  {'entity': 'PERSON',
#   'score': 0.4001094,
#   'index': 130,
#   'word': '##н',
#   'start': 151,
#   'end': 152},
#  {'entity': 'PERSON',
#   'score': 0.53356916,
#   'index': 131,
#   'word': '##г',
#   'start': 152,
#   'end': 153},
#  {'entity': 'PERSON',
#   'score': 0.34655207,
#   'index': 132,
#   'word': '##а',
#   'start': 153,
#   'end': 154},
#  {'entity': 'DATE',
#   'score': 0.93953496,
#   'index': 133,
#   'word': 'в',
#   'start': 155,
#   'end': 156},
#  {'entity': 'INJURY_POISONING',
#   'score': 0.83796155,
#   'index': 134,
#   'word': 'р',
#   'start': 157,
#   'end': 158},
#  {'entity': 'PERSON',
#   'score': 0.24853471,
#   'index': 135,
#   'word': '##ан',
#   'start': 158,
#   'end': 160},
#  {'entity': 'PERSON',
#   'score': 0.74899906,
#   'index': 136,
#   'word': '##н',
#   'start': 160,
#   'end': 161},
#  {'entity': 'PERSON',
#   'score': 0.29004082,
#   'index': 137,
#   'word': '##е',
#   'start': 161,
#   'end': 162},
#  {'entity': 'PERSON',
#   'score': 0.28069502,
#   'index': 138,
#   'word': '##и',
#   'start': 162,
#   'end': 163},
#  {'entity': 'MEDPROC',
#   'score': 0.36117718,
#   'index': 139,
#   'word': 'д',
#   'start': 164,
#   'end': 165},
#  {'entity': 'LABPROC',
#   'score': 0.26138055,
#   'index': 140,
#   'word': '##и',
#   'start': 165,
#   'end': 166},
#  {'entity': 'SCIPROC',
#   'score': 0.3146706,
#   'index': 141,
#   'word': '##а',
#   'start': 166,
#   'end': 167},
#  {'entity': 'SCIPROC',
#   'score': 0.17724924,
#   'index': 142,
#   'word': '##г',
#   'start': 167,
#   'end': 168},
#  {'entity': 'PHYS',
#   'score': 0.62665427,
#   'index': 143,
#   'word': '##н',
#   'start': 168,
#   'end': 169},
#  {'entity': 'PHYS',
#   'score': 0.47265568,
#   'index': 144,
#   'word': '##о',
#   'start': 169,
#   'end': 170},
#  {'entity': 'SCIPROC',
#   'score': 0.28254429,
#   'index': 145,
#   'word': '##с',
#   'start': 170,
#   'end': 171},
#  {'entity': 'PHYS',
#   'score': 0.13151836,
#   'index': 146,
#   'word': '##т',
#   'start': 171,
#   'end': 172},
#  {'entity': 'PHYS',
#   'score': 0.20587233,
#   'index': 147,
#   'word': '##и',
#   'start': 172,
#   'end': 173},
#  {'entity': 'PHYS',
#   'score': 0.21371947,
#   'index': 148,
#   'word': '##к',
#   'start': 173,
#   'end': 174},
#  {'entity': 'PERSON',
#   'score': 0.16138434,
#   'index': 149,
#   'word': '##е',
#   'start': 174,
#   'end': 175},
#  {'entity': 'DISO',
#   'score': 0.6717591,
#   'index': 150,
#   'word': 'б',
#   'start': 176,
#   'end': 177},
#  {'entity': 'SCIPROC',
#   'score': 0.41133007,
#   'index': 151,
#   'word': '##ф',
#   'start': 177,
#   'end': 178},
#  {'entity': 'PERSON',
#   'score': 0.42537192,
#   'index': 152,
#   'word': 'у',
#   'start': 179,
#   'end': 180},
#  {'entity': 'PERSON',
#   'score': 0.95423245,
#   'index': 153,
#   'word': 'р',
#   'start': 181,
#   'end': 182},
#  {'entity': 'PERSON',
#   'score': 0.38457692,
#   'index': 154,
#   'word': '##о',
#   'start': 182,
#   'end': 183},
#  {'entity': 'PERSON',
#   'score': 0.668174,
#   'index': 155,
#   'word': '##д',
#   'start': 183,
#   'end': 184},
#  {'entity': 'SCIPROC',
#   'score': 0.3379277,
#   'index': 156,
#   'word': '##с',
#   'start': 184,
#   'end': 185},
#  {'entity': 'SCIPROC',
#   'score': 0.17456649,
#   'index': 157,
#   'word': '##т',
#   'start': 185,
#   'end': 186},
#  {'entity': 'PERSON',
#   'score': 0.383159,
#   'index': 158,
#   'word': '##в',
#   'start': 186,
#   'end': 187},
#  {'entity': 'PERSON',
#   'score': 0.60668296,
#   'index': 159,
#   'word': '##е',
#   'start': 187,
#   'end': 188},
#  {'entity': 'PERSON',
#   'score': 0.88652414,
#   'index': 160,
#   'word': '##н',
#   'start': 188,
#   'end': 189},
#  {'entity': 'PERSON',
#   'score': 0.27048284,
#   'index': 161,
#   'word': '##н',
#   'start': 189,
#   'end': 190},
#  {'entity': 'PERSON',
#   'score': 0.3745795,
#   'index': 162,
#   'word': '##и',
#   'start': 190,
#   'end': 191},
#  {'entity': 'PERSON',
#   'score': 0.30171996,
#   'index': 163,
#   'word': '##к',
#   'start': 191,
#   'end': 192},
#  {'entity': 'PERSON',
#   'score': 0.8226323,
#   'index': 164,
#   'word': '##ов',
#   'start': 192,
#   'end': 194},
#  {'entity': 'DATE',
#   'score': 0.24681959,
#   'index': 165,
#   'word': '.',
#   'start': 194,
#   'end': 195},
#  {'entity': 'CHEM',
#   'score': 0.44555897,
#   'index': 166,
#   'word': 'м',
#   'start': 196,
#   'end': 197},
#  {'entity': 'DISO',
#   'score': 0.21395758,
#   'index': 167,
#   'word': '##а',
#   'start': 197,
#   'end': 198},
#  {'entity': 'ANATOMY',
#   'score': 0.2701712,
#   'index': 168,
#   'word': '##т',
#   'start': 198,
#   'end': 199},
#  {'entity': 'PERSON',
#   'score': 0.1181554,
#   'index': 169,
#   'word': '##е',
#   'start': 199,
#   'end': 200},
#  {'entity': 'LIVB',
#   'score': 0.26759213,
#   'index': 170,
#   'word': '##р',
#   'start': 200,
#   'end': 201},
#  {'entity': 'CHEM',
#   'score': 0.30469614,
#   'index': 171,
#   'word': '##и',
#   'start': 201,
#   'end': 202},
#  {'entity': 'PERSON',
#   'score': 0.18300214,
#   'index': 172,
#   'word': '##а',
#   'start': 202,
#   'end': 203},
#  {'entity': 'PERSON',
#   'score': 0.46407342,
#   'index': 173,
#   'word': '##л',
#   'start': 203,
#   'end': 204},
#  {'entity': 'PERSON',
#   'score': 0.43529066,
#   'index': 174,
#   'word': '##ы',
#   'start': 204,
#   'end': 205},
#  {'entity': 'DATE',
#   'score': 0.4944832,
#   'index': 175,
#   'word': 'и',
#   'start': 206,
#   'end': 207},
#  {'entity': 'SCIPROC',
#   'score': 0.22919855,
#   'index': 176,
#   'word': 'м',
#   'start': 208,
#   'end': 209},
#  {'entity': 'PERSON',
#   'score': 0.1714553,
#   'index': 177,
#   'word': '##е',
#   'start': 209,
#   'end': 210},
#  {'entity': 'PERSON',
#   'score': 0.245099,
#   'index': 178,
#   'word': '##т',
#   'start': 210,
#   'end': 211},
#  {'entity': 'PERSON',
#   'score': 0.34097677,
#   'index': 179,
#   'word': '##о',
#   'start': 211,
#   'end': 212},
#  {'entity': 'PERSON',
#   'score': 0.597304,
#   'index': 180,
#   'word': '##д',
#   'start': 212,
#   'end': 213},
#  {'entity': 'PERSON',
#   'score': 0.4927145,
#   'index': 181,
#   'word': '##ы',
#   'start': 213,
#   'end': 214},
#  {'entity': 'DATE',
#   'score': 0.23955186,
#   'index': 182,
#   'word': '.',
#   'start': 214,
#   'end': 215},
#  {'entity': 'DATE',
#   'score': 0.83336,
#   'index': 183,
#   'word': 'в',
#   'start': 216,
#   'end': 217},
#  {'entity': 'SCIPROC',
#   'score': 0.50635785,
#   'index': 184,
#   'word': 'и',
#   'start': 218,
#   'end': 219},
#  {'entity': 'SCIPROC',
#   'score': 0.6953075,
#   'index': 185,
#   'word': '##с',
#   'start': 219,
#   'end': 220},
#  {'entity': 'SCIPROC',
#   'score': 0.6223977,
#   'index': 186,
#   'word': '##с',
#   'start': 220,
#   'end': 221},
#  {'entity': 'SCIPROC',
#   'score': 0.41422626,
#   'index': 187,
#   'word': '##л',
#   'start': 221,
#   'end': 222},
#  {'entity': 'SCIPROC',
#   'score': 0.4234247,
#   'index': 188,
#   'word': '##е',
#   'start': 222,
#   'end': 223},
#  {'entity': 'SCIPROC',
#   'score': 0.41526672,
#   'index': 189,
#   'word': '##д',
#   'start': 223,
#   'end': 224},
#  {'entity': 'SCIPROC',
#   'score': 0.22995532,
#   'index': 190,
#   'word': '##ов',
#   'start': 224,
#   'end': 226},
#  {'entity': 'SCIPROC',
#   'score': 0.27283138,
#   'index': 191,
#   'word': '##ан',
#   'start': 226,
#   'end': 228},
#  {'entity': 'SCIPROC',
#   'score': 0.1959014,
#   'index': 192,
#   'word': '##и',
#   'start': 228,
#   'end': 229},
#  {'entity': 'DATE',
#   'score': 0.1926779,
#   'index': 193,
#   'word': '##е',
#   'start': 229,
#   'end': 230},
#  {'entity': 'DISO',
#   'score': 0.86341834,
#   'index': 194,
#   'word': 'в',
#   'start': 231,
#   'end': 232},
#  {'entity': 'ANATOMY',
#   'score': 0.2986235,
#   'index': 195,
#   'word': '##к',
#   'start': 232,
#   'end': 233},
#  {'entity': 'PERSON',
#   'score': 0.6358851,
#   'index': 196,
#   'word': '##л',
#   'start': 233,
#   'end': 234},
#  {'entity': 'PERSON',
#   'score': 0.75961244,
#   'index': 197,
#   'word': '##ю',
#   'start': 234,
#   'end': 235},
#  {'entity': 'PERSON',
#   'score': 0.6387252,
#   'index': 198,
#   'word': '##ч',
#   'start': 235,
#   'end': 236},
#  {'entity': 'PERSON',
#   'score': 0.63225865,
#   'index': 199,
#   'word': '##а',
#   'start': 236,
#   'end': 237},
#  {'entity': 'PHYS',
#   'score': 0.15561375,
#   'index': 200,
#   'word': '##л',
#   'start': 237,
#   'end': 238},
#  {'entity': 'DATE',
#   'score': 0.37552682,
#   'index': 201,
#   'word': '##и',
#   'start': 238,
#   'end': 239},
#  {'entity': 'PERSON',
#   'score': 0.9738675,
#   'index': 202,
#   'word': 'в',
#   'start': 240,
#   'end': 241},
#  {'entity': 'PERSON',
#   'score': 0.20518039,
#   'index': 203,
#   'word': '##з',
#   'start': 241,
#   'end': 242},
#  {'entity': 'PERSON',
#   'score': 0.09385854,
#   'index': 204,
#   'word': '##р',
#   'start': 242,
#   'end': 243},
#  {'entity': 'PERSON',
#   'score': 0.27374843,
#   'index': 205,
#   'word': '##о',
#   'start': 243,
#   'end': 244},
#  {'entity': 'AGE',
#   'score': 0.3978446,
#   'index': 206,
#   'word': '##с',
#   'start': 244,
#   'end': 245},
#  {'entity': 'PERSON',
#   'score': 0.171637,
#   'index': 207,
#   'word': '##л',
#   'start': 245,
#   'end': 246},
#  {'entity': 'AGE',
#   'score': 0.71296686,
#   'index': 208,
#   'word': '##ы',
#   'start': 246,
#   'end': 247},
#  {'entity': 'AGE',
#   'score': 0.7719681,
#   'index': 209,
#   'word': '##х',
#   'start': 247,
#   'end': 248},
#  {'entity': 'AGE',
#   'score': 0.93834007,
#   'index': 210,
#   'word': '(',
#   'start': 249,
#   'end': 250},
#  {'entity': 'AGE',
#   'score': 0.94172823,
#   'index': 211,
#   'word': 'с',
#   'start': 250,
#   'end': 251},
#  {'entity': 'AGE',
#   'score': 0.908733,
#   'index': 212,
#   'word': '##т',
#   'start': 251,
#   'end': 252},
#  {'entity': 'AGE',
#   'score': 0.91746265,
#   'index': 213,
#   'word': '##а',
#   'start': 252,
#   'end': 253},
#  {'entity': 'AGE',
#   'score': 0.61328006,
#   'index': 214,
#   'word': '##р',
#   'start': 253,
#   'end': 254},
#  {'entity': 'AGE',
#   'score': 0.9530352,
#   'index': 215,
#   'word': '##ш',
#   'start': 254,
#   'end': 255},
#  {'entity': 'AGE',
#   'score': 0.9450596,
#   'index': 216,
#   'word': '##е',
#   'start': 255,
#   'end': 256},
#  {'entity': 'AGE',
#   'score': 0.9681132,
#   'index': 217,
#   'word': '18',
#   'start': 257,
#   'end': 259},
#  {'entity': 'AGE',
#   'score': 0.92048025,
#   'index': 218,
#   'word': 'л',
#   'start': 260,
#   'end': 261},
#  {'entity': 'AGE',
#   'score': 0.96165013,
#   'index': 219,
#   'word': '##е',
#   'start': 261,
#   'end': 262},
#  {'entity': 'AGE',
#   'score': 0.9542277,
#   'index': 220,
#   'word': '##т',
#   'start': 262,
#   'end': 263},
#  {'entity': 'AGE',
#   'score': 0.7663093,
#   'index': 221,
#   'word': ')',
#   'start': 263,
#   'end': 264},
#  {'entity': 'PERSON',
#   'score': 0.9970752,
#   'index': 222,
#   'word': 'п',
#   'start': 265,
#   'end': 266},
#  {'entity': 'PERSON',
#   'score': 0.9531856,
#   'index': 223,
#   'word': '##а',
#   'start': 266,
#   'end': 267},
#  {'entity': 'PERSON',
#   'score': 0.60818595,
#   'index': 224,
#   'word': '##ц',
#   'start': 267,
#   'end': 268},
#  {'entity': 'PERSON',
#   'score': 0.51421964,
#   'index': 225,
#   'word': '##и',
#   'start': 268,
#   'end': 269},
#  {'entity': 'PERSON',
#   'score': 0.40597025,
#   'index': 226,
#   'word': '##е',
#   'start': 269,
#   'end': 270},
#  {'entity': 'PERSON',
#   'score': 0.54482114,
#   'index': 227,
#   'word': '##н',
#   'start': 270,
#   'end': 271},
#  {'entity': 'PERSON',
#   'score': 0.45598835,
#   'index': 228,
#   'word': '##т',
#   'start': 271,
#   'end': 272},
#  {'entity': 'PERSON',
#   'score': 0.39190465,
#   'index': 229,
#   'word': '##ов',
#   'start': 272,
#   'end': 274},
#  {'entity': 'DATE',
#   'score': 0.77490896,
#   'index': 230,
#   'word': 'с',
#   'start': 275,
#   'end': 276},
#  {'entity': 'DISO',
#   'score': 0.38683778,
#   'index': 231,
#   'word': 'п',
#   'start': 277,
#   'end': 278},
#  {'entity': 'DISO',
#   'score': 0.5773285,
#   'index': 232,
#   'word': '##о',
#   'start': 278,
#   'end': 279},
#  {'entity': 'SCIPROC',
#   'score': 0.6122589,
#   'index': 233,
#   'word': '##д',
#   'start': 279,
#   'end': 280},
#  {'entity': 'SCIPROC',
#   'score': 0.4720415,
#   'index': 234,
#   'word': '##т',
#   'start': 280,
#   'end': 281},
#  {'entity': 'PERSON',
#   'score': 0.46159223,
#   'index': 235,
#   'word': '##в',
#   'start': 281,
#   'end': 282},
#  {'entity': 'PERSON',
#   'score': 0.20376736,
#   'index': 236,
#   'word': '##е',
#   'start': 282,
#   'end': 283},
#  {'entity': 'PHYS',
#   'score': 0.19324036,
#   'index': 237,
#   'word': '##р',
#   'start': 283,
#   'end': 284},
#  {'entity': 'PERSON',
#   'score': 0.58156896,
#   'index': 238,
#   'word': '##ж',
#   'start': 284,
#   'end': 285},
#  {'entity': 'PERSON',
#   'score': 0.7176104,
#   'index': 239,
#   'word': '##д',
#   'start': 285,
#   'end': 286},
#  {'entity': 'PERSON',
#   'score': 0.18590201,
#   'index': 240,
#   'word': '##е',
#   'start': 286,
#   'end': 287},
#  {'entity': 'PERSON',
#   'score': 0.4126985,
#   'index': 241,
#   'word': '##н',
#   'start': 287,
#   'end': 288},
#  {'entity': 'PERSON',
#   'score': 0.7592617,
#   'index': 242,
#   'word': '##н',
#   'start': 288,
#   'end': 289},
#  {'entity': 'PERSON',
#   'score': 0.58713096,
#   'index': 243,
#   'word': '##ы',
#   'start': 289,
#   'end': 290},
#  {'entity': 'DATE',
#   'score': 0.15197387,
#   'index': 244,
#   'word': '##м',
#   'start': 290,
#   'end': 291},
#  {'entity': 'LABPROC',
#   'score': 0.59829766,
#   'index': 245,
#   'word': 'д',
#   'start': 292,
#   'end': 293},
#  {'entity': 'LABPROC',
#   'score': 0.44131634,
#   'index': 246,
#   'word': '##и',
#   'start': 293,
#   'end': 294},
#  {'entity': 'SCIPROC',
#   'score': 0.297904,
#   'index': 247,
#   'word': '##а',
#   'start': 294,
#   'end': 295},
#  {'entity': 'SCIPROC',
#   'score': 0.27872047,
#   'index': 248,
#   'word': '##г',
#   'start': 295,
#   'end': 296},
#  {'entity': 'PHYS',
#   'score': 0.22427876,
#   'index': 249,
#   'word': '##н',
#   'start': 296,
#   'end': 297},
#  {'entity': 'PHYS',
#   'score': 0.31794277,
#   'index': 250,
#   'word': '##о',
#   'start': 297,
#   'end': 298},
#  {'entity': 'PHYS',
#   'score': 0.5216819,
#   'index': 251,
#   'word': '##з',
#   'start': 298,
#   'end': 299},
#  {'entity': 'PHYS',
#   'score': 0.34117407,
#   'index': 252,
#   'word': '##о',
#   'start': 299,
#   'end': 300},
#  {'entity': 'PHYS',
#   'score': 0.14625558,
#   'index': 253,
#   'word': '##м',
#   'start': 300,
#   'end': 301},
#  {'entity': 'DISO',
#   'score': 0.7476087,
#   'index': 254,
#   'word': 'б',
#   'start': 302,
#   'end': 303},
#  {'entity': 'SCIPROC',
#   'score': 0.37467432,
#   'index': 255,
#   'word': '##ф',
#   'start': 303,
#   'end': 304},
#  {'entity': 'DATE',
#   'score': 0.15804248,
#   'index': 256,
#   'word': '.',
#   'start': 304,
#   'end': 305},
#  {'entity': 'LABPROC',
#   'score': 0.41425633,
#   'index': 257,
#   'word': 'т',
#   'start': 306,
#   'end': 307},
#  {'entity': 'MEDPROC',
#   'score': 0.29026487,
#   'index': 258,
#   'word': '##е',
#   'start': 307,
#   'end': 308},
#  {'entity': 'PHYS',
#   'score': 0.29533792,
#   'index': 259,
#   'word': '##р',
#   'start': 308,
#   'end': 309},
#  {'entity': 'SCIPROC',
#   'score': 0.61330664,
#   'index': 260,
#   'word': '##м',
#   'start': 309,
#   'end': 310},
#  {'entity': 'SCIPROC',
#   'score': 0.2278756,
#   'index': 261,
#   'word': '##и',
#   'start': 310,
#   'end': 311},
#  {'entity': 'PHYS',
#   'score': 0.16698602,
#   'index': 262,
#   'word': '##на',
#   'start': 311,
#   'end': 313},
#  {'entity': 'PHYS',
#   'score': 0.23289998,
#   'index': 263,
#   'word': '##л',
#   'start': 313,
#   'end': 314},
#  {'entity': 'SCIPROC',
#   'score': 0.264392,
#   'index': 264,
#   'word': '##ь',
#   'start': 314,
#   'end': 315},
#  {'entity': 'PHYS',
#   'score': 0.43478718,
#   'index': 265,
#   'word': '##на',
#   'start': 315,
#   'end': 317},
#  {'entity': 'PHYS',
#   'score': 0.35416427,
#   'index': 266,
#   'word': '##я',
#   'start': 317,
#   'end': 318},
#  {'entity': 'PHYS',
#   'score': 0.23189858,
#   'index': 267,
#   'word': 'с',
#   'start': 319,
#   'end': 320},
#  {'entity': 'PERSON',
#   'score': 0.13786961,
#   'index': 268,
#   'word': '##т',
#   'start': 320,
#   'end': 321},
#  {'entity': 'PHYS',
#   'score': 0.32944375,
#   'index': 269,
#   'word': '##а',
#   'start': 321,
#   'end': 322},
#  {'entity': 'SCIPROC',
#   'score': 0.11936649,
#   'index': 270,
#   'word': '##д',
#   'start': 322,
#   'end': 323},
#  {'entity': 'PHYS',
#   'score': 0.3585837,
#   'index': 271,
#   'word': '##ия',
#   'start': 323,
#   'end': 325},
#  {'entity': 'DISO',
#   'score': 0.99078685,
#   'index': 272,
#   'word': 'х',
#   'start': 326,
#   'end': 327},
#  {'entity': 'PHYS',
#   'score': 0.3718177,
#   'index': 273,
#   'word': '##р',
#   'start': 327,
#   'end': 328},
#  {'entity': 'PHYS',
#   'score': 0.3778324,
#   'index': 274,
#   'word': '##о',
#   'start': 328,
#   'end': 329},
#  {'entity': 'PHYS',
#   'score': 0.52988964,
#   'index': 275,
#   'word': '##н',
#   'start': 329,
#   'end': 330},
#  {'entity': 'PHYS',
#   'score': 0.34318107,
#   'index': 276,
#   'word': '##и',
#   'start': 330,
#   'end': 331},
#  {'entity': 'PHYS',
#   'score': 0.38227195,
#   'index': 277,
#   'word': '##ч',
#   'start': 331,
#   'end': 332},
#  {'entity': 'PHYS',
#   'score': 0.5394133,
#   'index': 278,
#   'word': '##е',
#   'start': 332,
#   'end': 333},
#  {'entity': 'PHYS',
#   'score': 0.34771973,
#   'index': 279,
#   'word': '##с',
#   'start': 333,
#   'end': 334},
#  {'entity': 'PHYS',
#   'score': 0.2757345,
#   'index': 280,
#   'word': '##к',
#   'start': 334,
#   'end': 335},
#  {'entity': 'PHYS',
#   'score': 0.5584595,
#   'index': 281,
#   'word': '##о',
#   'start': 335,
#   'end': 336},
#  {'entity': 'PHYS',
#   'score': 0.4717239,
#   'index': 282,
#   'word': '##и',
#   'start': 336,
#   'end': 337},
#  {'entity': 'DISO',
#   'score': 0.5097831,
#   'index': 283,
#   'word': 'п',
#   'start': 338,
#   'end': 339},
#  {'entity': 'PHYS',
#   'score': 0.48144567,
#   'index': 284,
#   'word': '##о',
#   'start': 339,
#   'end': 340},
#  {'entity': 'ANATOMY',
#   'score': 0.42979622,
#   'index': 285,
#   'word': '##ч',
#   'start': 340,
#   'end': 341},
#  {'entity': 'PHYS',
#   'score': 0.42916247,
#   'index': 286,
#   'word': '##е',
#   'start': 341,
#   'end': 342},
#  {'entity': 'PHYS',
#   'score': 0.3331122,
#   'index': 287,
#   'word': '##ч',
#   'start': 342,
#   'end': 343},
#  {'entity': 'PHYS',
#   'score': 0.35674196,
#   'index': 288,
#   'word': '##н',
#   'start': 343,
#   'end': 344},
#  {'entity': 'PHYS',
#   'score': 0.62599146,
#   'index': 289,
#   'word': '##о',
#   'start': 344,
#   'end': 345},
#  {'entity': 'PHYS',
#   'score': 0.5100603,
#   'index': 290,
#   'word': '##и',
#   'start': 345,
#   'end': 346},
#  {'entity': 'DISO',
#   'score': 0.19365746,
#   'index': 291,
#   'word': 'н',
#   'start': 347,
#   'end': 348},
#  {'entity': 'PHYS',
#   'score': 0.6597511,
#   'index': 292,
#   'word': '##е',
#   'start': 348,
#   'end': 349},
#  {'entity': 'PHYS',
#   'score': 0.2985241,
#   'index': 293,
#   'word': '##д',
#   'start': 349,
#   'end': 350},
#  {'entity': 'PHYS',
#   'score': 0.6563891,
#   'index': 294,
#   'word': '##о',
#   'start': 350,
#   'end': 351},
#  {'entity': 'PHYS',
#   'score': 0.41031152,
#   'index': 295,
#   'word': '##с',
#   'start': 351,
#   'end': 352},
#  {'entity': 'PHYS',
#   'score': 0.36023462,
#   'index': 296,
#   'word': '##т',
#   'start': 352,
#   'end': 353},
#  {'entity': 'PHYS',
#   'score': 0.69160724,
#   'index': 297,
#   'word': '##а',
#   'start': 353,
#   'end': 354},
#  {'entity': 'PHYS',
#   'score': 0.4146404,
#   'index': 298,
#   'word': '##т',
#   'start': 354,
#   'end': 355},
#  {'entity': 'PHYS',
#   'score': 0.54873866,
#   'index': 299,
#   'word': '##о',
#   'start': 355,
#   'end': 356},
#  {'entity': 'PHYS',
#   'score': 0.36220104,
#   'index': 300,
#   'word': '##ч',
#   'start': 356,
#   'end': 357},
#  {'entity': 'PHYS',
#   'score': 0.53241247,
#   'index': 301,
#   'word': '##н',
#   'start': 357,
#   'end': 358},
#  {'entity': 'PHYS',
#   'score': 0.7804407,
#   'index': 302,
#   'word': '##о',
#   'start': 358,
#   'end': 359},
#  {'entity': 'PHYS',
#   'score': 0.34718734,
#   'index': 303,
#   'word': '##с',
#   'start': 359,
#   'end': 360},
#  {'entity': 'PHYS',
#   'score': 0.2126249,
#   'index': 304,
#   'word': '##т',
#   'start': 360,
#   'end': 361},
#  {'entity': 'PHYS',
#   'score': 0.31469876,
#   'index': 305,
#   'word': '##и',
#   'start': 361,
#   'end': 362},
#  {'entity': 'MEDPROC',
#   'score': 0.35884416,
#   'index': 306,
#   'word': '(',
#   'start': 363,
#   'end': 364},
#  {'entity': 'MEDPROC',
#   'score': 0.33064508,
#   'index': 307,
#   'word': 'т',
#   'start': 364,
#   'end': 365},
#  {'entity': 'PHYS',
#   'score': 0.26413482,
#   'index': 308,
#   'word': '##х',
#   'start': 365,
#   'end': 366},
#  {'entity': 'SCIPROC',
#   'score': 0.38487422,
#   'index': 309,
#   'word': '##п',
#   'start': 366,
#   'end': 367},
#  {'entity': 'SCIPROC',
#   'score': 0.46129805,
#   'index': 310,
#   'word': '##н',
#   'start': 367,
#   'end': 368},
#  {'entity': 'PHYS',
#   'score': 0.13313936,
#   'index': 311,
#   'word': ')',
#   'start': 368,
#   'end': 369},
#  {'entity': 'LABPROC',
#   'score': 0.42286947,
#   'index': 312,
#   'word': 'д',
#   'start': 370,
#   'end': 371},
#  {'entity': 'LABPROC',
#   'score': 0.38722727,
#   'index': 313,
#   'word': '##и',
#   'start': 371,
#   'end': 372},
#  {'entity': 'SCIPROC',
#   'score': 0.43053722,
#   'index': 314,
#   'word': '##а',
#   'start': 372,
#   'end': 373},
#  {'entity': 'SCIPROC',
#   'score': 0.28363615,
#   'index': 315,
#   'word': '##г',
#   'start': 373,
#   'end': 374},
#  {'entity': 'PHYS',
#   'score': 0.29219523,
#   'index': 316,
#   'word': '##н',
#   'start': 374,
#   'end': 375},
#  {'entity': 'PHYS',
#   'score': 0.38019451,
#   'index': 317,
#   'word': '##о',
#   'start': 375,
#   'end': 376},
#  {'entity': 'SCIPROC',
#   'score': 0.37759882,
#   'index': 318,
#   'word': '##с',
#   'start': 376,
#   'end': 377},
#  {'entity': 'PHYS',
#   'score': 0.18860565,
#   'index': 319,
#   'word': '##т',
#   'start': 377,
#   'end': 378},
#  {'entity': 'PHYS',
#   'score': 0.37120134,
#   'index': 320,
#   'word': '##и',
#   'start': 378,
#   'end': 379},
#  {'entity': 'PHYS',
#   'score': 0.27968076,
#   'index': 321,
#   'word': '##р',
#   'start': 379,
#   'end': 380},
#  {'entity': 'PHYS',
#   'score': 0.32806697,
#   'index': 322,
#   'word': '##ов',
#   'start': 380,
#   'end': 382},
#  {'entity': 'PHYS',
#   'score': 0.25673983,
#   'index': 323,
#   'word': '##а',
#   'start': 382,
#   'end': 383},
#  {'entity': 'PHYS',
#   'score': 0.23916745,
#   'index': 324,
#   'word': '##л',
#   'start': 383,
#   'end': 384},
#  {'entity': 'PHYS',
#   'score': 0.17798172,
#   'index': 325,
#   'word': '##и',
#   'start': 384,
#   'end': 385},
#  {'entity': 'DATE',
#   'score': 0.8226244,
#   'index': 326,
#   'word': 'в',
#   'start': 386,
#   'end': 387},
#  {'entity': 'PHYS',
#   'score': 0.5502789,
#   'index': 327,
#   'word': 'с',
#   'start': 388,
#   'end': 389},
#  {'entity': 'PHYS',
#   'score': 0.54041946,
#   'index': 328,
#   'word': '##о',
#   'start': 389,
#   'end': 390},
#  {'entity': 'FINDING',
#   'score': 0.27297062,
#   'index': 329,
#   'word': '##о',
#   'start': 390,
#   'end': 391},
#  {'entity': 'PHYS',
#   'score': 0.44261044,
#   'index': 330,
#   'word': '##т',
#   'start': 391,
#   'end': 392},
#  {'entity': 'PHYS',
#   'score': 0.5555239,
#   'index': 331,
#   'word': '##в',
#   'start': 392,
#   'end': 393},
#  {'entity': 'PHYS',
#   'score': 0.16512957,
#   'index': 332,
#   'word': '##е',
#   'start': 393,
#   'end': 394},
#  {'entity': 'PHYS',
#   'score': 0.23487788,
#   'index': 333,
#   'word': '##т',
#   'start': 394,
#   'end': 395},
#  {'entity': 'PHYS',
#   'score': 0.21927752,
#   'index': 334,
#   'word': '##с',
#   'start': 395,
#   'end': 396},
#  {'entity': 'PHYS',
#   'score': 0.1184613,
#   'index': 335,
#   'word': '##т',
#   'start': 396,
#   'end': 397},
#  {'entity': 'SCIPROC',
#   'score': 0.15035224,
#   'index': 336,
#   'word': '##в',
#   'start': 397,
#   'end': 398},
#  {'entity': 'PHYS',
#   'score': 0.30350277,
#   'index': 337,
#   'word': '##ии',
#   'start': 398,
#   'end': 400},
#  {'entity': 'DATE',
#   'score': 0.5349079,
#   'index': 338,
#   'word': 'с',
#   'start': 401,
#   'end': 402},
#  {'entity': 'DISO',
#   'score': 0.42857653,
#   'index': 339,
#   'word': 'р',
#   'start': 403,
#   'end': 404},
#  {'entity': 'DISO',
#   'score': 0.4170423,
#   'index': 340,
#   'word': '##е',
#   'start': 404,
#   'end': 405},
#  {'entity': 'PHYS',
#   'score': 0.2839143,
#   'index': 341,
#   'word': '##к',
#   'start': 405,
#   'end': 406},
#  {'entity': 'PHYS',
#   'score': 0.63349223,
#   'index': 342,
#   'word': '##о',
#   'start': 406,
#   'end': 407},
#  {'entity': 'PHYS',
#   'score': 0.49676958,
#   'index': 343,
#   'word': '##м',
#   'start': 407,
#   'end': 408},
#  {'entity': 'PHYS',
#   'score': 0.5081693,
#   'index': 344,
#   'word': '##е',
#   'start': 408,
#   'end': 409},
#  {'entity': 'PHYS',
#   'score': 0.4539709,
#   'index': 345,
#   'word': '##н',
#   'start': 409,
#   'end': 410},
#  {'entity': 'SCIPROC',
#   'score': 0.149856,
#   'index': 346,
#   'word': '##д',
#   'start': 410,
#   'end': 411},
#  {'entity': 'PHYS',
#   'score': 0.09056504,
#   'index': 347,
#   'word': '##а',
#   'start': 411,
#   'end': 412},
#  {'entity': 'PHYS',
#   'score': 0.20622888,
#   'index': 348,
#   'word': '##ц',
#   'start': 412,
#   'end': 413},
#  {'entity': 'PHYS',
#   'score': 0.3703324,
#   'index': 349,
#   'word': '##ия',
#   'start': 413,
#   'end': 415},
#  {'entity': 'DISO',
#   'score': 0.50136566,
#   'index': 350,
#   'word': '##м',
#   'start': 415,
#   'end': 416},
#  {'entity': 'DATE',
#   'score': 0.42700925,
#   'index': 351,
#   'word': '##и',
#   'start': 416,
#   'end': 417},
#  {'entity': 'ANATOMY',
#   'score': 0.88193643,
#   'index': 352,
#   'word': 'н',
#   'start': 418,
#   'end': 419},
#  {'entity': 'ANATOMY',
#   'score': 0.49541503,
#   'index': 353,
#   'word': '##а',
#   'start': 419,
#   'end': 420},
#  {'entity': 'PERSON',
#   'score': 0.5240954,
#   'index': 354,
#   'word': '##у',
#   'start': 420,
#   'end': 421},
#  {'entity': 'ANATOMY',
#   'score': 0.31022412,
#   'index': 355,
#   'word': '##ч',
#   'start': 421,
#   'end': 422},
#  {'entity': 'ANATOMY',
#   'score': 0.3082607,
#   'index': 356,
#   'word': '##н',
#   'start': 422,
#   'end': 423},
#  {'entity': 'PHYS',
#   'score': 0.37148952,
#   'index': 357,
#   'word': '##о',
#   'start': 423,
#   'end': 424},
#  {'entity': 'PHYS',
#   'score': 0.2961163,
#   'index': 358,
#   'word': '##г',
#   'start': 424,
#   'end': 425},
#  {'entity': 'PHYS',
#   'score': 0.32284677,
#   'index': 359,
#   'word': '##о',
#   'start': 425,
#   'end': 426},
#  {'entity': 'PHYS',
#   'score': 0.7311539,
#   'index': 360,
#   'word': 'о',
#   'start': 427,
#   'end': 428},
#  {'entity': 'PHYS',
#   'score': 0.5554733,
#   'index': 361,
#   'word': '##б',
#   'start': 428,
#   'end': 429},
#  {'entity': 'PHYS',
#   'score': 0.44822586,
#   'index': 362,
#   'word': '##щ',
#   'start': 429,
#   'end': 430},
#  {'entity': 'PHYS',
#   'score': 0.5577947,
#   'index': 363,
#   'word': '##е',
#   'start': 430,
#   'end': 431},
#  {'entity': 'PHYS',
#   'score': 0.10048603,
#   'index': 364,
#   'word': '##с',
#   'start': 431,
#   'end': 432},
#  {'entity': 'PHYS',
#   'score': 0.15783782,
#   'index': 365,
#   'word': '##т',
#   'start': 432,
#   'end': 433},
#  {'entity': 'PHYS',
#   'score': 0.15747628,
#   'index': 366,
#   'word': '##в',
#   'start': 433,
#   'end': 434},
#  {'entity': 'PERSON',
#   'score': 0.14434811,
#   'index': 367,
#   'word': '##а',
#   'start': 434,
#   'end': 435},
#  {'entity': 'ANATOMY',
#   'score': 0.91647875,
#   'index': 368,
#   'word': 'н',
#   'start': 436,
#   'end': 437},
#  {'entity': 'PERSON',
#   'score': 0.5753676,
#   'index': 369,
#   'word': '##е',
#   'start': 437,
#   'end': 438},
#  {'entity': 'LIVB',
#   'score': 0.26339915,
#   'index': 370,
#   'word': '##ф',
#   'start': 438,
#   'end': 439},
#  {'entity': 'ANATOMY',
#   'score': 0.8283365,
#   'index': 371,
#   'word': '##р',
#   'start': 439,
#   'end': 440},
#  {'entity': 'PERSON',
#   'score': 0.2740127,
#   'index': 372,
#   'word': '##о',
#   'start': 440,
#   'end': 441},
#  {'entity': 'ANATOMY',
#   'score': 0.8349491,
#   'index': 373,
#   'word': '##л',
#   'start': 441,
#   'end': 442},
#  {'entity': 'PERSON',
#   'score': 0.5522712,
#   'index': 374,
#   'word': '##о',
#   'start': 442,
#   'end': 443},
#  {'entity': 'PERSON',
#   'score': 0.17124511,
#   'index': 375,
#   'word': '##г',
#   'start': 443,
#   'end': 444},
#  {'entity': 'PERSON',
#   'score': 0.69939524,
#   'index': 376,
#   'word': '##ов',
#   'start': 444,
#   'end': 446},
#  {'entity': 'COUNTRY',
#   'score': 0.870692,
#   'index': 377,
#   'word': 'р',
#   'start': 447,
#   'end': 448},
#  {'entity': 'COUNTRY',
#   'score': 0.5235216,
#   'index': 378,
#   'word': '##о',
#   'start': 448,
#   'end': 449},
#  {'entity': 'COUNTRY',
#   'score': 0.37904295,
#   'index': 379,
#   'word': '##с',
#   'start': 449,
#   'end': 450},
#  {'entity': 'COUNTRY',
#   'score': 0.17695154,
#   'index': 380,
#   'word': '##с',
#   'start': 450,
#   'end': 451},
#  {'entity': 'PHYS',
#   'score': 0.1639335,
#   'index': 381,
#   'word': '##ии',
#   'start': 451,
#   'end': 453},
#  {'entity': 'DATE',
#   'score': 0.4251655,
#   'index': 382,
#   'word': '(',
#   'start': 454,
#   'end': 455},
#  {'entity': 'DATE',
#   'score': 0.78671116,
#   'index': 383,
#   'word': '2016',
#   'start': 455,
#   'end': 459},
#  {'entity': 'DATE',
#   'score': 0.41906095,
#   'index': 384,
#   'word': ')',
#   'start': 459,
#   'end': 460},
#  {'entity': 'DATE',
#   'score': 0.60594785,
#   'index': 385,
#   'word': 'и',
#   'start': 461,
#   'end': 462},
#  {'entity': 'SCIPROC',
#   'score': 0.47921845,
#   'index': 386,
#   'word': 'k',
#   'start': 463,
#   'end': 464},
#  {'entity': 'SCIPROC',
#   'score': 0.46703744,
#   'index': 387,
#   'word': '##di',
#   'start': 464,
#   'end': 466},
#  {'entity': 'DATE',
#   'score': 0.33211386,
#   'index': 388,
#   'word': '##go',
#   'start': 466,
#   'end': 468},
#  {'entity': 'DATE',
#   'score': 0.4419854,
#   'index': 389,
#   'word': '(',
#   'start': 469,
#   'end': 470},
#  {'entity': 'DATE',
#   'score': 0.821631,
#   'index': 390,
#   'word': '2012',
#   'start': 470,
#   'end': 474},
#  {'entity': 'DATE',
#   'score': 0.12078105,
#   'index': 391,
#   'word': ')',
#   'start': 474,
#   'end': 475},
#  {'entity': 'DATE',
#   'score': 0.49459127,
#   'index': 392,
#   'word': '.',
#   'start': 475,
#   'end': 476},
#  {'entity': 'DISO',
#   'score': 0.54092777,
#   'index': 393,
#   'word': 'н',
#   'start': 477,
#   'end': 478},
#  {'entity': 'DATE',
#   'score': 0.44910592,
#   'index': 394,
#   'word': '##а',
#   'start': 478,
#   'end': 479},
#  {'entity': 'PHYS',
#   'score': 0.510915,
#   'index': 395,
#   'word': 'о',
#   'start': 480,
#   'end': 481},
#  {'entity': 'PHYS',
#   'score': 0.2826784,
#   'index': 396,
#   'word': '##с',
#   'start': 481,
#   'end': 482},
#  {'entity': 'PHYS',
#   'score': 0.14522447,
#   'index': 397,
#   'word': '##н',
#   'start': 482,
#   'end': 483},
#  {'entity': 'PHYS',
#   'score': 0.19146095,
#   'index': 398,
#   'word': '##ов',
#   'start': 483,
#   'end': 485},
#  {'entity': 'PHYS',
#   'score': 0.2107111,
#   'index': 399,
#   'word': '##ан',
#   'start': 485,
#   'end': 487},
#  {'entity': 'PHYS',
#   'score': 0.42369986,
#   'index': 400,
#   'word': '##ии',
#   'start': 487,
#   'end': 489},
#  {'entity': 'SCIPROC',
#   'score': 0.6692072,
#   'index': 401,
#   'word': 'о',
#   'start': 490,
#   'end': 491},
#  {'entity': 'PHYS',
#   'score': 0.30223405,
#   'index': 402,
#   'word': '##п',
#   'start': 491,
#   'end': 492},
#  {'entity': 'PHYS',
#   'score': 0.4591318,
#   'index': 403,
#   'word': '##р',
#   'start': 492,
#   'end': 493},
#  {'entity': 'PHYS',
#   'score': 0.5029268,
#   'index': 404,
#   'word': '##о',
#   'start': 493,
#   'end': 494},
#  {'entity': 'PHYS',
#   'score': 0.22897798,
#   'index': 405,
#   'word': '##с',
#   'start': 494,
#   'end': 495},
#  {'entity': 'PHYS',
#   'score': 0.20542143,
#   'index': 406,
#   'word': '##а',
#   'start': 495,
#   'end': 496},
#  {'entity': 'PERSON',
#   'score': 0.4152965,
#   'index': 407,
#   'word': 'п',
#   'start': 497,
#   'end': 498},
#  {'entity': 'LIVB',
#   'score': 0.19745643,
#   'index': 408,
#   'word': '##р',
#   'start': 498,
#   'end': 499},
#  {'entity': 'PERSON',
#   'score': 0.4233325,
#   'index': 409,
#   'word': '##о',
#   'start': 499,
#   'end': 500},
#  {'entity': 'PERSON',
#   'score': 0.27806193,
#   'index': 410,
#   'word': '##б',
#   'start': 500,
#   'end': 501},
#  {'entity': 'PERSON',
#   'score': 0.38816148,
#   'index': 411,
#   'word': '##ан',
#   'start': 501,
#   'end': 503},
#  {'entity': 'PERSON',
#   'score': 0.58011943,
#   'index': 412,
#   'word': '##д',
#   'start': 503,
#   'end': 504},
#  {'entity': 'PERSON',
#   'score': 0.6839057,
#   'index': 413,
#   'word': '##ов',
#   'start': 504,
#   'end': 506},
#  {'entity': 'ANATOMY',
#   'score': 0.18671158,
#   'index': 414,
#   'word': 'в',
#   'start': 507,
#   'end': 508},
#  {'entity': 'PERSON',
#   'score': 0.49205616,
#   'index': 415,
#   'word': '##ы',
#   'start': 508,
#   'end': 509},
#  {'entity': 'PERSON',
#   'score': 0.17810653,
#   'index': 416,
#   'word': '##я',
#   'start': 509,
#   'end': 510},
#  {'entity': 'PERSON',
#   'score': 0.34287167,
#   'index': 417,
#   'word': '##в',
#   'start': 510,
#   'end': 511},
#  {'entity': 'PERSON',
#   'score': 0.52415895,
#   'index': 418,
#   'word': '##л',
#   'start': 511,
#   'end': 512},
#  {'entity': 'PERSON',
#   'score': 0.28560993,
#   'index': 419,
#   'word': '##я',
#   'start': 512,
#   'end': 513},
#  {'entity': 'DISO',
#   'score': 0.26359615,
#   'index': 420,
#   'word': '##л',
#   'start': 513,
#   'end': 514},
#  {'entity': 'DATE',
#   'score': 0.5692352,
#   'index': 421,
#   'word': '##и',
#   'start': 514,
#   'end': 515},
#  {'entity': 'DISO',
#   'score': 0.25962076,
#   'index': 422,
#   'word': 'е',
#   'start': 516,
#   'end': 517},
#  {'entity': 'PERSON',
#   'score': 0.1673155,
#   'index': 423,
#   'word': '##г',
#   'start': 517,
#   'end': 518},
#  {'entity': 'DATE',
#   'score': 0.2869906,
#   'index': 424,
#   'word': '##о',
#   'start': 518,
#   'end': 519},
#  {'entity': 'PERSON',
#   'score': 0.92580897,
#   'index': 425,
#   'word': 'р',
#   'start': 520,
#   'end': 521},
#  {'entity': 'PERSON',
#   'score': 0.37759024,
#   'index': 426,
#   'word': '##о',
#   'start': 521,
#   'end': 522},
#  {'entity': 'PERSON',
#   'score': 0.34375972,
#   'index': 427,
#   'word': '##д',
#   'start': 522,
#   'end': 523},
#  {'entity': 'SCIPROC',
#   'score': 0.3103627,
#   'index': 428,
#   'word': '##с',
#   'start': 523,
#   'end': 524},
#  {'entity': 'SCIPROC',
#   'score': 0.12905537,
#   'index': 429,
#   'word': '##т',
#   'start': 524,
#   'end': 525},
#  {'entity': 'PERSON',
#   'score': 0.23774727,
#   'index': 430,
#   'word': '##в',
#   'start': 525,
#   'end': 526},
#  {'entity': 'PERSON',
#   'score': 0.27189243,
#   'index': 431,
#   'word': '##е',
#   'start': 526,
#   'end': 527},
#  {'entity': 'PERSON',
#   'score': 0.35896435,
#   'index': 432,
#   'word': '##н',
#   'start': 527,
#   'end': 528},
#  {'entity': 'ANATOMY',
#   'score': 0.09633454,
#   'index': 433,
#   'word': '##н',
#   'start': 528,
#   'end': 529},
#  {'entity': 'PERSON',
#   'score': 0.16045032,
#   'index': 434,
#   'word': '##и',
#   'start': 529,
#   'end': 530},
#  {'entity': 'PERSON',
#   'score': 0.09659437,
#   'index': 435,
#   'word': '##к',
#   'start': 530,
#   'end': 531},
#  {'entity': 'PERSON',
#   'score': 0.4300875,
#   'index': 436,
#   'word': '##ов',
#   'start': 531,
#   'end': 533},
#  {'entity': 'DATE',
#   'score': 0.18692262,
#   'index': 437,
#   'word': ',',
#   'start': 533,
#   'end': 534},
#  {'entity': 'ANATOMY',
#   'score': 0.55910337,
#   'index': 438,
#   'word': 'к',
#   'start': 535,
#   'end': 536},
#  {'entity': 'DISO',
#   'score': 0.15007012,
#   'index': 439,
#   'word': '##о',
#   'start': 536,
#   'end': 537},
#  {'entity': 'ANATOMY',
#   'score': 0.22269422,
#   'index': 440,
#   'word': '##т',
#   'start': 537,
#   'end': 538},
#  {'entity': 'ANATOMY',
#   'score': 0.25514695,
#   'index': 441,
#   'word': '##о',
#   'start': 538,
#   'end': 539},
#  {'entity': 'ANATOMY',
#   'score': 0.21988283,
#   'index': 442,
#   'word': '##р',
#   'start': 539,
#   'end': 540},
#  {'entity': 'PERSON',
#   'score': 0.35742518,
#   'index': 443,
#   'word': '##ы',
#   'start': 540,
#   'end': 541},
#  {'entity': 'DATE',
#   'score': 0.44898215,
#   'index': 444,
#   'word': '##е',
#   'start': 541,
#   'end': 542},
#  {'entity': 'SCIPROC',
#   'score': 0.36276248,
#   'index': 445,
#   'word': 'м',
#   'start': 543,
#   'end': 544},
#  {'entity': 'SCIPROC',
#   'score': 0.24781871,
#   'index': 446,
#   'word': '##о',
#   'start': 544,
#   'end': 545},
#  {'entity': 'PHYS',
#   'score': 0.14545552,
#   'index': 447,
#   'word': '##г',
#   'start': 545,
#   'end': 546},
#  {'entity': 'DISO',
#   'score': 0.19591065,
#   'index': 448,
#   'word': '##л',
#   'start': 546,
#   'end': 547},
#  {'entity': 'DATE',
#   'score': 0.30719608,
#   'index': 449,
#   'word': '##и',
#   'start': 547,
#   'end': 548},
#  {'entity': 'SCIPROC',
#   'score': 0.4718283,
#   'index': 450,
#   'word': 'у',
#   'start': 549,
#   'end': 550},
#  {'entity': 'SCIPROC',
#   'score': 0.5278905,
#   'index': 451,
#   'word': '##на',
#   'start': 550,
#   'end': 552},
#  {'entity': 'SCIPROC',
#   'score': 0.4677355,
#   'index': 452,
#   'word': '##с',
#   'start': 552,
#   'end': 553},
#  {'entity': 'SCIPROC',
#   'score': 0.3038413,
#   'index': 453,
#   'word': '##л',
#   'start': 553,
#   'end': 554},
#  {'entity': 'PHYS',
#   'score': 0.36691824,
#   'index': 454,
#   'word': '##е',
#   'start': 554,
#   'end': 555},
#  {'entity': 'SCIPROC',
#   'score': 0.270167,
#   'index': 455,
#   'word': '##д',
#   'start': 555,
#   'end': 556},
#  {'entity': 'PHYS',
#   'score': 0.19251737,
#   'index': 456,
#   'word': '##ов',
#   'start': 556,
#   'end': 558},
#  {'entity': 'PHYS',
#   'score': 0.18353881,
#   'index': 457,
#   'word': '##а',
#   'start': 558,
#   'end': 559},
#  {'entity': 'PHYS',
#   'score': 0.15148899,
#   'index': 458,
#   'word': '##т',
#   'start': 559,
#   'end': 560},
#  {'entity': 'DATE',
#   'score': 0.53795177,
#   'index': 459,
#   'word': '##ь',
#   'start': 560,
#   'end': 561},
#  {'entity': 'PHYS',
#   'score': 0.74072534,
#   'index': 460,
#   'word': 'м',
#   'start': 562,
#   'end': 563},
#  {'entity': 'PHYS',
#   'score': 0.21897289,
#   'index': 461,
#   'word': '##у',
#   'start': 563,
#   'end': 564},
#  {'entity': 'INJURY_POISONING',
#   'score': 0.10446337,
#   'index': 462,
#   'word': '##т',
#   'start': 564,
#   'end': 565},
#  {'entity': 'PERSON',
#   'score': 0.11585882,
#   'index': 463,
#   'word': '##ан',
#   'start': 565,
#   'end': 567},
#  {'entity': 'ORGANIZATION',
#   'score': 0.12497509,
#   'index': 464,
#   'word': '##т',
#   'start': 567,
#   'end': 568},
#  {'entity': 'PERSON',
#   'score': 0.47704098,
#   'index': 465,
#   'word': '##н',
#   'start': 568,
#   'end': 569},
#  {'entity': 'PHYS',
#   'score': 0.1483099,
#   'index': 466,
#   'word': '##ы',
#   'start': 569,
#   'end': 570},
#  {'entity': 'DATE',
#   'score': 0.18024369,
#   'index': 467,
#   'word': '##и',
#   'start': 570,
#   'end': 571},
#  {'entity': 'GENE',
#   'score': 0.7133665,
#   'index': 468,
#   'word': 'г',
#   'start': 572,
#   'end': 573},
#  {'entity': 'PERSON',
#   'score': 0.15768415,
#   'index': 469,
#   'word': '##е',
#   'start': 573,
#   'end': 574},
#  {'entity': 'PERSON',
#   'score': 0.33898446,
#   'index': 470,
#   'word': '##н',
#   'start': 574,
#   'end': 575},
#  {'entity': 'DATE',
#   'score': 0.1388766,
#   'index': 471,
#   'word': '.',
#   'start': 575,
#   'end': 576},
#  {'entity': 'DISO',
#   'score': 0.5412482,
#   'index': 472,
#   'word': 'р',
#   'start': 577,
#   'end': 578},
#  {'entity': 'PHYS',
#   'score': 0.2887662,
#   'index': 473,
#   'word': '##е',
#   'start': 578,
#   'end': 579},
#  {'entity': 'PHYS',
#   'score': 0.3839993,
#   'index': 474,
#   'word': '##з',
#   'start': 579,
#   'end': 580},
#  {'entity': 'PHYS',
#   'score': 0.31388828,
#   'index': 475,
#   'word': '##у',
#   'start': 580,
#   'end': 581},
#  {'entity': 'PHYS',
#   'score': 0.1404834,
#   'index': 476,
#   'word': '##л',
#   'start': 581,
#   'end': 582},
#  {'entity': 'SCIPROC',
#   'score': 0.16279714,
#   'index': 477,
#   'word': '##ь',
#   'start': 582,
#   'end': 583},
#  {'entity': 'PERSON',
#   'score': 0.21746323,
#   'index': 478,
#   'word': '##т',
#   'start': 583,
#   'end': 584},
#  {'entity': 'PERSON',
#   'score': 0.24328117,
#   'index': 479,
#   'word': '##а',
#   'start': 584,
#   'end': 585},
#  {'entity': 'PERSON',
#   'score': 0.36221227,
#   'index': 480,
#   'word': '##т',
#   'start': 585,
#   'end': 586},
#  {'entity': 'PERSON',
#   'score': 0.40099993,
#   'index': 481,
#   'word': '##ы',
#   'start': 586,
#   'end': 587},
#  {'entity': 'DATE',
#   'score': 0.42913193,
#   'index': 482,
#   'word': '.',
#   'start': 587,
#   'end': 588},
#  {'entity': 'DATE',
#   'score': 0.6684652,
#   'index': 483,
#   'word': 'у',
#   'start': 589,
#   'end': 590},
#  {'entity': 'AGE',
#   'score': 0.9340517,
#   'index': 484,
#   'word': '50',
#   'start': 591,
#   'end': 593},
#  {'entity': 'PERCENT',
#   'score': 0.5787838,
#   'index': 485,
#   'word': '(',
#   'start': 594,
#   'end': 595},
#  {'entity': 'PERCENT',
#   'score': 0.98534507,
#   'index': 486,
#   'word': '24',
#   'start': 595,
#   'end': 597},
#  {'entity': 'PERCENT',
#   'score': 0.9483237,
#   'index': 487,
#   'word': ',',
#   'start': 597,
#   'end': 598},
#  {'entity': 'PERCENT',
#   'score': 0.98862773,
#   'index': 488,
#   'word': '9',
#   'start': 598,
#   'end': 599},
#  {'entity': 'PERCENT',
#   'score': 0.93476385,
#   'index': 489,
#   'word': '%',
#   'start': 599,
#   'end': 600},
#  {'entity': 'NUMBER',
#   'score': 0.14882724,
#   'index': 490,
#   'word': ')',
#   'start': 600,
#   'end': 601},
#  {'entity': 'DISO',
#   'score': 0.5596037,
#   'index': 491,
#   'word': 'и',
#   'start': 602,
#   'end': 603},
#  {'entity': 'NUMBER',
#   'score': 0.20716825,
#   'index': 492,
#   'word': '##з',
#   'start': 603,
#   'end': 604},
#  {'entity': 'NUMBER',
#   'score': 0.80268484,
#   'index': 493,
#   'word': '201',
#   'start': 605,
#   'end': 608},
#  {'entity': 'PERSON',
#   'score': 0.4870367,
#   'index': 494,
#   'word': 'о',
#   'start': 609,
#   'end': 610},
#  {'entity': 'PERSON',
#   'score': 0.3872086,
#   'index': 495,
#   'word': '##б',
#   'start': 610,
#   'end': 611},
#  {'entity': 'SCIPROC',
#   'score': 0.34378633,
#   'index': 496,
#   'word': '##с',
#   'start': 611,
#   'end': 612},
#  {'entity': 'SCIPROC',
#   'score': 0.25906086,
#   'index': 497,
#   'word': '##л',
#   'start': 612,
#   'end': 613},
#  {'entity': 'PHYS',
#   'score': 0.22210076,
#   'index': 498,
#   'word': '##е',
#   'start': 613,
#   'end': 614},
#  {'entity': 'PERSON',
#   'score': 0.46809876,
#   'index': 499,
#   'word': '##д',
#   'start': 614,
#   'end': 615},
#  {'entity': 'PERSON',
#   'score': 0.38873693,
#   'index': 500,
#   'word': '##ов',
#   'start': 615,
#   'end': 617},
#  {'entity': 'PERSON',
#   'score': 0.5706273,
#   'index': 501,
#   'word': '##ан',
#   'start': 617,
#   'end': 619},
#  {'entity': 'PERSON',
#   'score': 0.8783956,
#   'index': 502,
#   'word': '##н',
#   'start': 619,
#   'end': 620},
#  {'entity': 'PERSON',
#   'score': 0.63948363,
#   'index': 503,
#   'word': '##ы',
#   'start': 620,
#   'end': 621},
#  {'entity': 'PERSON',
#   'score': 0.35158864,
#   'index': 504,
#   'word': '##х',
#   'start': 621,
#   'end': 622},
#  {'entity': 'PERSON',
#   'score': 0.99646544,
#   'index': 505,
#   'word': 'п',
#   'start': 623,
#   'end': 624},
#  {'entity': 'PERSON',
#   'score': 0.86376816,
#   'index': 506,
#   'word': '##а',
#   'start': 624,
#   'end': 625},
#  {'entity': 'PERSON',
#   'score': 0.3127214,
#   'index': 507,
#   'word': '##ц',
#   'start': 625,
#   'end': 626},
#  {'entity': 'PERSON',
#   'score': 0.31698185,
#   'index': 508,
#   'word': '##и',
#   'start': 626,
#   'end': 627},
#  {'entity': 'PERSON',
#   'score': 0.17923993,
#   'index': 509,
#   'word': '##е',
#   'start': 627,
#   'end': 628},
#  {'entity': 'PERSON',
#   'score': 0.593492,
#   'index': 510,
#   'word': '##н',
#   'start': 628,
#   'end': 629}]
